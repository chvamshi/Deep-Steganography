# %% [markdown]
# <a href="https://colab.research.google.com/github/chvamshi/Deep-Steganography/blob/main/Copy_of_LOSS2_DS_img_crop_50_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget http://cs231n.stanford.edu/tiny-imagenet-200.zip
# !unzip -q tiny-imagenet-200.zip && ls tiny-imagenet-200
# Out:
# --2022-02-08 20:36:46--  http://cs231n.stanford.edu/tiny-imagenet-200.zip
# Resolving cs231n.stanford.edu (cs231n.stanford.edu)... 171.64.68.10
# Connecting to cs231n.stanford.edu (cs231n.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248100043 (237M) [application/zip]
# Saving to: ‘tiny-imagenet-200.zip’
#
# tiny-imagenet-200.z 100%[===================>] 236.61M  69.9MB/s    in 3.7s
#
# 2022-02-08 20:36:50 (63.4 MB/s) - ‘tiny-imagenet-200.zip’ saved [248100043/248100043]
#
# test  train  val  wnids.txt  words.txt

# %%
# Imports necessary libraries and modules
from itertools import islice
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch.autograd import Variable
from torch import utils
from torch.utils.data import Subset
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import os 
from pathlib import Path
import pickle
import random
from torchvision import datasets, utils
import torchvision.transforms as transforms
from torchvision.transforms import ToPILImage
from torchvision.transforms import RandomResizedCrop
from torchvision.transforms.functional import resized_crop
from random import shuffle
from IPython.display import Image
from PIL import Image

# Use GPU if it is present
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
# Directory path
# os.chdir("..")
cwd = '/content/tiny-imagenet-200'

# Hyper Parameters
num_epochs = 50
batch_size = 32
learning_rate = 0.001
beta = 1

# Mean and std deviation of imagenet dataset. Source: http://cs231n.stanford.edu/reports/2017/pdfs/101.pdf
std = [0.229, 0.224, 0.225]
mean = [0.485, 0.456, 0.406]

# TODO: Define train, validation and models
MODELS_PATH = '/content/output/models'
# TRAIN_PATH = cwd+'/train/'
# VALID_PATH = cwd+'/valid/'
VALID_PATH = cwd+'/val/'
TRAIN_PATH = cwd+'/train/'
TEST_PATH = cwd+'/test/'

# if not os.path.exists(MODELS_PATH): os.mkdir(MODELS_PATH)

# %%
def variance(image1, image2):
    var1 = torch.var(image2-image1)
    # var2 = torch.var(image2)

    return var1

def customized_loss(S_prime, C_prime, S, C, B):
    ''' Calculates loss specified on the paper.'''
    
    loss_cover = torch.nn.functional.l1_loss(C_prime, C)
    # loss_cover = loss_cover/(64*64)
    loss_secret = torch.nn.functional.l1_loss(S_prime, S)
    # loss_secret = loss_secret/(64*64)

    variance_cover = variance(C_prime, C)
    variance_secret = variance(S_prime, S)

    loss_all = loss_cover+loss_secret+variance_cover+variance_secret
    loss_all = loss_all/4

    return loss_all, loss_cover, loss_secret

def denormalize(image, std, mean):
    ''' Denormalizes a tensor of images.'''

    for t in range(3):
        image[t, :, :] = (image[t, :, :] * std[t]) + mean[t]
    return image

def imshow(img, idx, learning_rate, beta):
    '''Prints out an image given in tensor format.'''
    
    img = denormalize(img, std, mean)
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.title('Example '+str(idx)+', lr='+str(learning_rate)+', B='+str(beta))
    plt.show()
    return

def gaussian(tensor, mean=0, stddev=0.1):
    '''Adds random noise to a tensor.'''
    
    noise = torch.nn.init.normal(torch.Tensor(tensor.size()), 0, 0.1).to(device)
    return Variable(tensor + noise)

def tensor_to_image(tensor):
    """
    Transforms a torch tensor into numpy uint8 array (image)
    :param tensor: (batch_size x channels x height x width) torch tensor in range [-1.0, 1.0]
    :return: (batch_size x height x width x channels) uint8 array
    """
    image = tensor.cpu().numpy()[0]
    # image = tensor.permute(0, 2, 3, 1).cpu().numpy()
    image = np.transpose(image, (1,2,0))
    image = (image + 1) * 127.5
    return np.clip(image, 0, 255).astype(np.uint8)

# %%
import torch.nn as nn
import numpy as np

def random_float(min, max):
    """
    Return a random number
    :param min:
    :param max:
    :return:
    """
    return np.random.rand() * (max - min) + min


def get_random_rectangle_inside(image, height_ratio_range, width_ratio_range):
    """
    Returns a random rectangle inside the image, where the size is random and is controlled by height_ratio_range and width_ratio_range.
    This is analogous to a random crop. For example, if height_ratio_range is (0.7, 0.9), then a random number in that range will be chosen
    (say it is 0.75 for illustration), and the image will be cropped such that the remaining height equals 0.75. In fact,
    a random 'starting' position rs will be chosen from (0, 0.25), and the crop will start at rs and end at rs + 0.75. This ensures
    that we crop from top/bottom with equal probability.
    The same logic applies to the width of the image, where width_ratio_range controls the width crop range.
    :param image: The image we want to crop
    :param height_ratio_range: The range of remaining height ratio
    :param width_ratio_range:  The range of remaining width ratio.
    :return: "Cropped" rectange with width and height drawn randomly height_ratio_range and width_ratio_range
    """
    # print(image.shape)
    image_height = image.shape[1]
    image_width = image.shape[2]

    remaining_height = int(np.rint(random_float(height_ratio_range[0], height_ratio_range[1]) * image_height))
    remaining_width = int(np.rint(random_float(width_ratio_range[0], width_ratio_range[0]) * image_width))

    if remaining_height == image_height:
        height_start = 0
    else:
        height_start = np.random.randint(0, image_height - remaining_height)

    if remaining_width == image_width:
        width_start = 0
    else:
        width_start = np.random.randint(0, image_width - remaining_width)

    return height_start, height_start+remaining_height, width_start, width_start+remaining_width


class Crop(nn.Module):
    """
    Randomly crops the image from top/bottom and left/right. The amount to crop is controlled by parameters
    heigth_ratio_range and width_ratio_range
    """
    def __init__(self, height_ratio_range, width_ratio_range):
        """
        :param height_ratio_range:
        :param width_ratio_range:
        """
        super(Crop, self).__init__()
        self.height_ratio_range = height_ratio_range
        self.width_ratio_range = width_ratio_range


    def forward(self, noised_and_cover):
        noised_image = noised_and_cover[0]
        print("Noisedimageshape: ",noised_image.shape)
        shape = noised_image.shape
        # crop_rectangle is in form (from, to) where @from and @to are 2D points -- (height, width)

        h_start, h_end, w_start, w_end = get_random_rectangle_inside(noised_image, self.height_ratio_range, self.width_ratio_range)

        noised_image =  noised_image[
               :,
               h_start: h_end,
               w_start: w_end].clone()
        noised_image1 = noised_image.expand(-1,64,64)
        print(noised_image1.shape)
        noised_and_cover[0] = noised_image1.clone()

        return noised_and_cover

# %%
# Preparation Network (2 conv layers)
class PrepNetwork(nn.Module):
    def __init__(self):
        super(PrepNetwork, self).__init__()
        self.initialP3 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialP4 = nn.Sequential(
            nn.Conv2d(3, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialP5 = nn.Sequential(
            nn.Conv2d(3, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalP3 = nn.Sequential(
            nn.Conv2d(65, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalP4 = nn.Sequential(
            nn.Conv2d(65, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalP5 = nn.Sequential(
            nn.Conv2d(65, 5, kernel_size=5, padding=2),
            nn.ReLU())

    def forward(self, p):
        p1 = self.initialP3(p)
        p2 = self.initialP4(p)
        p3 = self.initialP5(p)
        mid = torch.cat((p1, p2, p3), 1)
        p4 = self.finalP3(mid)
        p5 = self.finalP4(mid)
        p6 = self.finalP5(mid)
        # print(p4.shape)
        # print(p5.shape)
        # print(p6.shape)
        out = torch.cat((p4, p5, p6), 1)
        return out

# Hiding Network (5 conv layers)
class HidingNetwork(nn.Module):
    def __init__(self):
        super(HidingNetwork, self).__init__()
        self.initialH3 = nn.Sequential(
            nn.Conv2d(68, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialH4 = nn.Sequential(
            nn.Conv2d(68, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialH5 = nn.Sequential(
            nn.Conv2d(68, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalH3 = nn.Sequential(
            nn.Conv2d(65, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalH4 = nn.Sequential(
            nn.Conv2d(65, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalH5 = nn.Sequential(
            nn.Conv2d(65, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalH = nn.Sequential(
            nn.Conv2d(65, 3, kernel_size=1, padding=0))
        
    def forward(self, h):
        h1 = self.initialH3(h)
        h2 = self.initialH4(h)
        h3 = self.initialH5(h)
        mid = torch.cat((h1, h2, h3), 1)
        h4 = self.finalH3(mid)
        h5 = self.finalH4(mid)
        h6 = self.finalH5(mid)
        mid2 = torch.cat((h4, h5, h6), 1)
        out = self.finalH(mid2)
        out_noise = gaussian(out.data, 0, 0.1)
        return out, out_noise

# Reveal Network (2 conv layers)
class RevealNetwork(nn.Module):
    def __init__(self):
        super(RevealNetwork, self).__init__()
        self.initialR3 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialR4 = nn.Sequential(
            nn.Conv2d(3, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialR5 = nn.Sequential(
            nn.Conv2d(3, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalR3 = nn.Sequential(
            nn.Conv2d(65, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalR4 = nn.Sequential(
            nn.Conv2d(65, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalR5 = nn.Sequential(
            nn.Conv2d(65, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalR = nn.Sequential(
            nn.Conv2d(65, 3, kernel_size=1, padding=0))

    def forward(self, r, img_shape):
        # r = r.expand(img_shape)
        r1 = self.initialR3(r)
        r2 = self.initialR4(r)
        r3 = self.initialR5(r)
        mid = torch.cat((r1, r2, r3), 1)
        r4 = self.finalR3(mid)
        r5 = self.finalR4(mid)
        r6 = self.finalR5(mid)
        mid2 = torch.cat((r4, r5, r6), 1)
        out = self.finalR(mid2)
        return out

# Join three networks in one module
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.m1 = PrepNetwork().to(device)
        self.m2 = HidingNetwork().to(device)
        self.m3 = RevealNetwork().to(device)
        self.crop = Crop((0.7,0.9),(0.7,0.9)).to(device)

    def forward(self, secret, cover):
        img_shape = secret.shape
        x_1 = self.m1(secret)
        mid = torch.cat((x_1, cover), 1)
        x_2, x_2_noise = self.m2(mid)
        # x_2_noise = resized_crop(img=x_2_noise, top = 0, left=0, height=19, width=19, size=[64,64])
        x_2 =  resized_crop(img=x_2, top = 0, left=0, height=32, width=32, size=[64,64])
        # x_3 = self.m3(x_2_noise, img_shape)
        x_3 = self.m3(x_2, img_shape)
        return x_2, x_3

# %%
# Creates net object
net = Net().to(device)

# %%
# Creates training set
train_data = datasets.ImageFolder(
        TRAIN_PATH,
        transforms.Compose([
        # transforms.Scale(256),
        # transforms.RandomCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean,
        std=std)
        ]))
train_data = Subset(train_data, [i for i in range(32000)])
train_loader = torch.utils.data.DataLoader(
        train_data, batch_size=batch_size, num_workers=1, 
        pin_memory=True, shuffle=True, drop_last=True)

# Creates test set
test_data = datasets.ImageFolder(
        TEST_PATH, 
        transforms.Compose([
        # transforms.Scale(256),
        # transforms.RandomCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean,
        std=std)
        ]))
test_data = Subset(test_data,[i for i in range(5000)])
test_loader = torch.utils.data.DataLoader(
        test_data, batch_size=2, num_workers=1, 
        pin_memory=True, shuffle=True, drop_last=True)

# %%
PATH = "/content/drive/MyDrive/"
loss_history = []

def train_model(train_loader, beta, learning_rate):
    
    # Save optimizer
    optimizer = optim.Adam(net.parameters(), lr=learning_rate)
    
    loss_history = []
    # Iterate over batches performing forward and backward passes
    for epoch in range(num_epochs):

        # Train mode
        net.train()
        
        train_losses = []
        # Train one epoch
        for idx, train_batch in enumerate(train_loader):

            data, _  = train_batch
            data = data.to(device)

            # Saves secret images and secret covers
            train_covers = data[:len(data)//2]
            train_secrets = data[len(data)//2:]
            
            # Creates variable from secret and cover images
            train_secrets = Variable(train_secrets, requires_grad=False)
            train_covers = Variable(train_covers, requires_grad=False)

            # Forward + Backward + Optimize
            optimizer.zero_grad()
            train_hidden, train_output = net(train_secrets, train_covers)

            # Calculate loss and perform backprop
            train_loss, train_loss_cover, train_loss_secret = customized_loss(train_output, train_hidden, train_secrets, train_covers, beta)
            train_loss.backward()
            optimizer.step()
            
            # Saves training loss
            # print(train_loss.data)
            train_losses.append(train_loss.data.item())
            loss_history.append(train_loss.data.item())
            
            # Prints mini-batch losses
            print('Training: Batch {0}/{1}. Loss of {2:.4f}, cover loss of {3:.4f}, secret loss of {4:.4f}'.format(idx+1, len(train_loader), train_loss.data.item(), train_loss_cover.data.item(), train_loss_secret.data.item()))
    
        # Save model
        # torch.save(net.state_dict(), '/content/Epoch N{}.pkl'.format(epoch+1))
        torch.save(net.state_dict(), PATH+"LOSS2_1_ds_crop_50.pth")
        with open(PATH+"LOSS2_1_loss_history_crop_50.txt", "a") as f:
            for s in loss_history:
                f.write(str(s) +"\n")
        
        mean_train_loss = np.mean(train_losses)
    
        # Prints epoch average loss
        print ('Epoch [{0}/{1}], Average_loss: {2:.4f}'.format(
                epoch+1, num_epochs, mean_train_loss))
    
    return net, mean_train_loss, loss_history

# %%
# Load model
# net.load_state_dict(torch.load(PATH+"LOSS2_1_ds_crop_50.pth"))
# loss_history = []
# with open(PATH+"LOSS2_1_loss_history_crop_50.txt", "r") as f:
#   for line in f:
#     loss_history.append(float(line.strip()))

net, mean_train_loss, loss_history = train_model(train_loader, beta, learning_rate)
# loss_history.extend(loss_history1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:43: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
# Streaming output truncated to the last 5000 lines.
# Training: Batch 6/1000. Loss of 0.6630, cover loss of 0.6723, secret loss of 0.5935
# Training: Batch 7/1000. Loss of 0.7089, cover loss of 0.6983, secret loss of 0.6051
# Training: Batch 8/1000. Loss of 0.7131, cover loss of 0.7385, secret loss of 0.5883
# Training: Batch 9/1000. Loss of 0.7073, cover loss of 0.7115, secret loss of 0.6051
# Training: Batch 10/1000. Loss of 0.7222, cover loss of 0.6949, secret loss of 0.6482
# Training: Batch 11/1000. Loss of 0.6833, cover loss of 0.7674, secret loss of 0.5167
# Training: Batch 12/1000. Loss of 0.7356, cover loss of 0.7511, secret loss of 0.5834
# Training: Batch 13/1000. Loss of 0.7072, cover loss of 0.7121, secret loss of 0.6051
# Training: Batch 14/1000. Loss of 0.6850, cover loss of 0.7286, secret loss of 0.5630
# Training: Batch 15/1000. Loss of 0.6817, cover loss of 0.6618, secret loss of 0.6047
# Training: Batch 16/1000. Loss of 0.6932, cover loss of 0.7560, secret loss of 0.5320
# Training: Batch 17/1000. Loss of 0.7261, cover loss of 0.7693, secret loss of 0.5514
# Training: Batch 18/1000. Loss of 0.7663, cover loss of 0.7799, secret loss of 0.5934
# Training: Batch 19/1000. Loss of 0.7372, cover loss of 0.7353, secret loss of 0.6159
# Training: Batch 20/1000. Loss of 0.6885, cover loss of 0.7034, secret loss of 0.5995
# Training: Batch 21/1000. Loss of 0.7240, cover loss of 0.7419, secret loss of 0.5951
# Training: Batch 22/1000. Loss of 0.6942, cover loss of 0.7002, secret loss of 0.5895
# Training: Batch 23/1000. Loss of 0.6998, cover loss of 0.6524, secret loss of 0.6580
# Training: Batch 24/1000. Loss of 0.6525, cover loss of 0.6541, secret loss of 0.5843
# Training: Batch 25/1000. Loss of 0.7784, cover loss of 0.7874, secret loss of 0.6161
# Training: Batch 26/1000. Loss of 0.6993, cover loss of 0.6639, secret loss of 0.6556
# Training: Batch 27/1000. Loss of 0.7499, cover loss of 0.7882, secret loss of 0.5875
# Training: Batch 28/1000. Loss of 0.6912, cover loss of 0.7479, secret loss of 0.5379
# Training: Batch 29/1000. Loss of 0.7507, cover loss of 0.7625, secret loss of 0.6153
# Training: Batch 30/1000. Loss of 0.7805, cover loss of 0.7926, secret loss of 0.6033
# Training: Batch 31/1000. Loss of 0.6904, cover loss of 0.6886, secret loss of 0.6048
# Training: Batch 32/1000. Loss of 0.6999, cover loss of 0.6605, secret loss of 0.6584
# Training: Batch 33/1000. Loss of 0.6822, cover loss of 0.7120, secret loss of 0.5649
# Training: Batch 34/1000. Loss of 0.7388, cover loss of 0.7598, secret loss of 0.5689
# Training: Batch 35/1000. Loss of 0.6677, cover loss of 0.6721, secret loss of 0.6001
# Training: Batch 36/1000. Loss of 0.6766, cover loss of 0.7437, secret loss of 0.5445
# Training: Batch 37/1000. Loss of 0.6942, cover loss of 0.7345, secret loss of 0.5554
# Training: Batch 38/1000. Loss of 0.6999, cover loss of 0.7313, secret loss of 0.5682
# Training: Batch 39/1000. Loss of 0.7363, cover loss of 0.7019, secret loss of 0.6509
# Training: Batch 40/1000. Loss of 0.6944, cover loss of 0.6742, secret loss of 0.6074
# Training: Batch 41/1000. Loss of 0.7034, cover loss of 0.6685, secret loss of 0.6391
# Training: Batch 42/1000. Loss of 0.6697, cover loss of 0.6682, secret loss of 0.6128
# Training: Batch 43/1000. Loss of 0.6895, cover loss of 0.7056, secret loss of 0.5887
# Training: Batch 44/1000. Loss of 0.7104, cover loss of 0.6521, secret loss of 0.6535
# Training: Batch 45/1000. Loss of 0.7639, cover loss of 0.7293, secret loss of 0.6545
# Training: Batch 46/1000. Loss of 0.7115, cover loss of 0.8058, secret loss of 0.5290
# Training: Batch 47/1000. Loss of 0.6744, cover loss of 0.7201, secret loss of 0.5397
# Training: Batch 48/1000. Loss of 0.7213, cover loss of 0.6858, secret loss of 0.6560
# Training: Batch 49/1000. Loss of 0.6723, cover loss of 0.6823, secret loss of 0.5921
# Training: Batch 50/1000. Loss of 0.7841, cover loss of 0.7533, secret loss of 0.6547
# Training: Batch 51/1000. Loss of 0.6925, cover loss of 0.6813, secret loss of 0.6069
# Training: Batch 52/1000. Loss of 0.7059, cover loss of 0.7170, secret loss of 0.6157
# Training: Batch 53/1000. Loss of 0.7662, cover loss of 0.7589, secret loss of 0.6321
# Training: Batch 54/1000. Loss of 0.7032, cover loss of 0.7383, secret loss of 0.5742
# Training: Batch 55/1000. Loss of 0.7251, cover loss of 0.7299, secret loss of 0.6144
# Training: Batch 56/1000. Loss of 0.7389, cover loss of 0.7054, secret loss of 0.6518
# Training: Batch 57/1000. Loss of 0.7453, cover loss of 0.7409, secret loss of 0.6286
# Training: Batch 58/1000. Loss of 0.6306, cover loss of 0.6580, secret loss of 0.5489
# Training: Batch 59/1000. Loss of 0.7207, cover loss of 0.6941, secret loss of 0.5962
# Training: Batch 60/1000. Loss of 0.6870, cover loss of 0.6825, secret loss of 0.6057
# Training: Batch 61/1000. Loss of 0.6588, cover loss of 0.7061, secret loss of 0.5421
# Training: Batch 62/1000. Loss of 0.6880, cover loss of 0.7321, secret loss of 0.5567
# Training: Batch 63/1000. Loss of 0.7683, cover loss of 0.8031, secret loss of 0.5908
# Training: Batch 64/1000. Loss of 0.7165, cover loss of 0.7453, secret loss of 0.5653
# Training: Batch 65/1000. Loss of 0.7544, cover loss of 0.7207, secret loss of 0.6653
# Training: Batch 66/1000. Loss of 0.6744, cover loss of 0.7123, secret loss of 0.5270
# Training: Batch 67/1000. Loss of 0.7082, cover loss of 0.7333, secret loss of 0.5931
# Training: Batch 68/1000. Loss of 0.7071, cover loss of 0.6740, secret loss of 0.6351
# Training: Batch 69/1000. Loss of 0.7440, cover loss of 0.7116, secret loss of 0.6374
# Training: Batch 70/1000. Loss of 0.7178, cover loss of 0.7468, secret loss of 0.5749
# Training: Batch 71/1000. Loss of 0.7031, cover loss of 0.7255, secret loss of 0.5853
# Training: Batch 72/1000. Loss of 0.7433, cover loss of 0.7499, secret loss of 0.5975
# Training: Batch 73/1000. Loss of 0.6866, cover loss of 0.7182, secret loss of 0.5584
# Training: Batch 74/1000. Loss of 0.6766, cover loss of 0.6810, secret loss of 0.6056
# Training: Batch 75/1000. Loss of 0.7478, cover loss of 0.7851, secret loss of 0.5949
# Training: Batch 76/1000. Loss of 0.6616, cover loss of 0.6804, secret loss of 0.5827
# Training: Batch 77/1000. Loss of 0.5994, cover loss of 0.6265, secret loss of 0.5394
# Training: Batch 78/1000. Loss of 0.7015, cover loss of 0.6817, secret loss of 0.6454
# Training: Batch 79/1000. Loss of 0.7543, cover loss of 0.7428, secret loss of 0.6369
# Training: Batch 80/1000. Loss of 0.6716, cover loss of 0.6868, secret loss of 0.5782
# Training: Batch 81/1000. Loss of 0.6990, cover loss of 0.6503, secret loss of 0.6687
# Training: Batch 82/1000. Loss of 0.7017, cover loss of 0.7020, secret loss of 0.6159
# Training: Batch 83/1000. Loss of 0.7778, cover loss of 0.7510, secret loss of 0.6585
# Training: Batch 84/1000. Loss of 0.6752, cover loss of 0.7145, secret loss of 0.5683
# Training: Batch 85/1000. Loss of 0.7083, cover loss of 0.7338, secret loss of 0.5616
# Training: Batch 86/1000. Loss of 0.7446, cover loss of 0.7344, secret loss of 0.6190
# Training: Batch 87/1000. Loss of 0.6634, cover loss of 0.7079, secret loss of 0.5549
# Training: Batch 88/1000. Loss of 0.7121, cover loss of 0.7313, secret loss of 0.6124
# Training: Batch 89/1000. Loss of 0.7206, cover loss of 0.6841, secret loss of 0.6615
# Training: Batch 90/1000. Loss of 0.7104, cover loss of 0.7370, secret loss of 0.5814
# Training: Batch 91/1000. Loss of 0.7660, cover loss of 0.7463, secret loss of 0.6445
# Training: Batch 92/1000. Loss of 0.7260, cover loss of 0.7075, secret loss of 0.6281
# Training: Batch 93/1000. Loss of 0.6505, cover loss of 0.6795, secret loss of 0.5702
# Training: Batch 94/1000. Loss of 0.6753, cover loss of 0.6686, secret loss of 0.5968
# Training: Batch 95/1000. Loss of 0.7919, cover loss of 0.7969, secret loss of 0.6162
# Training: Batch 96/1000. Loss of 0.6830, cover loss of 0.6920, secret loss of 0.5813
# Training: Batch 97/1000. Loss of 0.7102, cover loss of 0.7169, secret loss of 0.5993
# Training: Batch 98/1000. Loss of 0.7339, cover loss of 0.7234, secret loss of 0.6263
# Training: Batch 99/1000. Loss of 0.6780, cover loss of 0.6784, secret loss of 0.6045
# Training: Batch 100/1000. Loss of 0.7291, cover loss of 0.7360, secret loss of 0.5947
# Training: Batch 101/1000. Loss of 0.7205, cover loss of 0.7285, secret loss of 0.6206
# Training: Batch 102/1000. Loss of 0.7290, cover loss of 0.7254, secret loss of 0.6210
# Training: Batch 103/1000. Loss of 0.7067, cover loss of 0.6883, secret loss of 0.6314
# Training: Batch 104/1000. Loss of 0.7244, cover loss of 0.7561, secret loss of 0.5936
# Training: Batch 105/1000. Loss of 0.7595, cover loss of 0.7522, secret loss of 0.6237
# Training: Batch 106/1000. Loss of 0.5970, cover loss of 0.5693, secret loss of 0.5917
# Training: Batch 107/1000. Loss of 0.6894, cover loss of 0.6615, secret loss of 0.6531
# Training: Batch 108/1000. Loss of 0.6884, cover loss of 0.7436, secret loss of 0.5545
# Training: Batch 109/1000. Loss of 0.7251, cover loss of 0.7115, secret loss of 0.6082
# Training: Batch 110/1000. Loss of 0.6593, cover loss of 0.7146, secret loss of 0.5477
# Training: Batch 111/1000. Loss of 0.7386, cover loss of 0.6761, secret loss of 0.6437
# Training: Batch 112/1000. Loss of 0.7411, cover loss of 0.7063, secret loss of 0.6379
# Training: Batch 113/1000. Loss of 0.7973, cover loss of 0.7106, secret loss of 0.6981
# Training: Batch 114/1000. Loss of 0.7329, cover loss of 0.7151, secret loss of 0.6415
# Training: Batch 115/1000. Loss of 0.7429, cover loss of 0.7478, secret loss of 0.6277
# Training: Batch 116/1000. Loss of 0.7143, cover loss of 0.7432, secret loss of 0.5818
# Training: Batch 117/1000. Loss of 0.7127, cover loss of 0.6595, secret loss of 0.6305
# Training: Batch 118/1000. Loss of 0.7228, cover loss of 0.7563, secret loss of 0.5957
# Training: Batch 119/1000. Loss of 0.7507, cover loss of 0.7000, secret loss of 0.6694
# Training: Batch 120/1000. Loss of 0.7685, cover loss of 0.7646, secret loss of 0.6373
# Training: Batch 121/1000. Loss of 0.7068, cover loss of 0.7698, secret loss of 0.5494
# Training: Batch 122/1000. Loss of 0.6804, cover loss of 0.6668, secret loss of 0.5995
# Training: Batch 123/1000. Loss of 0.7235, cover loss of 0.6821, secret loss of 0.6566
# Training: Batch 124/1000. Loss of 0.6516, cover loss of 0.6529, secret loss of 0.5944
# Training: Batch 125/1000. Loss of 0.7180, cover loss of 0.7259, secret loss of 0.6026
# Training: Batch 126/1000. Loss of 0.7506, cover loss of 0.7327, secret loss of 0.6434
# Training: Batch 127/1000. Loss of 0.6406, cover loss of 0.6571, secret loss of 0.5430
# Training: Batch 128/1000. Loss of 0.7369, cover loss of 0.7373, secret loss of 0.5915
# Training: Batch 129/1000. Loss of 0.6773, cover loss of 0.7256, secret loss of 0.5529
# Training: Batch 130/1000. Loss of 0.6429, cover loss of 0.6872, secret loss of 0.5499
# Training: Batch 131/1000. Loss of 0.7363, cover loss of 0.7154, secret loss of 0.6264
# Training: Batch 132/1000. Loss of 0.7037, cover loss of 0.7048, secret loss of 0.6122
# Training: Batch 133/1000. Loss of 0.7330, cover loss of 0.7064, secret loss of 0.6416
# Training: Batch 134/1000. Loss of 0.7242, cover loss of 0.7757, secret loss of 0.5647
# Training: Batch 135/1000. Loss of 0.6722, cover loss of 0.6864, secret loss of 0.5875
# Training: Batch 136/1000. Loss of 0.6968, cover loss of 0.7197, secret loss of 0.5849
# Training: Batch 137/1000. Loss of 0.7472, cover loss of 0.7934, secret loss of 0.5889
# Training: Batch 138/1000. Loss of 0.7377, cover loss of 0.7507, secret loss of 0.6046
# Training: Batch 139/1000. Loss of 0.6592, cover loss of 0.6718, secret loss of 0.5845
# Training: Batch 140/1000. Loss of 0.7831, cover loss of 0.7955, secret loss of 0.6115
# Training: Batch 141/1000. Loss of 0.6672, cover loss of 0.6777, secret loss of 0.5777
# Training: Batch 142/1000. Loss of 0.7699, cover loss of 0.7936, secret loss of 0.6060
# Training: Batch 143/1000. Loss of 0.7781, cover loss of 0.8158, secret loss of 0.5669
# Training: Batch 144/1000. Loss of 0.6331, cover loss of 0.6890, secret loss of 0.5307
# Training: Batch 145/1000. Loss of 0.7351, cover loss of 0.7820, secret loss of 0.5691
# Training: Batch 146/1000. Loss of 0.6395, cover loss of 0.6802, secret loss of 0.5464
# Training: Batch 147/1000. Loss of 0.6124, cover loss of 0.6196, secret loss of 0.5623
# Training: Batch 148/1000. Loss of 0.7371, cover loss of 0.7187, secret loss of 0.6469
# Training: Batch 149/1000. Loss of 0.7064, cover loss of 0.7523, secret loss of 0.5503
# Training: Batch 150/1000. Loss of 0.6657, cover loss of 0.6626, secret loss of 0.6019
# Training: Batch 151/1000. Loss of 0.6698, cover loss of 0.6652, secret loss of 0.5918
# Training: Batch 152/1000. Loss of 0.7356, cover loss of 0.7513, secret loss of 0.6047
# Training: Batch 153/1000. Loss of 0.7135, cover loss of 0.6554, secret loss of 0.6627
# Training: Batch 154/1000. Loss of 0.6757, cover loss of 0.7313, secret loss of 0.5631
# Training: Batch 155/1000. Loss of 0.6890, cover loss of 0.7028, secret loss of 0.5845
# Training: Batch 156/1000. Loss of 0.6586, cover loss of 0.6741, secret loss of 0.5897
# Training: Batch 157/1000. Loss of 0.6698, cover loss of 0.6785, secret loss of 0.5900
# Training: Batch 158/1000. Loss of 0.7933, cover loss of 0.8141, secret loss of 0.6097
# Training: Batch 159/1000. Loss of 0.7743, cover loss of 0.7398, secret loss of 0.6198
# Training: Batch 160/1000. Loss of 0.6620, cover loss of 0.6013, secret loss of 0.6479
# Training: Batch 161/1000. Loss of 0.6411, cover loss of 0.6152, secret loss of 0.6148
# Training: Batch 162/1000. Loss of 0.6505, cover loss of 0.6816, secret loss of 0.5601
# Training: Batch 163/1000. Loss of 0.8034, cover loss of 0.7580, secret loss of 0.6792
# Training: Batch 164/1000. Loss of 0.7168, cover loss of 0.7114, secret loss of 0.6209
# Training: Batch 165/1000. Loss of 0.7323, cover loss of 0.6788, secret loss of 0.6766
# Training: Batch 166/1000. Loss of 0.7494, cover loss of 0.7270, secret loss of 0.6512
# Training: Batch 167/1000. Loss of 0.6934, cover loss of 0.6618, secret loss of 0.6380
# Training: Batch 168/1000. Loss of 0.6682, cover loss of 0.7271, secret loss of 0.5402
# Training: Batch 169/1000. Loss of 0.6973, cover loss of 0.6914, secret loss of 0.5995
# Training: Batch 170/1000. Loss of 0.7027, cover loss of 0.6876, secret loss of 0.6393
# Training: Batch 171/1000. Loss of 0.6777, cover loss of 0.6876, secret loss of 0.5858
# Training: Batch 172/1000. Loss of 0.6803, cover loss of 0.6857, secret loss of 0.6085
# Training: Batch 173/1000. Loss of 0.6787, cover loss of 0.6801, secret loss of 0.6020
# Training: Batch 174/1000. Loss of 0.6982, cover loss of 0.7435, secret loss of 0.5645
# Training: Batch 175/1000. Loss of 0.7250, cover loss of 0.7052, secret loss of 0.6415
# Training: Batch 176/1000. Loss of 0.6396, cover loss of 0.6100, secret loss of 0.6080
# Training: Batch 177/1000. Loss of 0.6415, cover loss of 0.6737, secret loss of 0.5602
# Training: Batch 178/1000. Loss of 0.6949, cover loss of 0.6909, secret loss of 0.5986
# Training: Batch 179/1000. Loss of 0.6656, cover loss of 0.6857, secret loss of 0.5582
# Training: Batch 180/1000. Loss of 0.7148, cover loss of 0.7838, secret loss of 0.5407
# Training: Batch 181/1000. Loss of 0.6847, cover loss of 0.7262, secret loss of 0.5644
# Training: Batch 182/1000. Loss of 0.6189, cover loss of 0.6873, secret loss of 0.4970
# Training: Batch 183/1000. Loss of 0.6881, cover loss of 0.7026, secret loss of 0.5889
# Training: Batch 184/1000. Loss of 0.6968, cover loss of 0.7575, secret loss of 0.5106
# Training: Batch 185/1000. Loss of 0.6555, cover loss of 0.7148, secret loss of 0.5358
# Training: Batch 186/1000. Loss of 0.7127, cover loss of 0.7246, secret loss of 0.5991
# Training: Batch 187/1000. Loss of 0.8567, cover loss of 0.8763, secret loss of 0.5916
# Training: Batch 188/1000. Loss of 0.7194, cover loss of 0.6975, secret loss of 0.6187
# Training: Batch 189/1000. Loss of 0.8257, cover loss of 0.8027, secret loss of 0.6745
# Training: Batch 190/1000. Loss of 0.7241, cover loss of 0.7448, secret loss of 0.5864
# Training: Batch 191/1000. Loss of 0.7218, cover loss of 0.7388, secret loss of 0.5837
# Training: Batch 192/1000. Loss of 0.6786, cover loss of 0.7006, secret loss of 0.5790
# Training: Batch 193/1000. Loss of 0.6699, cover loss of 0.6389, secret loss of 0.6367
# Training: Batch 194/1000. Loss of 0.7694, cover loss of 0.7458, secret loss of 0.6384
# Training: Batch 195/1000. Loss of 0.6363, cover loss of 0.6367, secret loss of 0.5909
# Training: Batch 196/1000. Loss of 0.6245, cover loss of 0.6113, secret loss of 0.5961
# Training: Batch 197/1000. Loss of 0.6843, cover loss of 0.6866, secret loss of 0.6023
# Training: Batch 198/1000. Loss of 0.7037, cover loss of 0.7311, secret loss of 0.5906
# Training: Batch 199/1000. Loss of 0.6803, cover loss of 0.6838, secret loss of 0.5699
# Training: Batch 200/1000. Loss of 0.6850, cover loss of 0.6710, secret loss of 0.6197
# Training: Batch 201/1000. Loss of 0.7615, cover loss of 0.7781, secret loss of 0.5983
# Training: Batch 202/1000. Loss of 0.6649, cover loss of 0.6415, secret loss of 0.6159
# Training: Batch 203/1000. Loss of 0.7148, cover loss of 0.7073, secret loss of 0.6073
# Training: Batch 204/1000. Loss of 0.6864, cover loss of 0.7116, secret loss of 0.5839
# Training: Batch 205/1000. Loss of 0.7070, cover loss of 0.7281, secret loss of 0.5858
# Training: Batch 206/1000. Loss of 0.7020, cover loss of 0.7136, secret loss of 0.6042
# Training: Batch 207/1000. Loss of 0.6276, cover loss of 0.6618, secret loss of 0.5628
# Training: Batch 208/1000. Loss of 0.7261, cover loss of 0.6735, secret loss of 0.6755
# Training: Batch 209/1000. Loss of 0.7524, cover loss of 0.7692, secret loss of 0.5983
# Training: Batch 210/1000. Loss of 0.6814, cover loss of 0.6963, secret loss of 0.5964
# Training: Batch 211/1000. Loss of 0.7447, cover loss of 0.7039, secret loss of 0.6546
# Training: Batch 212/1000. Loss of 0.7253, cover loss of 0.7200, secret loss of 0.6216
# Training: Batch 213/1000. Loss of 0.7153, cover loss of 0.7548, secret loss of 0.5616
# Training: Batch 214/1000. Loss of 0.7127, cover loss of 0.6541, secret loss of 0.6563
# Training: Batch 215/1000. Loss of 0.7485, cover loss of 0.6996, secret loss of 0.6581
# Training: Batch 216/1000. Loss of 0.6300, cover loss of 0.7135, secret loss of 0.5014
# Training: Batch 217/1000. Loss of 0.6280, cover loss of 0.6584, secret loss of 0.5590
# Training: Batch 218/1000. Loss of 0.6372, cover loss of 0.6684, secret loss of 0.5468
# Training: Batch 219/1000. Loss of 0.7184, cover loss of 0.7871, secret loss of 0.5608
# Training: Batch 220/1000. Loss of 0.6424, cover loss of 0.6922, secret loss of 0.5436
# Training: Batch 221/1000. Loss of 0.6590, cover loss of 0.7370, secret loss of 0.5097
# Training: Batch 222/1000. Loss of 0.6757, cover loss of 0.7522, secret loss of 0.5085
# Training: Batch 223/1000. Loss of 0.7035, cover loss of 0.6817, secret loss of 0.6279
# Training: Batch 224/1000. Loss of 0.7496, cover loss of 0.7050, secret loss of 0.6453
# Training: Batch 225/1000. Loss of 0.6165, cover loss of 0.6253, secret loss of 0.5716
# Training: Batch 226/1000. Loss of 0.7745, cover loss of 0.7853, secret loss of 0.6038
# Training: Batch 227/1000. Loss of 0.7241, cover loss of 0.7332, secret loss of 0.6116
# Training: Batch 228/1000. Loss of 0.7275, cover loss of 0.7131, secret loss of 0.6335
# Training: Batch 229/1000. Loss of 0.7145, cover loss of 0.7478, secret loss of 0.5786
# Training: Batch 230/1000. Loss of 0.7011, cover loss of 0.7453, secret loss of 0.5480
# Training: Batch 231/1000. Loss of 0.7527, cover loss of 0.7206, secret loss of 0.6479
# Training: Batch 232/1000. Loss of 0.6259, cover loss of 0.7120, secret loss of 0.4917
# Training: Batch 233/1000. Loss of 0.6896, cover loss of 0.7025, secret loss of 0.5942
# Training: Batch 234/1000. Loss of 0.6561, cover loss of 0.6861, secret loss of 0.5601
# Training: Batch 235/1000. Loss of 0.7016, cover loss of 0.7332, secret loss of 0.5738
# Training: Batch 236/1000. Loss of 0.6613, cover loss of 0.7091, secret loss of 0.5635
# Training: Batch 237/1000. Loss of 0.6251, cover loss of 0.6191, secret loss of 0.5925
# Training: Batch 238/1000. Loss of 0.7348, cover loss of 0.6969, secret loss of 0.6689
# Training: Batch 239/1000. Loss of 0.7273, cover loss of 0.6795, secret loss of 0.6492
# Training: Batch 240/1000. Loss of 0.7831, cover loss of 0.7734, secret loss of 0.6211
# Training: Batch 241/1000. Loss of 0.6762, cover loss of 0.6755, secret loss of 0.6019
# Training: Batch 242/1000. Loss of 0.6877, cover loss of 0.7314, secret loss of 0.5764
# Training: Batch 243/1000. Loss of 0.6901, cover loss of 0.7196, secret loss of 0.5721
# Training: Batch 244/1000. Loss of 0.6874, cover loss of 0.6867, secret loss of 0.6002
# Training: Batch 245/1000. Loss of 0.6975, cover loss of 0.7157, secret loss of 0.5811
# Training: Batch 246/1000. Loss of 0.8262, cover loss of 0.7772, secret loss of 0.6520
# Training: Batch 247/1000. Loss of 0.7555, cover loss of 0.7215, secret loss of 0.6470
# Training: Batch 248/1000. Loss of 0.6788, cover loss of 0.6875, secret loss of 0.5972
# Training: Batch 249/1000. Loss of 0.7456, cover loss of 0.7856, secret loss of 0.5648
# Training: Batch 250/1000. Loss of 0.7258, cover loss of 0.7614, secret loss of 0.5782
# Training: Batch 251/1000. Loss of 0.7191, cover loss of 0.7316, secret loss of 0.6122
# Training: Batch 252/1000. Loss of 0.7008, cover loss of 0.6992, secret loss of 0.6008
# Training: Batch 253/1000. Loss of 0.6821, cover loss of 0.7267, secret loss of 0.5693
# Training: Batch 254/1000. Loss of 0.6876, cover loss of 0.6778, secret loss of 0.6176
# Training: Batch 255/1000. Loss of 0.6897, cover loss of 0.7327, secret loss of 0.5662
# Training: Batch 256/1000. Loss of 0.7316, cover loss of 0.6904, secret loss of 0.6498
# Training: Batch 257/1000. Loss of 0.7803, cover loss of 0.7371, secret loss of 0.6510
# Training: Batch 258/1000. Loss of 0.7155, cover loss of 0.6712, secret loss of 0.6545
# Training: Batch 259/1000. Loss of 0.7446, cover loss of 0.7306, secret loss of 0.6328
# Training: Batch 260/1000. Loss of 0.7217, cover loss of 0.7286, secret loss of 0.5945
# Training: Batch 261/1000. Loss of 0.6792, cover loss of 0.7144, secret loss of 0.5665
# Training: Batch 262/1000. Loss of 0.7562, cover loss of 0.7621, secret loss of 0.6228
# Training: Batch 263/1000. Loss of 0.6654, cover loss of 0.7246, secret loss of 0.5336
# Training: Batch 264/1000. Loss of 0.6589, cover loss of 0.6237, secret loss of 0.6432
# Training: Batch 265/1000. Loss of 0.7619, cover loss of 0.7518, secret loss of 0.5988
# Training: Batch 266/1000. Loss of 0.7439, cover loss of 0.7087, secret loss of 0.6566
# Training: Batch 267/1000. Loss of 0.6519, cover loss of 0.6567, secret loss of 0.5915
# Training: Batch 268/1000. Loss of 0.6637, cover loss of 0.6743, secret loss of 0.5669
# Training: Batch 269/1000. Loss of 0.7535, cover loss of 0.7540, secret loss of 0.6388
# Training: Batch 270/1000. Loss of 0.6031, cover loss of 0.6021, secret loss of 0.5657
# Training: Batch 271/1000. Loss of 0.7383, cover loss of 0.7281, secret loss of 0.6226
# Training: Batch 272/1000. Loss of 0.7215, cover loss of 0.6878, secret loss of 0.6428
# Training: Batch 273/1000. Loss of 0.7665, cover loss of 0.7770, secret loss of 0.6114
# Training: Batch 274/1000. Loss of 0.7150, cover loss of 0.7397, secret loss of 0.5859
# Training: Batch 275/1000. Loss of 0.8305, cover loss of 0.8469, secret loss of 0.6143
# Training: Batch 276/1000. Loss of 0.6653, cover loss of 0.6995, secret loss of 0.5679
# Training: Batch 277/1000. Loss of 0.7523, cover loss of 0.7683, secret loss of 0.5909
# Training: Batch 278/1000. Loss of 0.6695, cover loss of 0.6639, secret loss of 0.6074
# Training: Batch 279/1000. Loss of 0.7236, cover loss of 0.7279, secret loss of 0.6197
# Training: Batch 280/1000. Loss of 0.6917, cover loss of 0.6963, secret loss of 0.6014
# Training: Batch 281/1000. Loss of 0.6697, cover loss of 0.5919, secret loss of 0.6669
# Training: Batch 282/1000. Loss of 0.7058, cover loss of 0.7701, secret loss of 0.5315
# Training: Batch 283/1000. Loss of 0.6907, cover loss of 0.6572, secret loss of 0.6395
# Training: Batch 284/1000. Loss of 0.6474, cover loss of 0.6811, secret loss of 0.5548
# Training: Batch 285/1000. Loss of 0.7012, cover loss of 0.6885, secret loss of 0.6317
# Training: Batch 286/1000. Loss of 0.7470, cover loss of 0.7032, secret loss of 0.6510
# Training: Batch 287/1000. Loss of 0.6669, cover loss of 0.7071, secret loss of 0.5580
# Training: Batch 288/1000. Loss of 0.7380, cover loss of 0.7302, secret loss of 0.6508
# Training: Batch 289/1000. Loss of 0.7838, cover loss of 0.8003, secret loss of 0.5827
# Training: Batch 290/1000. Loss of 0.7240, cover loss of 0.7307, secret loss of 0.6040
# Training: Batch 291/1000. Loss of 0.6615, cover loss of 0.7185, secret loss of 0.5209
# Training: Batch 292/1000. Loss of 0.7482, cover loss of 0.7648, secret loss of 0.5926
# Training: Batch 293/1000. Loss of 0.7001, cover loss of 0.6804, secret loss of 0.6265
# Training: Batch 294/1000. Loss of 0.8349, cover loss of 0.7968, secret loss of 0.6470
# Training: Batch 295/1000. Loss of 0.7210, cover loss of 0.7019, secret loss of 0.6231
# Training: Batch 296/1000. Loss of 0.6028, cover loss of 0.6108, secret loss of 0.5657
# Training: Batch 297/1000. Loss of 0.6747, cover loss of 0.6721, secret loss of 0.6150
# Training: Batch 298/1000. Loss of 0.6853, cover loss of 0.7232, secret loss of 0.5675
# Training: Batch 299/1000. Loss of 0.7545, cover loss of 0.7689, secret loss of 0.6142
# Training: Batch 300/1000. Loss of 0.7260, cover loss of 0.7401, secret loss of 0.6012
# Training: Batch 301/1000. Loss of 0.7198, cover loss of 0.7088, secret loss of 0.6229
# Training: Batch 302/1000. Loss of 0.7057, cover loss of 0.7079, secret loss of 0.5897
# Training: Batch 303/1000. Loss of 0.6800, cover loss of 0.7273, secret loss of 0.5464
# Training: Batch 304/1000. Loss of 0.6579, cover loss of 0.6411, secret loss of 0.6196
# Training: Batch 305/1000. Loss of 0.7020, cover loss of 0.7259, secret loss of 0.5965
# Training: Batch 306/1000. Loss of 0.7987, cover loss of 0.8081, secret loss of 0.6253
# Training: Batch 307/1000. Loss of 0.6750, cover loss of 0.6894, secret loss of 0.6097
# Training: Batch 308/1000. Loss of 0.7072, cover loss of 0.7210, secret loss of 0.5938
# Training: Batch 309/1000. Loss of 0.7432, cover loss of 0.7461, secret loss of 0.6177
# Training: Batch 310/1000. Loss of 0.7799, cover loss of 0.7659, secret loss of 0.6264
# Training: Batch 311/1000. Loss of 0.7338, cover loss of 0.7498, secret loss of 0.5913
# Training: Batch 312/1000. Loss of 0.5776, cover loss of 0.5840, secret loss of 0.5500
# Training: Batch 313/1000. Loss of 0.6768, cover loss of 0.6405, secret loss of 0.6201
# Training: Batch 314/1000. Loss of 0.7963, cover loss of 0.8325, secret loss of 0.5976
# Training: Batch 315/1000. Loss of 0.7326, cover loss of 0.7566, secret loss of 0.5882
# Training: Batch 316/1000. Loss of 0.7055, cover loss of 0.7169, secret loss of 0.5838
# Training: Batch 317/1000. Loss of 0.7249, cover loss of 0.7204, secret loss of 0.6125
# Training: Batch 318/1000. Loss of 0.6544, cover loss of 0.6736, secret loss of 0.5634
# Training: Batch 319/1000. Loss of 0.7331, cover loss of 0.7762, secret loss of 0.5715
# Training: Batch 320/1000. Loss of 0.5820, cover loss of 0.6688, secret loss of 0.4748
# Training: Batch 321/1000. Loss of 0.6616, cover loss of 0.6077, secret loss of 0.6517
# Training: Batch 322/1000. Loss of 0.6824, cover loss of 0.7062, secret loss of 0.5808
# Training: Batch 323/1000. Loss of 0.7152, cover loss of 0.7547, secret loss of 0.5748
# Training: Batch 324/1000. Loss of 0.6324, cover loss of 0.6410, secret loss of 0.5727
# Training: Batch 325/1000. Loss of 0.6884, cover loss of 0.6922, secret loss of 0.5787
# Training: Batch 326/1000. Loss of 0.6967, cover loss of 0.6594, secret loss of 0.6459
# Training: Batch 327/1000. Loss of 0.6918, cover loss of 0.6865, secret loss of 0.6056
# Training: Batch 328/1000. Loss of 0.6394, cover loss of 0.6616, secret loss of 0.5653
# Training: Batch 329/1000. Loss of 0.7315, cover loss of 0.7219, secret loss of 0.6069
# Training: Batch 330/1000. Loss of 0.6694, cover loss of 0.6666, secret loss of 0.5925
# Training: Batch 331/1000. Loss of 0.7388, cover loss of 0.6683, secret loss of 0.6785
# Training: Batch 332/1000. Loss of 0.5714, cover loss of 0.6292, secret loss of 0.5194
# Training: Batch 333/1000. Loss of 0.7215, cover loss of 0.7579, secret loss of 0.5984
# Training: Batch 334/1000. Loss of 0.7052, cover loss of 0.6909, secret loss of 0.6203
# Training: Batch 335/1000. Loss of 0.7752, cover loss of 0.7669, secret loss of 0.6366
# Training: Batch 336/1000. Loss of 0.6726, cover loss of 0.7121, secret loss of 0.5586
# Training: Batch 337/1000. Loss of 0.6806, cover loss of 0.6743, secret loss of 0.6171
# Training: Batch 338/1000. Loss of 0.7022, cover loss of 0.6817, secret loss of 0.6230
# Training: Batch 339/1000. Loss of 0.7134, cover loss of 0.7060, secret loss of 0.6298
# Training: Batch 340/1000. Loss of 0.7199, cover loss of 0.7264, secret loss of 0.6267
# Training: Batch 341/1000. Loss of 0.7086, cover loss of 0.6630, secret loss of 0.6334
# Training: Batch 342/1000. Loss of 0.7431, cover loss of 0.7562, secret loss of 0.5925
# Training: Batch 343/1000. Loss of 0.7204, cover loss of 0.7008, secret loss of 0.6278
# Training: Batch 344/1000. Loss of 0.6438, cover loss of 0.6677, secret loss of 0.5757
# Training: Batch 345/1000. Loss of 0.6667, cover loss of 0.7343, secret loss of 0.5362
# Training: Batch 346/1000. Loss of 0.6915, cover loss of 0.6707, secret loss of 0.6422
# Training: Batch 347/1000. Loss of 0.7783, cover loss of 0.7049, secret loss of 0.6844
# Training: Batch 348/1000. Loss of 0.6885, cover loss of 0.7220, secret loss of 0.5645
# Training: Batch 349/1000. Loss of 0.6994, cover loss of 0.6418, secret loss of 0.6524
# Training: Batch 350/1000. Loss of 0.7557, cover loss of 0.7554, secret loss of 0.6342
# Training: Batch 351/1000. Loss of 0.7389, cover loss of 0.7378, secret loss of 0.6200
# Training: Batch 352/1000. Loss of 0.7382, cover loss of 0.8088, secret loss of 0.5648
# Training: Batch 353/1000. Loss of 0.6792, cover loss of 0.7342, secret loss of 0.5533
# Training: Batch 354/1000. Loss of 0.7881, cover loss of 0.7696, secret loss of 0.6508
# Training: Batch 355/1000. Loss of 0.7892, cover loss of 0.7811, secret loss of 0.6278
# Training: Batch 356/1000. Loss of 0.7707, cover loss of 0.7591, secret loss of 0.6313
# Training: Batch 357/1000. Loss of 0.7155, cover loss of 0.7235, secret loss of 0.6167
# Training: Batch 358/1000. Loss of 0.7958, cover loss of 0.7960, secret loss of 0.6186
# Training: Batch 359/1000. Loss of 0.6434, cover loss of 0.6891, secret loss of 0.5464
# Training: Batch 360/1000. Loss of 0.7354, cover loss of 0.6715, secret loss of 0.6764
# Training: Batch 361/1000. Loss of 0.6254, cover loss of 0.6162, secret loss of 0.5879
# Training: Batch 362/1000. Loss of 0.6484, cover loss of 0.6796, secret loss of 0.5504
# Training: Batch 363/1000. Loss of 0.7588, cover loss of 0.7875, secret loss of 0.5973
# Training: Batch 364/1000. Loss of 0.7078, cover loss of 0.7157, secret loss of 0.5969
# Training: Batch 365/1000. Loss of 0.7561, cover loss of 0.7394, secret loss of 0.6213
# Training: Batch 366/1000. Loss of 0.6486, cover loss of 0.6313, secret loss of 0.6000
# Training: Batch 367/1000. Loss of 0.7030, cover loss of 0.7433, secret loss of 0.5384
# Training: Batch 368/1000. Loss of 0.7158, cover loss of 0.7029, secret loss of 0.6345
# Training: Batch 369/1000. Loss of 0.6878, cover loss of 0.7022, secret loss of 0.5827
# Training: Batch 370/1000. Loss of 0.7023, cover loss of 0.7302, secret loss of 0.5993
# Training: Batch 371/1000. Loss of 0.6492, cover loss of 0.6371, secret loss of 0.6075
# Training: Batch 372/1000. Loss of 0.7111, cover loss of 0.6951, secret loss of 0.6397
# Training: Batch 373/1000. Loss of 0.6405, cover loss of 0.7006, secret loss of 0.5384
# Training: Batch 374/1000. Loss of 0.7366, cover loss of 0.6990, secret loss of 0.6328
# Training: Batch 375/1000. Loss of 0.6623, cover loss of 0.6332, secret loss of 0.6172
# Training: Batch 376/1000. Loss of 0.6718, cover loss of 0.6701, secret loss of 0.5956
# Training: Batch 377/1000. Loss of 0.7241, cover loss of 0.7230, secret loss of 0.6148
# Training: Batch 378/1000. Loss of 0.7082, cover loss of 0.7130, secret loss of 0.5997
# Training: Batch 379/1000. Loss of 0.7146, cover loss of 0.7203, secret loss of 0.5937
# Training: Batch 380/1000. Loss of 0.7207, cover loss of 0.7410, secret loss of 0.5910
# Training: Batch 381/1000. Loss of 0.6403, cover loss of 0.6121, secret loss of 0.6260
# Training: Batch 382/1000. Loss of 0.7521, cover loss of 0.7673, secret loss of 0.5981
# Training: Batch 383/1000. Loss of 0.6860, cover loss of 0.7062, secret loss of 0.5885
# Training: Batch 384/1000. Loss of 0.6678, cover loss of 0.6946, secret loss of 0.5917
# Training: Batch 385/1000. Loss of 0.8018, cover loss of 0.8130, secret loss of 0.6058
# Training: Batch 386/1000. Loss of 0.6958, cover loss of 0.6342, secret loss of 0.6514
# Training: Batch 387/1000. Loss of 0.7089, cover loss of 0.7168, secret loss of 0.6002
# Training: Batch 388/1000. Loss of 0.6301, cover loss of 0.6463, secret loss of 0.5796
# Training: Batch 389/1000. Loss of 0.7372, cover loss of 0.7126, secret loss of 0.6149
# Training: Batch 390/1000. Loss of 0.6942, cover loss of 0.6895, secret loss of 0.6211
# Training: Batch 391/1000. Loss of 0.6368, cover loss of 0.6975, secret loss of 0.5216
# Training: Batch 392/1000. Loss of 0.6439, cover loss of 0.6689, secret loss of 0.5534
# Training: Batch 393/1000. Loss of 0.6658, cover loss of 0.6942, secret loss of 0.5590
# Training: Batch 394/1000. Loss of 0.6546, cover loss of 0.6248, secret loss of 0.6038
# Training: Batch 395/1000. Loss of 0.7162, cover loss of 0.7220, secret loss of 0.6065
# Training: Batch 396/1000. Loss of 0.6859, cover loss of 0.6873, secret loss of 0.5886
# Training: Batch 397/1000. Loss of 0.7809, cover loss of 0.7723, secret loss of 0.6272
# Training: Batch 398/1000. Loss of 0.6318, cover loss of 0.6407, secret loss of 0.5923
# Training: Batch 399/1000. Loss of 0.7695, cover loss of 0.7627, secret loss of 0.6210
# Training: Batch 400/1000. Loss of 0.7420, cover loss of 0.7563, secret loss of 0.6010
# Training: Batch 401/1000. Loss of 0.7322, cover loss of 0.8190, secret loss of 0.5250
# Training: Batch 402/1000. Loss of 0.7631, cover loss of 0.7962, secret loss of 0.5987
# Training: Batch 403/1000. Loss of 0.7628, cover loss of 0.7833, secret loss of 0.5847
# Training: Batch 404/1000. Loss of 0.6959, cover loss of 0.6830, secret loss of 0.6145
# Training: Batch 405/1000. Loss of 0.7152, cover loss of 0.6718, secret loss of 0.6439
# Training: Batch 406/1000. Loss of 0.7063, cover loss of 0.7900, secret loss of 0.5254
# Training: Batch 407/1000. Loss of 0.7451, cover loss of 0.7417, secret loss of 0.6357
# Training: Batch 408/1000. Loss of 0.6486, cover loss of 0.6579, secret loss of 0.5833
# Training: Batch 409/1000. Loss of 0.6955, cover loss of 0.6922, secret loss of 0.6251
# Training: Batch 410/1000. Loss of 0.6912, cover loss of 0.7150, secret loss of 0.5815
# Training: Batch 411/1000. Loss of 0.6713, cover loss of 0.7609, secret loss of 0.4975
# Training: Batch 412/1000. Loss of 0.7749, cover loss of 0.7297, secret loss of 0.6782
# Training: Batch 413/1000. Loss of 0.7093, cover loss of 0.7369, secret loss of 0.5762
# Training: Batch 414/1000. Loss of 0.6734, cover loss of 0.6910, secret loss of 0.5852
# Training: Batch 415/1000. Loss of 0.8246, cover loss of 0.8183, secret loss of 0.6345
# Training: Batch 416/1000. Loss of 0.6774, cover loss of 0.6415, secret loss of 0.6436
# Training: Batch 417/1000. Loss of 0.6974, cover loss of 0.7416, secret loss of 0.5713
# Training: Batch 418/1000. Loss of 0.6869, cover loss of 0.6815, secret loss of 0.6241
# Training: Batch 419/1000. Loss of 0.6917, cover loss of 0.6889, secret loss of 0.6083
# Training: Batch 420/1000. Loss of 0.7028, cover loss of 0.7045, secret loss of 0.6076
# Training: Batch 421/1000. Loss of 0.7747, cover loss of 0.7381, secret loss of 0.6744
# Training: Batch 422/1000. Loss of 0.7136, cover loss of 0.7804, secret loss of 0.5319
# Training: Batch 423/1000. Loss of 0.6903, cover loss of 0.6980, secret loss of 0.6136
# Training: Batch 424/1000. Loss of 0.7311, cover loss of 0.7353, secret loss of 0.6238
# Training: Batch 425/1000. Loss of 0.6961, cover loss of 0.7278, secret loss of 0.5791
# Training: Batch 426/1000. Loss of 0.7214, cover loss of 0.7740, secret loss of 0.5703
# Training: Batch 427/1000. Loss of 0.6608, cover loss of 0.6696, secret loss of 0.5759
# Training: Batch 428/1000. Loss of 0.8038, cover loss of 0.7869, secret loss of 0.6546
# Training: Batch 429/1000. Loss of 0.7291, cover loss of 0.7618, secret loss of 0.5505
# Training: Batch 430/1000. Loss of 0.6832, cover loss of 0.7005, secret loss of 0.5654
# Training: Batch 431/1000. Loss of 0.7019, cover loss of 0.6892, secret loss of 0.6119
# Training: Batch 432/1000. Loss of 0.7321, cover loss of 0.7244, secret loss of 0.6290
# Training: Batch 433/1000. Loss of 0.7235, cover loss of 0.7369, secret loss of 0.5805
# Training: Batch 434/1000. Loss of 0.7090, cover loss of 0.6704, secret loss of 0.6391
# Training: Batch 435/1000. Loss of 0.6961, cover loss of 0.6308, secret loss of 0.6748
# Training: Batch 436/1000. Loss of 0.6635, cover loss of 0.6691, secret loss of 0.6165
# Training: Batch 437/1000. Loss of 0.6060, cover loss of 0.6710, secret loss of 0.5080
# Training: Batch 438/1000. Loss of 0.7375, cover loss of 0.7923, secret loss of 0.5470
# Training: Batch 439/1000. Loss of 0.6561, cover loss of 0.6935, secret loss of 0.5596
# Training: Batch 440/1000. Loss of 0.7391, cover loss of 0.6875, secret loss of 0.6846
# Training: Batch 441/1000. Loss of 0.6802, cover loss of 0.6844, secret loss of 0.5959
# Training: Batch 442/1000. Loss of 0.7758, cover loss of 0.7986, secret loss of 0.6081
# Training: Batch 443/1000. Loss of 0.6795, cover loss of 0.7076, secret loss of 0.6030
# Training: Batch 444/1000. Loss of 0.7437, cover loss of 0.7029, secret loss of 0.6539
# Training: Batch 445/1000. Loss of 0.7510, cover loss of 0.7198, secret loss of 0.6528
# Training: Batch 446/1000. Loss of 0.6200, cover loss of 0.6123, secret loss of 0.5899
# Training: Batch 447/1000. Loss of 0.7193, cover loss of 0.7470, secret loss of 0.5949
# Training: Batch 448/1000. Loss of 0.6816, cover loss of 0.7145, secret loss of 0.5764
# Training: Batch 449/1000. Loss of 0.7168, cover loss of 0.7504, secret loss of 0.5865
# Training: Batch 450/1000. Loss of 0.7696, cover loss of 0.7454, secret loss of 0.6456
# Training: Batch 451/1000. Loss of 0.6662, cover loss of 0.6416, secret loss of 0.6416
# Training: Batch 452/1000. Loss of 0.7697, cover loss of 0.7640, secret loss of 0.6254
# Training: Batch 453/1000. Loss of 0.7050, cover loss of 0.7232, secret loss of 0.5851
# Training: Batch 454/1000. Loss of 0.7922, cover loss of 0.8165, secret loss of 0.6049
# Training: Batch 455/1000. Loss of 0.6996, cover loss of 0.7442, secret loss of 0.5583
# Training: Batch 456/1000. Loss of 0.6838, cover loss of 0.6782, secret loss of 0.6135
# Training: Batch 457/1000. Loss of 0.6811, cover loss of 0.6736, secret loss of 0.5759
# Training: Batch 458/1000. Loss of 0.7994, cover loss of 0.7735, secret loss of 0.6461
# Training: Batch 459/1000. Loss of 0.6266, cover loss of 0.6012, secret loss of 0.5939
# Training: Batch 460/1000. Loss of 0.7331, cover loss of 0.7504, secret loss of 0.5923
# Training: Batch 461/1000. Loss of 0.7412, cover loss of 0.7773, secret loss of 0.5777
# Training: Batch 462/1000. Loss of 0.6871, cover loss of 0.7211, secret loss of 0.5681
# Training: Batch 463/1000. Loss of 0.7118, cover loss of 0.7258, secret loss of 0.6185
# Training: Batch 464/1000. Loss of 0.6882, cover loss of 0.7161, secret loss of 0.5737
# Training: Batch 465/1000. Loss of 0.7468, cover loss of 0.7617, secret loss of 0.6045
# Training: Batch 466/1000. Loss of 0.6883, cover loss of 0.6260, secret loss of 0.6488
# Training: Batch 467/1000. Loss of 0.6347, cover loss of 0.6373, secret loss of 0.5592
# Training: Batch 468/1000. Loss of 0.7984, cover loss of 0.7431, secret loss of 0.6587
# Training: Batch 469/1000. Loss of 0.7477, cover loss of 0.7419, secret loss of 0.6301
# Training: Batch 470/1000. Loss of 0.6878, cover loss of 0.6692, secret loss of 0.6319
# Training: Batch 471/1000. Loss of 0.6826, cover loss of 0.7160, secret loss of 0.5725
# Training: Batch 472/1000. Loss of 0.6666, cover loss of 0.6605, secret loss of 0.6316
# Training: Batch 473/1000. Loss of 0.6970, cover loss of 0.6911, secret loss of 0.6297
# Training: Batch 474/1000. Loss of 0.7109, cover loss of 0.6883, secret loss of 0.6431
# Training: Batch 475/1000. Loss of 0.6841, cover loss of 0.6892, secret loss of 0.6234
# Training: Batch 476/1000. Loss of 0.7766, cover loss of 0.7537, secret loss of 0.6263
# Training: Batch 477/1000. Loss of 0.6463, cover loss of 0.6695, secret loss of 0.5909
# Training: Batch 478/1000. Loss of 0.6880, cover loss of 0.6889, secret loss of 0.6091
# Training: Batch 479/1000. Loss of 0.7489, cover loss of 0.7721, secret loss of 0.5984
# Training: Batch 480/1000. Loss of 0.7642, cover loss of 0.7026, secret loss of 0.6890
# Training: Batch 481/1000. Loss of 0.6122, cover loss of 0.6221, secret loss of 0.5882
# Training: Batch 482/1000. Loss of 0.6390, cover loss of 0.6578, secret loss of 0.5577
# Training: Batch 483/1000. Loss of 0.8031, cover loss of 0.7786, secret loss of 0.6649
# Training: Batch 484/1000. Loss of 0.6671, cover loss of 0.6450, secret loss of 0.6100
# Training: Batch 485/1000. Loss of 0.6971, cover loss of 0.6817, secret loss of 0.6196
# Training: Batch 486/1000. Loss of 0.6725, cover loss of 0.6740, secret loss of 0.6037
# Training: Batch 487/1000. Loss of 0.7361, cover loss of 0.7583, secret loss of 0.5964
# Training: Batch 488/1000. Loss of 0.6786, cover loss of 0.7148, secret loss of 0.5738
# Training: Batch 489/1000. Loss of 0.6798, cover loss of 0.6366, secret loss of 0.6676
# Training: Batch 490/1000. Loss of 0.8083, cover loss of 0.7996, secret loss of 0.6235
# Training: Batch 491/1000. Loss of 0.7307, cover loss of 0.7284, secret loss of 0.6215
# Training: Batch 492/1000. Loss of 0.7338, cover loss of 0.6791, secret loss of 0.6623
# Training: Batch 493/1000. Loss of 0.6197, cover loss of 0.6014, secret loss of 0.5904
# Training: Batch 494/1000. Loss of 0.7140, cover loss of 0.7690, secret loss of 0.5550
# Training: Batch 495/1000. Loss of 0.7843, cover loss of 0.7911, secret loss of 0.6357
# Training: Batch 496/1000. Loss of 0.7188, cover loss of 0.7275, secret loss of 0.6046
# Training: Batch 497/1000. Loss of 0.7733, cover loss of 0.8254, secret loss of 0.5947
# Training: Batch 498/1000. Loss of 0.7150, cover loss of 0.7644, secret loss of 0.5770
# Training: Batch 499/1000. Loss of 0.6802, cover loss of 0.6775, secret loss of 0.6131
# Training: Batch 500/1000. Loss of 0.7005, cover loss of 0.6713, secret loss of 0.6444
# Training: Batch 501/1000. Loss of 0.7733, cover loss of 0.7315, secret loss of 0.6804
# Training: Batch 502/1000. Loss of 0.6636, cover loss of 0.6948, secret loss of 0.5639
# Training: Batch 503/1000. Loss of 0.6762, cover loss of 0.6892, secret loss of 0.6048
# Training: Batch 504/1000. Loss of 0.7305, cover loss of 0.7466, secret loss of 0.6066
# Training: Batch 505/1000. Loss of 0.6544, cover loss of 0.6901, secret loss of 0.5601
# Training: Batch 506/1000. Loss of 0.6383, cover loss of 0.7044, secret loss of 0.5314
# Training: Batch 507/1000. Loss of 0.7192, cover loss of 0.7446, secret loss of 0.5889
# Training: Batch 508/1000. Loss of 0.6645, cover loss of 0.6894, secret loss of 0.5645
# Training: Batch 509/1000. Loss of 0.7739, cover loss of 0.8028, secret loss of 0.5767
# Training: Batch 510/1000. Loss of 0.7730, cover loss of 0.7011, secret loss of 0.6888
# Training: Batch 511/1000. Loss of 0.7854, cover loss of 0.7488, secret loss of 0.6549
# Training: Batch 512/1000. Loss of 0.7029, cover loss of 0.6742, secret loss of 0.6703
# Training: Batch 513/1000. Loss of 0.7635, cover loss of 0.7398, secret loss of 0.6489
# Training: Batch 514/1000. Loss of 0.7217, cover loss of 0.7697, secret loss of 0.5568
# Training: Batch 515/1000. Loss of 0.7567, cover loss of 0.7255, secret loss of 0.6544
# Training: Batch 516/1000. Loss of 0.6974, cover loss of 0.6967, secret loss of 0.6101
# Training: Batch 517/1000. Loss of 0.6377, cover loss of 0.6546, secret loss of 0.5502
# Training: Batch 518/1000. Loss of 0.6713, cover loss of 0.6871, secret loss of 0.5668
# Training: Batch 519/1000. Loss of 0.7761, cover loss of 0.7453, secret loss of 0.6395
# Training: Batch 520/1000. Loss of 0.7489, cover loss of 0.7081, secret loss of 0.6357
# Training: Batch 521/1000. Loss of 0.7551, cover loss of 0.6936, secret loss of 0.7233
# Training: Batch 522/1000. Loss of 0.6750, cover loss of 0.7045, secret loss of 0.6017
# Training: Batch 523/1000. Loss of 0.7573, cover loss of 0.8220, secret loss of 0.5678
# Training: Batch 524/1000. Loss of 0.7478, cover loss of 0.7589, secret loss of 0.6351
# Training: Batch 525/1000. Loss of 0.6814, cover loss of 0.6542, secret loss of 0.6353
# Training: Batch 526/1000. Loss of 0.7196, cover loss of 0.7544, secret loss of 0.5731
# Training: Batch 527/1000. Loss of 0.6287, cover loss of 0.6756, secret loss of 0.5526
# Training: Batch 528/1000. Loss of 0.6575, cover loss of 0.7161, secret loss of 0.5411
# Training: Batch 529/1000. Loss of 0.7057, cover loss of 0.7069, secret loss of 0.6154
# Training: Batch 530/1000. Loss of 0.6840, cover loss of 0.6812, secret loss of 0.5764
# Training: Batch 531/1000. Loss of 0.7140, cover loss of 0.7381, secret loss of 0.5989
# Training: Batch 532/1000. Loss of 0.6115, cover loss of 0.6315, secret loss of 0.5629
# Training: Batch 533/1000. Loss of 0.6916, cover loss of 0.7173, secret loss of 0.5848
# Training: Batch 534/1000. Loss of 0.7384, cover loss of 0.7669, secret loss of 0.5658
# Training: Batch 535/1000. Loss of 0.8264, cover loss of 0.7876, secret loss of 0.6471
# Training: Batch 536/1000. Loss of 0.7964, cover loss of 0.7922, secret loss of 0.6488
# Training: Batch 537/1000. Loss of 0.6033, cover loss of 0.6618, secret loss of 0.5217
# Training: Batch 538/1000. Loss of 0.7675, cover loss of 0.7589, secret loss of 0.6466
# Training: Batch 539/1000. Loss of 0.7636, cover loss of 0.7501, secret loss of 0.6444
# Training: Batch 540/1000. Loss of 0.6254, cover loss of 0.6925, secret loss of 0.5254
# Training: Batch 541/1000. Loss of 0.7371, cover loss of 0.7502, secret loss of 0.6012
# Training: Batch 542/1000. Loss of 0.6647, cover loss of 0.6887, secret loss of 0.5719
# Training: Batch 543/1000. Loss of 0.6277, cover loss of 0.5999, secret loss of 0.6043
# Training: Batch 544/1000. Loss of 0.6129, cover loss of 0.6482, secret loss of 0.5480
# Training: Batch 545/1000. Loss of 0.7696, cover loss of 0.7295, secret loss of 0.6636
# Training: Batch 546/1000. Loss of 0.6729, cover loss of 0.6995, secret loss of 0.5729
# Training: Batch 547/1000. Loss of 0.7294, cover loss of 0.7456, secret loss of 0.5791
# Training: Batch 548/1000. Loss of 0.7448, cover loss of 0.7744, secret loss of 0.6042
# Training: Batch 549/1000. Loss of 0.7896, cover loss of 0.7747, secret loss of 0.6473
# Training: Batch 550/1000. Loss of 0.7334, cover loss of 0.6686, secret loss of 0.6724
# Training: Batch 551/1000. Loss of 0.6903, cover loss of 0.7267, secret loss of 0.5741
# Training: Batch 552/1000. Loss of 0.7222, cover loss of 0.7658, secret loss of 0.5711
# Training: Batch 553/1000. Loss of 0.6809, cover loss of 0.6810, secret loss of 0.6061
# Training: Batch 554/1000. Loss of 0.7254, cover loss of 0.7584, secret loss of 0.5762
# Training: Batch 555/1000. Loss of 0.6707, cover loss of 0.6341, secret loss of 0.6284
# Training: Batch 556/1000. Loss of 0.7661, cover loss of 0.7236, secret loss of 0.6487
# Training: Batch 557/1000. Loss of 0.7502, cover loss of 0.7403, secret loss of 0.6275
# Training: Batch 558/1000. Loss of 0.7006, cover loss of 0.6866, secret loss of 0.6273
# Training: Batch 559/1000. Loss of 0.6701, cover loss of 0.6979, secret loss of 0.5814
# Training: Batch 560/1000. Loss of 0.7959, cover loss of 0.7693, secret loss of 0.6490
# Training: Batch 561/1000. Loss of 0.7022, cover loss of 0.7171, secret loss of 0.6000
# Training: Batch 562/1000. Loss of 0.6880, cover loss of 0.6764, secret loss of 0.6197
# ...
# Training: Batch 816/1000. Loss of 0.6526, cover loss of 0.6840, secret loss of 0.5532
# Training: Batch 817/1000. Loss of 0.6555, cover loss of 0.6979, secret loss of 0.5245
# Training: Batch 818/1000. Loss of 0.7174, cover loss of 0.7674, secret loss of 0.5686
# Training: Batch 819/1000. Loss of 0.7088, cover loss of 0.6786, secret loss of 0.6257
# Training: Batch 820/1000. Loss of 0.7156, cover loss of 0.7282, secret loss of 0.5816
# Training: Batch 821/1000. Loss of 0.7762, cover loss of 0.8157, secret loss of 0.5735
# Training: Batch 822/1000. Loss of 0.7835, cover loss of 0.8133, secret loss of 0.5838
# Training: Batch 823/1000. Loss of 0.7746, cover loss of 0.7193, secret loss of 0.6556
# Training: Batch 824/1000. Loss of 0.7040, cover loss of 0.7383, secret loss of 0.5520
# Training: Batch 825/1000. Loss of 0.6648, cover loss of 0.6899, secret loss of 0.5716
# Training: Batch 826/1000. Loss of 0.6487, cover loss of 0.5940, secret loss of 0.6343
# Training: Batch 827/1000. Loss of 0.7032, cover loss of 0.6519, secret loss of 0.6317
# Training: Batch 828/1000. Loss of 0.7052, cover loss of 0.7016, secret loss of 0.6086
# Training: Batch 829/1000. Loss of 0.6829, cover loss of 0.7197, secret loss of 0.5339
# Training: Batch 830/1000. Loss of 0.7145, cover loss of 0.7225, secret loss of 0.6063
# Training: Batch 831/1000. Loss of 0.7121, cover loss of 0.7476, secret loss of 0.5784
# Training: Batch 832/1000. Loss of 0.7431, cover loss of 0.7535, secret loss of 0.6043
# Training: Batch 833/1000. Loss of 0.7818, cover loss of 0.7506, secret loss of 0.6799
# Training: Batch 834/1000. Loss of 0.6132, cover loss of 0.5726, secret loss of 0.6127
# Training: Batch 835/1000. Loss of 0.6874, cover loss of 0.7000, secret loss of 0.5863
# Training: Batch 836/1000. Loss of 0.7167, cover loss of 0.6993, secret loss of 0.6149
# Training: Batch 837/1000. Loss of 0.7466, cover loss of 0.7332, secret loss of 0.6398
# Training: Batch 838/1000. Loss of 0.6675, cover loss of 0.7140, secret loss of 0.5698
# Training: Batch 839/1000. Loss of 0.6987, cover loss of 0.7188, secret loss of 0.6035
# Training: Batch 840/1000. Loss of 0.6620, cover loss of 0.6506, secret loss of 0.6001
# Training: Batch 841/1000. Loss of 0.7042, cover loss of 0.7122, secret loss of 0.5893
# Training: Batch 842/1000. Loss of 0.7897, cover loss of 0.7787, secret loss of 0.6320
# Training: Batch 843/1000. Loss of 0.6219, cover loss of 0.6445, secret loss of 0.5418
# Training: Batch 844/1000. Loss of 0.7015, cover loss of 0.6781, secret loss of 0.6139
# Training: Batch 845/1000. Loss of 0.6469, cover loss of 0.6680, secret loss of 0.5622
# Training: Batch 846/1000. Loss of 0.7345, cover loss of 0.6979, secret loss of 0.6385
# Training: Batch 847/1000. Loss of 0.7119, cover loss of 0.7049, secret loss of 0.6286
# Training: Batch 848/1000. Loss of 0.7158, cover loss of 0.7266, secret loss of 0.5927
# Training: Batch 849/1000. Loss of 0.6527, cover loss of 0.6777, secret loss of 0.5762
# Training: Batch 850/1000. Loss of 0.7666, cover loss of 0.7834, secret loss of 0.6168
# Training: Batch 851/1000. Loss of 0.7310, cover loss of 0.6381, secret loss of 0.6953
# Training: Batch 852/1000. Loss of 0.7540, cover loss of 0.7485, secret loss of 0.6334
# Training: Batch 853/1000. Loss of 0.8209, cover loss of 0.7864, secret loss of 0.6373
# Training: Batch 854/1000. Loss of 0.7526, cover loss of 0.7725, secret loss of 0.5860
# Training: Batch 855/1000. Loss of 0.6965, cover loss of 0.6938, secret loss of 0.6199
# Training: Batch 856/1000. Loss of 0.6876, cover loss of 0.6758, secret loss of 0.6077
# Training: Batch 857/1000. Loss of 0.7161, cover loss of 0.6887, secret loss of 0.6528
# Training: Batch 858/1000. Loss of 0.6280, cover loss of 0.6342, secret loss of 0.5675
# Training: Batch 859/1000. Loss of 0.6915, cover loss of 0.7330, secret loss of 0.5621
# Training: Batch 860/1000. Loss of 0.7525, cover loss of 0.7540, secret loss of 0.6106
# Training: Batch 861/1000. Loss of 0.7129, cover loss of 0.6799, secret loss of 0.6179
# Training: Batch 862/1000. Loss of 0.7026, cover loss of 0.7738, secret loss of 0.5370
# Training: Batch 863/1000. Loss of 0.7091, cover loss of 0.7134, secret loss of 0.5928
# Training: Batch 864/1000. Loss of 0.7417, cover loss of 0.7123, secret loss of 0.6482
# Training: Batch 865/1000. Loss of 0.6883, cover loss of 0.6314, secret loss of 0.6446
# Training: Batch 866/1000. Loss of 0.7737, cover loss of 0.7328, secret loss of 0.6702
# Training: Batch 867/1000. Loss of 0.6517, cover loss of 0.6890, secret loss of 0.5548
# Training: Batch 868/1000. Loss of 0.6862, cover loss of 0.6711, secret loss of 0.6106
# Training: Batch 869/1000. Loss of 0.7074, cover loss of 0.7566, secret loss of 0.5467
# Training: Batch 870/1000. Loss of 0.7628, cover loss of 0.7303, secret loss of 0.6306
# Training: Batch 871/1000. Loss of 0.6517, cover loss of 0.6924, secret loss of 0.5471
# Training: Batch 872/1000. Loss of 0.6950, cover loss of 0.7030, secret loss of 0.5831
# Training: Batch 873/1000. Loss of 0.6813, cover loss of 0.7270, secret loss of 0.5515
# Training: Batch 874/1000. Loss of 0.7001, cover loss of 0.6906, secret loss of 0.6308
# Training: Batch 875/1000. Loss of 0.6822, cover loss of 0.7198, secret loss of 0.5437
# Training: Batch 876/1000. Loss of 0.7298, cover loss of 0.7112, secret loss of 0.6253
# Training: Batch 877/1000. Loss of 0.7732, cover loss of 0.7791, secret loss of 0.6109
# Training: Batch 878/1000. Loss of 0.6354, cover loss of 0.6773, secret loss of 0.5469
# Training: Batch 879/1000. Loss of 0.7792, cover loss of 0.7810, secret loss of 0.6025
# Training: Batch 880/1000. Loss of 0.7563, cover loss of 0.7005, secret loss of 0.6688
# Training: Batch 881/1000. Loss of 0.6467, cover loss of 0.6406, secret loss of 0.6047
# Training: Batch 882/1000. Loss of 0.7541, cover loss of 0.7766, secret loss of 0.6016
# Training: Batch 883/1000. Loss of 0.6327, cover loss of 0.6742, secret loss of 0.5458
# Training: Batch 884/1000. Loss of 0.6648, cover loss of 0.7193, secret loss of 0.5388
# Training: Batch 885/1000. Loss of 0.6947, cover loss of 0.7262, secret loss of 0.5883
# Training: Batch 886/1000. Loss of 0.6405, cover loss of 0.6509, secret loss of 0.5848
# Training: Batch 887/1000. Loss of 0.6558, cover loss of 0.7173, secret loss of 0.5282
# Training: Batch 888/1000. Loss of 0.6968, cover loss of 0.6931, secret loss of 0.6020
# Training: Batch 889/1000. Loss of 0.6904, cover loss of 0.6685, secret loss of 0.6125
# Training: Batch 890/1000. Loss of 0.7047, cover loss of 0.7049, secret loss of 0.5752
# Training: Batch 891/1000. Loss of 0.7498, cover loss of 0.7545, secret loss of 0.6057
# Training: Batch 892/1000. Loss of 0.7881, cover loss of 0.8210, secret loss of 0.5863
# Training: Batch 893/1000. Loss of 0.6977, cover loss of 0.7408, secret loss of 0.5674
# Training: Batch 894/1000. Loss of 0.6818, cover loss of 0.6950, secret loss of 0.5799
# Training: Batch 895/1000. Loss of 0.6553, cover loss of 0.7067, secret loss of 0.5359
# Training: Batch 896/1000. Loss of 0.6491, cover loss of 0.6658, secret loss of 0.5623
# Training: Batch 897/1000. Loss of 0.7369, cover loss of 0.6654, secret loss of 0.6734
# Training: Batch 898/1000. Loss of 0.7477, cover loss of 0.7866, secret loss of 0.5663
# Training: Batch 899/1000. Loss of 0.7573, cover loss of 0.7553, secret loss of 0.6099
# Training: Batch 900/1000. Loss of 0.6913, cover loss of 0.7419, secret loss of 0.5730
# Training: Batch 901/1000. Loss of 0.6715, cover loss of 0.7006, secret loss of 0.5590
# Training: Batch 902/1000. Loss of 0.6981, cover loss of 0.6775, secret loss of 0.6212
# Training: Batch 903/1000. Loss of 0.6870, cover loss of 0.7102, secret loss of 0.5690
# Training: Batch 904/1000. Loss of 0.7333, cover loss of 0.7550, secret loss of 0.5682
# Training: Batch 905/1000. Loss of 0.6615, cover loss of 0.6627, secret loss of 0.5866
# Training: Batch 906/1000. Loss of 0.6887, cover loss of 0.6638, secret loss of 0.6341
# Training: Batch 907/1000. Loss of 0.6380, cover loss of 0.6909, secret loss of 0.5250
# Training: Batch 908/1000. Loss of 0.6952, cover loss of 0.6967, secret loss of 0.6191
# Training: Batch 909/1000. Loss of 0.7054, cover loss of 0.7087, secret loss of 0.6038
# Training: Batch 910/1000. Loss of 0.7163, cover loss of 0.7402, secret loss of 0.5955
# Training: Batch 911/1000. Loss of 0.7414, cover loss of 0.7666, secret loss of 0.5966
# Training: Batch 912/1000. Loss of 0.6583, cover loss of 0.7212, secret loss of 0.5339
# Training: Batch 913/1000. Loss of 0.7653, cover loss of 0.7694, secret loss of 0.6069
# Training: Batch 914/1000. Loss of 0.7062, cover loss of 0.6640, secret loss of 0.6545
# Training: Batch 915/1000. Loss of 0.7400, cover loss of 0.7285, secret loss of 0.6052
# Training: Batch 916/1000. Loss of 0.8278, cover loss of 0.8270, secret loss of 0.6358
# Training: Batch 917/1000. Loss of 0.7070, cover loss of 0.7023, secret loss of 0.6017
# Training: Batch 918/1000. Loss of 0.7302, cover loss of 0.7142, secret loss of 0.6285
# Training: Batch 919/1000. Loss of 0.6866, cover loss of 0.6909, secret loss of 0.6047
# Training: Batch 920/1000. Loss of 0.7327, cover loss of 0.7121, secret loss of 0.6228
# Training: Batch 921/1000. Loss of 0.6945, cover loss of 0.7294, secret loss of 0.5830
# Training: Batch 922/1000. Loss of 0.6245, cover loss of 0.6622, secret loss of 0.5387
# Training: Batch 923/1000. Loss of 0.6615, cover loss of 0.6640, secret loss of 0.5971
# Training: Batch 924/1000. Loss of 0.7772, cover loss of 0.8394, secret loss of 0.5565
# Training: Batch 925/1000. Loss of 0.6821, cover loss of 0.7467, secret loss of 0.5304
# Training: Batch 926/1000. Loss of 0.7436, cover loss of 0.7738, secret loss of 0.5658
# Training: Batch 927/1000. Loss of 0.6777, cover loss of 0.7347, secret loss of 0.5319
# Training: Batch 928/1000. Loss of 0.7128, cover loss of 0.7185, secret loss of 0.6037
# Training: Batch 929/1000. Loss of 0.6855, cover loss of 0.7171, secret loss of 0.5656
# Training: Batch 930/1000. Loss of 0.7180, cover loss of 0.7472, secret loss of 0.5515
# Training: Batch 931/1000. Loss of 0.6008, cover loss of 0.6180, secret loss of 0.5518
# Training: Batch 932/1000. Loss of 0.7253, cover loss of 0.6909, secret loss of 0.6429
# Training: Batch 933/1000. Loss of 0.7050, cover loss of 0.7490, secret loss of 0.5545
# Training: Batch 934/1000. Loss of 0.7671, cover loss of 0.7322, secret loss of 0.6670
# Training: Batch 935/1000. Loss of 0.6678, cover loss of 0.7117, secret loss of 0.5507
# Training: Batch 936/1000. Loss of 0.6249, cover loss of 0.7007, secret loss of 0.5046
# Training: Batch 937/1000. Loss of 0.7191, cover loss of 0.7437, secret loss of 0.5868
# Training: Batch 938/1000. Loss of 0.7442, cover loss of 0.7625, secret loss of 0.6076
# Training: Batch 939/1000. Loss of 0.6688, cover loss of 0.6172, secret loss of 0.6313
# Training: Batch 940/1000. Loss of 0.7001, cover loss of 0.7354, secret loss of 0.5741
# Training: Batch 941/1000. Loss of 0.7320, cover loss of 0.7453, secret loss of 0.6095
# Training: Batch 942/1000. Loss of 0.6767, cover loss of 0.7237, secret loss of 0.5551
# Training: Batch 943/1000. Loss of 0.6825, cover loss of 0.6611, secret loss of 0.6577
# Training: Batch 944/1000. Loss of 0.7662, cover loss of 0.7567, secret loss of 0.6468
# Training: Batch 945/1000. Loss of 0.7410, cover loss of 0.7037, secret loss of 0.6290
# Training: Batch 946/1000. Loss of 0.6408, cover loss of 0.6695, secret loss of 0.5554
# Training: Batch 947/1000. Loss of 0.6912, cover loss of 0.6938, secret loss of 0.5968
# Training: Batch 948/1000. Loss of 0.6798, cover loss of 0.6772, secret loss of 0.6136
# Training: Batch 949/1000. Loss of 0.6017, cover loss of 0.6043, secret loss of 0.5792
# Training: Batch 950/1000. Loss of 0.7425, cover loss of 0.7564, secret loss of 0.6022
# Training: Batch 951/1000. Loss of 0.6640, cover loss of 0.6913, secret loss of 0.5630
# Training: Batch 952/1000. Loss of 0.6650, cover loss of 0.6924, secret loss of 0.5551
# Training: Batch 953/1000. Loss of 0.6532, cover loss of 0.6924, secret loss of 0.5558
# Training: Batch 954/1000. Loss of 0.6820, cover loss of 0.6737, secret loss of 0.6061
# Training: Batch 955/1000. Loss of 0.7391, cover loss of 0.7148, secret loss of 0.6300
# Training: Batch 956/1000. Loss of 0.7372, cover loss of 0.7127, secret loss of 0.6233
# Training: Batch 957/1000. Loss of 0.7447, cover loss of 0.7209, secret loss of 0.6506
# Training: Batch 958/1000. Loss of 0.7061, cover loss of 0.7326, secret loss of 0.5900
# Training: Batch 959/1000. Loss of 0.7045, cover loss of 0.7319, secret loss of 0.5795
# Training: Batch 960/1000. Loss of 0.7232, cover loss of 0.7095, secret loss of 0.6402
# Training: Batch 961/1000. Loss of 0.6727, cover loss of 0.7221, secret loss of 0.5470
# Training: Batch 962/1000. Loss of 0.7239, cover loss of 0.7374, secret loss of 0.5867
# Training: Batch 963/1000. Loss of 0.6778, cover loss of 0.7186, secret loss of 0.5698
# Training: Batch 964/1000. Loss of 0.7449, cover loss of 0.7702, secret loss of 0.5771
# Training: Batch 965/1000. Loss of 0.6399, cover loss of 0.6231, secret loss of 0.5997
# Training: Batch 966/1000. Loss of 0.7816, cover loss of 0.7268, secret loss of 0.6687
# Training: Batch 967/1000. Loss of 0.6394, cover loss of 0.6832, secret loss of 0.5416
# Training: Batch 968/1000. Loss of 0.7421, cover loss of 0.7369, secret loss of 0.6280
# Training: Batch 969/1000. Loss of 0.6901, cover loss of 0.7196, secret loss of 0.5976
# Training: Batch 970/1000. Loss of 0.7148, cover loss of 0.7127, secret loss of 0.6204
# Training: Batch 971/1000. Loss of 0.7147, cover loss of 0.7456, secret loss of 0.5892
# Training: Batch 972/1000. Loss of 0.6820, cover loss of 0.6603, secret loss of 0.6170
# Training: Batch 973/1000. Loss of 0.6772, cover loss of 0.6563, secret loss of 0.6180
# Training: Batch 974/1000. Loss of 0.6643, cover loss of 0.7220, secret loss of 0.5360
# Training: Batch 975/1000. Loss of 0.6360, cover loss of 0.6630, secret loss of 0.5457
# Training: Batch 976/1000. Loss of 0.6612, cover loss of 0.7517, secret loss of 0.4983
# Training: Batch 977/1000. Loss of 0.7022, cover loss of 0.6858, secret loss of 0.6102
# Training: Batch 978/1000. Loss of 0.7545, cover loss of 0.7439, secret loss of 0.6295
# Training: Batch 979/1000. Loss of 0.7382, cover loss of 0.7580, secret loss of 0.5928
# Training: Batch 980/1000. Loss of 0.6751, cover loss of 0.6947, secret loss of 0.5486
# Training: Batch 981/1000. Loss of 0.7055, cover loss of 0.7280, secret loss of 0.5721
# Training: Batch 982/1000. Loss of 0.6690, cover loss of 0.6723, secret loss of 0.5897
# Training: Batch 983/1000. Loss of 0.7285, cover loss of 0.7122, secret loss of 0.6246
# Training: Batch 984/1000. Loss of 0.8227, cover loss of 0.8269, secret loss of 0.6208
# Training: Batch 985/1000. Loss of 0.6712, cover loss of 0.7058, secret loss of 0.5541
# Training: Batch 986/1000. Loss of 0.6688, cover loss of 0.6736, secret loss of 0.5865
# Training: Batch 987/1000. Loss of 0.6475, cover loss of 0.6497, secret loss of 0.5952
# Training: Batch 988/1000. Loss of 0.7456, cover loss of 0.7472, secret loss of 0.6286
# Training: Batch 989/1000. Loss of 0.7072, cover loss of 0.7189, secret loss of 0.5927
# Training: Batch 990/1000. Loss of 0.6569, cover loss of 0.6650, secret loss of 0.5948
# Training: Batch 991/1000. Loss of 0.7938, cover loss of 0.7681, secret loss of 0.6594
# Training: Batch 992/1000. Loss of 0.8499, cover loss of 0.7924, secret loss of 0.6933
# Training: Batch 993/1000. Loss of 0.7416, cover loss of 0.7584, secret loss of 0.6089
# Training: Batch 994/1000. Loss of 0.6530, cover loss of 0.6729, secret loss of 0.5716
# Training: Batch 995/1000. Loss of 0.7526, cover loss of 0.6624, secret loss of 0.6863
# Training: Batch 996/1000. Loss of 0.6990, cover loss of 0.7069, secret loss of 0.6098
# Training: Batch 997/1000. Loss of 0.6748, cover loss of 0.6721, secret loss of 0.5804
# Training: Batch 998/1000. Loss of 0.7865, cover loss of 0.7922, secret loss of 0.6150
# Training: Batch 999/1000. Loss of 0.8142, cover loss of 0.7474, secret loss of 0.6788
# Training: Batch 1000/1000. Loss of 0.6909, cover loss of 0.7508, secret loss of 0.5576
# Epoch [50/50], Average_loss: 0.7023

# %%
 # Plot loss through epochs
plt.plot(loss_history)
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Batch')
plt.show()

# %%
def pixel_errors(input_S, input_C, decoded_S, decoded_C):
    """Calculates mean of Sum of Squared Errors per pixel for cover and secret images. """
    input_S = np.array(input_S.detach().cpu())
    input_C = np.array(input_C.detach().cpu())
    decoded_S = np.array(decoded_S.detach().cpu())
    decoded_C = np.array(decoded_C.detach().cpu())
    # print(input_S)
    see_Spixel = np.sqrt(np.mean(np.square(255*(input_S - decoded_S))))
    see_Cpixel = np.sqrt(np.mean(np.square(255*(input_C - decoded_C))))
    
    return see_Spixel, see_Cpixel

import math
def psnr(input_S, input_C, decoded_S, decoded_C):
    input_S = np.array(input_S.detach().cpu())
    input_C = np.array(input_C.detach().cpu())
    decoded_S = np.array(decoded_S.detach().cpu())
    decoded_C = np.array(decoded_C.detach().cpu())
    mse_s = np.mean(np.square(255*(input_S - decoded_S)))
    mse_c = np.mean(np.square(255*(input_C - decoded_C)))
    psnr_s = 10*math.log10(255**2/mse_s)
    psnr_c = 10*math.log10(255**2/mse_c)
    return psnr_s, psnr_c

def pixel_histogram(diff_S, diff_C):
    """Calculates histograms of errors for cover and secret image. """
    diff_Sflat = diff_S.flatten()
    diff_Cflat = diff_C.flatten()
    
    fig = plt.figure(figsize=(15, 5))
    a=fig.add_subplot(1,2,1)
        
    imgplot = plt.hist(255* diff_Cflat, 100, density=1, alpha=0.75, facecolor='red')
    a.set_title('Distribution of error in the Cover image.')
    plt.axis([0, 250, 0, 0.2])
    
    a=fig.add_subplot(1,2,2)
    imgplot = plt.hist(255* diff_Sflat, 100, density=1, alpha=0.75, facecolor='red')
    a.set_title('Distribution of errors in the Secret image.')
    plt.axis([0, 250, 0, 0.2])
    
    plt.show()

# %%
# net.load_state_dict(torch.load(MODELS_PATH+'Epoch N4.pkl'))

# Switch to evaluate mode
net.eval()
Path(PATH+"LOSS2_1_ds_img_50").mkdir(parents=True, exist_ok=True)
Path(PATH+"LOSS2_1_ds_img_50/cover_images/").mkdir(parents=True, exist_ok=True)
Path(PATH+"LOSS2_1_ds_img_50/container_images/").mkdir(parents=True, exist_ok=True)
save_path = PATH+"LOSS2_1_ds_img_50/"

test_losses = []

S_errors = []
C_errors = []

psnr_s,psnr_c = [], []
# Show images
for idx, test_batch in enumerate(test_loader):
     # Saves images
    data, _ = test_batch
    data = data.to(device)

    # Saves secret images and secret covers
    test_secret = data[:len(data)//2]
    test_cover = data[len(data)//2:]

    # Creates variable from secret and cover images
    test_secret = Variable(test_secret, volatile=True)
    test_cover = Variable(test_cover, volatile=True)

    # Compute output
    test_hidden, test_output = net(test_secret, test_cover)
    
    # Calculate loss
    test_loss, loss_cover, loss_secret = customized_loss(test_output, test_hidden, test_secret, test_cover, beta)
    
    diff_S, diff_C = np.abs(np.array(test_output.data.detach().cpu()) - np.array(test_secret.data.detach().cpu())), np.abs(np.array(test_hidden.data.detach().cpu()) - np.array(test_cover.data.detach().cpu()))
    
#     print (diff_S, diff_C)

    # Print pixel-wise average errors in a 256 scale.
    S_error, C_error = pixel_errors(test_secret, test_cover, test_output, test_hidden)
    S_errors.append(S_error)
    C_errors.append(C_error)

    S_psnr, C_psnr = psnr(test_secret, test_cover, test_output, test_hidden)
    psnr_s.append(S_psnr)
    psnr_c.append(C_psnr)
    
    if idx in [1,2,3,4]:
        print ('Total loss: {:.2f} \nLoss on secret: {:.2f} \nLoss on cover: {:.2f}'.format(test_loss.data.item(), loss_secret.data.item(), loss_cover.data.item()))

        # Creates img tensor
        imgs = [test_secret.data.detach().cpu(), test_output.data.detach().cpu(), test_cover.data.detach().cpu(), test_hidden.data.detach().cpu()]
        imgs_tsor = torch.cat(imgs, 0)

        # Prints Images
        imshow(utils.make_grid(imgs_tsor), idx+1, learning_rate=learning_rate, beta=beta)

    if idx < 500:
        container_img = tensor_to_image(test_hidden.data.detach().cpu())
        container_img = Image.fromarray(container_img)
        container_img.save(save_path+"container_images/"+str(idx)+".jpeg")
        cover_img = tensor_to_image(test_cover.data.detach().cpu())
        cover_img = Image.fromarray(cover_img)
        cover_img.save(save_path+"cover_images/"+str(idx)+".jpeg")
            
    test_losses.append(test_loss.data.item())
        
mean_test_loss = np.mean(test_losses)

print ('Average loss on test set: {:.2f}'.format(mean_test_loss))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:27: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:43: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Total loss: 0.46
# Loss on secret: 0.48
# Loss on cover: 0.69
# Total loss: 0.61
# Loss on secret: 0.68
# Loss on cover: 0.59
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Total loss: 0.93
# Loss on secret: 0.60
# Loss on cover: 1.05
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Total loss: 0.72
# Loss on secret: 0.72
# Loss on cover: 0.69
# Average loss on test set: 0.75

# %%
print ("Avg. S error per pixel [0, 255]:", sum(S_errors)/len(S_errors))
print ("Avg. C error per pixel [0, 255]:", sum(C_errors)/len(C_errors))

# %%
print ("Avg. PSNR of secret and decoded secret:", sum(psnr_s)/len(psnr_s))
print ("Avg. PSNR of cover and container:", sum(psnr_c)/len(psnr_c))

# %%
# Plot distribution of errors in cover and secret images.
pixel_histogram(diff_S, diff_C)
