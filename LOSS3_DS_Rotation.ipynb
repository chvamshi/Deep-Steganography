# %% [markdown]
# <a href="https://colab.research.google.com/github/chvamshi/Deep-Steganography/blob/main/LOSS3_DS_Rotation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget http://cs231n.stanford.edu/tiny-imagenet-200.zip
# !unzip -q tiny-imagenet-200.zip && ls tiny-imagenet-200
# Out:
# --2022-02-06 10:21:17--  http://cs231n.stanford.edu/tiny-imagenet-200.zip
# Resolving cs231n.stanford.edu (cs231n.stanford.edu)... 171.64.68.10
# Connecting to cs231n.stanford.edu (cs231n.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248100043 (237M) [application/zip]
# Saving to: ‘tiny-imagenet-200.zip’
#
# tiny-imagenet-200.z 100%[===================>] 236.61M  78.2MB/s    in 3.0s
#
# 2022-02-06 10:21:20 (78.2 MB/s) - ‘tiny-imagenet-200.zip’ saved [248100043/248100043]
#
# test  train  val  wnids.txt  words.txt

# %%
# Imports necessary libraries and modules
from itertools import islice
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch.autograd import Variable
from torch import utils
from torch.utils.data import Subset
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import os 
from pathlib import Path
import pickle
import random
from torchvision import datasets, utils
import torchvision.transforms as transforms
from torchvision.transforms import ToPILImage
from torchvision.transforms import RandomResizedCrop
from torchvision.transforms import RandomRotation
from torchvision.transforms.functional import resized_crop
from random import shuffle
from IPython.display import Image
from PIL import Image

# Use GPU if it is present
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
# Directory path
# os.chdir("..")
cwd = '/content/tiny-imagenet-200'

# Hyper Parameters
num_epochs = 50
batch_size = 32
learning_rate = 0.001
beta = 1

# Mean and std deviation of imagenet dataset. Source: http://cs231n.stanford.edu/reports/2017/pdfs/101.pdf
std = [0.229, 0.224, 0.225]
mean = [0.485, 0.456, 0.406]

# TODO: Define train, validation and models
MODELS_PATH = '/content/output/models'
# TRAIN_PATH = cwd+'/train/'
# VALID_PATH = cwd+'/valid/'
VALID_PATH = cwd+'/val/'
TRAIN_PATH = cwd+'/train/'
TEST_PATH = cwd+'/test/'

# if not os.path.exists(MODELS_PATH): os.mkdir(MODELS_PATH)

# %%
def variance(image1, image2):
    var1 = torch.var(image1)
    var2 = torch.var(image2)

    return var1+var2

def customized_loss(S_prime, C_prime, S, C, B):
    ''' Calculates loss specified on the paper.'''
    
    loss_cover = torch.nn.functional.mse_loss(C_prime, C)
    loss_secret = torch.nn.functional.mse_loss(S_prime, S)

    loss_all = (loss_cover + B * loss_secret + variance(C_prime, C) + variance(S_prime, S))/4

    return loss_all, loss_cover, loss_secret

def denormalize(image, std, mean):
    ''' Denormalizes a tensor of images.'''

    for t in range(3):
        image[t, :, :] = (image[t, :, :] * std[t]) + mean[t]
    return image

def imshow(img, idx, learning_rate, beta):
    '''Prints out an image given in tensor format.'''
    
    img = denormalize(img, std, mean)
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.title('Example '+str(idx)+', lr='+str(learning_rate)+', B='+str(beta))
    plt.show()
    return

def gaussian(tensor, mean=0, stddev=0.1):
    '''Adds random noise to a tensor.'''
    
    noise = torch.nn.init.normal(torch.Tensor(tensor.size()), 0, 0.1).to(device)
    return Variable(tensor + noise)

def tensor_to_image(tensor):
    """
    Transforms a torch tensor into numpy uint8 array (image)
    :param tensor: (batch_size x channels x height x width) torch tensor in range [-1.0, 1.0]
    :return: (batch_size x height x width x channels) uint8 array
    """
    image = tensor.cpu().numpy()[0]
    # image = tensor.permute(0, 2, 3, 1).cpu().numpy()
    image = np.transpose(image, (1,2,0))
    image = (image + 1) * 127.5
    return np.clip(image, 0, 255).astype(np.uint8)

# %%
import torch.nn as nn
import numpy as np

def random_float(min, max):
    """
    Return a random number
    :param min:
    :param max:
    :return:
    """
    return np.random.rand() * (max - min) + min


def get_random_rectangle_inside(image, height_ratio_range, width_ratio_range):
    """
    Returns a random rectangle inside the image, where the size is random and is controlled by height_ratio_range and width_ratio_range.
    This is analogous to a random crop. For example, if height_ratio_range is (0.7, 0.9), then a random number in that range will be chosen
    (say it is 0.75 for illustration), and the image will be cropped such that the remaining height equals 0.75. In fact,
    a random 'starting' position rs will be chosen from (0, 0.25), and the crop will start at rs and end at rs + 0.75. This ensures
    that we crop from top/bottom with equal probability.
    The same logic applies to the width of the image, where width_ratio_range controls the width crop range.
    :param image: The image we want to crop
    :param height_ratio_range: The range of remaining height ratio
    :param width_ratio_range:  The range of remaining width ratio.
    :return: "Cropped" rectange with width and height drawn randomly height_ratio_range and width_ratio_range
    """
    # print(image.shape)
    image_height = image.shape[1]
    image_width = image.shape[2]

    remaining_height = int(np.rint(random_float(height_ratio_range[0], height_ratio_range[1]) * image_height))
    remaining_width = int(np.rint(random_float(width_ratio_range[0], width_ratio_range[0]) * image_width))

    if remaining_height == image_height:
        height_start = 0
    else:
        height_start = np.random.randint(0, image_height - remaining_height)

    if remaining_width == image_width:
        width_start = 0
    else:
        width_start = np.random.randint(0, image_width - remaining_width)

    return height_start, height_start+remaining_height, width_start, width_start+remaining_width


class Crop(nn.Module):
    """
    Randomly crops the image from top/bottom and left/right. The amount to crop is controlled by parameters
    heigth_ratio_range and width_ratio_range
    """
    def __init__(self, height_ratio_range, width_ratio_range):
        """
        :param height_ratio_range:
        :param width_ratio_range:
        """
        super(Crop, self).__init__()
        self.height_ratio_range = height_ratio_range
        self.width_ratio_range = width_ratio_range


    def forward(self, noised_and_cover):
        noised_image = noised_and_cover[0]
        print("Noisedimageshape: ",noised_image.shape)
        shape = noised_image.shape
        # crop_rectangle is in form (from, to) where @from and @to are 2D points -- (height, width)

        h_start, h_end, w_start, w_end = get_random_rectangle_inside(noised_image, self.height_ratio_range, self.width_ratio_range)

        noised_image =  noised_image[
               :,
               h_start: h_end,
               w_start: w_end].clone()
        noised_image1 = noised_image.expand(-1,64,64)
        print(noised_image1.shape)
        noised_and_cover[0] = noised_image1.clone()

        return noised_and_cover

# %%
# Preparation Network (2 conv layers)
class PrepNetwork(nn.Module):
    def __init__(self):
        super(PrepNetwork, self).__init__()
        self.initialP3 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialP4 = nn.Sequential(
            nn.Conv2d(3, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialP5 = nn.Sequential(
            nn.Conv2d(3, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalP3 = nn.Sequential(
            nn.Conv2d(65, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalP4 = nn.Sequential(
            nn.Conv2d(65, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalP5 = nn.Sequential(
            nn.Conv2d(65, 5, kernel_size=5, padding=2),
            nn.ReLU())

    def forward(self, p):
        p1 = self.initialP3(p)
        p2 = self.initialP4(p)
        p3 = self.initialP5(p)
        mid = torch.cat((p1, p2, p3), 1)
        p4 = self.finalP3(mid)
        p5 = self.finalP4(mid)
        p6 = self.finalP5(mid)
        # print(p4.shape)
        # print(p5.shape)
        # print(p6.shape)
        out = torch.cat((p4, p5, p6), 1)
        return out

# Hiding Network (5 conv layers)
class HidingNetwork(nn.Module):
    def __init__(self):
        super(HidingNetwork, self).__init__()
        self.initialH3 = nn.Sequential(
            nn.Conv2d(68, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialH4 = nn.Sequential(
            nn.Conv2d(68, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialH5 = nn.Sequential(
            nn.Conv2d(68, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalH3 = nn.Sequential(
            nn.Conv2d(65, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalH4 = nn.Sequential(
            nn.Conv2d(65, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalH5 = nn.Sequential(
            nn.Conv2d(65, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalH = nn.Sequential(
            nn.Conv2d(65, 3, kernel_size=1, padding=0))
        
    def forward(self, h):
        h1 = self.initialH3(h)
        h2 = self.initialH4(h)
        h3 = self.initialH5(h)
        mid = torch.cat((h1, h2, h3), 1)
        h4 = self.finalH3(mid)
        h5 = self.finalH4(mid)
        h6 = self.finalH5(mid)
        mid2 = torch.cat((h4, h5, h6), 1)
        out = self.finalH(mid2)
        out_noise = gaussian(out.data, 0, 0.1)
        return out, out_noise

# Reveal Network (2 conv layers)
class RevealNetwork(nn.Module):
    def __init__(self):
        super(RevealNetwork, self).__init__()
        self.initialR3 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialR4 = nn.Sequential(
            nn.Conv2d(3, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialR5 = nn.Sequential(
            nn.Conv2d(3, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalR3 = nn.Sequential(
            nn.Conv2d(65, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalR4 = nn.Sequential(
            nn.Conv2d(65, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalR5 = nn.Sequential(
            nn.Conv2d(65, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalR = nn.Sequential(
            nn.Conv2d(65, 3, kernel_size=1, padding=0))

    def forward(self, r, img_shape):
        # r = r.expand(img_shape)
        r1 = self.initialR3(r)
        r2 = self.initialR4(r)
        r3 = self.initialR5(r)
        mid = torch.cat((r1, r2, r3), 1)
        r4 = self.finalR3(mid)
        r5 = self.finalR4(mid)
        r6 = self.finalR5(mid)
        mid2 = torch.cat((r4, r5, r6), 1)
        out = self.finalR(mid2)
        return out

# Join three networks in one module
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.m1 = PrepNetwork().to(device)
        self.m2 = HidingNetwork().to(device)
        self.m3 = RevealNetwork().to(device)
        self.crop = Crop((0.7,0.9),(0.7,0.9)).to(device)

    def forward(self, secret, cover):
        img_shape = secret.shape
        x_1 = self.m1(secret)
        mid = torch.cat((x_1, cover), 1)
        x_2, x_2_noise = self.m2(mid)
        # x_2_noise = RandomRotation(degrees=(0, 180))(x_2_noise)
        x_2 = RandomRotation(degrees=(0, 180))(x_2)
        # x_3 = self.m3(x_2_noise, img_shape)
        x_3 = self.m3(x_2, img_shape)
        return x_2, x_3

# %%
# Creates net object
net = Net().to(device)

# %%
# Creates training set
train_data = datasets.ImageFolder(
        TRAIN_PATH,
        transforms.Compose([
        # transforms.Scale(256),
        # transforms.RandomCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean,
        std=std)
        ]))
train_data = Subset(train_data, [i for i in range(32000)])
train_loader = torch.utils.data.DataLoader(
        train_data, batch_size=batch_size, num_workers=1, 
        pin_memory=True, shuffle=True, drop_last=True)

# Creates test set
test_data = datasets.ImageFolder(
        TEST_PATH, 
        transforms.Compose([
        # transforms.Scale(256),
        # transforms.RandomCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean,
        std=std)
        ]))
test_data = Subset(test_data,[i for i in range(5000)])
test_loader = torch.utils.data.DataLoader(
        test_data, batch_size=2, num_workers=1, 
        pin_memory=True, shuffle=True, drop_last=True)

# %%
PATH = "/content/drive/MyDrive/"
loss_history = []

def train_model(train_loader, beta, learning_rate):
    
    # Save optimizer
    optimizer = optim.Adam(net.parameters(), lr=learning_rate)
    
    loss_history = []
    # Iterate over batches performing forward and backward passes
    for epoch in range(num_epochs):

        # Train mode
        net.train()
        
        train_losses = []
        # Train one epoch
        for idx, train_batch in enumerate(train_loader):

            data, _  = train_batch
            data = data.to(device)

            # Saves secret images and secret covers
            train_covers = data[:len(data)//2]
            train_secrets = data[len(data)//2:]
            
            # Creates variable from secret and cover images
            train_secrets = Variable(train_secrets, requires_grad=False)
            train_covers = Variable(train_covers, requires_grad=False)

            # Forward + Backward + Optimize
            optimizer.zero_grad()
            train_hidden, train_output = net(train_secrets, train_covers)

            # Calculate loss and perform backprop
            train_loss, train_loss_cover, train_loss_secret = customized_loss(train_output, train_hidden, train_secrets, train_covers, beta)
            train_loss.backward()
            optimizer.step()
            
            # Saves training loss
            # print(train_loss.data)
            train_losses.append(train_loss.data.item())
            loss_history.append(train_loss.data.item())
            
            # Prints mini-batch losses
            print('Training: Batch {0}/{1}. Loss of {2:.4f}, cover loss of {3:.4f}, secret loss of {4:.4f}'.format(idx+1, len(train_loader), train_loss.data.item(), train_loss_cover.data.item(), train_loss_secret.data.item()))
    
        # Save model
        # torch.save(net.state_dict(), '/content/Epoch N{}.pkl'.format(epoch+1))
        torch.save(net.state_dict(), PATH+"LOSS3_ds_rotation.pth")
        with open(PATH+"LOSS3_loss_history_rotation.txt", "a") as f:
            for s in loss_history:
                f.write(str(s) +"\n")
                
        mean_train_loss = np.mean(train_losses)
    
        # Prints epoch average loss
        print ('Epoch [{0}/{1}], Average_loss: {2:.4f}'.format(
                epoch+1, num_epochs, mean_train_loss))
    
    return net, mean_train_loss, loss_history

# %%
# Load model
# net.load_state_dict(torch.load(PATH+"LOSS3_ds_rotation.pth"))
# loss_history = []
# with open(PATH+"LOSS3_loss_history_rotation.txt", "r") as f:
#   for line in f:
#     loss_history.append(float(line.strip()))

net, mean_train_loss, loss_history = train_model(train_loader, beta, learning_rate)
# loss_history.extend(loss_history1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
# Streaming output truncated to the last 5000 lines.
# Training: Batch 6/1000. Loss of 1.2535, cover loss of 1.1294, secret loss of 1.3107
# Training: Batch 7/1000. Loss of 1.2002, cover loss of 1.0910, secret loss of 0.9702
# Training: Batch 8/1000. Loss of 1.4187, cover loss of 1.3103, secret loss of 1.2857
# Training: Batch 9/1000. Loss of 1.5886, cover loss of 1.5784, secret loss of 1.4589
# Training: Batch 10/1000. Loss of 1.2434, cover loss of 1.1578, secret loss of 1.1664
# Training: Batch 11/1000. Loss of 1.1028, cover loss of 0.8536, secret loss of 0.8365
# Training: Batch 12/1000. Loss of 1.2758, cover loss of 1.1585, secret loss of 1.2823
# Training: Batch 13/1000. Loss of 1.2489, cover loss of 1.1287, secret loss of 1.1523
# Training: Batch 14/1000. Loss of 1.1657, cover loss of 1.0472, secret loss of 1.1690
# Training: Batch 15/1000. Loss of 1.0957, cover loss of 0.7989, secret loss of 0.8884
# Training: Batch 16/1000. Loss of 1.3075, cover loss of 1.2877, secret loss of 0.9057
# Training: Batch 17/1000. Loss of 1.2225, cover loss of 1.0298, secret loss of 1.2621
# Training: Batch 18/1000. Loss of 1.2208, cover loss of 1.0303, secret loss of 1.1518
# Training: Batch 19/1000. Loss of 1.3073, cover loss of 1.1688, secret loss of 1.1158
# Training: Batch 20/1000. Loss of 1.1173, cover loss of 1.0401, secret loss of 0.9919
# Training: Batch 21/1000. Loss of 1.1679, cover loss of 1.0402, secret loss of 1.0764
# Training: Batch 22/1000. Loss of 1.0627, cover loss of 1.0270, secret loss of 0.8133
# Training: Batch 23/1000. Loss of 1.2363, cover loss of 1.1043, secret loss of 0.7864
# Training: Batch 24/1000. Loss of 1.2277, cover loss of 1.1180, secret loss of 0.7571
# Training: Batch 25/1000. Loss of 1.0877, cover loss of 0.8834, secret loss of 0.8480
# Training: Batch 26/1000. Loss of 1.3007, cover loss of 1.1881, secret loss of 1.1459
# Training: Batch 27/1000. Loss of 1.1388, cover loss of 0.8817, secret loss of 0.8156
# Training: Batch 28/1000. Loss of 1.2422, cover loss of 1.0915, secret loss of 1.2544
# Training: Batch 29/1000. Loss of 1.0400, cover loss of 0.8262, secret loss of 0.8435
# Training: Batch 30/1000. Loss of 1.2726, cover loss of 1.0630, secret loss of 1.1542
# Training: Batch 31/1000. Loss of 1.2090, cover loss of 1.2515, secret loss of 1.0111
# Training: Batch 32/1000. Loss of 1.1596, cover loss of 1.0913, secret loss of 1.0923
# Training: Batch 33/1000. Loss of 1.0437, cover loss of 0.9100, secret loss of 0.6882
# Training: Batch 34/1000. Loss of 1.2662, cover loss of 1.0812, secret loss of 1.3376
# Training: Batch 35/1000. Loss of 1.1389, cover loss of 1.0263, secret loss of 0.7292
# Training: Batch 36/1000. Loss of 1.2678, cover loss of 1.1696, secret loss of 1.0975
# Training: Batch 37/1000. Loss of 1.1681, cover loss of 1.0147, secret loss of 0.9012
# Training: Batch 38/1000. Loss of 1.2433, cover loss of 1.2669, secret loss of 0.8232
# Training: Batch 39/1000. Loss of 1.1683, cover loss of 1.1301, secret loss of 0.7860
# Training: Batch 40/1000. Loss of 1.4584, cover loss of 1.3310, secret loss of 1.4082
# Training: Batch 41/1000. Loss of 1.0706, cover loss of 1.0803, secret loss of 0.8041
# Training: Batch 42/1000. Loss of 1.5466, cover loss of 1.3241, secret loss of 1.3697
# Training: Batch 43/1000. Loss of 1.2141, cover loss of 1.1318, secret loss of 0.9763
# Training: Batch 44/1000. Loss of 1.2784, cover loss of 1.1977, secret loss of 1.2834
# Training: Batch 45/1000. Loss of 1.1698, cover loss of 1.0504, secret loss of 0.9807
# Training: Batch 46/1000. Loss of 1.0881, cover loss of 0.9323, secret loss of 0.6941
# Training: Batch 47/1000. Loss of 1.3197, cover loss of 1.2280, secret loss of 1.1505
# Training: Batch 48/1000. Loss of 1.2690, cover loss of 1.1064, secret loss of 1.2568
# Training: Batch 49/1000. Loss of 1.2496, cover loss of 0.9662, secret loss of 0.8381
# Training: Batch 50/1000. Loss of 1.1135, cover loss of 1.0043, secret loss of 1.0663
# Training: Batch 51/1000. Loss of 1.1162, cover loss of 1.0008, secret loss of 0.7503
# Training: Batch 52/1000. Loss of 1.0485, cover loss of 0.9142, secret loss of 0.6330
# Training: Batch 53/1000. Loss of 1.0694, cover loss of 0.8372, secret loss of 0.9144
# Training: Batch 54/1000. Loss of 1.3176, cover loss of 1.2747, secret loss of 1.0708
# Training: Batch 55/1000. Loss of 1.3251, cover loss of 1.3654, secret loss of 1.0889
# Training: Batch 56/1000. Loss of 1.2584, cover loss of 1.2223, secret loss of 0.9586
# Training: Batch 57/1000. Loss of 1.1340, cover loss of 0.8634, secret loss of 0.9491
# Training: Batch 58/1000. Loss of 1.2471, cover loss of 0.9482, secret loss of 0.9565
# Training: Batch 59/1000. Loss of 1.0912, cover loss of 1.0639, secret loss of 0.6798
# Training: Batch 60/1000. Loss of 1.1400, cover loss of 0.9599, secret loss of 0.7186
# Training: Batch 61/1000. Loss of 1.1212, cover loss of 0.9410, secret loss of 0.7126
# Training: Batch 62/1000. Loss of 1.1639, cover loss of 0.9808, secret loss of 0.8561
# Training: Batch 63/1000. Loss of 1.2156, cover loss of 1.1576, secret loss of 1.0593
# Training: Batch 64/1000. Loss of 1.2468, cover loss of 1.0518, secret loss of 1.0334
# Training: Batch 65/1000. Loss of 1.1144, cover loss of 1.0108, secret loss of 0.5999
# Training: Batch 66/1000. Loss of 1.4317, cover loss of 1.2567, secret loss of 1.3694
# Training: Batch 67/1000. Loss of 1.3279, cover loss of 1.0230, secret loss of 1.4249
# Training: Batch 68/1000. Loss of 1.3378, cover loss of 1.0260, secret loss of 1.4474
# Training: Batch 69/1000. Loss of 1.2333, cover loss of 1.1598, secret loss of 1.1414
# Training: Batch 70/1000. Loss of 1.1787, cover loss of 1.1827, secret loss of 0.9609
# Training: Batch 71/1000. Loss of 1.1561, cover loss of 1.0667, secret loss of 1.0994
# Training: Batch 72/1000. Loss of 1.2370, cover loss of 1.1452, secret loss of 1.2181
# Training: Batch 73/1000. Loss of 1.1609, cover loss of 1.0920, secret loss of 1.0668
# Training: Batch 74/1000. Loss of 1.2578, cover loss of 1.1777, secret loss of 1.1639
# Training: Batch 75/1000. Loss of 1.3117, cover loss of 1.1748, secret loss of 1.2543
# Training: Batch 76/1000. Loss of 1.3604, cover loss of 1.3117, secret loss of 1.2895
# Training: Batch 77/1000. Loss of 1.4130, cover loss of 1.2607, secret loss of 1.4892
# Training: Batch 78/1000. Loss of 1.6324, cover loss of 1.4939, secret loss of 1.5925
# Training: Batch 79/1000. Loss of 1.2314, cover loss of 1.1111, secret loss of 1.1773
# Training: Batch 80/1000. Loss of 1.4195, cover loss of 1.3570, secret loss of 1.2593
# Training: Batch 81/1000. Loss of 1.2947, cover loss of 1.2391, secret loss of 1.1819
# Training: Batch 82/1000. Loss of 1.0587, cover loss of 0.9184, secret loss of 0.8007
# Training: Batch 83/1000. Loss of 1.1260, cover loss of 1.1273, secret loss of 0.7159
# Training: Batch 84/1000. Loss of 1.3008, cover loss of 1.0056, secret loss of 1.3496
# Training: Batch 85/1000. Loss of 1.2348, cover loss of 1.3385, secret loss of 1.0175
# Training: Batch 86/1000. Loss of 1.2118, cover loss of 1.1260, secret loss of 0.8039
# Training: Batch 87/1000. Loss of 1.1355, cover loss of 1.1191, secret loss of 0.9715
# Training: Batch 88/1000. Loss of 1.1664, cover loss of 1.0005, secret loss of 1.1905
# Training: Batch 89/1000. Loss of 1.1164, cover loss of 1.0512, secret loss of 1.0562
# Training: Batch 90/1000. Loss of 1.1768, cover loss of 0.9648, secret loss of 0.7723
# Training: Batch 91/1000. Loss of 1.2656, cover loss of 1.4015, secret loss of 0.9551
# Training: Batch 92/1000. Loss of 1.1737, cover loss of 1.0533, secret loss of 1.1965
# Training: Batch 93/1000. Loss of 1.2542, cover loss of 1.0363, secret loss of 0.7568
# Training: Batch 94/1000. Loss of 1.1500, cover loss of 0.9201, secret loss of 0.8387
# Training: Batch 95/1000. Loss of 1.2557, cover loss of 1.0403, secret loss of 1.2503
# Training: Batch 96/1000. Loss of 1.2189, cover loss of 1.0534, secret loss of 1.1404
# Training: Batch 97/1000. Loss of 1.0373, cover loss of 0.9342, secret loss of 0.9762
# Training: Batch 98/1000. Loss of 1.3075, cover loss of 1.1695, secret loss of 1.3287
# Training: Batch 99/1000. Loss of 1.0689, cover loss of 0.9170, secret loss of 1.1425
# Training: Batch 100/1000. Loss of 1.3312, cover loss of 1.2830, secret loss of 1.2397
# Training: Batch 101/1000. Loss of 1.2107, cover loss of 1.2987, secret loss of 1.0789
# Training: Batch 102/1000. Loss of 0.9742, cover loss of 0.9006, secret loss of 0.6627
# Training: Batch 103/1000. Loss of 1.3159, cover loss of 1.1060, secret loss of 0.9764
# Training: Batch 104/1000. Loss of 1.5051, cover loss of 1.6051, secret loss of 1.1185
# Training: Batch 105/1000. Loss of 1.3982, cover loss of 1.1374, secret loss of 1.5974
# Training: Batch 106/1000. Loss of 1.1167, cover loss of 1.0260, secret loss of 1.0342
# Training: Batch 107/1000. Loss of 1.1496, cover loss of 0.9528, secret loss of 0.9308
# Training: Batch 108/1000. Loss of 1.1150, cover loss of 0.9610, secret loss of 0.7864
# Training: Batch 109/1000. Loss of 1.2159, cover loss of 1.1466, secret loss of 0.8601
# Training: Batch 110/1000. Loss of 1.1297, cover loss of 1.0083, secret loss of 0.8736
# Training: Batch 111/1000. Loss of 1.2221, cover loss of 0.9079, secret loss of 0.8832
# Training: Batch 112/1000. Loss of 1.1921, cover loss of 0.8751, secret loss of 0.7482
# Training: Batch 113/1000. Loss of 1.1569, cover loss of 0.9307, secret loss of 0.8281
# Training: Batch 114/1000. Loss of 1.1777, cover loss of 0.9745, secret loss of 1.0953
# Training: Batch 115/1000. Loss of 1.2039, cover loss of 1.0182, secret loss of 1.2504
# Training: Batch 116/1000. Loss of 1.2514, cover loss of 1.0079, secret loss of 1.2947
# Training: Batch 117/1000. Loss of 1.4362, cover loss of 1.2322, secret loss of 1.4124
# Training: Batch 118/1000. Loss of 1.4280, cover loss of 1.3014, secret loss of 1.0669
# Training: Batch 119/1000. Loss of 1.1398, cover loss of 0.9506, secret loss of 1.1850
# Training: Batch 120/1000. Loss of 1.0666, cover loss of 0.8626, secret loss of 0.7981
# Training: Batch 121/1000. Loss of 1.3870, cover loss of 1.1926, secret loss of 1.3804
# Training: Batch 122/1000. Loss of 1.0859, cover loss of 0.9002, secret loss of 1.1427
# Training: Batch 123/1000. Loss of 1.1792, cover loss of 1.1937, secret loss of 0.9336
# Training: Batch 124/1000. Loss of 1.0526, cover loss of 0.9114, secret loss of 0.9229
# Training: Batch 125/1000. Loss of 1.1522, cover loss of 1.1594, secret loss of 0.8105
# Training: Batch 126/1000. Loss of 1.4781, cover loss of 1.3595, secret loss of 1.2416
# Training: Batch 127/1000. Loss of 1.3477, cover loss of 1.1257, secret loss of 1.4360
# Training: Batch 128/1000. Loss of 1.3773, cover loss of 1.3907, secret loss of 1.1938
# Training: Batch 129/1000. Loss of 1.1714, cover loss of 0.8898, secret loss of 0.8180
# Training: Batch 130/1000. Loss of 1.2455, cover loss of 1.2758, secret loss of 1.1512
# Training: Batch 131/1000. Loss of 1.2572, cover loss of 1.1031, secret loss of 1.1701
# Training: Batch 132/1000. Loss of 1.2174, cover loss of 1.2791, secret loss of 1.1022
# Training: Batch 133/1000. Loss of 1.4706, cover loss of 1.3814, secret loss of 1.3247
# Training: Batch 134/1000. Loss of 1.3099, cover loss of 1.2386, secret loss of 1.2874
# Training: Batch 135/1000. Loss of 1.2739, cover loss of 1.1503, secret loss of 1.2076
# Training: Batch 136/1000. Loss of 1.3102, cover loss of 1.3172, secret loss of 1.1142
# Training: Batch 137/1000. Loss of 1.0476, cover loss of 0.9153, secret loss of 0.7791
# Training: Batch 138/1000. Loss of 1.3046, cover loss of 1.1437, secret loss of 1.3402
# Training: Batch 139/1000. Loss of 1.4223, cover loss of 1.4023, secret loss of 1.2649
# Training: Batch 140/1000. Loss of 1.3728, cover loss of 1.2376, secret loss of 1.3116
# Training: Batch 141/1000. Loss of 1.1511, cover loss of 0.8735, secret loss of 0.9968
# Training: Batch 142/1000. Loss of 1.0843, cover loss of 0.9800, secret loss of 0.9597
# Training: Batch 143/1000. Loss of 1.1952, cover loss of 0.9853, secret loss of 1.0247
# Training: Batch 144/1000. Loss of 1.1719, cover loss of 1.0407, secret loss of 1.0043
# Training: Batch 145/1000. Loss of 1.2213, cover loss of 1.3284, secret loss of 1.0038
# Training: Batch 146/1000. Loss of 1.2573, cover loss of 1.1547, secret loss of 0.8938
# Training: Batch 147/1000. Loss of 1.1429, cover loss of 1.0814, secret loss of 0.6866
# Training: Batch 148/1000. Loss of 1.1504, cover loss of 1.0739, secret loss of 1.1049
# Training: Batch 149/1000. Loss of 1.2396, cover loss of 0.9589, secret loss of 1.0793
# Training: Batch 150/1000. Loss of 1.2282, cover loss of 1.0787, secret loss of 1.2056
# Training: Batch 151/1000. Loss of 1.2658, cover loss of 1.2337, secret loss of 1.0753
# Training: Batch 152/1000. Loss of 1.2083, cover loss of 1.3222, secret loss of 1.0063
# Training: Batch 153/1000. Loss of 1.0897, cover loss of 1.0456, secret loss of 0.7647
# Training: Batch 154/1000. Loss of 1.3025, cover loss of 1.3244, secret loss of 1.1100
# Training: Batch 155/1000. Loss of 1.3147, cover loss of 1.2724, secret loss of 1.0214
# Training: Batch 156/1000. Loss of 1.3453, cover loss of 1.3297, secret loss of 1.2568
# Training: Batch 157/1000. Loss of 1.2993, cover loss of 1.0055, secret loss of 0.9833
# Training: Batch 158/1000. Loss of 1.1799, cover loss of 0.9076, secret loss of 0.8912
# Training: Batch 159/1000. Loss of 1.3838, cover loss of 1.2035, secret loss of 1.4308
# Training: Batch 160/1000. Loss of 1.1647, cover loss of 1.0366, secret loss of 1.0970
# Training: Batch 161/1000. Loss of 1.1590, cover loss of 1.1832, secret loss of 0.9519
# Training: Batch 162/1000. Loss of 1.2920, cover loss of 1.1632, secret loss of 1.0865
# Training: Batch 163/1000. Loss of 1.1247, cover loss of 1.0316, secret loss of 1.0489
# Training: Batch 164/1000. Loss of 1.1156, cover loss of 1.0648, secret loss of 1.0046
# Training: Batch 165/1000. Loss of 1.3119, cover loss of 1.0628, secret loss of 1.2942
# Training: Batch 166/1000. Loss of 1.1190, cover loss of 1.0593, secret loss of 0.8358
# Training: Batch 167/1000. Loss of 1.2088, cover loss of 1.1617, secret loss of 1.1490
# Training: Batch 168/1000. Loss of 1.2150, cover loss of 1.1379, secret loss of 1.1568
# Training: Batch 169/1000. Loss of 1.2597, cover loss of 1.2067, secret loss of 1.1894
# Training: Batch 170/1000. Loss of 1.2756, cover loss of 1.1507, secret loss of 1.2619
# Training: Batch 171/1000. Loss of 1.4509, cover loss of 1.3122, secret loss of 1.4867
# Training: Batch 172/1000. Loss of 1.2598, cover loss of 1.2645, secret loss of 1.1351
# Training: Batch 173/1000. Loss of 1.2175, cover loss of 1.1731, secret loss of 1.1171
# Training: Batch 174/1000. Loss of 1.4730, cover loss of 1.4693, secret loss of 1.2908
# Training: Batch 175/1000. Loss of 1.1686, cover loss of 1.1113, secret loss of 1.1186
# Training: Batch 176/1000. Loss of 1.2009, cover loss of 1.1226, secret loss of 1.1790
# Training: Batch 177/1000. Loss of 1.3249, cover loss of 1.2144, secret loss of 1.3447
# Training: Batch 178/1000. Loss of 1.1933, cover loss of 1.2693, secret loss of 1.0207
# Training: Batch 179/1000. Loss of 1.2745, cover loss of 1.2802, secret loss of 1.1507
# Training: Batch 180/1000. Loss of 1.1349, cover loss of 0.8862, secret loss of 0.8624
# Training: Batch 181/1000. Loss of 1.1059, cover loss of 0.9344, secret loss of 1.1416
# Training: Batch 182/1000. Loss of 1.3520, cover loss of 1.3031, secret loss of 1.2005
# Training: Batch 183/1000. Loss of 1.1279, cover loss of 1.1017, secret loss of 1.0286
# Training: Batch 184/1000. Loss of 1.2342, cover loss of 1.2537, secret loss of 1.0954
# Training: Batch 185/1000. Loss of 1.2437, cover loss of 1.3486, secret loss of 0.9799
# Training: Batch 186/1000. Loss of 0.9532, cover loss of 0.9052, secret loss of 0.8233
# Training: Batch 187/1000. Loss of 1.2450, cover loss of 1.3004, secret loss of 0.9457
# Training: Batch 188/1000. Loss of 1.3287, cover loss of 1.1592, secret loss of 0.8302
# Training: Batch 189/1000. Loss of 1.1933, cover loss of 1.0713, secret loss of 1.1565
# Training: Batch 190/1000. Loss of 1.3316, cover loss of 1.1990, secret loss of 1.2618
# Training: Batch 191/1000. Loss of 1.2707, cover loss of 1.1268, secret loss of 1.0491
# Training: Batch 192/1000. Loss of 1.1789, cover loss of 1.0547, secret loss of 0.8460
# Training: Batch 193/1000. Loss of 1.2643, cover loss of 1.3827, secret loss of 0.9970
# Training: Batch 194/1000. Loss of 1.3131, cover loss of 1.4207, secret loss of 0.7590
# Training: Batch 195/1000. Loss of 1.2881, cover loss of 1.1744, secret loss of 1.2389
# Training: Batch 196/1000. Loss of 1.4128, cover loss of 1.3183, secret loss of 1.2817
# Training: Batch 197/1000. Loss of 1.3685, cover loss of 1.1380, secret loss of 1.3991
# Training: Batch 198/1000. Loss of 1.3429, cover loss of 1.2615, secret loss of 1.2651
# Training: Batch 199/1000. Loss of 1.1924, cover loss of 0.9849, secret loss of 1.1467
# Training: Batch 200/1000. Loss of 1.3990, cover loss of 1.2111, secret loss of 1.1646
# Training: Batch 201/1000. Loss of 1.2295, cover loss of 0.9224, secret loss of 0.8689
# Training: Batch 202/1000. Loss of 1.2327, cover loss of 1.4676, secret loss of 0.9224
# Training: Batch 203/1000. Loss of 1.3041, cover loss of 0.9859, secret loss of 0.9581
# Training: Batch 204/1000. Loss of 1.1250, cover loss of 1.0253, secret loss of 0.7463
# Training: Batch 205/1000. Loss of 1.3969, cover loss of 1.2985, secret loss of 1.2292
# Training: Batch 206/1000. Loss of 1.2511, cover loss of 1.0260, secret loss of 0.7134
# Training: Batch 207/1000. Loss of 1.0994, cover loss of 0.9024, secret loss of 1.1856
# Training: Batch 208/1000. Loss of 1.1669, cover loss of 1.1839, secret loss of 1.0787
# Training: Batch 209/1000. Loss of 1.2511, cover loss of 1.1263, secret loss of 1.1500
# Training: Batch 210/1000. Loss of 1.1744, cover loss of 1.2690, secret loss of 0.8734
# Training: Batch 211/1000. Loss of 1.3081, cover loss of 1.1891, secret loss of 1.1743
# Training: Batch 212/1000. Loss of 1.3811, cover loss of 1.2255, secret loss of 1.1583
# Training: Batch 213/1000. Loss of 1.3248, cover loss of 1.1661, secret loss of 1.2940
# Training: Batch 214/1000. Loss of 1.1579, cover loss of 1.0096, secret loss of 0.8262
# Training: Batch 215/1000. Loss of 1.1370, cover loss of 1.0773, secret loss of 1.0745
# Training: Batch 216/1000. Loss of 1.1138, cover loss of 1.1282, secret loss of 1.0019
# Training: Batch 217/1000. Loss of 1.2476, cover loss of 0.9737, secret loss of 0.9572
# Training: Batch 218/1000. Loss of 1.5803, cover loss of 1.3428, secret loss of 1.4823
# Training: Batch 219/1000. Loss of 0.9885, cover loss of 0.8382, secret loss of 0.6925
# Training: Batch 220/1000. Loss of 1.3594, cover loss of 1.1711, secret loss of 1.2106
# Training: Batch 221/1000. Loss of 1.3416, cover loss of 1.2221, secret loss of 1.1091
# Training: Batch 222/1000. Loss of 1.2117, cover loss of 1.0193, secret loss of 1.2500
# Training: Batch 223/1000. Loss of 1.3314, cover loss of 1.0726, secret loss of 1.1826
# Training: Batch 224/1000. Loss of 1.3446, cover loss of 1.3343, secret loss of 1.1022
# Training: Batch 225/1000. Loss of 1.2926, cover loss of 1.1561, secret loss of 1.1581
# Training: Batch 226/1000. Loss of 1.3278, cover loss of 1.1416, secret loss of 1.3715
# Training: Batch 227/1000. Loss of 1.1472, cover loss of 0.8597, secret loss of 0.9287
# Training: Batch 228/1000. Loss of 1.4920, cover loss of 1.3777, secret loss of 1.3846
# Training: Batch 229/1000. Loss of 1.0911, cover loss of 1.1264, secret loss of 0.8932
# Training: Batch 230/1000. Loss of 1.3199, cover loss of 1.3137, secret loss of 1.1747
# Training: Batch 231/1000. Loss of 1.3308, cover loss of 1.3946, secret loss of 1.1267
# Training: Batch 232/1000. Loss of 1.1880, cover loss of 0.8939, secret loss of 1.2936
# Training: Batch 233/1000. Loss of 1.0425, cover loss of 0.9992, secret loss of 0.6192
# Training: Batch 234/1000. Loss of 1.2624, cover loss of 1.0732, secret loss of 1.1431
# Training: Batch 235/1000. Loss of 1.1623, cover loss of 1.1103, secret loss of 1.1611
# Training: Batch 236/1000. Loss of 1.2987, cover loss of 1.0383, secret loss of 1.2873
# Training: Batch 237/1000. Loss of 1.3808, cover loss of 1.2116, secret loss of 1.0490
# Training: Batch 238/1000. Loss of 1.3968, cover loss of 1.3149, secret loss of 1.2946
# Training: Batch 239/1000. Loss of 0.9951, cover loss of 0.9240, secret loss of 0.9591
# Training: Batch 240/1000. Loss of 1.3039, cover loss of 1.2114, secret loss of 1.1247
# Training: Batch 241/1000. Loss of 1.1920, cover loss of 1.2390, secret loss of 1.0797
# Training: Batch 242/1000. Loss of 1.1912, cover loss of 1.2156, secret loss of 0.9795
# Training: Batch 243/1000. Loss of 1.4774, cover loss of 1.3783, secret loss of 1.3786
# Training: Batch 244/1000. Loss of 1.3306, cover loss of 1.3881, secret loss of 1.0459
# Training: Batch 245/1000. Loss of 1.2262, cover loss of 1.1541, secret loss of 1.1818
# Training: Batch 246/1000. Loss of 1.2517, cover loss of 1.2901, secret loss of 0.9555
# Training: Batch 247/1000. Loss of 1.3445, cover loss of 1.1951, secret loss of 1.4229
# Training: Batch 248/1000. Loss of 1.2870, cover loss of 1.1723, secret loss of 1.0164
# Training: Batch 249/1000. Loss of 1.1416, cover loss of 1.0362, secret loss of 0.7937
# Training: Batch 250/1000. Loss of 1.2651, cover loss of 1.1942, secret loss of 1.2579
# Training: Batch 251/1000. Loss of 1.2984, cover loss of 1.3265, secret loss of 1.1106
# Training: Batch 252/1000. Loss of 1.3125, cover loss of 1.2200, secret loss of 1.2355
# Training: Batch 253/1000. Loss of 1.3752, cover loss of 1.3558, secret loss of 1.1338
# Training: Batch 254/1000. Loss of 1.3537, cover loss of 1.3955, secret loss of 1.0813
# Training: Batch 255/1000. Loss of 1.3559, cover loss of 1.3051, secret loss of 1.1895
# Training: Batch 256/1000. Loss of 1.3145, cover loss of 1.0530, secret loss of 1.2677
# Training: Batch 257/1000. Loss of 1.2250, cover loss of 1.0983, secret loss of 1.2857
# Training: Batch 258/1000. Loss of 1.2608, cover loss of 1.0854, secret loss of 1.1534
# Training: Batch 259/1000. Loss of 1.4598, cover loss of 1.1450, secret loss of 1.5049
# Training: Batch 260/1000. Loss of 1.2433, cover loss of 1.0689, secret loss of 1.1184
# Training: Batch 261/1000. Loss of 1.2560, cover loss of 1.1220, secret loss of 1.3120
# Training: Batch 262/1000. Loss of 1.2317, cover loss of 1.3492, secret loss of 0.9096
# Training: Batch 263/1000. Loss of 1.1722, cover loss of 1.0342, secret loss of 0.9835
# Training: Batch 264/1000. Loss of 1.0992, cover loss of 1.2068, secret loss of 0.9049
# Training: Batch 265/1000. Loss of 1.1444, cover loss of 1.0081, secret loss of 1.1994
# Training: Batch 266/1000. Loss of 1.1016, cover loss of 0.9718, secret loss of 0.9168
# Training: Batch 267/1000. Loss of 1.3135, cover loss of 1.3117, secret loss of 1.1571
# Training: Batch 268/1000. Loss of 1.1456, cover loss of 1.0575, secret loss of 0.7870
# Training: Batch 269/1000. Loss of 1.4131, cover loss of 1.2784, secret loss of 1.3163
# Training: Batch 270/1000. Loss of 1.0559, cover loss of 0.9447, secret loss of 0.7068
# Training: Batch 271/1000. Loss of 1.4999, cover loss of 1.5515, secret loss of 1.2900
# Training: Batch 272/1000. Loss of 1.3522, cover loss of 1.2017, secret loss of 1.1985
# Training: Batch 273/1000. Loss of 1.0822, cover loss of 1.0910, secret loss of 0.8189
# Training: Batch 274/1000. Loss of 1.4137, cover loss of 1.2310, secret loss of 1.3325
# Training: Batch 275/1000. Loss of 1.2647, cover loss of 1.1424, secret loss of 0.7840
# Training: Batch 276/1000. Loss of 1.2043, cover loss of 1.0564, secret loss of 0.9843
# Training: Batch 277/1000. Loss of 1.2356, cover loss of 1.1117, secret loss of 1.1382
# Training: Batch 278/1000. Loss of 1.0821, cover loss of 1.1276, secret loss of 0.9605
# Training: Batch 279/1000. Loss of 1.3083, cover loss of 1.3705, secret loss of 1.0539
# Training: Batch 280/1000. Loss of 1.1369, cover loss of 1.0904, secret loss of 0.9775
# Training: Batch 281/1000. Loss of 1.2304, cover loss of 0.9835, secret loss of 0.9588
# Training: Batch 282/1000. Loss of 1.1610, cover loss of 0.9230, secret loss of 0.8396
# Training: Batch 283/1000. Loss of 1.2533, cover loss of 1.2201, secret loss of 1.0154
# Training: Batch 284/1000. Loss of 1.2644, cover loss of 1.1276, secret loss of 1.3001
# Training: Batch 285/1000. Loss of 1.2865, cover loss of 1.1808, secret loss of 1.2435
# Training: Batch 286/1000. Loss of 1.1598, cover loss of 0.9173, secret loss of 1.2246
# Training: Batch 287/1000. Loss of 1.0996, cover loss of 0.9404, secret loss of 1.1209
# Training: Batch 288/1000. Loss of 1.2275, cover loss of 1.3113, secret loss of 1.0408
# Training: Batch 289/1000. Loss of 1.0876, cover loss of 0.9646, secret loss of 0.6206
# Training: Batch 290/1000. Loss of 1.2876, cover loss of 1.1910, secret loss of 1.2623
# Training: Batch 291/1000. Loss of 1.2566, cover loss of 1.2676, secret loss of 1.0572
# Training: Batch 292/1000. Loss of 1.0725, cover loss of 0.9264, secret loss of 0.8054
# Training: Batch 293/1000. Loss of 1.2729, cover loss of 1.2449, secret loss of 1.2344
# Training: Batch 294/1000. Loss of 1.0495, cover loss of 0.9165, secret loss of 0.7503
# Training: Batch 295/1000. Loss of 1.2355, cover loss of 1.2035, secret loss of 0.9677
# Training: Batch 296/1000. Loss of 1.2406, cover loss of 1.2508, secret loss of 1.1803
# Training: Batch 297/1000. Loss of 1.0358, cover loss of 0.9936, secret loss of 0.7775
# Training: Batch 298/1000. Loss of 1.2334, cover loss of 1.1728, secret loss of 1.0877
# Training: Batch 299/1000. Loss of 1.2738, cover loss of 1.2311, secret loss of 1.1240
# Training: Batch 300/1000. Loss of 1.3291, cover loss of 1.2347, secret loss of 1.1860
# Training: Batch 301/1000. Loss of 1.0995, cover loss of 1.1244, secret loss of 0.8582
# Training: Batch 302/1000. Loss of 1.1848, cover loss of 1.1721, secret loss of 1.0368
# Training: Batch 303/1000. Loss of 1.2828, cover loss of 1.1486, secret loss of 1.2393
# Training: Batch 304/1000. Loss of 1.2090, cover loss of 1.1504, secret loss of 0.7339
# Training: Batch 305/1000. Loss of 1.1837, cover loss of 1.0372, secret loss of 1.1972
# Training: Batch 306/1000. Loss of 1.2879, cover loss of 1.1677, secret loss of 0.7660
# Training: Batch 307/1000. Loss of 1.1827, cover loss of 1.2167, secret loss of 1.0121
# Training: Batch 308/1000. Loss of 1.1476, cover loss of 1.1496, secret loss of 1.0392
# Training: Batch 309/1000. Loss of 1.0717, cover loss of 1.0192, secret loss of 0.8945
# Training: Batch 310/1000. Loss of 1.2350, cover loss of 1.2968, secret loss of 1.1013
# Training: Batch 311/1000. Loss of 1.0459, cover loss of 0.8689, secret loss of 0.6224
# Training: Batch 312/1000. Loss of 1.2663, cover loss of 1.2177, secret loss of 1.2928
# Training: Batch 313/1000. Loss of 1.3870, cover loss of 1.2781, secret loss of 1.3522
# Training: Batch 314/1000. Loss of 1.1334, cover loss of 0.9370, secret loss of 0.8404
# Training: Batch 315/1000. Loss of 1.3115, cover loss of 1.0072, secret loss of 0.9222
# Training: Batch 316/1000. Loss of 1.3988, cover loss of 1.3567, secret loss of 1.2435
# Training: Batch 317/1000. Loss of 1.2596, cover loss of 1.0784, secret loss of 0.8691
# Training: Batch 318/1000. Loss of 1.3638, cover loss of 1.1124, secret loss of 1.4312
# Training: Batch 319/1000. Loss of 1.2074, cover loss of 1.1093, secret loss of 1.1643
# Training: Batch 320/1000. Loss of 1.1326, cover loss of 0.9256, secret loss of 0.7804
# Training: Batch 321/1000. Loss of 1.1731, cover loss of 1.1740, secret loss of 1.0181
# Training: Batch 322/1000. Loss of 1.1931, cover loss of 0.9003, secret loss of 1.0650
# Training: Batch 323/1000. Loss of 0.9878, cover loss of 0.8391, secret loss of 0.6838
# Training: Batch 324/1000. Loss of 1.3007, cover loss of 1.0356, secret loss of 1.3138
# Training: Batch 325/1000. Loss of 1.1109, cover loss of 1.0601, secret loss of 0.6898
# Training: Batch 326/1000. Loss of 1.1762, cover loss of 1.0988, secret loss of 1.0325
# Training: Batch 327/1000. Loss of 1.3000, cover loss of 1.3823, secret loss of 1.0500
# Training: Batch 328/1000. Loss of 1.0711, cover loss of 0.8891, secret loss of 0.7541
# Training: Batch 329/1000. Loss of 1.1053, cover loss of 0.9440, secret loss of 1.0936
# Training: Batch 330/1000. Loss of 1.0880, cover loss of 0.8434, secret loss of 0.7394
# Training: Batch 331/1000. Loss of 1.2802, cover loss of 1.3078, secret loss of 1.0642
# Training: Batch 332/1000. Loss of 1.2525, cover loss of 1.1591, secret loss of 1.2320
# Training: Batch 333/1000. Loss of 1.2888, cover loss of 1.1114, secret loss of 0.8907
# Training: Batch 334/1000. Loss of 1.3258, cover loss of 1.2101, secret loss of 0.9599
# Training: Batch 335/1000. Loss of 1.2343, cover loss of 1.2267, secret loss of 1.0177
# Training: Batch 336/1000. Loss of 1.3096, cover loss of 1.2724, secret loss of 1.1550
# Training: Batch 337/1000. Loss of 1.3187, cover loss of 1.2002, secret loss of 1.2375
# Training: Batch 338/1000. Loss of 1.3497, cover loss of 1.5106, secret loss of 1.0911
# Training: Batch 339/1000. Loss of 1.3628, cover loss of 1.3089, secret loss of 1.2061
# Training: Batch 340/1000. Loss of 1.2993, cover loss of 1.1441, secret loss of 0.8204
# Training: Batch 341/1000. Loss of 1.4692, cover loss of 1.4742, secret loss of 1.2563
# Training: Batch 342/1000. Loss of 1.1579, cover loss of 0.9421, secret loss of 0.8903
# Training: Batch 343/1000. Loss of 1.2186, cover loss of 1.1067, secret loss of 1.2226
# Training: Batch 344/1000. Loss of 1.2215, cover loss of 1.1465, secret loss of 0.8167
# Training: Batch 345/1000. Loss of 1.2251, cover loss of 0.9891, secret loss of 1.3614
# Training: Batch 346/1000. Loss of 1.3368, cover loss of 1.2962, secret loss of 0.7077
# Training: Batch 347/1000. Loss of 1.1458, cover loss of 1.1586, secret loss of 1.0555
# Training: Batch 348/1000. Loss of 1.4031, cover loss of 1.3330, secret loss of 0.7158
# Training: Batch 349/1000. Loss of 1.2030, cover loss of 1.1146, secret loss of 0.6310
# Training: Batch 350/1000. Loss of 1.3697, cover loss of 1.1437, secret loss of 1.2592
# Training: Batch 351/1000. Loss of 1.0898, cover loss of 0.8992, secret loss of 0.7455
# Training: Batch 352/1000. Loss of 1.3854, cover loss of 1.3685, secret loss of 1.1735
# Training: Batch 353/1000. Loss of 1.1718, cover loss of 1.1086, secret loss of 1.0413
# Training: Batch 354/1000. Loss of 1.4597, cover loss of 1.2345, secret loss of 1.3272
# Training: Batch 355/1000. Loss of 1.1459, cover loss of 1.0219, secret loss of 0.8529
# Training: Batch 356/1000. Loss of 1.2125, cover loss of 1.0857, secret loss of 1.1186
# Training: Batch 357/1000. Loss of 1.0363, cover loss of 0.8054, secret loss of 0.7410
# Training: Batch 358/1000. Loss of 1.2446, cover loss of 1.1938, secret loss of 1.0479
# Training: Batch 359/1000. Loss of 1.2385, cover loss of 0.9546, secret loss of 1.2828
# Training: Batch 360/1000. Loss of 1.3529, cover loss of 1.1984, secret loss of 1.1431
# Training: Batch 361/1000. Loss of 1.0195, cover loss of 0.9378, secret loss of 0.6843
# Training: Batch 362/1000. Loss of 1.4195, cover loss of 1.2623, secret loss of 1.3409
# Training: Batch 363/1000. Loss of 1.0787, cover loss of 0.8500, secret loss of 0.6445
# Training: Batch 364/1000. Loss of 1.4110, cover loss of 1.4393, secret loss of 1.1940
# Training: Batch 365/1000. Loss of 1.3988, cover loss of 1.0588, secret loss of 1.4765
# Training: Batch 366/1000. Loss of 1.3586, cover loss of 1.2078, secret loss of 0.9878
# Training: Batch 367/1000. Loss of 1.1038, cover loss of 1.0324, secret loss of 1.1205
# Training: Batch 368/1000. Loss of 1.3483, cover loss of 1.1777, secret loss of 1.2381
# Training: Batch 369/1000. Loss of 1.1052, cover loss of 0.7861, secret loss of 0.8245
# Training: Batch 370/1000. Loss of 1.2573, cover loss of 1.0639, secret loss of 1.2155
# Training: Batch 371/1000. Loss of 1.3978, cover loss of 1.3402, secret loss of 1.3904
# Training: Batch 372/1000. Loss of 1.1918, cover loss of 1.0716, secret loss of 1.1904
# Training: Batch 373/1000. Loss of 1.1463, cover loss of 0.9746, secret loss of 0.8941
# Training: Batch 374/1000. Loss of 1.4313, cover loss of 1.2123, secret loss of 1.4468
# Training: Batch 375/1000. Loss of 1.3954, cover loss of 1.3957, secret loss of 1.2116
# Training: Batch 376/1000. Loss of 1.0836, cover loss of 0.9663, secret loss of 1.0458
# Training: Batch 377/1000. Loss of 1.3573, cover loss of 1.1398, secret loss of 1.2678
# Training: Batch 378/1000. Loss of 1.2973, cover loss of 1.1602, secret loss of 1.3304
# Training: Batch 379/1000. Loss of 1.1929, cover loss of 0.9619, secret loss of 1.2844
# Training: Batch 380/1000. Loss of 1.3310, cover loss of 1.2183, secret loss of 1.2079
# Training: Batch 381/1000. Loss of 1.2020, cover loss of 0.9486, secret loss of 0.9424
# Training: Batch 382/1000. Loss of 1.1766, cover loss of 1.0769, secret loss of 0.8280
# Training: Batch 383/1000. Loss of 1.0977, cover loss of 0.9586, secret loss of 1.0203
# Training: Batch 384/1000. Loss of 1.1890, cover loss of 1.1225, secret loss of 1.0585
# Training: Batch 385/1000. Loss of 1.3218, cover loss of 1.0287, secret loss of 0.9790
# Training: Batch 386/1000. Loss of 1.3676, cover loss of 1.1147, secret loss of 1.4397
# Training: Batch 387/1000. Loss of 1.0868, cover loss of 0.9546, secret loss of 0.6600
# Training: Batch 388/1000. Loss of 1.2515, cover loss of 1.0348, secret loss of 1.3575
# Training: Batch 389/1000. Loss of 1.1852, cover loss of 1.1165, secret loss of 1.0058
# Training: Batch 390/1000. Loss of 1.0835, cover loss of 0.8937, secret loss of 1.0964
# Training: Batch 391/1000. Loss of 1.1520, cover loss of 1.0939, secret loss of 0.9725
# Training: Batch 392/1000. Loss of 1.1301, cover loss of 1.0046, secret loss of 1.0369
# Training: Batch 393/1000. Loss of 1.1841, cover loss of 1.0960, secret loss of 1.1453
# Training: Batch 394/1000. Loss of 1.3009, cover loss of 1.2603, secret loss of 1.1759
# Training: Batch 395/1000. Loss of 1.2996, cover loss of 0.9865, secret loss of 1.0386
# Training: Batch 396/1000. Loss of 1.1850, cover loss of 1.2852, secret loss of 0.9896
# Training: Batch 397/1000. Loss of 1.4285, cover loss of 1.3999, secret loss of 1.2729
# Training: Batch 398/1000. Loss of 1.1772, cover loss of 0.8521, secret loss of 1.3912
# Training: Batch 399/1000. Loss of 1.2011, cover loss of 0.9019, secret loss of 1.3960
# Training: Batch 400/1000. Loss of 1.3454, cover loss of 1.1835, secret loss of 0.9931
# Training: Batch 401/1000. Loss of 1.2187, cover loss of 1.2521, secret loss of 1.0808
# Training: Batch 402/1000. Loss of 1.3828, cover loss of 1.3710, secret loss of 1.1890
# Training: Batch 403/1000. Loss of 1.2013, cover loss of 0.8663, secret loss of 1.3744
# Training: Batch 404/1000. Loss of 1.1330, cover loss of 1.1364, secret loss of 0.7079
# Training: Batch 405/1000. Loss of 1.3259, cover loss of 1.2176, secret loss of 1.2717
# Training: Batch 406/1000. Loss of 1.3551, cover loss of 1.2295, secret loss of 1.3352
# Training: Batch 407/1000. Loss of 1.2883, cover loss of 1.2100, secret loss of 0.8674
# Training: Batch 408/1000. Loss of 1.3975, cover loss of 1.0916, secret loss of 1.5654
# Training: Batch 409/1000. Loss of 1.4147, cover loss of 1.0822, secret loss of 1.6097
# Training: Batch 410/1000. Loss of 1.1929, cover loss of 1.1696, secret loss of 0.8729
# Training: Batch 411/1000. Loss of 1.2356, cover loss of 1.1299, secret loss of 1.0183
# Training: Batch 412/1000. Loss of 1.5132, cover loss of 1.6087, secret loss of 1.3429
# Training: Batch 413/1000. Loss of 0.9643, cover loss of 0.9287, secret loss of 0.5873
# Training: Batch 414/1000. Loss of 1.1141, cover loss of 0.9953, secret loss of 0.7722
# Training: Batch 415/1000. Loss of 1.3145, cover loss of 1.1589, secret loss of 1.2646
# Training: Batch 416/1000. Loss of 1.2517, cover loss of 1.1422, secret loss of 1.0381
# Training: Batch 417/1000. Loss of 1.1551, cover loss of 1.0987, secret loss of 0.9498
# Training: Batch 418/1000. Loss of 1.3240, cover loss of 1.1851, secret loss of 1.2438
# Training: Batch 419/1000. Loss of 1.2334, cover loss of 1.2138, secret loss of 0.9706
# Training: Batch 420/1000. Loss of 1.2192, cover loss of 1.2833, secret loss of 0.9647
# Training: Batch 421/1000. Loss of 1.3585, cover loss of 1.4329, secret loss of 1.1419
# Training: Batch 422/1000. Loss of 1.1066, cover loss of 0.9964, secret loss of 0.7920
# Training: Batch 423/1000. Loss of 1.2169, cover loss of 1.0643, secret loss of 1.2166
# Training: Batch 424/1000. Loss of 1.0061, cover loss of 0.8599, secret loss of 0.9497
# Training: Batch 425/1000. Loss of 1.3708, cover loss of 1.2806, secret loss of 1.3071
# Training: Batch 426/1000. Loss of 1.2050, cover loss of 1.1729, secret loss of 1.0572
# Training: Batch 427/1000. Loss of 1.2866, cover loss of 1.1970, secret loss of 1.0659
# Training: Batch 428/1000. Loss of 1.1143, cover loss of 1.0673, secret loss of 1.0372
# Training: Batch 429/1000. Loss of 1.0916, cover loss of 0.9774, secret loss of 0.8903
# Training: Batch 430/1000. Loss of 1.2198, cover loss of 1.1870, secret loss of 1.1704
# Training: Batch 431/1000. Loss of 1.1974, cover loss of 0.9995, secret loss of 0.8346
# Training: Batch 432/1000. Loss of 1.3498, cover loss of 1.2968, secret loss of 1.0175
# Training: Batch 433/1000. Loss of 1.2599, cover loss of 1.3022, secret loss of 1.0190
# Training: Batch 434/1000. Loss of 1.2005, cover loss of 1.1131, secret loss of 1.0595
# Training: Batch 435/1000. Loss of 1.3410, cover loss of 1.3822, secret loss of 1.0474
# Training: Batch 436/1000. Loss of 1.3366, cover loss of 1.3850, secret loss of 1.0951
# Training: Batch 437/1000. Loss of 1.1893, cover loss of 1.1762, secret loss of 0.9593
# Training: Batch 438/1000. Loss of 1.2423, cover loss of 1.2585, secret loss of 1.1373
# Training: Batch 439/1000. Loss of 1.3091, cover loss of 1.2632, secret loss of 1.1070
# Training: Batch 440/1000. Loss of 1.2055, cover loss of 1.2823, secret loss of 1.0986
# Training: Batch 441/1000. Loss of 1.3191, cover loss of 1.2595, secret loss of 1.2775
# Training: Batch 442/1000. Loss of 1.1331, cover loss of 0.9666, secret loss of 0.7912
# Training: Batch 443/1000. Loss of 1.2637, cover loss of 1.0432, secret loss of 1.3432
# Training: Batch 444/1000. Loss of 1.4242, cover loss of 1.5323, secret loss of 1.2391
# Training: Batch 445/1000. Loss of 1.2930, cover loss of 1.2579, secret loss of 1.1400
# Training: Batch 446/1000. Loss of 1.0463, cover loss of 0.9633, secret loss of 0.6793
# Training: Batch 447/1000. Loss of 1.2655, cover loss of 1.1978, secret loss of 1.0355
# Training: Batch 448/1000. Loss of 1.2568, cover loss of 1.0922, secret loss of 1.2466
# Training: Batch 449/1000. Loss of 1.2716, cover loss of 1.0608, secret loss of 1.0213
# Training: Batch 450/1000. Loss of 1.1578, cover loss of 1.0255, secret loss of 0.8044
# Training: Batch 451/1000. Loss of 1.4966, cover loss of 1.5076, secret loss of 1.4088
# Training: Batch 452/1000. Loss of 1.1703, cover loss of 0.9916, secret loss of 1.2393
# Training: Batch 453/1000. Loss of 1.4240, cover loss of 1.3464, secret loss of 1.4756
# Training: Batch 454/1000. Loss of 1.2662, cover loss of 1.1875, secret loss of 1.1467
# Training: Batch 455/1000. Loss of 1.3251, cover loss of 1.3043, secret loss of 1.1906
# Training: Batch 456/1000. Loss of 1.2188, cover loss of 1.2401, secret loss of 1.1132
# Training: Batch 457/1000. Loss of 1.2664, cover loss of 1.0071, secret loss of 0.9767
# Training: Batch 458/1000. Loss of 1.2376, cover loss of 1.1513, secret loss of 1.1989
# Training: Batch 459/1000. Loss of 1.1845, cover loss of 1.0905, secret loss of 1.1497
# Training: Batch 460/1000. Loss of 1.1299, cover loss of 1.2344, secret loss of 0.8952
# Training: Batch 461/1000. Loss of 1.4115, cover loss of 1.3569, secret loss of 1.1993
# Training: Batch 462/1000. Loss of 1.2401, cover loss of 1.2226, secret loss of 1.1316
# Training: Batch 463/1000. Loss of 1.2863, cover loss of 1.2409, secret loss of 0.8555
# Training: Batch 464/1000. Loss of 1.1036, cover loss of 0.9541, secret loss of 0.9258
# Training: Batch 465/1000. Loss of 1.1230, cover loss of 1.0893, secret loss of 1.0487
# Training: Batch 466/1000. Loss of 1.1784, cover loss of 1.1719, secret loss of 0.9492
# Training: Batch 467/1000. Loss of 1.3731, cover loss of 1.0773, secret loss of 1.5172
# Training: Batch 468/1000. Loss of 1.2861, cover loss of 1.3329, secret loss of 1.1330
# Training: Batch 469/1000. Loss of 1.2828, cover loss of 1.3754, secret loss of 1.0890
# Training: Batch 470/1000. Loss of 1.4657, cover loss of 1.2746, secret loss of 1.4893
# Training: Batch 471/1000. Loss of 1.1014, cover loss of 1.1622, secret loss of 0.9653
# Training: Batch 472/1000. Loss of 1.3227, cover loss of 1.3951, secret loss of 1.1170
# Training: Batch 473/1000. Loss of 1.1912, cover loss of 1.1241, secret loss of 0.8314
# Training: Batch 474/1000. Loss of 1.3650, cover loss of 1.1478, secret loss of 1.3719
# Training: Batch 475/1000. Loss of 1.2827, cover loss of 1.2132, secret loss of 1.0645
# Training: Batch 476/1000. Loss of 1.3351, cover loss of 1.3004, secret loss of 1.2019
# Training: Batch 477/1000. Loss of 1.2621, cover loss of 0.9974, secret loss of 1.0106
# Training: Batch 478/1000. Loss of 1.1323, cover loss of 1.0611, secret loss of 1.1168
# Training: Batch 479/1000. Loss of 1.6322, cover loss of 1.5664, secret loss of 1.5379
# Training: Batch 480/1000. Loss of 1.3236, cover loss of 1.1764, secret loss of 1.2654
# Training: Batch 481/1000. Loss of 1.2184, cover loss of 0.9082, secret loss of 1.2609
# Training: Batch 482/1000. Loss of 1.2315, cover loss of 1.1261, secret loss of 0.8137
# Training: Batch 483/1000. Loss of 1.2172, cover loss of 0.9932, secret loss of 1.3171
# Training: Batch 484/1000. Loss of 1.0549, cover loss of 1.0719, secret loss of 0.8576
# Training: Batch 485/1000. Loss of 1.0878, cover loss of 0.9698, secret loss of 0.7099
# Training: Batch 486/1000. Loss of 1.1317, cover loss of 0.9765, secret loss of 0.8387
# Training: Batch 487/1000. Loss of 1.1778, cover loss of 1.1457, secret loss of 0.8881
# Training: Batch 488/1000. Loss of 1.2926, cover loss of 1.2510, secret loss of 1.1969
# Training: Batch 489/1000. Loss of 1.1030, cover loss of 0.9824, secret loss of 0.8903
# Training: Batch 490/1000. Loss of 1.1785, cover loss of 0.9565, secret loss of 1.0851
# Training: Batch 491/1000. Loss of 1.1686, cover loss of 1.1229, secret loss of 1.0861
# Training: Batch 492/1000. Loss of 1.2314, cover loss of 1.0828, secret loss of 1.1136
# Training: Batch 493/1000. Loss of 1.2543, cover loss of 1.1004, secret loss of 0.7882
# Training: Batch 494/1000. Loss of 1.4124, cover loss of 1.2511, secret loss of 1.1806
# Training: Batch 495/1000. Loss of 1.2323, cover loss of 1.2111, secret loss of 1.1205
# Training: Batch 496/1000. Loss of 1.2922, cover loss of 0.9863, secret loss of 0.9927
# Training: Batch 497/1000. Loss of 1.1694, cover loss of 1.2438, secret loss of 0.8548
# Training: Batch 498/1000. Loss of 1.2833, cover loss of 1.2513, secret loss of 1.1387
# Training: Batch 499/1000. Loss of 1.2722, cover loss of 1.0664, secret loss of 1.3042
# Training: Batch 500/1000. Loss of 1.1282, cover loss of 1.0816, secret loss of 1.0453
# Training: Batch 501/1000. Loss of 1.3076, cover loss of 0.9475, secret loss of 1.1444
# Training: Batch 502/1000. Loss of 1.1105, cover loss of 1.0306, secret loss of 1.0989
# Training: Batch 503/1000. Loss of 1.3250, cover loss of 1.2841, secret loss of 1.2410
# Training: Batch 504/1000. Loss of 1.1057, cover loss of 0.9621, secret loss of 0.8053
# Training: Batch 505/1000. Loss of 1.3132, cover loss of 1.3193, secret loss of 1.2264
# Training: Batch 506/1000. Loss of 1.4376, cover loss of 1.2565, secret loss of 1.4267
# Training: Batch 507/1000. Loss of 1.0853, cover loss of 1.0033, secret loss of 1.0340
# Training: Batch 508/1000. Loss of 1.4716, cover loss of 1.2379, secret loss of 1.5826
# Training: Batch 509/1000. Loss of 1.0177, cover loss of 0.8844, secret loss of 0.8255
# Training: Batch 510/1000. Loss of 1.3351, cover loss of 1.2663, secret loss of 1.1706
# Training: Batch 511/1000. Loss of 1.2879, cover loss of 1.2421, secret loss of 1.0348
# Training: Batch 512/1000. Loss of 1.0917, cover loss of 1.0909, secret loss of 0.9780
# Training: Batch 513/1000. Loss of 1.2828, cover loss of 1.0987, secret loss of 0.9496
# Training: Batch 514/1000. Loss of 1.2487, cover loss of 1.2964, secret loss of 0.9889
# Training: Batch 515/1000. Loss of 1.0919, cover loss of 0.9448, secret loss of 0.8682
# Training: Batch 516/1000. Loss of 1.0818, cover loss of 1.0836, secret loss of 0.9721
# Training: Batch 517/1000. Loss of 1.1645, cover loss of 1.1460, secret loss of 0.9874
# Training: Batch 518/1000. Loss of 1.2086, cover loss of 1.0334, secret loss of 1.1011
# Training: Batch 519/1000. Loss of 1.1280, cover loss of 1.0762, secret loss of 1.0389
# Training: Batch 520/1000. Loss of 1.2086, cover loss of 1.1605, secret loss of 1.1270
# Training: Batch 521/1000. Loss of 1.1507, cover loss of 1.1661, secret loss of 0.9879
# Training: Batch 522/1000. Loss of 1.3709, cover loss of 1.1495, secret loss of 0.9860
# Training: Batch 523/1000. Loss of 1.2503, cover loss of 1.1079, secret loss of 1.0554
# Training: Batch 524/1000. Loss of 1.3398, cover loss of 1.0322, secret loss of 1.0276
# Training: Batch 525/1000. Loss of 1.0290, cover loss of 0.9794, secret loss of 0.8801
# Training: Batch 526/1000. Loss of 1.3712, cover loss of 1.2084, secret loss of 0.9506
# Training: Batch 527/1000. Loss of 1.1357, cover loss of 0.9128, secret loss of 0.8010
# Training: Batch 528/1000. Loss of 1.2563, cover loss of 1.0905, secret loss of 1.2550
# Training: Batch 529/1000. Loss of 1.4505, cover loss of 1.1914, secret loss of 1.4779
# Training: Batch 530/1000. Loss of 1.1299, cover loss of 0.8001, secret loss of 0.7817
# Training: Batch 531/1000. Loss of 0.9894, cover loss of 0.8577, secret loss of 0.9781
# Training: Batch 532/1000. Loss of 1.3193, cover loss of 1.2944, secret loss of 1.2490
# Training: Batch 533/1000. Loss of 1.2973, cover loss of 1.0716, secret loss of 1.3837
# Training: Batch 534/1000. Loss of 1.3614, cover loss of 1.1645, secret loss of 1.3367
# Training: Batch 535/1000. Loss of 1.3510, cover loss of 1.2959, secret loss of 1.2041
# Training: Batch 536/1000. Loss of 1.3010, cover loss of 1.1957, secret loss of 1.0631
# Training: Batch 537/1000. Loss of 1.4170, cover loss of 1.3742, secret loss of 1.3690
# Training: Batch 538/1000. Loss of 1.2528, cover loss of 1.0447, secret loss of 1.1073
# Training: Batch 539/1000. Loss of 1.3488, cover loss of 1.3111, secret loss of 1.2003
# Training: Batch 540/1000. Loss of 1.3907, cover loss of 1.1883, secret loss of 1.2944
# Training: Batch 541/1000. Loss of 1.1061, cover loss of 1.0140, secret loss of 1.0182
# Training: Batch 542/1000. Loss of 1.1516, cover loss of 1.0000, secret loss of 0.7443
# Training: Batch 543/1000. Loss of 1.2438, cover loss of 1.2192, secret loss of 0.9580
# Training: Batch 544/1000. Loss of 1.1031, cover loss of 0.9250, secret loss of 0.8056
# Training: Batch 545/1000. Loss of 1.5006, cover loss of 1.5777, secret loss of 1.2053
# Training: Batch 546/1000. Loss of 1.3249, cover loss of 1.3529, secret loss of 1.1452
# Training: Batch 547/1000. Loss of 1.0925, cover loss of 1.0965, secret loss of 0.7478
# Training: Batch 548/1000. Loss of 1.2641, cover loss of 1.0382, secret loss of 0.8803
# Training: Batch 549/1000. Loss of 1.3306, cover loss of 1.1482, secret loss of 1.2968
# Training: Batch 550/1000. Loss of 1.2329, cover loss of 1.2386, secret loss of 1.0587
# Training: Batch 551/1000. Loss of 1.1259, cover loss of 0.9549, secret loss of 0.9353
# Training: Batch 552/1000. Loss of 1.2763, cover loss of 1.2946, secret loss of 1.1495
# Training: Batch 553/1000. Loss of 1.1868, cover loss of 1.2269, secret loss of 0.8921
# Training: Batch 554/1000. Loss of 1.2588, cover loss of 1.2062, secret loss of 0.8066
# Training: Batch 555/1000. Loss of 1.1617, cover loss of 0.9487, secret loss of 0.7941
# Training: Batch 556/1000. Loss of 1.1509, cover loss of 1.0640, secret loss of 0.8224
# Training: Batch 557/1000. Loss of 1.3583, cover loss of 1.2380, secret loss of 1.2197
# Training: Batch 558/1000. Loss of 1.3699, cover loss of 1.3089, secret loss of 1.2788
# Training: Batch 559/1000. Loss of 1.1539, cover loss of 0.9545, secret loss of 1.0161
# Training: Batch 560/1000. Loss of 1.2203, cover loss of 1.2131, secret loss of 1.0938
# Training: Batch 561/1000. Loss of 1.4279, cover loss of 1.4682, secret loss of 1.2822
# Training: Batch 562/1000. Loss of 1.2009, cover loss of 1.2128, secret loss of 0.9582
# ...
# Training: Batch 816/1000. Loss of 1.3389, cover loss of 1.5309, secret loss of 1.0049
# Training: Batch 817/1000. Loss of 1.1473, cover loss of 1.0783, secret loss of 1.0338
# Training: Batch 818/1000. Loss of 1.1417, cover loss of 0.9662, secret loss of 0.8604
# Training: Batch 819/1000. Loss of 1.1140, cover loss of 0.9723, secret loss of 0.8176
# Training: Batch 820/1000. Loss of 1.0958, cover loss of 0.9239, secret loss of 1.1614
# Training: Batch 821/1000. Loss of 1.2498, cover loss of 1.2572, secret loss of 1.0162
# Training: Batch 822/1000. Loss of 1.2473, cover loss of 1.0606, secret loss of 1.1197
# Training: Batch 823/1000. Loss of 1.2520, cover loss of 1.0867, secret loss of 0.9850
# Training: Batch 824/1000. Loss of 1.1612, cover loss of 1.1267, secret loss of 1.0073
# Training: Batch 825/1000. Loss of 1.2954, cover loss of 1.2682, secret loss of 1.1892
# Training: Batch 826/1000. Loss of 1.2373, cover loss of 1.2313, secret loss of 1.0919
# Training: Batch 827/1000. Loss of 1.2013, cover loss of 1.0878, secret loss of 0.9446
# Training: Batch 828/1000. Loss of 1.2587, cover loss of 1.0320, secret loss of 1.3518
# Training: Batch 829/1000. Loss of 1.0849, cover loss of 0.9118, secret loss of 0.7840
# Training: Batch 830/1000. Loss of 1.3779, cover loss of 1.2323, secret loss of 1.3540
# Training: Batch 831/1000. Loss of 1.3636, cover loss of 1.2879, secret loss of 1.2533
# Training: Batch 832/1000. Loss of 1.3011, cover loss of 1.1435, secret loss of 1.2218
# Training: Batch 833/1000. Loss of 1.1935, cover loss of 1.1707, secret loss of 1.1248
# Training: Batch 834/1000. Loss of 1.3111, cover loss of 1.2154, secret loss of 1.1634
# Training: Batch 835/1000. Loss of 1.0858, cover loss of 0.9110, secret loss of 1.0967
# Training: Batch 836/1000. Loss of 1.3395, cover loss of 1.2435, secret loss of 1.2453
# Training: Batch 837/1000. Loss of 1.3061, cover loss of 1.2442, secret loss of 1.1347
# Training: Batch 838/1000. Loss of 1.1151, cover loss of 0.8965, secret loss of 0.8426
# Training: Batch 839/1000. Loss of 1.2262, cover loss of 1.0779, secret loss of 1.2631
# Training: Batch 840/1000. Loss of 1.2894, cover loss of 1.3014, secret loss of 1.0683
# Training: Batch 841/1000. Loss of 1.1617, cover loss of 1.0234, secret loss of 1.0476
# Training: Batch 842/1000. Loss of 1.2280, cover loss of 1.0028, secret loss of 1.2132
# Training: Batch 843/1000. Loss of 1.1064, cover loss of 1.0492, secret loss of 0.8412
# Training: Batch 844/1000. Loss of 1.3617, cover loss of 1.2301, secret loss of 1.3598
# Training: Batch 845/1000. Loss of 1.2302, cover loss of 1.0466, secret loss of 1.2200
# Training: Batch 846/1000. Loss of 1.1834, cover loss of 1.0632, secret loss of 0.9475
# Training: Batch 847/1000. Loss of 1.2740, cover loss of 1.1492, secret loss of 1.2111
# Training: Batch 848/1000. Loss of 1.2899, cover loss of 1.2006, secret loss of 1.2184
# Training: Batch 849/1000. Loss of 1.4193, cover loss of 1.2818, secret loss of 1.3759
# Training: Batch 850/1000. Loss of 1.3110, cover loss of 1.2028, secret loss of 1.1590
# Training: Batch 851/1000. Loss of 1.0682, cover loss of 1.0028, secret loss of 0.6956
# Training: Batch 852/1000. Loss of 1.2440, cover loss of 0.9745, secret loss of 1.0896
# Training: Batch 853/1000. Loss of 1.4074, cover loss of 1.4656, secret loss of 1.2456
# Training: Batch 854/1000. Loss of 1.3032, cover loss of 1.3019, secret loss of 1.0234
# Training: Batch 855/1000. Loss of 1.2538, cover loss of 1.0548, secret loss of 1.2412
# Training: Batch 856/1000. Loss of 1.1049, cover loss of 0.9643, secret loss of 1.0388
# Training: Batch 857/1000. Loss of 1.3175, cover loss of 1.0351, secret loss of 1.3511
# Training: Batch 858/1000. Loss of 1.3556, cover loss of 1.3892, secret loss of 1.1926
# Training: Batch 859/1000. Loss of 1.2581, cover loss of 1.1237, secret loss of 0.7416
# Training: Batch 860/1000. Loss of 1.5120, cover loss of 1.5302, secret loss of 1.2610
# Training: Batch 861/1000. Loss of 1.0628, cover loss of 0.9641, secret loss of 0.8610
# Training: Batch 862/1000. Loss of 1.1975, cover loss of 1.2575, secret loss of 0.8147
# Training: Batch 863/1000. Loss of 1.1440, cover loss of 1.2144, secret loss of 0.9508
# Training: Batch 864/1000. Loss of 1.4309, cover loss of 1.3231, secret loss of 1.2690
# Training: Batch 865/1000. Loss of 1.3417, cover loss of 1.2359, secret loss of 1.3033
# Training: Batch 866/1000. Loss of 1.3258, cover loss of 1.0485, secret loss of 1.4331
# Training: Batch 867/1000. Loss of 1.1650, cover loss of 1.1800, secret loss of 0.9777
# Training: Batch 868/1000. Loss of 1.0404, cover loss of 0.9959, secret loss of 0.7183
# Training: Batch 869/1000. Loss of 1.1600, cover loss of 1.1059, secret loss of 0.9863
# Training: Batch 870/1000. Loss of 1.1484, cover loss of 0.9924, secret loss of 0.8146
# Training: Batch 871/1000. Loss of 1.0760, cover loss of 1.0671, secret loss of 0.8699
# Training: Batch 872/1000. Loss of 1.0946, cover loss of 0.8903, secret loss of 0.8053
# Training: Batch 873/1000. Loss of 1.3072, cover loss of 1.1427, secret loss of 1.3284
# Training: Batch 874/1000. Loss of 1.2666, cover loss of 1.0362, secret loss of 1.2589
# Training: Batch 875/1000. Loss of 1.3108, cover loss of 1.0809, secret loss of 1.3927
# Training: Batch 876/1000. Loss of 1.4298, cover loss of 1.2603, secret loss of 1.4831
# Training: Batch 877/1000. Loss of 1.3778, cover loss of 1.2435, secret loss of 1.2440
# Training: Batch 878/1000. Loss of 1.3100, cover loss of 1.1154, secret loss of 1.2244
# Training: Batch 879/1000. Loss of 1.3152, cover loss of 1.3309, secret loss of 1.1548
# Training: Batch 880/1000. Loss of 1.4166, cover loss of 1.4177, secret loss of 1.1744
# Training: Batch 881/1000. Loss of 1.1521, cover loss of 0.8805, secret loss of 0.7632
# Training: Batch 882/1000. Loss of 1.3720, cover loss of 1.1107, secret loss of 1.3330
# Training: Batch 883/1000. Loss of 1.3974, cover loss of 1.3248, secret loss of 1.3003
# Training: Batch 884/1000. Loss of 1.3500, cover loss of 1.3438, secret loss of 1.2705
# Training: Batch 885/1000. Loss of 1.3191, cover loss of 1.3155, secret loss of 1.1385
# Training: Batch 886/1000. Loss of 1.1603, cover loss of 1.0415, secret loss of 0.7130
# Training: Batch 887/1000. Loss of 1.3750, cover loss of 1.1640, secret loss of 1.4540
# Training: Batch 888/1000. Loss of 1.2621, cover loss of 1.1770, secret loss of 1.2224
# Training: Batch 889/1000. Loss of 1.1741, cover loss of 1.0817, secret loss of 0.9053
# Training: Batch 890/1000. Loss of 1.0616, cover loss of 0.8463, secret loss of 0.8284
# Training: Batch 891/1000. Loss of 1.1729, cover loss of 1.0377, secret loss of 0.9628
# Training: Batch 892/1000. Loss of 1.2035, cover loss of 1.1589, secret loss of 1.1457
# Training: Batch 893/1000. Loss of 1.0229, cover loss of 0.9770, secret loss of 0.6079
# Training: Batch 894/1000. Loss of 1.2388, cover loss of 1.0658, secret loss of 1.2768
# Training: Batch 895/1000. Loss of 1.0949, cover loss of 0.9363, secret loss of 0.7766
# Training: Batch 896/1000. Loss of 1.1492, cover loss of 1.0300, secret loss of 0.9598
# Training: Batch 897/1000. Loss of 1.2097, cover loss of 0.9855, secret loss of 1.1611
# Training: Batch 898/1000. Loss of 1.4189, cover loss of 1.2578, secret loss of 1.0027
# Training: Batch 899/1000. Loss of 1.1669, cover loss of 1.1202, secret loss of 1.0438
# Training: Batch 900/1000. Loss of 1.4657, cover loss of 1.5500, secret loss of 1.1765
# Training: Batch 901/1000. Loss of 1.3283, cover loss of 1.3482, secret loss of 1.1888
# Training: Batch 902/1000. Loss of 1.2548, cover loss of 1.2966, secret loss of 1.0867
# Training: Batch 903/1000. Loss of 1.2497, cover loss of 1.2543, secret loss of 0.9715
# Training: Batch 904/1000. Loss of 1.0724, cover loss of 1.1026, secret loss of 0.9084
# Training: Batch 905/1000. Loss of 1.4695, cover loss of 1.3701, secret loss of 1.4442
# Training: Batch 906/1000. Loss of 1.3227, cover loss of 1.0734, secret loss of 1.3237
# Training: Batch 907/1000. Loss of 1.1704, cover loss of 1.0206, secret loss of 0.8745
# Training: Batch 908/1000. Loss of 1.1145, cover loss of 1.0719, secret loss of 0.6457
# Training: Batch 909/1000. Loss of 1.2278, cover loss of 1.2739, secret loss of 1.0608
# Training: Batch 910/1000. Loss of 1.3028, cover loss of 1.3304, secret loss of 1.0942
# Training: Batch 911/1000. Loss of 1.1491, cover loss of 1.2083, secret loss of 0.9820
# Training: Batch 912/1000. Loss of 1.2595, cover loss of 1.1004, secret loss of 1.0929
# Training: Batch 913/1000. Loss of 1.2047, cover loss of 1.1081, secret loss of 0.8994
# Training: Batch 914/1000. Loss of 1.2502, cover loss of 1.0614, secret loss of 1.2170
# Training: Batch 915/1000. Loss of 1.1141, cover loss of 1.0856, secret loss of 0.9941
# Training: Batch 916/1000. Loss of 1.1827, cover loss of 1.1581, secret loss of 0.8110
# Training: Batch 917/1000. Loss of 1.0794, cover loss of 1.1337, secret loss of 0.9017
# Training: Batch 918/1000. Loss of 1.3526, cover loss of 1.2518, secret loss of 1.1401
# Training: Batch 919/1000. Loss of 1.3105, cover loss of 1.0536, secret loss of 1.2785
# Training: Batch 920/1000. Loss of 1.3474, cover loss of 1.0067, secret loss of 1.3878
# Training: Batch 921/1000. Loss of 1.2384, cover loss of 1.0483, secret loss of 0.8372
# Training: Batch 922/1000. Loss of 1.1537, cover loss of 1.1078, secret loss of 0.8798
# Training: Batch 923/1000. Loss of 1.2239, cover loss of 1.0759, secret loss of 0.7825
# Training: Batch 924/1000. Loss of 1.3559, cover loss of 1.2305, secret loss of 1.2903
# Training: Batch 925/1000. Loss of 1.3117, cover loss of 1.4445, secret loss of 1.0035
# Training: Batch 926/1000. Loss of 1.0826, cover loss of 0.9700, secret loss of 0.9210
# Training: Batch 927/1000. Loss of 1.2177, cover loss of 1.0230, secret loss of 1.0277
# Training: Batch 928/1000. Loss of 1.3071, cover loss of 1.3417, secret loss of 1.0863
# Training: Batch 929/1000. Loss of 1.3288, cover loss of 1.2525, secret loss of 0.9102
# Training: Batch 930/1000. Loss of 1.1266, cover loss of 1.1088, secret loss of 0.9553
# Training: Batch 931/1000. Loss of 1.1417, cover loss of 1.0956, secret loss of 0.7343
# Training: Batch 932/1000. Loss of 1.1541, cover loss of 1.0654, secret loss of 1.1389
# Training: Batch 933/1000. Loss of 1.1761, cover loss of 1.0497, secret loss of 0.7271
# Training: Batch 934/1000. Loss of 1.2508, cover loss of 1.0873, secret loss of 1.1865
# Training: Batch 935/1000. Loss of 1.2477, cover loss of 1.0111, secret loss of 1.3387
# Training: Batch 936/1000. Loss of 1.1896, cover loss of 1.2111, secret loss of 1.0463
# Training: Batch 937/1000. Loss of 1.2944, cover loss of 1.3094, secret loss of 1.1168
# Training: Batch 938/1000. Loss of 1.3847, cover loss of 1.2957, secret loss of 1.1095
# Training: Batch 939/1000. Loss of 1.2087, cover loss of 1.2015, secret loss of 1.1432
# Training: Batch 940/1000. Loss of 1.3163, cover loss of 1.0846, secret loss of 1.0494
# Training: Batch 941/1000. Loss of 1.1393, cover loss of 1.0034, secret loss of 1.1578
# Training: Batch 942/1000. Loss of 1.1142, cover loss of 0.9290, secret loss of 1.1960
# Training: Batch 943/1000. Loss of 1.2363, cover loss of 1.0570, secret loss of 0.9902
# Training: Batch 944/1000. Loss of 1.3638, cover loss of 1.4247, secret loss of 1.1693
# Training: Batch 945/1000. Loss of 1.3098, cover loss of 1.2158, secret loss of 1.1996
# Training: Batch 946/1000. Loss of 1.2943, cover loss of 1.4380, secret loss of 1.0231
# Training: Batch 947/1000. Loss of 1.3260, cover loss of 1.2893, secret loss of 1.1908
# Training: Batch 948/1000. Loss of 1.1721, cover loss of 1.0748, secret loss of 0.9161
# Training: Batch 949/1000. Loss of 1.2728, cover loss of 1.0761, secret loss of 1.3477
# Training: Batch 950/1000. Loss of 1.2063, cover loss of 1.1173, secret loss of 1.0504
# Training: Batch 951/1000. Loss of 1.2246, cover loss of 0.8993, secret loss of 1.3952
# Training: Batch 952/1000. Loss of 1.1586, cover loss of 0.9752, secret loss of 1.2236
# Training: Batch 953/1000. Loss of 1.2719, cover loss of 1.1457, secret loss of 1.2856
# Training: Batch 954/1000. Loss of 1.1061, cover loss of 1.0544, secret loss of 1.0526
# Training: Batch 955/1000. Loss of 1.2813, cover loss of 1.1829, secret loss of 1.1107
# Training: Batch 956/1000. Loss of 1.1376, cover loss of 1.1004, secret loss of 1.0192
# Training: Batch 957/1000. Loss of 1.1644, cover loss of 1.0990, secret loss of 0.8822
# Training: Batch 958/1000. Loss of 1.0901, cover loss of 0.9265, secret loss of 0.7560
# Training: Batch 959/1000. Loss of 1.5026, cover loss of 1.5459, secret loss of 1.3993
# Training: Batch 960/1000. Loss of 1.1718, cover loss of 1.0641, secret loss of 1.1410
# Training: Batch 961/1000. Loss of 1.1831, cover loss of 1.1942, secret loss of 0.7856
# Training: Batch 962/1000. Loss of 1.2672, cover loss of 1.1255, secret loss of 1.2888
# Training: Batch 963/1000. Loss of 1.1126, cover loss of 0.9499, secret loss of 0.8253
# Training: Batch 964/1000. Loss of 1.2398, cover loss of 1.0668, secret loss of 1.1230
# Training: Batch 965/1000. Loss of 1.0146, cover loss of 0.8501, secret loss of 0.6972
# Training: Batch 966/1000. Loss of 1.3337, cover loss of 1.2045, secret loss of 1.2061
# Training: Batch 967/1000. Loss of 1.4382, cover loss of 1.4750, secret loss of 1.1166
# Training: Batch 968/1000. Loss of 1.2068, cover loss of 1.0087, secret loss of 1.1505
# Training: Batch 969/1000. Loss of 1.2320, cover loss of 1.2350, secret loss of 1.0334
# Training: Batch 970/1000. Loss of 1.3267, cover loss of 1.1556, secret loss of 1.2626
# Training: Batch 971/1000. Loss of 1.4314, cover loss of 1.3477, secret loss of 1.2800
# Training: Batch 972/1000. Loss of 1.2195, cover loss of 1.0468, secret loss of 1.2512
# Training: Batch 973/1000. Loss of 1.1834, cover loss of 1.0182, secret loss of 1.1277
# Training: Batch 974/1000. Loss of 1.0651, cover loss of 0.8708, secret loss of 0.7978
# Training: Batch 975/1000. Loss of 1.2852, cover loss of 1.2827, secret loss of 1.0254
# Training: Batch 976/1000. Loss of 1.2208, cover loss of 1.0943, secret loss of 1.1583
# Training: Batch 977/1000. Loss of 1.4531, cover loss of 1.4712, secret loss of 1.2862
# Training: Batch 978/1000. Loss of 1.1752, cover loss of 1.0627, secret loss of 0.9497
# Training: Batch 979/1000. Loss of 1.0098, cover loss of 0.8714, secret loss of 0.8284
# Training: Batch 980/1000. Loss of 1.1983, cover loss of 1.0779, secret loss of 1.1629
# Training: Batch 981/1000. Loss of 1.5404, cover loss of 1.2461, secret loss of 1.6310
# Training: Batch 982/1000. Loss of 1.1982, cover loss of 1.0036, secret loss of 0.7896
# Training: Batch 983/1000. Loss of 0.9128, cover loss of 0.7362, secret loss of 0.8456
# Training: Batch 984/1000. Loss of 1.1966, cover loss of 1.0520, secret loss of 1.0424
# Training: Batch 985/1000. Loss of 1.2261, cover loss of 1.1779, secret loss of 1.0591
# Training: Batch 986/1000. Loss of 1.1278, cover loss of 1.0423, secret loss of 0.8369
# Training: Batch 987/1000. Loss of 1.2203, cover loss of 1.0407, secret loss of 1.3476
# Training: Batch 988/1000. Loss of 1.3240, cover loss of 1.1019, secret loss of 1.4457
# Training: Batch 989/1000. Loss of 1.1929, cover loss of 1.1855, secret loss of 1.0103
# Training: Batch 990/1000. Loss of 1.3668, cover loss of 1.3120, secret loss of 0.9367
# Training: Batch 991/1000. Loss of 1.2539, cover loss of 1.1813, secret loss of 1.0008
# Training: Batch 992/1000. Loss of 1.3384, cover loss of 1.2303, secret loss of 1.2737
# Training: Batch 993/1000. Loss of 1.4450, cover loss of 1.2642, secret loss of 1.3967
# Training: Batch 994/1000. Loss of 1.1706, cover loss of 0.9701, secret loss of 1.0103
# Training: Batch 995/1000. Loss of 1.3899, cover loss of 1.1487, secret loss of 1.3662
# Training: Batch 996/1000. Loss of 1.3931, cover loss of 1.3479, secret loss of 1.2728
# Training: Batch 997/1000. Loss of 1.2951, cover loss of 1.2996, secret loss of 1.1399
# Training: Batch 998/1000. Loss of 1.2616, cover loss of 1.2034, secret loss of 1.0345
# Training: Batch 999/1000. Loss of 1.2716, cover loss of 1.2481, secret loss of 1.1443
# Training: Batch 1000/1000. Loss of 1.1946, cover loss of 1.2018, secret loss of 1.0227
# Epoch [50/50], Average_loss: 1.2403

# %%
 # Plot loss through epochs
plt.plot(loss_history)
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Batch')
plt.show()

# %%
def pixel_errors(input_S, input_C, decoded_S, decoded_C):
    """Calculates mean of Sum of Squared Errors per pixel for cover and secret images. """
    input_S = np.array(input_S.detach().cpu())
    input_C = np.array(input_C.detach().cpu())
    decoded_S = np.array(decoded_S.detach().cpu())
    decoded_C = np.array(decoded_C.detach().cpu())
    # print(input_S)
    see_Spixel = np.sqrt(np.mean(np.square(255*(input_S - decoded_S))))
    see_Cpixel = np.sqrt(np.mean(np.square(255*(input_C - decoded_C))))
    
    return see_Spixel, see_Cpixel

import math
def psnr(input_S, input_C, decoded_S, decoded_C):
    input_S = np.array(input_S.detach().cpu())
    input_C = np.array(input_C.detach().cpu())
    decoded_S = np.array(decoded_S.detach().cpu())
    decoded_C = np.array(decoded_C.detach().cpu())
    mse_s = np.mean(np.square(255*(input_S - decoded_S)))
    mse_c = np.mean(np.square(255*(input_C - decoded_C)))
    psnr_s = 10*math.log10(255**2/mse_s)
    psnr_c = 10*math.log10(255**2/mse_c)
    return psnr_s, psnr_c

def pixel_histogram(diff_S, diff_C):
    """Calculates histograms of errors for cover and secret image. """
    diff_Sflat = diff_S.flatten()
    diff_Cflat = diff_C.flatten()
    
    fig = plt.figure(figsize=(15, 5))
    a=fig.add_subplot(1,2,1)
        
    imgplot = plt.hist(255* diff_Cflat, 100, density=1, alpha=0.75, facecolor='red')
    a.set_title('Distribution of error in the Cover image.')
    plt.axis([0, 250, 0, 0.2])
    
    a=fig.add_subplot(1,2,2)
    imgplot = plt.hist(255* diff_Sflat, 100, density=1, alpha=0.75, facecolor='red')
    a.set_title('Distribution of errors in the Secret image.')
    plt.axis([0, 250, 0, 0.2])
    
    plt.show()

# %%
# net.load_state_dict(torch.load(MODELS_PATH+'Epoch N4.pkl'))

# Switch to evaluate mode
net.eval()
Path(PATH+"LOSS3_ds_rotation").mkdir(parents=True, exist_ok=True)
Path(PATH+"LOSS3_ds_rotation/cover_images/").mkdir(parents=True, exist_ok=True)
Path(PATH+"LOSS3_ds_rotation/container_images/").mkdir(parents=True, exist_ok=True)
save_path = PATH+"LOSS3_ds_rotation/"

test_losses = []

S_errors = []
C_errors = []

psnr_s,psnr_c = [], []
# Show images
for idx, test_batch in enumerate(test_loader):
     # Saves images
    data, _ = test_batch
    data = data.to(device)

    # Saves secret images and secret covers
    test_secret = data[:len(data)//2]
    test_cover = data[len(data)//2:]

    # Creates variable from secret and cover images
    test_secret = Variable(test_secret, volatile=True)
    test_cover = Variable(test_cover, volatile=True)

    # Compute output
    test_hidden, test_output = net(test_secret, test_cover)
    
    # Calculate loss
    test_loss, loss_cover, loss_secret = customized_loss(test_output, test_hidden, test_secret, test_cover, beta)
    
    diff_S, diff_C = np.abs(np.array(test_output.data.detach().cpu()) - np.array(test_secret.data.detach().cpu())), np.abs(np.array(test_hidden.data.detach().cpu()) - np.array(test_cover.data.detach().cpu()))
    
#     print (diff_S, diff_C)

    # Print pixel-wise average errors in a 256 scale.
    S_error, C_error = pixel_errors(test_secret, test_cover, test_output, test_hidden)
    S_errors.append(S_error)
    C_errors.append(C_error)

    S_psnr, C_psnr = psnr(test_secret, test_cover, test_output, test_hidden)
    psnr_s.append(S_psnr)
    psnr_c.append(C_psnr)
    
    if idx in [1,2,3,4]:
        print ('Total loss: {:.2f} \nLoss on secret: {:.2f} \nLoss on cover: {:.2f}'.format(test_loss.data.item(), loss_secret.data.item(), loss_cover.data.item()))

        # Creates img tensor
        imgs = [test_secret.data.detach().cpu(), test_output.data.detach().cpu(), test_cover.data.detach().cpu(), test_hidden.data.detach().cpu()]
        imgs_tsor = torch.cat(imgs, 0)

        # Prints Images
        imshow(utils.make_grid(imgs_tsor), idx+1, learning_rate=learning_rate, beta=beta)
        
    if idx < 500:
        container_img = tensor_to_image(test_hidden.data.detach().cpu())
        container_img = Image.fromarray(container_img)
        container_img.save(save_path+"container_images/"+str(idx)+".jpeg")
        cover_img = tensor_to_image(test_cover.data.detach().cpu())
        cover_img = Image.fromarray(cover_img)
        cover_img.save(save_path+"cover_images/"+str(idx)+".jpeg")
    
    test_losses.append(test_loss.data.item())
        
mean_test_loss = np.mean(test_losses)

print ('Average loss on test set: {:.2f}'.format(mean_test_loss))
# Out:
# Total loss: 1.12
# Loss on secret: 0.46
# Loss on cover: 1.60
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:27: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
# Total loss: 1.53
# Loss on secret: 1.38
# Loss on cover: 1.51
# Total loss: 1.07
# Loss on secret: 0.81
# Loss on cover: 1.25
# Total loss: 1.94
# Loss on secret: 1.90
# Loss on cover: 2.29
# Average loss on test set: 1.25

# %%
print ("Avg. S error per pixel [0, 255]:", sum(S_errors)/len(S_errors))
print ("Avg. C error per pixel [0, 255]:", sum(C_errors)/len(C_errors))
# Out:
# Avg. S error per pixel [0, 255]: 274.8308759399414
# Avg. C error per pixel [0, 255]: 286.4990874786377

# %%
print ("Avg. PSNR of secret and decoded secret:", sum(psnr_s)/len(psnr_s))
print ("Avg. PSNR of cover and container:", sum(psnr_c)/len(psnr_c))
# Out:
# Avg. PSNR of secret and decoded secret: -0.4292725493814342
# Avg. PSNR of cover and container: -0.8044015191316772

# %%
# Plot distribution of errors in cover and secret images.
pixel_histogram(diff_S, diff_C)
