# %% [markdown]
# <a href="https://colab.research.google.com/github/chvamshi/Deep-Steganography/blob/main/Copy_of_LOSS2_DS_img_crop_10_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget http://cs231n.stanford.edu/tiny-imagenet-200.zip
# !unzip -q tiny-imagenet-200.zip && ls tiny-imagenet-200
# Out:
# --2022-02-08 17:55:30--  http://cs231n.stanford.edu/tiny-imagenet-200.zip
# Resolving cs231n.stanford.edu (cs231n.stanford.edu)... 171.64.68.10
# Connecting to cs231n.stanford.edu (cs231n.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248100043 (237M) [application/zip]
# Saving to: ‘tiny-imagenet-200.zip’
#
# tiny-imagenet-200.z 100%[===================>] 236.61M  19.0MB/s    in 16s
#
# 2022-02-08 17:55:47 (14.8 MB/s) - ‘tiny-imagenet-200.zip’ saved [248100043/248100043]
#
# test  train  val  wnids.txt  words.txt

# %%
# Imports necessary libraries and modules
from itertools import islice
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch.autograd import Variable
from torch import utils
from torch.utils.data import Subset
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import os 
from pathlib import Path
import pickle
import random
from torchvision import datasets, utils
import torchvision.transforms as transforms
from torchvision.transforms import ToPILImage
from torchvision.transforms import RandomResizedCrop
from torchvision.transforms.functional import resized_crop
from random import shuffle
from IPython.display import Image
from PIL import Image

# Use GPU if it is present
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
# Directory path
# os.chdir("..")
cwd = '/content/tiny-imagenet-200'

# Hyper Parameters
num_epochs = 50
batch_size = 32
learning_rate = 0.001
beta = 1

# Mean and std deviation of imagenet dataset. Source: http://cs231n.stanford.edu/reports/2017/pdfs/101.pdf
std = [0.229, 0.224, 0.225]
mean = [0.485, 0.456, 0.406]

# TODO: Define train, validation and models
MODELS_PATH = '/content/output/models'
# TRAIN_PATH = cwd+'/train/'
# VALID_PATH = cwd+'/valid/'
VALID_PATH = cwd+'/val/'
TRAIN_PATH = cwd+'/train/'
TEST_PATH = cwd+'/test/'

# if not os.path.exists(MODELS_PATH): os.mkdir(MODELS_PATH)

# %%
def variance(image1, image2):
    var1 = torch.var(image2-image1)
    # var2 = torch.var(image2)

    return var1

def customized_loss(S_prime, C_prime, S, C, B):
    ''' Calculates loss specified on the paper.'''
    
    loss_cover = torch.nn.functional.l1_loss(C_prime, C)
    # loss_cover = loss_cover/(64*64)
    loss_secret = torch.nn.functional.l1_loss(S_prime, S)
    # loss_secret = loss_secret/(64*64)

    variance_cover = variance(C_prime, C)
    variance_secret = variance(S_prime, S)

    loss_all = loss_cover+loss_secret+variance_cover+variance_secret
    loss_all = loss_all/4

    return loss_all, loss_cover, loss_secret

def denormalize(image, std, mean):
    ''' Denormalizes a tensor of images.'''

    for t in range(3):
        image[t, :, :] = (image[t, :, :] * std[t]) + mean[t]
    return image

def imshow(img, idx, learning_rate, beta):
    '''Prints out an image given in tensor format.'''
    
    img = denormalize(img, std, mean)
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.title('Example '+str(idx)+', lr='+str(learning_rate)+', B='+str(beta))
    plt.show()
    return

def gaussian(tensor, mean=0, stddev=0.1):
    '''Adds random noise to a tensor.'''
    
    noise = torch.nn.init.normal(torch.Tensor(tensor.size()), 0, 0.1).to(device)
    return Variable(tensor + noise)

def tensor_to_image(tensor):
    """
    Transforms a torch tensor into numpy uint8 array (image)
    :param tensor: (batch_size x channels x height x width) torch tensor in range [-1.0, 1.0]
    :return: (batch_size x height x width x channels) uint8 array
    """
    image = tensor.cpu().numpy()[0]
    # image = tensor.permute(0, 2, 3, 1).cpu().numpy()
    image = np.transpose(image, (1,2,0))
    image = (image + 1) * 127.5
    return np.clip(image, 0, 255).astype(np.uint8)

# %%
import torch.nn as nn
import numpy as np

def random_float(min, max):
    """
    Return a random number
    :param min:
    :param max:
    :return:
    """
    return np.random.rand() * (max - min) + min


def get_random_rectangle_inside(image, height_ratio_range, width_ratio_range):
    """
    Returns a random rectangle inside the image, where the size is random and is controlled by height_ratio_range and width_ratio_range.
    This is analogous to a random crop. For example, if height_ratio_range is (0.7, 0.9), then a random number in that range will be chosen
    (say it is 0.75 for illustration), and the image will be cropped such that the remaining height equals 0.75. In fact,
    a random 'starting' position rs will be chosen from (0, 0.25), and the crop will start at rs and end at rs + 0.75. This ensures
    that we crop from top/bottom with equal probability.
    The same logic applies to the width of the image, where width_ratio_range controls the width crop range.
    :param image: The image we want to crop
    :param height_ratio_range: The range of remaining height ratio
    :param width_ratio_range:  The range of remaining width ratio.
    :return: "Cropped" rectange with width and height drawn randomly height_ratio_range and width_ratio_range
    """
    # print(image.shape)
    image_height = image.shape[1]
    image_width = image.shape[2]

    remaining_height = int(np.rint(random_float(height_ratio_range[0], height_ratio_range[1]) * image_height))
    remaining_width = int(np.rint(random_float(width_ratio_range[0], width_ratio_range[0]) * image_width))

    if remaining_height == image_height:
        height_start = 0
    else:
        height_start = np.random.randint(0, image_height - remaining_height)

    if remaining_width == image_width:
        width_start = 0
    else:
        width_start = np.random.randint(0, image_width - remaining_width)

    return height_start, height_start+remaining_height, width_start, width_start+remaining_width


class Crop(nn.Module):
    """
    Randomly crops the image from top/bottom and left/right. The amount to crop is controlled by parameters
    heigth_ratio_range and width_ratio_range
    """
    def __init__(self, height_ratio_range, width_ratio_range):
        """
        :param height_ratio_range:
        :param width_ratio_range:
        """
        super(Crop, self).__init__()
        self.height_ratio_range = height_ratio_range
        self.width_ratio_range = width_ratio_range


    def forward(self, noised_and_cover):
        noised_image = noised_and_cover[0]
        print("Noisedimageshape: ",noised_image.shape)
        shape = noised_image.shape
        # crop_rectangle is in form (from, to) where @from and @to are 2D points -- (height, width)

        h_start, h_end, w_start, w_end = get_random_rectangle_inside(noised_image, self.height_ratio_range, self.width_ratio_range)

        noised_image =  noised_image[
               :,
               h_start: h_end,
               w_start: w_end].clone()
        noised_image1 = noised_image.expand(-1,64,64)
        print(noised_image1.shape)
        noised_and_cover[0] = noised_image1.clone()

        return noised_and_cover

# %%
# Preparation Network (2 conv layers)
class PrepNetwork(nn.Module):
    def __init__(self):
        super(PrepNetwork, self).__init__()
        self.initialP3 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialP4 = nn.Sequential(
            nn.Conv2d(3, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialP5 = nn.Sequential(
            nn.Conv2d(3, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalP3 = nn.Sequential(
            nn.Conv2d(65, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalP4 = nn.Sequential(
            nn.Conv2d(65, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalP5 = nn.Sequential(
            nn.Conv2d(65, 5, kernel_size=5, padding=2),
            nn.ReLU())

    def forward(self, p):
        p1 = self.initialP3(p)
        p2 = self.initialP4(p)
        p3 = self.initialP5(p)
        mid = torch.cat((p1, p2, p3), 1)
        p4 = self.finalP3(mid)
        p5 = self.finalP4(mid)
        p6 = self.finalP5(mid)
        # print(p4.shape)
        # print(p5.shape)
        # print(p6.shape)
        out = torch.cat((p4, p5, p6), 1)
        return out

# Hiding Network (5 conv layers)
class HidingNetwork(nn.Module):
    def __init__(self):
        super(HidingNetwork, self).__init__()
        self.initialH3 = nn.Sequential(
            nn.Conv2d(68, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialH4 = nn.Sequential(
            nn.Conv2d(68, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialH5 = nn.Sequential(
            nn.Conv2d(68, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalH3 = nn.Sequential(
            nn.Conv2d(65, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalH4 = nn.Sequential(
            nn.Conv2d(65, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalH5 = nn.Sequential(
            nn.Conv2d(65, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalH = nn.Sequential(
            nn.Conv2d(65, 3, kernel_size=1, padding=0))
        
    def forward(self, h):
        h1 = self.initialH3(h)
        h2 = self.initialH4(h)
        h3 = self.initialH5(h)
        mid = torch.cat((h1, h2, h3), 1)
        h4 = self.finalH3(mid)
        h5 = self.finalH4(mid)
        h6 = self.finalH5(mid)
        mid2 = torch.cat((h4, h5, h6), 1)
        out = self.finalH(mid2)
        out_noise = gaussian(out.data, 0, 0.1)
        return out, out_noise

# Reveal Network (2 conv layers)
class RevealNetwork(nn.Module):
    def __init__(self):
        super(RevealNetwork, self).__init__()
        self.initialR3 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialR4 = nn.Sequential(
            nn.Conv2d(3, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialR5 = nn.Sequential(
            nn.Conv2d(3, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalR3 = nn.Sequential(
            nn.Conv2d(65, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalR4 = nn.Sequential(
            nn.Conv2d(65, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalR5 = nn.Sequential(
            nn.Conv2d(65, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalR = nn.Sequential(
            nn.Conv2d(65, 3, kernel_size=1, padding=0))

    def forward(self, r, img_shape):
        # r = r.expand(img_shape)
        r1 = self.initialR3(r)
        r2 = self.initialR4(r)
        r3 = self.initialR5(r)
        mid = torch.cat((r1, r2, r3), 1)
        r4 = self.finalR3(mid)
        r5 = self.finalR4(mid)
        r6 = self.finalR5(mid)
        mid2 = torch.cat((r4, r5, r6), 1)
        out = self.finalR(mid2)
        return out

# Join three networks in one module
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.m1 = PrepNetwork().to(device)
        self.m2 = HidingNetwork().to(device)
        self.m3 = RevealNetwork().to(device)
        self.crop = Crop((0.7,0.9),(0.7,0.9)).to(device)

    def forward(self, secret, cover):
        img_shape = secret.shape
        x_1 = self.m1(secret)
        mid = torch.cat((x_1, cover), 1)
        x_2, x_2_noise = self.m2(mid)
        # x_2_noise = resized_crop(img=x_2_noise, top = 0, left=0, height=19, width=19, size=[64,64])
        x_2 =  resized_crop(img=x_2, top = 0, left=0, height=58, width=58, size=[64,64])
        # x_3 = self.m3(x_2_noise, img_shape)
        x_3 = self.m3(x_2, img_shape)
        return x_2, x_3

# %%
# Creates net object
net = Net().to(device)

# %%
# Creates training set
train_data = datasets.ImageFolder(
        TRAIN_PATH,
        transforms.Compose([
        # transforms.Scale(256),
        # transforms.RandomCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean,
        std=std)
        ]))
train_data = Subset(train_data, [i for i in range(32000)])
train_loader = torch.utils.data.DataLoader(
        train_data, batch_size=batch_size, num_workers=1, 
        pin_memory=True, shuffle=True, drop_last=True)

# Creates test set
test_data = datasets.ImageFolder(
        TEST_PATH, 
        transforms.Compose([
        # transforms.Scale(256),
        # transforms.RandomCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean,
        std=std)
        ]))
test_data = Subset(test_data,[i for i in range(5000)])
test_loader = torch.utils.data.DataLoader(
        test_data, batch_size=2, num_workers=1, 
        pin_memory=True, shuffle=True, drop_last=True)

# %%
PATH = "/content/drive/MyDrive/"
loss_history = []

def train_model(train_loader, beta, learning_rate):
    
    # Save optimizer
    optimizer = optim.Adam(net.parameters(), lr=learning_rate)
    
    loss_history = []
    # Iterate over batches performing forward and backward passes
    for epoch in range(num_epochs):

        # Train mode
        net.train()
        
        train_losses = []
        # Train one epoch
        for idx, train_batch in enumerate(train_loader):

            data, _  = train_batch
            data = data.to(device)

            # Saves secret images and secret covers
            train_covers = data[:len(data)//2]
            train_secrets = data[len(data)//2:]
            
            # Creates variable from secret and cover images
            train_secrets = Variable(train_secrets, requires_grad=False)
            train_covers = Variable(train_covers, requires_grad=False)

            # Forward + Backward + Optimize
            optimizer.zero_grad()
            train_hidden, train_output = net(train_secrets, train_covers)

            # Calculate loss and perform backprop
            train_loss, train_loss_cover, train_loss_secret = customized_loss(train_output, train_hidden, train_secrets, train_covers, beta)
            train_loss.backward()
            optimizer.step()
            
            # Saves training loss
            # print(train_loss.data)
            train_losses.append(train_loss.data.item())
            loss_history.append(train_loss.data.item())
            
            # Prints mini-batch losses
            print('Training: Batch {0}/{1}. Loss of {2:.4f}, cover loss of {3:.4f}, secret loss of {4:.4f}'.format(idx+1, len(train_loader), train_loss.data.item(), train_loss_cover.data.item(), train_loss_secret.data.item()))
    
        # Save model
        # torch.save(net.state_dict(), '/content/Epoch N{}.pkl'.format(epoch+1))
        torch.save(net.state_dict(), PATH+"LOSS2_1_ds_crop_10.pth")
        with open(PATH+"LOSS2_1_loss_history_crop_10.txt", "a") as f:
            for s in loss_history:
                f.write(str(s) +"\n")
        
        mean_train_loss = np.mean(train_losses)
    
        # Prints epoch average loss
        print ('Epoch [{0}/{1}], Average_loss: {2:.4f}'.format(
                epoch+1, num_epochs, mean_train_loss))
    
    return net, mean_train_loss, loss_history

# %%
# Load model
# net.load_state_dict(torch.load(PATH+"LOSS2_1_ds_crop_10.pth"))
# loss_history = []
# with open(PATH+"LOSS2_1_loss_history_crop_10.txt", "r") as f:
#   for line in f:
#     loss_history.append(float(line.strip()))

net, mean_train_loss, loss_history = train_model(train_loader, beta, learning_rate)
# loss_history.extend(loss_history1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:43: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
# Streaming output truncated to the last 5000 lines.
# Training: Batch 6/1000. Loss of 0.2262, cover loss of 0.3002, secret loss of 0.2580
# Training: Batch 7/1000. Loss of 0.2068, cover loss of 0.3102, secret loss of 0.2030
# Training: Batch 8/1000. Loss of 0.2020, cover loss of 0.3056, secret loss of 0.2043
# Training: Batch 9/1000. Loss of 0.2311, cover loss of 0.3200, secret loss of 0.2661
# Training: Batch 10/1000. Loss of 0.2115, cover loss of 0.3318, secret loss of 0.1948
# Training: Batch 11/1000. Loss of 0.2071, cover loss of 0.2984, secret loss of 0.2261
# Training: Batch 12/1000. Loss of 0.2645, cover loss of 0.3704, secret loss of 0.2741
# Training: Batch 13/1000. Loss of 0.2393, cover loss of 0.3403, secret loss of 0.2398
# Training: Batch 14/1000. Loss of 0.2073, cover loss of 0.2769, secret loss of 0.2548
# Training: Batch 15/1000. Loss of 0.2641, cover loss of 0.3730, secret loss of 0.2649
# Training: Batch 16/1000. Loss of 0.2334, cover loss of 0.3094, secret loss of 0.2647
# Training: Batch 17/1000. Loss of 0.2179, cover loss of 0.3117, secret loss of 0.2472
# Training: Batch 18/1000. Loss of 0.2304, cover loss of 0.3472, secret loss of 0.2117
# Training: Batch 19/1000. Loss of 0.2406, cover loss of 0.3303, secret loss of 0.2689
# Training: Batch 20/1000. Loss of 0.1892, cover loss of 0.2589, secret loss of 0.2285
# Training: Batch 21/1000. Loss of 0.2062, cover loss of 0.2983, secret loss of 0.2243
# Training: Batch 22/1000. Loss of 0.2085, cover loss of 0.2845, secret loss of 0.2364
# Training: Batch 23/1000. Loss of 0.2117, cover loss of 0.2952, secret loss of 0.2286
# Training: Batch 24/1000. Loss of 0.2298, cover loss of 0.3302, secret loss of 0.2372
# Training: Batch 25/1000. Loss of 0.2248, cover loss of 0.3116, secret loss of 0.2306
# Training: Batch 26/1000. Loss of 0.2229, cover loss of 0.3102, secret loss of 0.2303
# Training: Batch 27/1000. Loss of 0.2349, cover loss of 0.3281, secret loss of 0.2441
# Training: Batch 28/1000. Loss of 0.2432, cover loss of 0.3373, secret loss of 0.2494
# Training: Batch 29/1000. Loss of 0.2249, cover loss of 0.3297, secret loss of 0.2202
# Training: Batch 30/1000. Loss of 0.2234, cover loss of 0.3241, secret loss of 0.2273
# Training: Batch 31/1000. Loss of 0.1739, cover loss of 0.2642, secret loss of 0.1878
# Training: Batch 32/1000. Loss of 0.2459, cover loss of 0.3547, secret loss of 0.2393
# Training: Batch 33/1000. Loss of 0.2010, cover loss of 0.2846, secret loss of 0.2216
# Training: Batch 34/1000. Loss of 0.2324, cover loss of 0.3258, secret loss of 0.2419
# Training: Batch 35/1000. Loss of 0.2346, cover loss of 0.3290, secret loss of 0.2356
# Training: Batch 36/1000. Loss of 0.2257, cover loss of 0.3246, secret loss of 0.2318
# Training: Batch 37/1000. Loss of 0.2517, cover loss of 0.3545, secret loss of 0.2426
# Training: Batch 38/1000. Loss of 0.1954, cover loss of 0.2874, secret loss of 0.2099
# Training: Batch 39/1000. Loss of 0.2480, cover loss of 0.3586, secret loss of 0.2412
# Training: Batch 40/1000. Loss of 0.1955, cover loss of 0.2938, secret loss of 0.2058
# Training: Batch 41/1000. Loss of 0.2268, cover loss of 0.2951, secret loss of 0.2626
# Training: Batch 42/1000. Loss of 0.2188, cover loss of 0.3041, secret loss of 0.2238
# Training: Batch 43/1000. Loss of 0.2145, cover loss of 0.3036, secret loss of 0.2311
# Training: Batch 44/1000. Loss of 0.2430, cover loss of 0.3452, secret loss of 0.2315
# Training: Batch 45/1000. Loss of 0.2045, cover loss of 0.2914, secret loss of 0.2297
# Training: Batch 46/1000. Loss of 0.2317, cover loss of 0.3497, secret loss of 0.2140
# Training: Batch 47/1000. Loss of 0.2188, cover loss of 0.3436, secret loss of 0.1961
# Training: Batch 48/1000. Loss of 0.2182, cover loss of 0.3318, secret loss of 0.2177
# Training: Batch 49/1000. Loss of 0.2035, cover loss of 0.2673, secret loss of 0.2455
# Training: Batch 50/1000. Loss of 0.2084, cover loss of 0.3154, secret loss of 0.2000
# Training: Batch 51/1000. Loss of 0.2405, cover loss of 0.3338, secret loss of 0.2637
# Training: Batch 52/1000. Loss of 0.2350, cover loss of 0.3378, secret loss of 0.2372
# Training: Batch 53/1000. Loss of 0.2371, cover loss of 0.3221, secret loss of 0.2548
# Training: Batch 54/1000. Loss of 0.2308, cover loss of 0.3168, secret loss of 0.2515
# Training: Batch 55/1000. Loss of 0.2131, cover loss of 0.2915, secret loss of 0.2473
# Training: Batch 56/1000. Loss of 0.2410, cover loss of 0.3274, secret loss of 0.2569
# Training: Batch 57/1000. Loss of 0.2135, cover loss of 0.3046, secret loss of 0.2389
# Training: Batch 58/1000. Loss of 0.2084, cover loss of 0.2888, secret loss of 0.2321
# Training: Batch 59/1000. Loss of 0.2339, cover loss of 0.3364, secret loss of 0.2357
# Training: Batch 60/1000. Loss of 0.2483, cover loss of 0.3466, secret loss of 0.2630
# Training: Batch 61/1000. Loss of 0.2318, cover loss of 0.3134, secret loss of 0.2555
# Training: Batch 62/1000. Loss of 0.2375, cover loss of 0.3225, secret loss of 0.2627
# Training: Batch 63/1000. Loss of 0.1950, cover loss of 0.2720, secret loss of 0.2260
# Training: Batch 64/1000. Loss of 0.2197, cover loss of 0.3106, secret loss of 0.2413
# Training: Batch 65/1000. Loss of 0.2360, cover loss of 0.3181, secret loss of 0.2713
# Training: Batch 66/1000. Loss of 0.2334, cover loss of 0.2986, secret loss of 0.2760
# Training: Batch 67/1000. Loss of 0.2498, cover loss of 0.3585, secret loss of 0.2508
# Training: Batch 68/1000. Loss of 0.2567, cover loss of 0.3466, secret loss of 0.2794
# Training: Batch 69/1000. Loss of 0.2559, cover loss of 0.3688, secret loss of 0.2504
# Training: Batch 70/1000. Loss of 0.2242, cover loss of 0.3039, secret loss of 0.2715
# Training: Batch 71/1000. Loss of 0.2189, cover loss of 0.3181, secret loss of 0.2294
# Training: Batch 72/1000. Loss of 0.2289, cover loss of 0.2987, secret loss of 0.2695
# Training: Batch 73/1000. Loss of 0.1953, cover loss of 0.2994, secret loss of 0.1949
# Training: Batch 74/1000. Loss of 0.2208, cover loss of 0.3231, secret loss of 0.2184
# Training: Batch 75/1000. Loss of 0.2238, cover loss of 0.3237, secret loss of 0.2260
# Training: Batch 76/1000. Loss of 0.1868, cover loss of 0.2665, secret loss of 0.2032
# Training: Batch 77/1000. Loss of 0.2284, cover loss of 0.3053, secret loss of 0.2596
# Training: Batch 78/1000. Loss of 0.2293, cover loss of 0.3189, secret loss of 0.2373
# Training: Batch 79/1000. Loss of 0.1850, cover loss of 0.2594, secret loss of 0.2142
# Training: Batch 80/1000. Loss of 0.2228, cover loss of 0.3087, secret loss of 0.2464
# Training: Batch 81/1000. Loss of 0.2097, cover loss of 0.3069, secret loss of 0.2166
# Training: Batch 82/1000. Loss of 0.2270, cover loss of 0.3363, secret loss of 0.2191
# Training: Batch 83/1000. Loss of 0.2071, cover loss of 0.3072, secret loss of 0.2174
# Training: Batch 84/1000. Loss of 0.2235, cover loss of 0.3140, secret loss of 0.2343
# Training: Batch 85/1000. Loss of 0.2229, cover loss of 0.3143, secret loss of 0.2293
# Training: Batch 86/1000. Loss of 0.2279, cover loss of 0.3383, secret loss of 0.2199
# Training: Batch 87/1000. Loss of 0.2219, cover loss of 0.3230, secret loss of 0.2211
# Training: Batch 88/1000. Loss of 0.2347, cover loss of 0.3234, secret loss of 0.2367
# Training: Batch 89/1000. Loss of 0.2063, cover loss of 0.2604, secret loss of 0.2605
# Training: Batch 90/1000. Loss of 0.2313, cover loss of 0.3455, secret loss of 0.2064
# Training: Batch 91/1000. Loss of 0.2225, cover loss of 0.3338, secret loss of 0.2198
# Training: Batch 92/1000. Loss of 0.2277, cover loss of 0.3362, secret loss of 0.2294
# Training: Batch 93/1000. Loss of 0.2231, cover loss of 0.3110, secret loss of 0.2414
# Training: Batch 94/1000. Loss of 0.2242, cover loss of 0.3011, secret loss of 0.2501
# Training: Batch 95/1000. Loss of 0.2063, cover loss of 0.3083, secret loss of 0.2102
# Training: Batch 96/1000. Loss of 0.2273, cover loss of 0.3017, secret loss of 0.2577
# Training: Batch 97/1000. Loss of 0.1927, cover loss of 0.2926, secret loss of 0.1991
# Training: Batch 98/1000. Loss of 0.2304, cover loss of 0.3210, secret loss of 0.2456
# Training: Batch 99/1000. Loss of 0.2224, cover loss of 0.2782, secret loss of 0.2733
# Training: Batch 100/1000. Loss of 0.2036, cover loss of 0.2771, secret loss of 0.2365
# Training: Batch 101/1000. Loss of 0.2414, cover loss of 0.3331, secret loss of 0.2487
# Training: Batch 102/1000. Loss of 0.2417, cover loss of 0.3139, secret loss of 0.2643
# Training: Batch 103/1000. Loss of 0.2065, cover loss of 0.2817, secret loss of 0.2395
# Training: Batch 104/1000. Loss of 0.2321, cover loss of 0.3383, secret loss of 0.2284
# Training: Batch 105/1000. Loss of 0.2211, cover loss of 0.3036, secret loss of 0.2492
# Training: Batch 106/1000. Loss of 0.2200, cover loss of 0.3080, secret loss of 0.2352
# Training: Batch 107/1000. Loss of 0.2231, cover loss of 0.3333, secret loss of 0.2210
# Training: Batch 108/1000. Loss of 0.2299, cover loss of 0.3243, secret loss of 0.2397
# Training: Batch 109/1000. Loss of 0.2344, cover loss of 0.3391, secret loss of 0.2319
# Training: Batch 110/1000. Loss of 0.1955, cover loss of 0.2829, secret loss of 0.2103
# Training: Batch 111/1000. Loss of 0.1891, cover loss of 0.2761, secret loss of 0.2042
# Training: Batch 112/1000. Loss of 0.2285, cover loss of 0.3159, secret loss of 0.2443
# Training: Batch 113/1000. Loss of 0.1987, cover loss of 0.2717, secret loss of 0.2220
# Training: Batch 114/1000. Loss of 0.2034, cover loss of 0.2774, secret loss of 0.2239
# Training: Batch 115/1000. Loss of 0.2301, cover loss of 0.3141, secret loss of 0.2523
# Training: Batch 116/1000. Loss of 0.2088, cover loss of 0.2922, secret loss of 0.2368
# Training: Batch 117/1000. Loss of 0.2251, cover loss of 0.3066, secret loss of 0.2470
# Training: Batch 118/1000. Loss of 0.2043, cover loss of 0.2637, secret loss of 0.2528
# Training: Batch 119/1000. Loss of 0.1997, cover loss of 0.2804, secret loss of 0.2252
# Training: Batch 120/1000. Loss of 0.2321, cover loss of 0.3368, secret loss of 0.2304
# Training: Batch 121/1000. Loss of 0.2356, cover loss of 0.3653, secret loss of 0.2061
# Training: Batch 122/1000. Loss of 0.2153, cover loss of 0.3055, secret loss of 0.2340
# Training: Batch 123/1000. Loss of 0.2043, cover loss of 0.3017, secret loss of 0.2060
# Training: Batch 124/1000. Loss of 0.2280, cover loss of 0.3223, secret loss of 0.2389
# Training: Batch 125/1000. Loss of 0.2396, cover loss of 0.3539, secret loss of 0.2249
# Training: Batch 126/1000. Loss of 0.2210, cover loss of 0.3286, secret loss of 0.2169
# Training: Batch 127/1000. Loss of 0.2386, cover loss of 0.3275, secret loss of 0.2501
# Training: Batch 128/1000. Loss of 0.1927, cover loss of 0.2785, secret loss of 0.2112
# Training: Batch 129/1000. Loss of 0.2008, cover loss of 0.2871, secret loss of 0.2232
# Training: Batch 130/1000. Loss of 0.2220, cover loss of 0.3079, secret loss of 0.2445
# Training: Batch 131/1000. Loss of 0.1851, cover loss of 0.2920, secret loss of 0.1845
# Training: Batch 132/1000. Loss of 0.2018, cover loss of 0.2753, secret loss of 0.2321
# Training: Batch 133/1000. Loss of 0.2072, cover loss of 0.3009, secret loss of 0.2219
# Training: Batch 134/1000. Loss of 0.2166, cover loss of 0.2955, secret loss of 0.2378
# Training: Batch 135/1000. Loss of 0.2217, cover loss of 0.3208, secret loss of 0.2200
# Training: Batch 136/1000. Loss of 0.1930, cover loss of 0.2768, secret loss of 0.2140
# Training: Batch 137/1000. Loss of 0.1965, cover loss of 0.2966, secret loss of 0.2017
# Training: Batch 138/1000. Loss of 0.2130, cover loss of 0.3151, secret loss of 0.2117
# Training: Batch 139/1000. Loss of 0.2141, cover loss of 0.3121, secret loss of 0.2161
# Training: Batch 140/1000. Loss of 0.2344, cover loss of 0.3462, secret loss of 0.2285
# Training: Batch 141/1000. Loss of 0.2161, cover loss of 0.3184, secret loss of 0.2201
# Training: Batch 142/1000. Loss of 0.2236, cover loss of 0.3276, secret loss of 0.2214
# Training: Batch 143/1000. Loss of 0.2091, cover loss of 0.3029, secret loss of 0.2188
# Training: Batch 144/1000. Loss of 0.2033, cover loss of 0.2917, secret loss of 0.2212
# Training: Batch 145/1000. Loss of 0.1898, cover loss of 0.2811, secret loss of 0.1992
# Training: Batch 146/1000. Loss of 0.2022, cover loss of 0.2781, secret loss of 0.2333
# Training: Batch 147/1000. Loss of 0.2088, cover loss of 0.3014, secret loss of 0.2106
# Training: Batch 148/1000. Loss of 0.2002, cover loss of 0.2753, secret loss of 0.2245
# Training: Batch 149/1000. Loss of 0.2262, cover loss of 0.3319, secret loss of 0.2190
# Training: Batch 150/1000. Loss of 0.2176, cover loss of 0.3004, secret loss of 0.2386
# Training: Batch 151/1000. Loss of 0.2151, cover loss of 0.2822, secret loss of 0.2516
# Training: Batch 152/1000. Loss of 0.2105, cover loss of 0.2830, secret loss of 0.2452
# Training: Batch 153/1000. Loss of 0.2482, cover loss of 0.3313, secret loss of 0.2571
# Training: Batch 154/1000. Loss of 0.1968, cover loss of 0.2578, secret loss of 0.2339
# Training: Batch 155/1000. Loss of 0.2455, cover loss of 0.3402, secret loss of 0.2485
# Training: Batch 156/1000. Loss of 0.2187, cover loss of 0.3142, secret loss of 0.2341
# Training: Batch 157/1000. Loss of 0.2349, cover loss of 0.3154, secret loss of 0.2641
# Training: Batch 158/1000. Loss of 0.2192, cover loss of 0.3297, secret loss of 0.2115
# Training: Batch 159/1000. Loss of 0.1937, cover loss of 0.2968, secret loss of 0.1934
# Training: Batch 160/1000. Loss of 0.2122, cover loss of 0.3344, secret loss of 0.1984
# Training: Batch 161/1000. Loss of 0.1966, cover loss of 0.2845, secret loss of 0.2190
# Training: Batch 162/1000. Loss of 0.2344, cover loss of 0.3318, secret loss of 0.2332
# Training: Batch 163/1000. Loss of 0.1896, cover loss of 0.2890, secret loss of 0.2019
# Training: Batch 164/1000. Loss of 0.2154, cover loss of 0.3036, secret loss of 0.2519
# Training: Batch 165/1000. Loss of 0.2296, cover loss of 0.3131, secret loss of 0.2659
# Training: Batch 166/1000. Loss of 0.2035, cover loss of 0.2618, secret loss of 0.2561
# Training: Batch 167/1000. Loss of 0.2012, cover loss of 0.2755, secret loss of 0.2298
# Training: Batch 168/1000. Loss of 0.1881, cover loss of 0.2846, secret loss of 0.2023
# Training: Batch 169/1000. Loss of 0.2077, cover loss of 0.2922, secret loss of 0.2334
# Training: Batch 170/1000. Loss of 0.2236, cover loss of 0.3083, secret loss of 0.2394
# Training: Batch 171/1000. Loss of 0.2075, cover loss of 0.2992, secret loss of 0.2275
# Training: Batch 172/1000. Loss of 0.2079, cover loss of 0.3269, secret loss of 0.1903
# Training: Batch 173/1000. Loss of 0.2165, cover loss of 0.3070, secret loss of 0.2296
# Training: Batch 174/1000. Loss of 0.2349, cover loss of 0.3467, secret loss of 0.2206
# Training: Batch 175/1000. Loss of 0.2260, cover loss of 0.3212, secret loss of 0.2413
# Training: Batch 176/1000. Loss of 0.2209, cover loss of 0.3167, secret loss of 0.2350
# Training: Batch 177/1000. Loss of 0.2179, cover loss of 0.3213, secret loss of 0.2068
# Training: Batch 178/1000. Loss of 0.2238, cover loss of 0.3167, secret loss of 0.2270
# Training: Batch 179/1000. Loss of 0.2289, cover loss of 0.3161, secret loss of 0.2377
# Training: Batch 180/1000. Loss of 0.2443, cover loss of 0.3382, secret loss of 0.2603
# Training: Batch 181/1000. Loss of 0.2324, cover loss of 0.3449, secret loss of 0.2185
# Training: Batch 182/1000. Loss of 0.2136, cover loss of 0.3255, secret loss of 0.2095
# Training: Batch 183/1000. Loss of 0.1971, cover loss of 0.2728, secret loss of 0.2243
# Training: Batch 184/1000. Loss of 0.2344, cover loss of 0.3381, secret loss of 0.2365
# Training: Batch 185/1000. Loss of 0.2131, cover loss of 0.3140, secret loss of 0.2180
# Training: Batch 186/1000. Loss of 0.2131, cover loss of 0.2963, secret loss of 0.2271
# Training: Batch 187/1000. Loss of 0.2077, cover loss of 0.2914, secret loss of 0.2363
# Training: Batch 188/1000. Loss of 0.2480, cover loss of 0.3324, secret loss of 0.2760
# Training: Batch 189/1000. Loss of 0.1940, cover loss of 0.2950, secret loss of 0.2045
# Training: Batch 190/1000. Loss of 0.2264, cover loss of 0.3208, secret loss of 0.2365
# Training: Batch 191/1000. Loss of 0.2248, cover loss of 0.3384, secret loss of 0.2185
# Training: Batch 192/1000. Loss of 0.2289, cover loss of 0.3220, secret loss of 0.2410
# Training: Batch 193/1000. Loss of 0.1960, cover loss of 0.2635, secret loss of 0.2313
# Training: Batch 194/1000. Loss of 0.2549, cover loss of 0.3774, secret loss of 0.2303
# Training: Batch 195/1000. Loss of 0.1931, cover loss of 0.3036, secret loss of 0.1876
# Training: Batch 196/1000. Loss of 0.2100, cover loss of 0.3109, secret loss of 0.2237
# Training: Batch 197/1000. Loss of 0.2261, cover loss of 0.3378, secret loss of 0.2213
# Training: Batch 198/1000. Loss of 0.2392, cover loss of 0.3398, secret loss of 0.2381
# Training: Batch 199/1000. Loss of 0.2196, cover loss of 0.3123, secret loss of 0.2444
# Training: Batch 200/1000. Loss of 0.2312, cover loss of 0.3209, secret loss of 0.2502
# Training: Batch 201/1000. Loss of 0.2048, cover loss of 0.3057, secret loss of 0.2108
# Training: Batch 202/1000. Loss of 0.1942, cover loss of 0.2896, secret loss of 0.2002
# Training: Batch 203/1000. Loss of 0.2502, cover loss of 0.3439, secret loss of 0.2699
# Training: Batch 204/1000. Loss of 0.2045, cover loss of 0.2806, secret loss of 0.2367
# Training: Batch 205/1000. Loss of 0.2359, cover loss of 0.3414, secret loss of 0.2322
# Training: Batch 206/1000. Loss of 0.1978, cover loss of 0.2611, secret loss of 0.2453
# Training: Batch 207/1000. Loss of 0.2348, cover loss of 0.3251, secret loss of 0.2491
# Training: Batch 208/1000. Loss of 0.2196, cover loss of 0.3074, secret loss of 0.2332
# Training: Batch 209/1000. Loss of 0.2295, cover loss of 0.3160, secret loss of 0.2680
# Training: Batch 210/1000. Loss of 0.2334, cover loss of 0.3305, secret loss of 0.2451
# Training: Batch 211/1000. Loss of 0.2216, cover loss of 0.3267, secret loss of 0.2212
# Training: Batch 212/1000. Loss of 0.2333, cover loss of 0.2872, secret loss of 0.2889
# Training: Batch 213/1000. Loss of 0.2134, cover loss of 0.2902, secret loss of 0.2425
# Training: Batch 214/1000. Loss of 0.2005, cover loss of 0.2801, secret loss of 0.2421
# Training: Batch 215/1000. Loss of 0.2684, cover loss of 0.3776, secret loss of 0.2622
# Training: Batch 216/1000. Loss of 0.2316, cover loss of 0.3335, secret loss of 0.2396
# Training: Batch 217/1000. Loss of 0.2218, cover loss of 0.2917, secret loss of 0.2517
# Training: Batch 218/1000. Loss of 0.1981, cover loss of 0.2826, secret loss of 0.2195
# Training: Batch 219/1000. Loss of 0.2440, cover loss of 0.3541, secret loss of 0.2414
# Training: Batch 220/1000. Loss of 0.2182, cover loss of 0.3140, secret loss of 0.2289
# Training: Batch 221/1000. Loss of 0.1987, cover loss of 0.2682, secret loss of 0.2400
# Training: Batch 222/1000. Loss of 0.2039, cover loss of 0.2961, secret loss of 0.2325
# Training: Batch 223/1000. Loss of 0.2298, cover loss of 0.3195, secret loss of 0.2456
# Training: Batch 224/1000. Loss of 0.2425, cover loss of 0.3748, secret loss of 0.2037
# Training: Batch 225/1000. Loss of 0.1926, cover loss of 0.2556, secret loss of 0.2431
# Training: Batch 226/1000. Loss of 0.2007, cover loss of 0.3095, secret loss of 0.2053
# Training: Batch 227/1000. Loss of 0.1931, cover loss of 0.2690, secret loss of 0.2206
# Training: Batch 228/1000. Loss of 0.2092, cover loss of 0.2841, secret loss of 0.2558
# Training: Batch 229/1000. Loss of 0.2166, cover loss of 0.2898, secret loss of 0.2447
# Training: Batch 230/1000. Loss of 0.2099, cover loss of 0.2961, secret loss of 0.2440
# Training: Batch 231/1000. Loss of 0.2176, cover loss of 0.2928, secret loss of 0.2524
# Training: Batch 232/1000. Loss of 0.2293, cover loss of 0.3134, secret loss of 0.2562
# Training: Batch 233/1000. Loss of 0.2582, cover loss of 0.3600, secret loss of 0.2556
# Training: Batch 234/1000. Loss of 0.2043, cover loss of 0.3016, secret loss of 0.2177
# Training: Batch 235/1000. Loss of 0.1880, cover loss of 0.2539, secret loss of 0.2317
# Training: Batch 236/1000. Loss of 0.2286, cover loss of 0.3088, secret loss of 0.2509
# Training: Batch 237/1000. Loss of 0.2140, cover loss of 0.3078, secret loss of 0.2276
# Training: Batch 238/1000. Loss of 0.2444, cover loss of 0.3393, secret loss of 0.2448
# Training: Batch 239/1000. Loss of 0.2136, cover loss of 0.3089, secret loss of 0.2183
# Training: Batch 240/1000. Loss of 0.2445, cover loss of 0.3601, secret loss of 0.2366
# Training: Batch 241/1000. Loss of 0.1989, cover loss of 0.2917, secret loss of 0.2067
# Training: Batch 242/1000. Loss of 0.2329, cover loss of 0.3288, secret loss of 0.2474
# Training: Batch 243/1000. Loss of 0.2113, cover loss of 0.3162, secret loss of 0.2111
# Training: Batch 244/1000. Loss of 0.2474, cover loss of 0.3301, secret loss of 0.2534
# Training: Batch 245/1000. Loss of 0.2194, cover loss of 0.3073, secret loss of 0.2384
# Training: Batch 246/1000. Loss of 0.2383, cover loss of 0.3523, secret loss of 0.2189
# Training: Batch 247/1000. Loss of 0.1985, cover loss of 0.2822, secret loss of 0.2176
# Training: Batch 248/1000. Loss of 0.2132, cover loss of 0.3001, secret loss of 0.2390
# Training: Batch 249/1000. Loss of 0.2042, cover loss of 0.3109, secret loss of 0.1996
# Training: Batch 250/1000. Loss of 0.2164, cover loss of 0.2910, secret loss of 0.2472
# Training: Batch 251/1000. Loss of 0.2092, cover loss of 0.3045, secret loss of 0.2140
# Training: Batch 252/1000. Loss of 0.1934, cover loss of 0.2754, secret loss of 0.2107
# Training: Batch 253/1000. Loss of 0.2215, cover loss of 0.3099, secret loss of 0.2354
# Training: Batch 254/1000. Loss of 0.2177, cover loss of 0.3039, secret loss of 0.2337
# Training: Batch 255/1000. Loss of 0.2038, cover loss of 0.3146, secret loss of 0.1954
# Training: Batch 256/1000. Loss of 0.2124, cover loss of 0.3147, secret loss of 0.2182
# Training: Batch 257/1000. Loss of 0.2065, cover loss of 0.3106, secret loss of 0.2027
# Training: Batch 258/1000. Loss of 0.2059, cover loss of 0.3044, secret loss of 0.2083
# Training: Batch 259/1000. Loss of 0.2425, cover loss of 0.3222, secret loss of 0.2506
# Training: Batch 260/1000. Loss of 0.2003, cover loss of 0.2651, secret loss of 0.2337
# Training: Batch 261/1000. Loss of 0.2217, cover loss of 0.3282, secret loss of 0.2134
# Training: Batch 262/1000. Loss of 0.2320, cover loss of 0.3293, secret loss of 0.2380
# Training: Batch 263/1000. Loss of 0.2328, cover loss of 0.3212, secret loss of 0.2424
# Training: Batch 264/1000. Loss of 0.2062, cover loss of 0.2637, secret loss of 0.2519
# Training: Batch 265/1000. Loss of 0.2421, cover loss of 0.3116, secret loss of 0.2750
# Training: Batch 266/1000. Loss of 0.2091, cover loss of 0.2934, secret loss of 0.2373
# Training: Batch 267/1000. Loss of 0.2260, cover loss of 0.3263, secret loss of 0.2209
# Training: Batch 268/1000. Loss of 0.2015, cover loss of 0.3176, secret loss of 0.1959
# Training: Batch 269/1000. Loss of 0.2450, cover loss of 0.3504, secret loss of 0.2386
# Training: Batch 270/1000. Loss of 0.2141, cover loss of 0.3206, secret loss of 0.2110
# Training: Batch 271/1000. Loss of 0.2353, cover loss of 0.3348, secret loss of 0.2303
# Training: Batch 272/1000. Loss of 0.2221, cover loss of 0.3257, secret loss of 0.2229
# Training: Batch 273/1000. Loss of 0.2369, cover loss of 0.3125, secret loss of 0.2683
# Training: Batch 274/1000. Loss of 0.2185, cover loss of 0.3399, secret loss of 0.1941
# Training: Batch 275/1000. Loss of 0.2099, cover loss of 0.3056, secret loss of 0.2180
# Training: Batch 276/1000. Loss of 0.2561, cover loss of 0.3612, secret loss of 0.2519
# Training: Batch 277/1000. Loss of 0.2328, cover loss of 0.3159, secret loss of 0.2458
# Training: Batch 278/1000. Loss of 0.2373, cover loss of 0.3520, secret loss of 0.2184
# Training: Batch 279/1000. Loss of 0.2265, cover loss of 0.3317, secret loss of 0.2298
# Training: Batch 280/1000. Loss of 0.2065, cover loss of 0.2795, secret loss of 0.2525
# Training: Batch 281/1000. Loss of 0.1871, cover loss of 0.2522, secret loss of 0.2388
# Training: Batch 282/1000. Loss of 0.2171, cover loss of 0.3211, secret loss of 0.1997
# Training: Batch 283/1000. Loss of 0.2237, cover loss of 0.2896, secret loss of 0.2672
# Training: Batch 284/1000. Loss of 0.2232, cover loss of 0.3142, secret loss of 0.2419
# Training: Batch 285/1000. Loss of 0.2215, cover loss of 0.3108, secret loss of 0.2411
# Training: Batch 286/1000. Loss of 0.2150, cover loss of 0.2992, secret loss of 0.2322
# Training: Batch 287/1000. Loss of 0.2022, cover loss of 0.2942, secret loss of 0.2062
# Training: Batch 288/1000. Loss of 0.1918, cover loss of 0.2825, secret loss of 0.2070
# Training: Batch 289/1000. Loss of 0.2393, cover loss of 0.3316, secret loss of 0.2434
# Training: Batch 290/1000. Loss of 0.2312, cover loss of 0.3320, secret loss of 0.2310
# Training: Batch 291/1000. Loss of 0.2143, cover loss of 0.3043, secret loss of 0.2263
# Training: Batch 292/1000. Loss of 0.2035, cover loss of 0.2861, secret loss of 0.2320
# Training: Batch 293/1000. Loss of 0.2222, cover loss of 0.3136, secret loss of 0.2346
# Training: Batch 294/1000. Loss of 0.2263, cover loss of 0.2952, secret loss of 0.2600
# Training: Batch 295/1000. Loss of 0.1950, cover loss of 0.2768, secret loss of 0.2051
# Training: Batch 296/1000. Loss of 0.1869, cover loss of 0.2848, secret loss of 0.1908
# Training: Batch 297/1000. Loss of 0.1938, cover loss of 0.2837, secret loss of 0.2243
# Training: Batch 298/1000. Loss of 0.2285, cover loss of 0.3125, secret loss of 0.2458
# Training: Batch 299/1000. Loss of 0.2018, cover loss of 0.2807, secret loss of 0.2225
# Training: Batch 300/1000. Loss of 0.2400, cover loss of 0.3575, secret loss of 0.2222
# Training: Batch 301/1000. Loss of 0.1910, cover loss of 0.2614, secret loss of 0.2272
# Training: Batch 302/1000. Loss of 0.2174, cover loss of 0.3016, secret loss of 0.2377
# Training: Batch 303/1000. Loss of 0.2216, cover loss of 0.3247, secret loss of 0.2169
# Training: Batch 304/1000. Loss of 0.2219, cover loss of 0.3089, secret loss of 0.2347
# Training: Batch 305/1000. Loss of 0.2128, cover loss of 0.3298, secret loss of 0.1973
# Training: Batch 306/1000. Loss of 0.2163, cover loss of 0.3309, secret loss of 0.2075
# Training: Batch 307/1000. Loss of 0.2217, cover loss of 0.3247, secret loss of 0.2288
# Training: Batch 308/1000. Loss of 0.2073, cover loss of 0.3096, secret loss of 0.2105
# Training: Batch 309/1000. Loss of 0.2065, cover loss of 0.3050, secret loss of 0.2082
# Training: Batch 310/1000. Loss of 0.2378, cover loss of 0.3252, secret loss of 0.2516
# Training: Batch 311/1000. Loss of 0.2117, cover loss of 0.3071, secret loss of 0.2127
# Training: Batch 312/1000. Loss of 0.2156, cover loss of 0.3223, secret loss of 0.2048
# Training: Batch 313/1000. Loss of 0.2249, cover loss of 0.3183, secret loss of 0.2329
# Training: Batch 314/1000. Loss of 0.2161, cover loss of 0.3312, secret loss of 0.2081
# Training: Batch 315/1000. Loss of 0.1824, cover loss of 0.2318, secret loss of 0.2330
# Training: Batch 316/1000. Loss of 0.2200, cover loss of 0.3275, secret loss of 0.2189
# Training: Batch 317/1000. Loss of 0.2057, cover loss of 0.2755, secret loss of 0.2459
# Training: Batch 318/1000. Loss of 0.2195, cover loss of 0.2902, secret loss of 0.2556
# Training: Batch 319/1000. Loss of 0.2372, cover loss of 0.3349, secret loss of 0.2369
# Training: Batch 320/1000. Loss of 0.2095, cover loss of 0.3141, secret loss of 0.2136
# Training: Batch 321/1000. Loss of 0.2378, cover loss of 0.3145, secret loss of 0.2812
# Training: Batch 322/1000. Loss of 0.2277, cover loss of 0.3474, secret loss of 0.2105
# Training: Batch 323/1000. Loss of 0.2365, cover loss of 0.3219, secret loss of 0.2521
# Training: Batch 324/1000. Loss of 0.2156, cover loss of 0.2961, secret loss of 0.2506
# Training: Batch 325/1000. Loss of 0.2233, cover loss of 0.2933, secret loss of 0.2688
# Training: Batch 326/1000. Loss of 0.2043, cover loss of 0.2914, secret loss of 0.2225
# Training: Batch 327/1000. Loss of 0.2078, cover loss of 0.2941, secret loss of 0.2400
# Training: Batch 328/1000. Loss of 0.2557, cover loss of 0.3700, secret loss of 0.2551
# Training: Batch 329/1000. Loss of 0.1934, cover loss of 0.3000, secret loss of 0.1920
# Training: Batch 330/1000. Loss of 0.2210, cover loss of 0.3065, secret loss of 0.2575
# Training: Batch 331/1000. Loss of 0.2256, cover loss of 0.2974, secret loss of 0.2697
# Training: Batch 332/1000. Loss of 0.2224, cover loss of 0.2873, secret loss of 0.2596
# Training: Batch 333/1000. Loss of 0.2373, cover loss of 0.3399, secret loss of 0.2571
# Training: Batch 334/1000. Loss of 0.2253, cover loss of 0.3352, secret loss of 0.2083
# Training: Batch 335/1000. Loss of 0.2073, cover loss of 0.2849, secret loss of 0.2508
# Training: Batch 336/1000. Loss of 0.2212, cover loss of 0.3093, secret loss of 0.2325
# Training: Batch 337/1000. Loss of 0.2083, cover loss of 0.2858, secret loss of 0.2307
# Training: Batch 338/1000. Loss of 0.2373, cover loss of 0.3226, secret loss of 0.2636
# Training: Batch 339/1000. Loss of 0.2410, cover loss of 0.3459, secret loss of 0.2390
# Training: Batch 340/1000. Loss of 0.2305, cover loss of 0.3232, secret loss of 0.2398
# Training: Batch 341/1000. Loss of 0.2694, cover loss of 0.3412, secret loss of 0.2897
# Training: Batch 342/1000. Loss of 0.1974, cover loss of 0.2985, secret loss of 0.1950
# Training: Batch 343/1000. Loss of 0.2174, cover loss of 0.3230, secret loss of 0.2197
# Training: Batch 344/1000. Loss of 0.2352, cover loss of 0.3271, secret loss of 0.2502
# Training: Batch 345/1000. Loss of 0.2173, cover loss of 0.2791, secret loss of 0.2542
# Training: Batch 346/1000. Loss of 0.2146, cover loss of 0.3050, secret loss of 0.2228
# Training: Batch 347/1000. Loss of 0.2320, cover loss of 0.3204, secret loss of 0.2417
# Training: Batch 348/1000. Loss of 0.2274, cover loss of 0.3130, secret loss of 0.2494
# Training: Batch 349/1000. Loss of 0.2056, cover loss of 0.2986, secret loss of 0.2148
# Training: Batch 350/1000. Loss of 0.2149, cover loss of 0.3071, secret loss of 0.2267
# Training: Batch 351/1000. Loss of 0.2087, cover loss of 0.2774, secret loss of 0.2483
# Training: Batch 352/1000. Loss of 0.2044, cover loss of 0.3017, secret loss of 0.2197
# Training: Batch 353/1000. Loss of 0.2330, cover loss of 0.3270, secret loss of 0.2367
# Training: Batch 354/1000. Loss of 0.2540, cover loss of 0.3633, secret loss of 0.2348
# Training: Batch 355/1000. Loss of 0.2354, cover loss of 0.2931, secret loss of 0.2933
# Training: Batch 356/1000. Loss of 0.2181, cover loss of 0.3260, secret loss of 0.2130
# Training: Batch 357/1000. Loss of 0.2374, cover loss of 0.3255, secret loss of 0.2520
# Training: Batch 358/1000. Loss of 0.2163, cover loss of 0.3232, secret loss of 0.2218
# Training: Batch 359/1000. Loss of 0.2039, cover loss of 0.2864, secret loss of 0.2265
# Training: Batch 360/1000. Loss of 0.2358, cover loss of 0.3090, secret loss of 0.2589
# Training: Batch 361/1000. Loss of 0.2063, cover loss of 0.2779, secret loss of 0.2507
# Training: Batch 362/1000. Loss of 0.2139, cover loss of 0.3100, secret loss of 0.2208
# Training: Batch 363/1000. Loss of 0.2172, cover loss of 0.3090, secret loss of 0.2233
# Training: Batch 364/1000. Loss of 0.2560, cover loss of 0.3668, secret loss of 0.2451
# Training: Batch 365/1000. Loss of 0.1880, cover loss of 0.2910, secret loss of 0.1922
# Training: Batch 366/1000. Loss of 0.2277, cover loss of 0.3073, secret loss of 0.2577
# Training: Batch 367/1000. Loss of 0.1968, cover loss of 0.2751, secret loss of 0.2288
# Training: Batch 368/1000. Loss of 0.2221, cover loss of 0.3073, secret loss of 0.2319
# Training: Batch 369/1000. Loss of 0.2411, cover loss of 0.3070, secret loss of 0.2811
# Training: Batch 370/1000. Loss of 0.2346, cover loss of 0.3383, secret loss of 0.2279
# Training: Batch 371/1000. Loss of 0.2292, cover loss of 0.3167, secret loss of 0.2505
# Training: Batch 372/1000. Loss of 0.2289, cover loss of 0.3374, secret loss of 0.2285
# Training: Batch 373/1000. Loss of 0.2401, cover loss of 0.3339, secret loss of 0.2419
# Training: Batch 374/1000. Loss of 0.2136, cover loss of 0.3158, secret loss of 0.2076
# Training: Batch 375/1000. Loss of 0.2154, cover loss of 0.2856, secret loss of 0.2598
# Training: Batch 376/1000. Loss of 0.2271, cover loss of 0.3356, secret loss of 0.2218
# Training: Batch 377/1000. Loss of 0.2330, cover loss of 0.3446, secret loss of 0.2294
# Training: Batch 378/1000. Loss of 0.2544, cover loss of 0.3578, secret loss of 0.2520
# Training: Batch 379/1000. Loss of 0.2136, cover loss of 0.2935, secret loss of 0.2444
# Training: Batch 380/1000. Loss of 0.2451, cover loss of 0.3129, secret loss of 0.2823
# Training: Batch 381/1000. Loss of 0.2149, cover loss of 0.3097, secret loss of 0.2237
# Training: Batch 382/1000. Loss of 0.2273, cover loss of 0.3223, secret loss of 0.2427
# Training: Batch 383/1000. Loss of 0.2112, cover loss of 0.2952, secret loss of 0.2426
# Training: Batch 384/1000. Loss of 0.2175, cover loss of 0.3239, secret loss of 0.2042
# Training: Batch 385/1000. Loss of 0.2225, cover loss of 0.2912, secret loss of 0.2603
# Training: Batch 386/1000. Loss of 0.2069, cover loss of 0.2984, secret loss of 0.2324
# Training: Batch 387/1000. Loss of 0.2200, cover loss of 0.3160, secret loss of 0.2142
# Training: Batch 388/1000. Loss of 0.2422, cover loss of 0.3342, secret loss of 0.2466
# Training: Batch 389/1000. Loss of 0.2117, cover loss of 0.3031, secret loss of 0.2347
# Training: Batch 390/1000. Loss of 0.2414, cover loss of 0.3445, secret loss of 0.2308
# Training: Batch 391/1000. Loss of 0.2446, cover loss of 0.3462, secret loss of 0.2398
# Training: Batch 392/1000. Loss of 0.2207, cover loss of 0.3165, secret loss of 0.2333
# Training: Batch 393/1000. Loss of 0.2242, cover loss of 0.3108, secret loss of 0.2410
# Training: Batch 394/1000. Loss of 0.2197, cover loss of 0.3343, secret loss of 0.2056
# Training: Batch 395/1000. Loss of 0.2401, cover loss of 0.3135, secret loss of 0.2855
# Training: Batch 396/1000. Loss of 0.2173, cover loss of 0.3100, secret loss of 0.2413
# Training: Batch 397/1000. Loss of 0.1884, cover loss of 0.2712, secret loss of 0.2131
# Training: Batch 398/1000. Loss of 0.2360, cover loss of 0.3361, secret loss of 0.2352
# Training: Batch 399/1000. Loss of 0.2448, cover loss of 0.3282, secret loss of 0.2745
# Training: Batch 400/1000. Loss of 0.2012, cover loss of 0.2918, secret loss of 0.2160
# Training: Batch 401/1000. Loss of 0.2249, cover loss of 0.2997, secret loss of 0.2525
# Training: Batch 402/1000. Loss of 0.2312, cover loss of 0.3104, secret loss of 0.2617
# Training: Batch 403/1000. Loss of 0.2464, cover loss of 0.3647, secret loss of 0.2409
# Training: Batch 404/1000. Loss of 0.1988, cover loss of 0.2906, secret loss of 0.2216
# Training: Batch 405/1000. Loss of 0.2080, cover loss of 0.3144, secret loss of 0.2065
# Training: Batch 406/1000. Loss of 0.2551, cover loss of 0.3629, secret loss of 0.2402
# Training: Batch 407/1000. Loss of 0.2379, cover loss of 0.3339, secret loss of 0.2486
# Training: Batch 408/1000. Loss of 0.2453, cover loss of 0.3601, secret loss of 0.2270
# Training: Batch 409/1000. Loss of 0.2372, cover loss of 0.3441, secret loss of 0.2414
# Training: Batch 410/1000. Loss of 0.2601, cover loss of 0.3557, secret loss of 0.2530
# Training: Batch 411/1000. Loss of 0.2489, cover loss of 0.3507, secret loss of 0.2537
# Training: Batch 412/1000. Loss of 0.1906, cover loss of 0.2727, secret loss of 0.2168
# Training: Batch 413/1000. Loss of 0.2254, cover loss of 0.3182, secret loss of 0.2385
# Training: Batch 414/1000. Loss of 0.2479, cover loss of 0.3604, secret loss of 0.2410
# Training: Batch 415/1000. Loss of 0.2070, cover loss of 0.3243, secret loss of 0.1938
# Training: Batch 416/1000. Loss of 0.1990, cover loss of 0.2934, secret loss of 0.2047
# Training: Batch 417/1000. Loss of 0.2357, cover loss of 0.3423, secret loss of 0.2428
# Training: Batch 418/1000. Loss of 0.2168, cover loss of 0.2991, secret loss of 0.2438
# Training: Batch 419/1000. Loss of 0.2169, cover loss of 0.3129, secret loss of 0.2230
# Training: Batch 420/1000. Loss of 0.2095, cover loss of 0.2968, secret loss of 0.2315
# Training: Batch 421/1000. Loss of 0.2097, cover loss of 0.3065, secret loss of 0.2191
# Training: Batch 422/1000. Loss of 0.2100, cover loss of 0.2975, secret loss of 0.2279
# Training: Batch 423/1000. Loss of 0.2389, cover loss of 0.3174, secret loss of 0.2642
# Training: Batch 424/1000. Loss of 0.2365, cover loss of 0.3296, secret loss of 0.2447
# Training: Batch 425/1000. Loss of 0.1869, cover loss of 0.2718, secret loss of 0.2045
# Training: Batch 426/1000. Loss of 0.2014, cover loss of 0.2765, secret loss of 0.2345
# Training: Batch 427/1000. Loss of 0.1862, cover loss of 0.2784, secret loss of 0.1969
# Training: Batch 428/1000. Loss of 0.1897, cover loss of 0.2759, secret loss of 0.2147
# Training: Batch 429/1000. Loss of 0.2076, cover loss of 0.2857, secret loss of 0.2370
# Training: Batch 430/1000. Loss of 0.1953, cover loss of 0.2978, secret loss of 0.2032
# Training: Batch 431/1000. Loss of 0.2291, cover loss of 0.3277, secret loss of 0.2259
# Training: Batch 432/1000. Loss of 0.1889, cover loss of 0.2851, secret loss of 0.1963
# Training: Batch 433/1000. Loss of 0.2210, cover loss of 0.2985, secret loss of 0.2424
# Training: Batch 434/1000. Loss of 0.2277, cover loss of 0.3214, secret loss of 0.2361
# Training: Batch 435/1000. Loss of 0.2486, cover loss of 0.3328, secret loss of 0.2623
# Training: Batch 436/1000. Loss of 0.2357, cover loss of 0.3367, secret loss of 0.2304
# Training: Batch 437/1000. Loss of 0.2308, cover loss of 0.3395, secret loss of 0.2267
# Training: Batch 438/1000. Loss of 0.2449, cover loss of 0.3618, secret loss of 0.2220
# Training: Batch 439/1000. Loss of 0.2144, cover loss of 0.2950, secret loss of 0.2458
# Training: Batch 440/1000. Loss of 0.1848, cover loss of 0.2710, secret loss of 0.2020
# Training: Batch 441/1000. Loss of 0.2115, cover loss of 0.3045, secret loss of 0.2262
# Training: Batch 442/1000. Loss of 0.2342, cover loss of 0.3308, secret loss of 0.2424
# Training: Batch 443/1000. Loss of 0.2384, cover loss of 0.3508, secret loss of 0.2326
# Training: Batch 444/1000. Loss of 0.2176, cover loss of 0.3143, secret loss of 0.2206
# Training: Batch 445/1000. Loss of 0.2085, cover loss of 0.2841, secret loss of 0.2385
# Training: Batch 446/1000. Loss of 0.2191, cover loss of 0.3184, secret loss of 0.2227
# Training: Batch 447/1000. Loss of 0.2056, cover loss of 0.2958, secret loss of 0.2160
# Training: Batch 448/1000. Loss of 0.2375, cover loss of 0.3224, secret loss of 0.2596
# Training: Batch 449/1000. Loss of 0.2199, cover loss of 0.3183, secret loss of 0.2324
# Training: Batch 450/1000. Loss of 0.2264, cover loss of 0.2786, secret loss of 0.2799
# Training: Batch 451/1000. Loss of 0.2476, cover loss of 0.3409, secret loss of 0.2499
# Training: Batch 452/1000. Loss of 0.2075, cover loss of 0.2976, secret loss of 0.2258
# Training: Batch 453/1000. Loss of 0.1978, cover loss of 0.2981, secret loss of 0.2074
# Training: Batch 454/1000. Loss of 0.2202, cover loss of 0.3235, secret loss of 0.2240
# Training: Batch 455/1000. Loss of 0.2042, cover loss of 0.2895, secret loss of 0.2268
# Training: Batch 456/1000. Loss of 0.2019, cover loss of 0.2889, secret loss of 0.2212
# Training: Batch 457/1000. Loss of 0.2219, cover loss of 0.3561, secret loss of 0.1879
# Training: Batch 458/1000. Loss of 0.2114, cover loss of 0.2987, secret loss of 0.2242
# Training: Batch 459/1000. Loss of 0.2089, cover loss of 0.3059, secret loss of 0.2074
# Training: Batch 460/1000. Loss of 0.1918, cover loss of 0.2908, secret loss of 0.1956
# Training: Batch 461/1000. Loss of 0.2099, cover loss of 0.2988, secret loss of 0.2257
# Training: Batch 462/1000. Loss of 0.1866, cover loss of 0.2755, secret loss of 0.2011
# Training: Batch 463/1000. Loss of 0.2279, cover loss of 0.3258, secret loss of 0.2292
# Training: Batch 464/1000. Loss of 0.2153, cover loss of 0.3051, secret loss of 0.2555
# Training: Batch 465/1000. Loss of 0.2502, cover loss of 0.3369, secret loss of 0.2885
# Training: Batch 466/1000. Loss of 0.2219, cover loss of 0.2971, secret loss of 0.2474
# Training: Batch 467/1000. Loss of 0.2275, cover loss of 0.3202, secret loss of 0.2538
# Training: Batch 468/1000. Loss of 0.2230, cover loss of 0.3173, secret loss of 0.2389
# Training: Batch 469/1000. Loss of 0.2337, cover loss of 0.3234, secret loss of 0.2553
# Training: Batch 470/1000. Loss of 0.2482, cover loss of 0.3187, secret loss of 0.2884
# Training: Batch 471/1000. Loss of 0.2332, cover loss of 0.3018, secret loss of 0.2680
# Training: Batch 472/1000. Loss of 0.2439, cover loss of 0.3449, secret loss of 0.2441
# Training: Batch 473/1000. Loss of 0.2112, cover loss of 0.2945, secret loss of 0.2356
# Training: Batch 474/1000. Loss of 0.2161, cover loss of 0.3048, secret loss of 0.2329
# Training: Batch 475/1000. Loss of 0.2124, cover loss of 0.2930, secret loss of 0.2447
# Training: Batch 476/1000. Loss of 0.2430, cover loss of 0.3355, secret loss of 0.2523
# Training: Batch 477/1000. Loss of 0.2376, cover loss of 0.3243, secret loss of 0.2468
# Training: Batch 478/1000. Loss of 0.2287, cover loss of 0.3275, secret loss of 0.2409
# Training: Batch 479/1000. Loss of 0.2172, cover loss of 0.3104, secret loss of 0.2285
# Training: Batch 480/1000. Loss of 0.2139, cover loss of 0.2855, secret loss of 0.2615
# Training: Batch 481/1000. Loss of 0.2137, cover loss of 0.2900, secret loss of 0.2410
# Training: Batch 482/1000. Loss of 0.2134, cover loss of 0.2836, secret loss of 0.2613
# Training: Batch 483/1000. Loss of 0.2525, cover loss of 0.3389, secret loss of 0.2770
# Training: Batch 484/1000. Loss of 0.2313, cover loss of 0.3117, secret loss of 0.2511
# Training: Batch 485/1000. Loss of 0.2171, cover loss of 0.2708, secret loss of 0.2663
# Training: Batch 486/1000. Loss of 0.2207, cover loss of 0.3065, secret loss of 0.2438
# Training: Batch 487/1000. Loss of 0.2394, cover loss of 0.3541, secret loss of 0.2286
# Training: Batch 488/1000. Loss of 0.2177, cover loss of 0.3194, secret loss of 0.2296
# Training: Batch 489/1000. Loss of 0.2117, cover loss of 0.2994, secret loss of 0.2252
# Training: Batch 490/1000. Loss of 0.2157, cover loss of 0.3020, secret loss of 0.2351
# Training: Batch 491/1000. Loss of 0.2559, cover loss of 0.3608, secret loss of 0.2527
# Training: Batch 492/1000. Loss of 0.1999, cover loss of 0.2795, secret loss of 0.2343
# Training: Batch 493/1000. Loss of 0.2256, cover loss of 0.3063, secret loss of 0.2531
# Training: Batch 494/1000. Loss of 0.2024, cover loss of 0.2847, secret loss of 0.2321
# Training: Batch 495/1000. Loss of 0.2442, cover loss of 0.3413, secret loss of 0.2509
# Training: Batch 496/1000. Loss of 0.2118, cover loss of 0.3137, secret loss of 0.2168
# Training: Batch 497/1000. Loss of 0.2120, cover loss of 0.2891, secret loss of 0.2414
# Training: Batch 498/1000. Loss of 0.2051, cover loss of 0.2915, secret loss of 0.2271
# Training: Batch 499/1000. Loss of 0.2107, cover loss of 0.2807, secret loss of 0.2514
# Training: Batch 500/1000. Loss of 0.2304, cover loss of 0.3324, secret loss of 0.2455
# Training: Batch 501/1000. Loss of 0.2467, cover loss of 0.3652, secret loss of 0.2356
# Training: Batch 502/1000. Loss of 0.2256, cover loss of 0.3357, secret loss of 0.2224
# Training: Batch 503/1000. Loss of 0.2133, cover loss of 0.2945, secret loss of 0.2510
# Training: Batch 504/1000. Loss of 0.2272, cover loss of 0.3174, secret loss of 0.2512
# Training: Batch 505/1000. Loss of 0.2023, cover loss of 0.2645, secret loss of 0.2577
# Training: Batch 506/1000. Loss of 0.2627, cover loss of 0.3451, secret loss of 0.2869
# Training: Batch 507/1000. Loss of 0.2189, cover loss of 0.2839, secret loss of 0.2658
# Training: Batch 508/1000. Loss of 0.2218, cover loss of 0.3148, secret loss of 0.2459
# Training: Batch 509/1000. Loss of 0.2151, cover loss of 0.3089, secret loss of 0.2194
# Training: Batch 510/1000. Loss of 0.2419, cover loss of 0.3337, secret loss of 0.2560
# Training: Batch 511/1000. Loss of 0.2139, cover loss of 0.3150, secret loss of 0.2154
# Training: Batch 512/1000. Loss of 0.2451, cover loss of 0.3783, secret loss of 0.2154
# Training: Batch 513/1000. Loss of 0.2061, cover loss of 0.2801, secret loss of 0.2445
# Training: Batch 514/1000. Loss of 0.2430, cover loss of 0.3483, secret loss of 0.2345
# Training: Batch 515/1000. Loss of 0.2082, cover loss of 0.2689, secret loss of 0.2620
# Training: Batch 516/1000. Loss of 0.2332, cover loss of 0.3287, secret loss of 0.2472
# Training: Batch 517/1000. Loss of 0.2283, cover loss of 0.3101, secret loss of 0.2548
# Training: Batch 518/1000. Loss of 0.2413, cover loss of 0.3553, secret loss of 0.2282
# Training: Batch 519/1000. Loss of 0.2038, cover loss of 0.2770, secret loss of 0.2412
# Training: Batch 520/1000. Loss of 0.2153, cover loss of 0.2919, secret loss of 0.2360
# Training: Batch 521/1000. Loss of 0.2224, cover loss of 0.3198, secret loss of 0.2281
# Training: Batch 522/1000. Loss of 0.2036, cover loss of 0.2784, secret loss of 0.2287
# Training: Batch 523/1000. Loss of 0.2004, cover loss of 0.3019, secret loss of 0.2058
# Training: Batch 524/1000. Loss of 0.2107, cover loss of 0.3021, secret loss of 0.2264
# Training: Batch 525/1000. Loss of 0.2369, cover loss of 0.3270, secret loss of 0.2510
# Training: Batch 526/1000. Loss of 0.2343, cover loss of 0.3111, secret loss of 0.2578
# Training: Batch 527/1000. Loss of 0.2119, cover loss of 0.2908, secret loss of 0.2360
# Training: Batch 528/1000. Loss of 0.2267, cover loss of 0.3193, secret loss of 0.2384
# Training: Batch 529/1000. Loss of 0.2058, cover loss of 0.3108, secret loss of 0.2051
# Training: Batch 530/1000. Loss of 0.2786, cover loss of 0.3993, secret loss of 0.2515
# Training: Batch 531/1000. Loss of 0.2233, cover loss of 0.3395, secret loss of 0.2079
# Training: Batch 532/1000. Loss of 0.2191, cover loss of 0.3229, secret loss of 0.2176
# Training: Batch 533/1000. Loss of 0.2176, cover loss of 0.3195, secret loss of 0.2261
# Training: Batch 534/1000. Loss of 0.2189, cover loss of 0.2819, secret loss of 0.2505
# Training: Batch 535/1000. Loss of 0.2248, cover loss of 0.3357, secret loss of 0.2211
# Training: Batch 536/1000. Loss of 0.1808, cover loss of 0.2702, secret loss of 0.2043
# Training: Batch 537/1000. Loss of 0.2140, cover loss of 0.3025, secret loss of 0.2250
# Training: Batch 538/1000. Loss of 0.2183, cover loss of 0.2883, secret loss of 0.2548
# Training: Batch 539/1000. Loss of 0.2443, cover loss of 0.3717, secret loss of 0.2180
# Training: Batch 540/1000. Loss of 0.2097, cover loss of 0.2713, secret loss of 0.2456
# Training: Batch 541/1000. Loss of 0.1876, cover loss of 0.2824, secret loss of 0.2065
# Training: Batch 542/1000. Loss of 0.1976, cover loss of 0.2824, secret loss of 0.2177
# Training: Batch 543/1000. Loss of 0.1984, cover loss of 0.2980, secret loss of 0.2042
# Training: Batch 544/1000. Loss of 0.2207, cover loss of 0.3090, secret loss of 0.2435
# Training: Batch 545/1000. Loss of 0.2091, cover loss of 0.2990, secret loss of 0.2235
# Training: Batch 546/1000. Loss of 0.2022, cover loss of 0.2995, secret loss of 0.2075
# Training: Batch 547/1000. Loss of 0.2141, cover loss of 0.3083, secret loss of 0.2276
# Training: Batch 548/1000. Loss of 0.2269, cover loss of 0.3135, secret loss of 0.2390
# Training: Batch 549/1000. Loss of 0.2065, cover loss of 0.2895, secret loss of 0.2256
# Training: Batch 550/1000. Loss of 0.2031, cover loss of 0.3231, secret loss of 0.1893
# Training: Batch 551/1000. Loss of 0.2311, cover loss of 0.3469, secret loss of 0.2113
# Training: Batch 552/1000. Loss of 0.2258, cover loss of 0.3351, secret loss of 0.2182
# Training: Batch 553/1000. Loss of 0.1936, cover loss of 0.2812, secret loss of 0.2092
# Training: Batch 554/1000. Loss of 0.2451, cover loss of 0.3166, secret loss of 0.2729
# Training: Batch 555/1000. Loss of 0.2626, cover loss of 0.3433, secret loss of 0.2855
# Training: Batch 556/1000. Loss of 0.2227, cover loss of 0.3188, secret loss of 0.2157
# Training: Batch 557/1000. Loss of 0.2260, cover loss of 0.3320, secret loss of 0.2320
# Training: Batch 558/1000. Loss of 0.2192, cover loss of 0.3180, secret loss of 0.2280
# Training: Batch 559/1000. Loss of 0.2126, cover loss of 0.3148, secret loss of 0.2206
# Training: Batch 560/1000. Loss of 0.2437, cover loss of 0.3503, secret loss of 0.2396
# Training: Batch 561/1000. Loss of 0.2279, cover loss of 0.3132, secret loss of 0.2494
# Training: Batch 562/1000. Loss of 0.2239, cover loss of 0.3240, secret loss of 0.2257
# ...
# Training: Batch 816/1000. Loss of 0.2079, cover loss of 0.2797, secret loss of 0.2351
# Training: Batch 817/1000. Loss of 0.2447, cover loss of 0.3467, secret loss of 0.2452
# Training: Batch 818/1000. Loss of 0.2323, cover loss of 0.3505, secret loss of 0.2208
# Training: Batch 819/1000. Loss of 0.2095, cover loss of 0.3106, secret loss of 0.2127
# Training: Batch 820/1000. Loss of 0.2275, cover loss of 0.3263, secret loss of 0.2296
# Training: Batch 821/1000. Loss of 0.2300, cover loss of 0.3165, secret loss of 0.2429
# Training: Batch 822/1000. Loss of 0.1931, cover loss of 0.2756, secret loss of 0.2105
# Training: Batch 823/1000. Loss of 0.1941, cover loss of 0.2924, secret loss of 0.2000
# Training: Batch 824/1000. Loss of 0.2243, cover loss of 0.3168, secret loss of 0.2276
# Training: Batch 825/1000. Loss of 0.2229, cover loss of 0.3040, secret loss of 0.2451
# Training: Batch 826/1000. Loss of 0.2439, cover loss of 0.3754, secret loss of 0.2059
# Training: Batch 827/1000. Loss of 0.2073, cover loss of 0.2983, secret loss of 0.2214
# Training: Batch 828/1000. Loss of 0.2125, cover loss of 0.2847, secret loss of 0.2500
# Training: Batch 829/1000. Loss of 0.2373, cover loss of 0.3369, secret loss of 0.2381
# Training: Batch 830/1000. Loss of 0.2243, cover loss of 0.3388, secret loss of 0.2189
# Training: Batch 831/1000. Loss of 0.2289, cover loss of 0.3189, secret loss of 0.2379
# Training: Batch 832/1000. Loss of 0.2217, cover loss of 0.3257, secret loss of 0.2207
# Training: Batch 833/1000. Loss of 0.2213, cover loss of 0.3173, secret loss of 0.2255
# Training: Batch 834/1000. Loss of 0.1992, cover loss of 0.2702, secret loss of 0.2288
# Training: Batch 835/1000. Loss of 0.1920, cover loss of 0.2828, secret loss of 0.2042
# Training: Batch 836/1000. Loss of 0.2232, cover loss of 0.3012, secret loss of 0.2518
# Training: Batch 837/1000. Loss of 0.2127, cover loss of 0.3137, secret loss of 0.2157
# Training: Batch 838/1000. Loss of 0.2372, cover loss of 0.3325, secret loss of 0.2320
# Training: Batch 839/1000. Loss of 0.1833, cover loss of 0.2739, secret loss of 0.1970
# Training: Batch 840/1000. Loss of 0.2315, cover loss of 0.3088, secret loss of 0.2683
# Training: Batch 841/1000. Loss of 0.2712, cover loss of 0.3660, secret loss of 0.2935
# Training: Batch 842/1000. Loss of 0.2009, cover loss of 0.2742, secret loss of 0.2323
# Training: Batch 843/1000. Loss of 0.2281, cover loss of 0.3277, secret loss of 0.2359
# Training: Batch 844/1000. Loss of 0.2551, cover loss of 0.3664, secret loss of 0.2767
# Training: Batch 845/1000. Loss of 0.2442, cover loss of 0.3181, secret loss of 0.2782
# Training: Batch 846/1000. Loss of 0.2265, cover loss of 0.3046, secret loss of 0.2723
# Training: Batch 847/1000. Loss of 0.2001, cover loss of 0.2561, secret loss of 0.2649
# Training: Batch 848/1000. Loss of 0.2106, cover loss of 0.3064, secret loss of 0.2187
# Training: Batch 849/1000. Loss of 0.2260, cover loss of 0.3192, secret loss of 0.2559
# Training: Batch 850/1000. Loss of 0.2195, cover loss of 0.2988, secret loss of 0.2392
# Training: Batch 851/1000. Loss of 0.2291, cover loss of 0.3508, secret loss of 0.2104
# Training: Batch 852/1000. Loss of 0.2025, cover loss of 0.2948, secret loss of 0.2221
# Training: Batch 853/1000. Loss of 0.2341, cover loss of 0.3254, secret loss of 0.2404
# Training: Batch 854/1000. Loss of 0.1987, cover loss of 0.2801, secret loss of 0.2280
# Training: Batch 855/1000. Loss of 0.2312, cover loss of 0.3269, secret loss of 0.2390
# Training: Batch 856/1000. Loss of 0.2206, cover loss of 0.3178, secret loss of 0.2316
# Training: Batch 857/1000. Loss of 0.2498, cover loss of 0.3799, secret loss of 0.2218
# Training: Batch 858/1000. Loss of 0.2295, cover loss of 0.3060, secret loss of 0.2647
# Training: Batch 859/1000. Loss of 0.2050, cover loss of 0.2928, secret loss of 0.2272
# Training: Batch 860/1000. Loss of 0.2544, cover loss of 0.3586, secret loss of 0.2589
# Training: Batch 861/1000. Loss of 0.2226, cover loss of 0.2832, secret loss of 0.2701
# Training: Batch 862/1000. Loss of 0.2300, cover loss of 0.3313, secret loss of 0.2244
# Training: Batch 863/1000. Loss of 0.2132, cover loss of 0.2936, secret loss of 0.2414
# Training: Batch 864/1000. Loss of 0.2258, cover loss of 0.3048, secret loss of 0.2502
# Training: Batch 865/1000. Loss of 0.2234, cover loss of 0.3097, secret loss of 0.2376
# Training: Batch 866/1000. Loss of 0.2028, cover loss of 0.2909, secret loss of 0.2271
# Training: Batch 867/1000. Loss of 0.1900, cover loss of 0.2924, secret loss of 0.1903
# Training: Batch 868/1000. Loss of 0.2015, cover loss of 0.2775, secret loss of 0.2311
# Training: Batch 869/1000. Loss of 0.2365, cover loss of 0.3323, secret loss of 0.2445
# Training: Batch 870/1000. Loss of 0.2212, cover loss of 0.3040, secret loss of 0.2421
# Training: Batch 871/1000. Loss of 0.2228, cover loss of 0.2937, secret loss of 0.2480
# Training: Batch 872/1000. Loss of 0.2267, cover loss of 0.3372, secret loss of 0.2151
# Training: Batch 873/1000. Loss of 0.1982, cover loss of 0.2761, secret loss of 0.2330
# Training: Batch 874/1000. Loss of 0.2286, cover loss of 0.3178, secret loss of 0.2544
# Training: Batch 875/1000. Loss of 0.2367, cover loss of 0.3604, secret loss of 0.2143
# Training: Batch 876/1000. Loss of 0.2331, cover loss of 0.3499, secret loss of 0.2057
# Training: Batch 877/1000. Loss of 0.2081, cover loss of 0.2799, secret loss of 0.2525
# Training: Batch 878/1000. Loss of 0.2213, cover loss of 0.3115, secret loss of 0.2182
# Training: Batch 879/1000. Loss of 0.2576, cover loss of 0.3673, secret loss of 0.2537
# Training: Batch 880/1000. Loss of 0.2332, cover loss of 0.3421, secret loss of 0.2299
# Training: Batch 881/1000. Loss of 0.1977, cover loss of 0.3007, secret loss of 0.1976
# Training: Batch 882/1000. Loss of 0.2195, cover loss of 0.3046, secret loss of 0.2392
# Training: Batch 883/1000. Loss of 0.2074, cover loss of 0.3099, secret loss of 0.2086
# Training: Batch 884/1000. Loss of 0.2224, cover loss of 0.3200, secret loss of 0.2308
# Training: Batch 885/1000. Loss of 0.1940, cover loss of 0.2776, secret loss of 0.2138
# Training: Batch 886/1000. Loss of 0.2357, cover loss of 0.3165, secret loss of 0.2601
# Training: Batch 887/1000. Loss of 0.2234, cover loss of 0.3119, secret loss of 0.2355
# Training: Batch 888/1000. Loss of 0.2260, cover loss of 0.3139, secret loss of 0.2497
# Training: Batch 889/1000. Loss of 0.2066, cover loss of 0.3011, secret loss of 0.2244
# Training: Batch 890/1000. Loss of 0.2308, cover loss of 0.3248, secret loss of 0.2435
# Training: Batch 891/1000. Loss of 0.2587, cover loss of 0.3273, secret loss of 0.2959
# Training: Batch 892/1000. Loss of 0.1873, cover loss of 0.2633, secret loss of 0.2140
# Training: Batch 893/1000. Loss of 0.2182, cover loss of 0.3045, secret loss of 0.2510
# Training: Batch 894/1000. Loss of 0.2525, cover loss of 0.3468, secret loss of 0.2566
# Training: Batch 895/1000. Loss of 0.2354, cover loss of 0.3270, secret loss of 0.2584
# Training: Batch 896/1000. Loss of 0.2236, cover loss of 0.3069, secret loss of 0.2546
# Training: Batch 897/1000. Loss of 0.2077, cover loss of 0.3118, secret loss of 0.2157
# Training: Batch 898/1000. Loss of 0.2351, cover loss of 0.3396, secret loss of 0.2651
# Training: Batch 899/1000. Loss of 0.2369, cover loss of 0.3462, secret loss of 0.2316
# Training: Batch 900/1000. Loss of 0.2595, cover loss of 0.3321, secret loss of 0.3143
# Training: Batch 901/1000. Loss of 0.2289, cover loss of 0.3253, secret loss of 0.2367
# Training: Batch 902/1000. Loss of 0.2361, cover loss of 0.3428, secret loss of 0.2461
# Training: Batch 903/1000. Loss of 0.2167, cover loss of 0.2983, secret loss of 0.2458
# Training: Batch 904/1000. Loss of 0.2104, cover loss of 0.2829, secret loss of 0.2687
# Training: Batch 905/1000. Loss of 0.2195, cover loss of 0.3226, secret loss of 0.2240
# Training: Batch 906/1000. Loss of 0.2308, cover loss of 0.3143, secret loss of 0.2717
# Training: Batch 907/1000. Loss of 0.2367, cover loss of 0.3349, secret loss of 0.2466
# Training: Batch 908/1000. Loss of 0.2142, cover loss of 0.3254, secret loss of 0.2142
# Training: Batch 909/1000. Loss of 0.2300, cover loss of 0.3333, secret loss of 0.2328
# Training: Batch 910/1000. Loss of 0.2030, cover loss of 0.2789, secret loss of 0.2339
# Training: Batch 911/1000. Loss of 0.2294, cover loss of 0.3239, secret loss of 0.2374
# Training: Batch 912/1000. Loss of 0.2088, cover loss of 0.2921, secret loss of 0.2315
# Training: Batch 913/1000. Loss of 0.2418, cover loss of 0.3417, secret loss of 0.2383
# Training: Batch 914/1000. Loss of 0.2058, cover loss of 0.2914, secret loss of 0.2206
# Training: Batch 915/1000. Loss of 0.2149, cover loss of 0.3231, secret loss of 0.2110
# Training: Batch 916/1000. Loss of 0.2082, cover loss of 0.3015, secret loss of 0.2221
# Training: Batch 917/1000. Loss of 0.2021, cover loss of 0.3074, secret loss of 0.2033
# Training: Batch 918/1000. Loss of 0.2222, cover loss of 0.3216, secret loss of 0.2389
# Training: Batch 919/1000. Loss of 0.2225, cover loss of 0.3314, secret loss of 0.2250
# Training: Batch 920/1000. Loss of 0.2136, cover loss of 0.2940, secret loss of 0.2325
# Training: Batch 921/1000. Loss of 0.1960, cover loss of 0.2457, secret loss of 0.2440
# Training: Batch 922/1000. Loss of 0.2224, cover loss of 0.3048, secret loss of 0.2371
# Training: Batch 923/1000. Loss of 0.2003, cover loss of 0.2830, secret loss of 0.2327
# Training: Batch 924/1000. Loss of 0.2076, cover loss of 0.2971, secret loss of 0.2252
# Training: Batch 925/1000. Loss of 0.2237, cover loss of 0.3199, secret loss of 0.2295
# Training: Batch 926/1000. Loss of 0.2054, cover loss of 0.2951, secret loss of 0.2225
# Training: Batch 927/1000. Loss of 0.2068, cover loss of 0.3112, secret loss of 0.2075
# Training: Batch 928/1000. Loss of 0.1999, cover loss of 0.2894, secret loss of 0.2165
# Training: Batch 929/1000. Loss of 0.2357, cover loss of 0.3334, secret loss of 0.2488
# Training: Batch 930/1000. Loss of 0.2216, cover loss of 0.3041, secret loss of 0.2435
# Training: Batch 931/1000. Loss of 0.2542, cover loss of 0.3691, secret loss of 0.2263
# Training: Batch 932/1000. Loss of 0.2323, cover loss of 0.3448, secret loss of 0.2292
# Training: Batch 933/1000. Loss of 0.2215, cover loss of 0.3158, secret loss of 0.2298
# Training: Batch 934/1000. Loss of 0.2137, cover loss of 0.3167, secret loss of 0.2227
# Training: Batch 935/1000. Loss of 0.2220, cover loss of 0.2938, secret loss of 0.2554
# Training: Batch 936/1000. Loss of 0.2187, cover loss of 0.3059, secret loss of 0.2382
# Training: Batch 937/1000. Loss of 0.2215, cover loss of 0.3247, secret loss of 0.2150
# Training: Batch 938/1000. Loss of 0.1919, cover loss of 0.2670, secret loss of 0.2200
# Training: Batch 939/1000. Loss of 0.2283, cover loss of 0.3544, secret loss of 0.2035
# Training: Batch 940/1000. Loss of 0.2270, cover loss of 0.3198, secret loss of 0.2309
# Training: Batch 941/1000. Loss of 0.2173, cover loss of 0.3065, secret loss of 0.2307
# Training: Batch 942/1000. Loss of 0.2368, cover loss of 0.3308, secret loss of 0.2475
# Training: Batch 943/1000. Loss of 0.2175, cover loss of 0.3166, secret loss of 0.2186
# Training: Batch 944/1000. Loss of 0.2120, cover loss of 0.2943, secret loss of 0.2369
# Training: Batch 945/1000. Loss of 0.2261, cover loss of 0.3022, secret loss of 0.2465
# Training: Batch 946/1000. Loss of 0.2091, cover loss of 0.2981, secret loss of 0.2302
# Training: Batch 947/1000. Loss of 0.2148, cover loss of 0.2953, secret loss of 0.2384
# Training: Batch 948/1000. Loss of 0.2220, cover loss of 0.3414, secret loss of 0.2052
# Training: Batch 949/1000. Loss of 0.1969, cover loss of 0.2722, secret loss of 0.2278
# Training: Batch 950/1000. Loss of 0.1999, cover loss of 0.2782, secret loss of 0.2281
# Training: Batch 951/1000. Loss of 0.2262, cover loss of 0.3264, secret loss of 0.2305
# Training: Batch 952/1000. Loss of 0.2044, cover loss of 0.2836, secret loss of 0.2371
# Training: Batch 953/1000. Loss of 0.2439, cover loss of 0.3721, secret loss of 0.2195
# Training: Batch 954/1000. Loss of 0.2427, cover loss of 0.3438, secret loss of 0.2436
# Training: Batch 955/1000. Loss of 0.1946, cover loss of 0.2977, secret loss of 0.1871
# Training: Batch 956/1000. Loss of 0.2268, cover loss of 0.3194, secret loss of 0.2345
# Training: Batch 957/1000. Loss of 0.2206, cover loss of 0.3190, secret loss of 0.2313
# Training: Batch 958/1000. Loss of 0.1761, cover loss of 0.2694, secret loss of 0.1892
# Training: Batch 959/1000. Loss of 0.2504, cover loss of 0.3570, secret loss of 0.2430
# Training: Batch 960/1000. Loss of 0.2031, cover loss of 0.3137, secret loss of 0.1892
# Training: Batch 961/1000. Loss of 0.1899, cover loss of 0.2641, secret loss of 0.2219
# Training: Batch 962/1000. Loss of 0.1851, cover loss of 0.2676, secret loss of 0.2060
# Training: Batch 963/1000. Loss of 0.1980, cover loss of 0.2905, secret loss of 0.2132
# Training: Batch 964/1000. Loss of 0.2257, cover loss of 0.2993, secret loss of 0.2463
# Training: Batch 965/1000. Loss of 0.2173, cover loss of 0.3361, secret loss of 0.2052
# Training: Batch 966/1000. Loss of 0.1976, cover loss of 0.2958, secret loss of 0.2050
# Training: Batch 967/1000. Loss of 0.2009, cover loss of 0.2869, secret loss of 0.2291
# Training: Batch 968/1000. Loss of 0.2302, cover loss of 0.2845, secret loss of 0.2845
# Training: Batch 969/1000. Loss of 0.2389, cover loss of 0.3246, secret loss of 0.2578
# Training: Batch 970/1000. Loss of 0.2102, cover loss of 0.3058, secret loss of 0.2237
# Training: Batch 971/1000. Loss of 0.2328, cover loss of 0.3333, secret loss of 0.2350
# Training: Batch 972/1000. Loss of 0.2446, cover loss of 0.3239, secret loss of 0.2763
# Training: Batch 973/1000. Loss of 0.2067, cover loss of 0.2911, secret loss of 0.2338
# Training: Batch 974/1000. Loss of 0.2352, cover loss of 0.3629, secret loss of 0.2110
# Training: Batch 975/1000. Loss of 0.1996, cover loss of 0.2931, secret loss of 0.2144
# Training: Batch 976/1000. Loss of 0.2507, cover loss of 0.3619, secret loss of 0.2453
# Training: Batch 977/1000. Loss of 0.2318, cover loss of 0.3284, secret loss of 0.2457
# Training: Batch 978/1000. Loss of 0.2247, cover loss of 0.3119, secret loss of 0.2417
# Training: Batch 979/1000. Loss of 0.2190, cover loss of 0.2970, secret loss of 0.2442
# Training: Batch 980/1000. Loss of 0.1917, cover loss of 0.2625, secret loss of 0.2270
# Training: Batch 981/1000. Loss of 0.2147, cover loss of 0.3091, secret loss of 0.2291
# Training: Batch 982/1000. Loss of 0.2176, cover loss of 0.3101, secret loss of 0.2313
# Training: Batch 983/1000. Loss of 0.2360, cover loss of 0.3372, secret loss of 0.2381
# Training: Batch 984/1000. Loss of 0.2105, cover loss of 0.3007, secret loss of 0.2286
# Training: Batch 985/1000. Loss of 0.2508, cover loss of 0.3628, secret loss of 0.2494
# Training: Batch 986/1000. Loss of 0.2117, cover loss of 0.3205, secret loss of 0.2103
# Training: Batch 987/1000. Loss of 0.2342, cover loss of 0.3508, secret loss of 0.2153
# Training: Batch 988/1000. Loss of 0.2525, cover loss of 0.3507, secret loss of 0.2479
# Training: Batch 989/1000. Loss of 0.2187, cover loss of 0.3008, secret loss of 0.2450
# Training: Batch 990/1000. Loss of 0.1686, cover loss of 0.2580, secret loss of 0.1816
# Training: Batch 991/1000. Loss of 0.2306, cover loss of 0.3320, secret loss of 0.2383
# Training: Batch 992/1000. Loss of 0.2118, cover loss of 0.3025, secret loss of 0.2198
# Training: Batch 993/1000. Loss of 0.2106, cover loss of 0.3026, secret loss of 0.2307
# Training: Batch 994/1000. Loss of 0.2248, cover loss of 0.3541, secret loss of 0.2012
# Training: Batch 995/1000. Loss of 0.2158, cover loss of 0.3133, secret loss of 0.2260
# Training: Batch 996/1000. Loss of 0.2246, cover loss of 0.3349, secret loss of 0.2168
# Training: Batch 997/1000. Loss of 0.2233, cover loss of 0.3218, secret loss of 0.2293
# Training: Batch 998/1000. Loss of 0.1849, cover loss of 0.2734, secret loss of 0.2023
# Training: Batch 999/1000. Loss of 0.1998, cover loss of 0.2726, secret loss of 0.2285
# Training: Batch 1000/1000. Loss of 0.1926, cover loss of 0.2906, secret loss of 0.1968
# Epoch [50/50], Average_loss: 0.2191

# %%
 # Plot loss through epochs
plt.plot(loss_history)
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Batch')
plt.show()

# %%
def pixel_errors(input_S, input_C, decoded_S, decoded_C):
    """Calculates mean of Sum of Squared Errors per pixel for cover and secret images. """
    input_S = np.array(input_S.detach().cpu())
    input_C = np.array(input_C.detach().cpu())
    decoded_S = np.array(decoded_S.detach().cpu())
    decoded_C = np.array(decoded_C.detach().cpu())
    # print(input_S)
    see_Spixel = np.sqrt(np.mean(np.square(255*(input_S - decoded_S))))
    see_Cpixel = np.sqrt(np.mean(np.square(255*(input_C - decoded_C))))
    
    return see_Spixel, see_Cpixel

import math
def psnr(input_S, input_C, decoded_S, decoded_C):
    input_S = np.array(input_S.detach().cpu())
    input_C = np.array(input_C.detach().cpu())
    decoded_S = np.array(decoded_S.detach().cpu())
    decoded_C = np.array(decoded_C.detach().cpu())
    mse_s = np.mean(np.square(255*(input_S - decoded_S)))
    mse_c = np.mean(np.square(255*(input_C - decoded_C)))
    psnr_s = 10*math.log10(255**2/mse_s)
    psnr_c = 10*math.log10(255**2/mse_c)
    return psnr_s, psnr_c

def pixel_histogram(diff_S, diff_C):
    """Calculates histograms of errors for cover and secret image. """
    diff_Sflat = diff_S.flatten()
    diff_Cflat = diff_C.flatten()
    
    fig = plt.figure(figsize=(15, 5))
    a=fig.add_subplot(1,2,1)
        
    imgplot = plt.hist(255* diff_Cflat, 100, density=1, alpha=0.75, facecolor='red')
    a.set_title('Distribution of error in the Cover image.')
    plt.axis([0, 250, 0, 0.2])
    
    a=fig.add_subplot(1,2,2)
    imgplot = plt.hist(255* diff_Sflat, 100, density=1, alpha=0.75, facecolor='red')
    a.set_title('Distribution of errors in the Secret image.')
    plt.axis([0, 250, 0, 0.2])
    
    plt.show()

# %%
# net.load_state_dict(torch.load(MODELS_PATH+'Epoch N4.pkl'))

# Switch to evaluate mode
net.eval()
Path(PATH+"LOSS2_1_ds_img_10").mkdir(parents=True, exist_ok=True)
Path(PATH+"LOSS2_1_ds_img_10/cover_images/").mkdir(parents=True, exist_ok=True)
Path(PATH+"LOSS2_1_ds_img_10/container_images/").mkdir(parents=True, exist_ok=True)
save_path = PATH+"LOSS2_1_ds_img_10/"

test_losses = []

S_errors = []
C_errors = []

psnr_s,psnr_c = [], []
# Show images
for idx, test_batch in enumerate(test_loader):
     # Saves images
    data, _ = test_batch
    data = data.to(device)

    # Saves secret images and secret covers
    test_secret = data[:len(data)//2]
    test_cover = data[len(data)//2:]

    # Creates variable from secret and cover images
    test_secret = Variable(test_secret, volatile=True)
    test_cover = Variable(test_cover, volatile=True)

    # Compute output
    test_hidden, test_output = net(test_secret, test_cover)
    
    # Calculate loss
    test_loss, loss_cover, loss_secret = customized_loss(test_output, test_hidden, test_secret, test_cover, beta)
    
    diff_S, diff_C = np.abs(np.array(test_output.data.detach().cpu()) - np.array(test_secret.data.detach().cpu())), np.abs(np.array(test_hidden.data.detach().cpu()) - np.array(test_cover.data.detach().cpu()))
    
#     print (diff_S, diff_C)

    # Print pixel-wise average errors in a 256 scale.
    S_error, C_error = pixel_errors(test_secret, test_cover, test_output, test_hidden)
    S_errors.append(S_error)
    C_errors.append(C_error)

    S_psnr, C_psnr = psnr(test_secret, test_cover, test_output, test_hidden)
    psnr_s.append(S_psnr)
    psnr_c.append(C_psnr)
    
    if idx in [1,2,3,4]:
        print ('Total loss: {:.2f} \nLoss on secret: {:.2f} \nLoss on cover: {:.2f}'.format(test_loss.data.item(), loss_secret.data.item(), loss_cover.data.item()))

        # Creates img tensor
        imgs = [test_secret.data.detach().cpu(), test_output.data.detach().cpu(), test_cover.data.detach().cpu(), test_hidden.data.detach().cpu()]
        imgs_tsor = torch.cat(imgs, 0)

        # Prints Images
        imshow(utils.make_grid(imgs_tsor), idx+1, learning_rate=learning_rate, beta=beta)

    if idx < 500:
        container_img = tensor_to_image(test_hidden.data.detach().cpu())
        container_img = Image.fromarray(container_img)
        container_img.save(save_path+"container_images/"+str(idx)+".jpeg")
        cover_img = tensor_to_image(test_cover.data.detach().cpu())
        cover_img = Image.fromarray(cover_img)
        cover_img.save(save_path+"cover_images/"+str(idx)+".jpeg")
            
    test_losses.append(test_loss.data.item())
        
mean_test_loss = np.mean(test_losses)

print ('Average loss on test set: {:.2f}'.format(mean_test_loss))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:27: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:43: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Total loss: 0.28
# Loss on secret: 0.26
# Loss on cover: 0.40
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Total loss: 0.17
# Loss on secret: 0.25
# Loss on cover: 0.21
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Total loss: 0.16
# Loss on secret: 0.25
# Loss on cover: 0.18
# Total loss: 0.23
# Loss on secret: 0.25
# Loss on cover: 0.33
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Average loss on test set: 0.24

# %%
print ("Avg. S error per pixel [0, 255]:", sum(S_errors)/len(S_errors))
print ("Avg. C error per pixel [0, 255]:", sum(C_errors)/len(C_errors))
# Out:
# Avg. S error per pixel [0, 255]: 91.69240931015014
# Avg. C error per pixel [0, 255]: 120.50250101394653

# %%
print ("Avg. PSNR of secret and decoded secret:", sum(psnr_s)/len(psnr_s))
print ("Avg. PSNR of cover and container:", sum(psnr_c)/len(psnr_c))
# Out:
# Avg. PSNR of secret and decoded secret: 9.235525103286458
# Avg. PSNR of cover and container: 6.859783762341556

# %%
# Plot distribution of errors in cover and secret images.
pixel_histogram(diff_S, diff_C)
