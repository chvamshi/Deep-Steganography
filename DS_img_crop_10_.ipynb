# %% [markdown]
# <a href="https://colab.research.google.com/github/chvamshi/Deep-Steganography/blob/main/DS_img_crop_10_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget http://cs231n.stanford.edu/tiny-imagenet-200.zip
# !unzip -q tiny-imagenet-200.zip && ls tiny-imagenet-200
# Out:
# --2022-02-03 18:27:56--  http://cs231n.stanford.edu/tiny-imagenet-200.zip
# Resolving cs231n.stanford.edu (cs231n.stanford.edu)... 171.64.68.10
# Connecting to cs231n.stanford.edu (cs231n.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248100043 (237M) [application/zip]
# Saving to: ‘tiny-imagenet-200.zip’
#
# tiny-imagenet-200.z 100%[===================>] 236.61M  77.0MB/s    in 3.1s
#
# 2022-02-03 18:27:59 (77.0 MB/s) - ‘tiny-imagenet-200.zip’ saved [248100043/248100043]
#
# test  train  val  wnids.txt  words.txt

# %%
# Imports necessary libraries and modules
from itertools import islice
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch.autograd import Variable
from torch import utils
from torch.utils.data import Subset
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import os 
from pathlib import Path
import pickle
import random
from torchvision import datasets, utils
import torchvision.transforms as transforms
from torchvision.transforms import ToPILImage
from torchvision.transforms import RandomResizedCrop
from torchvision.transforms.functional import resized_crop
from random import shuffle
from IPython.display import Image
from PIL import Image

# Use GPU if it is present
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
# Directory path
# os.chdir("..")
cwd = '/content/tiny-imagenet-200'

# Hyper Parameters
num_epochs = 50
batch_size = 32
learning_rate = 0.001
beta = 1

# Mean and std deviation of imagenet dataset. Source: http://cs231n.stanford.edu/reports/2017/pdfs/101.pdf
std = [0.229, 0.224, 0.225]
mean = [0.485, 0.456, 0.406]

# TODO: Define train, validation and models
MODELS_PATH = '/content/output/models'
# TRAIN_PATH = cwd+'/train/'
# VALID_PATH = cwd+'/valid/'
VALID_PATH = cwd+'/val/'
TRAIN_PATH = cwd+'/train/'
TEST_PATH = cwd+'/test/'

# if not os.path.exists(MODELS_PATH): os.mkdir(MODELS_PATH)

# %%
def variance(image1, image2):
    var1 = torch.var(image1)
    var2 = torch.var(image2)

    return var1+var2

def customized_loss(S_prime, C_prime, S, C, B):
    ''' Calculates loss specified on the paper.'''
    
    loss_cover = torch.nn.functional.l1_loss(C_prime, C)
    loss_cover = loss_cover/(64*64)
    loss_secret = torch.nn.functional.l1_loss(S_prime, S)
    loss_secret = loss_secret/(64*64)

    variance_cover = variance(C_prime, C)
    variance_secret = variance(S_prime, S)

    loss_all = loss_cover+loss_secret+variance_cover+variance_secret
    loss_all = loss_all/4

    return loss_all, loss_cover, loss_secret

def denormalize(image, std, mean):
    ''' Denormalizes a tensor of images.'''

    for t in range(3):
        image[t, :, :] = (image[t, :, :] * std[t]) + mean[t]
    return image

def imshow(img, idx, learning_rate, beta):
    '''Prints out an image given in tensor format.'''
    
    img = denormalize(img, std, mean)
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.title('Example '+str(idx)+', lr='+str(learning_rate)+', B='+str(beta))
    plt.show()
    return

def gaussian(tensor, mean=0, stddev=0.1):
    '''Adds random noise to a tensor.'''
    
    noise = torch.nn.init.normal(torch.Tensor(tensor.size()), 0, 0.1).to(device)
    return Variable(tensor + noise)

def tensor_to_image(tensor):
    """
    Transforms a torch tensor into numpy uint8 array (image)
    :param tensor: (batch_size x channels x height x width) torch tensor in range [-1.0, 1.0]
    :return: (batch_size x height x width x channels) uint8 array
    """
    image = tensor.cpu().numpy()[0]
    # image = tensor.permute(0, 2, 3, 1).cpu().numpy()
    image = np.transpose(image, (1,2,0))
    image = (image + 1) * 127.5
    return np.clip(image, 0, 255).astype(np.uint8)

# %%
import torch.nn as nn
import numpy as np

def random_float(min, max):
    """
    Return a random number
    :param min:
    :param max:
    :return:
    """
    return np.random.rand() * (max - min) + min


def get_random_rectangle_inside(image, height_ratio_range, width_ratio_range):
    """
    Returns a random rectangle inside the image, where the size is random and is controlled by height_ratio_range and width_ratio_range.
    This is analogous to a random crop. For example, if height_ratio_range is (0.7, 0.9), then a random number in that range will be chosen
    (say it is 0.75 for illustration), and the image will be cropped such that the remaining height equals 0.75. In fact,
    a random 'starting' position rs will be chosen from (0, 0.25), and the crop will start at rs and end at rs + 0.75. This ensures
    that we crop from top/bottom with equal probability.
    The same logic applies to the width of the image, where width_ratio_range controls the width crop range.
    :param image: The image we want to crop
    :param height_ratio_range: The range of remaining height ratio
    :param width_ratio_range:  The range of remaining width ratio.
    :return: "Cropped" rectange with width and height drawn randomly height_ratio_range and width_ratio_range
    """
    # print(image.shape)
    image_height = image.shape[1]
    image_width = image.shape[2]

    remaining_height = int(np.rint(random_float(height_ratio_range[0], height_ratio_range[1]) * image_height))
    remaining_width = int(np.rint(random_float(width_ratio_range[0], width_ratio_range[0]) * image_width))

    if remaining_height == image_height:
        height_start = 0
    else:
        height_start = np.random.randint(0, image_height - remaining_height)

    if remaining_width == image_width:
        width_start = 0
    else:
        width_start = np.random.randint(0, image_width - remaining_width)

    return height_start, height_start+remaining_height, width_start, width_start+remaining_width


class Crop(nn.Module):
    """
    Randomly crops the image from top/bottom and left/right. The amount to crop is controlled by parameters
    heigth_ratio_range and width_ratio_range
    """
    def __init__(self, height_ratio_range, width_ratio_range):
        """
        :param height_ratio_range:
        :param width_ratio_range:
        """
        super(Crop, self).__init__()
        self.height_ratio_range = height_ratio_range
        self.width_ratio_range = width_ratio_range


    def forward(self, noised_and_cover):
        noised_image = noised_and_cover[0]
        print("Noisedimageshape: ",noised_image.shape)
        shape = noised_image.shape
        # crop_rectangle is in form (from, to) where @from and @to are 2D points -- (height, width)

        h_start, h_end, w_start, w_end = get_random_rectangle_inside(noised_image, self.height_ratio_range, self.width_ratio_range)

        noised_image =  noised_image[
               :,
               h_start: h_end,
               w_start: w_end].clone()
        noised_image1 = noised_image.expand(-1,64,64)
        print(noised_image1.shape)
        noised_and_cover[0] = noised_image1.clone()

        return noised_and_cover

# %%
# Preparation Network (2 conv layers)
class PrepNetwork(nn.Module):
    def __init__(self):
        super(PrepNetwork, self).__init__()
        self.initialP3 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialP4 = nn.Sequential(
            nn.Conv2d(3, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialP5 = nn.Sequential(
            nn.Conv2d(3, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalP3 = nn.Sequential(
            nn.Conv2d(65, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalP4 = nn.Sequential(
            nn.Conv2d(65, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalP5 = nn.Sequential(
            nn.Conv2d(65, 5, kernel_size=5, padding=2),
            nn.ReLU())

    def forward(self, p):
        p1 = self.initialP3(p)
        p2 = self.initialP4(p)
        p3 = self.initialP5(p)
        mid = torch.cat((p1, p2, p3), 1)
        p4 = self.finalP3(mid)
        p5 = self.finalP4(mid)
        p6 = self.finalP5(mid)
        # print(p4.shape)
        # print(p5.shape)
        # print(p6.shape)
        out = torch.cat((p4, p5, p6), 1)
        return out

# Hiding Network (5 conv layers)
class HidingNetwork(nn.Module):
    def __init__(self):
        super(HidingNetwork, self).__init__()
        self.initialH3 = nn.Sequential(
            nn.Conv2d(68, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialH4 = nn.Sequential(
            nn.Conv2d(68, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialH5 = nn.Sequential(
            nn.Conv2d(68, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalH3 = nn.Sequential(
            nn.Conv2d(65, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalH4 = nn.Sequential(
            nn.Conv2d(65, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalH5 = nn.Sequential(
            nn.Conv2d(65, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalH = nn.Sequential(
            nn.Conv2d(65, 3, kernel_size=1, padding=0))
        
    def forward(self, h):
        h1 = self.initialH3(h)
        h2 = self.initialH4(h)
        h3 = self.initialH5(h)
        mid = torch.cat((h1, h2, h3), 1)
        h4 = self.finalH3(mid)
        h5 = self.finalH4(mid)
        h6 = self.finalH5(mid)
        mid2 = torch.cat((h4, h5, h6), 1)
        out = self.finalH(mid2)
        out_noise = gaussian(out.data, 0, 0.1)
        return out, out_noise

# Reveal Network (2 conv layers)
class RevealNetwork(nn.Module):
    def __init__(self):
        super(RevealNetwork, self).__init__()
        self.initialR3 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialR4 = nn.Sequential(
            nn.Conv2d(3, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialR5 = nn.Sequential(
            nn.Conv2d(3, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalR3 = nn.Sequential(
            nn.Conv2d(65, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalR4 = nn.Sequential(
            nn.Conv2d(65, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalR5 = nn.Sequential(
            nn.Conv2d(65, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalR = nn.Sequential(
            nn.Conv2d(65, 3, kernel_size=1, padding=0))

    def forward(self, r, img_shape):
        # r = r.expand(img_shape)
        r1 = self.initialR3(r)
        r2 = self.initialR4(r)
        r3 = self.initialR5(r)
        mid = torch.cat((r1, r2, r3), 1)
        r4 = self.finalR3(mid)
        r5 = self.finalR4(mid)
        r6 = self.finalR5(mid)
        mid2 = torch.cat((r4, r5, r6), 1)
        out = self.finalR(mid2)
        return out

# Join three networks in one module
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.m1 = PrepNetwork().to(device)
        self.m2 = HidingNetwork().to(device)
        self.m3 = RevealNetwork().to(device)
        self.crop = Crop((0.7,0.9),(0.7,0.9)).to(device)

    def forward(self, secret, cover):
        img_shape = secret.shape
        x_1 = self.m1(secret)
        mid = torch.cat((x_1, cover), 1)
        x_2, x_2_noise = self.m2(mid)
        # x_2_noise = resized_crop(img=x_2_noise, top = 0, left=0, height=19, width=19, size=[64,64])
        x_2 =  resized_crop(img=x_2, top = 0, left=0, height=7, width=7, size=[64,64])
        # x_3 = self.m3(x_2_noise, img_shape)
        x_3 = self.m3(x_2, img_shape)
        return x_2, x_3

# %%
# Creates net object
net = Net().to(device)

# %%
# Creates training set
train_data = datasets.ImageFolder(
        TRAIN_PATH,
        transforms.Compose([
        # transforms.Scale(256),
        # transforms.RandomCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean,
        std=std)
        ]))
train_data = Subset(train_data, [i for i in range(32000)])
train_loader = torch.utils.data.DataLoader(
        train_data, batch_size=batch_size, num_workers=1, 
        pin_memory=True, shuffle=True, drop_last=True)

# Creates test set
test_data = datasets.ImageFolder(
        TEST_PATH, 
        transforms.Compose([
        # transforms.Scale(256),
        # transforms.RandomCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean,
        std=std)
        ]))
test_data = Subset(test_data,[i for i in range(5000)])
test_loader = torch.utils.data.DataLoader(
        test_data, batch_size=2, num_workers=1, 
        pin_memory=True, shuffle=True, drop_last=True)

# %%
PATH = "/content/drive/MyDrive/"
loss_history = []

def train_model(train_loader, beta, learning_rate):
    
    # Save optimizer
    optimizer = optim.Adam(net.parameters(), lr=learning_rate)
    
    loss_history = []
    # Iterate over batches performing forward and backward passes
    for epoch in range(num_epochs):

        # Train mode
        net.train()
        
        train_losses = []
        # Train one epoch
        for idx, train_batch in enumerate(train_loader):

            data, _  = train_batch
            data = data.to(device)

            # Saves secret images and secret covers
            train_covers = data[:len(data)//2]
            train_secrets = data[len(data)//2:]
            
            # Creates variable from secret and cover images
            train_secrets = Variable(train_secrets, requires_grad=False)
            train_covers = Variable(train_covers, requires_grad=False)

            # Forward + Backward + Optimize
            optimizer.zero_grad()
            train_hidden, train_output = net(train_secrets, train_covers)

            # Calculate loss and perform backprop
            train_loss, train_loss_cover, train_loss_secret = customized_loss(train_output, train_hidden, train_secrets, train_covers, beta)
            train_loss.backward()
            optimizer.step()
            
            # Saves training loss
            # print(train_loss.data)
            train_losses.append(train_loss.data.item())
            loss_history.append(train_loss.data.item())
            
            # Prints mini-batch losses
            print('Training: Batch {0}/{1}. Loss of {2:.4f}, cover loss of {3:.4f}, secret loss of {4:.4f}'.format(idx+1, len(train_loader), train_loss.data.item(), train_loss_cover.data.item(), train_loss_secret.data.item()))
    
        # Save model
        # torch.save(net.state_dict(), '/content/Epoch N{}.pkl'.format(epoch+1))
        torch.save(net.state_dict(), PATH+"LOSS1_ds_crop_10.pth")
        with open(PATH+"LOSS1_loss_history_crop_10.txt", "a") as f:
            for s in loss_history:
                f.write(str(s) +"\n")
        
        mean_train_loss = np.mean(train_losses)
    
        # Prints epoch average loss
        print ('Epoch [{0}/{1}], Average_loss: {2:.4f}'.format(
                epoch+1, num_epochs, mean_train_loss))
    
    return net, mean_train_loss, loss_history

# %%
# Load model
# net.load_state_dict(torch.load(PATH+"LOSS1_ds_crop_10.pth"))
# loss_history = []
# with open(PATH+"LOSS1_loss_history_crop_10.txt", "r") as f:
#   for line in f:
#     loss_history.append(float(line.strip()))

net, mean_train_loss, loss_history = train_model(train_loader, beta, learning_rate)
# loss_history.extend(loss_history1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:43: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
# Streaming output truncated to the last 5000 lines.
# Training: Batch 6/1000. Loss of 0.6067, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 7/1000. Loss of 0.6473, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 8/1000. Loss of 0.7223, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 9/1000. Loss of 0.7397, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 10/1000. Loss of 0.7679, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 11/1000. Loss of 0.6083, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 12/1000. Loss of 0.7000, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 13/1000. Loss of 0.6884, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 14/1000. Loss of 0.6752, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch
cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 195/1000. Loss of 0.6481, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 196/1000. Loss of 0.7088, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 197/1000. Loss of 0.6097, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 198/1000. Loss of 0.5833, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 199/1000. Loss of 0.5972, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 200/1000. Loss of 0.6301, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 201/1000. Loss of 0.7478, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 202/1000. Loss of 0.6553, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 203/1000. Loss of 0.7112, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 204/1000. Loss of 0.6053, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 205/1000. Loss of 0.6041, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 206/1000. Loss of 0.5858, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 207/1000. Loss of 0.6207, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 208/1000. Loss of 0.7805, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 209/1000. Loss of 0.5567, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 210/1000. Loss of 0.6816, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 211/1000. Loss of 0.6964, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 212/1000. Loss of 0.6835, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 213/1000. Loss of 0.6041, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 214/1000. Loss of 0.6230, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 215/1000. Loss of 0.6608, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 216/1000. Loss of 0.7302, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 217/1000. Loss of 0.5445, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 218/1000. Loss of 0.6339, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 219/1000. Loss of 0.6903, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 220/1000. Loss of 0.6737, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 221/1000. Loss of 0.6343, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 222/1000. Loss of 0.5624, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 223/1000. Loss of 0.6417, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 224/1000. Loss of 0.6813, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 225/1000. Loss of 0.7610, cover loss of 0.0003, secret loss of 0.0003
# Training: Batch 226/1000. Loss of 0.6776, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 227/1000. Loss of 0.6562, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 228/1000. Loss of 0.6403, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 229/1000. Loss of 0.6863, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 230/1000. Loss of 0.7326, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 231/1000. Loss of 0.6835, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 232/1000. Loss of 0.6114, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 233/1000. Loss of 0.6855, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 234/1000. Loss of 0.6071, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 235/1000. Loss of 0.6829, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 236/1000. Loss of 0.5403, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 237/1000. Loss of 0.7159, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 238/1000. Loss of 0.5556, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 239/1000. Loss of 0.6867, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 240/1000. Loss of 0.6867, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 241/1000. Loss of 0.6661, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 242/1000. Loss of 0.6965, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 243/1000. Loss of 0.6513, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 244/1000. Loss of 0.6776, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 245/1000. Loss of 0.6494, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 246/1000. Loss of 0.6846, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 247/1000. Loss of 0.7002, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 248/1000. Loss of 0.5729, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 249/1000. Loss of 0.5970, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 250/1000. Loss of 0.5826, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 251/1000. Loss of 0.7070, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 252/1000. Loss of 0.6451, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 253/1000. Loss of 0.6093, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 254/1000. Loss of 0.6984, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 255/1000. Loss of 0.6478, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 256/1000. Loss of 0.7184, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 257/1000. Loss of 0.5799, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 258/1000. Loss of 0.6520, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 259/1000. Loss of 0.6725, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 260/1000. Loss of 0.7128, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 261/1000. Loss of 0.6890, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 262/1000. Loss of 0.7557, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 263/1000. Loss of 0.7074, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 264/1000. Loss of 0.6293, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 265/1000. Loss of 0.6809, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 266/1000. Loss of 0.6557, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 267/1000. Loss of 0.7320, cover loss of 0.0003, secret loss of 0.0003
# Training: Batch 268/1000. Loss of 0.6592, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 269/1000. Loss of 0.6232, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 270/1000. Loss of 0.6164, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 271/1000. Loss of 0.7095, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 272/1000. Loss of 0.7017, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 273/1000. Loss of 0.6433, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 274/1000. Loss of 0.7245, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 275/1000. Loss of 0.7617, cover loss of 0.0003, secret loss of 0.0003
# Training: Batch 276/1000. Loss of 0.6626, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 277/1000. Loss of 0.5854, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 278/1000. Loss of 0.5558, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 279/1000. Loss of 0.6661, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 280/1000. Loss of 0.6260, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 281/1000. Loss of 0.6426, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 282/1000. Loss of 0.8172, cover loss of 0.0003, secret loss of 0.0003
# Training: Batch 283/1000. Loss of 0.7539, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch
cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 463/1000. Loss of 0.6004, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 464/1000. Loss of 0.6259, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 465/1000. Loss of 0.5947, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 466/1000. Loss of 0.6630, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 467/1000. Loss of 0.6572, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 468/1000. Loss of 0.6676, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 469/1000. Loss of 0.5852, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 470/1000. Loss of 0.6320, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 471/1000. Loss of 0.7323, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 472/1000. Loss of 0.5555, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 473/1000. Loss of 0.6600, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 474/1000. Loss of 0.7136, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 475/1000. Loss of 0.6380, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 476/1000. Loss of 0.6378, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 477/1000. Loss of 0.7614, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 478/1000. Loss of 0.6135, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 479/1000. Loss of 0.5953, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 480/1000. Loss of 0.5319, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 481/1000. Loss of 0.6811, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 482/1000. Loss of 0.6790, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 483/1000. Loss of 0.6574, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 484/1000. Loss of 0.7085, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 485/1000. Loss of 0.6361, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 486/1000. Loss of 0.6154, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 487/1000. Loss of 0.5830, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 488/1000. Loss of 0.6097, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 489/1000. Loss of 0.7047, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 490/1000. Loss of 0.6616, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 491/1000. Loss of 0.6723, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 492/1000. Loss of 0.6904, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 493/1000. Loss of 0.6831, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 494/1000. Loss of 0.5763, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 495/1000. Loss of 0.6224, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 496/1000. Loss of 0.7728, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 497/1000. Loss of 0.6792, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 498/1000. Loss of 0.7421, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 499/1000. Loss of 0.6470, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 500/1000. Loss of 0.6252, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 501/1000. Loss of 0.5069, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 502/1000. Loss of 0.5951, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 503/1000. Loss of 0.6859, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 504/1000. Loss of 0.5975, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 505/1000. Loss of 0.7126, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 506/1000. Loss of 0.5999, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 507/1000. Loss of 0.7005, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 508/1000. Loss of 0.7098, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 509/1000. Loss of 0.7381, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 510/1000. Loss of 0.6551, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 511/1000. Loss of 0.6207, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 512/1000. Loss of 0.7419, cover loss of 0.0003, secret loss of 0.0003
# Training: Batch 513/1000. Loss of 0.7078, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 514/1000. Loss of 0.6976, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 515/1000. Loss of 0.6371, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 516/1000. Loss of 0.6826, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 517/1000. Loss of 0.6814, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 518/1000. Loss of 0.6501, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 519/1000. Loss of 0.6086, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 520/1000. Loss of 0.6716, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 521/1000. Loss of 0.6756, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 522/1000. Loss of 0.5810, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 523/1000. Loss of 0.6184, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 524/1000. Loss of 0.7259, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 525/1000. Loss of 0.7329, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 526/1000. Loss of 0.5842, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 527/1000. Loss of 0.7422, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 528/1000. Loss of 0.6842, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 529/1000. Loss of 0.5910, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 530/1000. Loss of 0.6179, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 531/1000. Loss of 0.6756, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 532/1000. Loss of 0.6392, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 533/1000. Loss of 0.6318, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 534/1000. Loss of 0.6970, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 535/1000. Loss of 0.6907, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 536/1000. Loss of 0.5963, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 537/1000. Loss of 0.6180, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 538/1000. Loss of 0.6195, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 539/1000. Loss of 0.6868, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 540/1000. Loss of 0.6992, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 541/1000. Loss of 0.6224, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 542/1000. Loss of 0.6943, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 543/1000. Loss of 0.6613, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 544/1000. Loss of 0.6934, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 545/1000. Loss of 0.7218, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 546/1000. Loss of 0.5692, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 547/1000. Loss of 0.6256, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 548/1000. Loss of 0.6491, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 549/1000. Loss of 0.6766, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 550/1000. Loss of 0.6716, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 551/1000. Loss of 0.6797, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 552/1000. Loss of 0.6235, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 553/1000. Loss of 0.6584, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 554/1000. Loss of 0.5312, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 555/1000. Loss of 0.6617, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 556/1000. Loss of 0.6636, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 557/1000. Loss of 0.6337, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 558/1000. Loss of 0.5812, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 559/1000. Loss of 0.7057, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 560/1000. Loss of 0.6508, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 561/1000. Loss of 0.6807, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 562/1000. Loss of 0.7158, cover loss of 0.0002, secret loss of 0.0002
# ...
# Training: Batch 816/1000. Loss of 0.7882, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 817/1000. Loss of 0.6613, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 818/1000. Loss of 0.5851, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 819/1000. Loss of 0.7029, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 820/1000. Loss of 0.6651, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 821/1000. Loss of 0.6999, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 822/1000. Loss of 0.6707, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 823/1000. Loss of 0.6155, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 824/1000. Loss of 0.6827, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 825/1000. Loss of 0.6951, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 826/1000. Loss of 0.6860, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 827/1000. Loss of 0.6436, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 828/1000. Loss of 0.7505, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 829/1000. Loss of 0.6612, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 830/1000. Loss of 0.7229, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 831/1000. Loss of 0.7006, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 832/1000. Loss of 0.7130, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 833/1000. Loss of 0.6220, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 834/1000. Loss of 0.6597, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 835/1000. Loss of 0.6167, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 836/1000. Loss of 0.5891, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 837/1000. Loss of 0.6066, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 838/1000. Loss of 0.7714, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 839/1000. Loss of 0.6793, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 840/1000. Loss of 0.6292, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 841/1000. Loss of 0.5641, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 842/1000. Loss of 0.5414, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 843/1000. Loss of 0.7462, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 844/1000. Loss of 0.6309, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 845/1000. Loss of 0.6712, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 846/1000. Loss of 0.6242, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 847/1000. Loss of 0.7077, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 848/1000. Loss of 0.6838, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 849/1000. Loss of 0.6677, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 850/1000. Loss of 0.6903, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 851/1000. Loss of 0.6271, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 852/1000. Loss of 0.7967, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 853/1000. Loss of 0.6708, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 854/1000. Loss of 0.6372, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 855/1000. Loss of 0.6524, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 856/1000. Loss of 0.7125, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 857/1000. Loss of 0.7242, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 858/1000. Loss of 0.5483, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 859/1000. Loss of 0.6849, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 860/1000. Loss of 0.7605, cover loss of 0.0003, secret loss of 0.0003
# Training: Batch 861/1000. Loss of 0.6539, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 862/1000. Loss of 0.6663, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 863/1000. Loss of 0.5922, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 864/1000. Loss of 0.6487, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 865/1000. Loss of 0.6550, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 866/1000. Loss of 0.6224, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 867/1000. Loss of 0.6513, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 868/1000. Loss of 0.6576, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 869/1000. Loss of 0.6729, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 870/1000. Loss of 0.5840, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 871/1000. Loss of 0.7220, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 872/1000. Loss of 0.6307, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 873/1000. Loss of 0.6316, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 874/1000. Loss of 0.6693, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 875/1000. Loss of 0.6367, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 876/1000. Loss of 0.6080, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 877/1000. Loss of 0.6229, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 878/1000. Loss of 0.6146, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 879/1000. Loss of 0.7237, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 880/1000. Loss of 0.5848, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 881/1000. Loss of 0.5932, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 882/1000. Loss of 0.6622, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 883/1000. Loss of 0.5671, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 884/1000. Loss of 0.6265, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 885/1000. Loss of 0.6194, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 886/1000. Loss of 0.5749, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 887/1000. Loss of 0.6954, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 888/1000. Loss of 0.7679, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 889/1000. Loss of 0.6070, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 890/1000. Loss of 0.6226, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 891/1000. Loss of 0.6782, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 892/1000. Loss of 0.7165, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 893/1000. Loss of 0.6466, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 894/1000. Loss of 0.6430, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 895/1000. Loss of 0.7473, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 896/1000. Loss of 0.7113, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 897/1000. Loss of 0.6435, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 898/1000. Loss of 0.6687, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 899/1000. Loss of 0.7250, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 900/1000. Loss of 0.6972, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 901/1000. Loss of 0.6578, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 902/1000. Loss of 0.5803, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 903/1000. Loss of 0.6123, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 904/1000. Loss of 0.6617, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 905/1000. Loss of 0.5403, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 906/1000. Loss of 0.5736, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 907/1000. Loss of 0.7929, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 908/1000. Loss of 0.7041, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 909/1000. Loss of 0.6539, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 910/1000. Loss of 0.6065, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 911/1000. Loss of 0.7335, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 912/1000. Loss of 0.6596, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 913/1000. Loss of 0.7238, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 914/1000. Loss of 0.7673, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 915/1000. Loss of 0.6568, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 916/1000. Loss of 0.6224, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 917/1000. Loss of 0.5809, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 918/1000. Loss of 0.5967, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 919/1000. Loss of 0.6203, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 920/1000. Loss of 0.6346, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 921/1000. Loss of 0.5766, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 922/1000. Loss of 0.8098, cover loss of 0.0003, secret loss of 0.0003
# Training: Batch 923/1000. Loss of 0.6875, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 924/1000. Loss of 0.6433, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 925/1000. Loss of 0.5794, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 926/1000. Loss of 0.6521, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 927/1000. Loss of 0.6374, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 928/1000. Loss of 0.5618, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 929/1000. Loss of 0.5983, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 930/1000. Loss of 0.7057, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 931/1000. Loss of 0.5886, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 932/1000. Loss of 0.6862, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 933/1000. Loss of 0.5804, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 934/1000. Loss of 0.7108, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 935/1000. Loss of 0.6058, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 936/1000. Loss of 0.6280, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 937/1000. Loss of 0.6634, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 938/1000. Loss of 0.7330, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 939/1000. Loss of 0.7045, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 940/1000. Loss of 0.7269, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 941/1000. Loss of 0.5591, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 942/1000. Loss of 0.5856, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 943/1000. Loss of 0.6728, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 944/1000. Loss of 0.6522, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 945/1000. Loss of 0.6376, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 946/1000. Loss of 0.6801, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 947/1000. Loss of 0.6768, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 948/1000. Loss of 0.6617, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 949/1000. Loss of 0.6977, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 950/1000. Loss of 0.6049, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 951/1000. Loss of 0.6904, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 952/1000. Loss of 0.8358, cover loss of 0.0003, secret loss of 0.0003
# Training: Batch 953/1000. Loss of 0.5570, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 954/1000. Loss of 0.6032, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 955/1000. Loss of 0.6901, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 956/1000. Loss of 0.6740, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 957/1000. Loss of 0.5594, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 958/1000. Loss of 0.5196, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 959/1000. Loss of 0.6263, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 960/1000. Loss of 0.6233, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 961/1000. Loss of 0.5774, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 962/1000. Loss of 0.6813, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 963/1000. Loss of 0.5885, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 964/1000. Loss of 0.6713, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 965/1000. Loss of 0.6038, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 966/1000. Loss of 0.6410, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 967/1000. Loss of 0.5713, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 968/1000. Loss of 0.6314, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 969/1000. Loss of 0.6253, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 970/1000. Loss of 0.6522, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 971/1000. Loss of 0.7552, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 972/1000. Loss of 0.6174, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 973/1000. Loss of 0.6876, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 974/1000. Loss of 0.5589, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 975/1000. Loss of 0.7221, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 976/1000. Loss of 0.6605, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 977/1000. Loss of 0.6306, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 978/1000. Loss of 0.7425, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 979/1000. Loss of 0.6054, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 980/1000. Loss of 0.7639, cover loss of 0.0003, secret loss of 0.0003
# Training: Batch 981/1000. Loss of 0.7103, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 982/1000. Loss of 0.5400, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 983/1000. Loss of 0.6616, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 984/1000. Loss of 0.7231, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 985/1000. Loss of 0.6831, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 986/1000. Loss of 0.6364, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 987/1000. Loss of 0.7033, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 988/1000. Loss of 0.6386, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 989/1000. Loss of 0.6716, cover loss of 0.0002, secret loss of 0.0003
# Training: Batch 990/1000. Loss of 0.6448, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 991/1000. Loss of 0.6447, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 992/1000. Loss of 0.6443, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 993/1000. Loss of 0.6498, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 994/1000. Loss of 0.6091, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 995/1000. Loss of 0.6340, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 996/1000. Loss of 0.6170, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 997/1000. Loss of 0.6344, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 998/1000. Loss of 0.7263, cover loss of 0.0003, secret loss of 0.0002
# Training: Batch 999/1000. Loss of 0.6172, cover loss of 0.0002, secret loss of 0.0002
# Training: Batch 1000/1000. Loss of 0.5799, cover loss of 0.0002, secret loss of 0.0002
# Epoch [50/50], Average_loss: 0.6501

# %%
 # Plot loss through epochs
plt.plot(loss_history)
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Batch')
plt.show()

# %%
def pixel_errors(input_S, input_C, decoded_S, decoded_C):
    """Calculates mean of Sum of Squared Errors per pixel for cover and secret images. """
    input_S = np.array(input_S.detach().cpu())
    input_C = np.array(input_C.detach().cpu())
    decoded_S = np.array(decoded_S.detach().cpu())
    decoded_C = np.array(decoded_C.detach().cpu())
    # print(input_S)
    see_Spixel = np.sqrt(np.mean(np.square(255*(input_S - decoded_S))))
    see_Cpixel = np.sqrt(np.mean(np.square(255*(input_C - decoded_C))))
    
    return see_Spixel, see_Cpixel

import math
def psnr(input_S, input_C, decoded_S, decoded_C):
    input_S = np.array(input_S.detach().cpu())
    input_C = np.array(input_C.detach().cpu())
    decoded_S = np.array(decoded_S.detach().cpu())
    decoded_C = np.array(decoded_C.detach().cpu())
    mse_s = np.mean(np.square(255*(input_S - decoded_S)))
    mse_c = np.mean(np.square(255*(input_C - decoded_C)))
    psnr_s = 10*math.log10(255**2/mse_s)
    psnr_c = 10*math.log10(255**2/mse_c)
    return psnr_s, psnr_c

def pixel_histogram(diff_S, diff_C):
    """Calculates histograms of errors for cover and secret image. """
    diff_Sflat = diff_S.flatten()
    diff_Cflat = diff_C.flatten()
    
    fig = plt.figure(figsize=(15, 5))
    a=fig.add_subplot(1,2,1)
        
    imgplot = plt.hist(255* diff_Cflat, 100, density=1, alpha=0.75, facecolor='red')
    a.set_title('Distribution of error in the Cover image.')
    plt.axis([0, 250, 0, 0.2])
    
    a=fig.add_subplot(1,2,2)
    imgplot = plt.hist(255* diff_Sflat, 100, density=1, alpha=0.75, facecolor='red')
    a.set_title('Distribution of errors in the Secret image.')
    plt.axis([0, 250, 0, 0.2])
    
    plt.show()

# %%
# net.load_state_dict(torch.load(MODELS_PATH+'Epoch N4.pkl'))

# Switch to evaluate mode
net.eval()
Path(PATH+"LOSS1_ds_img_10").mkdir(parents=True, exist_ok=True)
Path(PATH+"LOSS1_ds_img_10/cover_images/").mkdir(parents=True, exist_ok=True)
Path(PATH+"LOSS1_ds_img_10/container_images/").mkdir(parents=True, exist_ok=True)
save_path = PATH+"LOSS1_ds_img_10/"

test_losses = []

S_errors = []
C_errors = []

psnr_s,psnr_c = [], []
# Show images
for idx, test_batch in enumerate(test_loader):
     # Saves images
    data, _ = test_batch
    data = data.to(device)

    # Saves secret images and secret covers
    test_secret = data[:len(data)//2]
    test_cover = data[len(data)//2:]

    # Creates variable from secret and cover images
    test_secret = Variable(test_secret, volatile=True)
    test_cover = Variable(test_cover, volatile=True)

    # Compute output
    test_hidden, test_output = net(test_secret, test_cover)
    
    # Calculate loss
    test_loss, loss_cover, loss_secret = customized_loss(test_output, test_hidden, test_secret, test_cover, beta)
    
    diff_S, diff_C = np.abs(np.array(test_output.data.detach().cpu()) - np.array(test_secret.data.detach().cpu())), np.abs(np.array(test_hidden.data.detach().cpu()) - np.array(test_cover.data.detach().cpu()))
    
#     print (diff_S, diff_C)

    # Print pixel-wise average errors in a 256 scale.
    S_error, C_error = pixel_errors(test_secret, test_cover, test_output, test_hidden)
    S_errors.append(S_error)
    C_errors.append(C_error)

    S_psnr, C_psnr = psnr(test_secret, test_cover, test_output, test_hidden)
    psnr_s.append(S_psnr)
    psnr_c.append(C_psnr)
    
    if idx in [1,2,3,4]:
        print ('Total loss: {:.2f} \nLoss on secret: {:.2f} \nLoss on cover: {:.2f}'.format(test_loss.data.item(), loss_secret.data.item(), loss_cover.data.item()))

        # Creates img tensor
        imgs = [test_secret.data.detach().cpu(), test_output.data.detach().cpu(), test_cover.data.detach().cpu(), test_hidden.data.detach().cpu()]
        imgs_tsor = torch.cat(imgs, 0)

        # Prints Images
        imshow(utils.make_grid(imgs_tsor), idx+1, learning_rate=learning_rate, beta=beta)

    if idx < 500:
        container_img = tensor_to_image(test_hidden.data.detach().cpu())
        container_img = Image.fromarray(container_img)
        container_img.save(save_path+"container_images/"+str(idx)+".jpeg")
        cover_img = tensor_to_image(test_cover.data.detach().cpu())
        cover_img = Image.fromarray(cover_img)
        cover_img.save(save_path+"cover_images/"+str(idx)+".jpeg")
            
    test_losses.append(test_loss.data.item())
        
mean_test_loss = np.mean(test_losses)

print ('Average loss on test set: {:.2f}'.format(mean_test_loss))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:27: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:43: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
# Total loss: 0.70
# Loss on secret: 0.00
# Loss on cover: 0.00
# Total loss: 0.29
# Loss on secret: 0.00
# Loss on cover: 0.00
# Total loss: 0.76
# Loss on secret: 0.00
# Loss on cover: 0.00
# Total loss: 0.55
# Loss on secret: 0.00
# Loss on cover: 0.00
# Average loss on test set: 0.59

# %%
print ("Avg. S error per pixel [0, 255]:", sum(S_errors)/len(S_errors))
print ("Avg. C error per pixel [0, 255]:", sum(C_errors)/len(C_errors))

# %%
print ("Avg. PSNR of secret and decoded secret:", sum(psnr_s)/len(psnr_s))
print ("Avg. PSNR of cover and container:", sum(psnr_c)/len(psnr_c))

# %%
# Plot distribution of errors in cover and secret images.
pixel_histogram(diff_S, diff_C)
