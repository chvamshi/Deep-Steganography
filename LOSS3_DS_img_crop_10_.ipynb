# %% [markdown]
# <a href="https://colab.research.google.com/github/chvamshi/Deep-Steganography/blob/main/LOSS3_DS_img_crop_10_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget http://cs231n.stanford.edu/tiny-imagenet-200.zip
# !unzip -q tiny-imagenet-200.zip && ls tiny-imagenet-200
# Out:
# --2022-02-05 22:37:23--  http://cs231n.stanford.edu/tiny-imagenet-200.zip
# Resolving cs231n.stanford.edu (cs231n.stanford.edu)... 171.64.68.10
# Connecting to cs231n.stanford.edu (cs231n.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248100043 (237M) [application/zip]
# Saving to: ‘tiny-imagenet-200.zip’
#
# tiny-imagenet-200.z 100%[===================>] 236.61M  13.4MB/s    in 17s
#
# 2022-02-05 22:37:40 (13.8 MB/s) - ‘tiny-imagenet-200.zip’ saved [248100043/248100043]
#
# test  train  val  wnids.txt  words.txt

# %%
# Imports necessary libraries and modules
from itertools import islice
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch.autograd import Variable
from torch import utils
from torch.utils.data import Subset
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import os 
from pathlib import Path
import pickle
import random
from torchvision import datasets, utils
import torchvision.transforms as transforms
from torchvision.transforms import ToPILImage
from torchvision.transforms import RandomResizedCrop
from torchvision.transforms.functional import resized_crop
from random import shuffle
from IPython.display import Image
from PIL import Image

# Use GPU if it is present
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
# Directory path
# os.chdir("..")
cwd = '/content/tiny-imagenet-200'

# Hyper Parameters
num_epochs = 50
batch_size = 32
learning_rate = 0.001
beta = 1

# Mean and std deviation of imagenet dataset. Source: http://cs231n.stanford.edu/reports/2017/pdfs/101.pdf
std = [0.229, 0.224, 0.225]
mean = [0.485, 0.456, 0.406]

# TODO: Define train, validation and models
MODELS_PATH = '/content/output/models'
# TRAIN_PATH = cwd+'/train/'
# VALID_PATH = cwd+'/valid/'
VALID_PATH = cwd+'/val/'
TRAIN_PATH = cwd+'/train/'
TEST_PATH = cwd+'/test/'

# if not os.path.exists(MODELS_PATH): os.mkdir(MODELS_PATH)

# %%
def variance(image1, image2):
    var1 = torch.var(image1)
    var2 = torch.var(image2)

    return var1+var2

def customized_loss(S_prime, C_prime, S, C, B):
    ''' Calculates loss specified on the paper.'''
    
    loss_cover = torch.nn.functional.mse_loss(C_prime, C)
    loss_secret = torch.nn.functional.mse_loss(S_prime, S)

    loss_all = (loss_cover + B * loss_secret + variance(C_prime, C) + variance(S_prime, S))/4

    return loss_all, loss_cover, loss_secret

def denormalize(image, std, mean):
    ''' Denormalizes a tensor of images.'''

    for t in range(3):
        image[t, :, :] = (image[t, :, :] * std[t]) + mean[t]
    return image

def imshow(img, idx, learning_rate, beta):
    '''Prints out an image given in tensor format.'''
    
    img = denormalize(img, std, mean)
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.title('Example '+str(idx)+', lr='+str(learning_rate)+', B='+str(beta))
    plt.show()
    return

def gaussian(tensor, mean=0, stddev=0.1):
    '''Adds random noise to a tensor.'''
    
    noise = torch.nn.init.normal(torch.Tensor(tensor.size()), 0, 0.1).to(device)
    return Variable(tensor + noise)

def tensor_to_image(tensor):
    """
    Transforms a torch tensor into numpy uint8 array (image)
    :param tensor: (batch_size x channels x height x width) torch tensor in range [-1.0, 1.0]
    :return: (batch_size x height x width x channels) uint8 array
    """
    image = tensor.cpu().numpy()[0]
    # image = tensor.permute(0, 2, 3, 1).cpu().numpy()
    image = np.transpose(image, (1,2,0))
    image = (image + 1) * 127.5
    return np.clip(image, 0, 255).astype(np.uint8)

# %%
import torch.nn as nn
import numpy as np

def random_float(min, max):
    """
    Return a random number
    :param min:
    :param max:
    :return:
    """
    return np.random.rand() * (max - min) + min


def get_random_rectangle_inside(image, height_ratio_range, width_ratio_range):
    """
    Returns a random rectangle inside the image, where the size is random and is controlled by height_ratio_range and width_ratio_range.
    This is analogous to a random crop. For example, if height_ratio_range is (0.7, 0.9), then a random number in that range will be chosen
    (say it is 0.75 for illustration), and the image will be cropped such that the remaining height equals 0.75. In fact,
    a random 'starting' position rs will be chosen from (0, 0.25), and the crop will start at rs and end at rs + 0.75. This ensures
    that we crop from top/bottom with equal probability.
    The same logic applies to the width of the image, where width_ratio_range controls the width crop range.
    :param image: The image we want to crop
    :param height_ratio_range: The range of remaining height ratio
    :param width_ratio_range:  The range of remaining width ratio.
    :return: "Cropped" rectange with width and height drawn randomly height_ratio_range and width_ratio_range
    """
    # print(image.shape)
    image_height = image.shape[1]
    image_width = image.shape[2]

    remaining_height = int(np.rint(random_float(height_ratio_range[0], height_ratio_range[1]) * image_height))
    remaining_width = int(np.rint(random_float(width_ratio_range[0], width_ratio_range[0]) * image_width))

    if remaining_height == image_height:
        height_start = 0
    else:
        height_start = np.random.randint(0, image_height - remaining_height)

    if remaining_width == image_width:
        width_start = 0
    else:
        width_start = np.random.randint(0, image_width - remaining_width)

    return height_start, height_start+remaining_height, width_start, width_start+remaining_width


class Crop(nn.Module):
    """
    Randomly crops the image from top/bottom and left/right. The amount to crop is controlled by parameters
    heigth_ratio_range and width_ratio_range
    """
    def __init__(self, height_ratio_range, width_ratio_range):
        """
        :param height_ratio_range:
        :param width_ratio_range:
        """
        super(Crop, self).__init__()
        self.height_ratio_range = height_ratio_range
        self.width_ratio_range = width_ratio_range


    def forward(self, noised_and_cover):
        noised_image = noised_and_cover[0]
        print("Noisedimageshape: ",noised_image.shape)
        shape = noised_image.shape
        # crop_rectangle is in form (from, to) where @from and @to are 2D points -- (height, width)

        h_start, h_end, w_start, w_end = get_random_rectangle_inside(noised_image, self.height_ratio_range, self.width_ratio_range)

        noised_image =  noised_image[
               :,
               h_start: h_end,
               w_start: w_end].clone()
        noised_image1 = noised_image.expand(-1,64,64)
        print(noised_image1.shape)
        noised_and_cover[0] = noised_image1.clone()

        return noised_and_cover

# %%
# Preparation Network (2 conv layers)
class PrepNetwork(nn.Module):
    def __init__(self):
        super(PrepNetwork, self).__init__()
        self.initialP3 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialP4 = nn.Sequential(
            nn.Conv2d(3, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialP5 = nn.Sequential(
            nn.Conv2d(3, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalP3 = nn.Sequential(
            nn.Conv2d(65, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalP4 = nn.Sequential(
            nn.Conv2d(65, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalP5 = nn.Sequential(
            nn.Conv2d(65, 5, kernel_size=5, padding=2),
            nn.ReLU())

    def forward(self, p):
        p1 = self.initialP3(p)
        p2 = self.initialP4(p)
        p3 = self.initialP5(p)
        mid = torch.cat((p1, p2, p3), 1)
        p4 = self.finalP3(mid)
        p5 = self.finalP4(mid)
        p6 = self.finalP5(mid)
        # print(p4.shape)
        # print(p5.shape)
        # print(p6.shape)
        out = torch.cat((p4, p5, p6), 1)
        return out

# Hiding Network (5 conv layers)
class HidingNetwork(nn.Module):
    def __init__(self):
        super(HidingNetwork, self).__init__()
        self.initialH3 = nn.Sequential(
            nn.Conv2d(68, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialH4 = nn.Sequential(
            nn.Conv2d(68, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialH5 = nn.Sequential(
            nn.Conv2d(68, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalH3 = nn.Sequential(
            nn.Conv2d(65, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalH4 = nn.Sequential(
            nn.Conv2d(65, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalH5 = nn.Sequential(
            nn.Conv2d(65, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalH = nn.Sequential(
            nn.Conv2d(65, 3, kernel_size=1, padding=0))
        
    def forward(self, h):
        h1 = self.initialH3(h)
        h2 = self.initialH4(h)
        h3 = self.initialH5(h)
        mid = torch.cat((h1, h2, h3), 1)
        h4 = self.finalH3(mid)
        h5 = self.finalH4(mid)
        h6 = self.finalH5(mid)
        mid2 = torch.cat((h4, h5, h6), 1)
        out = self.finalH(mid2)
        out_noise = gaussian(out.data, 0, 0.1)
        return out, out_noise

# Reveal Network (2 conv layers)
class RevealNetwork(nn.Module):
    def __init__(self):
        super(RevealNetwork, self).__init__()
        self.initialR3 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialR4 = nn.Sequential(
            nn.Conv2d(3, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialR5 = nn.Sequential(
            nn.Conv2d(3, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalR3 = nn.Sequential(
            nn.Conv2d(65, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalR4 = nn.Sequential(
            nn.Conv2d(65, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalR5 = nn.Sequential(
            nn.Conv2d(65, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalR = nn.Sequential(
            nn.Conv2d(65, 3, kernel_size=1, padding=0))

    def forward(self, r, img_shape):
        # r = r.expand(img_shape)
        r1 = self.initialR3(r)
        r2 = self.initialR4(r)
        r3 = self.initialR5(r)
        mid = torch.cat((r1, r2, r3), 1)
        r4 = self.finalR3(mid)
        r5 = self.finalR4(mid)
        r6 = self.finalR5(mid)
        mid2 = torch.cat((r4, r5, r6), 1)
        out = self.finalR(mid2)
        return out

# Join three networks in one module
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.m1 = PrepNetwork().to(device)
        self.m2 = HidingNetwork().to(device)
        self.m3 = RevealNetwork().to(device)
        self.crop = Crop((0.7,0.9),(0.7,0.9)).to(device)

    def forward(self, secret, cover):
        img_shape = secret.shape
        x_1 = self.m1(secret)
        mid = torch.cat((x_1, cover), 1)
        x_2, x_2_noise = self.m2(mid)
        # x_2_noise = resized_crop(img=x_2_noise, top = 0, left=0, height=19, width=19, size=[64,64])
        x_2 =  resized_crop(img=x_2, top = 0, left=0, height=7, width=7, size=[64,64])
        # x_3 = self.m3(x_2_noise, img_shape)
        x_3 = self.m3(x_2, img_shape)
        return x_2, x_3

# %%
# Creates net object
net = Net().to(device)

# %%
# Creates training set
train_data = datasets.ImageFolder(
        TRAIN_PATH,
        transforms.Compose([
        # transforms.Scale(256),
        # transforms.RandomCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean,
        std=std)
        ]))
train_data = Subset(train_data, [i for i in range(32000)])
train_loader = torch.utils.data.DataLoader(
        train_data, batch_size=batch_size, num_workers=1, 
        pin_memory=True, shuffle=True, drop_last=True)

# Creates test set
test_data = datasets.ImageFolder(
        TEST_PATH, 
        transforms.Compose([
        # transforms.Scale(256),
        # transforms.RandomCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean,
        std=std)
        ]))
test_data = Subset(test_data,[i for i in range(5000)])
test_loader = torch.utils.data.DataLoader(
        test_data, batch_size=2, num_workers=1, 
        pin_memory=True, shuffle=True, drop_last=True)

# %%
PATH = "/content/drive/MyDrive/"
loss_history = []

def train_model(train_loader, beta, learning_rate):
    
    # Save optimizer
    optimizer = optim.Adam(net.parameters(), lr=learning_rate)
    
    loss_history = []
    # Iterate over batches performing forward and backward passes
    for epoch in range(num_epochs):

        # Train mode
        net.train()
        
        train_losses = []
        # Train one epoch
        for idx, train_batch in enumerate(train_loader):

            data, _  = train_batch
            data = data.to(device)

            # Saves secret images and secret covers
            train_covers = data[:len(data)//2]
            train_secrets = data[len(data)//2:]
            
            # Creates variable from secret and cover images
            train_secrets = Variable(train_secrets, requires_grad=False)
            train_covers = Variable(train_covers, requires_grad=False)

            # Forward + Backward + Optimize
            optimizer.zero_grad()
            train_hidden, train_output = net(train_secrets, train_covers)

            # Calculate loss and perform backprop
            train_loss, train_loss_cover, train_loss_secret = customized_loss(train_output, train_hidden, train_secrets, train_covers, beta)
            train_loss.backward()
            optimizer.step()
            
            # Saves training loss
            # print(train_loss.data)
            train_losses.append(train_loss.data.item())
            loss_history.append(train_loss.data.item())
            
            # Prints mini-batch losses
            print('Training: Batch {0}/{1}. Loss of {2:.4f}, cover loss of {3:.4f}, secret loss of {4:.4f}'.format(idx+1, len(train_loader), train_loss.data.item(), train_loss_cover.data.item(), train_loss_secret.data.item()))
    
        # Save model
        # torch.save(net.state_dict(), '/content/Epoch N{}.pkl'.format(epoch+1))
        torch.save(net.state_dict(), PATH+"LOSS3_ds_crop_10.pth")
        with open(PATH+"LOSS3_loss_history_crop_10.txt", "a") as f:
            for s in loss_history:
                f.write(str(s) +"\n")
        
        mean_train_loss = np.mean(train_losses)
    
        # Prints epoch average loss
        print ('Epoch [{0}/{1}], Average_loss: {2:.4f}'.format(
                epoch+1, num_epochs, mean_train_loss))
    
    return net, mean_train_loss, loss_history

# %%
# Load model
# net.load_state_dict(torch.load(PATH+"LOSS3_ds_crop_10.pth"))
# loss_history = []
# with open(PATH+"LOSS3_loss_history_crop_10.txt", "r") as f:
#   for line in f:
#     loss_history.append(float(line.strip()))

net, mean_train_loss, loss_history = train_model(train_loader, beta, learning_rate)
# loss_history.extend(loss_history1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
# Streaming output truncated to the last 5000 lines.
# Training: Batch 6/1000. Loss of 1.1100, cover loss of 1.1014, secret loss of 0.9496
# Training: Batch 7/1000. Loss of 1.2003, cover loss of 1.0765, secret loss of 1.0507
# Training: Batch 8/1000. Loss of 1.1172, cover loss of 1.0885, secret loss of 0.9751
# Training: Batch 9/1000. Loss of 1.1828, cover loss of 1.1168, secret loss of 1.1263
# Training: Batch 10/1000. Loss of 1.2120, cover loss of 1.1102, secret loss of 1.0206
# Training: Batch 11/1000. Loss of 1.3748, cover loss of 1.3363, secret loss of 1.0678
# Training: Batch 12/1000. Loss of 1.1773, cover loss of 0.9978, secret loss of 1.0861
# Training: Batch 13/1000. Loss of 1.2885, cover loss of 1.1487, secret loss of 1.1439
# Training: Batch 14/1000. Loss of 1.2092, cover loss of 1.0811, secret loss of 1.1220
# Training: Batch 15/1000. Loss of 1.2037, cover loss of 1.0254, secret loss of 1.1105
# Training: Batch 16/1000. Loss of 1.1114, cover loss of 1.0210, secret loss of 0.8982
# Training: Batch 17/1000. Loss of 1.2630, cover loss of 1.0777, secret loss of 1.1785
# Training: Batch 18/1000. Loss of 1.1074, cover loss of 0.8786, secret loss of 1.1307
# Training: Batch 19/1000. Loss of 1.1337, cover loss of 1.1449, secret loss of 0.9517
# Training: Batch 20/1000. Loss of 1.2884, cover loss of 1.1632, secret loss of 1.1019
# Training: Batch 21/1000. Loss of 1.2558, cover loss of 1.0672, secret loss of 1.1019
# Training: Batch 22/1000. Loss of 1.1936, cover loss of 1.2292, secret loss of 0.9682
# Training: Batch 23/1000. Loss of 1.1651, cover loss of 1.0461, secret loss of 1.0220
# Training: Batch 24/1000. Loss of 1.3026, cover loss of 0.9560, secret loss of 1.4445
# Training: Batch 25/1000. Loss of 1.4263, cover loss of 1.2040, secret loss of 1.2686
# Training: Batch 26/1000. Loss of 1.3729, cover loss of 1.2550, secret loss of 1.1850
# Training: Batch 27/1000. Loss of 1.0741, cover loss of 0.9273, secret loss of 0.9532
# Training: Batch 28/1000. Loss of 1.3299, cover loss of 1.1865, secret loss of 1.2053
# Training: Batch 29/1000. Loss of 1.1878, cover loss of 0.9532, secret loss of 1.1594
# Training: Batch 30/1000. Loss of 1.1216, cover loss of 0.9053, secret loss of 1.0978
# Training: Batch 31/1000. Loss of 1.3331, cover loss of 1.0925, secret loss of 1.2028
# Training: Batch 32/1000. Loss of 1.2248, cover loss of 1.1227, secret loss of 1.0631
# Training: Batch 33/1000. Loss of 1.2427, cover loss of 1.0637, secret loss of 1.0964
# Training: Batch 34/1000. Loss of 1.1740, cover loss of 0.9964, secret loss of 1.1511
# Training: Batch 35/1000. Loss of 1.3267, cover loss of 1.1929, secret loss of 1.2038
# Training: Batch 36/1000. Loss of 1.0159, cover loss of 0.8640, secret loss of 0.9385
# Training: Batch 37/1000. Loss of 1.2580, cover loss of 1.0180, secret loss of 1.1608
# Training: Batch 38/1000. Loss of 1.3360, cover loss of 1.0888, secret loss of 1.1537
# Training: Batch 39/1000. Loss of 1.1233, cover loss of 0.9618, secret loss of 1.0437
# Training: Batch 40/1000. Loss of 1.3340, cover loss of 1.1859, secret loss of 1.1805
# Training: Batch 41/1000. Loss of 1.1810, cover loss of 1.0777, secret loss of 1.0966
# Training: Batch 42/1000. Loss of 1.2451, cover loss of 1.0411, secret loss of 1.1750
# Training: Batch 43/1000. Loss of 1.3303, cover loss of 1.1050, secret loss of 1.3309
# Training: Batch 44/1000. Loss of 1.2463, cover loss of 1.0484, secret loss of 1.1561
# Training: Batch 45/1000. Loss of 1.3212, cover loss of 1.0283, secret loss of 1.2562
# Training: Batch 46/1000. Loss of 1.3528, cover loss of 1.2572, secret loss of 1.1743
# Training: Batch 47/1000. Loss of 1.2212, cover loss of 1.2163, secret loss of 0.9455
# Training: Batch 48/1000. Loss of 1.1356, cover loss of 1.0347, secret loss of 1.0424
# Training: Batch 49/1000. Loss of 1.1937, cover loss of 0.9820, secret loss of 0.9806
# Training: Batch 50/1000. Loss of 1.1880, cover loss of 1.2422, secret loss of 0.8831
# Training: Batch 51/1000. Loss of 1.2121, cover loss of 1.2039, secret loss of 1.0127
# Training: Batch 52/1000. Loss of 1.3265, cover loss of 1.0804, secret loss of 1.3001
# Training: Batch 53/1000. Loss of 1.0727, cover loss of 0.8597, secret loss of 1.0799
# Training: Batch 54/1000. Loss of 1.1998, cover loss of 1.0931, secret loss of 1.1139
# Training: Batch 55/1000. Loss of 1.2217, cover loss of 1.1319, secret loss of 0.9855
# Training: Batch 56/1000. Loss of 1.3931, cover loss of 1.3759, secret loss of 1.0694
# Training: Batch 57/1000. Loss of 1.2080, cover loss of 1.1100, secret loss of 1.0937
# Training: Batch 58/1000. Loss of 1.3803, cover loss of 1.1959, secret loss of 1.2547
# Training: Batch 59/1000. Loss of 1.2012, cover loss of 1.1901, secret loss of 0.9404
# Training: Batch 60/1000. Loss of 1.1479, cover loss of 0.9664, secret loss of 1.0847
# Training: Batch 61/1000. Loss of 1.1936, cover loss of 1.1064, secret loss of 0.9900
# Training: Batch 62/1000. Loss of 1.4506, cover loss of 1.5551, secret loss of 1.1347
# Training: Batch 63/1000. Loss of 1.1997, cover loss of 1.2861, secret loss of 0.8853
# Training: Batch 64/1000. Loss of 1.2963, cover loss of 1.0573, secret loss of 1.2574
# Training: Batch 65/1000. Loss of 1.2061, cover loss of 0.9841, secret loss of 1.1337
# Training: Batch 66/1000. Loss of 1.0934, cover loss of 0.9231, secret loss of 1.0223
# Training: Batch 67/1000. Loss of 1.0259, cover loss of 0.9750, secret loss of 0.8547
# Training: Batch 68/1000. Loss of 1.3018, cover loss of 1.1799, secret loss of 1.0972
# Training: Batch 69/1000. Loss of 1.3531, cover loss of 1.2795, secret loss of 1.1516
# Training: Batch 70/1000. Loss of 1.2134, cover loss of 1.1386, secret loss of 0.9144
# Training: Batch 71/1000. Loss of 1.1522, cover loss of 1.0072, secret loss of 1.0602
# Training: Batch 72/1000. Loss of 1.2475, cover loss of 1.1457, secret loss of 1.0919
# Training: Batch 73/1000. Loss of 1.1631, cover loss of 0.9568, secret loss of 1.0267
# Training: Batch 74/1000. Loss of 1.2681, cover loss of 1.1184, secret loss of 1.0864
# Training: Batch 75/1000. Loss of 1.3723, cover loss of 1.1856, secret loss of 1.2178
# Training: Batch 76/1000. Loss of 1.2464, cover loss of 0.9782, secret loss of 1.1632
# Training: Batch 77/1000. Loss of 1.2173, cover loss of 0.9678, secret loss of 1.2053
# Training: Batch 78/1000. Loss of 1.2508, cover loss of 1.1757, secret loss of 1.0269
# Training: Batch 79/1000. Loss of 1.2251, cover loss of 0.9836, secret loss of 1.2194
# Training: Batch 80/1000. Loss of 1.1751, cover loss of 1.1076, secret loss of 1.0512
# Training: Batch 81/1000. Loss of 1.2210, cover loss of 1.0875, secret loss of 1.1042
# Training: Batch 82/1000. Loss of 1.3178, cover loss of 1.2162, secret loss of 1.1422
# Training: Batch 83/1000. Loss of 1.2941, cover loss of 1.0468, secret loss of 1.2693
# Training: Batch 84/1000. Loss of 1.2102, cover loss of 1.2794, secret loss of 1.0052
# Training: Batch 85/1000. Loss of 1.0978, cover loss of 0.8753, secret loss of 1.1259
# Training: Batch 86/1000. Loss of 1.3756, cover loss of 1.1692, secret loss of 1.2690
# Training: Batch 87/1000. Loss of 1.1544, cover loss of 1.0045, secret loss of 1.0822
# Training: Batch 88/1000. Loss of 1.3309, cover loss of 1.0792, secret loss of 1.3097
# Training: Batch 89/1000. Loss of 1.0941, cover loss of 0.9763, secret loss of 0.9838
# Training: Batch 90/1000. Loss of 1.1813, cover loss of 0.9674, secret loss of 1.1509
# Training: Batch 91/1000. Loss of 1.2374, cover loss of 0.9359, secret loss of 1.2502
# Training: Batch 92/1000. Loss of 1.3246, cover loss of 1.1644, secret loss of 1.2156
# Training: Batch 93/1000. Loss of 1.3983, cover loss of 1.0189, secret loss of 1.3793
# Training: Batch 94/1000. Loss of 1.1350, cover loss of 1.0540, secret loss of 0.9521
# Training: Batch 95/1000. Loss of 1.4104, cover loss of 1.1437, secret loss of 1.2920
# Training: Batch 96/1000. Loss of 1.1897, cover loss of 1.2726, secret loss of 0.8902
# Training: Batch 97/1000. Loss of 1.1400, cover loss of 1.0839, secret loss of 0.9083
# Training: Batch 98/1000. Loss of 1.2964, cover loss of 1.2757, secret loss of 1.0153
# Training: Batch 99/1000. Loss of 1.1489, cover loss of 1.0631, secret loss of 1.0465
# Training: Batch 100/1000. Loss of 1.0604, cover loss of 0.9347, secret loss of 0.9355
# Training: Batch 101/1000. Loss of 1.3009, cover loss of 1.2927, secret loss of 0.8948
# Training: Batch 102/1000. Loss of 1.3566, cover loss of 1.1447, secret loss of 1.2621
# Training: Batch 103/1000. Loss of 1.1668, cover loss of 1.0634, secret loss of 1.0582
# Training: Batch 104/1000. Loss of 1.2162, cover loss of 1.2376, secret loss of 0.9065
# Training: Batch 105/1000. Loss of 1.2522, cover loss of 1.1981, secret loss of 1.0151
# Training: Batch 106/1000. Loss of 1.1354, cover loss of 0.9350, secret loss of 1.0858
# Training: Batch 107/1000. Loss of 1.3490, cover loss of 0.9731, secret loss of 1.3738
# Training: Batch 108/1000. Loss of 1.0532, cover loss of 0.9000, secret loss of 1.0313
# Training: Batch 109/1000. Loss of 1.0513, cover loss of 0.9448, secret loss of 0.9786
# Training: Batch 110/1000. Loss of 1.0831, cover loss of 0.9506, secret loss of 1.0523
# Training: Batch 111/1000. Loss of 1.2759, cover loss of 1.0947, secret loss of 1.1417
# Training: Batch 112/1000. Loss of 1.1779, cover loss of 1.0597, secret loss of 1.1306
# Training: Batch 113/1000. Loss of 1.5894, cover loss of 1.3745, secret loss of 1.3696
# Training: Batch 114/1000. Loss of 1.2795, cover loss of 1.2992, secret loss of 0.9926
# Training: Batch 115/1000. Loss of 1.2725, cover loss of 1.1961, secret loss of 1.0815
# Training: Batch 116/1000. Loss of 1.2590, cover loss of 1.1109, secret loss of 1.1688
# Training: Batch 117/1000. Loss of 1.2886, cover loss of 1.1980, secret loss of 1.0838
# Training: Batch 118/1000. Loss of 1.1948, cover loss of 1.1213, secret loss of 1.1017
# Training: Batch 119/1000. Loss of 0.9756, cover loss of 0.9732, secret loss of 0.8309
# Training: Batch 120/1000. Loss of 1.2290, cover loss of 1.1565, secret loss of 1.0493
# Training: Batch 121/1000. Loss of 1.0711, cover loss of 0.8846, secret loss of 1.0544
# Training: Batch 122/1000. Loss of 1.1760, cover loss of 1.1788, secret loss of 0.9997
# Training: Batch 123/1000. Loss of 1.2508, cover loss of 1.1042, secret loss of 1.1277
# Training: Batch 124/1000. Loss of 1.3662, cover loss of 1.0525, secret loss of 1.3829
# Training: Batch 125/1000. Loss of 1.3923, cover loss of 1.0859, secret loss of 1.3399
# Training: Batch 126/1000. Loss of 1.2748, cover loss of 1.2394, secret loss of 1.1320
# Training: Batch 127/1000. Loss of 1.1535, cover loss of 1.0794, secret loss of 1.0532
# Training: Batch 128/1000. Loss of 1.2603, cover loss of 1.1863, secret loss of 1.0264
# Training: Batch 129/1000. Loss of 1.2348, cover loss of 1.0927, secret loss of 1.1069
# Training: Batch 130/1000. Loss of 1.3622, cover loss of 1.1455, secret loss of 1.2868
# Training: Batch 131/1000. Loss of 1.0908, cover loss of 1.0727, secret loss of 0.8721
# Training: Batch 132/1000. Loss of 1.2043, cover loss of 0.9718, secret loss of 1.0594
# Training: Batch 133/1000. Loss of 1.1965, cover loss of 0.9943, secret loss of 1.1969
# Training: Batch 134/1000. Loss of 1.4614, cover loss of 1.3472, secret loss of 1.3335
# Training: Batch 135/1000. Loss of 1.1227, cover loss of 1.0209, secret loss of 0.9947
# Training: Batch 136/1000. Loss of 1.1709, cover loss of 0.9978, secret loss of 1.0922
# Training: Batch 137/1000. Loss of 1.1146, cover loss of 0.9871, secret loss of 0.9958
# Training: Batch 138/1000. Loss of 1.2460, cover loss of 1.0864, secret loss of 1.1510
# Training: Batch 139/1000. Loss of 1.4049, cover loss of 1.1470, secret loss of 1.3275
# Training: Batch 140/1000. Loss of 1.3265, cover loss of 1.2670, secret loss of 1.0882
# Training: Batch 141/1000. Loss of 1.2996, cover loss of 1.0878, secret loss of 1.1326
# Training: Batch 142/1000. Loss of 1.2057, cover loss of 1.1826, secret loss of 1.0010
# Training: Batch 143/1000. Loss of 1.2765, cover loss of 1.1246, secret loss of 1.1317
# Training: Batch 144/1000. Loss of 1.1508, cover loss of 0.9493, secret loss of 1.1498
# Training: Batch 145/1000. Loss of 1.2018, cover loss of 1.0864, secret loss of 1.0662
# Training: Batch 146/1000. Loss of 1.3358, cover loss of 1.1634, secret loss of 1.2202
# Training: Batch 147/1000. Loss of 1.1965, cover loss of 1.0503, secret loss of 1.1425
# Training: Batch 148/1000. Loss of 1.3020, cover loss of 1.1229, secret loss of 1.1909
# Training: Batch 149/1000. Loss of 1.0955, cover loss of 1.1044, secret loss of 0.9043
# Training: Batch 150/1000. Loss of 1.2277, cover loss of 1.0681, secret loss of 1.0535
# Training: Batch 151/1000. Loss of 1.1371, cover loss of 0.9604, secret loss of 1.0941
# Training: Batch 152/1000. Loss of 1.3840, cover loss of 1.0669, secret loss of 1.3078
# Training: Batch 153/1000. Loss of 1.4902, cover loss of 1.4131, secret loss of 1.1636
# Training: Batch 154/1000. Loss of 1.2229, cover loss of 1.2291, secret loss of 0.7971
# Training: Batch 155/1000. Loss of 1.1617, cover loss of 1.0648, secret loss of 0.9324
# Training: Batch 156/1000. Loss of 1.5375, cover loss of 1.2700, secret loss of 1.4537
# Training: Batch 157/1000. Loss of 1.1398, cover loss of 1.0716, secret loss of 0.9543
# Training: Batch 158/1000. Loss of 1.1849, cover loss of 1.1015, secret loss of 1.0680
# Training: Batch 159/1000. Loss of 1.2005, cover loss of 1.0322, secret loss of 1.0436
# Training: Batch 160/1000. Loss of 1.1617, cover loss of 0.9051, secret loss of 1.1707
# Training: Batch 161/1000. Loss of 1.1616, cover loss of 0.9291, secret loss of 1.1172
# Training: Batch 162/1000. Loss of 1.1731, cover loss of 1.1501, secret loss of 0.9273
# Training: Batch 163/1000. Loss of 1.2684, cover loss of 1.0812, secret loss of 1.1091
# Training: Batch 164/1000. Loss of 1.0865, cover loss of 0.9883, secret loss of 0.9922
# Training: Batch 165/1000. Loss of 1.1953, cover loss of 1.0435, secret loss of 1.0017
# Training: Batch 166/1000. Loss of 1.2805, cover loss of 1.2353, secret loss of 1.0916
# Training: Batch 167/1000. Loss of 1.5054, cover loss of 1.3872, secret loss of 1.2836
# Training: Batch 168/1000. Loss of 1.2124, cover loss of 1.0718, secret loss of 1.0527
# Training: Batch 169/1000. Loss of 1.4325, cover loss of 1.1756, secret loss of 1.2854
# Training: Batch 170/1000. Loss of 1.0927, cover loss of 0.9960, secret loss of 0.8907
# Training: Batch 171/1000. Loss of 1.4062, cover loss of 1.2098, secret loss of 1.2139
# Training: Batch 172/1000. Loss of 1.4133, cover loss of 1.3088, secret loss of 1.1539
# Training: Batch 173/1000. Loss of 1.3378, cover loss of 1.1895, secret loss of 1.1324
# Training: Batch 174/1000. Loss of 1.1797, cover loss of 1.1301, secret loss of 1.0257
# Training: Batch 175/1000. Loss of 1.3475, cover loss of 1.1721, secret loss of 1.1590
# Training: Batch 176/1000. Loss of 1.1664, cover loss of 1.0446, secret loss of 1.0637
# Training: Batch 177/1000. Loss of 1.0669, cover loss of 0.9134, secret loss of 1.0504
# Training: Batch 178/1000. Loss of 1.3786, cover loss of 1.2732, secret loss of 1.2471
# Training: Batch 179/1000. Loss of 1.2889, cover loss of 1.1829, secret loss of 1.0605
# Training: Batch 180/1000. Loss of 1.3124, cover loss of 1.0725, secret loss of 1.1211
# Training: Batch 181/1000. Loss of 1.3201, cover loss of 1.2934, secret loss of 1.0281
# Training: Batch 182/1000. Loss of 1.2320, cover loss of 1.0540, secret loss of 1.1758
# Training: Batch 183/1000. Loss of 1.4141, cover loss of 1.3587, secret loss of 1.2050
# Training: Batch 184/1000. Loss of 1.0880, cover loss of 1.0372, secret loss of 0.9589
# Training: Batch 185/1000. Loss of 1.4158, cover loss of 1.2595, secret loss of 1.1953
# Training: Batch 186/1000. Loss of 1.3268, cover loss of 1.0343, secret loss of 1.2544
# Training: Batch 187/1000. Loss of 1.1688, cover loss of 0.9997, secret loss of 1.0786
# Training: Batch 188/1000. Loss of 1.1502, cover loss of 0.9052, secret loss of 1.1790
# Training: Batch 189/1000. Loss of 1.3372, cover loss of 1.2444, secret loss of 1.1095
# Training: Batch 190/1000. Loss of 1.4868, cover loss of 1.0635, secret loss of 1.3731
# Training: Batch 191/1000. Loss of 1.2968, cover loss of 1.1742, secret loss of 1.1330
# Training: Batch 192/1000. Loss of 1.4007, cover loss of 1.0362, secret loss of 1.3404
# Training: Batch 193/1000. Loss of 1.3645, cover loss of 1.1965, secret loss of 1.2053
# Training: Batch 194/1000. Loss of 1.3277, cover loss of 1.1077, secret loss of 1.2821
# Training: Batch 195/1000. Loss of 1.4000, cover loss of 1.3061, secret loss of 1.1771
# Training: Batch 196/1000. Loss of 1.2912, cover loss of 1.1584, secret loss of 1.1202
# Training: Batch 197/1000. Loss of 1.0748, cover loss of 0.9469, secret loss of 0.9950
# Training: Batch 198/1000. Loss of 1.2331, cover loss of 1.1110, secret loss of 1.0853
# Training: Batch 199/1000. Loss of 1.1704, cover loss of 1.0462, secret loss of 0.9980
# Training: Batch 200/1000. Loss of 1.2076, cover loss of 1.0169, secret loss of 1.0642
# Training: Batch 201/1000. Loss of 1.1517, cover loss of 1.1195, secret loss of 0.9913
# Training: Batch 202/1000. Loss of 1.3212, cover loss of 1.2278, secret loss of 1.2114
# Training: Batch 203/1000. Loss of 1.0732, cover loss of 0.9244, secret loss of 1.0644
# Training: Batch 204/1000. Loss of 1.0987, cover loss of 0.8581, secret loss of 1.0678
# Training: Batch 205/1000. Loss of 1.0351, cover loss of 0.9752, secret loss of 0.9041
# Training: Batch 206/1000. Loss of 1.2692, cover loss of 1.3565, secret loss of 0.8876
# Training: Batch 207/1000. Loss of 1.1926, cover loss of 1.1253, secret loss of 0.9915
# Training: Batch 208/1000. Loss of 1.1641, cover loss of 1.0487, secret loss of 1.0073
# Training: Batch 209/1000. Loss of 1.0827, cover loss of 0.7743, secret loss of 1.1358
# Training: Batch 210/1000. Loss of 1.0654, cover loss of 0.8424, secret loss of 0.9804
# Training: Batch 211/1000. Loss of 1.2378, cover loss of 1.1762, secret loss of 1.0078
# Training: Batch 212/1000. Loss of 1.2381, cover loss of 1.1609, secret loss of 1.0249
# Training: Batch 213/1000. Loss of 1.1249, cover loss of 1.0705, secret loss of 0.9645
# Training: Batch 214/1000. Loss of 1.2669, cover loss of 1.1211, secret loss of 1.1513
# Training: Batch 215/1000. Loss of 1.5169, cover loss of 1.2065, secret loss of 1.4424
# Training: Batch 216/1000. Loss of 1.1944, cover loss of 1.0390, secret loss of 1.0800
# Training: Batch 217/1000. Loss of 1.2763, cover loss of 1.1349, secret loss of 1.1616
# Training: Batch 218/1000. Loss of 1.1154, cover loss of 0.9296, secret loss of 1.0173
# Training: Batch 219/1000. Loss of 1.2849, cover loss of 1.2201, secret loss of 1.0569
# Training: Batch 220/1000. Loss of 1.4295, cover loss of 1.2085, secret loss of 1.2795
# Training: Batch 221/1000. Loss of 1.1081, cover loss of 0.8717, secret loss of 1.1734
# Training: Batch 222/1000. Loss of 1.4553, cover loss of 1.1804, secret loss of 1.4531
# Training: Batch 223/1000. Loss of 1.1560, cover loss of 1.0428, secret loss of 1.0358
# Training: Batch 224/1000. Loss of 1.2947, cover loss of 1.1221, secret loss of 1.2073
# Training: Batch 225/1000. Loss of 1.2262, cover loss of 1.1149, secret loss of 1.0683
# Training: Batch 226/1000. Loss of 1.1307, cover loss of 1.1143, secret loss of 0.9038
# Training: Batch 227/1000. Loss of 1.2476, cover loss of 1.2063, secret loss of 1.0040
# Training: Batch 228/1000. Loss of 1.1875, cover loss of 1.0609, secret loss of 1.0493
# Training: Batch 229/1000. Loss of 1.2470, cover loss of 1.1271, secret loss of 1.0782
# Training: Batch 230/1000. Loss of 1.2264, cover loss of 1.0049, secret loss of 1.1051
# Training: Batch 231/1000. Loss of 1.2656, cover loss of 1.1070, secret loss of 1.1448
# Training: Batch 232/1000. Loss of 1.2156, cover loss of 0.9864, secret loss of 1.1849
# Training: Batch 233/1000. Loss of 1.1853, cover loss of 1.0993, secret loss of 0.9599
# Training: Batch 234/1000. Loss of 1.2558, cover loss of 1.1567, secret loss of 1.0314
# Training: Batch 235/1000. Loss of 1.2049, cover loss of 0.9444, secret loss of 1.1467
# Training: Batch 236/1000. Loss of 1.2106, cover loss of 1.0084, secret loss of 1.1480
# Training: Batch 237/1000. Loss of 1.3014, cover loss of 1.1174, secret loss of 1.1928
# Training: Batch 238/1000. Loss of 1.1043, cover loss of 1.0608, secret loss of 0.8943
# Training: Batch 239/1000. Loss of 1.3400, cover loss of 1.1272, secret loss of 1.1790
# Training: Batch 240/1000. Loss of 1.2584, cover loss of 1.2568, secret loss of 1.0229
# Training: Batch 241/1000. Loss of 1.2188, cover loss of 1.0689, secret loss of 1.1637
# Training: Batch 242/1000. Loss of 1.1877, cover loss of 1.0756, secret loss of 1.0545
# Training: Batch 243/1000. Loss of 1.2972, cover loss of 1.1552, secret loss of 1.1064
# Training: Batch 244/1000. Loss of 1.1024, cover loss of 0.9773, secret loss of 1.0081
# Training: Batch 245/1000. Loss of 1.1799, cover loss of 0.9130, secret loss of 1.2366
# Training: Batch 246/1000. Loss of 1.2667, cover loss of 1.2451, secret loss of 0.9391
# Training: Batch 247/1000. Loss of 1.1996, cover loss of 1.0114, secret loss of 1.1372
# Training: Batch 248/1000. Loss of 1.2965, cover loss of 1.0515, secret loss of 1.2411
# Training: Batch 249/1000. Loss of 1.2423, cover loss of 1.1150, secret loss of 1.1578
# Training: Batch 250/1000. Loss of 1.2123, cover loss of 1.0528, secret loss of 1.1409
# Training: Batch 251/1000. Loss of 1.2431, cover loss of 1.1926, secret loss of 1.0564
# Training: Batch 252/1000. Loss of 1.0654, cover loss of 0.9454, secret loss of 0.9673
# Training: Batch 253/1000. Loss of 1.2543, cover loss of 1.0413, secret loss of 1.2271
# Training: Batch 254/1000. Loss of 1.0578, cover loss of 1.0320, secret loss of 0.8975
# Training: Batch 255/1000. Loss of 1.2558, cover loss of 1.1656, secret loss of 1.1355
# Training: Batch 256/1000. Loss of 1.2178, cover loss of 1.0457, secret loss of 1.0238
# Training: Batch 257/1000. Loss of 1.2396, cover loss of 1.0125, secret loss of 1.1503
# Training: Batch 258/1000. Loss of 1.3390, cover loss of 1.2660, secret loss of 1.0805
# Training: Batch 259/1000. Loss of 1.1027, cover loss of 1.1340, secret loss of 0.9179
# Training: Batch 260/1000. Loss of 1.0442, cover loss of 0.9405, secret loss of 0.9941
# Training: Batch 261/1000. Loss of 1.3029, cover loss of 1.0302, secret loss of 1.2576
# Training: Batch 262/1000. Loss of 1.0717, cover loss of 1.0103, secret loss of 0.9479
# Training: Batch 263/1000. Loss of 1.0512, cover loss of 0.8525, secret loss of 0.9889
# Training: Batch 264/1000. Loss of 1.2661, cover loss of 0.9801, secret loss of 1.3163
# Training: Batch 265/1000. Loss of 1.3548, cover loss of 1.3730, secret loss of 1.0383
# Training: Batch 266/1000. Loss of 1.3161, cover loss of 1.1791, secret loss of 1.1832
# Training: Batch 267/1000. Loss of 1.2722, cover loss of 1.0210, secret loss of 1.2338
# Training: Batch 268/1000. Loss of 1.1329, cover loss of 1.0334, secret loss of 1.0087
# Training: Batch 269/1000. Loss of 1.2483, cover loss of 1.0904, secret loss of 1.0780
# Training: Batch 270/1000. Loss of 1.2730, cover loss of 1.1541, secret loss of 1.1108
# Training: Batch 271/1000. Loss of 1.3115, cover loss of 1.0921, secret loss of 1.1996
# Training: Batch 272/1000. Loss of 1.3177, cover loss of 1.1606, secret loss of 1.2418
# Training: Batch 273/1000. Loss of 1.2088, cover loss of 1.1171, secret loss of 1.0456
# Training: Batch 274/1000. Loss of 1.1311, cover loss of 0.9219, secret loss of 1.0728
# Training: Batch 275/1000. Loss of 1.0915, cover loss of 0.8646, secret loss of 1.1252
# Training: Batch 276/1000. Loss of 1.4590, cover loss of 1.4243, secret loss of 1.1060
# Training: Batch 277/1000. Loss of 1.1072, cover loss of 1.1329, secret loss of 0.8496
# Training: Batch 278/1000. Loss of 1.3584, cover loss of 0.9651, secret loss of 1.4212
# Training: Batch 279/1000. Loss of 1.0579, cover loss of 0.9259, secret loss of 0.9343
# Training: Batch 280/1000. Loss of 1.3383, cover loss of 1.1139, secret loss of 1.2452
# Training: Batch 281/1000. Loss of 1.2156, cover loss of 1.1051, secret loss of 1.0682
# Training: Batch 282/1000. Loss of 1.1988, cover loss of 1.0936, secret loss of 0.9809
# Training: Batch 283/1000. Loss of 1.1566, cover loss of 0.9571, secret loss of 1.1148
# Training: Batch 284/1000. Loss of 1.1058, cover loss of 1.0102, secret loss of 0.9298
# Training: Batch 285/1000. Loss of 1.3200, cover loss of 0.9802, secret loss of 1.3742
# Training: Batch 286/1000. Loss of 1.2843, cover loss of 1.0151, secret loss of 1.2631
# Training: Batch 287/1000. Loss of 1.2628, cover loss of 1.0795, secret loss of 1.1776
# Training: Batch 288/1000. Loss of 1.2504, cover loss of 1.2531, secret loss of 1.0287
# Training: Batch 289/1000. Loss of 1.3756, cover loss of 1.2442, secret loss of 1.2666
# Training: Batch 290/1000. Loss of 1.1779, cover loss of 1.0346, secret loss of 1.0434
# Training: Batch 291/1000. Loss of 1.1383, cover loss of 0.9226, secret loss of 1.1302
# Training: Batch 292/1000. Loss of 1.1608, cover loss of 1.0780, secret loss of 0.9954
# Training: Batch 293/1000. Loss of 1.3275, cover loss of 1.1334, secret loss of 1.2654
# Training: Batch 294/1000. Loss of 1.3126, cover loss of 1.2751, secret loss of 1.1664
# Training: Batch 295/1000. Loss of 1.2886, cover loss of 1.2640, secret loss of 1.1196
# Training: Batch 296/1000. Loss of 1.3410, cover loss of 1.3012, secret loss of 1.0800
# Training: Batch 297/1000. Loss of 1.2700, cover loss of 1.1369, secret loss of 1.1343
# Training: Batch 298/1000. Loss of 1.3131, cover loss of 1.2797, secret loss of 1.0419
# Training: Batch 299/1000. Loss of 1.3515, cover loss of 1.0205, secret loss of 1.3270
# Training: Batch 300/1000. Loss of 1.2493, cover loss of 1.1333, secret loss of 1.0580
# Training: Batch 301/1000. Loss of 1.2061, cover loss of 1.2573, secret loss of 0.7879
# Training: Batch 302/1000. Loss of 0.9586, cover loss of 0.8854, secret loss of 0.8435
# Training: Batch 303/1000. Loss of 1.0710, cover loss of 0.9519, secret loss of 0.9936
# Training: Batch 304/1000. Loss of 1.3316, cover loss of 1.1684, secret loss of 1.1950
# Training: Batch 305/1000. Loss of 1.4258, cover loss of 1.3830, secret loss of 1.1777
# Training: Batch 306/1000. Loss of 1.3102, cover loss of 1.1777, secret loss of 1.1353
# Training: Batch 307/1000. Loss of 1.0589, cover loss of 0.9964, secret loss of 0.9339
# Training: Batch 308/1000. Loss of 1.1813, cover loss of 1.0980, secret loss of 1.0461
# Training: Batch 309/1000. Loss of 1.1551, cover loss of 1.0709, secret loss of 0.9784
# Training: Batch 310/1000. Loss of 1.0338, cover loss of 0.8853, secret loss of 0.9837
# Training: Batch 311/1000. Loss of 1.2978, cover loss of 1.2211, secret loss of 1.0239
# Training: Batch 312/1000. Loss of 0.9960, cover loss of 0.9704, secret loss of 0.8729
# Training: Batch 313/1000. Loss of 1.1162, cover loss of 1.0300, secret loss of 0.9749
# Training: Batch 314/1000. Loss of 1.3582, cover loss of 1.1106, secret loss of 1.1791
# Training: Batch 315/1000. Loss of 1.2132, cover loss of 0.9521, secret loss of 1.1033
# Training: Batch 316/1000. Loss of 1.2485, cover loss of 1.1384, secret loss of 1.1002
# Training: Batch 317/1000. Loss of 1.1148, cover loss of 1.0412, secret loss of 1.0056
# Training: Batch 318/1000. Loss of 1.1750, cover loss of 0.9932, secret loss of 1.0948
# Training: Batch 319/1000. Loss of 1.2843, cover loss of 1.2070, secret loss of 1.0548
# Training: Batch 320/1000. Loss of 1.2829, cover loss of 1.3228, secret loss of 1.0232
# Training: Batch 321/1000. Loss of 1.1745, cover loss of 1.0883, secret loss of 1.0313
# Training: Batch 322/1000. Loss of 1.1927, cover loss of 0.9659, secret loss of 1.0149
# Training: Batch 323/1000. Loss of 1.1489, cover loss of 0.8840, secret loss of 1.0844
# Training: Batch 324/1000. Loss of 1.2229, cover loss of 1.1019, secret loss of 1.0619
# Training: Batch 325/1000. Loss of 1.1416, cover loss of 1.0406, secret loss of 0.9966
# Training: Batch 326/1000. Loss of 1.1991, cover loss of 1.1385, secret loss of 1.0043
# Training: Batch 327/1000. Loss of 1.1745, cover loss of 1.0817, secret loss of 1.0239
# Training: Batch 328/1000. Loss of 1.3228, cover loss of 1.0876, secret loss of 1.2992
# Training: Batch 329/1000. Loss of 1.2601, cover loss of 1.0619, secret loss of 1.1602
# Training: Batch 330/1000. Loss of 1.3339, cover loss of 1.1555, secret loss of 1.1915
# Training: Batch 331/1000. Loss of 1.0819, cover loss of 1.0363, secret loss of 0.9541
# Training: Batch 332/1000. Loss of 1.0740, cover loss of 0.9860, secret loss of 0.9498
# Training: Batch 333/1000. Loss of 1.2049, cover loss of 1.0265, secret loss of 1.1569
# Training: Batch 334/1000. Loss of 1.3882, cover loss of 1.3569, secret loss of 1.2116
# Training: Batch 335/1000. Loss of 1.4623, cover loss of 1.5221, secret loss of 1.1390
# Training: Batch 336/1000. Loss of 1.1226, cover loss of 0.9924, secret loss of 1.0177
# Training: Batch 337/1000. Loss of 1.1907, cover loss of 0.9967, secret loss of 1.1158
# Training: Batch 338/1000. Loss of 1.3135, cover loss of 1.0851, secret loss of 1.1502
# Training: Batch 339/1000. Loss of 1.3027, cover loss of 1.2597, secret loss of 1.0100
# Training: Batch 340/1000. Loss of 1.3325, cover loss of 1.2300, secret loss of 1.0328
# Training: Batch 341/1000. Loss of 1.2533, cover loss of 1.0683, secret loss of 1.1445
# Training: Batch 342/1000. Loss of 1.2880, cover loss of 1.1733, secret loss of 1.2147
# Training: Batch 343/1000. Loss of 1.4508, cover loss of 1.1245, secret loss of 1.3698
# Training: Batch 344/1000. Loss of 1.1286, cover loss of 0.9327, secret loss of 1.0445
# Training: Batch 345/1000. Loss of 1.0744, cover loss of 1.0268, secret loss of 0.8502
# Training: Batch 346/1000. Loss of 1.3041, cover loss of 1.0692, secret loss of 1.2727
# Training: Batch 347/1000. Loss of 1.0870, cover loss of 1.0720, secret loss of 0.8370
# Training: Batch 348/1000. Loss of 1.1823, cover loss of 1.0737, secret loss of 1.0413
# Training: Batch 349/1000. Loss of 1.1953, cover loss of 1.0841, secret loss of 1.0730
# Training: Batch 350/1000. Loss of 1.3360, cover loss of 1.1671, secret loss of 1.2366
# Training: Batch 351/1000. Loss of 1.3119, cover loss of 1.1860, secret loss of 1.1687
# Training: Batch 352/1000. Loss of 1.1596, cover loss of 0.9444, secret loss of 1.1360
# Training: Batch 353/1000. Loss of 1.2903, cover loss of 1.2382, secret loss of 1.1059
# Training: Batch 354/1000. Loss of 1.0704, cover loss of 0.8062, secret loss of 1.1009
# Training: Batch 355/1000. Loss of 1.1813, cover loss of 0.9740, secret loss of 1.1751
# Training: Batch 356/1000. Loss of 1.2850, cover loss of 1.2087, secret loss of 1.1488
# Training: Batch 357/1000. Loss of 1.2373, cover loss of 1.2173, secret loss of 1.0270
# Training: Batch 358/1000. Loss of 1.1556, cover loss of 0.8828, secret loss of 1.1439
# Training: Batch 359/1000. Loss of 1.2136, cover loss of 0.9342, secret loss of 1.1978
# Training: Batch 360/1000. Loss of 1.1322, cover loss of 1.0247, secret loss of 0.9732
# Training: Batch 361/1000. Loss of 1.2641, cover loss of 1.1657, secret loss of 1.0619
# Training: Batch 362/1000. Loss of 1.0356, cover loss of 0.8812, secret loss of 1.0161
# Training: Batch 363/1000. Loss of 1.1650, cover loss of 1.1055, secret loss of 1.0116
# Training: Batch 364/1000. Loss of 1.3578, cover loss of 1.2227, secret loss of 1.1734
# Training: Batch 365/1000. Loss of 1.2865, cover loss of 1.2036, secret loss of 1.0954
# Training: Batch 366/1000. Loss of 1.2274, cover loss of 1.2199, secret loss of 0.9706
# Training: Batch 367/1000. Loss of 1.1227, cover loss of 1.0856, secret loss of 1.0151
# Training: Batch 368/1000. Loss of 1.1953, cover loss of 0.9562, secret loss of 1.1843
# Training: Batch 369/1000. Loss of 1.1560, cover loss of 1.0469, secret loss of 1.0528
# Training: Batch 370/1000. Loss of 1.0913, cover loss of 0.9865, secret loss of 0.9668
# Training: Batch 371/1000. Loss of 1.2667, cover loss of 1.0624, secret loss of 1.0750
# Training: Batch 372/1000. Loss of 1.1354, cover loss of 0.9640, secret loss of 1.0738
# Training: Batch 373/1000. Loss of 1.0638, cover loss of 0.9678, secret loss of 0.9641
# Training: Batch 374/1000. Loss of 1.2966, cover loss of 1.3037, secret loss of 1.0168
# Training: Batch 375/1000. Loss of 1.2093, cover loss of 1.1563, secret loss of 1.0094
# Training: Batch 376/1000. Loss of 1.1617, cover loss of 1.0631, secret loss of 0.9899
# Training: Batch 377/1000. Loss of 1.0312, cover loss of 0.8187, secret loss of 1.0103
# Training: Batch 378/1000. Loss of 1.0730, cover loss of 1.0360, secret loss of 0.8120
# Training: Batch 379/1000. Loss of 1.2968, cover loss of 1.1385, secret loss of 1.1647
# Training: Batch 380/1000. Loss of 1.0491, cover loss of 1.0016, secret loss of 0.8810
# Training: Batch 381/1000. Loss of 1.2938, cover loss of 1.1589, secret loss of 1.1633
# Training: Batch 382/1000. Loss of 1.3796, cover loss of 1.1403, secret loss of 1.3322
# Training: Batch 383/1000. Loss of 1.1481, cover loss of 1.0190, secret loss of 1.1177
# Training: Batch 384/1000. Loss of 0.8937, cover loss of 0.8251, secret loss of 0.8134
# Training: Batch 385/1000. Loss of 1.1785, cover loss of 0.9966, secret loss of 1.1063
# Training: Batch 386/1000. Loss of 1.2584, cover loss of 1.0865, secret loss of 1.1202
# Training: Batch 387/1000. Loss of 1.2717, cover loss of 1.0432, secret loss of 1.2027
# Training: Batch 388/1000. Loss of 1.2118, cover loss of 0.9441, secret loss of 1.2504
# Training: Batch 389/1000. Loss of 1.2002, cover loss of 1.0955, secret loss of 1.0702
# Training: Batch 390/1000. Loss of 1.0703, cover loss of 1.0109, secret loss of 0.8918
# Training: Batch 391/1000. Loss of 1.2513, cover loss of 1.1680, secret loss of 1.0467
# Training: Batch 392/1000. Loss of 1.1466, cover loss of 0.9671, secret loss of 1.1359
# Training: Batch 393/1000. Loss of 1.2530, cover loss of 1.1593, secret loss of 1.1179
# Training: Batch 394/1000. Loss of 1.0950, cover loss of 0.9031, secret loss of 1.0283
# Training: Batch 395/1000. Loss of 1.2290, cover loss of 1.0703, secret loss of 1.0966
# Training: Batch 396/1000. Loss of 1.2468, cover loss of 1.1136, secret loss of 1.1261
# Training: Batch 397/1000. Loss of 1.2401, cover loss of 1.2358, secret loss of 0.9679
# Training: Batch 398/1000. Loss of 1.3407, cover loss of 1.1598, secret loss of 1.2153
# Training: Batch 399/1000. Loss of 1.2351, cover loss of 1.0372, secret loss of 1.1822
# Training: Batch 400/1000. Loss of 1.2020, cover loss of 1.0742, secret loss of 1.0511
# Training: Batch 401/1000. Loss of 1.2397, cover loss of 1.0113, secret loss of 1.1756
# Training: Batch 402/1000. Loss of 1.2193, cover loss of 1.0400, secret loss of 1.0370
# Training: Batch 403/1000. Loss of 1.1999, cover loss of 1.0457, secret loss of 1.0870
# Training: Batch 404/1000. Loss of 1.2585, cover loss of 1.2064, secret loss of 1.0917
# Training: Batch 405/1000. Loss of 1.2602, cover loss of 1.0389, secret loss of 1.2034
# Training: Batch 406/1000. Loss of 1.1995, cover loss of 1.1835, secret loss of 1.0200
# Training: Batch 407/1000. Loss of 1.1432, cover loss of 1.0660, secret loss of 1.0624
# Training: Batch 408/1000. Loss of 1.3418, cover loss of 1.0893, secret loss of 1.3626
# Training: Batch 409/1000. Loss of 1.5410, cover loss of 1.4226, secret loss of 1.2440
# Training: Batch 410/1000. Loss of 1.1548, cover loss of 1.1275, secret loss of 0.9525
# Training: Batch 411/1000. Loss of 1.1872, cover loss of 1.0903, secret loss of 1.0896
# Training: Batch 412/1000. Loss of 1.2384, cover loss of 1.0217, secret loss of 1.1750
# Training: Batch 413/1000. Loss of 1.0934, cover loss of 1.0478, secret loss of 0.9152
# Training: Batch 414/1000. Loss of 1.1532, cover loss of 1.0508, secret loss of 1.0417
# Training: Batch 415/1000. Loss of 1.2994, cover loss of 1.2376, secret loss of 1.1382
# Training: Batch 416/1000. Loss of 1.4185, cover loss of 1.1695, secret loss of 1.3034
# Training: Batch 417/1000. Loss of 1.3921, cover loss of 1.2495, secret loss of 1.1562
# Training: Batch 418/1000. Loss of 1.2290, cover loss of 1.1343, secret loss of 1.0270
# Training: Batch 419/1000. Loss of 1.1909, cover loss of 1.1919, secret loss of 0.9496
# Training: Batch 420/1000. Loss of 1.2756, cover loss of 1.2302, secret loss of 1.0034
# Training: Batch 421/1000. Loss of 1.3926, cover loss of 1.2820, secret loss of 1.1496
# Training: Batch 422/1000. Loss of 1.0378, cover loss of 1.0344, secret loss of 0.8466
# Training: Batch 423/1000. Loss of 1.2617, cover loss of 1.2305, secret loss of 0.9320
# Training: Batch 424/1000. Loss of 1.2581, cover loss of 1.0483, secret loss of 1.1173
# Training: Batch 425/1000. Loss of 1.4146, cover loss of 1.2578, secret loss of 1.2287
# Training: Batch 426/1000. Loss of 1.1717, cover loss of 1.1243, secret loss of 1.0497
# Training: Batch 427/1000. Loss of 1.1309, cover loss of 1.0169, secret loss of 0.9687
# Training: Batch 428/1000. Loss of 1.1203, cover loss of 1.0350, secret loss of 0.9093
# Training: Batch 429/1000. Loss of 1.2883, cover loss of 1.2432, secret loss of 0.9298
# Training: Batch 430/1000. Loss of 1.2543, cover loss of 1.2189, secret loss of 1.0525
# Training: Batch 431/1000. Loss of 1.2624, cover loss of 1.1164, secret loss of 1.2038
# Training: Batch 432/1000. Loss of 1.4906, cover loss of 1.3667, secret loss of 1.2414
# Training: Batch 433/1000. Loss of 1.2225, cover loss of 1.1655, secret loss of 1.0671
# Training: Batch 434/1000. Loss of 1.1961, cover loss of 1.1715, secret loss of 0.9811
# Training: Batch 435/1000. Loss of 1.2943, cover loss of 1.3851, secret loss of 0.9221
# Training: Batch 436/1000. Loss of 1.1960, cover loss of 1.1531, secret loss of 0.9933
# Training: Batch 437/1000. Loss of 1.2573, cover loss of 1.2539, secret loss of 1.0371
# Training: Batch 438/1000. Loss of 1.3307, cover loss of 1.0725, secret loss of 1.2662
# Training: Batch 439/1000. Loss of 1.3827, cover loss of 1.1782, secret loss of 1.1784
# Training: Batch 440/1000. Loss of 0.9654, cover loss of 0.7698, secret loss of 0.9639
# Training: Batch 441/1000. Loss of 1.3445, cover loss of 1.2224, secret loss of 1.2284
# Training: Batch 442/1000. Loss of 1.2458, cover loss of 1.0156, secret loss of 1.2043
# Training: Batch 443/1000. Loss of 1.2189, cover loss of 1.2444, secret loss of 0.9541
# Training: Batch 444/1000. Loss of 1.2589, cover loss of 1.1027, secret loss of 1.0732
# Training: Batch 445/1000. Loss of 1.0897, cover loss of 1.0068, secret loss of 0.9394
# Training: Batch 446/1000. Loss of 1.1070, cover loss of 1.0052, secret loss of 1.0231
# Training: Batch 447/1000. Loss of 1.0890, cover loss of 0.9744, secret loss of 1.0042
# Training: Batch 448/1000. Loss of 1.3749, cover loss of 1.2908, secret loss of 1.1768
# Training: Batch 449/1000. Loss of 1.3059, cover loss of 1.0978, secret loss of 1.1788
# Training: Batch 450/1000. Loss of 1.1900, cover loss of 1.0548, secret loss of 1.0159
# Training: Batch 451/1000. Loss of 1.2092, cover loss of 1.0739, secret loss of 1.0191
# Training: Batch 452/1000. Loss of 1.0937, cover loss of 0.9585, secret loss of 0.9970
# Training: Batch 453/1000. Loss of 1.3613, cover loss of 1.1739, secret loss of 1.2739
# Training: Batch 454/1000. Loss of 1.1104, cover loss of 0.9632, secret loss of 1.0584
# Training: Batch 455/1000. Loss of 1.0864, cover loss of 0.9709, secret loss of 0.9122
# Training: Batch 456/1000. Loss of 1.2979, cover loss of 1.1731, secret loss of 1.1025
# Training: Batch 457/1000. Loss of 1.1658, cover loss of 0.9642, secret loss of 1.1178
# Training: Batch 458/1000. Loss of 1.1524, cover loss of 1.0737, secret loss of 1.0218
# Training: Batch 459/1000. Loss of 1.1429, cover loss of 0.9512, secret loss of 1.1319
# Training: Batch 460/1000. Loss of 1.1206, cover loss of 0.9465, secret loss of 1.0610
# Training: Batch 461/1000. Loss of 1.1889, cover loss of 0.9927, secret loss of 1.1433
# Training: Batch 462/1000. Loss of 1.2171, cover loss of 1.0167, secret loss of 1.2184
# Training: Batch 463/1000. Loss of 1.1555, cover loss of 1.0976, secret loss of 0.9390
# Training: Batch 464/1000. Loss of 1.2168, cover loss of 1.0770, secret loss of 1.1480
# Training: Batch 465/1000. Loss of 1.3293, cover loss of 1.1068, secret loss of 1.2180
# Training: Batch 466/1000. Loss of 1.1783, cover loss of 1.0777, secret loss of 1.0791
# Training: Batch 467/1000. Loss of 1.2736, cover loss of 1.1277, secret loss of 1.0999
# Training: Batch 468/1000. Loss of 1.2387, cover loss of 1.2845, secret loss of 0.8924
# Training: Batch 469/1000. Loss of 1.2523, cover loss of 1.1201, secret loss of 1.0575
# Training: Batch 470/1000. Loss of 1.3333, cover loss of 1.1101, secret loss of 1.2392
# Training: Batch 471/1000. Loss of 1.5179, cover loss of 1.4154, secret loss of 1.2234
# Training: Batch 472/1000. Loss of 1.2335, cover loss of 0.8911, secret loss of 1.2919
# Training: Batch 473/1000. Loss of 1.1252, cover loss of 1.0403, secret loss of 0.9683
# Training: Batch 474/1000. Loss of 1.0569, cover loss of 1.0532, secret loss of 0.8500
# Training: Batch 475/1000. Loss of 1.3417, cover loss of 1.2197, secret loss of 1.1553
# Training: Batch 476/1000. Loss of 1.3101, cover loss of 1.2651, secret loss of 1.1199
# Training: Batch 477/1000. Loss of 1.1076, cover loss of 1.2273, secret loss of 0.7857
# Training: Batch 478/1000. Loss of 1.1964, cover loss of 1.2608, secret loss of 0.8965
# Training: Batch 479/1000. Loss of 1.3178, cover loss of 1.0493, secret loss of 1.2885
# Training: Batch 480/1000. Loss of 1.2751, cover loss of 1.1560, secret loss of 1.1133
# Training: Batch 481/1000. Loss of 1.1033, cover loss of 1.1595, secret loss of 0.8946
# Training: Batch 482/1000. Loss of 1.2725, cover loss of 1.2161, secret loss of 1.0635
# Training: Batch 483/1000. Loss of 1.2420, cover loss of 1.2503, secret loss of 1.0685
# Training: Batch 484/1000. Loss of 1.2899, cover loss of 1.1354, secret loss of 1.2282
# Training: Batch 485/1000. Loss of 1.2533, cover loss of 1.1821, secret loss of 1.0503
# Training: Batch 486/1000. Loss of 1.1518, cover loss of 1.1629, secret loss of 0.9612
# Training: Batch 487/1000. Loss of 1.2144, cover loss of 1.2279, secret loss of 0.9125
# Training: Batch 488/1000. Loss of 1.2377, cover loss of 1.0047, secret loss of 1.1506
# Training: Batch 489/1000. Loss of 1.2799, cover loss of 1.1127, secret loss of 1.1731
# Training: Batch 490/1000. Loss of 1.2156, cover loss of 1.1058, secret loss of 1.0348
# Training: Batch 491/1000. Loss of 1.2150, cover loss of 1.1056, secret loss of 1.1303
# Training: Batch 492/1000. Loss of 1.2658, cover loss of 1.0538, secret loss of 1.1632
# Training: Batch 493/1000. Loss of 1.1244, cover loss of 1.1671, secret loss of 0.8862
# Training: Batch 494/1000. Loss of 1.3376, cover loss of 1.3140, secret loss of 1.0686
# Training: Batch 495/1000. Loss of 1.2677, cover loss of 1.1563, secret loss of 1.0277
# Training: Batch 496/1000. Loss of 1.1160, cover loss of 1.1073, secret loss of 0.9325
# Training: Batch 497/1000. Loss of 1.2362, cover loss of 1.1137, secret loss of 1.1478
# Training: Batch 498/1000. Loss of 1.4208, cover loss of 1.1654, secret loss of 1.2962
# Training: Batch 499/1000. Loss of 1.1768, cover loss of 0.9449, secret loss of 1.0904
# Training: Batch 500/1000. Loss of 1.1998, cover loss of 1.1029, secret loss of 0.9789
# Training: Batch 501/1000. Loss of 1.2179, cover loss of 1.1177, secret loss of 1.1439
# Training: Batch 502/1000. Loss of 1.1317, cover loss of 1.1751, secret loss of 0.9515
# Training: Batch 503/1000. Loss of 1.2152, cover loss of 1.1197, secret loss of 1.0680
# Training: Batch 504/1000. Loss of 1.3516, cover loss of 1.3506, secret loss of 1.0841
# Training: Batch 505/1000. Loss of 1.4556, cover loss of 1.2413, secret loss of 1.3522
# Training: Batch 506/1000. Loss of 1.1979, cover loss of 1.1326, secret loss of 1.0082
# Training: Batch 507/1000. Loss of 1.2671, cover loss of 1.1376, secret loss of 1.1398
# Training: Batch 508/1000. Loss of 1.2902, cover loss of 1.2427, secret loss of 1.1193
# Training: Batch 509/1000. Loss of 1.3255, cover loss of 1.2810, secret loss of 1.1124
# Training: Batch 510/1000. Loss of 1.3261, cover loss of 1.1637, secret loss of 1.2158
# Training: Batch 511/1000. Loss of 1.2877, cover loss of 1.2640, secret loss of 1.0928
# Training: Batch 512/1000. Loss of 1.1737, cover loss of 1.1180, secret loss of 1.0410
# Training: Batch 513/1000. Loss of 1.4664, cover loss of 1.3129, secret loss of 1.2536
# Training: Batch 514/1000. Loss of 1.2894, cover loss of 1.0689, secret loss of 1.3096
# Training: Batch 515/1000. Loss of 1.2204, cover loss of 0.9390, secret loss of 1.1892
# Training: Batch 516/1000. Loss of 1.2713, cover loss of 1.0618, secret loss of 1.1755
# Training: Batch 517/1000. Loss of 1.3320, cover loss of 1.1331, secret loss of 1.2413
# Training: Batch 518/1000. Loss of 1.3031, cover loss of 1.2831, secret loss of 1.0501
# Training: Batch 519/1000. Loss of 1.2443, cover loss of 1.1896, secret loss of 1.0335
# Training: Batch 520/1000. Loss of 1.1782, cover loss of 1.0471, secret loss of 1.0405
# Training: Batch 521/1000. Loss of 1.1645, cover loss of 1.0620, secret loss of 1.0179
# Training: Batch 522/1000. Loss of 1.3065, cover loss of 1.3347, secret loss of 0.9861
# Training: Batch 523/1000. Loss of 1.2727, cover loss of 1.1279, secret loss of 1.0090
# Training: Batch 524/1000. Loss of 1.2453, cover loss of 1.0226, secret loss of 1.2360
# Training: Batch 525/1000. Loss of 1.2765, cover loss of 1.1211, secret loss of 1.1899
# Training: Batch 526/1000. Loss of 1.2952, cover loss of 1.0848, secret loss of 1.2067
# Training: Batch 527/1000. Loss of 1.1400, cover loss of 1.1114, secret loss of 0.9661
# Training: Batch 528/1000. Loss of 1.4040, cover loss of 1.2999, secret loss of 1.1676
# Training: Batch 529/1000. Loss of 1.1503, cover loss of 1.0347, secret loss of 1.0836
# Training: Batch 530/1000. Loss of 1.2709, cover loss of 0.9467, secret loss of 1.2584
# Training: Batch 531/1000. Loss of 1.2757, cover loss of 1.1743, secret loss of 1.0775
# Training: Batch 532/1000. Loss of 1.0655, cover loss of 0.8516, secret loss of 1.0341
# Training: Batch 533/1000. Loss of 1.3928, cover loss of 1.4628, secret loss of 0.9876
# Training: Batch 534/1000. Loss of 1.2308, cover loss of 0.9841, secret loss of 1.2932
# Training: Batch 535/1000. Loss of 1.2988, cover loss of 1.1252, secret loss of 1.1210
# Training: Batch 536/1000. Loss of 1.1137, cover loss of 0.8614, secret loss of 1.1786
# Training: Batch 537/1000. Loss of 1.2870, cover loss of 1.0625, secret loss of 1.2169
# Training: Batch 538/1000. Loss of 1.1392, cover loss of 0.9336, secret loss of 1.1579
# Training: Batch 539/1000. Loss of 1.3585, cover loss of 1.2022, secret loss of 1.1050
# Training: Batch 540/1000. Loss of 1.2766, cover loss of 1.2963, secret loss of 0.9849
# Training: Batch 541/1000. Loss of 1.2459, cover loss of 1.0514, secret loss of 1.0272
# Training: Batch 542/1000. Loss of 1.3247, cover loss of 1.1576, secret loss of 1.0959
# Training: Batch 543/1000. Loss of 1.1272, cover loss of 0.9584, secret loss of 1.0645
# Training: Batch 544/1000. Loss of 1.1676, cover loss of 1.1347, secret loss of 0.9935
# Training: Batch 545/1000. Loss of 1.2815, cover loss of 1.0873, secret loss of 1.1591
# Training: Batch 546/1000. Loss of 1.1965, cover loss of 1.1450, secret loss of 1.0265
# Training: Batch 547/1000. Loss of 1.2211, cover loss of 1.1287, secret loss of 1.0357
# Training: Batch 548/1000. Loss of 1.2605, cover loss of 1.0449, secret loss of 1.1874
# Training: Batch 549/1000. Loss of 1.2170, cover loss of 1.0888, secret loss of 0.9922
# Training: Batch 550/1000. Loss of 1.1376, cover loss of 1.0621, secret loss of 0.9357
# Training: Batch 551/1000. Loss of 1.2085, cover loss of 1.2151, secret loss of 1.0013
# Training: Batch 552/1000. Loss of 1.0831, cover loss of 0.8122, secret loss of 1.1024
# Training: Batch 553/1000. Loss of 1.0830, cover loss of 0.7715, secret loss of 1.1438
# Training: Batch 554/1000. Loss of 1.2474, cover loss of 1.1271, secret loss of 1.1432
# Training: Batch 555/1000. Loss of 1.1718, cover loss of 0.9497, secret loss of 1.1529
# Training: Batch 556/1000. Loss of 1.3735, cover loss of 1.2329, secret loss of 1.2711
# Training: Batch 557/1000. Loss of 1.2797, cover loss of 1.0932, secret loss of 1.1834
# Training: Batch 558/1000. Loss of 1.1458, cover loss of 0.9935, secret loss of 1.0791
# Training: Batch 559/1000. Loss of 1.3886, cover loss of 1.2985, secret loss of 1.1468
# Training: Batch 560/1000. Loss of 1.1273, cover loss of 0.8074, secret loss of 1.2649
# Training: Batch 561/1000. Loss of 1.2240, cover loss of 1.0672, secret loss of 1.1722
# Training: Batch 562/1000. Loss of 1.2228, cover loss of 1.2640, secret loss of 0.9676
# ...
# Training: Batch 816/1000. Loss of 1.3044, cover loss of 1.1707, secret loss of 1.1246
# Training: Batch 817/1000. Loss of 1.1341, cover loss of 0.9490, secret loss of 1.0561
# Training: Batch 818/1000. Loss of 1.3872, cover loss of 1.3087, secret loss of 1.1447
# Training: Batch 819/1000. Loss of 1.2356, cover loss of 1.0313, secret loss of 1.1281
# Training: Batch 820/1000. Loss of 1.1584, cover loss of 0.9801, secret loss of 1.0581
# Training: Batch 821/1000. Loss of 1.0165, cover loss of 0.9260, secret loss of 0.9480
# Training: Batch 822/1000. Loss of 1.2431, cover loss of 1.1664, secret loss of 1.0302
# Training: Batch 823/1000. Loss of 1.2402, cover loss of 0.9443, secret loss of 1.2991
# Training: Batch 824/1000. Loss of 1.1900, cover loss of 1.0250, secret loss of 1.1459
# Training: Batch 825/1000. Loss of 1.1200, cover loss of 1.0295, secret loss of 1.0533
# Training: Batch 826/1000. Loss of 1.2014, cover loss of 1.2532, secret loss of 0.9592
# Training: Batch 827/1000. Loss of 1.1574, cover loss of 1.1278, secret loss of 1.0522
# Training: Batch 828/1000. Loss of 1.0419, cover loss of 0.9801, secret loss of 0.9220
# Training: Batch 829/1000. Loss of 1.3585, cover loss of 1.3421, secret loss of 1.1636
# Training: Batch 830/1000. Loss of 1.0668, cover loss of 0.9642, secret loss of 0.9353
# Training: Batch 831/1000. Loss of 1.3645, cover loss of 1.2448, secret loss of 1.1820
# Training: Batch 832/1000. Loss of 1.2883, cover loss of 1.0048, secret loss of 1.2298
# Training: Batch 833/1000. Loss of 1.2973, cover loss of 1.4027, secret loss of 0.9467
# Training: Batch 834/1000. Loss of 1.1622, cover loss of 0.9739, secret loss of 1.1426
# Training: Batch 835/1000. Loss of 1.0075, cover loss of 0.9084, secret loss of 0.9069
# Training: Batch 836/1000. Loss of 1.2286, cover loss of 1.1001, secret loss of 1.0678
# Training: Batch 837/1000. Loss of 1.3210, cover loss of 1.3464, secret loss of 1.0089
# Training: Batch 838/1000. Loss of 1.4102, cover loss of 1.0968, secret loss of 1.2626
# Training: Batch 839/1000. Loss of 1.3525, cover loss of 1.0794, secret loss of 1.3149
# Training: Batch 840/1000. Loss of 1.1044, cover loss of 1.0378, secret loss of 1.0206
# Training: Batch 841/1000. Loss of 1.3055, cover loss of 1.1926, secret loss of 1.1573
# Training: Batch 842/1000. Loss of 1.2905, cover loss of 1.2288, secret loss of 0.9714
# Training: Batch 843/1000. Loss of 1.2405, cover loss of 1.1278, secret loss of 1.0827
# Training: Batch 844/1000. Loss of 1.0052, cover loss of 0.9646, secret loss of 0.8655
# Training: Batch 845/1000. Loss of 1.4297, cover loss of 1.1612, secret loss of 1.2947
# Training: Batch 846/1000. Loss of 1.1764, cover loss of 1.0867, secret loss of 1.0483
# Training: Batch 847/1000. Loss of 1.4398, cover loss of 1.4230, secret loss of 1.2226
# Training: Batch 848/1000. Loss of 1.2165, cover loss of 1.1778, secret loss of 0.9785
# Training: Batch 849/1000. Loss of 1.1092, cover loss of 0.9684, secret loss of 1.0022
# Training: Batch 850/1000. Loss of 1.3352, cover loss of 1.1573, secret loss of 1.2542
# Training: Batch 851/1000. Loss of 1.0469, cover loss of 1.0265, secret loss of 0.8594
# Training: Batch 852/1000. Loss of 1.3056, cover loss of 1.1564, secret loss of 1.2185
# Training: Batch 853/1000. Loss of 1.1939, cover loss of 1.2654, secret loss of 0.9101
# Training: Batch 854/1000. Loss of 1.1604, cover loss of 0.8884, secret loss of 1.1178
# Training: Batch 855/1000. Loss of 1.0963, cover loss of 1.0064, secret loss of 0.9420
# Training: Batch 856/1000. Loss of 1.2483, cover loss of 1.0992, secret loss of 1.1756
# Training: Batch 857/1000. Loss of 1.0621, cover loss of 0.9140, secret loss of 1.0449
# Training: Batch 858/1000. Loss of 1.2571, cover loss of 1.1062, secret loss of 1.1863
# Training: Batch 859/1000. Loss of 1.2928, cover loss of 1.1570, secret loss of 1.2251
# Training: Batch 860/1000. Loss of 1.1408, cover loss of 1.0797, secret loss of 1.0485
# Training: Batch 861/1000. Loss of 1.1049, cover loss of 1.0710, secret loss of 0.9454
# Training: Batch 862/1000. Loss of 1.1554, cover loss of 1.1085, secret loss of 0.9813
# Training: Batch 863/1000. Loss of 1.2954, cover loss of 1.2252, secret loss of 1.1459
# Training: Batch 864/1000. Loss of 1.3042, cover loss of 1.1657, secret loss of 1.1249
# Training: Batch 865/1000. Loss of 1.5434, cover loss of 1.5352, secret loss of 1.1162
# Training: Batch 866/1000. Loss of 1.2431, cover loss of 1.3130, secret loss of 0.8982
# Training: Batch 867/1000. Loss of 1.0778, cover loss of 0.8775, secret loss of 1.0743
# Training: Batch 868/1000. Loss of 1.2412, cover loss of 1.1004, secret loss of 1.0770
# Training: Batch 869/1000. Loss of 1.1502, cover loss of 1.0468, secret loss of 1.0677
# Training: Batch 870/1000. Loss of 1.2736, cover loss of 1.1123, secret loss of 1.1511
# Training: Batch 871/1000. Loss of 1.3147, cover loss of 1.0814, secret loss of 1.2478
# Training: Batch 872/1000. Loss of 1.2694, cover loss of 1.1384, secret loss of 1.1528
# Training: Batch 873/1000. Loss of 1.1361, cover loss of 0.9196, secret loss of 1.1038
# Training: Batch 874/1000. Loss of 1.4131, cover loss of 1.0800, secret loss of 1.4378
# Training: Batch 875/1000. Loss of 1.4339, cover loss of 1.3861, secret loss of 1.1576
# Training: Batch 876/1000. Loss of 1.1404, cover loss of 1.0365, secret loss of 0.9664
# Training: Batch 877/1000. Loss of 1.2914, cover loss of 1.1503, secret loss of 1.2262
# Training: Batch 878/1000. Loss of 1.1298, cover loss of 1.0348, secret loss of 1.0224
# Training: Batch 879/1000. Loss of 1.2261, cover loss of 1.0668, secret loss of 1.1216
# Training: Batch 880/1000. Loss of 1.1958, cover loss of 1.1021, secret loss of 1.0723
# Training: Batch 881/1000. Loss of 1.1355, cover loss of 1.1091, secret loss of 0.9558
# Training: Batch 882/1000. Loss of 1.1455, cover loss of 1.0853, secret loss of 0.9814
# Training: Batch 883/1000. Loss of 1.1746, cover loss of 0.9558, secret loss of 1.0927
# Training: Batch 884/1000. Loss of 1.1518, cover loss of 1.1822, secret loss of 0.9670
# Training: Batch 885/1000. Loss of 1.1631, cover loss of 1.0184, secret loss of 1.0684
# Training: Batch 886/1000. Loss of 1.2909, cover loss of 1.1464, secret loss of 1.1676
# Training: Batch 887/1000. Loss of 1.1547, cover loss of 1.1088, secret loss of 1.0104
# Training: Batch 888/1000. Loss of 1.2967, cover loss of 0.9291, secret loss of 1.4535
# Training: Batch 889/1000. Loss of 1.2600, cover loss of 1.2768, secret loss of 0.9922
# Training: Batch 890/1000. Loss of 1.2152, cover loss of 1.0095, secret loss of 1.1979
# Training: Batch 891/1000. Loss of 1.4429, cover loss of 1.1620, secret loss of 1.4217
# Training: Batch 892/1000. Loss of 1.1883, cover loss of 1.1499, secret loss of 1.0133
# Training: Batch 893/1000. Loss of 1.1138, cover loss of 0.9992, secret loss of 0.9889
# Training: Batch 894/1000. Loss of 1.3731, cover loss of 1.3155, secret loss of 1.2300
# Training: Batch 895/1000. Loss of 1.2151, cover loss of 1.0588, secret loss of 1.1111
# Training: Batch 896/1000. Loss of 1.1861, cover loss of 1.1352, secret loss of 1.0041
# Training: Batch 897/1000. Loss of 1.2667, cover loss of 1.1632, secret loss of 1.0258
# Training: Batch 898/1000. Loss of 1.3164, cover loss of 1.1827, secret loss of 1.0895
# Training: Batch 899/1000. Loss of 1.0940, cover loss of 0.9315, secret loss of 0.9998
# Training: Batch 900/1000. Loss of 1.3907, cover loss of 1.1019, secret loss of 1.1328
# Training: Batch 901/1000. Loss of 1.1293, cover loss of 1.0442, secret loss of 0.9775
# Training: Batch 902/1000. Loss of 1.1462, cover loss of 0.9323, secret loss of 1.0690
# Training: Batch 903/1000. Loss of 1.3443, cover loss of 1.4032, secret loss of 0.9542
# Training: Batch 904/1000. Loss of 1.2259, cover loss of 1.1994, secret loss of 0.9600
# Training: Batch 905/1000. Loss of 1.1713, cover loss of 0.9570, secret loss of 1.1437
# Training: Batch 906/1000. Loss of 1.2529, cover loss of 1.0845, secret loss of 1.1344
# Training: Batch 907/1000. Loss of 1.2075, cover loss of 1.1076, secret loss of 0.9313
# Training: Batch 908/1000. Loss of 1.1952, cover loss of 1.0903, secret loss of 1.1301
# Training: Batch 909/1000. Loss of 1.1693, cover loss of 1.0966, secret loss of 1.0090
# Training: Batch 910/1000. Loss of 1.2521, cover loss of 1.0986, secret loss of 1.1429
# Training: Batch 911/1000. Loss of 1.3763, cover loss of 1.2339, secret loss of 1.2222
# Training: Batch 912/1000. Loss of 1.2313, cover loss of 0.9963, secret loss of 1.2612
# Training: Batch 913/1000. Loss of 1.3160, cover loss of 1.0974, secret loss of 1.2301
# Training: Batch 914/1000. Loss of 1.4476, cover loss of 1.1671, secret loss of 1.3580
# Training: Batch 915/1000. Loss of 1.2323, cover loss of 1.1174, secret loss of 1.1421
# Training: Batch 916/1000. Loss of 1.2135, cover loss of 0.9028, secret loss of 1.2743
# Training: Batch 917/1000. Loss of 1.0591, cover loss of 0.7857, secret loss of 1.0602
# Training: Batch 918/1000. Loss of 1.2356, cover loss of 1.2558, secret loss of 1.0167
# Training: Batch 919/1000. Loss of 1.1553, cover loss of 1.0769, secret loss of 0.9897
# Training: Batch 920/1000. Loss of 1.4613, cover loss of 1.2561, secret loss of 1.2780
# Training: Batch 921/1000. Loss of 1.1926, cover loss of 1.1086, secret loss of 1.1033
# Training: Batch 922/1000. Loss of 1.2021, cover loss of 1.0486, secret loss of 1.0521
# Training: Batch 923/1000. Loss of 1.2601, cover loss of 1.1850, secret loss of 1.1056
# Training: Batch 924/1000. Loss of 1.1845, cover loss of 1.1491, secret loss of 1.0353
# Training: Batch 925/1000. Loss of 1.3056, cover loss of 1.1275, secret loss of 1.1699
# Training: Batch 926/1000. Loss of 1.4084, cover loss of 1.4149, secret loss of 1.0899
# Training: Batch 927/1000. Loss of 1.4927, cover loss of 1.4017, secret loss of 1.2989
# Training: Batch 928/1000. Loss of 1.3300, cover loss of 1.2018, secret loss of 1.1670
# Training: Batch 929/1000. Loss of 1.1224, cover loss of 0.9173, secret loss of 1.1326
# Training: Batch 930/1000. Loss of 1.2936, cover loss of 1.1828, secret loss of 1.1954
# Training: Batch 931/1000. Loss of 1.2753, cover loss of 1.0520, secret loss of 1.2222
# Training: Batch 932/1000. Loss of 1.2732, cover loss of 1.0485, secret loss of 1.2409
# Training: Batch 933/1000. Loss of 1.4211, cover loss of 1.2850, secret loss of 1.2270
# Training: Batch 934/1000. Loss of 1.1447, cover loss of 1.0163, secret loss of 0.9931
# Training: Batch 935/1000. Loss of 1.2755, cover loss of 1.0962, secret loss of 1.1414
# Training: Batch 936/1000. Loss of 1.1549, cover loss of 1.0202, secret loss of 1.1068
# Training: Batch 937/1000. Loss of 1.2054, cover loss of 1.1491, secret loss of 1.0278
# Training: Batch 938/1000. Loss of 1.2550, cover loss of 1.0590, secret loss of 1.1735
# Training: Batch 939/1000. Loss of 1.1745, cover loss of 1.2501, secret loss of 0.9023
# Training: Batch 940/1000. Loss of 1.1645, cover loss of 1.0813, secret loss of 0.8642
# Training: Batch 941/1000. Loss of 1.0558, cover loss of 0.9526, secret loss of 1.0159
# Training: Batch 942/1000. Loss of 1.3903, cover loss of 1.1917, secret loss of 1.2922
# Training: Batch 943/1000. Loss of 1.1037, cover loss of 1.1098, secret loss of 0.8878
# Training: Batch 944/1000. Loss of 1.2600, cover loss of 1.2187, secret loss of 0.9414
# Training: Batch 945/1000. Loss of 1.3950, cover loss of 1.3433, secret loss of 1.0767
# Training: Batch 946/1000. Loss of 1.3947, cover loss of 1.2683, secret loss of 1.1503
# Training: Batch 947/1000. Loss of 1.2283, cover loss of 1.1124, secret loss of 1.1343
# Training: Batch 948/1000. Loss of 1.3701, cover loss of 1.2267, secret loss of 1.2262
# Training: Batch 949/1000. Loss of 1.1628, cover loss of 0.9228, secret loss of 1.1607
# Training: Batch 950/1000. Loss of 1.1811, cover loss of 1.0655, secret loss of 0.9596
# Training: Batch 951/1000. Loss of 1.2294, cover loss of 1.2147, secret loss of 0.9841
# Training: Batch 952/1000. Loss of 1.3098, cover loss of 0.9709, secret loss of 1.2848
# Training: Batch 953/1000. Loss of 1.1032, cover loss of 0.9876, secret loss of 1.0471
# Training: Batch 954/1000. Loss of 1.2261, cover loss of 1.1459, secret loss of 1.0590
# Training: Batch 955/1000. Loss of 1.1603, cover loss of 0.9138, secret loss of 1.1671
# Training: Batch 956/1000. Loss of 1.2282, cover loss of 1.1405, secret loss of 1.0528
# Training: Batch 957/1000. Loss of 1.2899, cover loss of 1.1196, secret loss of 1.1053
# Training: Batch 958/1000. Loss of 1.2174, cover loss of 1.1700, secret loss of 1.0436
# Training: Batch 959/1000. Loss of 1.2940, cover loss of 1.1629, secret loss of 1.0931
# Training: Batch 960/1000. Loss of 1.2161, cover loss of 1.1012, secret loss of 1.1020
# Training: Batch 961/1000. Loss of 1.1965, cover loss of 0.9926, secret loss of 1.1784
# Training: Batch 962/1000. Loss of 1.1034, cover loss of 0.8770, secret loss of 1.0856
# Training: Batch 963/1000. Loss of 1.2940, cover loss of 1.1326, secret loss of 1.1707
# Training: Batch 964/1000. Loss of 1.1696, cover loss of 1.0201, secret loss of 1.0597
# Training: Batch 965/1000. Loss of 1.2020, cover loss of 1.1321, secret loss of 1.0690
# Training: Batch 966/1000. Loss of 0.9823, cover loss of 0.8700, secret loss of 0.8875
# Training: Batch 967/1000. Loss of 1.3205, cover loss of 1.1531, secret loss of 1.1563
# Training: Batch 968/1000. Loss of 1.1031, cover loss of 0.9982, secret loss of 0.9262
# Training: Batch 969/1000. Loss of 1.0646, cover loss of 0.9385, secret loss of 0.8931
# Training: Batch 970/1000. Loss of 1.1320, cover loss of 1.0911, secret loss of 0.8852
# Training: Batch 971/1000. Loss of 1.2322, cover loss of 1.0719, secret loss of 1.1627
# Training: Batch 972/1000. Loss of 1.1346, cover loss of 0.9016, secret loss of 1.0953
# Training: Batch 973/1000. Loss of 1.3926, cover loss of 1.3213, secret loss of 1.2187
# Training: Batch 974/1000. Loss of 1.4586, cover loss of 1.3036, secret loss of 1.2869
# Training: Batch 975/1000. Loss of 1.3308, cover loss of 1.1092, secret loss of 1.2665
# Training: Batch 976/1000. Loss of 1.2773, cover loss of 1.1261, secret loss of 1.1471
# Training: Batch 977/1000. Loss of 1.2052, cover loss of 1.1004, secret loss of 1.0462
# Training: Batch 978/1000. Loss of 1.2389, cover loss of 1.1225, secret loss of 1.1523
# Training: Batch 979/1000. Loss of 1.2280, cover loss of 1.2669, secret loss of 0.9889
# Training: Batch 980/1000. Loss of 1.0750, cover loss of 1.0418, secret loss of 0.8749
# Training: Batch 981/1000. Loss of 1.2436, cover loss of 1.0443, secret loss of 1.1619
# Training: Batch 982/1000. Loss of 1.3213, cover loss of 1.2212, secret loss of 1.0645
# Training: Batch 983/1000. Loss of 1.1654, cover loss of 0.9470, secret loss of 1.0399
# Training: Batch 984/1000. Loss of 1.3341, cover loss of 1.1327, secret loss of 1.1708
# Training: Batch 985/1000. Loss of 1.2349, cover loss of 1.1432, secret loss of 0.9551
# Training: Batch 986/1000. Loss of 1.0300, cover loss of 0.9803, secret loss of 0.8341
# Training: Batch 987/1000. Loss of 1.1378, cover loss of 1.0454, secret loss of 0.9780
# Training: Batch 988/1000. Loss of 1.1643, cover loss of 1.0010, secret loss of 1.1039
# Training: Batch 989/1000. Loss of 1.2277, cover loss of 1.1189, secret loss of 1.0588
# Training: Batch 990/1000. Loss of 1.1677, cover loss of 0.8823, secret loss of 1.2451
# Training: Batch 991/1000. Loss of 1.1800, cover loss of 0.9755, secret loss of 1.1141
# Training: Batch 992/1000. Loss of 1.1564, cover loss of 1.1240, secret loss of 0.8935
# Training: Batch 993/1000. Loss of 1.2547, cover loss of 1.0720, secret loss of 1.1317
# Training: Batch 994/1000. Loss of 1.0973, cover loss of 1.0134, secret loss of 1.0029
# Training: Batch 995/1000. Loss of 1.2609, cover loss of 1.1548, secret loss of 1.0863
# Training: Batch 996/1000. Loss of 1.1322, cover loss of 1.0789, secret loss of 1.0033
# Training: Batch 997/1000. Loss of 1.3495, cover loss of 1.1902, secret loss of 1.1605
# Training: Batch 998/1000. Loss of 1.2934, cover loss of 1.1969, secret loss of 1.0389
# Training: Batch 999/1000. Loss of 1.2613, cover loss of 1.0619, secret loss of 1.1894
# Training: Batch 1000/1000. Loss of 1.0528, cover loss of 0.8994, secret loss of 1.0580
# Epoch [50/50], Average_loss: 1.2353

# %%
 # Plot loss through epochs
plt.plot(loss_history)
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Batch')
plt.show()

# %%
def pixel_errors(input_S, input_C, decoded_S, decoded_C):
    """Calculates mean of Sum of Squared Errors per pixel for cover and secret images. """
    input_S = np.array(input_S.detach().cpu())
    input_C = np.array(input_C.detach().cpu())
    decoded_S = np.array(decoded_S.detach().cpu())
    decoded_C = np.array(decoded_C.detach().cpu())
    # print(input_S)
    see_Spixel = np.sqrt(np.mean(np.square(255*(input_S - decoded_S))))
    see_Cpixel = np.sqrt(np.mean(np.square(255*(input_C - decoded_C))))
    
    return see_Spixel, see_Cpixel

import math
def psnr(input_S, input_C, decoded_S, decoded_C):
    input_S = np.array(input_S.detach().cpu())
    input_C = np.array(input_C.detach().cpu())
    decoded_S = np.array(decoded_S.detach().cpu())
    decoded_C = np.array(decoded_C.detach().cpu())
    mse_s = np.mean(np.square(255*(input_S - decoded_S)))
    mse_c = np.mean(np.square(255*(input_C - decoded_C)))
    psnr_s = 10*math.log10(255**2/mse_s)
    psnr_c = 10*math.log10(255**2/mse_c)
    return psnr_s, psnr_c

def pixel_histogram(diff_S, diff_C):
    """Calculates histograms of errors for cover and secret image. """
    diff_Sflat = diff_S.flatten()
    diff_Cflat = diff_C.flatten()
    
    fig = plt.figure(figsize=(15, 5))
    a=fig.add_subplot(1,2,1)
        
    imgplot = plt.hist(255* diff_Cflat, 100, density=1, alpha=0.75, facecolor='red')
    a.set_title('Distribution of error in the Cover image.')
    plt.axis([0, 250, 0, 0.2])
    
    a=fig.add_subplot(1,2,2)
    imgplot = plt.hist(255* diff_Sflat, 100, density=1, alpha=0.75, facecolor='red')
    a.set_title('Distribution of errors in the Secret image.')
    plt.axis([0, 250, 0, 0.2])
    
    plt.show()

# %%
# net.load_state_dict(torch.load(MODELS_PATH+'Epoch N4.pkl'))

# Switch to evaluate mode
net.eval()
Path(PATH+"LOSS3_ds_img_10").mkdir(parents=True, exist_ok=True)
Path(PATH+"LOSS3_ds_img_10/cover_images/").mkdir(parents=True, exist_ok=True)
Path(PATH+"LOSS3_ds_img_10/container_images/").mkdir(parents=True, exist_ok=True)
save_path = PATH+"LOSS3_ds_img_10/"

test_losses = []

S_errors = []
C_errors = []

psnr_s,psnr_c = [], []
# Show images
for idx, test_batch in enumerate(test_loader):
     # Saves images
    data, _ = test_batch
    data = data.to(device)

    # Saves secret images and secret covers
    test_secret = data[:len(data)//2]
    test_cover = data[len(data)//2:]

    # Creates variable from secret and cover images
    test_secret = Variable(test_secret, volatile=True)
    test_cover = Variable(test_cover, volatile=True)

    # Compute output
    test_hidden, test_output = net(test_secret, test_cover)
    
    # Calculate loss
    test_loss, loss_cover, loss_secret = customized_loss(test_output, test_hidden, test_secret, test_cover, beta)
    
    diff_S, diff_C = np.abs(np.array(test_output.data.detach().cpu()) - np.array(test_secret.data.detach().cpu())), np.abs(np.array(test_hidden.data.detach().cpu()) - np.array(test_cover.data.detach().cpu()))
    
#     print (diff_S, diff_C)

    # Print pixel-wise average errors in a 256 scale.
    S_error, C_error = pixel_errors(test_secret, test_cover, test_output, test_hidden)
    S_errors.append(S_error)
    C_errors.append(C_error)

    S_psnr, C_psnr = psnr(test_secret, test_cover, test_output, test_hidden)
    psnr_s.append(S_psnr)
    psnr_c.append(C_psnr)
    
    if idx in [1,2,3,4]:
        print ('Total loss: {:.2f} \nLoss on secret: {:.2f} \nLoss on cover: {:.2f}'.format(test_loss.data.item(), loss_secret.data.item(), loss_cover.data.item()))

        # Creates img tensor
        imgs = [test_secret.data.detach().cpu(), test_output.data.detach().cpu(), test_cover.data.detach().cpu(), test_hidden.data.detach().cpu()]
        imgs_tsor = torch.cat(imgs, 0)

        # Prints Images
        imshow(utils.make_grid(imgs_tsor), idx+1, learning_rate=learning_rate, beta=beta)

    if idx < 500:
        container_img = tensor_to_image(test_hidden.data.detach().cpu())
        container_img = Image.fromarray(container_img)
        container_img.save(save_path+"container_images/"+str(idx)+".jpeg")
        cover_img = tensor_to_image(test_cover.data.detach().cpu())
        cover_img = Image.fromarray(cover_img)
        cover_img.save(save_path+"cover_images/"+str(idx)+".jpeg")
            
    test_losses.append(test_loss.data.item())
        
mean_test_loss = np.mean(test_losses)

print ('Average loss on test set: {:.2f}'.format(mean_test_loss))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:27: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
# Total loss: 1.93
# Loss on secret: 1.83
# Loss on cover: 1.92
# Total loss: 1.43
# Loss on secret: 1.40
# Loss on cover: 1.44
# Total loss: 1.97
# Loss on secret: 2.38
# Loss on cover: 1.65
# Total loss: 1.40
# Loss on secret: 1.77
# Loss on cover: 1.00
# Average loss on test set: 1.23

# %%
print ("Avg. S error per pixel [0, 255]:", sum(S_errors)/len(S_errors))
print ("Avg. C error per pixel [0, 255]:", sum(C_errors)/len(C_errors))
# Out:
# Avg. S error per pixel [0, 255]: 278.055452154541
# Avg. C error per pixel [0, 255]: 277.6644119354248

# %%
print ("Avg. PSNR of secret and decoded secret:", sum(psnr_s)/len(psnr_s))
print ("Avg. PSNR of cover and container:", sum(psnr_c)/len(psnr_c))
# Out:
# Avg. PSNR of secret and decoded secret: -0.5652232525897298
# Avg. PSNR of cover and container: -0.5468128653505722

# %%
# Plot distribution of errors in cover and secret images.
pixel_histogram(diff_S, diff_C)
