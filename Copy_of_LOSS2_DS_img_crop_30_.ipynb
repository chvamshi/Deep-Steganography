# %% [markdown]
# <a href="https://colab.research.google.com/github/chvamshi/Deep-Steganography/blob/main/Copy_of_LOSS2_DS_img_crop_30_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget http://cs231n.stanford.edu/tiny-imagenet-200.zip
# !unzip -q tiny-imagenet-200.zip && ls tiny-imagenet-200
# Out:
# --2022-02-08 20:36:54--  http://cs231n.stanford.edu/tiny-imagenet-200.zip
# Resolving cs231n.stanford.edu (cs231n.stanford.edu)... 171.64.68.10
# Connecting to cs231n.stanford.edu (cs231n.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248100043 (237M) [application/zip]
# Saving to: ‘tiny-imagenet-200.zip’
#
# tiny-imagenet-200.z 100%[===================>] 236.61M  38.0MB/s    in 7.5s
#
# 2022-02-08 20:37:02 (31.4 MB/s) - ‘tiny-imagenet-200.zip’ saved [248100043/248100043]
#
# test  train  val  wnids.txt  words.txt

# %%
# Imports necessary libraries and modules
from itertools import islice
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch.autograd import Variable
from torch import utils
from torch.utils.data import Subset
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import os 
from pathlib import Path
import pickle
import random
from torchvision import datasets, utils
import torchvision.transforms as transforms
from torchvision.transforms import ToPILImage
from torchvision.transforms import RandomResizedCrop
from torchvision.transforms.functional import resized_crop
from random import shuffle
from IPython.display import Image
from PIL import Image

# Use GPU if it is present
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
# Directory path
# os.chdir("..")
cwd = '/content/tiny-imagenet-200'

# Hyper Parameters
num_epochs = 50
batch_size = 32
learning_rate = 0.001
beta = 1

# Mean and std deviation of imagenet dataset. Source: http://cs231n.stanford.edu/reports/2017/pdfs/101.pdf
std = [0.229, 0.224, 0.225]
mean = [0.485, 0.456, 0.406]

# TODO: Define train, validation and models
MODELS_PATH = '/content/output/models'
# TRAIN_PATH = cwd+'/train/'
# VALID_PATH = cwd+'/valid/'
VALID_PATH = cwd+'/val/'
TRAIN_PATH = cwd+'/train/'
TEST_PATH = cwd+'/test/'

# if not os.path.exists(MODELS_PATH): os.mkdir(MODELS_PATH)

# %%
def variance(image1, image2):
    var1 = torch.var(image2-image1)
    # var2 = torch.var(image2)

    return var1

def customized_loss(S_prime, C_prime, S, C, B):
    ''' Calculates loss specified on the paper.'''
    
    loss_cover = torch.nn.functional.l1_loss(C_prime, C)
    # loss_cover = loss_cover/(64*64)
    loss_secret = torch.nn.functional.l1_loss(S_prime, S)
    # loss_secret = loss_secret/(64*64)

    variance_cover = variance(C_prime, C)
    variance_secret = variance(S_prime, S)

    loss_all = loss_cover+loss_secret+variance_cover+variance_secret
    loss_all = loss_all/4

    return loss_all, loss_cover, loss_secret

def denormalize(image, std, mean):
    ''' Denormalizes a tensor of images.'''

    for t in range(3):
        image[t, :, :] = (image[t, :, :] * std[t]) + mean[t]
    return image

def imshow(img, idx, learning_rate, beta):
    '''Prints out an image given in tensor format.'''
    
    img = denormalize(img, std, mean)
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.title('Example '+str(idx)+', lr='+str(learning_rate)+', B='+str(beta))
    plt.show()
    return

def gaussian(tensor, mean=0, stddev=0.1):
    '''Adds random noise to a tensor.'''
    
    noise = torch.nn.init.normal(torch.Tensor(tensor.size()), 0, 0.1).to(device)
    return Variable(tensor + noise)

def tensor_to_image(tensor):
    """
    Transforms a torch tensor into numpy uint8 array (image)
    :param tensor: (batch_size x channels x height x width) torch tensor in range [-1.0, 1.0]
    :return: (batch_size x height x width x channels) uint8 array
    """
    image = tensor.cpu().numpy()[0]
    # image = tensor.permute(0, 2, 3, 1).cpu().numpy()
    image = np.transpose(image, (1,2,0))
    image = (image + 1) * 127.5
    return np.clip(image, 0, 255).astype(np.uint8)

# %%
import torch.nn as nn
import numpy as np

def random_float(min, max):
    """
    Return a random number
    :param min:
    :param max:
    :return:
    """
    return np.random.rand() * (max - min) + min


def get_random_rectangle_inside(image, height_ratio_range, width_ratio_range):
    """
    Returns a random rectangle inside the image, where the size is random and is controlled by height_ratio_range and width_ratio_range.
    This is analogous to a random crop. For example, if height_ratio_range is (0.7, 0.9), then a random number in that range will be chosen
    (say it is 0.75 for illustration), and the image will be cropped such that the remaining height equals 0.75. In fact,
    a random 'starting' position rs will be chosen from (0, 0.25), and the crop will start at rs and end at rs + 0.75. This ensures
    that we crop from top/bottom with equal probability.
    The same logic applies to the width of the image, where width_ratio_range controls the width crop range.
    :param image: The image we want to crop
    :param height_ratio_range: The range of remaining height ratio
    :param width_ratio_range:  The range of remaining width ratio.
    :return: "Cropped" rectange with width and height drawn randomly height_ratio_range and width_ratio_range
    """
    # print(image.shape)
    image_height = image.shape[1]
    image_width = image.shape[2]

    remaining_height = int(np.rint(random_float(height_ratio_range[0], height_ratio_range[1]) * image_height))
    remaining_width = int(np.rint(random_float(width_ratio_range[0], width_ratio_range[0]) * image_width))

    if remaining_height == image_height:
        height_start = 0
    else:
        height_start = np.random.randint(0, image_height - remaining_height)

    if remaining_width == image_width:
        width_start = 0
    else:
        width_start = np.random.randint(0, image_width - remaining_width)

    return height_start, height_start+remaining_height, width_start, width_start+remaining_width


class Crop(nn.Module):
    """
    Randomly crops the image from top/bottom and left/right. The amount to crop is controlled by parameters
    heigth_ratio_range and width_ratio_range
    """
    def __init__(self, height_ratio_range, width_ratio_range):
        """
        :param height_ratio_range:
        :param width_ratio_range:
        """
        super(Crop, self).__init__()
        self.height_ratio_range = height_ratio_range
        self.width_ratio_range = width_ratio_range


    def forward(self, noised_and_cover):
        noised_image = noised_and_cover[0]
        print("Noisedimageshape: ",noised_image.shape)
        shape = noised_image.shape
        # crop_rectangle is in form (from, to) where @from and @to are 2D points -- (height, width)

        h_start, h_end, w_start, w_end = get_random_rectangle_inside(noised_image, self.height_ratio_range, self.width_ratio_range)

        noised_image =  noised_image[
               :,
               h_start: h_end,
               w_start: w_end].clone()
        noised_image1 = noised_image.expand(-1,64,64)
        print(noised_image1.shape)
        noised_and_cover[0] = noised_image1.clone()

        return noised_and_cover

# %%
# Preparation Network (2 conv layers)
class PrepNetwork(nn.Module):
    def __init__(self):
        super(PrepNetwork, self).__init__()
        self.initialP3 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialP4 = nn.Sequential(
            nn.Conv2d(3, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialP5 = nn.Sequential(
            nn.Conv2d(3, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalP3 = nn.Sequential(
            nn.Conv2d(65, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalP4 = nn.Sequential(
            nn.Conv2d(65, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalP5 = nn.Sequential(
            nn.Conv2d(65, 5, kernel_size=5, padding=2),
            nn.ReLU())

    def forward(self, p):
        p1 = self.initialP3(p)
        p2 = self.initialP4(p)
        p3 = self.initialP5(p)
        mid = torch.cat((p1, p2, p3), 1)
        p4 = self.finalP3(mid)
        p5 = self.finalP4(mid)
        p6 = self.finalP5(mid)
        # print(p4.shape)
        # print(p5.shape)
        # print(p6.shape)
        out = torch.cat((p4, p5, p6), 1)
        return out

# Hiding Network (5 conv layers)
class HidingNetwork(nn.Module):
    def __init__(self):
        super(HidingNetwork, self).__init__()
        self.initialH3 = nn.Sequential(
            nn.Conv2d(68, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialH4 = nn.Sequential(
            nn.Conv2d(68, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialH5 = nn.Sequential(
            nn.Conv2d(68, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalH3 = nn.Sequential(
            nn.Conv2d(65, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalH4 = nn.Sequential(
            nn.Conv2d(65, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalH5 = nn.Sequential(
            nn.Conv2d(65, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalH = nn.Sequential(
            nn.Conv2d(65, 3, kernel_size=1, padding=0))
        
    def forward(self, h):
        h1 = self.initialH3(h)
        h2 = self.initialH4(h)
        h3 = self.initialH5(h)
        mid = torch.cat((h1, h2, h3), 1)
        h4 = self.finalH3(mid)
        h5 = self.finalH4(mid)
        h6 = self.finalH5(mid)
        mid2 = torch.cat((h4, h5, h6), 1)
        out = self.finalH(mid2)
        out_noise = gaussian(out.data, 0, 0.1)
        return out, out_noise

# Reveal Network (2 conv layers)
class RevealNetwork(nn.Module):
    def __init__(self):
        super(RevealNetwork, self).__init__()
        self.initialR3 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialR4 = nn.Sequential(
            nn.Conv2d(3, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialR5 = nn.Sequential(
            nn.Conv2d(3, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalR3 = nn.Sequential(
            nn.Conv2d(65, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalR4 = nn.Sequential(
            nn.Conv2d(65, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalR5 = nn.Sequential(
            nn.Conv2d(65, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalR = nn.Sequential(
            nn.Conv2d(65, 3, kernel_size=1, padding=0))

    def forward(self, r, img_shape):
        # r = r.expand(img_shape)
        r1 = self.initialR3(r)
        r2 = self.initialR4(r)
        r3 = self.initialR5(r)
        mid = torch.cat((r1, r2, r3), 1)
        r4 = self.finalR3(mid)
        r5 = self.finalR4(mid)
        r6 = self.finalR5(mid)
        mid2 = torch.cat((r4, r5, r6), 1)
        out = self.finalR(mid2)
        return out

# Join three networks in one module
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.m1 = PrepNetwork().to(device)
        self.m2 = HidingNetwork().to(device)
        self.m3 = RevealNetwork().to(device)
        self.crop = Crop((0.7,0.9),(0.7,0.9)).to(device)

    def forward(self, secret, cover):
        img_shape = secret.shape
        x_1 = self.m1(secret)
        mid = torch.cat((x_1, cover), 1)
        x_2, x_2_noise = self.m2(mid)
        # x_2_noise = resized_crop(img=x_2_noise, top = 0, left=0, height=19, width=19, size=[64,64])
        x_2 =  resized_crop(img=x_2, top = 0, left=0, height=45, width=45, size=[64,64])
        # x_3 = self.m3(x_2_noise, img_shape)
        x_3 = self.m3(x_2, img_shape)
        return x_2, x_3

# %%
# Creates net object
net = Net().to(device)

# %%
# Creates training set
train_data = datasets.ImageFolder(
        TRAIN_PATH,
        transforms.Compose([
        # transforms.Scale(256),
        # transforms.RandomCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean,
        std=std)
        ]))
train_data = Subset(train_data, [i for i in range(32000)])
train_loader = torch.utils.data.DataLoader(
        train_data, batch_size=batch_size, num_workers=1, 
        pin_memory=True, shuffle=True, drop_last=True)

# Creates test set
test_data = datasets.ImageFolder(
        TEST_PATH, 
        transforms.Compose([
        # transforms.Scale(256),
        # transforms.RandomCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean,
        std=std)
        ]))
test_data = Subset(test_data,[i for i in range(5000)])
test_loader = torch.utils.data.DataLoader(
        test_data, batch_size=2, num_workers=1, 
        pin_memory=True, shuffle=True, drop_last=True)

# %%
PATH = "/content/drive/MyDrive/"
loss_history = []

def train_model(train_loader, beta, learning_rate):
    
    # Save optimizer
    optimizer = optim.Adam(net.parameters(), lr=learning_rate)
    
    loss_history = []
    # Iterate over batches performing forward and backward passes
    for epoch in range(num_epochs):

        # Train mode
        net.train()
        
        train_losses = []
        # Train one epoch
        for idx, train_batch in enumerate(train_loader):

            data, _  = train_batch
            data = data.to(device)

            # Saves secret images and secret covers
            train_covers = data[:len(data)//2]
            train_secrets = data[len(data)//2:]
            
            # Creates variable from secret and cover images
            train_secrets = Variable(train_secrets, requires_grad=False)
            train_covers = Variable(train_covers, requires_grad=False)

            # Forward + Backward + Optimize
            optimizer.zero_grad()
            train_hidden, train_output = net(train_secrets, train_covers)

            # Calculate loss and perform backprop
            train_loss, train_loss_cover, train_loss_secret = customized_loss(train_output, train_hidden, train_secrets, train_covers, beta)
            train_loss.backward()
            optimizer.step()
            
            # Saves training loss
            # print(train_loss.data)
            train_losses.append(train_loss.data.item())
            loss_history.append(train_loss.data.item())
            
            # Prints mini-batch losses
            print('Training: Batch {0}/{1}. Loss of {2:.4f}, cover loss of {3:.4f}, secret loss of {4:.4f}'.format(idx+1, len(train_loader), train_loss.data.item(), train_loss_cover.data.item(), train_loss_secret.data.item()))
    
        # Save model
        # torch.save(net.state_dict(), '/content/Epoch N{}.pkl'.format(epoch+1))
        torch.save(net.state_dict(), PATH+"LOSS2_1_ds_crop_30.pth")
        with open(PATH+"LOSS2_1_loss_history_crop_30.txt", "a") as f:
            for s in loss_history:
                f.write(str(s) +"\n")
        
        mean_train_loss = np.mean(train_losses)
    
        # Prints epoch average loss
        print ('Epoch [{0}/{1}], Average_loss: {2:.4f}'.format(
                epoch+1, num_epochs, mean_train_loss))
    
    return net, mean_train_loss, loss_history

# %%
# Load model
# net.load_state_dict(torch.load(PATH+"LOSS2_1_ds_crop_30.pth"))
# loss_history = []
# with open(PATH+"LOSS2_1_loss_history_crop_30.txt", "r") as f:
#   for line in f:
#     loss_history.append(float(line.strip()))

net, mean_train_loss, loss_history = train_model(train_loader, beta, learning_rate)
# loss_history.extend(loss_history1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:43: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
# Streaming output truncated to the last 5000 lines.
# Training: Batch 6/1000. Loss of 0.4778, cover loss of 0.5309, secret loss of 0.4797
# Training: Batch 7/1000. Loss of 0.4606, cover loss of 0.5009, secret loss of 0.4642
# Training: Batch 8/1000. Loss of 0.4582, cover loss of 0.4700, secret loss of 0.4688
# Training: Batch 9/1000. Loss of 0.4385, cover loss of 0.4315, secret loss of 0.5134
# Training: Batch 10/1000. Loss of 0.5305, cover loss of 0.5271, secret loss of 0.5314
# Training: Batch 11/1000. Loss of 0.4538, cover loss of 0.4816, secret loss of 0.4769
# Training: Batch 12/1000. Loss of 0.5025, cover loss of 0.4994, secret loss of 0.5202
# Training: Batch 13/1000. Loss of 0.4662, cover loss of 0.5038, secret loss of 0.4658
# Training: Batch 14/1000. Loss of 0.4642, cover loss of 0.5098, secret loss of 0.4561
# Training: Batch 15/1000. Loss of 0.5133, cover loss of 0.5228, secret loss of 0.5087
# Training: Batch 16/1000. Loss of 0.4761, cover loss of 0.5092, secret loss of 0.4717
# Training: Batch 17/1000. Loss of 0.4561, cover loss of 0.5016, secret loss of 0.4454
# Training: Batch 18/1000. Loss of 0.4669, cover loss of 0.4766, secret loss of 0.4852
# Training: Batch 19/1000. Loss of 0.5114, cover loss of 0.5592, secret loss of 0.4740
# Training: Batch 20/1000. Loss of 0.4333, cover loss of 0.4863, secret loss of 0.4315
# Training: Batch 21/1000. Loss of 0.5068, cover loss of 0.5208, secret loss of 0.4784
# Training: Batch 22/1000. Loss of 0.4559, cover loss of 0.5102, secret loss of 0.4489
# Training: Batch 23/1000. Loss of 0.4844, cover loss of 0.4970, secret loss of 0.4993
# Training: Batch 24/1000. Loss of 0.5258, cover loss of 0.5488, secret loss of 0.4895
# Training: Batch 25/1000. Loss of 0.4994, cover loss of 0.5138, secret loss of 0.5021
# Training: Batch 26/1000. Loss of 0.4710, cover loss of 0.5110, secret loss of 0.4646
# Training: Batch 27/1000. Loss of 0.5208, cover loss of 0.5303, secret loss of 0.5019
# Training: Batch 28/1000. Loss of 0.4713, cover loss of 0.5260, secret loss of 0.4175
# Training: Batch 29/1000. Loss of 0.5446, cover loss of 0.5642, secret loss of 0.4903
# Training: Batch 30/1000. Loss of 0.4871, cover loss of 0.5247, secret loss of 0.4675
# Training: Batch 31/1000. Loss of 0.4705, cover loss of 0.5031, secret loss of 0.4742
# Training: Batch 32/1000. Loss of 0.5272, cover loss of 0.4831, secret loss of 0.5627
# Training: Batch 33/1000. Loss of 0.5199, cover loss of 0.5278, secret loss of 0.5187
# Training: Batch 34/1000. Loss of 0.5444, cover loss of 0.5847, secret loss of 0.4840
# Training: Batch 35/1000. Loss of 0.5027, cover loss of 0.4713, secret loss of 0.5426
# Training: Batch 36/1000. Loss of 0.4680, cover loss of 0.5499, secret loss of 0.4183
# Training: Batch 37/1000. Loss of 0.5105, cover loss of 0.5269, secret loss of 0.5010
# Training: Batch 38/1000. Loss of 0.4721, cover loss of 0.5309, secret loss of 0.4512
# Training: Batch 39/1000. Loss of 0.5444, cover loss of 0.5935, secret loss of 0.4571
# Training: Batch 40/1000. Loss of 0.5216, cover loss of 0.5649, secret loss of 0.4865
# Training: Batch 41/1000. Loss of 0.4892, cover loss of 0.5482, secret loss of 0.4486
# Training: Batch 42/1000. Loss of 0.5336, cover loss of 0.5119, secret loss of 0.5587
# Training: Batch 43/1000. Loss of 0.4990, cover loss of 0.5724, secret loss of 0.4371
# Training: Batch 44/1000. Loss of 0.4775, cover loss of 0.5143, secret loss of 0.4581
# Training: Batch 45/1000. Loss of 0.4826, cover loss of 0.4931, secret loss of 0.4867
# Training: Batch 46/1000. Loss of 0.4773, cover loss of 0.4886, secret loss of 0.4761
# Training: Batch 47/1000. Loss of 0.4758, cover loss of 0.4633, secret loss of 0.5186
# Training: Batch 48/1000. Loss of 0.5293, cover loss of 0.5478, secret loss of 0.4988
# Training: Batch 49/1000. Loss of 0.5481, cover loss of 0.5562, secret loss of 0.5334
# Training: Batch 50/1000. Loss of 0.5012, cover loss of 0.5099, secret loss of 0.5015
# Training: Batch 51/1000. Loss of 0.4777, cover loss of 0.4846, secret loss of 0.4915
# Training: Batch 52/1000. Loss of 0.5574, cover loss of 0.5499, secret loss of 0.5431
# Training: Batch 53/1000. Loss of 0.4679, cover loss of 0.5353, secret loss of 0.4238
# Training: Batch 54/1000. Loss of 0.4450, cover loss of 0.4956, secret loss of 0.4522
# Training: Batch 55/1000. Loss of 0.4680, cover loss of 0.4703, secret loss of 0.4983
# Training: Batch 56/1000. Loss of 0.5375, cover loss of 0.5664, secret loss of 0.4900
# Training: Batch 57/1000. Loss of 0.5492, cover loss of 0.5607, secret loss of 0.5078
# Training: Batch 58/1000. Loss of 0.5117, cover loss of 0.5355, secret loss of 0.5032
# Training: Batch 59/1000. Loss of 0.4989, cover loss of 0.5318, secret loss of 0.4907
# Training: Batch 60/1000. Loss of 0.5238, cover loss of 0.5416, secret loss of 0.5028
# Training: Batch 61/1000. Loss of 0.4749, cover loss of 0.5362, secret loss of 0.4390
# Training: Batch 62/1000. Loss of 0.4945, cover loss of 0.5635, secret loss of 0.4314
# Training: Batch 63/1000. Loss of 0.4999, cover loss of 0.4965, secret loss of 0.5155
# Training: Batch 64/1000. Loss of 0.4375, cover loss of 0.4819, secret loss of 0.4385
# Training: Batch 65/1000. Loss of 0.5245, cover loss of 0.5595, secret loss of 0.4651
# Training: Batch 66/1000. Loss of 0.4469, cover loss of 0.4882, secret loss of 0.4285
# Training: Batch 67/1000. Loss of 0.4586, cover loss of 0.5165, secret loss of 0.4325
# Training: Batch 68/1000. Loss of 0.5087, cover loss of 0.5274, secret loss of 0.5003
# Training: Batch 69/1000. Loss of 0.5387, cover loss of 0.5823, secret loss of 0.4779
# Training: Batch 70/1000. Loss of 0.4949, cover loss of 0.5186, secret loss of 0.4805
# Training: Batch 71/1000. Loss of 0.5020, cover loss of 0.5357, secret loss of 0.4860
# Training: Batch 72/1000. Loss of 0.4779, cover loss of 0.4820, secret loss of 0.5106
# Training: Batch 73/1000. Loss of 0.4797, cover loss of 0.5257, secret loss of 0.4578
# Training: Batch 74/1000. Loss of 0.4681, cover loss of 0.5407, secret loss of 0.4376
# Training: Batch 75/1000. Loss of 0.4787, cover loss of 0.5190, secret loss of 0.4570
# Training: Batch 76/1000. Loss of 0.4839, cover loss of 0.5278, secret loss of 0.4586
# Training: Batch 77/1000. Loss of 0.4374, cover loss of 0.4673, secret loss of 0.4534
# Training: Batch 78/1000. Loss of 0.4910, cover loss of 0.5442, secret loss of 0.4592
# Training: Batch 79/1000. Loss of 0.5296, cover loss of 0.5419, secret loss of 0.5164
# Training: Batch 80/1000. Loss of 0.4753, cover loss of 0.5110, secret loss of 0.4563
# Training: Batch 81/1000. Loss of 0.4974, cover loss of 0.5062, secret loss of 0.4920
# Training: Batch 82/1000. Loss of 0.4732, cover loss of 0.5108, secret loss of 0.4604
# Training: Batch 83/1000. Loss of 0.5192, cover loss of 0.5842, secret loss of 0.4507
# Training: Batch 84/1000. Loss of 0.4847, cover loss of 0.5190, secret loss of 0.4488
# Training: Batch 85/1000. Loss of 0.4926, cover loss of 0.5071, secret loss of 0.5023
# Training: Batch 86/1000. Loss of 0.5331, cover loss of 0.5696, secret loss of 0.5051
# Training: Batch 87/1000. Loss of 0.4925, cover loss of 0.5399, secret loss of 0.4677
# Training: Batch 88/1000. Loss of 0.4592, cover loss of 0.4993, secret loss of 0.4468
# Training: Batch 89/1000. Loss of 0.5583, cover loss of 0.5884, secret loss of 0.5196
# Training: Batch 90/1000. Loss of 0.4754, cover loss of 0.5491, secret loss of 0.4407
# Training: Batch 91/1000. Loss of 0.4763, cover loss of 0.5448, secret loss of 0.4192
# Training: Batch 92/1000. Loss of 0.4351, cover loss of 0.4587, secret loss of 0.4491
# Training: Batch 93/1000. Loss of 0.5313, cover loss of 0.5427, secret loss of 0.5319
# Training: Batch 94/1000. Loss of 0.4707, cover loss of 0.5315, secret loss of 0.4100
# Training: Batch 95/1000. Loss of 0.6257, cover loss of 0.6045, secret loss of 0.5602
# Training: Batch 96/1000. Loss of 0.5171, cover loss of 0.5370, secret loss of 0.4781
# Training: Batch 97/1000. Loss of 0.4447, cover loss of 0.5014, secret loss of 0.4343
# Training: Batch 98/1000. Loss of 0.4729, cover loss of 0.5039, secret loss of 0.4747
# Training: Batch 99/1000. Loss of 0.4457, cover loss of 0.4896, secret loss of 0.4441
# Training: Batch 100/1000. Loss of 0.5199, cover loss of 0.5542, secret loss of 0.4770
# Training: Batch 101/1000. Loss of 0.5061, cover loss of 0.5725, secret loss of 0.4454
# Training: Batch 102/1000. Loss of 0.4641, cover loss of 0.4884, secret loss of 0.4670
# Training: Batch 103/1000. Loss of 0.4759, cover loss of 0.5112, secret loss of 0.4763
# Training: Batch 104/1000. Loss of 0.4866, cover loss of 0.4842, secret loss of 0.4985
# Training: Batch 105/1000. Loss of 0.5058, cover loss of 0.5442, secret loss of 0.4892
# Training: Batch 106/1000. Loss of 0.4728, cover loss of 0.5211, secret loss of 0.4548
# Training: Batch 107/1000. Loss of 0.4551, cover loss of 0.4593, secret loss of 0.4918
# Training: Batch 108/1000. Loss of 0.5345, cover loss of 0.5437, secret loss of 0.5298
# Training: Batch 109/1000. Loss of 0.5001, cover loss of 0.5184, secret loss of 0.4929
# Training: Batch 110/1000. Loss of 0.4642, cover loss of 0.5362, secret loss of 0.4159
# Training: Batch 111/1000. Loss of 0.5069, cover loss of 0.5525, secret loss of 0.4771
# Training: Batch 112/1000. Loss of 0.5332, cover loss of 0.5560, secret loss of 0.4991
# Training: Batch 113/1000. Loss of 0.4845, cover loss of 0.5212, secret loss of 0.4720
# Training: Batch 114/1000. Loss of 0.5420, cover loss of 0.5505, secret loss of 0.5239
# Training: Batch 115/1000. Loss of 0.5394, cover loss of 0.5278, secret loss of 0.5527
# Training: Batch 116/1000. Loss of 0.4809, cover loss of 0.4917, secret loss of 0.5139
# Training: Batch 117/1000. Loss of 0.4946, cover loss of 0.4916, secret loss of 0.5177
# Training: Batch 118/1000. Loss of 0.4769, cover loss of 0.5025, secret loss of 0.5079
# Training: Batch 119/1000. Loss of 0.4496, cover loss of 0.4928, secret loss of 0.4502
# Training: Batch 120/1000. Loss of 0.5246, cover loss of 0.5639, secret loss of 0.4586
# Training: Batch 121/1000. Loss of 0.5192, cover loss of 0.5134, secret loss of 0.5227
# Training: Batch 122/1000. Loss of 0.5149, cover loss of 0.5313, secret loss of 0.5040
# Training: Batch 123/1000. Loss of 0.5248, cover loss of 0.5537, secret loss of 0.5174
# Training: Batch 124/1000. Loss of 0.4569, cover loss of 0.5000, secret loss of 0.4741
# Training: Batch 125/1000. Loss of 0.4496, cover loss of 0.4752, secret loss of 0.4609
# Training: Batch 126/1000. Loss of 0.4813, cover loss of 0.5250, secret loss of 0.4812
# Training: Batch 127/1000. Loss of 0.5184, cover loss of 0.5942, secret loss of 0.4349
# Training: Batch 128/1000. Loss of 0.5238, cover loss of 0.5341, secret loss of 0.5409
# Training: Batch 129/1000. Loss of 0.5162, cover loss of 0.5571, secret loss of 0.4757
# Training: Batch 130/1000. Loss of 0.5413, cover loss of 0.5686, secret loss of 0.5144
# Training: Batch 131/1000. Loss of 0.4783, cover loss of 0.5309, secret loss of 0.4481
# Training: Batch 132/1000. Loss of 0.5352, cover loss of 0.5471, secret loss of 0.5323
# Training: Batch 133/1000. Loss of 0.5055, cover loss of 0.5269, secret loss of 0.5002
# Training: Batch 134/1000. Loss of 0.4858, cover loss of 0.5212, secret loss of 0.4777
# Training: Batch 135/1000. Loss of 0.4752, cover loss of 0.4428, secret loss of 0.5286
# Training: Batch 136/1000. Loss of 0.4726, cover loss of 0.5218, secret loss of 0.4560
# Training: Batch 137/1000. Loss of 0.5203, cover loss of 0.5286, secret loss of 0.4963
# Training: Batch 138/1000. Loss of 0.5177, cover loss of 0.5689, secret loss of 0.4709
# Training: Batch 139/1000. Loss of 0.4693, cover loss of 0.5176, secret loss of 0.4638
# Training: Batch 140/1000. Loss of 0.5327, cover loss of 0.5601, secret loss of 0.4782
# Training: Batch 141/1000. Loss of 0.4462, cover loss of 0.4583, secret loss of 0.4814
# Training: Batch 142/1000. Loss of 0.5222, cover loss of 0.5263, secret loss of 0.5115
# Training: Batch 143/1000. Loss of 0.5171, cover loss of 0.5155, secret loss of 0.5322
# Training: Batch 144/1000. Loss of 0.5769, cover loss of 0.5879, secret loss of 0.5296
# Training: Batch 145/1000. Loss of 0.5002, cover loss of 0.5042, secret loss of 0.4989
# Training: Batch 146/1000. Loss of 0.5392, cover loss of 0.5626, secret loss of 0.5119
# Training: Batch 147/1000. Loss of 0.4978, cover loss of 0.5664, secret loss of 0.4319
# Training: Batch 148/1000. Loss of 0.5127, cover loss of 0.5464, secret loss of 0.4954
# Training: Batch 149/1000. Loss of 0.4456, cover loss of 0.4654, secret loss of 0.4716
# Training: Batch 150/1000. Loss of 0.4486, cover loss of 0.4995, secret loss of 0.4446
# Training: Batch 151/1000. Loss of 0.5398, cover loss of 0.5871, secret loss of 0.4865
# Training: Batch 152/1000. Loss of 0.5014, cover loss of 0.5502, secret loss of 0.4806
# Training: Batch 153/1000. Loss of 0.4547, cover loss of 0.4888, secret loss of 0.4728
# Training: Batch 154/1000. Loss of 0.4418, cover loss of 0.4788, secret loss of 0.4389
# Training: Batch 155/1000. Loss of 0.5247, cover loss of 0.5663, secret loss of 0.4910
# Training: Batch 156/1000. Loss of 0.5030, cover loss of 0.5348, secret loss of 0.5016
# Training: Batch 157/1000. Loss of 0.4820, cover loss of 0.5145, secret loss of 0.4800
# Training: Batch 158/1000. Loss of 0.4777, cover loss of 0.5182, secret loss of 0.4698
# Training: Batch 159/1000. Loss of 0.5094, cover loss of 0.5316, secret loss of 0.5009
# Training: Batch 160/1000. Loss of 0.5614, cover loss of 0.5574, secret loss of 0.5433
# Training: Batch 161/1000. Loss of 0.5129, cover loss of 0.5863, secret loss of 0.4435
# Training: Batch 162/1000. Loss of 0.5462, cover loss of 0.5554, secret loss of 0.5407
# Training: Batch 163/1000. Loss of 0.5121, cover loss of 0.5356, secret loss of 0.4887
# Training: Batch 164/1000. Loss of 0.5259, cover loss of 0.5651, secret loss of 0.4831
# Training: Batch 165/1000. Loss of 0.4733, cover loss of 0.4927, secret loss of 0.4678
# Training: Batch 166/1000. Loss of 0.5040, cover loss of 0.4950, secret loss of 0.5285
# Training: Batch 167/1000. Loss of 0.5605, cover loss of 0.5768, secret loss of 0.5238
# Training: Batch 168/1000. Loss of 0.4554, cover loss of 0.4903, secret loss of 0.4612
# Training: Batch 169/1000. Loss of 0.4719, cover loss of 0.5421, secret loss of 0.4412
# Training: Batch 170/1000. Loss of 0.4846, cover loss of 0.5477, secret loss of 0.4328
# Training: Batch 171/1000. Loss of 0.4749, cover loss of 0.4982, secret loss of 0.4624
# Training: Batch 172/1000. Loss of 0.4976, cover loss of 0.5464, secret loss of 0.4573
# Training: Batch 173/1000. Loss of 0.4878, cover loss of 0.5383, secret loss of 0.4532
# Training: Batch 174/1000. Loss of 0.5052, cover loss of 0.5479, secret loss of 0.4623
# Training: Batch 175/1000. Loss of 0.5419, cover loss of 0.5410, secret loss of 0.5365
# Training: Batch 176/1000. Loss of 0.4976, cover loss of 0.5703, secret loss of 0.4439
# Training: Batch 177/1000. Loss of 0.4995, cover loss of 0.5231, secret loss of 0.4979
# Training: Batch 178/1000. Loss of 0.4949, cover loss of 0.5479, secret loss of 0.4563
# Training: Batch 179/1000. Loss of 0.4739, cover loss of 0.4735, secret loss of 0.5061
# Training: Batch 180/1000. Loss of 0.4470, cover loss of 0.4729, secret loss of 0.4703
# Training: Batch 181/1000. Loss of 0.5541, cover loss of 0.5379, secret loss of 0.5632
# Training: Batch 182/1000. Loss of 0.5876, cover loss of 0.6123, secret loss of 0.5360
# Training: Batch 183/1000. Loss of 0.4712, cover loss of 0.4991, secret loss of 0.4751
# Training: Batch 184/1000. Loss of 0.4648, cover loss of 0.4953, secret loss of 0.4650
# Training: Batch 185/1000. Loss of 0.4931, cover loss of 0.5338, secret loss of 0.4814
# Training: Batch 186/1000. Loss of 0.4575, cover loss of 0.5166, secret loss of 0.4512
# Training: Batch 187/1000. Loss of 0.4689, cover loss of 0.5311, secret loss of 0.4215
# Training: Batch 188/1000. Loss of 0.5650, cover loss of 0.5471, secret loss of 0.5623
# Training: Batch 189/1000. Loss of 0.5034, cover loss of 0.5613, secret loss of 0.4580
# Training: Batch 190/1000. Loss of 0.5286, cover loss of 0.5484, secret loss of 0.4949
# Training: Batch 191/1000. Loss of 0.5390, cover loss of 0.5589, secret loss of 0.5088
# Training: Batch 192/1000. Loss of 0.4671, cover loss of 0.4830, secret loss of 0.4836
# Training: Batch 193/1000. Loss of 0.4890, cover loss of 0.5195, secret loss of 0.4808
# Training: Batch 194/1000. Loss of 0.5129, cover loss of 0.5241, secret loss of 0.5163
# Training: Batch 195/1000. Loss of 0.5294, cover loss of 0.5391, secret loss of 0.4820
# Training: Batch 196/1000. Loss of 0.4486, cover loss of 0.4564, secret loss of 0.4703
# Training: Batch 197/1000. Loss of 0.5144, cover loss of 0.5221, secret loss of 0.4908
# Training: Batch 198/1000. Loss of 0.5022, cover loss of 0.5438, secret loss of 0.4460
# Training: Batch 199/1000. Loss of 0.5500, cover loss of 0.5456, secret loss of 0.5389
# Training: Batch 200/1000. Loss of 0.5306, cover loss of 0.5539, secret loss of 0.4942
# Training: Batch 201/1000. Loss of 0.5311, cover loss of 0.5058, secret loss of 0.5447
# Training: Batch 202/1000. Loss of 0.5165, cover loss of 0.5324, secret loss of 0.5011
# Training: Batch 203/1000. Loss of 0.5431, cover loss of 0.5420, secret loss of 0.5312
# Training: Batch 204/1000. Loss of 0.4730, cover loss of 0.5122, secret loss of 0.4570
# Training: Batch 205/1000. Loss of 0.5277, cover loss of 0.5247, secret loss of 0.5177
# Training: Batch 206/1000. Loss of 0.5272, cover loss of 0.5430, secret loss of 0.5268
# Training: Batch 207/1000. Loss of 0.5082, cover loss of 0.5134, secret loss of 0.5131
# Training: Batch 208/1000. Loss of 0.5428, cover loss of 0.5406, secret loss of 0.5227
# Training: Batch 209/1000. Loss of 0.4689, cover loss of 0.4769, secret loss of 0.5014
# Training: Batch 210/1000. Loss of 0.5778, cover loss of 0.5348, secret loss of 0.5891
# Training: Batch 211/1000. Loss of 0.4951, cover loss of 0.5317, secret loss of 0.4781
# Training: Batch 212/1000. Loss of 0.4763, cover loss of 0.5346, secret loss of 0.4404
# Training: Batch 213/1000. Loss of 0.4846, cover loss of 0.5124, secret loss of 0.4825
# Training: Batch 214/1000. Loss of 0.5527, cover loss of 0.6004, secret loss of 0.4907
# Training: Batch 215/1000. Loss of 0.4744, cover loss of 0.5354, secret loss of 0.4413
# Training: Batch 216/1000. Loss of 0.5246, cover loss of 0.5339, secret loss of 0.5280
# Training: Batch 217/1000. Loss of 0.5205, cover loss of 0.5661, secret loss of 0.4795
# Training: Batch 218/1000. Loss of 0.5336, cover loss of 0.5613, secret loss of 0.5056
# Training: Batch 219/1000. Loss of 0.4757, cover loss of 0.4725, secret loss of 0.4898
# Training: Batch 220/1000. Loss of 0.5477, cover loss of 0.5589, secret loss of 0.5356
# Training: Batch 221/1000. Loss of 0.4949, cover loss of 0.5271, secret loss of 0.4792
# Training: Batch 222/1000. Loss of 0.5346, cover loss of 0.5191, secret loss of 0.5585
# Training: Batch 223/1000. Loss of 0.4752, cover loss of 0.5598, secret loss of 0.4075
# Training: Batch 224/1000. Loss of 0.5407, cover loss of 0.5879, secret loss of 0.4932
# Training: Batch 225/1000. Loss of 0.4571, cover loss of 0.5238, secret loss of 0.4136
# Training: Batch 226/1000. Loss of 0.5369, cover loss of 0.5226, secret loss of 0.5669
# Training: Batch 227/1000. Loss of 0.4882, cover loss of 0.5287, secret loss of 0.4700
# Training: Batch 228/1000. Loss of 0.4498, cover loss of 0.4585, secret loss of 0.5074
# Training: Batch 229/1000. Loss of 0.5225, cover loss of 0.5077, secret loss of 0.5160
# Training: Batch 230/1000. Loss of 0.5776, cover loss of 0.5959, secret loss of 0.5541
# Training: Batch 231/1000. Loss of 0.4777, cover loss of 0.4801, secret loss of 0.4984
# Training: Batch 232/1000. Loss of 0.5569, cover loss of 0.5028, secret loss of 0.6173
# Training: Batch 233/1000. Loss of 0.4824, cover loss of 0.5106, secret loss of 0.4799
# Training: Batch 234/1000. Loss of 0.5637, cover loss of 0.5622, secret loss of 0.5640
# Training: Batch 235/1000. Loss of 0.4989, cover loss of 0.5220, secret loss of 0.5069
# Training: Batch 236/1000. Loss of 0.4453, cover loss of 0.4792, secret loss of 0.4727
# Training: Batch 237/1000. Loss of 0.5472, cover loss of 0.5255, secret loss of 0.5539
# Training: Batch 238/1000. Loss of 0.5405, cover loss of 0.5443, secret loss of 0.5261
# Training: Batch 239/1000. Loss of 0.5363, cover loss of 0.6044, secret loss of 0.4546
# Training: Batch 240/1000. Loss of 0.4914, cover loss of 0.5122, secret loss of 0.4916
# Training: Batch 241/1000. Loss of 0.5274, cover loss of 0.5151, secret loss of 0.5229
# Training: Batch 242/1000. Loss of 0.5008, cover loss of 0.5265, secret loss of 0.4950
# Training: Batch 243/1000. Loss of 0.4815, cover loss of 0.5182, secret loss of 0.4803
# Training: Batch 244/1000. Loss of 0.5302, cover loss of 0.5460, secret loss of 0.5216
# Training: Batch 245/1000. Loss of 0.5318, cover loss of 0.5323, secret loss of 0.5095
# Training: Batch 246/1000. Loss of 0.4310, cover loss of 0.4809, secret loss of 0.4486
# Training: Batch 247/1000. Loss of 0.4760, cover loss of 0.5183, secret loss of 0.4558
# Training: Batch 248/1000. Loss of 0.4746, cover loss of 0.5141, secret loss of 0.4730
# Training: Batch 249/1000. Loss of 0.5275, cover loss of 0.5195, secret loss of 0.5474
# Training: Batch 250/1000. Loss of 0.4785, cover loss of 0.5206, secret loss of 0.4720
# Training: Batch 251/1000. Loss of 0.4818, cover loss of 0.5059, secret loss of 0.4869
# Training: Batch 252/1000. Loss of 0.4949, cover loss of 0.5204, secret loss of 0.4847
# Training: Batch 253/1000. Loss of 0.4755, cover loss of 0.5116, secret loss of 0.4723
# Training: Batch 254/1000. Loss of 0.5415, cover loss of 0.5455, secret loss of 0.5400
# Training: Batch 255/1000. Loss of 0.5314, cover loss of 0.5577, secret loss of 0.5080
# Training: Batch 256/1000. Loss of 0.4842, cover loss of 0.5195, secret loss of 0.4709
# Training: Batch 257/1000. Loss of 0.5445, cover loss of 0.5317, secret loss of 0.5441
# Training: Batch 258/1000. Loss of 0.5028, cover loss of 0.5350, secret loss of 0.4685
# Training: Batch 259/1000. Loss of 0.4885, cover loss of 0.5457, secret loss of 0.4596
# Training: Batch 260/1000. Loss of 0.5620, cover loss of 0.5811, secret loss of 0.5151
# Training: Batch 261/1000. Loss of 0.5073, cover loss of 0.5532, secret loss of 0.4661
# Training: Batch 262/1000. Loss of 0.4749, cover loss of 0.5130, secret loss of 0.4560
# Training: Batch 263/1000. Loss of 0.5586, cover loss of 0.5564, secret loss of 0.5293
# Training: Batch 264/1000. Loss of 0.5137, cover loss of 0.5748, secret loss of 0.4499
# Training: Batch 265/1000. Loss of 0.4579, cover loss of 0.4974, secret loss of 0.4624
# Training: Batch 266/1000. Loss of 0.4181, cover loss of 0.4558, secret loss of 0.4375
# Training: Batch 267/1000. Loss of 0.4853, cover loss of 0.4942, secret loss of 0.5047
# Training: Batch 268/1000. Loss of 0.4392, cover loss of 0.4910, secret loss of 0.4302
# Training: Batch 269/1000. Loss of 0.5338, cover loss of 0.5384, secret loss of 0.5146
# Training: Batch 270/1000. Loss of 0.4855, cover loss of 0.5046, secret loss of 0.4648
# Training: Batch 271/1000. Loss of 0.5408, cover loss of 0.5505, secret loss of 0.5124
# Training: Batch 272/1000. Loss of 0.5301, cover loss of 0.5624, secret loss of 0.4794
# Training: Batch 273/1000. Loss of 0.5258, cover loss of 0.5233, secret loss of 0.5296
# Training: Batch 274/1000. Loss of 0.5309, cover loss of 0.5457, secret loss of 0.5165
# Training: Batch 275/1000. Loss of 0.5185, cover loss of 0.5358, secret loss of 0.5070
# Training: Batch 276/1000. Loss of 0.4927, cover loss of 0.5115, secret loss of 0.4836
# Training: Batch 277/1000. Loss of 0.4972, cover loss of 0.5779, secret loss of 0.4283
# Training: Batch 278/1000. Loss of 0.5728, cover loss of 0.5984, secret loss of 0.5308
# Training: Batch 279/1000. Loss of 0.5173, cover loss of 0.5511, secret loss of 0.4835
# Training: Batch 280/1000. Loss of 0.5710, cover loss of 0.5953, secret loss of 0.5207
# Training: Batch 281/1000. Loss of 0.5355, cover loss of 0.5761, secret loss of 0.4827
# Training: Batch 282/1000. Loss of 0.4740, cover loss of 0.5359, secret loss of 0.4605
# Training: Batch 283/1000. Loss of 0.4946, cover loss of 0.5321, secret loss of 0.4664
# Training: Batch 284/1000. Loss of 0.5233, cover loss of 0.5616, secret loss of 0.4846
# Training: Batch 285/1000. Loss of 0.5108, cover loss of 0.5348, secret loss of 0.4847
# Training: Batch 286/1000. Loss of 0.5390, cover loss of 0.5948, secret loss of 0.4632
# Training: Batch 287/1000. Loss of 0.6065, cover loss of 0.5598, secret loss of 0.5872
# Training: Batch 288/1000. Loss of 0.4725, cover loss of 0.4977, secret loss of 0.4670
# Training: Batch 289/1000. Loss of 0.4592, cover loss of 0.5173, secret loss of 0.4349
# Training: Batch 290/1000. Loss of 0.4761, cover loss of 0.5142, secret loss of 0.4532
# Training: Batch 291/1000. Loss of 0.4512, cover loss of 0.4472, secret loss of 0.4854
# Training: Batch 292/1000. Loss of 0.4884, cover loss of 0.5273, secret loss of 0.4728
# Training: Batch 293/1000. Loss of 0.5480, cover loss of 0.5464, secret loss of 0.5137
# Training: Batch 294/1000. Loss of 0.5323, cover loss of 0.5477, secret loss of 0.5173
# Training: Batch 295/1000. Loss of 0.4778, cover loss of 0.5245, secret loss of 0.4512
# Training: Batch 296/1000. Loss of 0.4657, cover loss of 0.5286, secret loss of 0.4362
# Training: Batch 297/1000. Loss of 0.4395, cover loss of 0.4638, secret loss of 0.4480
# Training: Batch 298/1000. Loss of 0.5186, cover loss of 0.5313, secret loss of 0.5079
# Training: Batch 299/1000. Loss of 0.5180, cover loss of 0.5524, secret loss of 0.5006
# Training: Batch 300/1000. Loss of 0.5131, cover loss of 0.5305, secret loss of 0.5132
# Training: Batch 301/1000. Loss of 0.4435, cover loss of 0.5061, secret loss of 0.4290
# Training: Batch 302/1000. Loss of 0.4432, cover loss of 0.4857, secret loss of 0.4299
# Training: Batch 303/1000. Loss of 0.5347, cover loss of 0.5752, secret loss of 0.4820
# Training: Batch 304/1000. Loss of 0.4912, cover loss of 0.5700, secret loss of 0.4287
# Training: Batch 305/1000. Loss of 0.4299, cover loss of 0.4819, secret loss of 0.4184
# Training: Batch 306/1000. Loss of 0.5518, cover loss of 0.5599, secret loss of 0.5323
# Training: Batch 307/1000. Loss of 0.5398, cover loss of 0.5519, secret loss of 0.5247
# Training: Batch 308/1000. Loss of 0.4966, cover loss of 0.5151, secret loss of 0.5045
# Training: Batch 309/1000. Loss of 0.5370, cover loss of 0.5761, secret loss of 0.5145
# Training: Batch 310/1000. Loss of 0.4092, cover loss of 0.4522, secret loss of 0.4281
# Training: Batch 311/1000. Loss of 0.4957, cover loss of 0.5051, secret loss of 0.5048
# Training: Batch 312/1000. Loss of 0.4994, cover loss of 0.5540, secret loss of 0.4478
# Training: Batch 313/1000. Loss of 0.4734, cover loss of 0.4802, secret loss of 0.4891
# Training: Batch 314/1000. Loss of 0.4770, cover loss of 0.4979, secret loss of 0.4899
# Training: Batch 315/1000. Loss of 0.4528, cover loss of 0.5319, secret loss of 0.4171
# Training: Batch 316/1000. Loss of 0.5230, cover loss of 0.5637, secret loss of 0.4808
# Training: Batch 317/1000. Loss of 0.4834, cover loss of 0.5058, secret loss of 0.4814
# Training: Batch 318/1000. Loss of 0.4942, cover loss of 0.5286, secret loss of 0.4878
# Training: Batch 319/1000. Loss of 0.4566, cover loss of 0.5367, secret loss of 0.4104
# Training: Batch 320/1000. Loss of 0.5004, cover loss of 0.5117, secret loss of 0.5065
# Training: Batch 321/1000. Loss of 0.5403, cover loss of 0.5384, secret loss of 0.5276
# Training: Batch 322/1000. Loss of 0.4891, cover loss of 0.5478, secret loss of 0.4342
# Training: Batch 323/1000. Loss of 0.4797, cover loss of 0.4967, secret loss of 0.5034
# Training: Batch 324/1000. Loss of 0.5178, cover loss of 0.5336, secret loss of 0.5072
# Training: Batch 325/1000. Loss of 0.4961, cover loss of 0.5167, secret loss of 0.4972
# Training: Batch 326/1000. Loss of 0.4980, cover loss of 0.5616, secret loss of 0.4282
# Training: Batch 327/1000. Loss of 0.5165, cover loss of 0.5069, secret loss of 0.5408
# Training: Batch 328/1000. Loss of 0.5371, cover loss of 0.5460, secret loss of 0.5315
# Training: Batch 329/1000. Loss of 0.5265, cover loss of 0.5720, secret loss of 0.4868
# Training: Batch 330/1000. Loss of 0.5122, cover loss of 0.5112, secret loss of 0.5400
# Training: Batch 331/1000. Loss of 0.5171, cover loss of 0.5345, secret loss of 0.4880
# Training: Batch 332/1000. Loss of 0.4758, cover loss of 0.4859, secret loss of 0.4969
# Training: Batch 333/1000. Loss of 0.4981, cover loss of 0.4722, secret loss of 0.5578
# Training: Batch 334/1000. Loss of 0.4370, cover loss of 0.4328, secret loss of 0.4842
# Training: Batch 335/1000. Loss of 0.4664, cover loss of 0.4902, secret loss of 0.4611
# Training: Batch 336/1000. Loss of 0.5202, cover loss of 0.5598, secret loss of 0.4858
# Training: Batch 337/1000. Loss of 0.5270, cover loss of 0.4833, secret loss of 0.5408
# Training: Batch 338/1000. Loss of 0.5148, cover loss of 0.5546, secret loss of 0.4810
# Training: Batch 339/1000. Loss of 0.4888, cover loss of 0.5793, secret loss of 0.4145
# Training: Batch 340/1000. Loss of 0.5478, cover loss of 0.6022, secret loss of 0.4833
# Training: Batch 341/1000. Loss of 0.5242, cover loss of 0.5702, secret loss of 0.4784
# Training: Batch 342/1000. Loss of 0.4493, cover loss of 0.4905, secret loss of 0.4568
# Training: Batch 343/1000. Loss of 0.4896, cover loss of 0.5271, secret loss of 0.4811
# Training: Batch 344/1000. Loss of 0.4467, cover loss of 0.4549, secret loss of 0.5004
# Training: Batch 345/1000. Loss of 0.5246, cover loss of 0.5244, secret loss of 0.5059
# Training: Batch 346/1000. Loss of 0.4894, cover loss of 0.5104, secret loss of 0.4934
# Training: Batch 347/1000. Loss of 0.4964, cover loss of 0.5469, secret loss of 0.4606
# Training: Batch 348/1000. Loss of 0.4627, cover loss of 0.5384, secret loss of 0.4116
# Training: Batch 349/1000. Loss of 0.4829, cover loss of 0.5663, secret loss of 0.4188
# Training: Batch 350/1000. Loss of 0.4630, cover loss of 0.4995, secret loss of 0.4712
# Training: Batch 351/1000. Loss of 0.4825, cover loss of 0.5492, secret loss of 0.4431
# Training: Batch 352/1000. Loss of 0.4867, cover loss of 0.5210, secret loss of 0.4703
# Training: Batch 353/1000. Loss of 0.4841, cover loss of 0.5404, secret loss of 0.4263
# Training: Batch 354/1000. Loss of 0.4903, cover loss of 0.5023, secret loss of 0.5081
# Training: Batch 355/1000. Loss of 0.4851, cover loss of 0.4968, secret loss of 0.4867
# Training: Batch 356/1000. Loss of 0.4349, cover loss of 0.4651, secret loss of 0.4396
# Training: Batch 357/1000. Loss of 0.4860, cover loss of 0.5671, secret loss of 0.4175
# Training: Batch 358/1000. Loss of 0.5478, cover loss of 0.5604, secret loss of 0.5217
# Training: Batch 359/1000. Loss of 0.4898, cover loss of 0.5220, secret loss of 0.4619
# Training: Batch 360/1000. Loss of 0.5269, cover loss of 0.5185, secret loss of 0.5393
# Training: Batch 361/1000. Loss of 0.5610, cover loss of 0.5828, secret loss of 0.5062
# Training: Batch 362/1000. Loss of 0.4703, cover loss of 0.4826, secret loss of 0.4850
# Training: Batch 363/1000. Loss of 0.5369, cover loss of 0.5827, secret loss of 0.4704
# Training: Batch 364/1000. Loss of 0.5000, cover loss of 0.5381, secret loss of 0.4729
# Training: Batch 365/1000. Loss of 0.5266, cover loss of 0.5199, secret loss of 0.5191
# Training: Batch 366/1000. Loss of 0.4714, cover loss of 0.4976, secret loss of 0.4617
# Training: Batch 367/1000. Loss of 0.4539, cover loss of 0.5062, secret loss of 0.4525
# Training: Batch 368/1000. Loss of 0.4650, cover loss of 0.4877, secret loss of 0.4763
# Training: Batch 369/1000. Loss of 0.4822, cover loss of 0.4543, secret loss of 0.5343
# Training: Batch 370/1000. Loss of 0.4630, cover loss of 0.5101, secret loss of 0.4495
# Training: Batch 371/1000. Loss of 0.4961, cover loss of 0.5392, secret loss of 0.4780
# Training: Batch 372/1000. Loss of 0.5281, cover loss of 0.5483, secret loss of 0.5025
# Training: Batch 373/1000. Loss of 0.4749, cover loss of 0.5382, secret loss of 0.4310
# Training: Batch 374/1000. Loss of 0.5285, cover loss of 0.5576, secret loss of 0.4752
# Training: Batch 375/1000. Loss of 0.4414, cover loss of 0.4440, secret loss of 0.4936
# Training: Batch 376/1000. Loss of 0.5150, cover loss of 0.4582, secret loss of 0.5740
# Training: Batch 377/1000. Loss of 0.4669, cover loss of 0.4714, secret loss of 0.4882
# Training: Batch 378/1000. Loss of 0.5089, cover loss of 0.5055, secret loss of 0.5046
# Training: Batch 379/1000. Loss of 0.4811, cover loss of 0.5293, secret loss of 0.4598
# Training: Batch 380/1000. Loss of 0.4893, cover loss of 0.5454, secret loss of 0.4569
# Training: Batch 381/1000. Loss of 0.5240, cover loss of 0.5388, secret loss of 0.4970
# Training: Batch 382/1000. Loss of 0.5223, cover loss of 0.5487, secret loss of 0.5060
# Training: Batch 383/1000. Loss of 0.5082, cover loss of 0.5277, secret loss of 0.4863
# Training: Batch 384/1000. Loss of 0.4607, cover loss of 0.5037, secret loss of 0.4631
# Training: Batch 385/1000. Loss of 0.4976, cover loss of 0.5248, secret loss of 0.5040
# Training: Batch 386/1000. Loss of 0.4965, cover loss of 0.5294, secret loss of 0.4582
# Training: Batch 387/1000. Loss of 0.5322, cover loss of 0.5353, secret loss of 0.5216
# Training: Batch 388/1000. Loss of 0.5216, cover loss of 0.5389, secret loss of 0.4990
# Training: Batch 389/1000. Loss of 0.5174, cover loss of 0.5306, secret loss of 0.5336
# Training: Batch 390/1000. Loss of 0.4577, cover loss of 0.5422, secret loss of 0.4133
# Training: Batch 391/1000. Loss of 0.5193, cover loss of 0.5356, secret loss of 0.5180
# Training: Batch 392/1000. Loss of 0.4905, cover loss of 0.5151, secret loss of 0.4764
# Training: Batch 393/1000. Loss of 0.4535, cover loss of 0.4939, secret loss of 0.4587
# Training: Batch 394/1000. Loss of 0.5409, cover loss of 0.5603, secret loss of 0.5270
# Training: Batch 395/1000. Loss of 0.4387, cover loss of 0.4921, secret loss of 0.4217
# Training: Batch 396/1000. Loss of 0.5392, cover loss of 0.5612, secret loss of 0.5023
# Training: Batch 397/1000. Loss of 0.4877, cover loss of 0.5451, secret loss of 0.4469
# Training: Batch 398/1000. Loss of 0.4965, cover loss of 0.5003, secret loss of 0.5062
# Training: Batch 399/1000. Loss of 0.4796, cover loss of 0.5448, secret loss of 0.4232
# Training: Batch 400/1000. Loss of 0.5087, cover loss of 0.4976, secret loss of 0.5391
# Training: Batch 401/1000. Loss of 0.5066, cover loss of 0.5224, secret loss of 0.5115
# Training: Batch 402/1000. Loss of 0.4811, cover loss of 0.5463, secret loss of 0.4390
# Training: Batch 403/1000. Loss of 0.5131, cover loss of 0.5522, secret loss of 0.4879
# Training: Batch 404/1000. Loss of 0.5067, cover loss of 0.5680, secret loss of 0.4505
# Training: Batch 405/1000. Loss of 0.5421, cover loss of 0.5722, secret loss of 0.5144
# Training: Batch 406/1000. Loss of 0.4967, cover loss of 0.5191, secret loss of 0.5083
# Training: Batch 407/1000. Loss of 0.4519, cover loss of 0.4825, secret loss of 0.4545
# Training: Batch 408/1000. Loss of 0.5178, cover loss of 0.5278, secret loss of 0.4831
# Training: Batch 409/1000. Loss of 0.4220, cover loss of 0.4448, secret loss of 0.4490
# Training: Batch 410/1000. Loss of 0.5054, cover loss of 0.5385, secret loss of 0.4841
# Training: Batch 411/1000. Loss of 0.5559, cover loss of 0.6048, secret loss of 0.4933
# Training: Batch 412/1000. Loss of 0.4815, cover loss of 0.5337, secret loss of 0.4731
# Training: Batch 413/1000. Loss of 0.4918, cover loss of 0.4611, secret loss of 0.5352
# Training: Batch 414/1000. Loss of 0.5043, cover loss of 0.5092, secret loss of 0.5329
# Training: Batch 415/1000. Loss of 0.5313, cover loss of 0.5479, secret loss of 0.5077
# Training: Batch 416/1000. Loss of 0.5206, cover loss of 0.5668, secret loss of 0.4766
# Training: Batch 417/1000. Loss of 0.4562, cover loss of 0.4885, secret loss of 0.4859
# Training: Batch 418/1000. Loss of 0.4913, cover loss of 0.5040, secret loss of 0.4944
# Training: Batch 419/1000. Loss of 0.4889, cover loss of 0.5285, secret loss of 0.4728
# Training: Batch 420/1000. Loss of 0.5202, cover loss of 0.5516, secret loss of 0.4837
# Training: Batch 421/1000. Loss of 0.4806, cover loss of 0.5341, secret loss of 0.4562
# Training: Batch 422/1000. Loss of 0.4560, cover loss of 0.5001, secret loss of 0.4494
# Training: Batch 423/1000. Loss of 0.5149, cover loss of 0.4952, secret loss of 0.5393
# Training: Batch 424/1000. Loss of 0.4951, cover loss of 0.5264, secret loss of 0.4745
# Training: Batch 425/1000. Loss of 0.4615, cover loss of 0.4749, secret loss of 0.4735
# Training: Batch 426/1000. Loss of 0.4875, cover loss of 0.5163, secret loss of 0.4867
# Training: Batch 427/1000. Loss of 0.5237, cover loss of 0.5233, secret loss of 0.5255
# Training: Batch 428/1000. Loss of 0.4472, cover loss of 0.5038, secret loss of 0.4193
# Training: Batch 429/1000. Loss of 0.4972, cover loss of 0.5888, secret loss of 0.4076
# Training: Batch 430/1000. Loss of 0.5478, cover loss of 0.5572, secret loss of 0.5241
# Training: Batch 431/1000. Loss of 0.4789, cover loss of 0.4872, secret loss of 0.4978
# Training: Batch 432/1000. Loss of 0.5386, cover loss of 0.5690, secret loss of 0.5008
# Training: Batch 433/1000. Loss of 0.4567, cover loss of 0.5239, secret loss of 0.4137
# Training: Batch 434/1000. Loss of 0.4429, cover loss of 0.4929, secret loss of 0.4471
# Training: Batch 435/1000. Loss of 0.4846, cover loss of 0.5001, secret loss of 0.4846
# Training: Batch 436/1000. Loss of 0.5457, cover loss of 0.5547, secret loss of 0.5367
# Training: Batch 437/1000. Loss of 0.5277, cover loss of 0.5880, secret loss of 0.4611
# Training: Batch 438/1000. Loss of 0.4653, cover loss of 0.4984, secret loss of 0.4670
# Training: Batch 439/1000. Loss of 0.4965, cover loss of 0.5440, secret loss of 0.4620
# Training: Batch 440/1000. Loss of 0.4731, cover loss of 0.5038, secret loss of 0.4678
# Training: Batch 441/1000. Loss of 0.4482, cover loss of 0.5309, secret loss of 0.4063
# Training: Batch 442/1000. Loss of 0.5076, cover loss of 0.5405, secret loss of 0.4711
# Training: Batch 443/1000. Loss of 0.4594, cover loss of 0.4925, secret loss of 0.4558
# Training: Batch 444/1000. Loss of 0.5066, cover loss of 0.5359, secret loss of 0.4859
# Training: Batch 445/1000. Loss of 0.4789, cover loss of 0.5155, secret loss of 0.4545
# Training: Batch 446/1000. Loss of 0.4606, cover loss of 0.4929, secret loss of 0.4574
# Training: Batch 447/1000. Loss of 0.5309, cover loss of 0.5335, secret loss of 0.5276
# Training: Batch 448/1000. Loss of 0.4946, cover loss of 0.5479, secret loss of 0.4474
# Training: Batch 449/1000. Loss of 0.4826, cover loss of 0.5298, secret loss of 0.4547
# Training: Batch 450/1000. Loss of 0.5119, cover loss of 0.5198, secret loss of 0.5072
# Training: Batch 451/1000. Loss of 0.4892, cover loss of 0.5166, secret loss of 0.5025
# Training: Batch 452/1000. Loss of 0.4692, cover loss of 0.4891, secret loss of 0.4771
# Training: Batch 453/1000. Loss of 0.4721, cover loss of 0.5194, secret loss of 0.4372
# Training: Batch 454/1000. Loss of 0.4636, cover loss of 0.4428, secret loss of 0.5004
# Training: Batch 455/1000. Loss of 0.4777, cover loss of 0.4926, secret loss of 0.4806
# Training: Batch 456/1000. Loss of 0.5044, cover loss of 0.5686, secret loss of 0.4488
# Training: Batch 457/1000. Loss of 0.5330, cover loss of 0.5726, secret loss of 0.5004
# Training: Batch 458/1000. Loss of 0.4892, cover loss of 0.5336, secret loss of 0.4628
# Training: Batch 459/1000. Loss of 0.4785, cover loss of 0.4555, secret loss of 0.5403
# Training: Batch 460/1000. Loss of 0.4916, cover loss of 0.5173, secret loss of 0.4683
# Training: Batch 461/1000. Loss of 0.5084, cover loss of 0.5278, secret loss of 0.4966
# Training: Batch 462/1000. Loss of 0.4871, cover loss of 0.5481, secret loss of 0.4495
# Training: Batch 463/1000. Loss of 0.4980, cover loss of 0.5178, secret loss of 0.4772
# Training: Batch 464/1000. Loss of 0.4751, cover loss of 0.5136, secret loss of 0.4554
# Training: Batch 465/1000. Loss of 0.5008, cover loss of 0.5387, secret loss of 0.4641
# Training: Batch 466/1000. Loss of 0.5264, cover loss of 0.5312, secret loss of 0.5197
# Training: Batch 467/1000. Loss of 0.5183, cover loss of 0.5512, secret loss of 0.4973
# Training: Batch 468/1000. Loss of 0.4545, cover loss of 0.4427, secret loss of 0.5118
# Training: Batch 469/1000. Loss of 0.5000, cover loss of 0.5028, secret loss of 0.5043
# Training: Batch 470/1000. Loss of 0.4993, cover loss of 0.5349, secret loss of 0.4788
# Training: Batch 471/1000. Loss of 0.4973, cover loss of 0.5656, secret loss of 0.4312
# Training: Batch 472/1000. Loss of 0.5051, cover loss of 0.5372, secret loss of 0.4686
# Training: Batch 473/1000. Loss of 0.4756, cover loss of 0.4712, secret loss of 0.5034
# Training: Batch 474/1000. Loss of 0.5200, cover loss of 0.5420, secret loss of 0.5030
# Training: Batch 475/1000. Loss of 0.5246, cover loss of 0.5369, secret loss of 0.5134
# Training: Batch 476/1000. Loss of 0.5484, cover loss of 0.5205, secret loss of 0.5621
# Training: Batch 477/1000. Loss of 0.4966, cover loss of 0.5525, secret loss of 0.4432
# Training: Batch 478/1000. Loss of 0.5208, cover loss of 0.5430, secret loss of 0.4963
# Training: Batch 479/1000. Loss of 0.4769, cover loss of 0.5015, secret loss of 0.4751
# Training: Batch 480/1000. Loss of 0.4674, cover loss of 0.4857, secret loss of 0.4913
# Training: Batch 481/1000. Loss of 0.5366, cover loss of 0.5225, secret loss of 0.5335
# Training: Batch 482/1000. Loss of 0.5427, cover loss of 0.5398, secret loss of 0.5079
# Training: Batch 483/1000. Loss of 0.4960, cover loss of 0.5339, secret loss of 0.4830
# Training: Batch 484/1000. Loss of 0.5189, cover loss of 0.5398, secret loss of 0.4986
# Training: Batch 485/1000. Loss of 0.4916, cover loss of 0.4741, secret loss of 0.5163
# Training: Batch 486/1000. Loss of 0.5267, cover loss of 0.5375, secret loss of 0.5094
# Training: Batch 487/1000. Loss of 0.4869, cover loss of 0.5487, secret loss of 0.4543
# Training: Batch 488/1000. Loss of 0.4594, cover loss of 0.4811, secret loss of 0.4895
# Training: Batch 489/1000. Loss of 0.4430, cover loss of 0.5165, secret loss of 0.4140
# Training: Batch 490/1000. Loss of 0.5632, cover loss of 0.5631, secret loss of 0.5521
# Training: Batch 491/1000. Loss of 0.4848, cover loss of 0.5478, secret loss of 0.4322
# Training: Batch 492/1000. Loss of 0.5112, cover loss of 0.5188, secret loss of 0.5321
# Training: Batch 493/1000. Loss of 0.4668, cover loss of 0.5253, secret loss of 0.4534
# Training: Batch 494/1000. Loss of 0.5467, cover loss of 0.5772, secret loss of 0.5083
# Training: Batch 495/1000. Loss of 0.5557, cover loss of 0.5559, secret loss of 0.5499
# Training: Batch 496/1000. Loss of 0.4921, cover loss of 0.5127, secret loss of 0.4739
# Training: Batch 497/1000. Loss of 0.5204, cover loss of 0.5496, secret loss of 0.5046
# Training: Batch 498/1000. Loss of 0.4959, cover loss of 0.5518, secret loss of 0.4353
# Training: Batch 499/1000. Loss of 0.5514, cover loss of 0.5556, secret loss of 0.5371
# Training: Batch 500/1000. Loss of 0.5366, cover loss of 0.4971, secret loss of 0.5584
# Training: Batch 501/1000. Loss of 0.5294, cover loss of 0.5320, secret loss of 0.5081
# Training: Batch 502/1000. Loss of 0.5024, cover loss of 0.5199, secret loss of 0.5028
# Training: Batch 503/1000. Loss of 0.5162, cover loss of 0.5856, secret loss of 0.4622
# Training: Batch 504/1000. Loss of 0.5313, cover loss of 0.5479, secret loss of 0.4899
# Training: Batch 505/1000. Loss of 0.4822, cover loss of 0.5480, secret loss of 0.4470
# Training: Batch 506/1000. Loss of 0.4938, cover loss of 0.5384, secret loss of 0.4728
# Training: Batch 507/1000. Loss of 0.4603, cover loss of 0.5099, secret loss of 0.4443
# Training: Batch 508/1000. Loss of 0.5083, cover loss of 0.5387, secret loss of 0.4737
# Training: Batch 509/1000. Loss of 0.5163, cover loss of 0.5255, secret loss of 0.5016
# Training: Batch 510/1000. Loss of 0.5127, cover loss of 0.5367, secret loss of 0.4955
# Training: Batch 511/1000. Loss of 0.5153, cover loss of 0.5579, secret loss of 0.4569
# Training: Batch 512/1000. Loss of 0.4528, cover loss of 0.4835, secret loss of 0.4511
# Training: Batch 513/1000. Loss of 0.4761, cover loss of 0.4684, secret loss of 0.4858
# Training: Batch 514/1000. Loss of 0.5744, cover loss of 0.5625, secret loss of 0.5473
# Training: Batch 515/1000. Loss of 0.4974, cover loss of 0.5074, secret loss of 0.4994
# Training: Batch 516/1000. Loss of 0.4638, cover loss of 0.5086, secret loss of 0.4483
# Training: Batch 517/1000. Loss of 0.4785, cover loss of 0.5291, secret loss of 0.4616
# Training: Batch 518/1000. Loss of 0.5080, cover loss of 0.5422, secret loss of 0.4656
# Training: Batch 519/1000. Loss of 0.4679, cover loss of 0.5019, secret loss of 0.4446
# Training: Batch 520/1000. Loss of 0.4889, cover loss of 0.5367, secret loss of 0.4656
# Training: Batch 521/1000. Loss of 0.5285, cover loss of 0.5739, secret loss of 0.4677
# Training: Batch 522/1000. Loss of 0.5701, cover loss of 0.5736, secret loss of 0.5228
# Training: Batch 523/1000. Loss of 0.4680, cover loss of 0.5278, secret loss of 0.4505
# Training: Batch 524/1000. Loss of 0.4945, cover loss of 0.5219, secret loss of 0.4857
# Training: Batch 525/1000. Loss of 0.4534, cover loss of 0.4925, secret loss of 0.4358
# Training: Batch 526/1000. Loss of 0.4944, cover loss of 0.5417, secret loss of 0.4662
# Training: Batch 527/1000. Loss of 0.5169, cover loss of 0.5451, secret loss of 0.4979
# Training: Batch 528/1000. Loss of 0.4767, cover loss of 0.5085, secret loss of 0.4830
# Training: Batch 529/1000. Loss of 0.5230, cover loss of 0.5632, secret loss of 0.4787
# Training: Batch 530/1000. Loss of 0.5003, cover loss of 0.5082, secret loss of 0.5036
# Training: Batch 531/1000. Loss of 0.5063, cover loss of 0.4989, secret loss of 0.5217
# Training: Batch 532/1000. Loss of 0.4950, cover loss of 0.5689, secret loss of 0.4243
# Training: Batch 533/1000. Loss of 0.4624, cover loss of 0.4859, secret loss of 0.4813
# Training: Batch 534/1000. Loss of 0.4852, cover loss of 0.5324, secret loss of 0.4576
# Training: Batch 535/1000. Loss of 0.5392, cover loss of 0.5295, secret loss of 0.5347
# Training: Batch 536/1000. Loss of 0.4434, cover loss of 0.4864, secret loss of 0.4462
# Training: Batch 537/1000. Loss of 0.4790, cover loss of 0.5050, secret loss of 0.4873
# Training: Batch 538/1000. Loss of 0.5397, cover loss of 0.5418, secret loss of 0.5226
# Training: Batch 539/1000. Loss of 0.4975, cover loss of 0.4860, secret loss of 0.5220
# Training: Batch 540/1000. Loss of 0.5305, cover loss of 0.5625, secret loss of 0.5077
# Training: Batch 541/1000. Loss of 0.4955, cover loss of 0.5229, secret loss of 0.4809
# Training: Batch 542/1000. Loss of 0.5299, cover loss of 0.5149, secret loss of 0.5327
# Training: Batch 543/1000. Loss of 0.4795, cover loss of 0.5582, secret loss of 0.4178
# Training: Batch 544/1000. Loss of 0.5063, cover loss of 0.5291, secret loss of 0.4940
# Training: Batch 545/1000. Loss of 0.5310, cover loss of 0.5668, secret loss of 0.4832
# Training: Batch 546/1000. Loss of 0.4538, cover loss of 0.5267, secret loss of 0.4351
# Training: Batch 547/1000. Loss of 0.4574, cover loss of 0.4849, secret loss of 0.4692
# Training: Batch 548/1000. Loss of 0.5137, cover loss of 0.5465, secret loss of 0.4865
# Training: Batch 549/1000. Loss of 0.5143, cover loss of 0.5437, secret loss of 0.4953
# Training: Batch 550/1000. Loss of 0.4794, cover loss of 0.5286, secret loss of 0.4475
# Training: Batch 551/1000. Loss of 0.5200, cover loss of 0.5091, secret loss of 0.5146
# Training: Batch 552/1000. Loss of 0.5150, cover loss of 0.5378, secret loss of 0.5005
# Training: Batch 553/1000. Loss of 0.5140, cover loss of 0.5462, secret loss of 0.4965
# Training: Batch 554/1000. Loss of 0.4648, cover loss of 0.4429, secret loss of 0.5256
# Training: Batch 555/1000. Loss of 0.4999, cover loss of 0.5120, secret loss of 0.4729
# Training: Batch 556/1000. Loss of 0.5280, cover loss of 0.5224, secret loss of 0.5216
# Training: Batch 557/1000. Loss of 0.4615, cover loss of 0.5044, secret loss of 0.4465
# Training: Batch 558/1000. Loss of 0.3916, cover loss of 0.4217, secret loss of 0.4353
# Training: Batch 559/1000. Loss of 0.4911, cover loss of 0.4962, secret loss of 0.5199
# Training: Batch 560/1000. Loss of 0.4727, cover loss of 0.4832, secret loss of 0.4997
# Training: Batch 561/1000. Loss of 0.5366, cover loss of 0.5569, secret loss of 0.5079
# Training: Batch 562/1000. Loss of 0.5762, cover loss of 0.5424, secret loss of 0.5945
# ...
# Training: Batch 816/1000. Loss of 0.4531, cover loss of 0.5165, secret loss of 0.4190
# Training: Batch 817/1000. Loss of 0.5049, cover loss of 0.5600, secret loss of 0.4491
# Training: Batch 818/1000. Loss of 0.5012, cover loss of 0.5303, secret loss of 0.4923
# Training: Batch 819/1000. Loss of 0.4844, cover loss of 0.5355, secret loss of 0.4584
# Training: Batch 820/1000. Loss of 0.4832, cover loss of 0.5267, secret loss of 0.4644
# Training: Batch 821/1000. Loss of 0.5019, cover loss of 0.5451, secret loss of 0.4751
# Training: Batch 822/1000. Loss of 0.4864, cover loss of 0.5523, secret loss of 0.4462
# Training: Batch 823/1000. Loss of 0.5208, cover loss of 0.5469, secret loss of 0.4917
# Training: Batch 824/1000. Loss of 0.5119, cover loss of 0.5229, secret loss of 0.5092
# Training: Batch 825/1000. Loss of 0.4757, cover loss of 0.5071, secret loss of 0.4673
# Training: Batch 826/1000. Loss of 0.5242, cover loss of 0.5743, secret loss of 0.4660
# Training: Batch 827/1000. Loss of 0.4993, cover loss of 0.5357, secret loss of 0.4800
# Training: Batch 828/1000. Loss of 0.4963, cover loss of 0.5289, secret loss of 0.4941
# Training: Batch 829/1000. Loss of 0.4954, cover loss of 0.5126, secret loss of 0.5109
# Training: Batch 830/1000. Loss of 0.5841, cover loss of 0.5914, secret loss of 0.5284
# Training: Batch 831/1000. Loss of 0.6080, cover loss of 0.5865, secret loss of 0.6009
# Training: Batch 832/1000. Loss of 0.4647, cover loss of 0.4769, secret loss of 0.4675
# Training: Batch 833/1000. Loss of 0.4781, cover loss of 0.4858, secret loss of 0.5296
# Training: Batch 834/1000. Loss of 0.4784, cover loss of 0.5356, secret loss of 0.4462
# Training: Batch 835/1000. Loss of 0.5466, cover loss of 0.5485, secret loss of 0.5342
# Training: Batch 836/1000. Loss of 0.4921, cover loss of 0.5293, secret loss of 0.4531
# Training: Batch 837/1000. Loss of 0.4793, cover loss of 0.5227, secret loss of 0.4728
# Training: Batch 838/1000. Loss of 0.4794, cover loss of 0.5097, secret loss of 0.4973
# Training: Batch 839/1000. Loss of 0.4957, cover loss of 0.5605, secret loss of 0.4523
# Training: Batch 840/1000. Loss of 0.4596, cover loss of 0.4357, secret loss of 0.5294
# Training: Batch 841/1000. Loss of 0.4704, cover loss of 0.5062, secret loss of 0.4595
# Training: Batch 842/1000. Loss of 0.4542, cover loss of 0.4743, secret loss of 0.4872
# Training: Batch 843/1000. Loss of 0.4478, cover loss of 0.4464, secret loss of 0.5055
# Training: Batch 844/1000. Loss of 0.4688, cover loss of 0.4885, secret loss of 0.5031
# Training: Batch 845/1000. Loss of 0.4553, cover loss of 0.5363, secret loss of 0.3961
# Training: Batch 846/1000. Loss of 0.5399, cover loss of 0.5756, secret loss of 0.4892
# Training: Batch 847/1000. Loss of 0.4561, cover loss of 0.4690, secret loss of 0.4698
# Training: Batch 848/1000. Loss of 0.4093, cover loss of 0.4361, secret loss of 0.4508
# Training: Batch 849/1000. Loss of 0.5044, cover loss of 0.5196, secret loss of 0.4967
# Training: Batch 850/1000. Loss of 0.4591, cover loss of 0.5066, secret loss of 0.4217
# Training: Batch 851/1000. Loss of 0.5037, cover loss of 0.5550, secret loss of 0.4756
# Training: Batch 852/1000. Loss of 0.5949, cover loss of 0.5828, secret loss of 0.5447
# Training: Batch 853/1000. Loss of 0.5338, cover loss of 0.5386, secret loss of 0.5215
# Training: Batch 854/1000. Loss of 0.4667, cover loss of 0.5274, secret loss of 0.4520
# Training: Batch 855/1000. Loss of 0.4706, cover loss of 0.5026, secret loss of 0.4609
# Training: Batch 856/1000. Loss of 0.5198, cover loss of 0.5456, secret loss of 0.5002
# Training: Batch 857/1000. Loss of 0.5605, cover loss of 0.5644, secret loss of 0.5296
# Training: Batch 858/1000. Loss of 0.4427, cover loss of 0.4998, secret loss of 0.4459
# Training: Batch 859/1000. Loss of 0.5357, cover loss of 0.5630, secret loss of 0.5143
# Training: Batch 860/1000. Loss of 0.5649, cover loss of 0.5558, secret loss of 0.5613
# Training: Batch 861/1000. Loss of 0.5113, cover loss of 0.5511, secret loss of 0.4822
# Training: Batch 862/1000. Loss of 0.5333, cover loss of 0.5680, secret loss of 0.4724
# Training: Batch 863/1000. Loss of 0.4805, cover loss of 0.5183, secret loss of 0.4882
# Training: Batch 864/1000. Loss of 0.5032, cover loss of 0.5195, secret loss of 0.4743
# Training: Batch 865/1000. Loss of 0.4744, cover loss of 0.5020, secret loss of 0.5024
# Training: Batch 866/1000. Loss of 0.5103, cover loss of 0.5980, secret loss of 0.4287
# Training: Batch 867/1000. Loss of 0.5263, cover loss of 0.5663, secret loss of 0.4910
# Training: Batch 868/1000. Loss of 0.5178, cover loss of 0.5787, secret loss of 0.4748
# Training: Batch 869/1000. Loss of 0.4850, cover loss of 0.5053, secret loss of 0.4785
# Training: Batch 870/1000. Loss of 0.5556, cover loss of 0.5444, secret loss of 0.5549
# Training: Batch 871/1000. Loss of 0.4959, cover loss of 0.5713, secret loss of 0.4415
# Training: Batch 872/1000. Loss of 0.4762, cover loss of 0.5107, secret loss of 0.4594
# Training: Batch 873/1000. Loss of 0.4518, cover loss of 0.4709, secret loss of 0.4806
# Training: Batch 874/1000. Loss of 0.4891, cover loss of 0.4711, secret loss of 0.5205
# Training: Batch 875/1000. Loss of 0.5107, cover loss of 0.5274, secret loss of 0.5110
# Training: Batch 876/1000. Loss of 0.4685, cover loss of 0.4957, secret loss of 0.4697
# Training: Batch 877/1000. Loss of 0.4919, cover loss of 0.5274, secret loss of 0.4648
# Training: Batch 878/1000. Loss of 0.4962, cover loss of 0.5337, secret loss of 0.4722
# Training: Batch 879/1000. Loss of 0.5204, cover loss of 0.5119, secret loss of 0.5404
# Training: Batch 880/1000. Loss of 0.4745, cover loss of 0.5079, secret loss of 0.4663
# Training: Batch 881/1000. Loss of 0.5327, cover loss of 0.5328, secret loss of 0.5257
# Training: Batch 882/1000. Loss of 0.5004, cover loss of 0.5410, secret loss of 0.4639
# Training: Batch 883/1000. Loss of 0.4616, cover loss of 0.4709, secret loss of 0.4689
# Training: Batch 884/1000. Loss of 0.4643, cover loss of 0.4940, secret loss of 0.4660
# Training: Batch 885/1000. Loss of 0.5580, cover loss of 0.5948, secret loss of 0.4906
# Training: Batch 886/1000. Loss of 0.5208, cover loss of 0.5650, secret loss of 0.4862
# Training: Batch 887/1000. Loss of 0.4855, cover loss of 0.5015, secret loss of 0.4860
# Training: Batch 888/1000. Loss of 0.4881, cover loss of 0.5220, secret loss of 0.4790
# Training: Batch 889/1000. Loss of 0.5003, cover loss of 0.5036, secret loss of 0.5053
# Training: Batch 890/1000. Loss of 0.4924, cover loss of 0.5615, secret loss of 0.4509
# Training: Batch 891/1000. Loss of 0.5191, cover loss of 0.5556, secret loss of 0.4877
# Training: Batch 892/1000. Loss of 0.4405, cover loss of 0.4905, secret loss of 0.4519
# Training: Batch 893/1000. Loss of 0.5232, cover loss of 0.5365, secret loss of 0.5145
# Training: Batch 894/1000. Loss of 0.4914, cover loss of 0.4384, secret loss of 0.5623
# Training: Batch 895/1000. Loss of 0.5149, cover loss of 0.5477, secret loss of 0.4793
# Training: Batch 896/1000. Loss of 0.4969, cover loss of 0.5240, secret loss of 0.4766
# Training: Batch 897/1000. Loss of 0.4263, cover loss of 0.5013, secret loss of 0.4199
# Training: Batch 898/1000. Loss of 0.5514, cover loss of 0.5579, secret loss of 0.5235
# Training: Batch 899/1000. Loss of 0.4631, cover loss of 0.4980, secret loss of 0.4694
# Training: Batch 900/1000. Loss of 0.5624, cover loss of 0.6002, secret loss of 0.4849
# Training: Batch 901/1000. Loss of 0.5373, cover loss of 0.5521, secret loss of 0.5082
# Training: Batch 902/1000. Loss of 0.4668, cover loss of 0.4961, secret loss of 0.4686
# Training: Batch 903/1000. Loss of 0.5146, cover loss of 0.5097, secret loss of 0.4986
# Training: Batch 904/1000. Loss of 0.4546, cover loss of 0.4804, secret loss of 0.4712
# Training: Batch 905/1000. Loss of 0.5050, cover loss of 0.5519, secret loss of 0.4569
# Training: Batch 906/1000. Loss of 0.5490, cover loss of 0.5896, secret loss of 0.5110
# Training: Batch 907/1000. Loss of 0.5069, cover loss of 0.5358, secret loss of 0.4781
# Training: Batch 908/1000. Loss of 0.5148, cover loss of 0.5570, secret loss of 0.4794
# Training: Batch 909/1000. Loss of 0.4506, cover loss of 0.4854, secret loss of 0.4504
# Training: Batch 910/1000. Loss of 0.4772, cover loss of 0.5306, secret loss of 0.4557
# Training: Batch 911/1000. Loss of 0.4549, cover loss of 0.5042, secret loss of 0.4624
# Training: Batch 912/1000. Loss of 0.4701, cover loss of 0.5409, secret loss of 0.4346
# Training: Batch 913/1000. Loss of 0.5222, cover loss of 0.5521, secret loss of 0.4989
# Training: Batch 914/1000. Loss of 0.5227, cover loss of 0.5468, secret loss of 0.4887
# Training: Batch 915/1000. Loss of 0.4532, cover loss of 0.4884, secret loss of 0.4696
# Training: Batch 916/1000. Loss of 0.4413, cover loss of 0.5053, secret loss of 0.4158
# Training: Batch 917/1000. Loss of 0.5104, cover loss of 0.5347, secret loss of 0.5182
# Training: Batch 918/1000. Loss of 0.5394, cover loss of 0.5787, secret loss of 0.5032
# Training: Batch 919/1000. Loss of 0.4245, cover loss of 0.4886, secret loss of 0.4280
# Training: Batch 920/1000. Loss of 0.5224, cover loss of 0.5221, secret loss of 0.5276
# Training: Batch 921/1000. Loss of 0.5237, cover loss of 0.5424, secret loss of 0.5323
# Training: Batch 922/1000. Loss of 0.5091, cover loss of 0.5282, secret loss of 0.5160
# Training: Batch 923/1000. Loss of 0.4465, cover loss of 0.4602, secret loss of 0.4888
# Training: Batch 924/1000. Loss of 0.5176, cover loss of 0.5535, secret loss of 0.4835
# Training: Batch 925/1000. Loss of 0.4680, cover loss of 0.5214, secret loss of 0.4538
# Training: Batch 926/1000. Loss of 0.5328, cover loss of 0.5258, secret loss of 0.5150
# Training: Batch 927/1000. Loss of 0.4774, cover loss of 0.4866, secret loss of 0.5071
# Training: Batch 928/1000. Loss of 0.4647, cover loss of 0.4897, secret loss of 0.4915
# Training: Batch 929/1000. Loss of 0.4353, cover loss of 0.4825, secret loss of 0.4277
# Training: Batch 930/1000. Loss of 0.4316, cover loss of 0.4702, secret loss of 0.4628
# Training: Batch 931/1000. Loss of 0.4645, cover loss of 0.4923, secret loss of 0.4652
# Training: Batch 932/1000. Loss of 0.4183, cover loss of 0.4506, secret loss of 0.4562
# Training: Batch 933/1000. Loss of 0.5030, cover loss of 0.4953, secret loss of 0.5259
# Training: Batch 934/1000. Loss of 0.5695, cover loss of 0.5722, secret loss of 0.5334
# Training: Batch 935/1000. Loss of 0.4731, cover loss of 0.5063, secret loss of 0.4828
# Training: Batch 936/1000. Loss of 0.5176, cover loss of 0.5042, secret loss of 0.5477
# Training: Batch 937/1000. Loss of 0.4842, cover loss of 0.5351, secret loss of 0.4432
# Training: Batch 938/1000. Loss of 0.5191, cover loss of 0.5142, secret loss of 0.5244
# Training: Batch 939/1000. Loss of 0.4886, cover loss of 0.5513, secret loss of 0.4470
# Training: Batch 940/1000. Loss of 0.5679, cover loss of 0.5939, secret loss of 0.5034
# Training: Batch 941/1000. Loss of 0.5040, cover loss of 0.5170, secret loss of 0.4949
# Training: Batch 942/1000. Loss of 0.4608, cover loss of 0.4881, secret loss of 0.4657
# Training: Batch 943/1000. Loss of 0.4851, cover loss of 0.4936, secret loss of 0.4824
# Training: Batch 944/1000. Loss of 0.4955, cover loss of 0.5381, secret loss of 0.4833
# Training: Batch 945/1000. Loss of 0.4302, cover loss of 0.4644, secret loss of 0.4499
# Training: Batch 946/1000. Loss of 0.4989, cover loss of 0.5249, secret loss of 0.4881
# Training: Batch 947/1000. Loss of 0.4774, cover loss of 0.5062, secret loss of 0.4564
# Training: Batch 948/1000. Loss of 0.5041, cover loss of 0.5617, secret loss of 0.4509
# Training: Batch 949/1000. Loss of 0.4955, cover loss of 0.5523, secret loss of 0.4633
# Training: Batch 950/1000. Loss of 0.5250, cover loss of 0.5546, secret loss of 0.4947
# Training: Batch 951/1000. Loss of 0.4507, cover loss of 0.5152, secret loss of 0.4413
# Training: Batch 952/1000. Loss of 0.5159, cover loss of 0.5629, secret loss of 0.4738
# Training: Batch 953/1000. Loss of 0.4970, cover loss of 0.5733, secret loss of 0.4270
# Training: Batch 954/1000. Loss of 0.5271, cover loss of 0.5299, secret loss of 0.5290
# Training: Batch 955/1000. Loss of 0.4916, cover loss of 0.5384, secret loss of 0.4597
# Training: Batch 956/1000. Loss of 0.4728, cover loss of 0.4937, secret loss of 0.4716
# Training: Batch 957/1000. Loss of 0.4803, cover loss of 0.4994, secret loss of 0.4817
# Training: Batch 958/1000. Loss of 0.5507, cover loss of 0.5196, secret loss of 0.5775
# Training: Batch 959/1000. Loss of 0.5151, cover loss of 0.5724, secret loss of 0.4605
# Training: Batch 960/1000. Loss of 0.5019, cover loss of 0.4929, secret loss of 0.5161
# Training: Batch 961/1000. Loss of 0.5115, cover loss of 0.5646, secret loss of 0.4698
# Training: Batch 962/1000. Loss of 0.5117, cover loss of 0.5307, secret loss of 0.4977
# Training: Batch 963/1000. Loss of 0.5107, cover loss of 0.5507, secret loss of 0.4543
# Training: Batch 964/1000. Loss of 0.5195, cover loss of 0.5674, secret loss of 0.4884
# Training: Batch 965/1000. Loss of 0.4764, cover loss of 0.5180, secret loss of 0.4606
# Training: Batch 966/1000. Loss of 0.4209, cover loss of 0.4364, secret loss of 0.4683
# Training: Batch 967/1000. Loss of 0.4560, cover loss of 0.4923, secret loss of 0.4456
# Training: Batch 968/1000. Loss of 0.5498, cover loss of 0.5865, secret loss of 0.4746
# Training: Batch 969/1000. Loss of 0.4975, cover loss of 0.5579, secret loss of 0.4593
# Training: Batch 970/1000. Loss of 0.4691, cover loss of 0.5176, secret loss of 0.4614
# Training: Batch 971/1000. Loss of 0.4723, cover loss of 0.5236, secret loss of 0.4527
# Training: Batch 972/1000. Loss of 0.4223, cover loss of 0.4745, secret loss of 0.4276
# Training: Batch 973/1000. Loss of 0.5397, cover loss of 0.5480, secret loss of 0.5286
# Training: Batch 974/1000. Loss of 0.4828, cover loss of 0.5017, secret loss of 0.5029
# Training: Batch 975/1000. Loss of 0.5151, cover loss of 0.5305, secret loss of 0.5001
# Training: Batch 976/1000. Loss of 0.5542, cover loss of 0.5558, secret loss of 0.5214
# Training: Batch 977/1000. Loss of 0.5080, cover loss of 0.5468, secret loss of 0.4709
# Training: Batch 978/1000. Loss of 0.4958, cover loss of 0.5360, secret loss of 0.4747
# Training: Batch 979/1000. Loss of 0.5009, cover loss of 0.5380, secret loss of 0.4782
# Training: Batch 980/1000. Loss of 0.5137, cover loss of 0.5735, secret loss of 0.4703
# Training: Batch 981/1000. Loss of 0.5133, cover loss of 0.5289, secret loss of 0.5184
# Training: Batch 982/1000. Loss of 0.5335, cover loss of 0.5806, secret loss of 0.4929
# Training: Batch 983/1000. Loss of 0.4628, cover loss of 0.5007, secret loss of 0.4748
# Training: Batch 984/1000. Loss of 0.4644, cover loss of 0.5180, secret loss of 0.4493
# Training: Batch 985/1000. Loss of 0.4913, cover loss of 0.5368, secret loss of 0.4736
# Training: Batch 986/1000. Loss of 0.4724, cover loss of 0.5439, secret loss of 0.4467
# Training: Batch 987/1000. Loss of 0.4267, cover loss of 0.4830, secret loss of 0.4209
# Training: Batch 988/1000. Loss of 0.5277, cover loss of 0.5240, secret loss of 0.5392
# Training: Batch 989/1000. Loss of 0.4804, cover loss of 0.4725, secret loss of 0.4968
# Training: Batch 990/1000. Loss of 0.5288, cover loss of 0.5585, secret loss of 0.4936
# Training: Batch 991/1000. Loss of 0.4815, cover loss of 0.5057, secret loss of 0.4932
# Training: Batch 992/1000. Loss of 0.5094, cover loss of 0.5236, secret loss of 0.4904
# Training: Batch 993/1000. Loss of 0.4774, cover loss of 0.4938, secret loss of 0.4980
# Training: Batch 994/1000. Loss of 0.4843, cover loss of 0.5198, secret loss of 0.4828
# Training: Batch 995/1000. Loss of 0.4955, cover loss of 0.5044, secret loss of 0.4819
# Training: Batch 996/1000. Loss of 0.4978, cover loss of 0.5335, secret loss of 0.4856
# Training: Batch 997/1000. Loss of 0.5089, cover loss of 0.5390, secret loss of 0.4841
# Training: Batch 998/1000. Loss of 0.4829, cover loss of 0.4751, secret loss of 0.5039
# Training: Batch 999/1000. Loss of 0.5128, cover loss of 0.4633, secret loss of 0.5707
# Training: Batch 1000/1000. Loss of 0.5568, cover loss of 0.5890, secret loss of 0.5112
# Epoch [50/50], Average_loss: 0.4962

# %%
 # Plot loss through epochs
plt.plot(loss_history)
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Batch')
plt.show()

# %%
def pixel_errors(input_S, input_C, decoded_S, decoded_C):
    """Calculates mean of Sum of Squared Errors per pixel for cover and secret images. """
    input_S = np.array(input_S.detach().cpu())
    input_C = np.array(input_C.detach().cpu())
    decoded_S = np.array(decoded_S.detach().cpu())
    decoded_C = np.array(decoded_C.detach().cpu())
    # print(input_S)
    see_Spixel = np.sqrt(np.mean(np.square(255*(input_S - decoded_S))))
    see_Cpixel = np.sqrt(np.mean(np.square(255*(input_C - decoded_C))))
    
    return see_Spixel, see_Cpixel

import math
def psnr(input_S, input_C, decoded_S, decoded_C):
    input_S = np.array(input_S.detach().cpu())
    input_C = np.array(input_C.detach().cpu())
    decoded_S = np.array(decoded_S.detach().cpu())
    decoded_C = np.array(decoded_C.detach().cpu())
    mse_s = np.mean(np.square(255*(input_S - decoded_S)))
    mse_c = np.mean(np.square(255*(input_C - decoded_C)))
    psnr_s = 10*math.log10(255**2/mse_s)
    psnr_c = 10*math.log10(255**2/mse_c)
    return psnr_s, psnr_c

def pixel_histogram(diff_S, diff_C):
    """Calculates histograms of errors for cover and secret image. """
    diff_Sflat = diff_S.flatten()
    diff_Cflat = diff_C.flatten()
    
    fig = plt.figure(figsize=(15, 5))
    a=fig.add_subplot(1,2,1)
        
    imgplot = plt.hist(255* diff_Cflat, 100, density=1, alpha=0.75, facecolor='red')
    a.set_title('Distribution of error in the Cover image.')
    plt.axis([0, 250, 0, 0.2])
    
    a=fig.add_subplot(1,2,2)
    imgplot = plt.hist(255* diff_Sflat, 100, density=1, alpha=0.75, facecolor='red')
    a.set_title('Distribution of errors in the Secret image.')
    plt.axis([0, 250, 0, 0.2])
    
    plt.show()

# %%
# net.load_state_dict(torch.load(MODELS_PATH+'Epoch N4.pkl'))

# Switch to evaluate mode
net.eval()
Path(PATH+"LOSS2_1_ds_img_30").mkdir(parents=True, exist_ok=True)
Path(PATH+"LOSS2_1_ds_img_30/cover_images/").mkdir(parents=True, exist_ok=True)
Path(PATH+"LOSS2_1_ds_img_30/container_images/").mkdir(parents=True, exist_ok=True)
save_path = PATH+"LOSS2_1_ds_img_30/"

test_losses = []

S_errors = []
C_errors = []

psnr_s,psnr_c = [], []
# Show images
for idx, test_batch in enumerate(test_loader):
     # Saves images
    data, _ = test_batch
    data = data.to(device)

    # Saves secret images and secret covers
    test_secret = data[:len(data)//2]
    test_cover = data[len(data)//2:]

    # Creates variable from secret and cover images
    test_secret = Variable(test_secret, volatile=True)
    test_cover = Variable(test_cover, volatile=True)

    # Compute output
    test_hidden, test_output = net(test_secret, test_cover)
    
    # Calculate loss
    test_loss, loss_cover, loss_secret = customized_loss(test_output, test_hidden, test_secret, test_cover, beta)
    
    diff_S, diff_C = np.abs(np.array(test_output.data.detach().cpu()) - np.array(test_secret.data.detach().cpu())), np.abs(np.array(test_hidden.data.detach().cpu()) - np.array(test_cover.data.detach().cpu()))
    
#     print (diff_S, diff_C)

    # Print pixel-wise average errors in a 256 scale.
    S_error, C_error = pixel_errors(test_secret, test_cover, test_output, test_hidden)
    S_errors.append(S_error)
    C_errors.append(C_error)

    S_psnr, C_psnr = psnr(test_secret, test_cover, test_output, test_hidden)
    psnr_s.append(S_psnr)
    psnr_c.append(C_psnr)
    
    if idx in [1,2,3,4]:
        print ('Total loss: {:.2f} \nLoss on secret: {:.2f} \nLoss on cover: {:.2f}'.format(test_loss.data.item(), loss_secret.data.item(), loss_cover.data.item()))

        # Creates img tensor
        imgs = [test_secret.data.detach().cpu(), test_output.data.detach().cpu(), test_cover.data.detach().cpu(), test_hidden.data.detach().cpu()]
        imgs_tsor = torch.cat(imgs, 0)

        # Prints Images
        imshow(utils.make_grid(imgs_tsor), idx+1, learning_rate=learning_rate, beta=beta)

    if idx < 500:
        container_img = tensor_to_image(test_hidden.data.detach().cpu())
        container_img = Image.fromarray(container_img)
        container_img.save(save_path+"container_images/"+str(idx)+".jpeg")
        cover_img = tensor_to_image(test_cover.data.detach().cpu())
        cover_img = Image.fromarray(cover_img)
        cover_img.save(save_path+"cover_images/"+str(idx)+".jpeg")
            
    test_losses.append(test_loss.data.item())
        
mean_test_loss = np.mean(test_losses)

print ('Average loss on test set: {:.2f}'.format(mean_test_loss))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:27: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:43: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Total loss: 0.87
# Loss on secret: 0.83
# Loss on cover: 0.72
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Total loss: 0.42
# Loss on secret: 0.36
# Loss on cover: 0.48
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Total loss: 0.53
# Loss on secret: 0.58
# Loss on cover: 0.54
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Total loss: 0.56
# Loss on secret: 0.42
# Loss on cover: 0.70
# Average loss on test set: 0.53

# %%
print ("Avg. S error per pixel [0, 255]:", sum(S_errors)/len(S_errors))
print ("Avg. C error per pixel [0, 255]:", sum(C_errors)/len(C_errors))
# Out:
# Avg. S error per pixel [0, 255]: 172.69853595581054
# Avg. C error per pixel [0, 255]: 194.1798922241211

# %%
print ("Avg. PSNR of secret and decoded secret:", sum(psnr_s)/len(psnr_s))
print ("Avg. PSNR of cover and container:", sum(psnr_c)/len(psnr_c))
# Out:
# Avg. PSNR of secret and decoded secret: 3.653716826473699
# Avg. PSNR of cover and container: 2.6527313842502998

# %%
# Plot distribution of errors in cover and secret images.
pixel_histogram(diff_S, diff_C)
