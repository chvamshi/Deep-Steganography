# %% [markdown]
# <a href="https://colab.research.google.com/github/chvamshi/Deep-Steganography/blob/main/Copy_of_LOSS2_DS_with_noise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget http://cs231n.stanford.edu/tiny-imagenet-200.zip
# !unzip -q tiny-imagenet-200.zip && ls tiny-imagenet-200
# Out:
# --2022-02-08 17:55:25--  http://cs231n.stanford.edu/tiny-imagenet-200.zip
# Resolving cs231n.stanford.edu (cs231n.stanford.edu)... 171.64.68.10
# Connecting to cs231n.stanford.edu (cs231n.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248100043 (237M) [application/zip]
# Saving to: ‘tiny-imagenet-200.zip’
#
# tiny-imagenet-200.z 100%[===================>] 236.61M  78.1MB/s    in 3.0s
#
# 2022-02-08 17:55:29 (78.1 MB/s) - ‘tiny-imagenet-200.zip’ saved [248100043/248100043]
#
# test  train  val  wnids.txt  words.txt

# %%
# Imports necessary libraries and modules
from itertools import islice
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch.autograd import Variable
from torch import utils
from torch.utils.data import Subset
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import os 
from pathlib import Path
import pickle
import random
from torchvision import datasets, utils
import torchvision.transforms as transforms
from torchvision.transforms import ToPILImage
from torchvision.transforms import RandomResizedCrop
from torchvision.transforms.functional import resized_crop
from random import shuffle
from IPython.display import Image
from PIL import Image

# Use GPU if it is present
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
# Directory path
# os.chdir("..")
cwd = '/content/tiny-imagenet-200'



# Hyper Parameters
num_epochs = 23
batch_size = 32
learning_rate = 0.001
beta = 1

# Mean and std deviation of imagenet dataset. Source: http://cs231n.stanford.edu/reports/2017/pdfs/101.pdf
std = [0.229, 0.224, 0.225]
mean = [0.485, 0.456, 0.406]

# TODO: Define train, validation and models
MODELS_PATH = '/content/output/models'
# TRAIN_PATH = cwd+'/train/'
# VALID_PATH = cwd+'/valid/'
VALID_PATH = cwd+'/val/'
TRAIN_PATH = cwd+'/train/'
TEST_PATH = cwd+'/test/'

# if not os.path.exists(MODELS_PATH): os.mkdir(MODELS_PATH)

# %%
from skimage.util import random_noise

def variance(image1, image2):
    var1 = torch.var(image2-image1)
    # var2 = torch.var(image2)

    return var1

def customized_loss(S_prime, C_prime, S, C, B):
    ''' Calculates loss specified on the paper.'''
    
    loss_cover = torch.nn.functional.l1_loss(C_prime, C)
    # loss_cover = loss_cover/(64*64)
    loss_secret = torch.nn.functional.l1_loss(S_prime, S)
    # loss_secret = loss_secret/(64*64)

    variance_cover = variance(C_prime, C)
    variance_secret = variance(S_prime, S)

    loss_all = loss_cover+loss_secret+variance_cover+variance_secret
    loss_all = loss_all/4

    return loss_all, loss_cover, loss_secret

def denormalize(image, std, mean):
    ''' Denormalizes a tensor of images.'''

    for t in range(3):
        image[t, :, :] = (image[t, :, :] * std[t]) + mean[t]
    return image

def imshow(img, idx, learning_rate, beta):
    '''Prints out an image given in tensor format.'''
    
    img = denormalize(img, std, mean)
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.title('Example '+str(idx)+', lr='+str(learning_rate)+', B='+str(beta))
    plt.show()
    return

def gaussian(tensor, mean=0, stddev=0.1):
    '''Adds random noise to a tensor.'''
    
    noise = torch.nn.init.normal(torch.Tensor(tensor.size()), 0, 0.1).to(device)
    return Variable(tensor + noise)

def salt(tensor):
    salt_img = torch.tensor(random_noise(tensor, mode='salt', amount=0.05))
    return Variable(tensor + salt_img)


def tensor_to_image(tensor):
    """
    Transforms a torch tensor into numpy uint8 array (image)
    :param tensor: (batch_size x channels x height x width) torch tensor in range [-1.0, 1.0]
    :return: (batch_size x height x width x channels) uint8 array
    """
    image = tensor.cpu().numpy()[0]
    # image = tensor.permute(0, 2, 3, 1).cpu().numpy()
    image = np.transpose(image, (1,2,0))
    image = (image + 1) * 127.5
    return np.clip(image, 0, 255).astype(np.uint8)

# %%
# Preparation Network (2 conv layers)
class PrepNetwork(nn.Module):
    def __init__(self):
        super(PrepNetwork, self).__init__()
        self.initialP3 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialP4 = nn.Sequential(
            nn.Conv2d(3, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialP5 = nn.Sequential(
            nn.Conv2d(3, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalP3 = nn.Sequential(
            nn.Conv2d(65, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalP4 = nn.Sequential(
            nn.Conv2d(65, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalP5 = nn.Sequential(
            nn.Conv2d(65, 5, kernel_size=5, padding=2),
            nn.ReLU())

    def forward(self, p):
        p1 = self.initialP3(p)
        p2 = self.initialP4(p)
        p3 = self.initialP5(p)
        mid = torch.cat((p1, p2, p3), 1)
        p4 = self.finalP3(mid)
        p5 = self.finalP4(mid)
        p6 = self.finalP5(mid)
        # print(p4.shape)
        # print(p5.shape)
        # print(p6.shape)
        out = torch.cat((p4, p5, p6), 1)
        return out

# Hiding Network (5 conv layers)
class HidingNetwork(nn.Module):
    def __init__(self):
        super(HidingNetwork, self).__init__()
        self.initialH3 = nn.Sequential(
            nn.Conv2d(68, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialH4 = nn.Sequential(
            nn.Conv2d(68, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialH5 = nn.Sequential(
            nn.Conv2d(68, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalH3 = nn.Sequential(
            nn.Conv2d(65, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalH4 = nn.Sequential(
            nn.Conv2d(65, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalH5 = nn.Sequential(
            nn.Conv2d(65, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalH = nn.Sequential(
            nn.Conv2d(65, 3, kernel_size=1, padding=0))
        
    def forward(self, h):
        h1 = self.initialH3(h)
        h2 = self.initialH4(h)
        h3 = self.initialH5(h)
        mid = torch.cat((h1, h2, h3), 1)
        h4 = self.finalH3(mid)
        h5 = self.finalH4(mid)
        h6 = self.finalH5(mid)
        mid2 = torch.cat((h4, h5, h6), 1)
        out = self.finalH(mid2)
        out_noise = gaussian(out.data, 0, 0.1)
        return out, out_noise

# Reveal Network (2 conv layers)
class RevealNetwork(nn.Module):
    def __init__(self):
        super(RevealNetwork, self).__init__()
        self.initialR3 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialR4 = nn.Sequential(
            nn.Conv2d(3, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialR5 = nn.Sequential(
            nn.Conv2d(3, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalR3 = nn.Sequential(
            nn.Conv2d(65, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalR4 = nn.Sequential(
            nn.Conv2d(65, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalR5 = nn.Sequential(
            nn.Conv2d(65, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalR = nn.Sequential(
            nn.Conv2d(65, 3, kernel_size=1, padding=0))

    def forward(self, r):
        r1 = self.initialR3(r)
        r2 = self.initialR4(r)
        r3 = self.initialR5(r)
        mid = torch.cat((r1, r2, r3), 1)
        r4 = self.finalR3(mid)
        r5 = self.finalR4(mid)
        r6 = self.finalR5(mid)
        mid2 = torch.cat((r4, r5, r6), 1)
        out = self.finalR(mid2)
        return out

# Join three networks in one module
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.m1 = PrepNetwork().to(device)
        self.m2 = HidingNetwork().to(device)
        self.m3 = RevealNetwork().to(device)

    def forward(self, secret, cover):
        x_1 = self.m1(secret)
        mid = torch.cat((x_1, cover), 1)
        x_2, x_2_noise = self.m2(mid)
        x_3 = self.m3(x_2_noise)
        # x_3 = self.m3(x_2)
        return x_2, x_3

# %%
# Creates net object
net = Net().to(device)

# %%
# Creates training set
train_data = datasets.ImageFolder(
        TRAIN_PATH,
        transforms.Compose([
        # transforms.Scale(256),
        # transforms.RandomCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean,
        std=std)
        ]))
train_data = Subset(train_data, [i for i in range(32000)])
train_loader = torch.utils.data.DataLoader(
        train_data, batch_size=batch_size, num_workers=1, 
        pin_memory=True, shuffle=True, drop_last=True)

# Creates test set
test_data = datasets.ImageFolder(
        TEST_PATH, 
        transforms.Compose([
        # transforms.Scale(256),
        # transforms.RandomCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean,
        std=std)
        ]))
test_data = Subset(test_data,[i for i in range(5000)])
test_loader = torch.utils.data.DataLoader(
        test_data, batch_size=2, num_workers=1, 
        pin_memory=True, shuffle=True, drop_last=True)

# %%
PATH = "/content/drive/MyDrive/"
loss_history = []

def train_model(train_loader, beta, learning_rate):
    
    # Save optimizer
    optimizer = optim.Adam(net.parameters(), lr=learning_rate)
    
    loss_history = []
    # Iterate over batches performing forward and backward passes
    for epoch in range(num_epochs):

        # Train mode
        net.train()
        
        train_losses = []
        # Train one epoch
        for idx, train_batch in enumerate(train_loader):

            data, _  = train_batch
            data = data.to(device)

            # Saves secret images and secret covers
            train_covers = data[:len(data)//2]
            train_secrets = data[len(data)//2:]
            
            # Creates variable from secret and cover images
            train_secrets = Variable(train_secrets, requires_grad=False)
            train_covers = Variable(train_covers, requires_grad=False)

            # Forward + Backward + Optimize
            optimizer.zero_grad()
            train_hidden, train_output = net(train_secrets, train_covers)

            # Calculate loss and perform backprop
            train_loss, train_loss_cover, train_loss_secret = customized_loss(train_output, train_hidden, train_secrets, train_covers, beta)
            train_loss.backward()
            optimizer.step()
            
            # Saves training loss
            # print(train_loss.data)
            train_losses.append(train_loss.data.item())
            loss_history.append(train_loss.data.item())
            
            # Prints mini-batch losses
            print('Training: Batch {0}/{1}. Loss of {2:.4f}, cover loss of {3:.4f}, secret loss of {4:.4f}'.format(idx+1, len(train_loader), train_loss.data.item(), train_loss_cover.data.item(), train_loss_secret.data.item()))
    
        # Save model
        # torch.save(net.state_dict(), '/content/Epoch N{}.pkl'.format(epoch+1))
        torch.save(net.state_dict(), PATH+"LOSS2_1_ds_with_noise.pth")
        with open(PATH+"LOSS2_1_loss_history_with_noise.txt", "a") as f:
            for s in loss_history:
                f.write(str(s) +"\n")
        
        mean_train_loss = np.mean(train_losses)
    
        # Prints epoch average loss
        print ('Epoch [{0}/{1}], Average_loss: {2:.4f}'.format(
                epoch+1, num_epochs, mean_train_loss))
    
    return net, mean_train_loss, loss_history

# %%
# Load model
# net.load_state_dict(torch.load(PATH+"LOSS2_1__ds_with_noise.pth"))
# loss_history = []
# with open(PATH+"LOSS2_1_loss_history_with_noise.txt", "r") as f:
#   for line in f:
#     loss_history.append(float(line.strip()))

net, mean_train_loss, loss_history1 = train_model(train_loader, beta, learning_rate)
# loss_history.extend(loss_history1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:43: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
# Streaming output truncated to the last 5000 lines.
# Training: Batch 816/1000. Loss of 0.5714, cover loss of 0.0188, secret loss of 0.9726
# Training: Batch 817/1000. Loss of 0.5949, cover loss of 0.0245, secret loss of 0.9920
# Training: Batch 818/1000. Loss of 0.5256, cover loss of 0.0212, secret loss of 0.8888
# Training: Batch 819/1000. Loss of 0.5732, cover loss of 0.0205, secret loss of 0.9649
# Training: Batch 820/1000. Loss of 0.4792, cover loss of 0.0197, secret loss of 0.8542
# Training: Batch 821/1000. Loss of 0.5922, cover loss of 0.0222, secret loss of 0.9792
# Training: Batch 822/1000. Loss of 0.6145, cover loss of 0.0177, secret loss of 0.9930
# Training: Batch 823/1000. Loss of 0.6304, cover loss of 0.0195, secret loss of 1.0320
# Training: Batch 824/1000. Loss of 0.5392, cover loss of 0.0225, secret loss of 0.9244
# Training: Batch 825/1000. Loss of 0.4653, cover loss of 0.0216, secret loss of 0.8063
# Training: Batch 826/1000. Loss of 0.5484, cover loss of 0.0209, secret loss of 0.9231
# Training: Batch 827/1000. Loss of 0.6078, cover loss of 0.0214, secret loss of 0.9856
# Training: Batch 828/1000. Loss of 0.5210, cover loss of 0.0239, secret loss of 0.9028
# Training: Batch 829/1000. Loss of 0.6326, cover loss of 0.0241, secret loss of 1.0288
# Training: Batch 830/1000. Loss of 0.5413, cover loss of 0.0274, secret loss of 0.9226
# Training: Batch 831/1000. Loss of 0.6150, cover loss of 0.0302, secret loss of 1.0169
# Training: Batch 832/1000. Loss of 0.6204, cover loss of 0.0288, secret loss of 1.0344
# Training: Batch 833/1000. Loss of 0.5087, cover loss of 0.0235, secret loss of 0.8988
# Training: Batch 834/1000. Loss of 0.6026, cover loss of 0.0267, secret loss of 0.9949
# Training: Batch 835/1000. Loss of 0.5395, cover loss of 0.0316, secret loss of 0.9198
# Training: Batch 836/1000. Loss of 0.5694, cover loss of 0.0276, secret loss of 0.9818
# Training: Batch 837/1000. Loss of 0.6433, cover loss of 0.0293, secret loss of 1.0531
# Training: Batch 838/1000. Loss of 0.5517, cover loss of 0.0283, secret loss of 0.9337
# Training: Batch 839/1000. Loss of 0.5393, cover loss of 0.0397, secret loss of 0.9226
# Training: Batch 840/1000. Loss of 0.5288, cover loss of 0.0287, secret loss of 0.9214
# Training: Batch 841/1000. Loss of 0.5961, cover loss of 0.0352, secret loss of 0.9939
# Training: Batch 842/1000. Loss of 0.6009, cover loss of 0.0322, secret loss of 0.9878
# Training: Batch 843/1000. Loss of 0.5033, cover loss of 0.0379, secret loss of 0.8585
# Training: Batch 844/1000. Loss of 0.5044, cover loss of 0.0333, secret loss of 0.8762
# Training: Batch 845/1000. Loss of 0.5854, cover loss of 0.0280, secret loss of 0.9769
# Training: Batch 846/1000. Loss of 0.5688, cover loss of 0.0250, secret loss of 0.9614
# Training: Batch 847/1000. Loss of 0.6060, cover loss of 0.0253, secret loss of 0.9975
# Training: Batch 848/1000. Loss of 0.6257, cover loss of 0.0342, secret loss of 1.0109
# Training: Batch 849/1000. Loss of 0.5974, cover loss of 0.0254, secret loss of 0.9909
# Training: Batch 850/1000. Loss of 0.5839, cover loss of 0.0434, secret loss of 0.9626
# Training: Batch 851/1000. Loss of 0.7146, cover loss of 0.0241, secret loss of 1.1286
# Training: Batch 852/1000. Loss of 0.6256, cover loss of 0.0411, secret loss of 1.0141
# Training: Batch 853/1000. Loss of 0.4881, cover loss of 0.0261, secret loss of 0.8662
# Training: Batch 854/1000. Loss of 0.6184, cover loss of 0.0431, secret loss of 1.0104
# Training: Batch 855/1000. Loss of 0.5614, cover loss of 0.0271, secret loss of 0.9516
# Training: Batch 856/1000. Loss of 0.5060, cover loss of 0.0237, secret loss of 0.8803
# Training: Batch 857/1000. Loss of 0.5288, cover loss of 0.0265, secret loss of 0.9119
# Training: Batch 858/1000. Loss of 0.5487, cover loss of 0.0251, secret loss of 0.9512
# Training: Batch 859/1000. Loss of 0.5646, cover loss of 0.0249, secret loss of 0.9572
# Training: Batch 860/1000. Loss of 0.5493, cover loss of 0.0245, secret loss of 0.9287
# Training: Batch 861/1000. Loss of 0.5280, cover loss of 0.0264, secret loss of 0.9053
# Training: Batch 862/1000. Loss of 0.5362, cover loss of 0.0258, secret loss of 0.9130
# Training: Batch 863/1000. Loss of 0.5704, cover loss of 0.0246, secret loss of 0.9613
# Training: Batch 864/1000. Loss of 0.6020, cover loss of 0.0243, secret loss of 0.9685
# Training: Batch 865/1000. Loss of 0.5390, cover loss of 0.0261, secret loss of 0.9319
# Training: Batch 866/1000. Loss of 0.6258, cover loss of 0.0282, secret loss of 1.0227
# Training: Batch 867/1000. Loss of 0.5680, cover loss of 0.0282, secret loss of 0.9451
# Training: Batch 868/1000. Loss of 0.5104, cover loss of 0.0356, secret loss of 0.8752
# Training: Batch 869/1000. Loss of 0.6474, cover loss of 0.0258, secret loss of 1.0756
# Training: Batch 870/1000. Loss of 0.5600, cover loss of 0.0294, secret loss of 0.9453
# Training: Batch 871/1000. Loss of 0.6214, cover loss of 0.0290, secret loss of 1.0268
# Training: Batch 872/1000. Loss of 0.5252, cover loss of 0.0193, secret loss of 0.9069
# Training: Batch 873/1000. Loss of 0.6335, cover loss of 0.0228, secret loss of 1.0252
# Training: Batch 874/1000. Loss of 0.5957, cover loss of 0.0293, secret loss of 0.9990
# Training: Batch 875/1000. Loss of 0.5878, cover loss of 0.0325, secret loss of 0.9788
# Training: Batch 876/1000. Loss of 0.5645, cover loss of 0.0261, secret loss of 0.9498
# Training: Batch 877/1000. Loss of 0.5602, cover loss of 0.0385, secret loss of 0.9582
# Training: Batch 878/1000. Loss of 0.4973, cover loss of 0.0290, secret loss of 0.8784
# Training: Batch 879/1000. Loss of 0.6155, cover loss of 0.0268, secret loss of 1.0061
# Training: Batch 880/1000. Loss of 0.5356, cover loss of 0.0327, secret loss of 0.9121
# Training: Batch 881/1000. Loss of 0.5658, cover loss of 0.0355, secret loss of 0.9518
# Training: Batch 882/1000. Loss of 0.5047, cover loss of 0.0305, secret loss of 0.8868
# Training: Batch 883/1000. Loss of 0.6091, cover loss of 0.0292, secret loss of 1.0010
# Training: Batch 884/1000. Loss of 0.6054, cover loss of 0.0291, secret loss of 1.0253
# Training: Batch 885/1000. Loss of 0.5452, cover loss of 0.0337, secret loss of 0.9147
# Training: Batch 886/1000. Loss of 0.5258, cover loss of 0.0258, secret loss of 0.9093
# Training: Batch 887/1000. Loss of 0.5379, cover loss of 0.0314, secret loss of 0.9148
# Training: Batch 888/1000. Loss of 0.5217, cover loss of 0.0265, secret loss of 0.9038
# Training: Batch 889/1000. Loss of 0.5657, cover loss of 0.0274, secret loss of 0.9558
# Training: Batch 890/1000. Loss of 0.6031, cover loss of 0.0287, secret loss of 0.9764
# Training: Batch 891/1000. Loss of 0.6303, cover loss of 0.0218, secret loss of 1.0043
# Training: Batch 892/1000. Loss of 0.5368, cover loss of 0.0282, secret loss of 0.9233
# Training: Batch 893/1000. Loss of 0.5593, cover loss of 0.0215, secret loss of 0.9432
# Training: Batch 894/1000. Loss of 0.6017, cover loss of 0.0262, secret loss of 1.0122
# Training: Batch 895/1000. Loss of 0.6408, cover loss of 0.0251, secret loss of 1.0768
# Training: Batch 896/1000. Loss of 0.5073, cover loss of 0.0208, secret loss of 0.8964
# Training: Batch 897/1000. Loss of 0.5511, cover loss of 0.0287, secret loss of 0.9309
# Training: Batch 898/1000. Loss of 0.5543, cover loss of 0.0206, secret loss of 0.9311
# Training: Batch 899/1000. Loss of 0.6022, cover loss of 0.0231, secret loss of 1.0115
# Training: Batch 900/1000. Loss of 0.4815, cover loss of 0.0234, secret loss of 0.8571
# Training: Batch 901/1000. Loss of 0.5308, cover loss of 0.0230, secret loss of 0.9099
# Training: Batch 902/1000. Loss of 0.6312, cover loss of 0.0254, secret loss of 1.0455
# Training: Batch 903/1000. Loss of 0.5378, cover loss of 0.0216, secret loss of 0.9345
# Training: Batch 904/1000. Loss of 0.4813, cover loss of 0.0266, secret loss of 0.8383
# Training: Batch 905/1000. Loss of 0.6024, cover loss of 0.0228, secret loss of 0.9841
# Training: Batch 906/1000. Loss of 0.5832, cover loss of 0.0239, secret loss of 0.9824
# Training: Batch 907/1000. Loss of 0.4895, cover loss of 0.0328, secret loss of 0.8492
# Training: Batch 908/1000. Loss of 0.5647, cover loss of 0.0259, secret loss of 0.9488
# Training: Batch 909/1000. Loss of 0.4908, cover loss of 0.0233, secret loss of 0.8574
# Training: Batch 910/1000. Loss of 0.5358, cover loss of 0.0288, secret loss of 0.9196
# Training: Batch 911/1000. Loss of 0.6414, cover loss of 0.0283, secret loss of 1.0508
# Training: Batch 912/1000. Loss of 0.5375, cover loss of 0.0338, secret loss of 0.9216
# Training: Batch 913/1000. Loss of 0.5799, cover loss of 0.0283, secret loss of 0.9743
# Training: Batch 914/1000. Loss of 0.6655, cover loss of 0.0331, secret loss of 1.0647
# Training: Batch 915/1000. Loss of 0.5770, cover loss of 0.0271, secret loss of 0.9538
# Training: Batch 916/1000. Loss of 0.5618, cover loss of 0.0272, secret loss of 0.9518
# Training: Batch 917/1000. Loss of 0.5311, cover loss of 0.0255, secret loss of 0.9286
# Training: Batch 918/1000. Loss of 0.6559, cover loss of 0.0249, secret loss of 1.0553
# Training: Batch 919/1000. Loss of 0.6338, cover loss of 0.0359, secret loss of 1.0146
# Training: Batch 920/1000. Loss of 0.4980, cover loss of 0.0288, secret loss of 0.8689
# Training: Batch 921/1000. Loss of 0.5988, cover loss of 0.0252, secret loss of 1.0059
# Training: Batch 922/1000. Loss of 0.5120, cover loss of 0.0304, secret loss of 0.8857
# Training: Batch 923/1000. Loss of 0.5428, cover loss of 0.0261, secret loss of 0.9347
# Training: Batch 924/1000. Loss of 0.6003, cover loss of 0.0271, secret loss of 1.0119
# Training: Batch 925/1000. Loss of 0.5553, cover loss of 0.0323, secret loss of 0.9262
# Training: Batch 926/1000. Loss of 0.5561, cover loss of 0.0318, secret loss of 0.9496
# Training: Batch 927/1000. Loss of 0.5550, cover loss of 0.0252, secret loss of 0.9419
# Training: Batch 928/1000. Loss of 0.5218, cover loss of 0.0270, secret loss of 0.8949
# Training: Batch 929/1000. Loss of 0.6416, cover loss of 0.0268, secret loss of 1.0228
# Training: Batch 930/1000. Loss of 0.5370, cover loss of 0.0281, secret loss of 0.9193
# Training: Batch 931/1000. Loss of 0.5018, cover loss of 0.0303, secret loss of 0.8650
# Training: Batch 932/1000. Loss of 0.5980, cover loss of 0.0238, secret loss of 0.9706
# Training: Batch 933/1000. Loss of 0.5689, cover loss of 0.0394, secret loss of 0.9471
# Training: Batch 934/1000. Loss of 0.6010, cover loss of 0.0241, secret loss of 1.0065
# Training: Batch 935/1000. Loss of 0.5103, cover loss of 0.0231, secret loss of 0.8825
# Training: Batch 936/1000. Loss of 0.5932, cover loss of 0.0242, secret loss of 0.9874
# Training: Batch 937/1000. Loss of 0.6146, cover loss of 0.0236, secret loss of 1.0059
# Training: Batch 938/1000. Loss of 0.6328, cover loss of 0.0229, secret loss of 1.0341
# Training: Batch 939/1000. Loss of 0.5625, cover loss of 0.0186, secret loss of 0.9489
# Training: Batch 940/1000. Loss of 0.5372, cover loss of 0.0259, secret loss of 0.9145
# Training: Batch 941/1000. Loss of 0.4672, cover loss of 0.0212, secret loss of 0.8469
# Training: Batch 942/1000. Loss of 0.5751, cover loss of 0.0230, secret loss of 0.9454
# Training: Batch 943/1000. Loss of 0.5503, cover loss of 0.0254, secret loss of 0.9382
# Training: Batch 944/1000. Loss of 0.6122, cover loss of 0.0280, secret loss of 1.0124
# Training: Batch 945/1000. Loss of 0.5094, cover loss of 0.0235, secret loss of 0.8918
# Training: Batch 946/1000. Loss of 0.5088, cover loss of 0.0317, secret loss of 0.8864
# Training: Batch 947/1000. Loss of 0.5319, cover loss of 0.0356, secret loss of 0.8973
# Training: Batch 948/1000. Loss of 0.5697, cover loss of 0.0253, secret loss of 0.9511
# Training: Batch 949/1000. Loss of 0.5561, cover loss of 0.0328, secret loss of 0.9497
# Training: Batch 950/1000. Loss of 0.6312, cover loss of 0.0273, secret loss of 1.0221
# Training: Batch 951/1000. Loss of 0.5744, cover loss of 0.0343, secret loss of 0.9562
# Training: Batch 952/1000. Loss of 0.5270, cover loss of 0.0300, secret loss of 0.9086
# Training: Batch 953/1000. Loss of 0.5889, cover loss of 0.0311, secret loss of 0.9782
# Training: Batch 954/1000. Loss of 0.5435, cover loss of 0.0281, secret loss of 0.9230
# Training: Batch 955/1000. Loss of 0.5825, cover loss of 0.0272, secret loss of 0.9639
# Training: Batch 956/1000. Loss of 0.6954, cover loss of 0.0333, secret loss of 1.1122
# Training: Batch 957/1000. Loss of 0.6843, cover loss of 0.0266, secret loss of 1.0629
# Training: Batch 958/1000. Loss of 0.5849, cover loss of 0.0369, secret loss of 0.9750
# Training: Batch 959/1000. Loss of 0.5472, cover loss of 0.0243, secret loss of 0.9193
# Training: Batch 960/1000. Loss of 0.5348, cover loss of 0.0304, secret loss of 0.8959
# Training: Batch 961/1000. Loss of 0.5975, cover loss of 0.0288, secret loss of 0.9673
# Training: Batch 962/1000. Loss of 0.5992, cover loss of 0.0277, secret loss of 0.9874
# Training: Batch 963/1000. Loss of 0.5336, cover loss of 0.0229, secret loss of 0.9102
# Training: Batch 964/1000. Loss of 0.6055, cover loss of 0.0259, secret loss of 0.9879
# Training: Batch 965/1000. Loss of 0.6252, cover loss of 0.0248, secret loss of 0.9981
# Training: Batch 966/1000. Loss of 0.4911, cover loss of 0.0241, secret loss of 0.8589
# Training: Batch 967/1000. Loss of 0.6052, cover loss of 0.0235, secret loss of 1.0135
# Training: Batch 968/1000. Loss of 0.4854, cover loss of 0.0203, secret loss of 0.8656
# Training: Batch 969/1000. Loss of 0.5379, cover loss of 0.0180, secret loss of 0.9346
# Training: Batch 970/1000. Loss of 0.5445, cover loss of 0.0247, secret loss of 0.9191
# Training: Batch 971/1000. Loss of 0.5585, cover loss of 0.0226, secret loss of 0.9293
# Training: Batch 972/1000. Loss of 0.5908, cover loss of 0.0249, secret loss of 1.0008
# Training: Batch 973/1000. Loss of 0.5142, cover loss of 0.0204, secret loss of 0.8987
# Training: Batch 974/1000. Loss of 0.5994, cover loss of 0.0191, secret loss of 1.0024
# Training: Batch 975/1000. Loss of 0.5387, cover loss of 0.0170, secret loss of 0.9216
# Training: Batch 976/1000. Loss of 0.5780, cover loss of 0.0194, secret loss of 0.9829
# Training: Batch 977/1000. Loss of 0.7175, cover loss of 0.0225, secret loss of 1.1060
# Training: Batch 978/1000. Loss of 0.5952, cover loss of 0.0237, secret loss of 0.9963
# Training: Batch 979/1000. Loss of 0.6184, cover loss of 0.0241, secret loss of 0.9943
# Training: Batch 980/1000. Loss of 0.4560, cover loss of 0.0260, secret loss of 0.8092
# Training: Batch 981/1000. Loss of 0.4786, cover loss of 0.0226, secret loss of 0.8422
# Training: Batch 982/1000. Loss of 0.5781, cover loss of 0.0218, secret loss of 0.9694
# Training: Batch 983/1000. Loss of 0.5670, cover loss of 0.0210, secret loss of 0.9414
# Training: Batch 984/1000. Loss of 0.7067, cover loss of 0.0239, secret loss of 1.1230
# Training: Batch 985/1000. Loss of 0.5444, cover loss of 0.0224, secret loss of 0.9267
# Training: Batch 986/1000. Loss of 0.6111, cover loss of 0.0207, secret loss of 1.0040
# Training: Batch 987/1000. Loss of 0.5748, cover loss of 0.0213, secret loss of 0.9671
# Training: Batch 988/1000. Loss of 0.6096, cover loss of 0.0183, secret loss of 0.9948
# Training: Batch 989/1000. Loss of 0.5751, cover loss of 0.0174, secret loss of 0.9701
# Training: Batch 990/1000. Loss of 0.5507, cover loss of 0.0232, secret loss of 0.9390
# Training: Batch 991/1000. Loss of 0.5612, cover loss of 0.0176, secret loss of 0.9378
# Training: Batch 992/1000. Loss of 0.5420, cover loss of 0.0172, secret loss of 0.9318
# Training: Batch 993/1000. Loss of 0.5593, cover loss of 0.0207, secret loss of 0.9431
# Training: Batch 994/1000. Loss of 0.6290, cover loss of 0.0258, secret loss of 1.0242
# Training: Batch 995/1000. Loss of 0.5587, cover loss of 0.0320, secret loss of 0.9440
# Training: Batch 996/1000. Loss of 0.6101, cover loss of 0.0231, secret loss of 0.9910
# Training: Batch 997/1000. Loss of 0.6256, cover loss of 0.0236, secret loss of 1.0385
# Training: Batch 998/1000. Loss of 0.4997, cover loss of 0.0239, secret loss of 0.8546
# Training: Batch 999/1000. Loss of 0.5050, cover loss of 0.0239, secret loss of 0.8689
# Training: Batch 1000/1000. Loss of 0.5713, cover loss of 0.0245, secret loss of 0.9677
# Epoch [5/23], Average_loss: 0.5698
# Training: Batch 1/1000. Loss of 0.5683, cover loss of 0.0325, secret loss of 0.9413
# Training: Batch 2/1000. Loss of 0.5538, cover loss of 0.0217, secret loss of 0.9352
# Training: Batch 3/1000. Loss of 0.6068, cover loss of 0.0264, secret loss of 0.9970
# Training: Batch 4/1000. Loss of 0.5857, cover loss of 0.0284, secret loss of 0.9790
# Training: Batch 5/1000. Loss of 0.5987, cover loss of 0.0213, secret loss of 1.0091
# Training: Batch 6/1000. Loss of 0.5316, cover loss of 0.0254, secret loss of 0.9440
# Training: Batch 7/1000. Loss of 0.6834, cover loss of 0.0317, secret loss of 1.0735
# Training: Batch 8/1000. Loss of 0.6264, cover loss of 0.0215, secret loss of 1.0327
# Training: Batch 9/1000. Loss of 0.5940, cover loss of 0.0238, secret loss of 0.9971
# Training: Batch 10/1000. Loss of 0.6159, cover loss of 0.0275, secret loss of 1.0037
# Training: Batch 11/1000. Loss of 0.6397, cover loss of 0.0266, secret loss of 1.0231
# Training: Batch 12/1000. Loss of 0.5332, cover loss of 0.0353, secret loss of 0.8969
# Training: Batch 13/1000. Loss of 0.5982, cover loss of 0.0295, secret loss of 0.9892
# Training: Batch 14/1000. Loss of 0.4768, cover loss of 0.0305, secret loss of 0.8480
# Training: Batch 15/1000. Loss of 0.5647, cover loss of 0.0291, secret loss of 0.9751
# Training: Batch 16/1000. Loss of 0.5826, cover loss of 0.0256, secret loss of 0.9671
# Training: Batch 17/1000. Loss of 0.6487, cover loss of 0.0332, secret loss of 1.0373
# Training: Batch 18/1000. Loss of 0.5808, cover loss of 0.0279, secret loss of 0.9683
# Training: Batch 19/1000. Loss of 0.6089, cover loss of 0.0433, secret loss of 0.9909
# Training: Batch 20/1000. Loss of 0.6072, cover loss of 0.0347, secret loss of 0.9963
# Training: Batch 21/1000. Loss of 0.5619, cover loss of 0.0381, secret loss of 0.9329
# Training: Batch 22/1000. Loss of 0.6154, cover loss of 0.0290, secret loss of 1.0142
# Training: Batch 23/1000. Loss of 0.6147, cover loss of 0.0450, secret loss of 1.0032
# Training: Batch 24/1000. Loss of 0.6389, cover loss of 0.0371, secret loss of 1.0039
# Training: Batch 25/1000. Loss of 0.6012, cover loss of 0.0415, secret loss of 1.0014
# Training: Batch 26/1000. Loss of 0.5117, cover loss of 0.0408, secret loss of 0.8608
# Training: Batch 27/1000. Loss of 0.5281, cover loss of 0.0432, secret loss of 0.9088
# Training: Batch 28/1000. Loss of 0.5786, cover loss of 0.0569, secret loss of 0.9434
# Training: Batch 29/1000. Loss of 0.4952, cover loss of 0.0371, secret loss of 0.8519
# Training: Batch 30/1000. Loss of 0.6978, cover loss of 0.0438, secret loss of 1.0840
# Training: Batch 31/1000. Loss of 0.4584, cover loss of 0.0382, secret loss of 0.8152
# Training: Batch 32/1000. Loss of 0.5787, cover loss of 0.0492, secret loss of 0.9729
# Training: Batch 33/1000. Loss of 0.5648, cover loss of 0.0427, secret loss of 0.9589
# Training: Batch 34/1000. Loss of 0.5348, cover loss of 0.0430, secret loss of 0.9196
# Training: Batch 35/1000. Loss of 0.5530, cover loss of 0.0424, secret loss of 0.9287
# Training: Batch 36/1000. Loss of 0.6389, cover loss of 0.0304, secret loss of 1.0344
# Training: Batch 37/1000. Loss of 0.5038, cover loss of 0.0359, secret loss of 0.8760
# Training: Batch 38/1000. Loss of 0.5841, cover loss of 0.0305, secret loss of 0.9822
# Training: Batch 39/1000. Loss of 0.7210, cover loss of 0.0271, secret loss of 1.1323
# Training: Batch 40/1000. Loss of 0.5596, cover loss of 0.0400, secret loss of 0.9262
# Training: Batch 41/1000. Loss of 0.6202, cover loss of 0.0265, secret loss of 1.0092
# Training: Batch 42/1000. Loss of 0.4792, cover loss of 0.0420, secret loss of 0.8393
# Training: Batch 43/1000. Loss of 0.4697, cover loss of 0.0313, secret loss of 0.8297
# Training: Batch 44/1000. Loss of 0.5639, cover loss of 0.0336, secret loss of 0.9545
# Training: Batch 45/1000. Loss of 0.6180, cover loss of 0.0368, secret loss of 0.9932
# Training: Batch 46/1000. Loss of 0.6507, cover loss of 0.0356, secret loss of 1.0480
# Training: Batch 47/1000. Loss of 0.5255, cover loss of 0.0274, secret loss of 0.9066
# Training: Batch 48/1000. Loss of 0.5688, cover loss of 0.0378, secret loss of 0.9552
# Training: Batch 49/1000. Loss of 0.5248, cover loss of 0.0347, secret loss of 0.8946
# Training: Batch 50/1000. Loss of 0.5508, cover loss of 0.0238, secret loss of 0.9381
# Training: Batch 51/1000. Loss of 0.5392, cover loss of 0.0341, secret loss of 0.9221
# Training: Batch 52/1000. Loss of 0.5200, cover loss of 0.0237, secret loss of 0.9091
# Training: Batch 53/1000. Loss of 0.5552, cover loss of 0.0270, secret loss of 0.9378
# Training: Batch 54/1000. Loss of 0.6704, cover loss of 0.0283, secret loss of 1.0643
# Training: Batch 55/1000. Loss of 0.5016, cover loss of 0.0240, secret loss of 0.8747
# Training: Batch 56/1000. Loss of 0.5286, cover loss of 0.0275, secret loss of 0.9102
# Training: Batch 57/1000. Loss of 0.6180, cover loss of 0.0243, secret loss of 1.0372
# Training: Batch 58/1000. Loss of 0.4731, cover loss of 0.0253, secret loss of 0.8445
# Training: Batch 59/1000. Loss of 0.5166, cover loss of 0.0236, secret loss of 0.8871
# Training: Batch 60/1000. Loss of 0.5696, cover loss of 0.0220, secret loss of 0.9634
# Training: Batch 61/1000. Loss of 0.4749, cover loss of 0.0274, secret loss of 0.8380
# Training: Batch 62/1000. Loss of 0.5307, cover loss of 0.0266, secret loss of 0.8865
# Training: Batch 63/1000. Loss of 0.5805, cover loss of 0.0269, secret loss of 0.9607
# Training: Batch 64/1000. Loss of 0.5222, cover loss of 0.0309, secret loss of 0.8906
# Training: Batch 65/1000. Loss of 0.5818, cover loss of 0.0304, secret loss of 0.9496
# Training: Batch 66/1000. Loss of 0.7607, cover loss of 0.0356, secret loss of 1.1660
# Training: Batch 67/1000. Loss of 0.5193, cover loss of 0.0370, secret loss of 0.8979
# Training: Batch 68/1000. Loss of 0.6852, cover loss of 0.0362, secret loss of 1.0653
# Training: Batch 69/1000. Loss of 0.6660, cover loss of 0.0385, secret loss of 1.0667
# Training: Batch 70/1000. Loss of 0.5470, cover loss of 0.0318, secret loss of 0.9245
# Training: Batch 71/1000. Loss of 0.5077, cover loss of 0.0383, secret loss of 0.8906
# Training: Batch 72/1000. Loss of 0.6200, cover loss of 0.0324, secret loss of 1.0252
# Training: Batch 73/1000. Loss of 0.5417, cover loss of 0.0323, secret loss of 0.9058
# Training: Batch 74/1000. Loss of 0.5460, cover loss of 0.0244, secret loss of 0.9666
# Training: Batch 75/1000. Loss of 0.5728, cover loss of 0.0299, secret loss of 0.9747
# Training: Batch 76/1000. Loss of 0.5361, cover loss of 0.0245, secret loss of 0.9264
# Training: Batch 77/1000. Loss of 0.5840, cover loss of 0.0274, secret loss of 0.9747
# Training: Batch 78/1000. Loss of 0.5306, cover loss of 0.0259, secret loss of 0.9176
# Training: Batch 79/1000. Loss of 0.5630, cover loss of 0.0346, secret loss of 0.9472
# Training: Batch 80/1000. Loss of 0.5667, cover loss of 0.0234, secret loss of 0.9482
# Training: Batch 81/1000. Loss of 0.4774, cover loss of 0.0340, secret loss of 0.8534
# Training: Batch 82/1000. Loss of 0.5676, cover loss of 0.0353, secret loss of 0.9364
# Training: Batch 83/1000. Loss of 0.5212, cover loss of 0.0309, secret loss of 0.9020
# Training: Batch 84/1000. Loss of 0.5336, cover loss of 0.0347, secret loss of 0.8987
# Training: Batch 85/1000. Loss of 0.5382, cover loss of 0.0354, secret loss of 0.9243
# Training: Batch 86/1000. Loss of 0.5789, cover loss of 0.0395, secret loss of 0.9637
# Training: Batch 87/1000. Loss of 0.6339, cover loss of 0.0396, secret loss of 1.0371
# Training: Batch 88/1000. Loss of 0.5069, cover loss of 0.0276, secret loss of 0.8742
# Training: Batch 89/1000. Loss of 0.5583, cover loss of 0.0436, secret loss of 0.9390
# Training: Batch 90/1000. Loss of 0.5122, cover loss of 0.0334, secret loss of 0.8894
# Training: Batch 91/1000. Loss of 0.5110, cover loss of 0.0395, secret loss of 0.8892
# Training: Batch 92/1000. Loss of 0.5590, cover loss of 0.0474, secret loss of 0.9356
# Training: Batch 93/1000. Loss of 0.6172, cover loss of 0.0243, secret loss of 1.0040
# Training: Batch 94/1000. Loss of 0.5954, cover loss of 0.0543, secret loss of 0.9924
# Training: Batch 95/1000. Loss of 0.5461, cover loss of 0.0574, secret loss of 0.9254
# Training: Batch 96/1000. Loss of 0.4996, cover loss of 0.0221, secret loss of 0.8730
# Training: Batch 97/1000. Loss of 0.6723, cover loss of 0.0372, secret loss of 1.0821
# Training: Batch 98/1000. Loss of 0.5076, cover loss of 0.0407, secret loss of 0.8844
# Training: Batch 99/1000. Loss of 0.5631, cover loss of 0.0319, secret loss of 0.9588
# Training: Batch 100/1000. Loss of 0.6111, cover loss of 0.0379, secret loss of 1.0027
# Training: Batch 101/1000. Loss of 0.5129, cover loss of 0.0213, secret loss of 0.8818
# Training: Batch 102/1000. Loss of 0.5846, cover loss of 0.0367, secret loss of 0.9710
# Training: Batch 103/1000. Loss of 0.5636, cover loss of 0.0315, secret loss of 0.9286
# Training: Batch 104/1000. Loss of 0.6416, cover loss of 0.0307, secret loss of 1.0455
# Training: Batch 105/1000. Loss of 0.5598, cover loss of 0.0350, secret loss of 0.9402
# Training: Batch 106/1000. Loss of 0.5153, cover loss of 0.0272, secret loss of 0.9068
# Training: Batch 107/1000. Loss of 0.6274, cover loss of 0.0340, secret loss of 1.0295
# Training: Batch 108/1000. Loss of 0.6628, cover loss of 0.0334, secret loss of 1.0611
# Training: Batch 109/1000. Loss of 0.5928, cover loss of 0.0352, secret loss of 0.9822
# Training: Batch 110/1000. Loss of 0.5147, cover loss of 0.0288, secret loss of 0.8924
# Training: Batch 111/1000. Loss of 0.4838, cover loss of 0.0386, secret loss of 0.8358
# Training: Batch 112/1000. Loss of 0.5967, cover loss of 0.0361, secret loss of 0.9866
# Training: Batch 113/1000. Loss of 0.6275, cover loss of 0.0326, secret loss of 1.0407
# Training: Batch 114/1000. Loss of 0.4990, cover loss of 0.0345, secret loss of 0.8621
# Training: Batch 115/1000. Loss of 0.5806, cover loss of 0.0233, secret loss of 0.9507
# Training: Batch 116/1000. Loss of 0.4812, cover loss of 0.0339, secret loss of 0.8567
# Training: Batch 117/1000. Loss of 0.5351, cover loss of 0.0316, secret loss of 0.9166
# Training: Batch 118/1000. Loss of 0.6946, cover loss of 0.0298, secret loss of 1.1199
# Training: Batch 119/1000. Loss of 0.5367, cover loss of 0.0397, secret loss of 0.9185
# Training: Batch 120/1000. Loss of 0.5134, cover loss of 0.0351, secret loss of 0.8733
# Training: Batch 121/1000. Loss of 0.5643, cover loss of 0.0312, secret loss of 0.9409
# Training: Batch 122/1000. Loss of 0.5101, cover loss of 0.0311, secret loss of 0.8789
# Training: Batch 123/1000. Loss of 0.5332, cover loss of 0.0237, secret loss of 0.9179
# Training: Batch 124/1000. Loss of 0.4342, cover loss of 0.0313, secret loss of 0.7888
# Training: Batch 125/1000. Loss of 0.5753, cover loss of 0.0230, secret loss of 0.9672
# Training: Batch 126/1000. Loss of 0.7198, cover loss of 0.0282, secret loss of 1.1116
# Training: Batch 127/1000. Loss of 0.5117, cover loss of 0.0254, secret loss of 0.8898
# Training: Batch 128/1000. Loss of 0.5238, cover loss of 0.0230, secret loss of 0.8989
# Training: Batch 129/1000. Loss of 0.6500, cover loss of 0.0388, secret loss of 1.0465
# Training: Batch 130/1000. Loss of 0.6276, cover loss of 0.0319, secret loss of 1.0377
# Training: Batch 131/1000. Loss of 0.4971, cover loss of 0.0240, secret loss of 0.8786
# Training: Batch 132/1000. Loss of 0.4773, cover loss of 0.0307, secret loss of 0.8384
# Training: Batch 133/1000. Loss of 0.5931, cover loss of 0.0279, secret loss of 0.9606
# Training: Batch 134/1000. Loss of 0.6132, cover loss of 0.0293, secret loss of 0.9695
# Training: Batch 135/1000. Loss of 0.6031, cover loss of 0.0260, secret loss of 0.9893
# Training: Batch 136/1000. Loss of 0.5385, cover loss of 0.0403, secret loss of 0.9452
# Training: Batch 137/1000. Loss of 0.6104, cover loss of 0.0257, secret loss of 1.0045
# Training: Batch 138/1000. Loss of 0.5497, cover loss of 0.0381, secret loss of 0.9261
# Training: Batch 139/1000. Loss of 0.6171, cover loss of 0.0303, secret loss of 1.0174
# Training: Batch 140/1000. Loss of 0.5834, cover loss of 0.0335, secret loss of 0.9929
# Training: Batch 141/1000. Loss of 0.6127, cover loss of 0.0358, secret loss of 1.0027
# Training: Batch 142/1000. Loss of 0.5958, cover loss of 0.0332, secret loss of 0.9736
# Training: Batch 143/1000. Loss of 0.5612, cover loss of 0.0357, secret loss of 0.9320
# Training: Batch 144/1000. Loss of 0.5398, cover loss of 0.0348, secret loss of 0.9138
# Training: Batch 145/1000. Loss of 0.5253, cover loss of 0.0328, secret loss of 0.9000
# Training: Batch 146/1000. Loss of 0.5795, cover loss of 0.0247, secret loss of 0.9671
# Training: Batch 147/1000. Loss of 0.5878, cover loss of 0.0327, secret loss of 0.9795
# Training: Batch 148/1000. Loss of 0.5920, cover loss of 0.0312, secret loss of 0.9901
# Training: Batch 149/1000. Loss of 0.5810, cover loss of 0.0242, secret loss of 0.9601
# Training: Batch 150/1000. Loss of 0.5537, cover loss of 0.0239, secret loss of 0.9320
# Training: Batch 151/1000. Loss of 0.5274, cover loss of 0.0254, secret loss of 0.9183
# Training: Batch 152/1000. Loss of 0.5509, cover loss of 0.0254, secret loss of 0.9329
# Training: Batch 153/1000. Loss of 0.5331, cover loss of 0.0224, secret loss of 0.9069
# Training: Batch 154/1000. Loss of 0.5453, cover loss of 0.0189, secret loss of 0.9270
# Training: Batch 155/1000. Loss of 0.6313, cover loss of 0.0224, secret loss of 1.0305
# Training: Batch 156/1000. Loss of 0.5502, cover loss of 0.0184, secret loss of 0.9307
# Training: Batch 157/1000. Loss of 0.5456, cover loss of 0.0206, secret loss of 0.9409
# Training: Batch 158/1000. Loss of 0.6339, cover loss of 0.0246, secret loss of 1.0772
# Training: Batch 159/1000. Loss of 0.6642, cover loss of 0.0233, secret loss of 1.0712
# Training: Batch 160/1000. Loss of 0.5593, cover loss of 0.0230, secret loss of 0.9574
# Training: Batch 161/1000. Loss of 0.5984, cover loss of 0.0231, secret loss of 0.9827
# Training: Batch 162/1000. Loss of 0.6426, cover loss of 0.0268, secret loss of 1.0352
# Training: Batch 163/1000. Loss of 0.5960, cover loss of 0.0205, secret loss of 0.9913
# Training: Batch 164/1000. Loss of 0.5531, cover loss of 0.0347, secret loss of 0.9359
# Training: Batch 165/1000. Loss of 0.5689, cover loss of 0.0242, secret loss of 0.9644
# Training: Batch 166/1000. Loss of 0.5489, cover loss of 0.0235, secret loss of 0.9349
# Training: Batch 167/1000. Loss of 0.5746, cover loss of 0.0319, secret loss of 0.9464
# Training: Batch 168/1000. Loss of 0.4862, cover loss of 0.0224, secret loss of 0.8614
# Training: Batch 169/1000. Loss of 0.6251, cover loss of 0.0342, secret loss of 1.0153
# Training: Batch 170/1000. Loss of 0.6313, cover loss of 0.0317, secret loss of 1.0143
# Training: Batch 171/1000. Loss of 0.6036, cover loss of 0.0287, secret loss of 1.0009
# Training: Batch 172/1000. Loss of 0.6510, cover loss of 0.0260, secret loss of 1.0569
# Training: Batch 173/1000. Loss of 0.6263, cover loss of 0.0246, secret loss of 1.0194
# Training: Batch 174/1000. Loss of 0.5182, cover loss of 0.0339, secret loss of 0.8832
# Training: Batch 175/1000. Loss of 0.5514, cover loss of 0.0222, secret loss of 0.9377
# Training: Batch 176/1000. Loss of 0.5006, cover loss of 0.0209, secret loss of 0.8617
# Training: Batch 177/1000. Loss of 0.7010, cover loss of 0.0256, secret loss of 1.1215
# Training: Batch 178/1000. Loss of 0.4745, cover loss of 0.0181, secret loss of 0.8360
# Training: Batch 179/1000. Loss of 0.5764, cover loss of 0.0274, secret loss of 0.9829
# Training: Batch 180/1000. Loss of 0.6251, cover loss of 0.0240, secret loss of 1.0244
# Training: Batch 181/1000. Loss of 0.5705, cover loss of 0.0227, secret loss of 0.9434
# Training: Batch 182/1000. Loss of 0.5593, cover loss of 0.0208, secret loss of 0.9357
# Training: Batch 183/1000. Loss of 0.5786, cover loss of 0.0299, secret loss of 0.9562
# Training: Batch 184/1000. Loss of 0.6449, cover loss of 0.0225, secret loss of 1.0542
# Training: Batch 185/1000. Loss of 0.5758, cover loss of 0.0308, secret loss of 0.9608
# Training: Batch 186/1000. Loss of 0.6734, cover loss of 0.0236, secret loss of 1.0704
# Training: Batch 187/1000. Loss of 0.5476, cover loss of 0.0259, secret loss of 0.9350
# Training: Batch 188/1000. Loss of 0.5159, cover loss of 0.0222, secret loss of 0.9066
# Training: Batch 189/1000. Loss of 0.5001, cover loss of 0.0262, secret loss of 0.8656
# Training: Batch 190/1000. Loss of 0.5345, cover loss of 0.0233, secret loss of 0.9284
# Training: Batch 191/1000. Loss of 0.5162, cover loss of 0.0337, secret loss of 0.8972
# Training: Batch 192/1000. Loss of 0.6141, cover loss of 0.0289, secret loss of 1.0038
# Training: Batch 193/1000. Loss of 0.5064, cover loss of 0.0246, secret loss of 0.8722
# Training: Batch 194/1000. Loss of 0.6742, cover loss of 0.0293, secret loss of 1.0654
# Training: Batch 195/1000. Loss of 0.6481, cover loss of 0.0328, secret loss of 1.0487
# Training: Batch 196/1000. Loss of 0.7385, cover loss of 0.0312, secret loss of 1.1451
# Training: Batch 197/1000. Loss of 0.6113, cover loss of 0.0226, secret loss of 1.0112
# Training: Batch 198/1000. Loss of 0.6127, cover loss of 0.0323, secret loss of 0.9919
# Training: Batch 199/1000. Loss of 0.5961, cover loss of 0.0217, secret loss of 0.9792
# Training: Batch 200/1000. Loss of 0.5939, cover loss of 0.0318, secret loss of 0.9806
# Training: Batch 201/1000. Loss of 0.4512, cover loss of 0.0302, secret loss of 0.8150
# Training: Batch 202/1000. Loss of 0.5701, cover loss of 0.0295, secret loss of 0.9489
# Training: Batch 203/1000. Loss of 0.5519, cover loss of 0.0227, secret loss of 0.9261
# Training: Batch 204/1000. Loss of 0.6007, cover loss of 0.0283, secret loss of 1.0260
# Training: Batch 205/1000. Loss of 0.6589, cover loss of 0.0231, secret loss of 1.0555
# Training: Batch 206/1000. Loss of 0.5046, cover loss of 0.0229, secret loss of 0.8853
# Training: Batch 207/1000. Loss of 0.5448, cover loss of 0.0222, secret loss of 0.9337
# Training: Batch 208/1000. Loss of 0.5798, cover loss of 0.0307, secret loss of 0.9437
# Training: Batch 209/1000. Loss of 0.6297, cover loss of 0.0285, secret loss of 1.0192
# Training: Batch 210/1000. Loss of 0.6007, cover loss of 0.0314, secret loss of 1.0014
# Training: Batch 211/1000. Loss of 0.7197, cover loss of 0.0211, secret loss of 1.1096
# Training: Batch 212/1000. Loss of 0.5538, cover loss of 0.0297, secret loss of 0.9506
# Training: Batch 213/1000. Loss of 0.5053, cover loss of 0.0271, secret loss of 0.8933
# Training: Batch 214/1000. Loss of 0.6529, cover loss of 0.0309, secret loss of 1.0452
# Training: Batch 215/1000. Loss of 0.4997, cover loss of 0.0242, secret loss of 0.8726
# Training: Batch 216/1000. Loss of 0.5755, cover loss of 0.0302, secret loss of 0.9550
# Training: Batch 217/1000. Loss of 0.5680, cover loss of 0.0222, secret loss of 0.9650
# Training: Batch 218/1000. Loss of 0.5117, cover loss of 0.0220, secret loss of 0.8806
# Training: Batch 219/1000. Loss of 0.5943, cover loss of 0.0307, secret loss of 0.9815
# Training: Batch 220/1000. Loss of 0.4849, cover loss of 0.0278, secret loss of 0.8639
# Training: Batch 221/1000. Loss of 0.5393, cover loss of 0.0219, secret loss of 0.9044
# Training: Batch 222/1000. Loss of 0.6018, cover loss of 0.0273, secret loss of 0.9991
# Training: Batch 223/1000. Loss of 0.5967, cover loss of 0.0248, secret loss of 0.9970
# Training: Batch 224/1000. Loss of 0.6150, cover loss of 0.0231, secret loss of 1.0273
# Training: Batch 225/1000. Loss of 0.4992, cover loss of 0.0229, secret loss of 0.8874
# Training: Batch 226/1000. Loss of 0.5377, cover loss of 0.0326, secret loss of 0.9227
# Training: Batch 227/1000. Loss of 0.6004, cover loss of 0.0230, secret loss of 0.9752
# Training: Batch 228/1000. Loss of 0.5188, cover loss of 0.0252, secret loss of 0.8947
# Training: Batch 229/1000. Loss of 0.5846, cover loss of 0.0217, secret loss of 0.9745
# Training: Batch 230/1000. Loss of 0.6718, cover loss of 0.0202, secret loss of 1.0594
# Training: Batch 231/1000. Loss of 0.6049, cover loss of 0.0289, secret loss of 1.0146
# Training: Batch 232/1000. Loss of 0.6694, cover loss of 0.0168, secret loss of 1.0680
# Training: Batch 233/1000. Loss of 0.5813, cover loss of 0.0286, secret loss of 0.9851
# Training: Batch 234/1000. Loss of 0.5692, cover loss of 0.0218, secret loss of 0.9504
# Training: Batch 235/1000. Loss of 0.5830, cover loss of 0.0220, secret loss of 0.9597
# Training: Batch 236/1000. Loss of 0.5569, cover loss of 0.0226, secret loss of 0.9673
# Training: Batch 237/1000. Loss of 0.6575, cover loss of 0.0293, secret loss of 1.0644
# Training: Batch 238/1000. Loss of 0.4982, cover loss of 0.0239, secret loss of 0.8736
# Training: Batch 239/1000. Loss of 0.6340, cover loss of 0.0329, secret loss of 1.0354
# Training: Batch 240/1000. Loss of 0.4303, cover loss of 0.0193, secret loss of 0.7725
# Training: Batch 241/1000. Loss of 0.6504, cover loss of 0.0316, secret loss of 1.0260
# Training: Batch 242/1000. Loss of 0.5724, cover loss of 0.0218, secret loss of 0.9617
# Training: Batch 243/1000. Loss of 0.5729, cover loss of 0.0285, secret loss of 0.9611
# Training: Batch 244/1000. Loss of 0.5737, cover loss of 0.0249, secret loss of 0.9618
# Training: Batch 245/1000. Loss of 0.5377, cover loss of 0.0278, secret loss of 0.9235
# Training: Batch 246/1000. Loss of 0.4808, cover loss of 0.0212, secret loss of 0.8436
# Training: Batch 247/1000. Loss of 0.5175, cover loss of 0.0264, secret loss of 0.8957
# Training: Batch 248/1000. Loss of 0.6340, cover loss of 0.0255, secret loss of 1.0415
# Training: Batch 249/1000. Loss of 0.6109, cover loss of 0.0292, secret loss of 1.0059
# Training: Batch 250/1000. Loss of 0.6356, cover loss of 0.0292, secret loss of 1.0146
# Training: Batch 251/1000. Loss of 0.5870, cover loss of 0.0276, secret loss of 0.9601
# Training: Batch 252/1000. Loss of 0.5278, cover loss of 0.0261, secret loss of 0.9056
# Training: Batch 253/1000. Loss of 0.6298, cover loss of 0.0235, secret loss of 1.0269
# Training: Batch 254/1000. Loss of 0.5242, cover loss of 0.0240, secret loss of 0.9194
# Training: Batch 255/1000. Loss of 0.4799, cover loss of 0.0248, secret loss of 0.8460
# Training: Batch 256/1000. Loss of 0.5998, cover loss of 0.0306, secret loss of 1.0178
# Training: Batch 257/1000. Loss of 0.6358, cover loss of 0.0227, secret loss of 1.0290
# Training: Batch 258/1000. Loss of 0.6689, cover loss of 0.0293, secret loss of 1.0751
# Training: Batch 259/1000. Loss of 0.5247, cover loss of 0.0258, secret loss of 0.8849
# Training: Batch 260/1000. Loss of 0.5303, cover loss of 0.0307, secret loss of 0.9052
# Training: Batch 261/1000. Loss of 0.5543, cover loss of 0.0341, secret loss of 0.9427
# Training: Batch 262/1000. Loss of 0.5038, cover loss of 0.0273, secret loss of 0.8843
# Training: Batch 263/1000. Loss of 0.5663, cover loss of 0.0325, secret loss of 0.9547
# Training: Batch 264/1000. Loss of 0.5082, cover loss of 0.0234, secret loss of 0.8710
# Training: Batch 265/1000. Loss of 0.6295, cover loss of 0.0288, secret loss of 1.0250
# Training: Batch 266/1000. Loss of 0.5058, cover loss of 0.0280, secret loss of 0.8753
# Training: Batch 267/1000. Loss of 0.6019, cover loss of 0.0325, secret loss of 0.9827
# Training: Batch 268/1000. Loss of 0.5620, cover loss of 0.0246, secret loss of 0.9481
# Training: Batch 269/1000. Loss of 0.6142, cover loss of 0.0393, secret loss of 0.9926
# Training: Batch 270/1000. Loss of 0.5500, cover loss of 0.0256, secret loss of 0.9382
# Training: Batch 271/1000. Loss of 0.6078, cover loss of 0.0299, secret loss of 1.0025
# Training: Batch 272/1000. Loss of 0.5160, cover loss of 0.0270, secret loss of 0.9024
# Training: Batch 273/1000. Loss of 0.5916, cover loss of 0.0307, secret loss of 0.9752
# Training: Batch 274/1000. Loss of 0.6394, cover loss of 0.0338, secret loss of 1.0499
# Training: Batch 275/1000. Loss of 0.4314, cover loss of 0.0275, secret loss of 0.7938
# Training: Batch 276/1000. Loss of 0.5621, cover loss of 0.0294, secret loss of 0.9555
# Training: Batch 277/1000. Loss of 0.4812, cover loss of 0.0282, secret loss of 0.8387
# Training: Batch 278/1000. Loss of 0.6259, cover loss of 0.0305, secret loss of 1.0258
# Training: Batch 279/1000. Loss of 0.5533, cover loss of 0.0245, secret loss of 0.9371
# Training: Batch 280/1000. Loss of 0.6089, cover loss of 0.0288, secret loss of 1.0099
# Training: Batch 281/1000. Loss of 0.5460, cover loss of 0.0332, secret loss of 0.9307
# Training: Batch 282/1000. Loss of 0.6712, cover loss of 0.0248, secret loss of 1.0931
# Training: Batch 283/1000. Loss of 0.5771, cover loss of 0.0259, secret loss of 0.9401
# Training: Batch 284/1000. Loss of 0.7703, cover loss of 0.0306, secret loss of 1.1944
# Training: Batch 285/1000. Loss of 0.6112, cover loss of 0.0263, secret loss of 0.9989
# Training: Batch 286/1000. Loss of 0.5033, cover loss of 0.0220, secret loss of 0.8727
# Training: Batch 287/1000. Loss of 0.5290, cover loss of 0.0258, secret loss of 0.9112
# Training: Batch 288/1000. Loss of 0.6131, cover loss of 0.0238, secret loss of 0.9800
# Training: Batch 289/1000. Loss of 0.6853, cover loss of 0.0176, secret loss of 1.0678
# Training: Batch 290/1000. Loss of 0.5057, cover loss of 0.0222, secret loss of 0.8680
# Training: Batch 291/1000. Loss of 0.5264, cover loss of 0.0221, secret loss of 0.9076
# Training: Batch 292/1000. Loss of 0.4920, cover loss of 0.0260, secret loss of 0.8627
# Training: Batch 293/1000. Loss of 0.5446, cover loss of 0.0196, secret loss of 0.9407
# Training: Batch 294/1000. Loss of 0.6176, cover loss of 0.0244, secret loss of 1.0084
# Training: Batch 295/1000. Loss of 0.5249, cover loss of 0.0228, secret loss of 0.9095
# Training: Batch 296/1000. Loss of 0.5879, cover loss of 0.0186, secret loss of 0.9870
# Training: Batch 297/1000. Loss of 0.5507, cover loss of 0.0224, secret loss of 0.9383
# Training: Batch 298/1000. Loss of 0.6284, cover loss of 0.0220, secret loss of 1.0316
# Training: Batch 299/1000. Loss of 0.6627, cover loss of 0.0228, secret loss of 1.0652
# Training: Batch 300/1000. Loss of 0.6146, cover loss of 0.0274, secret loss of 1.0015
# Training: Batch 301/1000. Loss of 0.5022, cover loss of 0.0312, secret loss of 0.8704
# Training: Batch 302/1000. Loss of 0.5703, cover loss of 0.0204, secret loss of 0.9544
# Training: Batch 303/1000. Loss of 0.6719, cover loss of 0.0287, secret loss of 1.0756
# Training: Batch 304/1000. Loss of 0.5658, cover loss of 0.0209, secret loss of 0.9350
# Training: Batch 305/1000. Loss of 0.4878, cover loss of 0.0339, secret loss of 0.8383
# Training: Batch 306/1000. Loss of 0.5327, cover loss of 0.0202, secret loss of 0.9336
# Training: Batch 307/1000. Loss of 0.6248, cover loss of 0.0209, secret loss of 1.0178
# Training: Batch 308/1000. Loss of 0.6505, cover loss of 0.0260, secret loss of 1.0514
# Training: Batch 309/1000. Loss of 0.5902, cover loss of 0.0197, secret loss of 0.9865
# Training: Batch 310/1000. Loss of 0.5799, cover loss of 0.0272, secret loss of 0.9590
# Training: Batch 311/1000. Loss of 0.6822, cover loss of 0.0210, secret loss of 1.0783
# Training: Batch 312/1000. Loss of 0.5456, cover loss of 0.0230, secret loss of 0.9405
# Training: Batch 313/1000. Loss of 0.5810, cover loss of 0.0187, secret loss of 0.9702
# Training: Batch 314/1000. Loss of 0.5619, cover loss of 0.0224, secret loss of 0.9324
# Training: Batch 315/1000. Loss of 0.5401, cover loss of 0.0226, secret loss of 0.9376
# Training: Batch 316/1000. Loss of 0.5145, cover loss of 0.0198, secret loss of 0.8940
# Training: Batch 317/1000. Loss of 0.5734, cover loss of 0.0222, secret loss of 0.9580
# Training: Batch 318/1000. Loss of 0.6144, cover loss of 0.0214, secret loss of 1.0150
# Training: Batch 319/1000. Loss of 0.6234, cover loss of 0.0226, secret loss of 1.0362
# Training: Batch 320/1000. Loss of 0.5678, cover loss of 0.0238, secret loss of 0.9514
# Training: Batch 321/1000. Loss of 0.5676, cover loss of 0.0204, secret loss of 0.9565
# Training: Batch 322/1000. Loss of 0.5362, cover loss of 0.0181, secret loss of 0.9112
# Training: Batch 323/1000. Loss of 0.5834, cover loss of 0.0222, secret loss of 0.9787
# Training: Batch 324/1000. Loss of 0.5093, cover loss of 0.0268, secret loss of 0.8805
# Training: Batch 325/1000. Loss of 0.5819, cover loss of 0.0263, secret loss of 0.9807
# Training: Batch 326/1000. Loss of 0.5770, cover loss of 0.0208, secret loss of 0.9693
# Training: Batch 327/1000. Loss of 0.6412, cover loss of 0.0221, secret loss of 1.0549
# Training: Batch 328/1000. Loss of 0.6068, cover loss of 0.0321, secret loss of 0.9864
# Training: Batch 329/1000. Loss of 0.4554, cover loss of 0.0274, secret loss of 0.8156
# Training: Batch 330/1000. Loss of 0.5065, cover loss of 0.0276, secret loss of 0.8863
# Training: Batch 331/1000. Loss of 0.5254, cover loss of 0.0322, secret loss of 0.8823
# Training: Batch 332/1000. Loss of 0.5962, cover loss of 0.0241, secret loss of 1.0155
# Training: Batch 333/1000. Loss of 0.5769, cover loss of 0.0480, secret loss of 0.9572
# Training: Batch 334/1000. Loss of 0.6899, cover loss of 0.0378, secret loss of 1.0775
# Training: Batch 335/1000. Loss of 0.5142, cover loss of 0.0326, secret loss of 0.8891
# Training: Batch 336/1000. Loss of 0.6093, cover loss of 0.0530, secret loss of 1.0082
# Training: Batch 337/1000. Loss of 0.5918, cover loss of 0.0502, secret loss of 0.9787
# Training: Batch 338/1000. Loss of 0.5449, cover loss of 0.0504, secret loss of 0.9295
# Training: Batch 339/1000. Loss of 0.4963, cover loss of 0.0407, secret loss of 0.8495
# Training: Batch 340/1000. Loss of 0.6117, cover loss of 0.0438, secret loss of 0.9994
# Training: Batch 341/1000. Loss of 0.5323, cover loss of 0.0489, secret loss of 0.8925
# Training: Batch 342/1000. Loss of 0.5297, cover loss of 0.0393, secret loss of 0.9204
# Training: Batch 343/1000. Loss of 0.5924, cover loss of 0.0589, secret loss of 0.9737
# Training: Batch 344/1000. Loss of 0.5006, cover loss of 0.0362, secret loss of 0.8657
# Training: Batch 345/1000. Loss of 0.6533, cover loss of 0.0393, secret loss of 1.0499
# Training: Batch 346/1000. Loss of 0.6346, cover loss of 0.0411, secret loss of 1.0319
# Training: Batch 347/1000. Loss of 0.6372, cover loss of 0.0305, secret loss of 1.0411
# Training: Batch 348/1000. Loss of 0.6560, cover loss of 0.0424, secret loss of 1.0525
# Training: Batch 349/1000. Loss of 0.4814, cover loss of 0.0315, secret loss of 0.8411
# Training: Batch 350/1000. Loss of 0.5618, cover loss of 0.0322, secret loss of 0.9519
# Training: Batch 351/1000. Loss of 0.5887, cover loss of 0.0310, secret loss of 0.9784
# Training: Batch 352/1000. Loss of 0.5755, cover loss of 0.0248, secret loss of 0.9639
# Training: Batch 353/1000. Loss of 0.6225, cover loss of 0.0322, secret loss of 0.9998
# Training: Batch 354/1000. Loss of 0.5144, cover loss of 0.0221, secret loss of 0.8914
# Training: Batch 355/1000. Loss of 0.5274, cover loss of 0.0272, secret loss of 0.8865
# Training: Batch 356/1000. Loss of 0.6142, cover loss of 0.0235, secret loss of 1.0301
# Training: Batch 357/1000. Loss of 0.5170, cover loss of 0.0321, secret loss of 0.8998
# Training: Batch 358/1000. Loss of 0.5920, cover loss of 0.0265, secret loss of 0.9738
# Training: Batch 359/1000. Loss of 0.5787, cover loss of 0.0239, secret loss of 0.9645
# Training: Batch 360/1000. Loss of 0.5413, cover loss of 0.0418, secret loss of 0.9482
# Training: Batch 361/1000. Loss of 0.5365, cover loss of 0.0368, secret loss of 0.9034
# Training: Batch 362/1000. Loss of 0.6018, cover loss of 0.0222, secret loss of 0.9988
# Training: Batch 363/1000. Loss of 0.5213, cover loss of 0.0392, secret loss of 0.9010
# Training: Batch 364/1000. Loss of 0.6421, cover loss of 0.0325, secret loss of 1.0326
# Training: Batch 365/1000. Loss of 0.6478, cover loss of 0.0361, secret loss of 1.0492
# Training: Batch 366/1000. Loss of 0.5958, cover loss of 0.0358, secret loss of 0.9946
# Training: Batch 367/1000. Loss of 0.5342, cover loss of 0.0313, secret loss of 0.9232
# Training: Batch 368/1000. Loss of 0.5656, cover loss of 0.0340, secret loss of 0.9481
# Training: Batch 369/1000. Loss of 0.5670, cover loss of 0.0308, secret loss of 0.9595
# Training: Batch 370/1000. Loss of 0.6286, cover loss of 0.0308, secret loss of 1.0241
# Training: Batch 371/1000. Loss of 0.6195, cover loss of 0.0256, secret loss of 1.0327
# ...
# Training: Batch 637/1000. Loss of 0.4851, cover loss of 0.0277, secret loss of 0.8362
# Training: Batch 638/1000. Loss of 0.5781, cover loss of 0.0145, secret loss of 0.9836
# Training: Batch 639/1000. Loss of 0.5037, cover loss of 0.0160, secret loss of 0.8853
# Training: Batch 640/1000. Loss of 0.4991, cover loss of 0.0142, secret loss of 0.8760
# Training: Batch 641/1000. Loss of 0.5028, cover loss of 0.0187, secret loss of 0.8750
# Training: Batch 642/1000. Loss of 0.6213, cover loss of 0.0159, secret loss of 1.0195
# Training: Batch 643/1000. Loss of 0.5653, cover loss of 0.0167, secret loss of 0.9784
# Training: Batch 644/1000. Loss of 0.5999, cover loss of 0.0227, secret loss of 0.9956
# Training: Batch 645/1000. Loss of 0.5031, cover loss of 0.0208, secret loss of 0.8779
# Training: Batch 646/1000. Loss of 0.5269, cover loss of 0.0140, secret loss of 0.9164
# Training: Batch 647/1000. Loss of 0.6285, cover loss of 0.0221, secret loss of 1.0241
# Training: Batch 648/1000. Loss of 0.5377, cover loss of 0.0152, secret loss of 0.9027
# Training: Batch 649/1000. Loss of 0.5643, cover loss of 0.0211, secret loss of 0.9395
# Training: Batch 650/1000. Loss of 0.5320, cover loss of 0.0184, secret loss of 0.9137
# Training: Batch 651/1000. Loss of 0.7031, cover loss of 0.0191, secret loss of 1.1048
# Training: Batch 652/1000. Loss of 0.5354, cover loss of 0.0170, secret loss of 0.9287
# Training: Batch 653/1000. Loss of 0.5246, cover loss of 0.0220, secret loss of 0.9093
# Training: Batch 654/1000. Loss of 0.5678, cover loss of 0.0251, secret loss of 0.9351
# Training: Batch 655/1000. Loss of 0.5315, cover loss of 0.0208, secret loss of 0.9158
# Training: Batch 656/1000. Loss of 0.5460, cover loss of 0.0223, secret loss of 0.9517
# Training: Batch 657/1000. Loss of 0.5962, cover loss of 0.0163, secret loss of 0.9745
# Training: Batch 658/1000. Loss of 0.5200, cover loss of 0.0206, secret loss of 0.9012
# Training: Batch 659/1000. Loss of 0.5986, cover loss of 0.0236, secret loss of 1.0037
# Training: Batch 660/1000. Loss of 0.5578, cover loss of 0.0224, secret loss of 0.9377
# Training: Batch 661/1000. Loss of 0.5378, cover loss of 0.0209, secret loss of 0.9098
# Training: Batch 662/1000. Loss of 0.6006, cover loss of 0.0189, secret loss of 0.9942
# Training: Batch 663/1000. Loss of 0.5462, cover loss of 0.0172, secret loss of 0.9309
# Training: Batch 664/1000. Loss of 0.5186, cover loss of 0.0208, secret loss of 0.9189
# Training: Batch 665/1000. Loss of 0.6263, cover loss of 0.0152, secret loss of 1.0362
# Training: Batch 666/1000. Loss of 0.7058, cover loss of 0.0201, secret loss of 1.1263
# Training: Batch 667/1000. Loss of 0.5686, cover loss of 0.0139, secret loss of 0.9823
# Training: Batch 668/1000. Loss of 0.5287, cover loss of 0.0183, secret loss of 0.9112
# Training: Batch 669/1000. Loss of 0.5548, cover loss of 0.0189, secret loss of 0.9365
# Training: Batch 670/1000. Loss of 0.4624, cover loss of 0.0171, secret loss of 0.8384
# Training: Batch 671/1000. Loss of 0.5394, cover loss of 0.0155, secret loss of 0.9259
# Training: Batch 672/1000. Loss of 0.5361, cover loss of 0.0146, secret loss of 0.9026
# Training: Batch 673/1000. Loss of 0.5977, cover loss of 0.0136, secret loss of 1.0028
# Training: Batch 674/1000. Loss of 0.5213, cover loss of 0.0174, secret loss of 0.9150
# Training: Batch 675/1000. Loss of 0.5794, cover loss of 0.0172, secret loss of 0.9845
# Training: Batch 676/1000. Loss of 0.5576, cover loss of 0.0116, secret loss of 0.9561
# Training: Batch 677/1000. Loss of 0.5758, cover loss of 0.0160, secret loss of 0.9600
# Training: Batch 678/1000. Loss of 0.5426, cover loss of 0.0133, secret loss of 0.9159
# Training: Batch 679/1000. Loss of 0.6519, cover loss of 0.0146, secret loss of 1.0493
# Training: Batch 680/1000. Loss of 0.6402, cover loss of 0.0134, secret loss of 1.0572
# Training: Batch 681/1000. Loss of 0.4406, cover loss of 0.0141, secret loss of 0.8038
# Training: Batch 682/1000. Loss of 0.6132, cover loss of 0.0177, secret loss of 0.9914
# Training: Batch 683/1000. Loss of 0.5532, cover loss of 0.0162, secret loss of 0.9522
# Training: Batch 684/1000. Loss of 0.5392, cover loss of 0.0178, secret loss of 0.9292
# Training: Batch 685/1000. Loss of 0.6045, cover loss of 0.0147, secret loss of 0.9998
# Training: Batch 686/1000. Loss of 0.5029, cover loss of 0.0184, secret loss of 0.8888
# Training: Batch 687/1000. Loss of 0.5813, cover loss of 0.0159, secret loss of 0.9929
# Training: Batch 688/1000. Loss of 0.6338, cover loss of 0.0165, secret loss of 1.0379
# Training: Batch 689/1000. Loss of 0.6857, cover loss of 0.0227, secret loss of 1.0827
# Training: Batch 690/1000. Loss of 0.5390, cover loss of 0.0206, secret loss of 0.9130
# Training: Batch 691/1000. Loss of 0.4865, cover loss of 0.0176, secret loss of 0.8627
# Training: Batch 692/1000. Loss of 0.5227, cover loss of 0.0263, secret loss of 0.9110
# Training: Batch 693/1000. Loss of 0.6816, cover loss of 0.0191, secret loss of 1.0885
# Training: Batch 694/1000. Loss of 0.5529, cover loss of 0.0181, secret loss of 0.9500
# Training: Batch 695/1000. Loss of 0.6155, cover loss of 0.0193, secret loss of 1.0103
# Training: Batch 696/1000. Loss of 0.6508, cover loss of 0.0207, secret loss of 1.0350
# Training: Batch 697/1000. Loss of 0.5489, cover loss of 0.0196, secret loss of 0.9376
# Training: Batch 698/1000. Loss of 0.6423, cover loss of 0.0166, secret loss of 1.0430
# Training: Batch 699/1000. Loss of 0.5847, cover loss of 0.0155, secret loss of 0.9852
# Training: Batch 700/1000. Loss of 0.4662, cover loss of 0.0145, secret loss of 0.8403
# Training: Batch 701/1000. Loss of 0.6921, cover loss of 0.0134, secret loss of 1.0942
# Training: Batch 702/1000. Loss of 0.5778, cover loss of 0.0131, secret loss of 0.9649
# Training: Batch 703/1000. Loss of 0.6024, cover loss of 0.0176, secret loss of 0.9979
# Training: Batch 704/1000. Loss of 0.4815, cover loss of 0.0138, secret loss of 0.8763
# Training: Batch 705/1000. Loss of 0.5998, cover loss of 0.0150, secret loss of 0.9905
# Training: Batch 706/1000. Loss of 0.5284, cover loss of 0.0138, secret loss of 0.9093
# Training: Batch 707/1000. Loss of 0.5634, cover loss of 0.0191, secret loss of 0.9477
# Training: Batch 708/1000. Loss of 0.6172, cover loss of 0.0168, secret loss of 1.0084
# Training: Batch 709/1000. Loss of 0.5018, cover loss of 0.0157, secret loss of 0.8666
# Training: Batch 710/1000. Loss of 0.5220, cover loss of 0.0147, secret loss of 0.9069
# Training: Batch 711/1000. Loss of 0.5364, cover loss of 0.0172, secret loss of 0.9217
# Training: Batch 712/1000. Loss of 0.5608, cover loss of 0.0244, secret loss of 0.9522
# Training: Batch 713/1000. Loss of 0.5955, cover loss of 0.0142, secret loss of 0.9831
# Training: Batch 714/1000. Loss of 0.5616, cover loss of 0.0269, secret loss of 0.9361
# Training: Batch 715/1000. Loss of 0.5645, cover loss of 0.0195, secret loss of 0.9562
# Training: Batch 716/1000. Loss of 0.4895, cover loss of 0.0356, secret loss of 0.8507
# Training: Batch 717/1000. Loss of 0.6006, cover loss of 0.0202, secret loss of 0.9882
# Training: Batch 718/1000. Loss of 0.6516, cover loss of 0.0480, secret loss of 1.0287
# Training: Batch 719/1000. Loss of 0.5933, cover loss of 0.0446, secret loss of 0.9841
# Training: Batch 720/1000. Loss of 0.5612, cover loss of 0.0381, secret loss of 0.9388
# Training: Batch 721/1000. Loss of 0.5516, cover loss of 0.0536, secret loss of 0.9329
# Training: Batch 722/1000. Loss of 0.5742, cover loss of 0.0352, secret loss of 0.9647
# Training: Batch 723/1000. Loss of 0.5940, cover loss of 0.0288, secret loss of 0.9638
# Training: Batch 724/1000. Loss of 0.6498, cover loss of 0.0450, secret loss of 1.0612
# Training: Batch 725/1000. Loss of 0.5360, cover loss of 0.0318, secret loss of 0.9085
# Training: Batch 726/1000. Loss of 0.5982, cover loss of 0.0584, secret loss of 0.9555
# Training: Batch 727/1000. Loss of 0.6091, cover loss of 0.0410, secret loss of 0.9801
# Training: Batch 728/1000. Loss of 0.6219, cover loss of 0.0234, secret loss of 1.0117
# Training: Batch 729/1000. Loss of 0.5259, cover loss of 0.0472, secret loss of 0.8985
# Training: Batch 730/1000. Loss of 0.5148, cover loss of 0.0467, secret loss of 0.8820
# Training: Batch 731/1000. Loss of 0.5209, cover loss of 0.0256, secret loss of 0.8926
# Training: Batch 732/1000. Loss of 0.5480, cover loss of 0.0402, secret loss of 0.9248
# Training: Batch 733/1000. Loss of 0.5215, cover loss of 0.0325, secret loss of 0.8938
# Training: Batch 734/1000. Loss of 0.6111, cover loss of 0.0320, secret loss of 1.0163
# Training: Batch 735/1000. Loss of 0.5773, cover loss of 0.0285, secret loss of 0.9674
# Training: Batch 736/1000. Loss of 0.5788, cover loss of 0.0324, secret loss of 0.9638
# Training: Batch 737/1000. Loss of 0.5025, cover loss of 0.0434, secret loss of 0.8683
# Training: Batch 738/1000. Loss of 0.5318, cover loss of 0.0220, secret loss of 0.9044
# Training: Batch 739/1000. Loss of 0.6820, cover loss of 0.0414, secret loss of 1.0950
# Training: Batch 740/1000. Loss of 0.5256, cover loss of 0.0361, secret loss of 0.9188
# Training: Batch 741/1000. Loss of 0.6079, cover loss of 0.0243, secret loss of 1.0006
# Training: Batch 742/1000. Loss of 0.6014, cover loss of 0.0270, secret loss of 1.0093
# Training: Batch 743/1000. Loss of 0.5629, cover loss of 0.0222, secret loss of 0.9419
# Training: Batch 744/1000. Loss of 0.6379, cover loss of 0.0311, secret loss of 1.0439
# Training: Batch 745/1000. Loss of 0.5519, cover loss of 0.0214, secret loss of 0.9237
# Training: Batch 746/1000. Loss of 0.5725, cover loss of 0.0286, secret loss of 0.9428
# Training: Batch 747/1000. Loss of 0.5490, cover loss of 0.0182, secret loss of 0.9318
# Training: Batch 748/1000. Loss of 0.4955, cover loss of 0.0273, secret loss of 0.8786
# Training: Batch 749/1000. Loss of 0.4853, cover loss of 0.0185, secret loss of 0.8516
# Training: Batch 750/1000. Loss of 0.6316, cover loss of 0.0231, secret loss of 1.0465
# Training: Batch 751/1000. Loss of 0.6182, cover loss of 0.0222, secret loss of 1.0088
# Training: Batch 752/1000. Loss of 0.5533, cover loss of 0.0173, secret loss of 0.9473
# Training: Batch 753/1000. Loss of 0.5935, cover loss of 0.0156, secret loss of 0.9851
# Training: Batch 754/1000. Loss of 0.6187, cover loss of 0.0152, secret loss of 1.0369
# Training: Batch 755/1000. Loss of 0.5739, cover loss of 0.0172, secret loss of 0.9579
# Training: Batch 756/1000. Loss of 0.5535, cover loss of 0.0200, secret loss of 0.9149
# Training: Batch 757/1000. Loss of 0.5553, cover loss of 0.0127, secret loss of 0.9499
# Training: Batch 758/1000. Loss of 0.5956, cover loss of 0.0188, secret loss of 1.0122
# Training: Batch 759/1000. Loss of 0.5372, cover loss of 0.0223, secret loss of 0.9156
# Training: Batch 760/1000. Loss of 0.5194, cover loss of 0.0171, secret loss of 0.9066
# Training: Batch 761/1000. Loss of 0.5809, cover loss of 0.0296, secret loss of 0.9662
# Training: Batch 762/1000. Loss of 0.6684, cover loss of 0.0182, secret loss of 1.0702
# Training: Batch 763/1000. Loss of 0.6357, cover loss of 0.0291, secret loss of 1.0091
# Training: Batch 764/1000. Loss of 0.5000, cover loss of 0.0170, secret loss of 0.8674
# Training: Batch 765/1000. Loss of 0.5971, cover loss of 0.0168, secret loss of 1.0000
# Training: Batch 766/1000. Loss of 0.7265, cover loss of 0.0236, secret loss of 1.1555
# Training: Batch 767/1000. Loss of 0.5369, cover loss of 0.0233, secret loss of 0.9163
# Training: Batch 768/1000. Loss of 0.5044, cover loss of 0.0232, secret loss of 0.8704
# Training: Batch 769/1000. Loss of 0.5294, cover loss of 0.0235, secret loss of 0.9113
# Training: Batch 770/1000. Loss of 0.5694, cover loss of 0.0263, secret loss of 0.9573
# Training: Batch 771/1000. Loss of 0.5819, cover loss of 0.0297, secret loss of 0.9853
# Training: Batch 772/1000. Loss of 0.6468, cover loss of 0.0257, secret loss of 1.0361
# Training: Batch 773/1000. Loss of 0.5705, cover loss of 0.0254, secret loss of 0.9753
# Training: Batch 774/1000. Loss of 0.4984, cover loss of 0.0198, secret loss of 0.8622
# Training: Batch 775/1000. Loss of 0.5319, cover loss of 0.0268, secret loss of 0.9064
# Training: Batch 776/1000. Loss of 0.5994, cover loss of 0.0261, secret loss of 1.0099
# Training: Batch 777/1000. Loss of 0.5687, cover loss of 0.0201, secret loss of 0.9482
# Training: Batch 778/1000. Loss of 0.5829, cover loss of 0.0278, secret loss of 0.9656
# Training: Batch 779/1000. Loss of 0.5599, cover loss of 0.0222, secret loss of 0.9581
# Training: Batch 780/1000. Loss of 0.4592, cover loss of 0.0232, secret loss of 0.8215
# Training: Batch 781/1000. Loss of 0.5345, cover loss of 0.0233, secret loss of 0.9095
# Training: Batch 782/1000. Loss of 0.5227, cover loss of 0.0189, secret loss of 0.9047
# Training: Batch 783/1000. Loss of 0.5127, cover loss of 0.0220, secret loss of 0.8879
# Training: Batch 784/1000. Loss of 0.5389, cover loss of 0.0202, secret loss of 0.9243
# Training: Batch 785/1000. Loss of 0.5712, cover loss of 0.0290, secret loss of 0.9604
# Training: Batch 786/1000. Loss of 0.5267, cover loss of 0.0190, secret loss of 0.9114
# Training: Batch 787/1000. Loss of 0.4761, cover loss of 0.0170, secret loss of 0.8548
# Training: Batch 788/1000. Loss of 0.6221, cover loss of 0.0191, secret loss of 0.9899
# Training: Batch 789/1000. Loss of 0.4833, cover loss of 0.0175, secret loss of 0.8631
# Training: Batch 790/1000. Loss of 0.5161, cover loss of 0.0166, secret loss of 0.9057
# Training: Batch 791/1000. Loss of 0.5230, cover loss of 0.0188, secret loss of 0.9155
# Training: Batch 792/1000. Loss of 0.6680, cover loss of 0.0202, secret loss of 1.0528
# Training: Batch 793/1000. Loss of 0.5639, cover loss of 0.0187, secret loss of 0.9502
# Training: Batch 794/1000. Loss of 0.5781, cover loss of 0.0172, secret loss of 0.9649
# Training: Batch 795/1000. Loss of 0.4721, cover loss of 0.0157, secret loss of 0.8473
# Training: Batch 796/1000. Loss of 0.5250, cover loss of 0.0158, secret loss of 0.8841
# Training: Batch 797/1000. Loss of 0.5389, cover loss of 0.0199, secret loss of 0.9186
# Training: Batch 798/1000. Loss of 0.6513, cover loss of 0.0172, secret loss of 1.0574
# Training: Batch 799/1000. Loss of 0.5224, cover loss of 0.0153, secret loss of 0.9208
# Training: Batch 800/1000. Loss of 0.5469, cover loss of 0.0196, secret loss of 0.9261
# Training: Batch 801/1000. Loss of 0.5076, cover loss of 0.0138, secret loss of 0.8946
# Training: Batch 802/1000. Loss of 0.6180, cover loss of 0.0177, secret loss of 0.9992
# Training: Batch 803/1000. Loss of 0.5222, cover loss of 0.0155, secret loss of 0.9103
# Training: Batch 804/1000. Loss of 0.5370, cover loss of 0.0139, secret loss of 0.9290
# Training: Batch 805/1000. Loss of 0.5008, cover loss of 0.0147, secret loss of 0.8856
# Training: Batch 806/1000. Loss of 0.6490, cover loss of 0.0136, secret loss of 1.0715
# Training: Batch 807/1000. Loss of 0.4097, cover loss of 0.0200, secret loss of 0.7634
# Training: Batch 808/1000. Loss of 0.5870, cover loss of 0.0155, secret loss of 0.9837
# Training: Batch 809/1000. Loss of 0.5377, cover loss of 0.0136, secret loss of 0.9181
# Training: Batch 810/1000. Loss of 0.5016, cover loss of 0.0316, secret loss of 0.8899
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-a7bddcd850b1> in <module>()
#       6 #     loss_history.append(float(line.strip()))
#       7
# ----> 8 net, mean_train_loss, loss_history1 = train_model(train_loader, beta, learning_rate)
#       9 # loss_history.extend(loss_history1)
#
# <ipython-input-9-04aebc73a3cc> in train_model(train_loader, beta, learning_rate)
#      30
#      31             # Forward + Backward + Optimize
# ---> 32             optimizer.zero_grad()
#      33             train_hidden, train_output = net(train_secrets, train_covers)
#      34
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/optimizer.py in zero_grad(self, set_to_none)
#     214                                 p.grad.detach_()
#     215                             else:
# --> 216                                 p.grad.requires_grad_(False)
#     217                             p.grad.zero_()
#     218
#
# KeyboardInterrupt:

# %%
 # Plot loss through epochs
plt.plot(loss_history)
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Batch')
plt.show()

# %%
def pixel_errors(input_S, input_C, decoded_S, decoded_C):
    """Calculates mean of Sum of Squared Errors per pixel for cover and secret images. """
    input_S = np.array(input_S.detach().cpu())
    input_C = np.array(input_C.detach().cpu())
    decoded_S = np.array(decoded_S.detach().cpu())
    decoded_C = np.array(decoded_C.detach().cpu())
    # print(input_S)
    see_Spixel = np.sqrt(np.mean(np.square(255*(input_S - decoded_S))))
    see_Cpixel = np.sqrt(np.mean(np.square(255*(input_C - decoded_C))))
    
    return see_Spixel, see_Cpixel

import math
def psnr(input_S, input_C, decoded_S, decoded_C):
    input_S = np.array(input_S.detach().cpu())
    input_C = np.array(input_C.detach().cpu())
    decoded_S = np.array(decoded_S.detach().cpu())
    decoded_C = np.array(decoded_C.detach().cpu())
    mse_s = np.mean(np.square(255*(input_S - decoded_S)))
    mse_c = np.mean(np.square(255*(input_C - decoded_C)))
    psnr_s = 10*math.log10(255**2/mse_s)
    psnr_c = 10*math.log10(255**2/mse_c)
    return psnr_s, psnr_c

def pixel_histogram(diff_S, diff_C):
    """Calculates histograms of errors for cover and secret image. """
    diff_Sflat = diff_S.flatten()
    diff_Cflat = diff_C.flatten()
    
    fig = plt.figure(figsize=(15, 5))
    a=fig.add_subplot(1,2,1)
        
    imgplot = plt.hist(255* diff_Cflat, 100, density=1, alpha=0.75, facecolor='red')
    a.set_title('Distribution of error in the Cover image.')
    plt.axis([0, 250, 0, 0.2])
    
    a=fig.add_subplot(1,2,2)
    imgplot = plt.hist(255* diff_Sflat, 100, density=1, alpha=0.75, facecolor='red')
    a.set_title('Distribution of errors in the Secret image.')
    plt.axis([0, 250, 0, 0.2])
    
    plt.show()

# %%
# net.load_state_dict(torch.load(MODELS_PATH+'Epoch N4.pkl'))

# Switch to evaluate mode
net.eval()
Path(PATH+"LOSS2_1_ds_with_noise").mkdir(parents=True, exist_ok=True)
Path(PATH+"LOSS2_1_ds_with_noise/cover_images/").mkdir(parents=True, exist_ok=True)
Path(PATH+"LOSS2_1_ds_with_noise/container_images/").mkdir(parents=True, exist_ok=True)
save_path = PATH+"LOSS2_1_ds_with_noise/"

test_losses = []

S_errors = []
C_errors = []

psnr_s,psnr_c = [], []
# Show images
for idx, test_batch in enumerate(test_loader):
     # Saves images
    data, _ = test_batch
    data = data.to(device)

    # Saves secret images and secret covers
    test_secret = data[:len(data)//2]
    test_cover = data[len(data)//2:]

    # Creates variable from secret and cover images
    test_secret = Variable(test_secret, volatile=True)
    test_cover = Variable(test_cover, volatile=True)

    # Compute output
    test_hidden, test_output = net(test_secret, test_cover)
    
    # Calculate loss
    test_loss, loss_cover, loss_secret = customized_loss(test_output, test_hidden, test_secret, test_cover, beta)
    
    diff_S, diff_C = np.abs(np.array(test_output.data.detach().cpu()) - np.array(test_secret.data.detach().cpu())), np.abs(np.array(test_hidden.data.detach().cpu()) - np.array(test_cover.data.detach().cpu()))
    
#     print (diff_S, diff_C)

    # Print pixel-wise average errors in a 256 scale.
    S_error, C_error = pixel_errors(test_secret, test_cover, test_output, test_hidden)
    S_errors.append(S_error)
    C_errors.append(C_error)

    S_psnr, C_psnr = psnr(test_secret, test_cover, test_output, test_hidden)
    psnr_s.append(S_psnr)
    psnr_c.append(C_psnr)
    
    if idx in [1,2,3,4]:
        print ('Total loss: {:.2f} \nLoss on secret: {:.2f} \nLoss on cover: {:.2f}'.format(test_loss.data.item(), loss_secret.data.item(), loss_cover.data.item()))

        # Creates img tensor
        imgs = [test_secret.data.detach().cpu(), test_output.data.detach().cpu(), test_cover.data.detach().cpu(), test_hidden.data.detach().cpu()]
        imgs_tsor = torch.cat(imgs, 0)

        # Prints Images
        imshow(utils.make_grid(imgs_tsor), idx+1, learning_rate=learning_rate, beta=beta)
        
    if idx < 500:
        container_img = tensor_to_image(test_hidden.data.detach().cpu())
        container_img = Image.fromarray(container_img)
        container_img.save(save_path+"container_images/"+str(idx)+".jpeg")
        cover_img = tensor_to_image(test_cover.data.detach().cpu())
        cover_img = Image.fromarray(cover_img)
        cover_img.save(save_path+"cover_images/"+str(idx)+".jpeg")

    test_losses.append(test_loss.data.item())
        
mean_test_loss = np.mean(test_losses)

print ('Average loss on test set: {:.2f}'.format(mean_test_loss))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:27: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:43: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Total loss: 0.75
# Loss on secret: 1.20
# Loss on cover: 0.01
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Total loss: 0.44
# Loss on secret: 1.27
# Loss on cover: 0.02
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Total loss: 0.40
# Loss on secret: 0.76
# Loss on cover: 0.01
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Total loss: 0.62
# Loss on secret: 1.07
# Loss on cover: 0.02
# Average loss on test set: 0.55

# %%
print ("Avg. S error per pixel [0, 255]:", sum(S_errors)/len(S_errors))
print ("Avg. C error per pixel [0, 255]:", sum(C_errors)/len(C_errors))
# Out:
# Avg. S error per pixel [0, 255]: 302.23401552734373
# Avg. C error per pixel [0, 255]: 6.346587062263489

# %%
print ("Avg. PSNR of secret and decoded secret:", sum(psnr_s)/len(psnr_s))
print ("Avg. PSNR of cover and container:", sum(psnr_c)/len(psnr_c))
# Out:
# Avg. PSNR of secret and decoded secret: -1.2598225171863746
# Avg. PSNR of cover and container: 32.36929356198094

# %%
# Plot distribution of errors in cover and secret images.
pixel_histogram(diff_S, diff_C)
