# %% [markdown]
# <a href="https://colab.research.google.com/github/chvamshi/Deep-Steganography/blob/main/LOSS3_DS_with_noise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget http://cs231n.stanford.edu/tiny-imagenet-200.zip
# !unzip -q tiny-imagenet-200.zip && ls tiny-imagenet-200
# Out:
# --2022-02-05 21:19:20--  http://cs231n.stanford.edu/tiny-imagenet-200.zip
# Resolving cs231n.stanford.edu (cs231n.stanford.edu)... 171.64.68.10
# Connecting to cs231n.stanford.edu (cs231n.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248100043 (237M) [application/zip]
# Saving to: ‘tiny-imagenet-200.zip’
#
# tiny-imagenet-200.z 100%[===================>] 236.61M  19.0MB/s    in 16s
#
# 2022-02-05 21:19:36 (15.2 MB/s) - ‘tiny-imagenet-200.zip’ saved [248100043/248100043]
#
# test  train  val  wnids.txt  words.txt

# %%
# Imports necessary libraries and modules
from itertools import islice
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch.autograd import Variable
from torch import utils
from torch.utils.data import Subset
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import os 
from pathlib import Path
import pickle
import random
from torchvision import datasets, utils
import torchvision.transforms as transforms
from torchvision.transforms import ToPILImage
from torchvision.transforms import RandomResizedCrop
from torchvision.transforms.functional import resized_crop
from random import shuffle
from IPython.display import Image
from PIL import Image

# Use GPU if it is present
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
# Directory path
# os.chdir("..")
cwd = '/content/tiny-imagenet-200'



# Hyper Parameters
num_epochs = 30
batch_size = 32
learning_rate = 0.001
beta = 1

# Mean and std deviation of imagenet dataset. Source: http://cs231n.stanford.edu/reports/2017/pdfs/101.pdf
std = [0.229, 0.224, 0.225]
mean = [0.485, 0.456, 0.406]

# TODO: Define train, validation and models
MODELS_PATH = '/content/output/models'
# TRAIN_PATH = cwd+'/train/'
# VALID_PATH = cwd+'/valid/'
VALID_PATH = cwd+'/val/'
TRAIN_PATH = cwd+'/train/'
TEST_PATH = cwd+'/test/'

# if not os.path.exists(MODELS_PATH): os.mkdir(MODELS_PATH)

# %%
def variance(image1, image2):
    var1 = torch.var(image1)
    var2 = torch.var(image2)

    return var1+var2

def customized_loss(S_prime, C_prime, S, C, B):
    ''' Calculates loss specified on the paper.'''
    
    loss_cover = torch.nn.functional.mse_loss(C_prime, C)
    loss_secret = torch.nn.functional.mse_loss(S_prime, S)

    loss_all = (loss_cover + B * loss_secret + variance(C_prime, C) + variance(S_prime, S))/4

    return loss_all, loss_cover, loss_secret

def denormalize(image, std, mean):
    ''' Denormalizes a tensor of images.'''

    for t in range(3):
        image[t, :, :] = (image[t, :, :] * std[t]) + mean[t]
    return image

def imshow(img, idx, learning_rate, beta):
    '''Prints out an image given in tensor format.'''
    
    img = denormalize(img, std, mean)
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.title('Example '+str(idx)+', lr='+str(learning_rate)+', B='+str(beta))
    plt.show()
    return

def gaussian(tensor, mean=0, stddev=0.1):
    '''Adds random noise to a tensor.'''
    
    noise = torch.nn.init.normal(torch.Tensor(tensor.size()), 0, 0.1).to(device)
    return Variable(tensor + noise)

def tensor_to_image(tensor):
    """
    Transforms a torch tensor into numpy uint8 array (image)
    :param tensor: (batch_size x channels x height x width) torch tensor in range [-1.0, 1.0]
    :return: (batch_size x height x width x channels) uint8 array
    """
    image = tensor.cpu().numpy()[0]
    # image = tensor.permute(0, 2, 3, 1).cpu().numpy()
    image = np.transpose(image, (1,2,0))
    image = (image + 1) * 127.5
    return np.clip(image, 0, 255).astype(np.uint8)

# %%
# Preparation Network (2 conv layers)
class PrepNetwork(nn.Module):
    def __init__(self):
        super(PrepNetwork, self).__init__()
        self.initialP3 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialP4 = nn.Sequential(
            nn.Conv2d(3, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialP5 = nn.Sequential(
            nn.Conv2d(3, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalP3 = nn.Sequential(
            nn.Conv2d(65, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalP4 = nn.Sequential(
            nn.Conv2d(65, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalP5 = nn.Sequential(
            nn.Conv2d(65, 5, kernel_size=5, padding=2),
            nn.ReLU())

    def forward(self, p):
        p1 = self.initialP3(p)
        p2 = self.initialP4(p)
        p3 = self.initialP5(p)
        mid = torch.cat((p1, p2, p3), 1)
        p4 = self.finalP3(mid)
        p5 = self.finalP4(mid)
        p6 = self.finalP5(mid)
        # print(p4.shape)
        # print(p5.shape)
        # print(p6.shape)
        out = torch.cat((p4, p5, p6), 1)
        return out

# Hiding Network (5 conv layers)
class HidingNetwork(nn.Module):
    def __init__(self):
        super(HidingNetwork, self).__init__()
        self.initialH3 = nn.Sequential(
            nn.Conv2d(68, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialH4 = nn.Sequential(
            nn.Conv2d(68, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialH5 = nn.Sequential(
            nn.Conv2d(68, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalH3 = nn.Sequential(
            nn.Conv2d(65, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalH4 = nn.Sequential(
            nn.Conv2d(65, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalH5 = nn.Sequential(
            nn.Conv2d(65, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalH = nn.Sequential(
            nn.Conv2d(65, 3, kernel_size=1, padding=0))
        
    def forward(self, h):
        h1 = self.initialH3(h)
        h2 = self.initialH4(h)
        h3 = self.initialH5(h)
        mid = torch.cat((h1, h2, h3), 1)
        h4 = self.finalH3(mid)
        h5 = self.finalH4(mid)
        h6 = self.finalH5(mid)
        mid2 = torch.cat((h4, h5, h6), 1)
        out = self.finalH(mid2)
        out_noise = gaussian(out.data, 0, 0.1)
        return out, out_noise

# Reveal Network (2 conv layers)
class RevealNetwork(nn.Module):
    def __init__(self):
        super(RevealNetwork, self).__init__()
        self.initialR3 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialR4 = nn.Sequential(
            nn.Conv2d(3, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialR5 = nn.Sequential(
            nn.Conv2d(3, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalR3 = nn.Sequential(
            nn.Conv2d(65, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalR4 = nn.Sequential(
            nn.Conv2d(65, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalR5 = nn.Sequential(
            nn.Conv2d(65, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalR = nn.Sequential(
            nn.Conv2d(65, 3, kernel_size=1, padding=0))

    def forward(self, r):
        r1 = self.initialR3(r)
        r2 = self.initialR4(r)
        r3 = self.initialR5(r)
        mid = torch.cat((r1, r2, r3), 1)
        r4 = self.finalR3(mid)
        r5 = self.finalR4(mid)
        r6 = self.finalR5(mid)
        mid2 = torch.cat((r4, r5, r6), 1)
        out = self.finalR(mid2)
        return out

# Join three networks in one module
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.m1 = PrepNetwork().to(device)
        self.m2 = HidingNetwork().to(device)
        self.m3 = RevealNetwork().to(device)

    def forward(self, secret, cover):
        x_1 = self.m1(secret)
        mid = torch.cat((x_1, cover), 1)
        x_2, x_2_noise = self.m2(mid)
        x_3 = self.m3(x_2_noise)
        # x_3 = self.m3(x_2)
        return x_2, x_3

# %%
# Creates net object
net = Net().to(device)

# %%
# Creates training set
train_data = datasets.ImageFolder(
        TRAIN_PATH,
        transforms.Compose([
        # transforms.Scale(256),
        # transforms.RandomCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean,
        std=std)
        ]))
train_data = Subset(train_data, [i for i in range(32000)])
train_loader = torch.utils.data.DataLoader(
        train_data, batch_size=batch_size, num_workers=1, 
        pin_memory=True, shuffle=True, drop_last=True)

# Creates test set
test_data = datasets.ImageFolder(
        TEST_PATH, 
        transforms.Compose([
        # transforms.Scale(256),
        # transforms.RandomCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean,
        std=std)
        ]))
test_data = Subset(test_data,[i for i in range(5000)])
test_loader = torch.utils.data.DataLoader(
        test_data, batch_size=2, num_workers=1, 
        pin_memory=True, shuffle=True, drop_last=True)

# %%
PATH = "/content/drive/MyDrive/"
loss_history = []

def train_model(train_loader, beta, learning_rate):
    
    # Save optimizer
    optimizer = optim.Adam(net.parameters(), lr=learning_rate)
    
    loss_history = []
    # Iterate over batches performing forward and backward passes
    for epoch in range(num_epochs):

        # Train mode
        net.train()
        
        train_losses = []
        # Train one epoch
        for idx, train_batch in enumerate(train_loader):

            data, _  = train_batch
            data = data.to(device)

            # Saves secret images and secret covers
            train_covers = data[:len(data)//2]
            train_secrets = data[len(data)//2:]
            
            # Creates variable from secret and cover images
            train_secrets = Variable(train_secrets, requires_grad=False)
            train_covers = Variable(train_covers, requires_grad=False)

            # Forward + Backward + Optimize
            optimizer.zero_grad()
            train_hidden, train_output = net(train_secrets, train_covers)

            # Calculate loss and perform backprop
            train_loss, train_loss_cover, train_loss_secret = customized_loss(train_output, train_hidden, train_secrets, train_covers, beta)
            train_loss.backward()
            optimizer.step()
            
            # Saves training loss
            # print(train_loss.data)
            train_losses.append(train_loss.data.item())
            loss_history.append(train_loss.data.item())
            
            # Prints mini-batch losses
            print('Training: Batch {0}/{1}. Loss of {2:.4f}, cover loss of {3:.4f}, secret loss of {4:.4f}'.format(idx+1, len(train_loader), train_loss.data.item(), train_loss_cover.data.item(), train_loss_secret.data.item()))
    
        # Save model
        # torch.save(net.state_dict(), '/content/Epoch N{}.pkl'.format(epoch+1))
        torch.save(net.state_dict(), PATH+"LOSS3_ds_with_noise.pth")
        with open(PATH+"LOSS3_loss_history_with_noise.txt", "a") as f:
            for s in loss_history:
                f.write(str(s) +"\n")
        
        mean_train_loss = np.mean(train_losses)
    
        # Prints epoch average loss
        print ('Epoch [{0}/{1}], Average_loss: {2:.4f}'.format(
                epoch+1, num_epochs, mean_train_loss))
    
    return net, mean_train_loss, loss_history

# %%
# Load model
net.load_state_dict(torch.load(PATH+"LOSS3_ds_with_noise.pth"))
loss_history = []
with open(PATH+"LOSS3_loss_history_with_noise.txt", "r") as f:
  for line in f:
    loss_history.append(float(line.strip()))

net, mean_train_loss, loss_history1 = train_model(train_loader, beta, learning_rate)
loss_history.extend(loss_history1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
# Streaming output truncated to the last 5000 lines.
# Training: Batch 6/1000. Loss of 1.0864, cover loss of 0.3244, secret loss of 1.1796
# Training: Batch 7/1000. Loss of 1.1710, cover loss of 0.2719, secret loss of 1.5376
# Training: Batch 8/1000. Loss of 1.0692, cover loss of 0.2790, secret loss of 1.3164
# Training: Batch 9/1000. Loss of 1.0676, cover loss of 0.3370, secret loss of 1.1559
# Training: Batch 10/1000. Loss of 1.2156, cover loss of 0.4252, secret loss of 1.1679
# Training: Batch 11/1000. Loss of 1.1353, cover loss of 0.2921, secret loss of 1.4400
# Training: Batch 12/1000. Loss of 0.9952, cover loss of 0.3011, secret loss of 1.1712
# Training: Batch 13/1000. Loss of 1.0415, cover loss of 0.3372, secret loss of 1.1074
# Training: Batch 14/1000. Loss of 1.0908, cover loss of 0.3043, secret loss of 1.2860
# Training: Batch 15/1000. Loss of 1.0819, cover loss of 0.3638, secret loss of 1.0876
# Training: Batch 16/1000. Loss of 1.2312, cover loss of 0.3375, secret loss of 1.4607
# Training: Batch 17/1000. Loss of 0.9801, cover loss of 0.2855, secret loss of 1.1238
# Training: Batch 18/1000. Loss of 1.1081, cover loss of 0.3373, secret loss of 1.2056
# Training: Batch 19/1000. Loss of 1.1373, cover loss of 0.2998, secret loss of 1.3756
# Training: Batch 20/1000. Loss of 1.3113, cover loss of 0.3555, secret loss of 1.6703
# Training: Batch 21/1000. Loss of 1.2113, cover loss of 0.4191, secret loss of 1.1533
# Training: Batch 22/1000. Loss of 1.2084, cover loss of 0.4139, secret loss of 1.1269
# Training: Batch 23/1000. Loss of 1.1759, cover loss of 0.3594, secret loss of 1.2310
# Training: Batch 24/1000. Loss of 1.1173, cover loss of 0.3423, secret loss of 1.2555
# Training: Batch 25/1000. Loss of 1.1323, cover loss of 0.2904, secret loss of 1.3720
# Training: Batch 26/1000. Loss of 1.1041, cover loss of 0.2948, secret loss of 1.3653
# Training: Batch 27/1000. Loss of 1.2265, cover loss of 0.3308, secret loss of 1.4649
# Training: Batch 28/1000. Loss of 1.3324, cover loss of 0.3361, secret loss of 1.6471
# Training: Batch 29/1000. Loss of 1.2152, cover loss of 0.3641, secret loss of 1.3151
# Training: Batch 30/1000. Loss of 1.0860, cover loss of 0.3244, secret loss of 1.2025
# Training: Batch 31/1000. Loss of 1.1646, cover loss of 0.3176, secret loss of 1.3967
# Training: Batch 32/1000. Loss of 1.0887, cover loss of 0.3529, secret loss of 1.1401
# Training: Batch 33/1000. Loss of 0.9933, cover loss of 0.2938, secret loss of 1.1060
# Training: Batch 34/1000. Loss of 1.2315, cover loss of 0.3594, secret loss of 1.4153
# Training: Batch 35/1000. Loss of 1.0114, cover loss of 0.3063, secret loss of 1.1105
# Training: Batch 36/1000. Loss of 1.0830, cover loss of 0.3179, secret loss of 1.2186
# Training: Batch 37/1000. Loss of 1.1363, cover loss of 0.2979, secret loss of 1.3860
# Training: Batch 38/1000. Loss of 1.0666, cover loss of 0.2785, secret loss of 1.3153
# Training: Batch 39/1000. Loss of 1.1623, cover loss of 0.3012, secret loss of 1.4189
# Training: Batch 40/1000. Loss of 1.3223, cover loss of 0.3629, secret loss of 1.5743
# Training: Batch 41/1000. Loss of 1.1115, cover loss of 0.3220, secret loss of 1.2504
# Training: Batch 42/1000. Loss of 0.9119, cover loss of 0.2776, secret loss of 1.0723
# Training: Batch 43/1000. Loss of 1.1867, cover loss of 0.3350, secret loss of 1.3523
# Training: Batch 44/1000. Loss of 1.1434, cover loss of 0.3818, secret loss of 1.1258
# Training: Batch 45/1000. Loss of 1.4468, cover loss of 0.4627, secret loss of 1.5455
# Training: Batch 46/1000. Loss of 1.0986, cover loss of 0.3221, secret loss of 1.2125
# Training: Batch 47/1000. Loss of 1.1134, cover loss of 0.3232, secret loss of 1.2274
# Training: Batch 48/1000. Loss of 1.0835, cover loss of 0.2997, secret loss of 1.2484
# Training: Batch 49/1000. Loss of 1.1227, cover loss of 0.2674, secret loss of 1.4564
# Training: Batch 50/1000. Loss of 1.3341, cover loss of 0.3156, secret loss of 1.7444
# Training: Batch 51/1000. Loss of 0.9057, cover loss of 0.2990, secret loss of 0.9887
# Training: Batch 52/1000. Loss of 1.1478, cover loss of 0.3571, secret loss of 1.2569
# Training: Batch 53/1000. Loss of 1.1350, cover loss of 0.3060, secret loss of 1.3647
# Training: Batch 54/1000. Loss of 1.1629, cover loss of 0.3127, secret loss of 1.4049
# Training: Batch 55/1000. Loss of 1.0631, cover loss of 0.3281, secret loss of 1.1537
# Training: Batch 56/1000. Loss of 1.0928, cover loss of 0.3176, secret loss of 1.2411
# Training: Batch 57/1000. Loss of 1.1454, cover loss of 0.3054, secret loss of 1.3848
# Training: Batch 58/1000. Loss of 1.1888, cover loss of 0.3590, secret loss of 1.3357
# Training: Batch 59/1000. Loss of 1.2383, cover loss of 0.3339, secret loss of 1.5332
# Training: Batch 60/1000. Loss of 1.1887, cover loss of 0.3315, secret loss of 1.4187
# Training: Batch 61/1000. Loss of 1.1715, cover loss of 0.2841, secret loss of 1.5100
# Training: Batch 62/1000. Loss of 1.1939, cover loss of 0.4004, secret loss of 1.2199
# Training: Batch 63/1000. Loss of 1.1514, cover loss of 0.3897, secret loss of 1.1897
# Training: Batch 64/1000. Loss of 1.0989, cover loss of 0.2923, secret loss of 1.3138
# Training: Batch 65/1000. Loss of 1.1597, cover loss of 0.3610, secret loss of 1.2482
# Training: Batch 66/1000. Loss of 0.9641, cover loss of 0.2827, secret loss of 1.0640
# Training: Batch 67/1000. Loss of 1.1018, cover loss of 0.2955, secret loss of 1.3269
# Training: Batch 68/1000. Loss of 1.1718, cover loss of 0.3223, secret loss of 1.3591
# Training: Batch 69/1000. Loss of 1.0783, cover loss of 0.3250, secret loss of 1.1952
# Training: Batch 70/1000. Loss of 1.1956, cover loss of 0.3029, secret loss of 1.4795
# Training: Batch 71/1000. Loss of 1.0790, cover loss of 0.3628, secret loss of 1.0725
# Training: Batch 72/1000. Loss of 1.1798, cover loss of 0.3621, secret loss of 1.3404
# Training: Batch 73/1000. Loss of 0.9993, cover loss of 0.2696, secret loss of 1.1829
# Training: Batch 74/1000. Loss of 1.2506, cover loss of 0.3908, secret loss of 1.3304
# Training: Batch 75/1000. Loss of 1.3435, cover loss of 0.4000, secret loss of 1.4707
# Training: Batch 76/1000. Loss of 1.0768, cover loss of 0.3357, secret loss of 1.1771
# Training: Batch 77/1000. Loss of 1.2012, cover loss of 0.3303, secret loss of 1.4590
# Training: Batch 78/1000. Loss of 1.3614, cover loss of 0.3813, secret loss of 1.5836
# Training: Batch 79/1000. Loss of 1.0642, cover loss of 0.3194, secret loss of 1.1772
# Training: Batch 80/1000. Loss of 1.0831, cover loss of 0.3113, secret loss of 1.2168
# Training: Batch 81/1000. Loss of 1.2646, cover loss of 0.3432, secret loss of 1.4999
# Training: Batch 82/1000. Loss of 0.9705, cover loss of 0.2869, secret loss of 1.0776
# Training: Batch 83/1000. Loss of 1.2277, cover loss of 0.3520, secret loss of 1.4169
# Training: Batch 84/1000. Loss of 1.2188, cover loss of 0.3310, secret loss of 1.4185
# Training: Batch 85/1000. Loss of 1.0201, cover loss of 0.2548, secret loss of 1.2729
# Training: Batch 86/1000. Loss of 1.0455, cover loss of 0.3028, secret loss of 1.2047
# Training: Batch 87/1000. Loss of 1.3945, cover loss of 0.4970, secret loss of 1.3372
# Training: Batch 88/1000. Loss of 1.2180, cover loss of 0.3086, secret loss of 1.6096
# Training: Batch 89/1000. Loss of 1.1119, cover loss of 0.3595, secret loss of 1.1766
# Training: Batch 90/1000. Loss of 1.0648, cover loss of 0.2838, secret loss of 1.3154
# Training: Batch 91/1000. Loss of 1.1124, cover loss of 0.3092, secret loss of 1.2994
# Training: Batch 92/1000. Loss of 1.2674, cover loss of 0.4021, secret loss of 1.4063
# Training: Batch 93/1000. Loss of 1.0466, cover loss of 0.2461, secret loss of 1.3486
# Training: Batch 94/1000. Loss of 1.0825, cover loss of 0.2971, secret loss of 1.2535
# Training: Batch 95/1000. Loss of 1.2335, cover loss of 0.3383, secret loss of 1.4889
# Training: Batch 96/1000. Loss of 1.0503, cover loss of 0.3334, secret loss of 1.2225
# Training: Batch 97/1000. Loss of 1.0169, cover loss of 0.3191, secret loss of 1.0593
# Training: Batch 98/1000. Loss of 1.1372, cover loss of 0.3266, secret loss of 1.2845
# Training: Batch 99/1000. Loss of 1.0322, cover loss of 0.3182, secret loss of 1.0559
# Training: Batch 100/1000. Loss of 1.2225, cover loss of 0.3820, secret loss of 1.2571
# Training: Batch 101/1000. Loss of 1.1501, cover loss of 0.2934, secret loss of 1.3964
# Training: Batch 102/1000. Loss of 1.2404, cover loss of 0.2838, secret loss of 1.6032
# Training: Batch 103/1000. Loss of 1.1260, cover loss of 0.3297, secret loss of 1.2484
# Training: Batch 104/1000. Loss of 1.1228, cover loss of 0.3277, secret loss of 1.2754
# Training: Batch 105/1000. Loss of 0.9802, cover loss of 0.3127, secret loss of 1.0707
# Training: Batch 106/1000. Loss of 1.1693, cover loss of 0.4074, secret loss of 1.2236
# Training: Batch 107/1000. Loss of 1.1584, cover loss of 0.3269, secret loss of 1.3698
# Training: Batch 108/1000. Loss of 1.0275, cover loss of 0.2983, secret loss of 1.1874
# Training: Batch 109/1000. Loss of 1.2988, cover loss of 0.3769, secret loss of 1.4897
# Training: Batch 110/1000. Loss of 1.0748, cover loss of 0.3242, secret loss of 1.2258
# Training: Batch 111/1000. Loss of 1.2377, cover loss of 0.3729, secret loss of 1.3820
# Training: Batch 112/1000. Loss of 0.9581, cover loss of 0.2882, secret loss of 1.0638
# Training: Batch 113/1000. Loss of 1.1111, cover loss of 0.3316, secret loss of 1.2665
# Training: Batch 114/1000. Loss of 1.0665, cover loss of 0.2612, secret loss of 1.3552
# Training: Batch 115/1000. Loss of 1.2277, cover loss of 0.3253, secret loss of 1.4421
# Training: Batch 116/1000. Loss of 1.0861, cover loss of 0.2654, secret loss of 1.3836
# Training: Batch 117/1000. Loss of 1.1379, cover loss of 0.3200, secret loss of 1.3099
# Training: Batch 118/1000. Loss of 1.0573, cover loss of 0.3120, secret loss of 1.1848
# Training: Batch 119/1000. Loss of 1.0807, cover loss of 0.3004, secret loss of 1.3026
# Training: Batch 120/1000. Loss of 1.1953, cover loss of 0.3124, secret loss of 1.4954
# Training: Batch 121/1000. Loss of 1.2339, cover loss of 0.4640, secret loss of 1.2317
# Training: Batch 122/1000. Loss of 1.1712, cover loss of 0.2874, secret loss of 1.5000
# Training: Batch 123/1000. Loss of 1.1760, cover loss of 0.3353, secret loss of 1.3393
# Training: Batch 124/1000. Loss of 1.0623, cover loss of 0.3204, secret loss of 1.1297
# Training: Batch 125/1000. Loss of 1.1751, cover loss of 0.2884, secret loss of 1.4310
# Training: Batch 126/1000. Loss of 1.0902, cover loss of 0.2454, secret loss of 1.4176
# Training: Batch 127/1000. Loss of 1.1627, cover loss of 0.3104, secret loss of 1.3496
# Training: Batch 128/1000. Loss of 1.0340, cover loss of 0.3036, secret loss of 1.1302
# Training: Batch 129/1000. Loss of 0.9929, cover loss of 0.3165, secret loss of 1.0383
# Training: Batch 130/1000. Loss of 1.1810, cover loss of 0.3282, secret loss of 1.3864
# Training: Batch 131/1000. Loss of 1.1681, cover loss of 0.3007, secret loss of 1.4301
# Training: Batch 132/1000. Loss of 1.0771, cover loss of 0.3706, secret loss of 1.0435
# Training: Batch 133/1000. Loss of 1.0231, cover loss of 0.3582, secret loss of 1.0200
# Training: Batch 134/1000. Loss of 1.1148, cover loss of 0.3797, secret loss of 1.1127
# Training: Batch 135/1000. Loss of 1.1535, cover loss of 0.3907, secret loss of 1.1401
# Training: Batch 136/1000. Loss of 1.2361, cover loss of 0.3431, secret loss of 1.4494
# Training: Batch 137/1000. Loss of 1.0303, cover loss of 0.3035, secret loss of 1.1698
# Training: Batch 138/1000. Loss of 1.1142, cover loss of 0.3202, secret loss of 1.2615
# Training: Batch 139/1000. Loss of 1.0671, cover loss of 0.3292, secret loss of 1.1465
# Training: Batch 140/1000. Loss of 1.0678, cover loss of 0.3119, secret loss of 1.1957
# Training: Batch 141/1000. Loss of 1.2705, cover loss of 0.3128, secret loss of 1.6045
# Training: Batch 142/1000. Loss of 1.2839, cover loss of 0.3607, secret loss of 1.5025
# Training: Batch 143/1000. Loss of 1.2394, cover loss of 0.2766, secret loss of 1.6572
# Training: Batch 144/1000. Loss of 1.1640, cover loss of 0.3323, secret loss of 1.3556
# Training: Batch 145/1000. Loss of 1.1534, cover loss of 0.2715, secret loss of 1.4888
# Training: Batch 146/1000. Loss of 1.1509, cover loss of 0.3505, secret loss of 1.2455
# Training: Batch 147/1000. Loss of 0.9673, cover loss of 0.2646, secret loss of 1.1508
# Training: Batch 148/1000. Loss of 1.1649, cover loss of 0.3147, secret loss of 1.3868
# Training: Batch 149/1000. Loss of 1.0414, cover loss of 0.3292, secret loss of 1.0988
# Training: Batch 150/1000. Loss of 1.1173, cover loss of 0.3136, secret loss of 1.3272
# Training: Batch 151/1000. Loss of 0.9649, cover loss of 0.2576, secret loss of 1.1907
# Training: Batch 152/1000. Loss of 1.4357, cover loss of 0.3339, secret loss of 1.8567
# Training: Batch 153/1000. Loss of 1.1331, cover loss of 0.3200, secret loss of 1.2835
# Training: Batch 154/1000. Loss of 1.1002, cover loss of 0.3456, secret loss of 1.1539
# Training: Batch 155/1000. Loss of 1.2393, cover loss of 0.3919, secret loss of 1.2866
# Training: Batch 156/1000. Loss of 1.2316, cover loss of 0.3165, secret loss of 1.5245
# Training: Batch 157/1000. Loss of 1.0657, cover loss of 0.3542, secret loss of 1.0791
# Training: Batch 158/1000. Loss of 1.0420, cover loss of 0.3186, secret loss of 1.1354
# Training: Batch 159/1000. Loss of 1.1243, cover loss of 0.3530, secret loss of 1.2073
# Training: Batch 160/1000. Loss of 1.3003, cover loss of 0.3841, secret loss of 1.4618
# Training: Batch 161/1000. Loss of 1.0362, cover loss of 0.3509, secret loss of 1.0987
# Training: Batch 162/1000. Loss of 1.1894, cover loss of 0.2928, secret loss of 1.4947
# Training: Batch 163/1000. Loss of 1.1265, cover loss of 0.3165, secret loss of 1.3194
# Training: Batch 164/1000. Loss of 1.0625, cover loss of 0.3488, secret loss of 1.0993
# Training: Batch 165/1000. Loss of 1.2316, cover loss of 0.4259, secret loss of 1.2300
# Training: Batch 166/1000. Loss of 1.1171, cover loss of 0.2980, secret loss of 1.3426
# Training: Batch 167/1000. Loss of 1.0334, cover loss of 0.2803, secret loss of 1.2266
# Training: Batch 168/1000. Loss of 1.1808, cover loss of 0.3760, secret loss of 1.2363
# Training: Batch 169/1000. Loss of 1.1730, cover loss of 0.3535, secret loss of 1.2892
# Training: Batch 170/1000. Loss of 1.2861, cover loss of 0.3657, secret loss of 1.5134
# Training: Batch 171/1000. Loss of 1.1988, cover loss of 0.2613, secret loss of 1.6284
# Training: Batch 172/1000. Loss of 1.3522, cover loss of 0.4104, secret loss of 1.5556
# Training: Batch 173/1000. Loss of 1.1968, cover loss of 0.2889, secret loss of 1.5192
# Training: Batch 174/1000. Loss of 1.0873, cover loss of 0.3362, secret loss of 1.1576
# Training: Batch 175/1000. Loss of 1.0254, cover loss of 0.2946, secret loss of 1.1422
# Training: Batch 176/1000. Loss of 0.9327, cover loss of 0.2925, secret loss of 0.9579
# Training: Batch 177/1000. Loss of 1.2794, cover loss of 0.3550, secret loss of 1.4521
# Training: Batch 178/1000. Loss of 1.2240, cover loss of 0.2996, secret loss of 1.5401
# Training: Batch 179/1000. Loss of 1.2376, cover loss of 0.3540, secret loss of 1.4173
# Training: Batch 180/1000. Loss of 1.2642, cover loss of 0.3767, secret loss of 1.4722
# Training: Batch 181/1000. Loss of 0.9800, cover loss of 0.3218, secret loss of 0.9959
# Training: Batch 182/1000. Loss of 1.1749, cover loss of 0.3464, secret loss of 1.3334
# Training: Batch 183/1000. Loss of 1.1976, cover loss of 0.3630, secret loss of 1.3280
# Training: Batch 184/1000. Loss of 1.0964, cover loss of 0.3048, secret loss of 1.2914
# Training: Batch 185/1000. Loss of 1.3262, cover loss of 0.3610, secret loss of 1.5860
# Training: Batch 186/1000. Loss of 1.1062, cover loss of 0.2867, secret loss of 1.3581
# Training: Batch 187/1000. Loss of 1.1055, cover loss of 0.3098, secret loss of 1.3109
# Training: Batch 188/1000. Loss of 0.9857, cover loss of 0.2697, secret loss of 1.1844
# Training: Batch 189/1000. Loss of 1.0208, cover loss of 0.2897, secret loss of 1.1712
# Training: Batch 190/1000. Loss of 1.3215, cover loss of 0.4266, secret loss of 1.3796
# Training: Batch 191/1000. Loss of 1.1180, cover loss of 0.3554, secret loss of 1.2538
# Training: Batch 192/1000. Loss of 1.1755, cover loss of 0.3247, secret loss of 1.4137
# Training: Batch 193/1000. Loss of 1.3255, cover loss of 0.3604, secret loss of 1.5494
# Training: Batch 194/1000. Loss of 0.9633, cover loss of 0.3031, secret loss of 0.9711
# Training: Batch 195/1000. Loss of 1.2147, cover loss of 0.3565, secret loss of 1.3333
# Training: Batch 196/1000. Loss of 1.1729, cover loss of 0.3393, secret loss of 1.2750
# Training: Batch 197/1000. Loss of 1.1955, cover loss of 0.3135, secret loss of 1.4365
# Training: Batch 198/1000. Loss of 1.0791, cover loss of 0.3354, secret loss of 1.1475
# Training: Batch 199/1000. Loss of 0.9112, cover loss of 0.2775, secret loss of 0.9949
# Training: Batch 200/1000. Loss of 1.1102, cover loss of 0.3340, secret loss of 1.2016
# Training: Batch 201/1000. Loss of 1.0573, cover loss of 0.2620, secret loss of 1.3348
# Training: Batch 202/1000. Loss of 1.3281, cover loss of 0.3829, secret loss of 1.5061
# Training: Batch 203/1000. Loss of 1.2574, cover loss of 0.2968, secret loss of 1.6598
# Training: Batch 204/1000. Loss of 1.0465, cover loss of 0.3015, secret loss of 1.1902
# Training: Batch 205/1000. Loss of 1.2354, cover loss of 0.3914, secret loss of 1.3455
# Training: Batch 206/1000. Loss of 0.8679, cover loss of 0.2930, secret loss of 0.8583
# Training: Batch 207/1000. Loss of 1.2030, cover loss of 0.3012, secret loss of 1.5112
# Training: Batch 208/1000. Loss of 0.9704, cover loss of 0.2938, secret loss of 1.0595
# Training: Batch 209/1000. Loss of 1.0035, cover loss of 0.2896, secret loss of 1.1315
# Training: Batch 210/1000. Loss of 1.0123, cover loss of 0.2868, secret loss of 1.1819
# Training: Batch 211/1000. Loss of 1.0776, cover loss of 0.3815, secret loss of 1.0058
# Training: Batch 212/1000. Loss of 1.1221, cover loss of 0.3410, secret loss of 1.2290
# Training: Batch 213/1000. Loss of 1.1008, cover loss of 0.3672, secret loss of 1.1109
# Training: Batch 214/1000. Loss of 1.0695, cover loss of 0.3223, secret loss of 1.1633
# Training: Batch 215/1000. Loss of 1.0700, cover loss of 0.3172, secret loss of 1.1920
# Training: Batch 216/1000. Loss of 1.0105, cover loss of 0.3122, secret loss of 1.0833
# Training: Batch 217/1000. Loss of 1.0979, cover loss of 0.2889, secret loss of 1.3389
# Training: Batch 218/1000. Loss of 1.2821, cover loss of 0.3527, secret loss of 1.5319
# Training: Batch 219/1000. Loss of 1.0477, cover loss of 0.3071, secret loss of 1.2251
# Training: Batch 220/1000. Loss of 1.2158, cover loss of 0.3251, secret loss of 1.4657
# Training: Batch 221/1000. Loss of 1.1524, cover loss of 0.3138, secret loss of 1.3538
# Training: Batch 222/1000. Loss of 1.0764, cover loss of 0.3208, secret loss of 1.2258
# Training: Batch 223/1000. Loss of 1.0249, cover loss of 0.3279, secret loss of 1.1152
# Training: Batch 224/1000. Loss of 1.0019, cover loss of 0.2972, secret loss of 1.1098
# Training: Batch 225/1000. Loss of 1.2358, cover loss of 0.4129, secret loss of 1.2566
# Training: Batch 226/1000. Loss of 1.1943, cover loss of 0.3473, secret loss of 1.3717
# Training: Batch 227/1000. Loss of 1.1738, cover loss of 0.3428, secret loss of 1.2903
# Training: Batch 228/1000. Loss of 1.2692, cover loss of 0.3942, secret loss of 1.3608
# Training: Batch 229/1000. Loss of 1.2279, cover loss of 0.3055, secret loss of 1.5412
# Training: Batch 230/1000. Loss of 1.1461, cover loss of 0.3620, secret loss of 1.2218
# Training: Batch 231/1000. Loss of 1.1434, cover loss of 0.3232, secret loss of 1.2987
# Training: Batch 232/1000. Loss of 1.2478, cover loss of 0.3564, secret loss of 1.4089
# Training: Batch 233/1000. Loss of 1.1558, cover loss of 0.4427, secret loss of 1.0811
# Training: Batch 234/1000. Loss of 1.1805, cover loss of 0.3361, secret loss of 1.3413
# Training: Batch 235/1000. Loss of 1.2258, cover loss of 0.3415, secret loss of 1.4122
# Training: Batch 236/1000. Loss of 1.2684, cover loss of 0.3577, secret loss of 1.4306
# Training: Batch 237/1000. Loss of 1.0886, cover loss of 0.3775, secret loss of 1.0526
# Training: Batch 238/1000. Loss of 1.1464, cover loss of 0.3419, secret loss of 1.2945
# Training: Batch 239/1000. Loss of 1.1311, cover loss of 0.2888, secret loss of 1.3984
# Training: Batch 240/1000. Loss of 1.1016, cover loss of 0.3227, secret loss of 1.2416
# Training: Batch 241/1000. Loss of 1.1441, cover loss of 0.3502, secret loss of 1.3255
# Training: Batch 242/1000. Loss of 1.1819, cover loss of 0.3512, secret loss of 1.3505
# Training: Batch 243/1000. Loss of 1.1545, cover loss of 0.2943, secret loss of 1.4327
# Training: Batch 244/1000. Loss of 0.9077, cover loss of 0.2633, secret loss of 0.9965
# Training: Batch 245/1000. Loss of 1.1935, cover loss of 0.3460, secret loss of 1.4092
# Training: Batch 246/1000. Loss of 1.0997, cover loss of 0.2996, secret loss of 1.2718
# Training: Batch 247/1000. Loss of 1.2269, cover loss of 0.3454, secret loss of 1.4023
# Training: Batch 248/1000. Loss of 1.2133, cover loss of 0.3442, secret loss of 1.3685
# Training: Batch 249/1000. Loss of 1.2081, cover loss of 0.3063, secret loss of 1.5183
# Training: Batch 250/1000. Loss of 1.0365, cover loss of 0.2786, secret loss of 1.2619
# Training: Batch 251/1000. Loss of 1.1916, cover loss of 0.3625, secret loss of 1.3528
# Training: Batch 252/1000. Loss of 1.1802, cover loss of 0.3631, secret loss of 1.2601
# Training: Batch 253/1000. Loss of 0.9758, cover loss of 0.2888, secret loss of 1.0873
# Training: Batch 254/1000. Loss of 1.1742, cover loss of 0.3123, secret loss of 1.4053
# Training: Batch 255/1000. Loss of 1.3077, cover loss of 0.3993, secret loss of 1.4600
# Training: Batch 256/1000. Loss of 1.3605, cover loss of 0.2918, secret loss of 1.8365
# Training: Batch 257/1000. Loss of 1.1056, cover loss of 0.2642, secret loss of 1.4328
# Training: Batch 258/1000. Loss of 1.0413, cover loss of 0.3014, secret loss of 1.2052
# Training: Batch 259/1000. Loss of 1.2387, cover loss of 0.3155, secret loss of 1.5100
# Training: Batch 260/1000. Loss of 1.1646, cover loss of 0.3839, secret loss of 1.1962
# Training: Batch 261/1000. Loss of 1.1689, cover loss of 0.3441, secret loss of 1.3013
# Training: Batch 262/1000. Loss of 1.0977, cover loss of 0.2937, secret loss of 1.3331
# Training: Batch 263/1000. Loss of 1.0305, cover loss of 0.3070, secret loss of 1.1776
# Training: Batch 264/1000. Loss of 1.1417, cover loss of 0.2905, secret loss of 1.4399
# Training: Batch 265/1000. Loss of 1.2477, cover loss of 0.3897, secret loss of 1.3489
# Training: Batch 266/1000. Loss of 0.9592, cover loss of 0.2741, secret loss of 1.1163
# Training: Batch 267/1000. Loss of 1.0588, cover loss of 0.2762, secret loss of 1.2878
# Training: Batch 268/1000. Loss of 1.0407, cover loss of 0.2867, secret loss of 1.2160
# Training: Batch 269/1000. Loss of 1.1405, cover loss of 0.2873, secret loss of 1.4275
# Training: Batch 270/1000. Loss of 1.1835, cover loss of 0.2967, secret loss of 1.4818
# Training: Batch 271/1000. Loss of 1.0503, cover loss of 0.2944, secret loss of 1.2270
# Training: Batch 272/1000. Loss of 1.1516, cover loss of 0.3625, secret loss of 1.2907
# Training: Batch 273/1000. Loss of 1.1916, cover loss of 0.3209, secret loss of 1.4363
# Training: Batch 274/1000. Loss of 1.2660, cover loss of 0.3564, secret loss of 1.4691
# Training: Batch 275/1000. Loss of 1.3923, cover loss of 0.3628, secret loss of 1.7610
# Training: Batch 276/1000. Loss of 0.9740, cover loss of 0.2522, secret loss of 1.1936
# Training: Batch 277/1000. Loss of 0.9785, cover loss of 0.3076, secret loss of 1.0461
# Training: Batch 278/1000. Loss of 1.0565, cover loss of 0.2856, secret loss of 1.2587
# Training: Batch 279/1000. Loss of 1.2502, cover loss of 0.3361, secret loss of 1.4877
# Training: Batch 280/1000. Loss of 1.1624, cover loss of 0.3070, secret loss of 1.3943
# Training: Batch 281/1000. Loss of 1.1406, cover loss of 0.3121, secret loss of 1.3827
# Training: Batch 282/1000. Loss of 1.1615, cover loss of 0.3289, secret loss of 1.3515
# Training: Batch 283/1000. Loss of 1.0417, cover loss of 0.3063, secret loss of 1.1717
# Training: Batch 284/1000. Loss of 1.0763, cover loss of 0.3069, secret loss of 1.2732
# Training: Batch 285/1000. Loss of 1.2854, cover loss of 0.3462, secret loss of 1.5901
# Training: Batch 286/1000. Loss of 1.0509, cover loss of 0.3105, secret loss of 1.1343
# Training: Batch 287/1000. Loss of 1.1247, cover loss of 0.2933, secret loss of 1.3824
# Training: Batch 288/1000. Loss of 1.2475, cover loss of 0.3111, secret loss of 1.5181
# Training: Batch 289/1000. Loss of 1.0014, cover loss of 0.2940, secret loss of 1.1059
# Training: Batch 290/1000. Loss of 1.0838, cover loss of 0.3579, secret loss of 1.0936
# Training: Batch 291/1000. Loss of 1.0562, cover loss of 0.2726, secret loss of 1.2840
# Training: Batch 292/1000. Loss of 1.1893, cover loss of 0.3603, secret loss of 1.3242
# Training: Batch 293/1000. Loss of 1.1513, cover loss of 0.3708, secret loss of 1.1664
# Training: Batch 294/1000. Loss of 1.1516, cover loss of 0.2870, secret loss of 1.4345
# Training: Batch 295/1000. Loss of 1.3148, cover loss of 0.3763, secret loss of 1.4926
# Training: Batch 296/1000. Loss of 1.0663, cover loss of 0.2956, secret loss of 1.2371
# Training: Batch 297/1000. Loss of 1.1328, cover loss of 0.3487, secret loss of 1.2175
# Training: Batch 298/1000. Loss of 1.0797, cover loss of 0.3681, secret loss of 1.1020
# Training: Batch 299/1000. Loss of 1.1885, cover loss of 0.3470, secret loss of 1.3402
# Training: Batch 300/1000. Loss of 1.0501, cover loss of 0.3069, secret loss of 1.1970
# Training: Batch 301/1000. Loss of 1.1769, cover loss of 0.3100, secret loss of 1.4550
# Training: Batch 302/1000. Loss of 1.2065, cover loss of 0.3105, secret loss of 1.4838
# Training: Batch 303/1000. Loss of 1.0516, cover loss of 0.3322, secret loss of 1.1767
# Training: Batch 304/1000. Loss of 1.2891, cover loss of 0.3267, secret loss of 1.6231
# Training: Batch 305/1000. Loss of 1.0947, cover loss of 0.3122, secret loss of 1.2476
# Training: Batch 306/1000. Loss of 1.1269, cover loss of 0.3486, secret loss of 1.1955
# Training: Batch 307/1000. Loss of 1.0066, cover loss of 0.2975, secret loss of 1.1402
# Training: Batch 308/1000. Loss of 1.2625, cover loss of 0.3410, secret loss of 1.4821
# Training: Batch 309/1000. Loss of 1.2372, cover loss of 0.3158, secret loss of 1.5088
# Training: Batch 310/1000. Loss of 1.2789, cover loss of 0.3447, secret loss of 1.4970
# Training: Batch 311/1000. Loss of 1.0566, cover loss of 0.2853, secret loss of 1.2345
# Training: Batch 312/1000. Loss of 1.2390, cover loss of 0.3162, secret loss of 1.5195
# Training: Batch 313/1000. Loss of 1.2996, cover loss of 0.3497, secret loss of 1.5955
# Training: Batch 314/1000. Loss of 1.1076, cover loss of 0.2884, secret loss of 1.3443
# Training: Batch 315/1000. Loss of 1.2549, cover loss of 0.3466, secret loss of 1.4626
# Training: Batch 316/1000. Loss of 1.0651, cover loss of 0.3601, secret loss of 1.0772
# Training: Batch 317/1000. Loss of 1.0627, cover loss of 0.3118, secret loss of 1.1898
# Training: Batch 318/1000. Loss of 1.1686, cover loss of 0.3990, secret loss of 1.1289
# Training: Batch 319/1000. Loss of 1.0558, cover loss of 0.3046, secret loss of 1.1769
# Training: Batch 320/1000. Loss of 1.0243, cover loss of 0.2620, secret loss of 1.2521
# Training: Batch 321/1000. Loss of 1.2677, cover loss of 0.3805, secret loss of 1.4087
# Training: Batch 322/1000. Loss of 1.1576, cover loss of 0.2714, secret loss of 1.5246
# Training: Batch 323/1000. Loss of 1.1673, cover loss of 0.3455, secret loss of 1.3234
# Training: Batch 324/1000. Loss of 1.4618, cover loss of 0.4719, secret loss of 1.6223
# Training: Batch 325/1000. Loss of 1.1533, cover loss of 0.3836, secret loss of 1.2255
# Training: Batch 326/1000. Loss of 1.1332, cover loss of 0.3030, secret loss of 1.3773
# Training: Batch 327/1000. Loss of 1.0594, cover loss of 0.3980, secret loss of 0.9469
# Training: Batch 328/1000. Loss of 1.1143, cover loss of 0.3528, secret loss of 1.1961
# Training: Batch 329/1000. Loss of 1.2611, cover loss of 0.3488, secret loss of 1.4717
# Training: Batch 330/1000. Loss of 1.3079, cover loss of 0.3920, secret loss of 1.3732
# Training: Batch 331/1000. Loss of 1.3283, cover loss of 0.2964, secret loss of 1.7686
# Training: Batch 332/1000. Loss of 0.9855, cover loss of 0.2951, secret loss of 1.1061
# Training: Batch 333/1000. Loss of 1.0593, cover loss of 0.2842, secret loss of 1.2404
# Training: Batch 334/1000. Loss of 1.2606, cover loss of 0.3534, secret loss of 1.5147
# Training: Batch 335/1000. Loss of 1.1021, cover loss of 0.3477, secret loss of 1.2722
# Training: Batch 336/1000. Loss of 1.0342, cover loss of 0.2952, secret loss of 1.2382
# Training: Batch 337/1000. Loss of 1.1623, cover loss of 0.3323, secret loss of 1.3720
# Training: Batch 338/1000. Loss of 1.0932, cover loss of 0.3432, secret loss of 1.2044
# Training: Batch 339/1000. Loss of 1.1298, cover loss of 0.3388, secret loss of 1.3326
# Training: Batch 340/1000. Loss of 1.1322, cover loss of 0.3061, secret loss of 1.3784
# Training: Batch 341/1000. Loss of 1.0350, cover loss of 0.2459, secret loss of 1.3093
# Training: Batch 342/1000. Loss of 1.1222, cover loss of 0.3102, secret loss of 1.2789
# Training: Batch 343/1000. Loss of 1.0712, cover loss of 0.2826, secret loss of 1.2679
# Training: Batch 344/1000. Loss of 1.0623, cover loss of 0.3594, secret loss of 1.0377
# Training: Batch 345/1000. Loss of 1.1752, cover loss of 0.3287, secret loss of 1.3372
# Training: Batch 346/1000. Loss of 1.1235, cover loss of 0.3690, secret loss of 1.1178
# Training: Batch 347/1000. Loss of 1.3140, cover loss of 0.4641, secret loss of 1.2310
# Training: Batch 348/1000. Loss of 1.1688, cover loss of 0.3249, secret loss of 1.3595
# Training: Batch 349/1000. Loss of 1.1264, cover loss of 0.3508, secret loss of 1.2067
# Training: Batch 350/1000. Loss of 1.0428, cover loss of 0.3189, secret loss of 1.1309
# Training: Batch 351/1000. Loss of 1.1946, cover loss of 0.2914, secret loss of 1.5144
# Training: Batch 352/1000. Loss of 1.0099, cover loss of 0.3271, secret loss of 1.0481
# Training: Batch 353/1000. Loss of 1.3694, cover loss of 0.4069, secret loss of 1.5901
# Training: Batch 354/1000. Loss of 1.2403, cover loss of 0.3418, secret loss of 1.4803
# Training: Batch 355/1000. Loss of 1.1631, cover loss of 0.3917, secret loss of 1.1808
# Training: Batch 356/1000. Loss of 1.1890, cover loss of 0.3439, secret loss of 1.3891
# Training: Batch 357/1000. Loss of 1.0572, cover loss of 0.3636, secret loss of 1.1292
# Training: Batch 358/1000. Loss of 1.1325, cover loss of 0.2969, secret loss of 1.4288
# Training: Batch 359/1000. Loss of 1.1468, cover loss of 0.3136, secret loss of 1.3828
# Training: Batch 360/1000. Loss of 1.2408, cover loss of 0.3320, secret loss of 1.5157
# Training: Batch 361/1000. Loss of 1.0862, cover loss of 0.3199, secret loss of 1.2163
# Training: Batch 362/1000. Loss of 1.0638, cover loss of 0.2758, secret loss of 1.2932
# Training: Batch 363/1000. Loss of 0.9826, cover loss of 0.2669, secret loss of 1.1570
# Training: Batch 364/1000. Loss of 1.1766, cover loss of 0.2774, secret loss of 1.5099
# Training: Batch 365/1000. Loss of 1.0275, cover loss of 0.3391, secret loss of 1.0823
# Training: Batch 366/1000. Loss of 0.9711, cover loss of 0.3088, secret loss of 0.9872
# Training: Batch 367/1000. Loss of 1.2291, cover loss of 0.4011, secret loss of 1.2334
# Training: Batch 368/1000. Loss of 1.0393, cover loss of 0.3019, secret loss of 1.1669
# Training: Batch 369/1000. Loss of 1.0409, cover loss of 0.3114, secret loss of 1.1456
# Training: Batch 370/1000. Loss of 1.0764, cover loss of 0.3227, secret loss of 1.2022
# Training: Batch 371/1000. Loss of 1.0235, cover loss of 0.3028, secret loss of 1.1497
# Training: Batch 372/1000. Loss of 1.1845, cover loss of 0.3269, secret loss of 1.4250
# Training: Batch 373/1000. Loss of 1.2250, cover loss of 0.3484, secret loss of 1.4117
# Training: Batch 374/1000. Loss of 1.2298, cover loss of 0.3520, secret loss of 1.3981
# Training: Batch 375/1000. Loss of 1.1209, cover loss of 0.3705, secret loss of 1.1200
# Training: Batch 376/1000. Loss of 1.0897, cover loss of 0.3390, secret loss of 1.1529
# Training: Batch 377/1000. Loss of 0.9520, cover loss of 0.3083, secret loss of 0.9998
# Training: Batch 378/1000. Loss of 1.1174, cover loss of 0.3597, secret loss of 1.2421
# Training: Batch 379/1000. Loss of 1.4308, cover loss of 0.3109, secret loss of 1.9334
# Training: Batch 380/1000. Loss of 1.1920, cover loss of 0.3293, secret loss of 1.3980
# Training: Batch 381/1000. Loss of 1.0342, cover loss of 0.3106, secret loss of 1.1301
# Training: Batch 382/1000. Loss of 1.2114, cover loss of 0.3113, secret loss of 1.4933
# Training: Batch 383/1000. Loss of 1.1136, cover loss of 0.2741, secret loss of 1.4426
# Training: Batch 384/1000. Loss of 1.0977, cover loss of 0.3232, secret loss of 1.2277
# Training: Batch 385/1000. Loss of 1.0452, cover loss of 0.3106, secret loss of 1.1773
# Training: Batch 386/1000. Loss of 0.9951, cover loss of 0.3073, secret loss of 1.0781
# Training: Batch 387/1000. Loss of 1.1941, cover loss of 0.4106, secret loss of 1.2036
# Training: Batch 388/1000. Loss of 1.3856, cover loss of 0.4870, secret loss of 1.4488
# Training: Batch 389/1000. Loss of 1.1282, cover loss of 0.3254, secret loss of 1.2414
# Training: Batch 390/1000. Loss of 1.1188, cover loss of 0.3339, secret loss of 1.1716
# Training: Batch 391/1000. Loss of 1.2593, cover loss of 0.3365, secret loss of 1.4365
# Training: Batch 392/1000. Loss of 1.0473, cover loss of 0.3251, secret loss of 1.0678
# Training: Batch 393/1000. Loss of 1.0751, cover loss of 0.2413, secret loss of 1.4340
# Training: Batch 394/1000. Loss of 1.1363, cover loss of 0.3192, secret loss of 1.3312
# Training: Batch 395/1000. Loss of 1.1238, cover loss of 0.2682, secret loss of 1.4774
# Training: Batch 396/1000. Loss of 1.0141, cover loss of 0.2942, secret loss of 1.2577
# Training: Batch 397/1000. Loss of 1.0510, cover loss of 0.3100, secret loss of 1.2158
# Training: Batch 398/1000. Loss of 1.2184, cover loss of 0.3824, secret loss of 1.3337
# Training: Batch 399/1000. Loss of 1.1281, cover loss of 0.3136, secret loss of 1.3535
# Training: Batch 400/1000. Loss of 1.1712, cover loss of 0.3127, secret loss of 1.4298
# Training: Batch 401/1000. Loss of 1.0801, cover loss of 0.3117, secret loss of 1.2548
# Training: Batch 402/1000. Loss of 1.1062, cover loss of 0.3113, secret loss of 1.2856
# Training: Batch 403/1000. Loss of 1.2198, cover loss of 0.3561, secret loss of 1.3774
# Training: Batch 404/1000. Loss of 1.1728, cover loss of 0.3569, secret loss of 1.3103
# Training: Batch 405/1000. Loss of 1.2436, cover loss of 0.2789, secret loss of 1.6430
# Training: Batch 406/1000. Loss of 1.1592, cover loss of 0.3115, secret loss of 1.3764
# Training: Batch 407/1000. Loss of 1.2455, cover loss of 0.3187, secret loss of 1.5224
# Training: Batch 408/1000. Loss of 1.0827, cover loss of 0.3474, secret loss of 1.1288
# Training: Batch 409/1000. Loss of 1.3215, cover loss of 0.3287, secret loss of 1.6607
# Training: Batch 410/1000. Loss of 1.1401, cover loss of 0.3124, secret loss of 1.3529
# Training: Batch 411/1000. Loss of 1.3378, cover loss of 0.3736, secret loss of 1.5583
# Training: Batch 412/1000. Loss of 1.3133, cover loss of 0.3151, secret loss of 1.6716
# Training: Batch 413/1000. Loss of 1.1594, cover loss of 0.3159, secret loss of 1.3657
# Training: Batch 414/1000. Loss of 1.1656, cover loss of 0.3134, secret loss of 1.3882
# Training: Batch 415/1000. Loss of 1.0314, cover loss of 0.3166, secret loss of 1.1005
# Training: Batch 416/1000. Loss of 1.2191, cover loss of 0.3074, secret loss of 1.5050
# Training: Batch 417/1000. Loss of 1.1027, cover loss of 0.3023, secret loss of 1.3153
# Training: Batch 418/1000. Loss of 1.2008, cover loss of 0.3681, secret loss of 1.3067
# Training: Batch 419/1000. Loss of 1.3219, cover loss of 0.3367, secret loss of 1.7358
# Training: Batch 420/1000. Loss of 1.1597, cover loss of 0.3189, secret loss of 1.3687
# Training: Batch 421/1000. Loss of 1.1413, cover loss of 0.3821, secret loss of 1.1479
# Training: Batch 422/1000. Loss of 1.0783, cover loss of 0.3478, secret loss of 1.1127
# Training: Batch 423/1000. Loss of 1.2775, cover loss of 0.3408, secret loss of 1.5355
# Training: Batch 424/1000. Loss of 1.2454, cover loss of 0.3410, secret loss of 1.4468
# Training: Batch 425/1000. Loss of 1.0236, cover loss of 0.2942, secret loss of 1.1517
# Training: Batch 426/1000. Loss of 1.1449, cover loss of 0.3455, secret loss of 1.2505
# Training: Batch 427/1000. Loss of 1.1081, cover loss of 0.2524, secret loss of 1.4467
# Training: Batch 428/1000. Loss of 1.2700, cover loss of 0.3520, secret loss of 1.5272
# Training: Batch 429/1000. Loss of 1.0237, cover loss of 0.3114, secret loss of 1.1238
# Training: Batch 430/1000. Loss of 1.5113, cover loss of 0.4428, secret loss of 1.7706
# Training: Batch 431/1000. Loss of 1.1847, cover loss of 0.2938, secret loss of 1.5150
# Training: Batch 432/1000. Loss of 1.1321, cover loss of 0.2693, secret loss of 1.5087
# Training: Batch 433/1000. Loss of 1.1538, cover loss of 0.3345, secret loss of 1.3376
# Training: Batch 434/1000. Loss of 1.0500, cover loss of 0.3685, secret loss of 1.0048
# Training: Batch 435/1000. Loss of 1.0855, cover loss of 0.3115, secret loss of 1.2334
# Training: Batch 436/1000. Loss of 1.1205, cover loss of 0.3243, secret loss of 1.2572
# Training: Batch 437/1000. Loss of 1.0508, cover loss of 0.2907, secret loss of 1.2279
# Training: Batch 438/1000. Loss of 1.0168, cover loss of 0.3665, secret loss of 0.9637
# Training: Batch 439/1000. Loss of 1.3657, cover loss of 0.4390, secret loss of 1.5099
# Training: Batch 440/1000. Loss of 1.0971, cover loss of 0.3320, secret loss of 1.1793
# Training: Batch 441/1000. Loss of 1.1223, cover loss of 0.3442, secret loss of 1.2062
# Training: Batch 442/1000. Loss of 1.2638, cover loss of 0.3457, secret loss of 1.5126
# Training: Batch 443/1000. Loss of 1.0958, cover loss of 0.3285, secret loss of 1.2059
# Training: Batch 444/1000. Loss of 1.0884, cover loss of 0.3192, secret loss of 1.2459
# Training: Batch 445/1000. Loss of 1.1056, cover loss of 0.3500, secret loss of 1.2054
# Training: Batch 446/1000. Loss of 1.1821, cover loss of 0.3075, secret loss of 1.4344
# Training: Batch 447/1000. Loss of 1.0360, cover loss of 0.3235, secret loss of 1.0931
# Training: Batch 448/1000. Loss of 1.1002, cover loss of 0.3145, secret loss of 1.2539
# Training: Batch 449/1000. Loss of 1.1054, cover loss of 0.3105, secret loss of 1.3216
# Training: Batch 450/1000. Loss of 1.1364, cover loss of 0.3664, secret loss of 1.1991
# Training: Batch 451/1000. Loss of 1.2513, cover loss of 0.3606, secret loss of 1.4753
# Training: Batch 452/1000. Loss of 1.2573, cover loss of 0.3607, secret loss of 1.4414
# Training: Batch 453/1000. Loss of 1.0641, cover loss of 0.3367, secret loss of 1.1283
# Training: Batch 454/1000. Loss of 1.3005, cover loss of 0.3675, secret loss of 1.5107
# Training: Batch 455/1000. Loss of 1.1733, cover loss of 0.3329, secret loss of 1.3947
# Training: Batch 456/1000. Loss of 1.1083, cover loss of 0.2790, secret loss of 1.3733
# Training: Batch 457/1000. Loss of 1.0299, cover loss of 0.2875, secret loss of 1.1942
# Training: Batch 458/1000. Loss of 1.1121, cover loss of 0.3808, secret loss of 1.1179
# Training: Batch 459/1000. Loss of 1.2265, cover loss of 0.3297, secret loss of 1.4592
# Training: Batch 460/1000. Loss of 1.1604, cover loss of 0.3306, secret loss of 1.3509
# Training: Batch 461/1000. Loss of 1.1609, cover loss of 0.2995, secret loss of 1.4328
# Training: Batch 462/1000. Loss of 0.9816, cover loss of 0.2849, secret loss of 1.1036
# Training: Batch 463/1000. Loss of 1.0849, cover loss of 0.3299, secret loss of 1.1526
# Training: Batch 464/1000. Loss of 1.1878, cover loss of 0.2678, secret loss of 1.5709
# Training: Batch 465/1000. Loss of 1.2015, cover loss of 0.3417, secret loss of 1.3824
# Training: Batch 466/1000. Loss of 1.1502, cover loss of 0.3305, secret loss of 1.3197
# Training: Batch 467/1000. Loss of 1.0843, cover loss of 0.3253, secret loss of 1.1888
# Training: Batch 468/1000. Loss of 1.0266, cover loss of 0.3236, secret loss of 1.0771
# Training: Batch 469/1000. Loss of 1.0365, cover loss of 0.3090, secret loss of 1.1486
# Training: Batch 470/1000. Loss of 1.1463, cover loss of 0.3616, secret loss of 1.2240
# Training: Batch 471/1000. Loss of 1.2357, cover loss of 0.3072, secret loss of 1.5582
# Training: Batch 472/1000. Loss of 1.1015, cover loss of 0.3215, secret loss of 1.2360
# Training: Batch 473/1000. Loss of 1.1485, cover loss of 0.3273, secret loss of 1.3213
# Training: Batch 474/1000. Loss of 1.3688, cover loss of 0.3359, secret loss of 1.7583
# Training: Batch 475/1000. Loss of 1.2026, cover loss of 0.3703, secret loss of 1.3102
# Training: Batch 476/1000. Loss of 1.0396, cover loss of 0.2754, secret loss of 1.2677
# Training: Batch 477/1000. Loss of 0.9741, cover loss of 0.2834, secret loss of 1.0889
# Training: Batch 478/1000. Loss of 1.2512, cover loss of 0.3347, secret loss of 1.4930
# Training: Batch 479/1000. Loss of 1.0680, cover loss of 0.2901, secret loss of 1.2552
# Training: Batch 480/1000. Loss of 1.2163, cover loss of 0.2746, secret loss of 1.5921
# Training: Batch 481/1000. Loss of 1.2636, cover loss of 0.2967, secret loss of 1.6178
# Training: Batch 482/1000. Loss of 1.0963, cover loss of 0.4305, secret loss of 1.0795
# Training: Batch 483/1000. Loss of 1.3089, cover loss of 0.3729, secret loss of 1.4777
# Training: Batch 484/1000. Loss of 1.2966, cover loss of 0.3429, secret loss of 1.5842
# Training: Batch 485/1000. Loss of 1.1821, cover loss of 0.3275, secret loss of 1.3936
# Training: Batch 486/1000. Loss of 1.0580, cover loss of 0.2991, secret loss of 1.2151
# Training: Batch 487/1000. Loss of 1.2908, cover loss of 0.2930, secret loss of 1.6821
# Training: Batch 488/1000. Loss of 1.1219, cover loss of 0.3201, secret loss of 1.2346
# Training: Batch 489/1000. Loss of 1.0616, cover loss of 0.3009, secret loss of 1.2256
# Training: Batch 490/1000. Loss of 1.1517, cover loss of 0.3206, secret loss of 1.3814
# Training: Batch 491/1000. Loss of 1.2308, cover loss of 0.3294, secret loss of 1.4595
# Training: Batch 492/1000. Loss of 1.1731, cover loss of 0.3795, secret loss of 1.1871
# Training: Batch 493/1000. Loss of 1.3110, cover loss of 0.3672, secret loss of 1.5234
# Training: Batch 494/1000. Loss of 1.1255, cover loss of 0.3588, secret loss of 1.2178
# Training: Batch 495/1000. Loss of 1.1852, cover loss of 0.3714, secret loss of 1.3200
# Training: Batch 496/1000. Loss of 1.2736, cover loss of 0.4287, secret loss of 1.3338
# Training: Batch 497/1000. Loss of 1.1082, cover loss of 0.3442, secret loss of 1.2385
# Training: Batch 498/1000. Loss of 1.2197, cover loss of 0.3794, secret loss of 1.3886
# Training: Batch 499/1000. Loss of 1.1816, cover loss of 0.3635, secret loss of 1.3098
# Training: Batch 500/1000. Loss of 1.2173, cover loss of 0.4249, secret loss of 1.1735
# Training: Batch 501/1000. Loss of 1.0166, cover loss of 0.3022, secret loss of 1.1566
# Training: Batch 502/1000. Loss of 1.1495, cover loss of 0.2959, secret loss of 1.3839
# Training: Batch 503/1000. Loss of 1.1478, cover loss of 0.2775, secret loss of 1.4652
# Training: Batch 504/1000. Loss of 0.9183, cover loss of 0.2679, secret loss of 1.0181
# Training: Batch 505/1000. Loss of 0.9513, cover loss of 0.2664, secret loss of 1.0848
# Training: Batch 506/1000. Loss of 1.1008, cover loss of 0.3103, secret loss of 1.2261
# Training: Batch 507/1000. Loss of 1.2457, cover loss of 0.2956, secret loss of 1.5762
# Training: Batch 508/1000. Loss of 1.3154, cover loss of 0.3752, secret loss of 1.5631
# Training: Batch 509/1000. Loss of 1.1985, cover loss of 0.3626, secret loss of 1.2980
# Training: Batch 510/1000. Loss of 1.1805, cover loss of 0.3333, secret loss of 1.3723
# Training: Batch 511/1000. Loss of 0.9664, cover loss of 0.2656, secret loss of 1.1424
# Training: Batch 512/1000. Loss of 1.2806, cover loss of 0.3558, secret loss of 1.5778
# Training: Batch 513/1000. Loss of 1.0687, cover loss of 0.3182, secret loss of 1.2130
# Training: Batch 514/1000. Loss of 1.2597, cover loss of 0.3301, secret loss of 1.5369
# Training: Batch 515/1000. Loss of 1.2892, cover loss of 0.3951, secret loss of 1.4028
# Training: Batch 516/1000. Loss of 1.0729, cover loss of 0.3331, secret loss of 1.1549
# Training: Batch 517/1000. Loss of 1.1920, cover loss of 0.3802, secret loss of 1.2724
# Training: Batch 518/1000. Loss of 1.2507, cover loss of 0.3607, secret loss of 1.4688
# Training: Batch 519/1000. Loss of 1.1980, cover loss of 0.3355, secret loss of 1.4068
# Training: Batch 520/1000. Loss of 1.0387, cover loss of 0.2792, secret loss of 1.2676
# Training: Batch 521/1000. Loss of 1.0570, cover loss of 0.3005, secret loss of 1.2181
# Training: Batch 522/1000. Loss of 1.1094, cover loss of 0.3531, secret loss of 1.1568
# Training: Batch 523/1000. Loss of 1.2035, cover loss of 0.3212, secret loss of 1.4292
# Training: Batch 524/1000. Loss of 1.0727, cover loss of 0.3208, secret loss of 1.1625
# Training: Batch 525/1000. Loss of 1.2034, cover loss of 0.3793, secret loss of 1.2771
# Training: Batch 526/1000. Loss of 1.0138, cover loss of 0.2628, secret loss of 1.2269
# Training: Batch 527/1000. Loss of 1.2314, cover loss of 0.3882, secret loss of 1.2972
# Training: Batch 528/1000. Loss of 0.9616, cover loss of 0.2947, secret loss of 1.0541
# Training: Batch 529/1000. Loss of 1.0396, cover loss of 0.3009, secret loss of 1.1831
# Training: Batch 530/1000. Loss of 1.1304, cover loss of 0.2886, secret loss of 1.4212
# Training: Batch 531/1000. Loss of 1.0467, cover loss of 0.3147, secret loss of 1.1633
# Training: Batch 532/1000. Loss of 0.9110, cover loss of 0.2853, secret loss of 0.9762
# Training: Batch 533/1000. Loss of 1.2806, cover loss of 0.4370, secret loss of 1.2672
# Training: Batch 534/1000. Loss of 1.0724, cover loss of 0.2988, secret loss of 1.2747
# Training: Batch 535/1000. Loss of 1.0961, cover loss of 0.3140, secret loss of 1.2676
# Training: Batch 536/1000. Loss of 0.9515, cover loss of 0.3180, secret loss of 0.9616
# Training: Batch 537/1000. Loss of 1.1308, cover loss of 0.2893, secret loss of 1.4057
# Training: Batch 538/1000. Loss of 1.1771, cover loss of 0.3895, secret loss of 1.2048
# Training: Batch 539/1000. Loss of 1.2181, cover loss of 0.3190, secret loss of 1.4912
# Training: Batch 540/1000. Loss of 1.1188, cover loss of 0.3884, secret loss of 1.0615
# Training: Batch 541/1000. Loss of 1.1122, cover loss of 0.3226, secret loss of 1.2795
# Training: Batch 542/1000. Loss of 1.0930, cover loss of 0.2912, secret loss of 1.3072
# Training: Batch 543/1000. Loss of 1.3156, cover loss of 0.3938, secret loss of 1.4367
# Training: Batch 544/1000. Loss of 1.1474, cover loss of 0.2818, secret loss of 1.4400
# Training: Batch 545/1000. Loss of 1.3026, cover loss of 0.3705, secret loss of 1.4886
# Training: Batch 546/1000. Loss of 1.1688, cover loss of 0.3370, secret loss of 1.3299
# Training: Batch 547/1000. Loss of 1.1580, cover loss of 0.2939, secret loss of 1.4531
# Training: Batch 548/1000. Loss of 1.1704, cover loss of 0.3114, secret loss of 1.4290
# Training: Batch 549/1000. Loss of 1.0698, cover loss of 0.2691, secret loss of 1.3514
# Training: Batch 550/1000. Loss of 1.2152, cover loss of 0.3695, secret loss of 1.3372
# Training: Batch 551/1000. Loss of 0.9960, cover loss of 0.3337, secret loss of 0.9964
# Training: Batch 552/1000. Loss of 1.2537, cover loss of 0.3541, secret loss of 1.4362
# Training: Batch 553/1000. Loss of 1.0675, cover loss of 0.3090, secret loss of 1.2092
# Training: Batch 554/1000. Loss of 1.0089, cover loss of 0.3026, secret loss of 1.1117
# Training: Batch 555/1000. Loss of 1.0802, cover loss of 0.2932, secret loss of 1.2786
# Training: Batch 556/1000. Loss of 1.0234, cover loss of 0.3397, secret loss of 1.0391
# Training: Batch 557/1000. Loss of 1.1074, cover loss of 0.3007, secret loss of 1.3171
# Training: Batch 558/1000. Loss of 1.0703, cover loss of 0.3165, secret loss of 1.1936
# Training: Batch 559/1000. Loss of 1.0785, cover loss of 0.2982, secret loss of 1.3234
# Training: Batch 560/1000. Loss of 1.0594, cover loss of 0.2708, secret loss of 1.3391
# Training: Batch 561/1000. Loss of 1.1528, cover loss of 0.3578, secret loss of 1.2422
# Training: Batch 562/1000. Loss of 1.2422, cover loss of 0.3763, secret loss of 1.3443
# ...
# Training: Batch 816/1000. Loss of 1.3518, cover loss of 0.3859, secret loss of 1.5589
# Training: Batch 817/1000. Loss of 1.0967, cover loss of 0.3140, secret loss of 1.2483
# Training: Batch 818/1000. Loss of 1.1144, cover loss of 0.3374, secret loss of 1.2628
# Training: Batch 819/1000. Loss of 1.1941, cover loss of 0.2967, secret loss of 1.4977
# Training: Batch 820/1000. Loss of 1.1513, cover loss of 0.3067, secret loss of 1.3969
# Training: Batch 821/1000. Loss of 1.2613, cover loss of 0.3731, secret loss of 1.3998
# Training: Batch 822/1000. Loss of 1.0938, cover loss of 0.2687, secret loss of 1.3971
# Training: Batch 823/1000. Loss of 1.0826, cover loss of 0.2700, secret loss of 1.3562
# Training: Batch 824/1000. Loss of 1.0972, cover loss of 0.3267, secret loss of 1.1995
# Training: Batch 825/1000. Loss of 1.1338, cover loss of 0.4129, secret loss of 1.0303
# Training: Batch 826/1000. Loss of 1.1437, cover loss of 0.3643, secret loss of 1.2132
# Training: Batch 827/1000. Loss of 1.2254, cover loss of 0.3826, secret loss of 1.2972
# Training: Batch 828/1000. Loss of 1.1019, cover loss of 0.3369, secret loss of 1.1921
# Training: Batch 829/1000. Loss of 0.9802, cover loss of 0.3101, secret loss of 1.0503
# Training: Batch 830/1000. Loss of 1.0972, cover loss of 0.3152, secret loss of 1.2690
# Training: Batch 831/1000. Loss of 1.0153, cover loss of 0.3311, secret loss of 1.0546
# Training: Batch 832/1000. Loss of 1.0494, cover loss of 0.2993, secret loss of 1.2207
# Training: Batch 833/1000. Loss of 0.9113, cover loss of 0.2565, secret loss of 1.0608
# Training: Batch 834/1000. Loss of 1.0638, cover loss of 0.3493, secret loss of 1.0659
# Training: Batch 835/1000. Loss of 0.9547, cover loss of 0.2524, secret loss of 1.1401
# Training: Batch 836/1000. Loss of 1.1293, cover loss of 0.3004, secret loss of 1.3470
# Training: Batch 837/1000. Loss of 1.1103, cover loss of 0.3613, secret loss of 1.1275
# Training: Batch 838/1000. Loss of 1.1756, cover loss of 0.3024, secret loss of 1.4507
# Training: Batch 839/1000. Loss of 1.1843, cover loss of 0.3631, secret loss of 1.2616
# Training: Batch 840/1000. Loss of 1.2864, cover loss of 0.3901, secret loss of 1.4352
# Training: Batch 841/1000. Loss of 1.2107, cover loss of 0.3670, secret loss of 1.3289
# Training: Batch 842/1000. Loss of 1.1113, cover loss of 0.3259, secret loss of 1.2807
# Training: Batch 843/1000. Loss of 1.1189, cover loss of 0.3902, secret loss of 1.0898
# Training: Batch 844/1000. Loss of 1.2748, cover loss of 0.4376, secret loss of 1.2663
# Training: Batch 845/1000. Loss of 1.3088, cover loss of 0.3871, secret loss of 1.5462
# Training: Batch 846/1000. Loss of 1.0899, cover loss of 0.3118, secret loss of 1.2722
# Training: Batch 847/1000. Loss of 1.1403, cover loss of 0.3708, secret loss of 1.1783
# Training: Batch 848/1000. Loss of 1.4023, cover loss of 0.3551, secret loss of 1.7978
# Training: Batch 849/1000. Loss of 1.2052, cover loss of 0.3073, secret loss of 1.4958
# Training: Batch 850/1000. Loss of 1.2159, cover loss of 0.3512, secret loss of 1.3762
# Training: Batch 851/1000. Loss of 1.2523, cover loss of 0.3253, secret loss of 1.5083
# Training: Batch 852/1000. Loss of 1.2302, cover loss of 0.3417, secret loss of 1.4243
# Training: Batch 853/1000. Loss of 1.1348, cover loss of 0.3009, secret loss of 1.3774
# Training: Batch 854/1000. Loss of 1.0997, cover loss of 0.2969, secret loss of 1.3130
# Training: Batch 855/1000. Loss of 1.1918, cover loss of 0.3913, secret loss of 1.2369
# Training: Batch 856/1000. Loss of 1.0876, cover loss of 0.3198, secret loss of 1.2138
# Training: Batch 857/1000. Loss of 1.1450, cover loss of 0.3375, secret loss of 1.2670
# Training: Batch 858/1000. Loss of 1.1432, cover loss of 0.2779, secret loss of 1.4437
# Training: Batch 859/1000. Loss of 1.1369, cover loss of 0.3090, secret loss of 1.3551
# Training: Batch 860/1000. Loss of 1.0269, cover loss of 0.3200, secret loss of 1.0793
# Training: Batch 861/1000. Loss of 1.2751, cover loss of 0.3824, secret loss of 1.3747
# Training: Batch 862/1000. Loss of 1.0108, cover loss of 0.2929, secret loss of 1.1317
# Training: Batch 863/1000. Loss of 1.1678, cover loss of 0.3112, secret loss of 1.3996
# Training: Batch 864/1000. Loss of 1.0334, cover loss of 0.2915, secret loss of 1.2198
# Training: Batch 865/1000. Loss of 1.2304, cover loss of 0.2604, secret loss of 1.6918
# Training: Batch 866/1000. Loss of 1.1964, cover loss of 0.3249, secret loss of 1.4418
# Training: Batch 867/1000. Loss of 1.1835, cover loss of 0.3213, secret loss of 1.4180
# Training: Batch 868/1000. Loss of 1.2455, cover loss of 0.4066, secret loss of 1.2737
# Training: Batch 869/1000. Loss of 1.1738, cover loss of 0.3717, secret loss of 1.2649
# Training: Batch 870/1000. Loss of 1.1412, cover loss of 0.2829, secret loss of 1.4427
# Training: Batch 871/1000. Loss of 1.1896, cover loss of 0.2974, secret loss of 1.4834
# Training: Batch 872/1000. Loss of 1.0843, cover loss of 0.3846, secret loss of 1.1104
# Training: Batch 873/1000. Loss of 1.2170, cover loss of 0.3222, secret loss of 1.4596
# Training: Batch 874/1000. Loss of 1.0973, cover loss of 0.3371, secret loss of 1.1583
# Training: Batch 875/1000. Loss of 1.2608, cover loss of 0.3757, secret loss of 1.3477
# Training: Batch 876/1000. Loss of 1.1035, cover loss of 0.3359, secret loss of 1.1622
# Training: Batch 877/1000. Loss of 1.0698, cover loss of 0.3431, secret loss of 1.0838
# Training: Batch 878/1000. Loss of 1.0790, cover loss of 0.3150, secret loss of 1.2119
# Training: Batch 879/1000. Loss of 1.0284, cover loss of 0.2957, secret loss of 1.2097
# Training: Batch 880/1000. Loss of 1.1253, cover loss of 0.3421, secret loss of 1.2585
# Training: Batch 881/1000. Loss of 1.0785, cover loss of 0.3180, secret loss of 1.1931
# Training: Batch 882/1000. Loss of 1.1361, cover loss of 0.3124, secret loss of 1.3257
# Training: Batch 883/1000. Loss of 1.3291, cover loss of 0.3366, secret loss of 1.7517
# Training: Batch 884/1000. Loss of 1.1785, cover loss of 0.3456, secret loss of 1.3097
# Training: Batch 885/1000. Loss of 1.2016, cover loss of 0.2548, secret loss of 1.6325
# Training: Batch 886/1000. Loss of 1.0822, cover loss of 0.2796, secret loss of 1.3345
# Training: Batch 887/1000. Loss of 1.1889, cover loss of 0.3175, secret loss of 1.4552
# Training: Batch 888/1000. Loss of 1.0031, cover loss of 0.2771, secret loss of 1.2222
# Training: Batch 889/1000. Loss of 1.1712, cover loss of 0.3526, secret loss of 1.3188
# Training: Batch 890/1000. Loss of 1.2274, cover loss of 0.3385, secret loss of 1.4630
# Training: Batch 891/1000. Loss of 1.2633, cover loss of 0.3640, secret loss of 1.4264
# Training: Batch 892/1000. Loss of 1.2849, cover loss of 0.3076, secret loss of 1.6498
# Training: Batch 893/1000. Loss of 1.2662, cover loss of 0.3795, secret loss of 1.3721
# Training: Batch 894/1000. Loss of 1.1141, cover loss of 0.3011, secret loss of 1.3357
# Training: Batch 895/1000. Loss of 1.1141, cover loss of 0.2908, secret loss of 1.3565
# Training: Batch 896/1000. Loss of 1.1121, cover loss of 0.3669, secret loss of 1.0916
# Training: Batch 897/1000. Loss of 0.9320, cover loss of 0.3041, secret loss of 0.9367
# Training: Batch 898/1000. Loss of 1.1519, cover loss of 0.2838, secret loss of 1.4406
# Training: Batch 899/1000. Loss of 1.1087, cover loss of 0.2859, secret loss of 1.4035
# Training: Batch 900/1000. Loss of 1.3792, cover loss of 0.3450, secret loss of 1.7755
# Training: Batch 901/1000. Loss of 1.1283, cover loss of 0.3868, secret loss of 1.1288
# Training: Batch 902/1000. Loss of 1.1014, cover loss of 0.2932, secret loss of 1.3525
# Training: Batch 903/1000. Loss of 1.2753, cover loss of 0.4650, secret loss of 1.1957
# Training: Batch 904/1000. Loss of 1.1339, cover loss of 0.2747, secret loss of 1.4608
# Training: Batch 905/1000. Loss of 1.1667, cover loss of 0.3475, secret loss of 1.3115
# Training: Batch 906/1000. Loss of 1.2531, cover loss of 0.3307, secret loss of 1.5615
# Training: Batch 907/1000. Loss of 1.1823, cover loss of 0.3447, secret loss of 1.3086
# Training: Batch 908/1000. Loss of 1.2396, cover loss of 0.3578, secret loss of 1.3822
# Training: Batch 909/1000. Loss of 1.1813, cover loss of 0.3446, secret loss of 1.3280
# Training: Batch 910/1000. Loss of 1.2485, cover loss of 0.3290, secret loss of 1.4989
# Training: Batch 911/1000. Loss of 1.0779, cover loss of 0.2996, secret loss of 1.2806
# Training: Batch 912/1000. Loss of 1.2543, cover loss of 0.2991, secret loss of 1.6424
# Training: Batch 913/1000. Loss of 1.2711, cover loss of 0.3729, secret loss of 1.4462
# Training: Batch 914/1000. Loss of 1.1526, cover loss of 0.2992, secret loss of 1.4070
# Training: Batch 915/1000. Loss of 1.0154, cover loss of 0.2869, secret loss of 1.2107
# Training: Batch 916/1000. Loss of 1.3037, cover loss of 0.3278, secret loss of 1.6269
# Training: Batch 917/1000. Loss of 1.1233, cover loss of 0.3712, secret loss of 1.1358
# Training: Batch 918/1000. Loss of 1.1361, cover loss of 0.3317, secret loss of 1.3003
# Training: Batch 919/1000. Loss of 1.1621, cover loss of 0.2972, secret loss of 1.4365
# Training: Batch 920/1000. Loss of 1.1524, cover loss of 0.4165, secret loss of 1.1147
# Training: Batch 921/1000. Loss of 1.1298, cover loss of 0.3654, secret loss of 1.1483
# Training: Batch 922/1000. Loss of 1.3033, cover loss of 0.3957, secret loss of 1.4193
# Training: Batch 923/1000. Loss of 1.0964, cover loss of 0.3081, secret loss of 1.2661
# Training: Batch 924/1000. Loss of 1.0405, cover loss of 0.3229, secret loss of 1.1107
# Training: Batch 925/1000. Loss of 1.1178, cover loss of 0.3468, secret loss of 1.2126
# Training: Batch 926/1000. Loss of 1.4255, cover loss of 0.4384, secret loss of 1.5335
# Training: Batch 927/1000. Loss of 0.9580, cover loss of 0.2770, secret loss of 1.0931
# Training: Batch 928/1000. Loss of 1.1037, cover loss of 0.3305, secret loss of 1.2349
# Training: Batch 929/1000. Loss of 1.4431, cover loss of 0.3658, secret loss of 1.7817
# Training: Batch 930/1000. Loss of 0.9635, cover loss of 0.3309, secret loss of 0.9669
# Training: Batch 931/1000. Loss of 1.2634, cover loss of 0.3715, secret loss of 1.4269
# Training: Batch 932/1000. Loss of 1.0964, cover loss of 0.3064, secret loss of 1.2678
# Training: Batch 933/1000. Loss of 1.0315, cover loss of 0.2933, secret loss of 1.1994
# Training: Batch 934/1000. Loss of 1.1806, cover loss of 0.3806, secret loss of 1.2476
# Training: Batch 935/1000. Loss of 1.1090, cover loss of 0.3056, secret loss of 1.3036
# Training: Batch 936/1000. Loss of 1.2169, cover loss of 0.3538, secret loss of 1.4013
# Training: Batch 937/1000. Loss of 1.0236, cover loss of 0.3513, secret loss of 1.0593
# Training: Batch 938/1000. Loss of 1.1667, cover loss of 0.2844, secret loss of 1.5374
# Training: Batch 939/1000. Loss of 1.1779, cover loss of 0.3078, secret loss of 1.4306
# Training: Batch 940/1000. Loss of 1.0878, cover loss of 0.2824, secret loss of 1.3373
# Training: Batch 941/1000. Loss of 1.2141, cover loss of 0.3693, secret loss of 1.3432
# Training: Batch 942/1000. Loss of 1.0539, cover loss of 0.2997, secret loss of 1.1867
# Training: Batch 943/1000. Loss of 1.2186, cover loss of 0.2712, secret loss of 1.6112
# Training: Batch 944/1000. Loss of 1.0413, cover loss of 0.2728, secret loss of 1.2322
# Training: Batch 945/1000. Loss of 1.1808, cover loss of 0.3232, secret loss of 1.3688
# Training: Batch 946/1000. Loss of 1.1789, cover loss of 0.3644, secret loss of 1.2598
# Training: Batch 947/1000. Loss of 1.2053, cover loss of 0.3509, secret loss of 1.3963
# Training: Batch 948/1000. Loss of 1.1556, cover loss of 0.3821, secret loss of 1.1862
# Training: Batch 949/1000. Loss of 1.0320, cover loss of 0.3226, secret loss of 1.1141
# Training: Batch 950/1000. Loss of 1.0736, cover loss of 0.3385, secret loss of 1.1725
# Training: Batch 951/1000. Loss of 1.3111, cover loss of 0.3843, secret loss of 1.4884
# Training: Batch 952/1000. Loss of 1.0825, cover loss of 0.2670, secret loss of 1.3804
# Training: Batch 953/1000. Loss of 1.1959, cover loss of 0.3053, secret loss of 1.4718
# Training: Batch 954/1000. Loss of 1.1857, cover loss of 0.3513, secret loss of 1.3085
# Training: Batch 955/1000. Loss of 1.0816, cover loss of 0.3356, secret loss of 1.1433
# Training: Batch 956/1000. Loss of 1.1777, cover loss of 0.3165, secret loss of 1.4854
# Training: Batch 957/1000. Loss of 1.0684, cover loss of 0.3336, secret loss of 1.1551
# Training: Batch 958/1000. Loss of 1.0299, cover loss of 0.3119, secret loss of 1.1554
# Training: Batch 959/1000. Loss of 1.0536, cover loss of 0.3111, secret loss of 1.1879
# Training: Batch 960/1000. Loss of 0.9972, cover loss of 0.2562, secret loss of 1.2320
# Training: Batch 961/1000. Loss of 0.9772, cover loss of 0.3006, secret loss of 1.0554
# Training: Batch 962/1000. Loss of 1.2615, cover loss of 0.3994, secret loss of 1.3531
# Training: Batch 963/1000. Loss of 1.0112, cover loss of 0.2782, secret loss of 1.2329
# Training: Batch 964/1000. Loss of 1.0149, cover loss of 0.2841, secret loss of 1.1791
# Training: Batch 965/1000. Loss of 1.0943, cover loss of 0.3173, secret loss of 1.2310
# Training: Batch 966/1000. Loss of 0.9730, cover loss of 0.3273, secret loss of 1.0078
# Training: Batch 967/1000. Loss of 1.1865, cover loss of 0.3769, secret loss of 1.2872
# Training: Batch 968/1000. Loss of 1.1116, cover loss of 0.3856, secret loss of 1.0490
# Training: Batch 969/1000. Loss of 1.1781, cover loss of 0.3022, secret loss of 1.4325
# Training: Batch 970/1000. Loss of 1.0915, cover loss of 0.3371, secret loss of 1.1711
# Training: Batch 971/1000. Loss of 1.2158, cover loss of 0.3507, secret loss of 1.3503
# Training: Batch 972/1000. Loss of 1.1028, cover loss of 0.3034, secret loss of 1.2852
# Training: Batch 973/1000. Loss of 1.1558, cover loss of 0.3139, secret loss of 1.3588
# Training: Batch 974/1000. Loss of 1.1875, cover loss of 0.3532, secret loss of 1.3205
# Training: Batch 975/1000. Loss of 1.3188, cover loss of 0.4061, secret loss of 1.4641
# Training: Batch 976/1000. Loss of 1.0327, cover loss of 0.3342, secret loss of 1.0735
# Training: Batch 977/1000. Loss of 1.0446, cover loss of 0.2778, secret loss of 1.2635
# Training: Batch 978/1000. Loss of 1.0644, cover loss of 0.3045, secret loss of 1.2207
# Training: Batch 979/1000. Loss of 1.0375, cover loss of 0.2728, secret loss of 1.2476
# Training: Batch 980/1000. Loss of 0.8900, cover loss of 0.2544, secret loss of 1.0144
# Training: Batch 981/1000. Loss of 1.1745, cover loss of 0.3358, secret loss of 1.3620
# Training: Batch 982/1000. Loss of 1.1063, cover loss of 0.3260, secret loss of 1.2249
# Training: Batch 983/1000. Loss of 1.0803, cover loss of 0.2905, secret loss of 1.3220
# Training: Batch 984/1000. Loss of 1.1105, cover loss of 0.3824, secret loss of 1.0751
# Training: Batch 985/1000. Loss of 1.1929, cover loss of 0.3716, secret loss of 1.2723
# Training: Batch 986/1000. Loss of 1.3477, cover loss of 0.3473, secret loss of 1.6736
# Training: Batch 987/1000. Loss of 1.1071, cover loss of 0.3623, secret loss of 1.1563
# Training: Batch 988/1000. Loss of 1.2714, cover loss of 0.3602, secret loss of 1.4678
# Training: Batch 989/1000. Loss of 1.0866, cover loss of 0.3583, secret loss of 1.1093
# Training: Batch 990/1000. Loss of 1.2232, cover loss of 0.3900, secret loss of 1.2745
# Training: Batch 991/1000. Loss of 1.1276, cover loss of 0.3538, secret loss of 1.2171
# Training: Batch 992/1000. Loss of 1.0996, cover loss of 0.3266, secret loss of 1.2401
# Training: Batch 993/1000. Loss of 1.0105, cover loss of 0.2830, secret loss of 1.1681
# Training: Batch 994/1000. Loss of 1.2065, cover loss of 0.3545, secret loss of 1.3758
# Training: Batch 995/1000. Loss of 1.1543, cover loss of 0.3333, secret loss of 1.3561
# Training: Batch 996/1000. Loss of 1.3240, cover loss of 0.3552, secret loss of 1.6391
# Training: Batch 997/1000. Loss of 1.0855, cover loss of 0.3053, secret loss of 1.2352
# Training: Batch 998/1000. Loss of 1.1289, cover loss of 0.3223, secret loss of 1.2949
# Training: Batch 999/1000. Loss of 1.1274, cover loss of 0.2866, secret loss of 1.3586
# Training: Batch 1000/1000. Loss of 1.2069, cover loss of 0.3295, secret loss of 1.3811
# Epoch [30/30], Average_loss: 1.1421

# %%
 # Plot loss through epochs
plt.plot(loss_history)
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Batch')
plt.show()

# %%
def pixel_errors(input_S, input_C, decoded_S, decoded_C):
    """Calculates mean of Sum of Squared Errors per pixel for cover and secret images. """
    input_S = np.array(input_S.detach().cpu())
    input_C = np.array(input_C.detach().cpu())
    decoded_S = np.array(decoded_S.detach().cpu())
    decoded_C = np.array(decoded_C.detach().cpu())
    # print(input_S)
    see_Spixel = np.sqrt(np.mean(np.square(255*(input_S - decoded_S))))
    see_Cpixel = np.sqrt(np.mean(np.square(255*(input_C - decoded_C))))
    
    return see_Spixel, see_Cpixel

import math
def psnr(input_S, input_C, decoded_S, decoded_C):
    input_S = np.array(input_S.detach().cpu())
    input_C = np.array(input_C.detach().cpu())
    decoded_S = np.array(decoded_S.detach().cpu())
    decoded_C = np.array(decoded_C.detach().cpu())
    mse_s = np.mean(np.square(255*(input_S - decoded_S)))
    mse_c = np.mean(np.square(255*(input_C - decoded_C)))
    psnr_s = 10*math.log10(255**2/mse_s)
    psnr_c = 10*math.log10(255**2/mse_c)
    return psnr_s, psnr_c

def pixel_histogram(diff_S, diff_C):
    """Calculates histograms of errors for cover and secret image. """
    diff_Sflat = diff_S.flatten()
    diff_Cflat = diff_C.flatten()
    
    fig = plt.figure(figsize=(15, 5))
    a=fig.add_subplot(1,2,1)
        
    imgplot = plt.hist(255* diff_Cflat, 100, density=1, alpha=0.75, facecolor='red')
    a.set_title('Distribution of error in the Cover image.')
    plt.axis([0, 250, 0, 0.2])
    
    a=fig.add_subplot(1,2,2)
    imgplot = plt.hist(255* diff_Sflat, 100, density=1, alpha=0.75, facecolor='red')
    a.set_title('Distribution of errors in the Secret image.')
    plt.axis([0, 250, 0, 0.2])
    
    plt.show()

# %%
# net.load_state_dict(torch.load(MODELS_PATH+'Epoch N4.pkl'))

# Switch to evaluate mode
net.eval()
Path(PATH+"LOSS3_ds_with_noise").mkdir(parents=True, exist_ok=True)
Path(PATH+"LOSS3_ds_with_noise/cover_images/").mkdir(parents=True, exist_ok=True)
Path(PATH+"LOSS3_ds_with_noise/container_images/").mkdir(parents=True, exist_ok=True)
save_path = PATH+"LOSS3_ds_with_noise/"

test_losses = []

S_errors = []
C_errors = []

psnr_s,psnr_c = [], []
# Show images
for idx, test_batch in enumerate(test_loader):
     # Saves images
    data, _ = test_batch
    data = data.to(device)

    # Saves secret images and secret covers
    test_secret = data[:len(data)//2]
    test_cover = data[len(data)//2:]

    # Creates variable from secret and cover images
    test_secret = Variable(test_secret, volatile=True)
    test_cover = Variable(test_cover, volatile=True)

    # Compute output
    test_hidden, test_output = net(test_secret, test_cover)
    
    # Calculate loss
    test_loss, loss_cover, loss_secret = customized_loss(test_output, test_hidden, test_secret, test_cover, beta)
    
    diff_S, diff_C = np.abs(np.array(test_output.data.detach().cpu()) - np.array(test_secret.data.detach().cpu())), np.abs(np.array(test_hidden.data.detach().cpu()) - np.array(test_cover.data.detach().cpu()))
    
#     print (diff_S, diff_C)

    # Print pixel-wise average errors in a 256 scale.
    S_error, C_error = pixel_errors(test_secret, test_cover, test_output, test_hidden)
    S_errors.append(S_error)
    C_errors.append(C_error)

    S_psnr, C_psnr = psnr(test_secret, test_cover, test_output, test_hidden)
    psnr_s.append(S_psnr)
    psnr_c.append(C_psnr)
    
    if idx in [1,2,3,4]:
        print ('Total loss: {:.2f} \nLoss on secret: {:.2f} \nLoss on cover: {:.2f}'.format(test_loss.data.item(), loss_secret.data.item(), loss_cover.data.item()))

        # Creates img tensor
        imgs = [test_secret.data.detach().cpu(), test_output.data.detach().cpu(), test_cover.data.detach().cpu(), test_hidden.data.detach().cpu()]
        imgs_tsor = torch.cat(imgs, 0)

        # Prints Images
        imshow(utils.make_grid(imgs_tsor), idx+1, learning_rate=learning_rate, beta=beta)
        
    if idx < 500:
        container_img = tensor_to_image(test_hidden.data.detach().cpu())
        container_img = Image.fromarray(container_img)
        container_img.save(save_path+"container_images/"+str(idx)+".jpeg")
        cover_img = tensor_to_image(test_cover.data.detach().cpu())
        cover_img = Image.fromarray(cover_img)
        cover_img.save(save_path+"cover_images/"+str(idx)+".jpeg")

    test_losses.append(test_loss.data.item())
        
mean_test_loss = np.mean(test_losses)

print ('Average loss on test set: {:.2f}'.format(mean_test_loss))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:27: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
# Total loss: 1.32
# Loss on secret: 1.54
# Loss on cover: 0.40
# Total loss: 1.02
# Loss on secret: 1.39
# Loss on cover: 0.25
# Total loss: 0.70
# Loss on secret: 0.75
# Loss on cover: 0.27
# Total loss: 0.77
# Loss on secret: 1.05
# Loss on cover: 0.22
# Average loss on test set: 1.12

# %%
print ("Avg. S error per pixel [0, 255]:", sum(S_errors)/len(S_errors))
print ("Avg. C error per pixel [0, 255]:", sum(C_errors)/len(C_errors))
# Out:
# Avg. S error per pixel [0, 255]: 301.3899710571289
# Avg. C error per pixel [0, 255]: 148.78399286956787

# %%
print ("Avg. PSNR of secret and decoded secret:", sum(psnr_s)/len(psnr_s))
print ("Avg. PSNR of cover and container:", sum(psnr_c)/len(psnr_c))
# Out:
# Avg. PSNR of secret and decoded secret: -1.2406629395140314
# Avg. PSNR of cover and container: 4.887369368191127

# %%
# Plot distribution of errors in cover and secret images.
pixel_histogram(diff_S, diff_C)
