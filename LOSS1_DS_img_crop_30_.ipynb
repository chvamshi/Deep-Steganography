# %% [markdown]
# <a href="https://colab.research.google.com/github/chvamshi/Deep-Steganography/blob/main/LOSS1_DS_img_crop_30_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget http://cs231n.stanford.edu/tiny-imagenet-200.zip
# !unzip -q tiny-imagenet-200.zip && ls tiny-imagenet-200
# Out:
# --2022-02-03 18:31:56--  http://cs231n.stanford.edu/tiny-imagenet-200.zip
# Resolving cs231n.stanford.edu (cs231n.stanford.edu)... 171.64.68.10
# Connecting to cs231n.stanford.edu (cs231n.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248100043 (237M) [application/zip]
# Saving to: ‘tiny-imagenet-200.zip’
#
# tiny-imagenet-200.z 100%[===================>] 236.61M  78.8MB/s    in 3.0s
#
# 2022-02-03 18:31:59 (78.8 MB/s) - ‘tiny-imagenet-200.zip’ saved [248100043/248100043]
#
# test  train  val  wnids.txt  words.txt

# %%
# Imports necessary libraries and modules
from itertools import islice
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch.autograd import Variable
from torch import utils
from torch.utils.data import Subset
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import os 
from pathlib import Path
import pickle
import random
from torchvision import datasets, utils
import torchvision.transforms as transforms
from torchvision.transforms import ToPILImage
from torchvision.transforms import RandomResizedCrop
from torchvision.transforms.functional import resized_crop
from random import shuffle
from IPython.display import Image
from PIL import Image

# Use GPU if it is present
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
# Directory path
# os.chdir("..")
cwd = '/content/tiny-imagenet-200'

# Hyper Parameters
num_epochs = 50
batch_size = 32
learning_rate = 0.001
beta = 1

# Mean and std deviation of imagenet dataset. Source: http://cs231n.stanford.edu/reports/2017/pdfs/101.pdf
std = [0.229, 0.224, 0.225]
mean = [0.485, 0.456, 0.406]

# TODO: Define train, validation and models
MODELS_PATH = '/content/output/models'
# TRAIN_PATH = cwd+'/train/'
# VALID_PATH = cwd+'/valid/'
VALID_PATH = cwd+'/val/'
TRAIN_PATH = cwd+'/train/'
TEST_PATH = cwd+'/test/'

# if not os.path.exists(MODELS_PATH): os.mkdir(MODELS_PATH)

# %%
def variance(image1, image2):
    var1 = torch.var(image1)
    var2 = torch.var(image2)

    return var1+var2

def customized_loss(S_prime, C_prime, S, C, B):
    ''' Calculates loss specified on the paper.'''
    
    loss_cover = torch.nn.functional.l1_loss(C_prime, C)
    # loss_cover = loss_cover/(64*64)
    loss_secret = torch.nn.functional.l1_loss(S_prime, S)
    # loss_secret = loss_secret/(64*64)

    variance_cover = variance(C_prime, C)
    variance_secret = variance(S_prime, S)

    loss_all = loss_cover+loss_secret+variance_cover+variance_secret
    loss_all = loss_all/4

    return loss_all, loss_cover, loss_secret

def denormalize(image, std, mean):
    ''' Denormalizes a tensor of images.'''

    for t in range(3):
        image[t, :, :] = (image[t, :, :] * std[t]) + mean[t]
    return image

def imshow(img, idx, learning_rate, beta):
    '''Prints out an image given in tensor format.'''
    
    img = denormalize(img, std, mean)
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.title('Example '+str(idx)+', lr='+str(learning_rate)+', B='+str(beta))
    plt.show()
    return

def gaussian(tensor, mean=0, stddev=0.1):
    '''Adds random noise to a tensor.'''
    
    noise = torch.nn.init.normal(torch.Tensor(tensor.size()), 0, 0.1).to(device)
    return Variable(tensor + noise)

def tensor_to_image(tensor):
    """
    Transforms a torch tensor into numpy uint8 array (image)
    :param tensor: (batch_size x channels x height x width) torch tensor in range [-1.0, 1.0]
    :return: (batch_size x height x width x channels) uint8 array
    """
    image = tensor.cpu().numpy()[0]
    # image = tensor.permute(0, 2, 3, 1).cpu().numpy()
    image = np.transpose(image, (1,2,0))
    image = (image + 1) * 127.5
    return np.clip(image, 0, 255).astype(np.uint8)

# %%
import torch.nn as nn
import numpy as np

def random_float(min, max):
    """
    Return a random number
    :param min:
    :param max:
    :return:
    """
    return np.random.rand() * (max - min) + min


def get_random_rectangle_inside(image, height_ratio_range, width_ratio_range):
    """
    Returns a random rectangle inside the image, where the size is random and is controlled by height_ratio_range and width_ratio_range.
    This is analogous to a random crop. For example, if height_ratio_range is (0.7, 0.9), then a random number in that range will be chosen
    (say it is 0.75 for illustration), and the image will be cropped such that the remaining height equals 0.75. In fact,
    a random 'starting' position rs will be chosen from (0, 0.25), and the crop will start at rs and end at rs + 0.75. This ensures
    that we crop from top/bottom with equal probability.
    The same logic applies to the width of the image, where width_ratio_range controls the width crop range.
    :param image: The image we want to crop
    :param height_ratio_range: The range of remaining height ratio
    :param width_ratio_range:  The range of remaining width ratio.
    :return: "Cropped" rectange with width and height drawn randomly height_ratio_range and width_ratio_range
    """
    # print(image.shape)
    image_height = image.shape[1]
    image_width = image.shape[2]

    remaining_height = int(np.rint(random_float(height_ratio_range[0], height_ratio_range[1]) * image_height))
    remaining_width = int(np.rint(random_float(width_ratio_range[0], width_ratio_range[0]) * image_width))

    if remaining_height == image_height:
        height_start = 0
    else:
        height_start = np.random.randint(0, image_height - remaining_height)

    if remaining_width == image_width:
        width_start = 0
    else:
        width_start = np.random.randint(0, image_width - remaining_width)

    return height_start, height_start+remaining_height, width_start, width_start+remaining_width


class Crop(nn.Module):
    """
    Randomly crops the image from top/bottom and left/right. The amount to crop is controlled by parameters
    heigth_ratio_range and width_ratio_range
    """
    def __init__(self, height_ratio_range, width_ratio_range):
        """
        :param height_ratio_range:
        :param width_ratio_range:
        """
        super(Crop, self).__init__()
        self.height_ratio_range = height_ratio_range
        self.width_ratio_range = width_ratio_range


    def forward(self, noised_and_cover):
        noised_image = noised_and_cover[0]
        print("Noisedimageshape: ",noised_image.shape)
        shape = noised_image.shape
        # crop_rectangle is in form (from, to) where @from and @to are 2D points -- (height, width)

        h_start, h_end, w_start, w_end = get_random_rectangle_inside(noised_image, self.height_ratio_range, self.width_ratio_range)

        noised_image =  noised_image[
               :,
               h_start: h_end,
               w_start: w_end].clone()
        noised_image1 = noised_image.expand(-1,64,64)
        print(noised_image1.shape)
        noised_and_cover[0] = noised_image1.clone()

        return noised_and_cover

# %%
# Preparation Network (2 conv layers)
class PrepNetwork(nn.Module):
    def __init__(self):
        super(PrepNetwork, self).__init__()
        self.initialP3 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialP4 = nn.Sequential(
            nn.Conv2d(3, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialP5 = nn.Sequential(
            nn.Conv2d(3, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalP3 = nn.Sequential(
            nn.Conv2d(65, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalP4 = nn.Sequential(
            nn.Conv2d(65, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalP5 = nn.Sequential(
            nn.Conv2d(65, 5, kernel_size=5, padding=2),
            nn.ReLU())

    def forward(self, p):
        p1 = self.initialP3(p)
        p2 = self.initialP4(p)
        p3 = self.initialP5(p)
        mid = torch.cat((p1, p2, p3), 1)
        p4 = self.finalP3(mid)
        p5 = self.finalP4(mid)
        p6 = self.finalP5(mid)
        # print(p4.shape)
        # print(p5.shape)
        # print(p6.shape)
        out = torch.cat((p4, p5, p6), 1)
        return out

# Hiding Network (5 conv layers)
class HidingNetwork(nn.Module):
    def __init__(self):
        super(HidingNetwork, self).__init__()
        self.initialH3 = nn.Sequential(
            nn.Conv2d(68, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialH4 = nn.Sequential(
            nn.Conv2d(68, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialH5 = nn.Sequential(
            nn.Conv2d(68, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalH3 = nn.Sequential(
            nn.Conv2d(65, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalH4 = nn.Sequential(
            nn.Conv2d(65, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalH5 = nn.Sequential(
            nn.Conv2d(65, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalH = nn.Sequential(
            nn.Conv2d(65, 3, kernel_size=1, padding=0))
        
    def forward(self, h):
        h1 = self.initialH3(h)
        h2 = self.initialH4(h)
        h3 = self.initialH5(h)
        mid = torch.cat((h1, h2, h3), 1)
        h4 = self.finalH3(mid)
        h5 = self.finalH4(mid)
        h6 = self.finalH5(mid)
        mid2 = torch.cat((h4, h5, h6), 1)
        out = self.finalH(mid2)
        out_noise = gaussian(out.data, 0, 0.1)
        return out, out_noise

# Reveal Network (2 conv layers)
class RevealNetwork(nn.Module):
    def __init__(self):
        super(RevealNetwork, self).__init__()
        self.initialR3 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialR4 = nn.Sequential(
            nn.Conv2d(3, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialR5 = nn.Sequential(
            nn.Conv2d(3, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(5, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalR3 = nn.Sequential(
            nn.Conv2d(65, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalR4 = nn.Sequential(
            nn.Conv2d(65, 10, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalR5 = nn.Sequential(
            nn.Conv2d(65, 5, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalR = nn.Sequential(
            nn.Conv2d(65, 3, kernel_size=1, padding=0))

    def forward(self, r, img_shape):
        # r = r.expand(img_shape)
        r1 = self.initialR3(r)
        r2 = self.initialR4(r)
        r3 = self.initialR5(r)
        mid = torch.cat((r1, r2, r3), 1)
        r4 = self.finalR3(mid)
        r5 = self.finalR4(mid)
        r6 = self.finalR5(mid)
        mid2 = torch.cat((r4, r5, r6), 1)
        out = self.finalR(mid2)
        return out

# Join three networks in one module
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.m1 = PrepNetwork().to(device)
        self.m2 = HidingNetwork().to(device)
        self.m3 = RevealNetwork().to(device)
        self.crop = Crop((0.7,0.9),(0.7,0.9)).to(device)

    def forward(self, secret, cover):
        img_shape = secret.shape
        x_1 = self.m1(secret)
        mid = torch.cat((x_1, cover), 1)
        x_2, x_2_noise = self.m2(mid)
        # x_2_noise = resized_crop(img=x_2_noise, top = 0, left=0, height=19, width=19, size=[64,64])
        x_2 =  resized_crop(img=x_2, top = 0, left=0, height=19, width=19, size=[64,64])
        # x_3 = self.m3(x_2_noise, img_shape)
        x_3 = self.m3(x_2, img_shape)
        return x_2, x_3

# %%
# Creates net object
net = Net().to(device)

# %%
# Creates training set
train_data = datasets.ImageFolder(
        TRAIN_PATH,
        transforms.Compose([
        # transforms.Scale(256),
        # transforms.RandomCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean,
        std=std)
        ]))
train_data = Subset(train_data, [i for i in range(32000)])
train_loader = torch.utils.data.DataLoader(
        train_data, batch_size=batch_size, num_workers=1, 
        pin_memory=True, shuffle=True, drop_last=True)

# Creates test set
test_data = datasets.ImageFolder(
        TEST_PATH, 
        transforms.Compose([
        # transforms.Scale(256),
        # transforms.RandomCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean,
        std=std)
        ]))
test_data = Subset(test_data,[i for i in range(5000)])
test_loader = torch.utils.data.DataLoader(
        test_data, batch_size=2, num_workers=1, 
        pin_memory=True, shuffle=True, drop_last=True)

# %%
PATH = "/content/drive/MyDrive/"
loss_history = []

def train_model(train_loader, beta, learning_rate):
    
    # Save optimizer
    optimizer = optim.Adam(net.parameters(), lr=learning_rate)
    
    loss_history = []
    # Iterate over batches performing forward and backward passes
    for epoch in range(num_epochs):

        # Train mode
        net.train()
        
        train_losses = []
        # Train one epoch
        for idx, train_batch in enumerate(train_loader):

            data, _  = train_batch
            data = data.to(device)

            # Saves secret images and secret covers
            train_covers = data[:len(data)//2]
            train_secrets = data[len(data)//2:]
            
            # Creates variable from secret and cover images
            train_secrets = Variable(train_secrets, requires_grad=False)
            train_covers = Variable(train_covers, requires_grad=False)

            # Forward + Backward + Optimize
            optimizer.zero_grad()
            train_hidden, train_output = net(train_secrets, train_covers)

            # Calculate loss and perform backprop
            train_loss, train_loss_cover, train_loss_secret = customized_loss(train_output, train_hidden, train_secrets, train_covers, beta)
            train_loss.backward()
            optimizer.step()
            
            # Saves training loss
            # print(train_loss.data)
            train_losses.append(train_loss.data.item())
            loss_history.append(train_loss.data.item())
            
            # Prints mini-batch losses
            print('Training: Batch {0}/{1}. Loss of {2:.4f}, cover loss of {3:.4f}, secret loss of {4:.4f}'.format(idx+1, len(train_loader), train_loss.data.item(), train_loss_cover.data.item(), train_loss_secret.data.item()))
    
        # Save model
        # torch.save(net.state_dict(), '/content/Epoch N{}.pkl'.format(epoch+1))
        torch.save(net.state_dict(), PATH+"LOSS1_ds_crop_30.pth")
        with open(PATH+"LOSS1_loss_history_crop_30.txt", "a") as f:
            for s in loss_history:
                f.write(str(s) +"\n")
        
        mean_train_loss = np.mean(train_losses)
    
        # Prints epoch average loss
        print ('Epoch [{0}/{1}], Average_loss: {2:.4f}'.format(
                epoch+1, num_epochs, mean_train_loss))
    
    return net, mean_train_loss, loss_history

# %%
# Load model
# net.load_state_dict(torch.load(PATH+"LOSS1_ds_crop_30.pth"))
# loss_history = []
# with open(PATH+"LOSS1_loss_history_crop_30.txt", "r") as f:
#   for line in f:
#     loss_history.append(float(line.strip()))

net, mean_train_loss, loss_history = train_model(train_loader, beta, learning_rate)
# loss_history.extend(loss_history1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:43: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
# Streaming output truncated to the last 5000 lines.
# Training: Batch 6/1000. Loss of 1.1520, cover loss of 0.9175, secret loss of 0.9157
# Training: Batch 7/1000. Loss of 1.1116, cover loss of 0.8485, secret loss of 0.9289
# Training: Batch 8/1000. Loss of 0.9553, cover loss of 0.8430, secret loss of 0.7565
# Training: Batch 9/1000. Loss of 1.0490, cover loss of 0.9345, secret loss of 0.7875
# Training: Batch 10/1000. Loss of 1.1525, cover loss of 0.8703, secret loss of 0.9469
# Training: Batch 11/1000. Loss of 1.0494, cover loss of 0.9118, secret loss of 0.8012
# Training: Batch 12/1000. Loss of 1.1730, cover loss of 1.0162, secret loss of 0.8501
# Training: Batch 13/1000. Loss of 1.0520, cover loss of 0.8944, secret loss of 0.8101
# Training: Batch 14/1000. Loss of 1.1033, cover loss of 0.8274, secret loss of 0.9637
# Training: Batch 15/1000. Loss of 1.1939, cover loss of 0.8649, secret loss of 1.0399
# Training: Batch 16/1000. Loss of 0.9425, cover loss of 0.8013, secret loss of 0.7899
# Training: Batch 17/1000. Loss of 1.1069, cover loss of 0.7607, secret loss of 0.9789
# Training: Batch 18/1000. Loss of 1.0540, cover loss of 0.8717, secret loss of 0.8209
# Training: Batch 19/1000. Loss of 1.0011, cover loss of 0.8494, secret loss of 0.7804
# Training: Batch 20/1000. Loss of 1.0637, cover loss of 0.8831, secret loss of 0.8166
# Training: Batch 21/1000. Loss of 1.0346, cover loss of 0.8892, secret loss of 0.8069
# Training: Batch 22/1000. Loss of 1.1179, cover loss of 0.9357, secret loss of 0.8348
# Training: Batch 23/1000. Loss of 1.1817, cover loss of 0.9580, secret loss of 0.8718
# Training: Batch 24/1000. Loss of 1.0870, cover loss of 0.8183, secret loss of 0.9321
# Training: Batch 25/1000. Loss of 1.1015, cover loss of 0.8842, secret loss of 0.8981
# Training: Batch 26/1000. Loss of 1.1449, cover loss of 0.9016, secret loss of 0.9534
# Training: Batch 27/1000. Loss of 1.0402, cover loss of 0.8414, secret loss of 0.8303
# Training: Batch 28/1000. Loss of 1.1822, cover loss of 0.9807, secret loss of 0.8885
# Training: Batch 29/1000. Loss of 1.1677, cover loss of 1.0518, secret loss of 0.8022
# Training: Batch 30/1000. Loss of 1.0182, cover loss of 0.8486, secret loss of 0.8455
# Training: Batch 31/1000. Loss of 1.0809, cover loss of 0.9278, secret loss of 0.8382
# Training: Batch 32/1000. Loss of 1.0637, cover loss of 0.8539, secret loss of 0.8916
# Training: Batch 33/1000. Loss of 1.3344, cover loss of 0.9634, secret loss of 1.0216
# Training: Batch 34/1000. Loss of 1.0065, cover loss of 0.7611, secret loss of 0.8908
# Training: Batch 35/1000. Loss of 1.0894, cover loss of 0.8011, secret loss of 0.9580
# Training: Batch 36/1000. Loss of 1.0930, cover loss of 0.9252, secret loss of 0.8348
# Training: Batch 37/1000. Loss of 1.1277, cover loss of 0.9156, secret loss of 0.9074
# Training: Batch 38/1000. Loss of 1.2058, cover loss of 1.0368, secret loss of 0.8591
# Training: Batch 39/1000. Loss of 1.0340, cover loss of 0.8461, secret loss of 0.8331
# Training: Batch 40/1000. Loss of 1.2032, cover loss of 0.9451, secret loss of 0.9355
# Training: Batch 41/1000. Loss of 1.1153, cover loss of 0.8812, secret loss of 0.8893
# Training: Batch 42/1000. Loss of 1.1064, cover loss of 0.9005, secret loss of 0.8817
# Training: Batch 43/1000. Loss of 1.1049, cover loss of 0.8648, secret loss of 0.8926
# Training: Batch 44/1000. Loss of 1.1902, cover loss of 0.8632, secret loss of 0.9855
# Training: Batch 45/1000. Loss of 1.1088, cover loss of 0.8613, secret loss of 0.9444
# Training: Batch 46/1000. Loss of 1.0250, cover loss of 0.8632, secret loss of 0.8256
# Training: Batch 47/1000. Loss of 1.2191, cover loss of 0.9711, secret loss of 0.9237
# Training: Batch 48/1000. Loss of 1.1897, cover loss of 0.9320, secret loss of 0.9216
# Training: Batch 49/1000. Loss of 1.1527, cover loss of 0.9540, secret loss of 0.8877
# Training: Batch 50/1000. Loss of 1.1639, cover loss of 0.8597, secret loss of 0.9948
# Training: Batch 51/1000. Loss of 1.1896, cover loss of 0.8870, secret loss of 0.9945
# Training: Batch 52/1000. Loss of 1.1465, cover loss of 0.8832, secret loss of 0.9672
# Training: Batch 53/1000. Loss of 1.1437, cover loss of 0.8820, secret loss of 0.9301
# Training: Batch 54/1000. Loss of 1.0298, cover loss of 0.8324, secret loss of 0.8709
# Training: Batch 55/1000. Loss of 1.1080, cover loss of 0.9075, secret loss of 0.8756
# Training: Batch 56/1000. Loss of 1.0060, cover loss of 0.8552, secret loss of 0.8560
# Training: Batch 57/1000. Loss of 1.1744, cover loss of 0.8960, secret loss of 0.9355
# Training: Batch 58/1000. Loss of 1.2163, cover loss of 0.9255, secret loss of 0.9874
# Training: Batch 59/1000. Loss of 1.2089, cover loss of 0.9182, secret loss of 0.9598
# Training: Batch 60/1000. Loss of 1.0260, cover loss of 0.7792, secret loss of 0.8929
# Training: Batch 61/1000. Loss of 1.0130, cover loss of 0.8019, secret loss of 0.8870
# Training: Batch 62/1000. Loss of 1.1330, cover loss of 0.9789, secret loss of 0.8013
# Training: Batch 63/1000. Loss of 1.1137, cover loss of 0.9472, secret loss of 0.8537
# Training: Batch 64/1000. Loss of 1.0324, cover loss of 0.8138, secret loss of 0.8711
# Training: Batch 65/1000. Loss of 1.1589, cover loss of 0.8995, secret loss of 0.9198
# Training: Batch 66/1000. Loss of 1.0566, cover loss of 0.7951, secret loss of 0.9063
# Training: Batch 67/1000. Loss of 1.0836, cover loss of 0.8079, secret loss of 0.9320
# Training: Batch 68/1000. Loss of 1.0870, cover loss of 0.9095, secret loss of 0.8261
# Training: Batch 69/1000. Loss of 1.2394, cover loss of 0.9541, secret loss of 0.9134
# Training: Batch 70/1000. Loss of 1.0555, cover loss of 0.8413, secret loss of 0.8595
# Training: Batch 71/1000. Loss of 1.0918, cover loss of 0.8510, secret loss of 0.9165
# Training: Batch 72/1000. Loss of 1.0227, cover loss of 0.8200, secret loss of 0.8249
# Training: Batch 73/1000. Loss of 1.1541, cover loss of 0.9369, secret loss of 0.8956
# Training: Batch 74/1000. Loss of 1.1324, cover loss of 0.8279, secret loss of 0.9478
# Training: Batch 75/1000. Loss of 1.0310, cover loss of 0.8817, secret loss of 0.8014
# Training: Batch 76/1000. Loss of 1.1317, cover loss of 0.9284, secret loss of 0.8722
# Training: Batch 77/1000. Loss of 1.0529, cover loss of 0.9145, secret loss of 0.8064
# Training: Batch 78/1000. Loss of 1.0265, cover loss of 0.9141, secret loss of 0.8198
# Training: Batch 79/1000. Loss of 1.0030, cover loss of 0.8211, secret loss of 0.8607
# Training: Batch 80/1000. Loss of 1.0500, cover loss of 0.8090, secret loss of 0.9199
# Training: Batch 81/1000. Loss of 1.0608, cover loss of 0.7743, secret loss of 0.9551
# Training: Batch 82/1000. Loss of 1.0391, cover loss of 0.8254, secret loss of 0.8843
# Training: Batch 83/1000. Loss of 1.0506, cover loss of 0.9020, secret loss of 0.8284
# Training: Batch 84/1000. Loss of 1.1688, cover loss of 0.8750, secret loss of 0.9695
# Training: Batch 85/1000. Loss of 1.1535, cover loss of 0.8868, secret loss of 0.9142
# Training: Batch 86/1000. Loss of 1.0530, cover loss of 0.9148, secret loss of 0.7922
# Training: Batch 87/1000. Loss of 1.1669, cover loss of 0.9737, secret loss of 0.8610
# Training: Batch 88/1000. Loss of 1.0883, cover loss of 0.8295, secret loss of 0.9323
# Training: Batch 89/1000. Loss of 1.0717, cover loss of 0.8982, secret loss of 0.8501
# Training: Batch 90/1000. Loss of 1.0289, cover loss of 0.7727, secret loss of 0.8919
# Training: Batch 91/1000. Loss of 1.1777, cover loss of 0.9040, secret loss of 0.9542
# Training: Batch 92/1000. Loss of 1.0362, cover loss of 0.8923, secret loss of 0.8197
# Training: Batch 93/1000. Loss of 1.0974, cover loss of 0.8341, secret loss of 0.9209
# Training: Batch 94/1000. Loss of 1.1462, cover loss of 0.8036, secret loss of 0.9895
# Training: Batch 95/1000. Loss of 1.1226, cover loss of 0.9240, secret loss of 0.8878
# Training: Batch 96/1000. Loss of 1.1517, cover loss of 0.9082, secret loss of 0.9060
# Training: Batch 97/1000. Loss of 1.1861, cover loss of 0.8708, secret loss of 1.0084
# Training: Batch 98/1000. Loss of 1.1631, cover loss of 0.8350, secret loss of 0.9922
# Training: Batch 99/1000. Loss of 1.1804, cover loss of 0.9435, secret loss of 0.9369
# Training: Batch 100/1000. Loss of 1.0224, cover loss of 0.8535, secret loss of 0.8462
# Training: Batch 101/1000. Loss of 1.1094, cover loss of 0.8506, secret loss of 0.8993
# Training: Batch 102/1000. Loss of 1.0983, cover loss of 0.9395, secret loss of 0.8499
# Training: Batch 103/1000. Loss of 1.0461, cover loss of 0.8588, secret loss of 0.8149
# Training: Batch 104/1000. Loss of 0.9798, cover loss of 0.8123, secret loss of 0.8395
# Training: Batch 105/1000. Loss of 0.9926, cover loss of 0.7681, secret loss of 0.8588
# Training: Batch 106/1000. Loss of 1.1378, cover loss of 0.9369, secret loss of 0.8502
# Training: Batch 107/1000. Loss of 1.1734, cover loss of 0.8901, secret loss of 0.9396
# Training: Batch 108/1000. Loss of 1.0709, cover loss of 0.8711, secret loss of 0.8603
# Training: Batch 109/1000. Loss of 0.9967, cover loss of 0.8070, secret loss of 0.8179
# Training: Batch 110/1000. Loss of 1.2755, cover loss of 0.9345, secret loss of 1.0288
# Training: Batch 111/1000. Loss of 1.0347, cover loss of 0.8692, secret loss of 0.8177
# Training: Batch 112/1000. Loss of 1.1806, cover loss of 0.9394, secret loss of 0.9379
# Training: Batch 113/1000. Loss of 1.0631, cover loss of 0.8401, secret loss of 0.8886
# Training: Batch 114/1000. Loss of 1.0510, cover loss of 0.8715, secret loss of 0.8265
# Training: Batch 115/1000. Loss of 1.2657, cover loss of 1.0302, secret loss of 0.9177
# Training: Batch 116/1000. Loss of 1.0046, cover loss of 0.8576, secret loss of 0.8490
# Training: Batch 117/1000. Loss of 1.1474, cover loss of 0.8825, secret loss of 0.9073
# Training: Batch 118/1000. Loss of 1.2662, cover loss of 0.8822, secret loss of 1.0302
# Training: Batch 119/1000. Loss of 1.2038, cover loss of 0.9828, secret loss of 0.9029
# Training: Batch 120/1000. Loss of 1.2399, cover loss of 0.9022, secret loss of 1.0078
# Training: Batch 121/1000. Loss of 1.1403, cover loss of 0.8852, secret loss of 0.9510
# Training: Batch 122/1000. Loss of 1.1202, cover loss of 0.8704, secret loss of 0.9321
# Training: Batch 123/1000. Loss of 1.0762, cover loss of 0.8091, secret loss of 0.9178
# Training: Batch 124/1000. Loss of 1.1721, cover loss of 0.9629, secret loss of 0.8592
# Training: Batch 125/1000. Loss of 1.0155, cover loss of 0.8127, secret loss of 0.8305
# Training: Batch 126/1000. Loss of 1.0457, cover loss of 0.8132, secret loss of 0.8890
# Training: Batch 127/1000. Loss of 1.1917, cover loss of 0.9001, secret loss of 0.9681
# Training: Batch 128/1000. Loss of 1.0893, cover loss of 0.9086, secret loss of 0.8589
# Training: Batch 129/1000. Loss of 1.0879, cover loss of 0.8934, secret loss of 0.8680
# Training: Batch 130/1000. Loss of 1.1194, cover loss of 1.0009, secret loss of 0.7679
# Training: Batch 131/1000. Loss of 1.1556, cover loss of 0.9061, secret loss of 0.9387
# Training: Batch 132/1000. Loss of 1.0761, cover loss of 0.8242, secret loss of 0.8994
# Training: Batch 133/1000. Loss of 1.1760, cover loss of 0.9150, secret loss of 0.9317
# Training: Batch 134/1000. Loss of 1.1270, cover loss of 0.9033, secret loss of 0.8848
# Training: Batch 135/1000. Loss of 1.2010, cover loss of 0.9310, secret loss of 0.9675
# Training: Batch 136/1000. Loss of 1.2464, cover loss of 1.1436, secret loss of 0.7943
# Training: Batch 137/1000. Loss of 1.1719, cover loss of 0.9345, secret loss of 0.8976
# Training: Batch 138/1000. Loss of 1.1052, cover loss of 0.8667, secret loss of 0.8864
# Training: Batch 139/1000. Loss of 1.0870, cover loss of 0.8255, secret loss of 0.9147
# Training: Batch 140/1000. Loss of 0.9952, cover loss of 0.7623, secret loss of 0.8906
# Training: Batch 141/1000. Loss of 1.0255, cover loss of 0.7935, secret loss of 0.9000
# Training: Batch 142/1000. Loss of 1.0153, cover loss of 0.8732, secret loss of 0.7917
# Training: Batch 143/1000. Loss of 1.0218, cover loss of 0.8422, secret loss of 0.8392
# Training: Batch 144/1000. Loss of 1.0783, cover loss of 0.8386, secret loss of 0.9200
# Training: Batch 145/1000. Loss of 1.0919, cover loss of 0.8931, secret loss of 0.8717
# Training: Batch 146/1000. Loss of 1.0745, cover loss of 0.9038, secret loss of 0.8284
# Training: Batch 147/1000. Loss of 1.1218, cover loss of 0.8386, secret loss of 0.9587
# Training: Batch 148/1000. Loss of 1.0259, cover loss of 0.8577, secret loss of 0.8038
# Training: Batch 149/1000. Loss of 1.0034, cover loss of 0.7724, secret loss of 0.8878
# Training: Batch 150/1000. Loss of 1.1847, cover loss of 0.9388, secret loss of 0.9274
# Training: Batch 151/1000. Loss of 1.0401, cover loss of 0.9329, secret loss of 0.8023
# Training: Batch 152/1000. Loss of 1.1254, cover loss of 0.9630, secret loss of 0.8247
# Training: Batch 153/1000. Loss of 1.0648, cover loss of 0.8391, secret loss of 0.9251
# Training: Batch 154/1000. Loss of 1.2853, cover loss of 1.0720, secret loss of 0.8770
# Training: Batch 155/1000. Loss of 1.1531, cover loss of 0.9302, secret loss of 0.8628
# Training: Batch 156/1000. Loss of 1.0486, cover loss of 0.8770, secret loss of 0.8059
# Training: Batch 157/1000. Loss of 1.0630, cover loss of 0.8355, secret loss of 0.8756
# Training: Batch 158/1000. Loss of 1.1845, cover loss of 0.8932, secret loss of 0.9638
# Training: Batch 159/1000. Loss of 1.2102, cover loss of 0.9936, secret loss of 0.8891
# Training: Batch 160/1000. Loss of 1.1009, cover loss of 0.8157, secret loss of 0.9596
# Training: Batch 161/1000. Loss of 1.0292, cover loss of 0.8605, secret loss of 0.7974
# Training: Batch 162/1000. Loss of 1.2145, cover loss of 0.8568, secret loss of 1.0251
# Training: Batch 163/1000. Loss of 1.1263, cover loss of 0.8768, secret loss of 0.9103
# Training: Batch 164/1000. Loss of 1.1789, cover loss of 1.0427, secret loss of 0.8184
# Training: Batch 165/1000. Loss of 1.1840, cover loss of 0.9763, secret loss of 0.8769
# Training: Batch 166/1000. Loss of 1.1064, cover loss of 0.8317, secret loss of 0.9370
# Training: Batch 167/1000. Loss of 1.1823, cover loss of 0.9154, secret loss of 0.9302
# Training: Batch 168/1000. Loss of 1.0677, cover loss of 0.8904, secret loss of 0.8367
# Training: Batch 169/1000. Loss of 1.0338, cover loss of 0.8484, secret loss of 0.8379
# Training: Batch 170/1000. Loss of 1.1018, cover loss of 0.8177, secret loss of 0.9712
# Training: Batch 171/1000. Loss of 1.0761, cover loss of 0.9619, secret loss of 0.7853
# Training: Batch 172/1000. Loss of 1.1145, cover loss of 0.9056, secret loss of 0.9015
# Training: Batch 173/1000. Loss of 0.9661, cover loss of 0.8062, secret loss of 0.8230
# Training: Batch 174/1000. Loss of 1.1156, cover loss of 0.7776, secret loss of 1.0001
# Training: Batch 175/1000. Loss of 1.2123, cover loss of 0.8919, secret loss of 0.9724
# Training: Batch 176/1000. Loss of 1.1864, cover loss of 0.8542, secret loss of 0.9887
# Training: Batch 177/1000. Loss of 0.9990, cover loss of 0.8550, secret loss of 0.8026
# Training: Batch 178/1000. Loss of 1.1077, cover loss of 0.9221, secret loss of 0.8025
# Training: Batch 179/1000. Loss of 1.1361, cover loss of 0.9292, secret loss of 0.8455
# Training: Batch 180/1000. Loss of 1.0497, cover loss of 0.8735, secret loss of 0.8159
# Training: Batch 181/1000. Loss of 1.0637, cover loss of 0.8292, secret loss of 0.8701
# Training: Batch 182/1000. Loss of 1.1161, cover loss of 0.8714, secret loss of 0.9193
# Training: Batch 183/1000. Loss of 1.2707, cover loss of 0.8344, secret loss of 1.0863
# Training: Batch 184/1000. Loss of 1.2310, cover loss of 0.9031, secret loss of 1.0136
# Training: Batch 185/1000. Loss of 1.1939, cover loss of 0.8907, secret loss of 0.9688
# Training: Batch 186/1000. Loss of 1.2569, cover loss of 0.9852, secret loss of 0.9634
# Training: Batch 187/1000. Loss of 0.9977, cover loss of 0.8173, secret loss of 0.8242
# Training: Batch 188/1000. Loss of 1.1088, cover loss of 0.9334, secret loss of 0.8560
# Training: Batch 189/1000. Loss of 1.1210, cover loss of 0.8944, secret loss of 0.9190
# Training: Batch 190/1000. Loss of 1.1071, cover loss of 0.8432, secret loss of 0.9373
# Training: Batch 191/1000. Loss of 1.0887, cover loss of 0.8404, secret loss of 0.9000
# Training: Batch 192/1000. Loss of 1.1436, cover loss of 0.9796, secret loss of 0.8035
# Training: Batch 193/1000. Loss of 1.0423, cover loss of 0.7782, secret loss of 0.9090
# Training: Batch 194/1000. Loss of 1.0124, cover loss of 0.8730, secret loss of 0.7693
# Training: Batch 195/1000. Loss of 1.0523, cover loss of 0.8116, secret loss of 0.8899
# Training: Batch 196/1000. Loss of 1.1759, cover loss of 0.8966, secret loss of 0.9653
# Training: Batch 197/1000. Loss of 1.0016, cover loss of 0.7520, secret loss of 0.9236
# Training: Batch 198/1000. Loss of 1.0864, cover loss of 0.8473, secret loss of 0.8952
# Training: Batch 199/1000. Loss of 1.1444, cover loss of 1.0043, secret loss of 0.8307
# Training: Batch 200/1000. Loss of 1.0916, cover loss of 0.8752, secret loss of 0.8583
# Training: Batch 201/1000. Loss of 1.0910, cover loss of 0.8999, secret loss of 0.8987
# Training: Batch 202/1000. Loss of 1.0705, cover loss of 0.9249, secret loss of 0.8164
# Training: Batch 203/1000. Loss of 1.0454, cover loss of 0.9190, secret loss of 0.8152
# Training: Batch 204/1000. Loss of 1.0599, cover loss of 0.9000, secret loss of 0.8445
# Training: Batch 205/1000. Loss of 1.1171, cover loss of 0.8590, secret loss of 0.9263
# Training: Batch 206/1000. Loss of 1.0017, cover loss of 0.8497, secret loss of 0.8479
# Training: Batch 207/1000. Loss of 1.1311, cover loss of 0.8435, secret loss of 0.9817
# Training: Batch 208/1000. Loss of 1.0949, cover loss of 0.9220, secret loss of 0.8652
# Training: Batch 209/1000. Loss of 0.9938, cover loss of 0.8466, secret loss of 0.8036
# Training: Batch 210/1000. Loss of 1.1582, cover loss of 0.8894, secret loss of 0.9686
# Training: Batch 211/1000. Loss of 1.1699, cover loss of 0.8605, secret loss of 0.9833
# Training: Batch 212/1000. Loss of 1.0397, cover loss of 0.8098, secret loss of 0.8938
# Training: Batch 213/1000. Loss of 1.0119, cover loss of 0.8149, secret loss of 0.8423
# Training: Batch 214/1000. Loss of 1.0245, cover loss of 0.8396, secret loss of 0.8629
# Training: Batch 215/1000. Loss of 1.1310, cover loss of 0.8843, secret loss of 0.9157
# Training: Batch 216/1000. Loss of 1.0928, cover loss of 0.8037, secret loss of 0.9613
# Training: Batch 217/1000. Loss of 1.2169, cover loss of 0.9496, secret loss of 0.9264
# Training: Batch 218/1000. Loss of 1.2670, cover loss of 0.9272, secret loss of 0.9785
# Training: Batch 219/1000. Loss of 0.9754, cover loss of 0.8509, secret loss of 0.7808
# Training: Batch 220/1000. Loss of 1.0476, cover loss of 0.8579, secret loss of 0.8443
# Training: Batch 221/1000. Loss of 1.0958, cover loss of 0.9069, secret loss of 0.8493
# Training: Batch 222/1000. Loss of 1.0483, cover loss of 0.9186, secret loss of 0.7944
# Training: Batch 223/1000. Loss of 1.0906, cover loss of 0.8892, secret loss of 0.8521
# Training: Batch 224/1000. Loss of 1.1518, cover loss of 0.8943, secret loss of 0.9355
# Training: Batch 225/1000. Loss of 1.0915, cover loss of 0.8621, secret loss of 0.8583
# Training: Batch 226/1000. Loss of 1.1454, cover loss of 0.9001, secret loss of 0.9160
# Training: Batch 227/1000. Loss of 1.1370, cover loss of 0.8704, secret loss of 0.9023
# Training: Batch 228/1000. Loss of 1.1759, cover loss of 0.9173, secret loss of 0.9165
# Training: Batch 229/1000. Loss of 1.0991, cover loss of 0.8212, secret loss of 0.9940
# Training: Batch 230/1000. Loss of 1.1873, cover loss of 0.8833, secret loss of 0.9558
# Training: Batch 231/1000. Loss of 1.0036, cover loss of 0.8298, secret loss of 0.8338
# Training: Batch 232/1000. Loss of 1.2898, cover loss of 0.8879, secret loss of 1.0711
# Training: Batch 233/1000. Loss of 1.1789, cover loss of 0.9175, secret loss of 0.9097
# Training: Batch 234/1000. Loss of 1.0974, cover loss of 0.8896, secret loss of 0.8773
# Training: Batch 235/1000. Loss of 1.1290, cover loss of 0.7645, secret loss of 0.9877
# Training: Batch 236/1000. Loss of 1.0814, cover loss of 0.8706, secret loss of 0.8640
# Training: Batch 237/1000. Loss of 1.1517, cover loss of 0.9573, secret loss of 0.8750
# Training: Batch 238/1000. Loss of 1.1236, cover loss of 0.9405, secret loss of 0.8563
# Training: Batch 239/1000. Loss of 1.1678, cover loss of 0.9306, secret loss of 0.9026
# Training: Batch 240/1000. Loss of 1.1455, cover loss of 0.8731, secret loss of 0.9408
# Training: Batch 241/1000. Loss of 1.0862, cover loss of 0.8058, secret loss of 0.9233
# Training: Batch 242/1000. Loss of 1.0783, cover loss of 0.8789, secret loss of 0.8568
# Training: Batch 243/1000. Loss of 1.1339, cover loss of 0.9164, secret loss of 0.9059
# Training: Batch 244/1000. Loss of 1.2092, cover loss of 0.9526, secret loss of 0.9267
# Training: Batch 245/1000. Loss of 1.0316, cover loss of 0.8583, secret loss of 0.8404
# Training: Batch 246/1000. Loss of 1.2007, cover loss of 1.0404, secret loss of 0.8371
# Training: Batch 247/1000. Loss of 1.1085, cover loss of 0.9798, secret loss of 0.7985
# Training: Batch 248/1000. Loss of 1.0635, cover loss of 0.8592, secret loss of 0.8619
# Training: Batch 249/1000. Loss of 1.0747, cover loss of 0.8361, secret loss of 0.8935
# Training: Batch 250/1000. Loss of 1.0635, cover loss of 0.8500, secret loss of 0.8686
# Training: Batch 251/1000. Loss of 1.0250, cover loss of 0.7792, secret loss of 0.8878
# Training: Batch 252/1000. Loss of 1.0111, cover loss of 0.8277, secret loss of 0.8316
# Training: Batch 253/1000. Loss of 1.2562, cover loss of 1.0663, secret loss of 0.9169
# Training: Batch 254/1000. Loss of 0.9648, cover loss of 0.7718, secret loss of 0.8229
# Training: Batch 255/1000. Loss of 1.1413, cover loss of 0.8586, secret loss of 0.9534
# Training: Batch 256/1000. Loss of 0.9737, cover loss of 0.8577, secret loss of 0.7916
# Training: Batch 257/1000. Loss of 1.0803, cover loss of 0.9005, secret loss of 0.8579
# Training: Batch 258/1000. Loss of 1.1912, cover loss of 0.8822, secret loss of 0.9851
# Training: Batch 259/1000. Loss of 1.1548, cover loss of 0.9807, secret loss of 0.8709
# Training: Batch 260/1000. Loss of 1.0591, cover loss of 0.8948, secret loss of 0.8550
# Training: Batch 261/1000. Loss of 1.0235, cover loss of 0.8105, secret loss of 0.8750
# Training: Batch 262/1000. Loss of 1.0373, cover loss of 0.7964, secret loss of 0.9048
# Training: Batch 263/1000. Loss of 1.1446, cover loss of 0.8650, secret loss of 0.9592
# Training: Batch 264/1000. Loss of 1.1983, cover loss of 0.9141, secret loss of 0.9790
# Training: Batch 265/1000. Loss of 1.0617, cover loss of 0.8615, secret loss of 0.8368
# Training: Batch 266/1000. Loss of 1.1062, cover loss of 0.8521, secret loss of 0.9343
# Training: Batch 267/1000. Loss of 1.0005, cover loss of 0.9078, secret loss of 0.7384
# Training: Batch 268/1000. Loss of 1.2363, cover loss of 0.9799, secret loss of 0.9419
# Training: Batch 269/1000. Loss of 1.0692, cover loss of 0.8087, secret loss of 0.9045
# Training: Batch 270/1000. Loss of 1.2416, cover loss of 1.0050, secret loss of 0.9361
# Training: Batch 271/1000. Loss of 1.1466, cover loss of 0.9766, secret loss of 0.8730
# Training: Batch 272/1000. Loss of 1.1219, cover loss of 0.8925, secret loss of 0.9119
# Training: Batch 273/1000. Loss of 1.1881, cover loss of 0.8607, secret loss of 1.0142
# Training: Batch 274/1000. Loss of 1.0995, cover loss of 0.8656, secret loss of 0.9006
# Training: Batch 275/1000. Loss of 0.9715, cover loss of 0.7352, secret loss of 0.8851
# Training: Batch 276/1000. Loss of 1.1103, cover loss of 0.9705, secret loss of 0.8427
# Training: Batch 277/1000. Loss of 1.0063, cover loss of 0.8030, secret loss of 0.8668
# Training: Batch 278/1000. Loss of 1.0684, cover loss of 0.9101, secret loss of 0.8319
# Training: Batch 279/1000. Loss of 0.9822, cover loss of 0.8651, secret loss of 0.7665
# Training: Batch 280/1000. Loss of 1.0543, cover loss of 0.8351, secret loss of 0.8818
# Training: Batch 281/1000. Loss of 0.9813, cover loss of 0.8798, secret loss of 0.7436
# Training: Batch 282/1000. Loss of 1.1621, cover loss of 0.9215, secret loss of 0.9079
# Training: Batch 283/1000. Loss of 1.0981, cover loss of 0.9072, secret loss of 0.8644
# Training: Batch 284/1000. Loss of 1.1929, cover loss of 0.9481, secret loss of 0.9323
# Training: Batch 285/1000. Loss of 1.1573, cover loss of 0.9349, secret loss of 0.9148
# Training: Batch 286/1000. Loss of 1.0286, cover loss of 0.8166, secret loss of 0.8694
# Training: Batch 287/1000. Loss of 1.1576, cover loss of 0.9242, secret loss of 0.8982
# Training: Batch 288/1000. Loss of 1.0947, cover loss of 0.8900, secret loss of 0.8553
# Training: Batch 289/1000. Loss of 1.1942, cover loss of 0.9943, secret loss of 0.8672
# Training: Batch 290/1000. Loss of 1.2476, cover loss of 0.9295, secret loss of 0.9981
# Training: Batch 291/1000. Loss of 1.1061, cover loss of 0.8264, secret loss of 0.9318
# Training: Batch 292/1000. Loss of 1.2122, cover loss of 0.9054, secret loss of 0.9939
# Training: Batch 293/1000. Loss of 1.1209, cover loss of 0.9229, secret loss of 0.8804
# Training: Batch 294/1000. Loss of 1.1088, cover loss of 0.9468, secret loss of 0.8312
# Training: Batch 295/1000. Loss of 1.0207, cover loss of 0.8547, secret loss of 0.8255
# Training: Batch 296/1000. Loss of 0.9406, cover loss of 0.8471, secret loss of 0.7499
# Training: Batch 297/1000. Loss of 1.1055, cover loss of 0.8504, secret loss of 0.9197
# Training: Batch 298/1000. Loss of 1.0656, cover loss of 0.8528, secret loss of 0.8952
# Training: Batch 299/1000. Loss of 1.1329, cover loss of 0.8582, secret loss of 0.9586
# Training: Batch 300/1000. Loss of 1.1806, cover loss of 0.9448, secret loss of 0.9218
# Training: Batch 301/1000. Loss of 1.0774, cover loss of 0.7925, secret loss of 0.9316
# Training: Batch 302/1000. Loss of 1.0449, cover loss of 0.9002, secret loss of 0.8007
# Training: Batch 303/1000. Loss of 1.0225, cover loss of 0.9196, secret loss of 0.7605
# Training: Batch 304/1000. Loss of 1.2950, cover loss of 1.0063, secret loss of 0.9857
# Training: Batch 305/1000. Loss of 1.1652, cover loss of 0.9806, secret loss of 0.8726
# Training: Batch 306/1000. Loss of 1.1558, cover loss of 0.9041, secret loss of 0.9435
# Training: Batch 307/1000. Loss of 1.1445, cover loss of 0.9808, secret loss of 0.8840
# Training: Batch 308/1000. Loss of 1.0857, cover loss of 0.8337, secret loss of 0.9077
# Training: Batch 309/1000. Loss of 1.0556, cover loss of 0.8586, secret loss of 0.8763
# Training: Batch 310/1000. Loss of 1.0802, cover loss of 0.8695, secret loss of 0.8903
# Training: Batch 311/1000. Loss of 1.2580, cover loss of 0.9467, secret loss of 0.9849
# Training: Batch 312/1000. Loss of 1.1060, cover loss of 0.9640, secret loss of 0.7915
# Training: Batch 313/1000. Loss of 1.0318, cover loss of 0.8053, secret loss of 0.8493
# Training: Batch 314/1000. Loss of 1.0475, cover loss of 0.8999, secret loss of 0.8167
# Training: Batch 315/1000. Loss of 0.9728, cover loss of 0.7768, secret loss of 0.8222
# Training: Batch 316/1000. Loss of 1.0623, cover loss of 0.8696, secret loss of 0.8408
# Training: Batch 317/1000. Loss of 1.1352, cover loss of 0.9161, secret loss of 0.8801
# Training: Batch 318/1000. Loss of 1.1025, cover loss of 0.8548, secret loss of 0.9130
# Training: Batch 319/1000. Loss of 1.0596, cover loss of 0.9115, secret loss of 0.8030
# Training: Batch 320/1000. Loss of 1.0957, cover loss of 0.9190, secret loss of 0.8296
# Training: Batch 321/1000. Loss of 1.0613, cover loss of 0.8143, secret loss of 0.9097
# Training: Batch 322/1000. Loss of 1.1401, cover loss of 0.8841, secret loss of 0.9430
# Training: Batch 323/1000. Loss of 1.1445, cover loss of 0.9096, secret loss of 0.9351
# Training: Batch 324/1000. Loss of 1.2799, cover loss of 0.8475, secret loss of 1.0934
# Training: Batch 325/1000. Loss of 1.0716, cover loss of 0.8914, secret loss of 0.8443
# Training: Batch 326/1000. Loss of 1.0899, cover loss of 0.8594, secret loss of 0.9356
# Training: Batch 327/1000. Loss of 1.1670, cover loss of 0.9442, secret loss of 0.9097
# Training: Batch 328/1000. Loss of 1.0703, cover loss of 0.8158, secret loss of 0.9446
# Training: Batch 329/1000. Loss of 1.0947, cover loss of 0.9338, secret loss of 0.8579
# Training: Batch 330/1000. Loss of 1.0571, cover loss of 0.8649, secret loss of 0.8516
# Training: Batch 331/1000. Loss of 1.0526, cover loss of 0.8903, secret loss of 0.8415
# Training: Batch 332/1000. Loss of 0.9550, cover loss of 0.7934, secret loss of 0.8238
# Training: Batch 333/1000. Loss of 1.1604, cover loss of 1.0206, secret loss of 0.7942
# Training: Batch 334/1000. Loss of 0.9745, cover loss of 0.7047, secret loss of 0.9246
# Training: Batch 335/1000. Loss of 1.1137, cover loss of 0.8422, secret loss of 0.9176
# Training: Batch 336/1000. Loss of 1.1611, cover loss of 0.9212, secret loss of 0.9152
# Training: Batch 337/1000. Loss of 1.2636, cover loss of 0.9405, secret loss of 0.9962
# Training: Batch 338/1000. Loss of 1.0916, cover loss of 0.9262, secret loss of 0.8375
# Training: Batch 339/1000. Loss of 1.1214, cover loss of 0.7715, secret loss of 1.0004
# Training: Batch 340/1000. Loss of 1.0367, cover loss of 0.8351, secret loss of 0.8613
# Training: Batch 341/1000. Loss of 1.1560, cover loss of 0.9476, secret loss of 0.8578
# Training: Batch 342/1000. Loss of 1.1148, cover loss of 0.8944, secret loss of 0.8885
# Training: Batch 343/1000. Loss of 1.1720, cover loss of 1.0139, secret loss of 0.8386
# Training: Batch 344/1000. Loss of 1.1549, cover loss of 0.8965, secret loss of 0.9135
# Training: Batch 345/1000. Loss of 1.1190, cover loss of 0.8740, secret loss of 0.8990
# Training: Batch 346/1000. Loss of 1.2098, cover loss of 0.9273, secret loss of 0.9463
# Training: Batch 347/1000. Loss of 1.1726, cover loss of 1.0038, secret loss of 0.8474
# Training: Batch 348/1000. Loss of 1.2003, cover loss of 0.8980, secret loss of 0.9855
# Training: Batch 349/1000. Loss of 1.0626, cover loss of 0.7308, secret loss of 0.9519
# Training: Batch 350/1000. Loss of 1.1213, cover loss of 0.8635, secret loss of 0.9556
# Training: Batch 351/1000. Loss of 1.1506, cover loss of 0.8295, secret loss of 1.0067
# Training: Batch 352/1000. Loss of 1.0735, cover loss of 0.8638, secret loss of 0.8740
# Training: Batch 353/1000. Loss of 0.9539, cover loss of 0.7975, secret loss of 0.8018
# Training: Batch 354/1000. Loss of 0.9872, cover loss of 0.7282, secret loss of 0.8893
# Training: Batch 355/1000. Loss of 1.1112, cover loss of 0.9529, secret loss of 0.8247
# Training: Batch 356/1000. Loss of 0.9762, cover loss of 0.8379, secret loss of 0.7816
# Training: Batch 357/1000. Loss of 1.1693, cover loss of 0.8763, secret loss of 0.9619
# Training: Batch 358/1000. Loss of 1.1517, cover loss of 0.9311, secret loss of 0.8957
# Training: Batch 359/1000. Loss of 1.1009, cover loss of 0.8709, secret loss of 0.9039
# Training: Batch 360/1000. Loss of 1.1190, cover loss of 0.9418, secret loss of 0.8386
# Training: Batch 361/1000. Loss of 1.1706, cover loss of 0.9209, secret loss of 0.9149
# Training: Batch 362/1000. Loss of 1.1901, cover loss of 0.9184, secret loss of 0.9387
# Training: Batch 363/1000. Loss of 1.1970, cover loss of 0.9563, secret loss of 0.9311
# Training: Batch 364/1000. Loss of 1.0339, cover loss of 0.8147, secret loss of 0.8861
# Training: Batch 365/1000. Loss of 1.1747, cover loss of 0.9064, secret loss of 0.9402
# Training: Batch 366/1000. Loss of 1.1616, cover loss of 0.8952, secret loss of 0.9439
# Training: Batch 367/1000. Loss of 1.1849, cover loss of 0.9570, secret loss of 0.9310
# Training: Batch 368/1000. Loss of 1.1561, cover loss of 0.8857, secret loss of 0.9330
# Training: Batch 369/1000. Loss of 1.1047, cover loss of 0.8777, secret loss of 0.9037
# Training: Batch 370/1000. Loss of 1.0174, cover loss of 0.8914, secret loss of 0.7891
# Training: Batch 371/1000. Loss of 0.9583, cover loss of 0.8493, secret loss of 0.7787
# Training: Batch 372/1000. Loss of 1.1134, cover loss of 0.9328, secret loss of 0.8496
# Training: Batch 373/1000. Loss of 1.0660, cover loss of 0.8726, secret loss of 0.8592
# Training: Batch 374/1000. Loss of 1.1767, cover loss of 0.9285, secret loss of 0.9011
# Training: Batch 375/1000. Loss of 1.1136, cover loss of 0.9702, secret loss of 0.8121
# Training: Batch 376/1000. Loss of 1.2007, cover loss of 0.9448, secret loss of 0.9486
# Training: Batch 377/1000. Loss of 1.0165, cover loss of 0.8293, secret loss of 0.8189
# Training: Batch 378/1000. Loss of 1.1065, cover loss of 0.8440, secret loss of 0.9627
# Training: Batch 379/1000. Loss of 1.0901, cover loss of 0.8761, secret loss of 0.8791
# Training: Batch 380/1000. Loss of 0.9869, cover loss of 0.8369, secret loss of 0.7850
# Training: Batch 381/1000. Loss of 1.0324, cover loss of 0.7960, secret loss of 0.9154
# Training: Batch 382/1000. Loss of 1.1917, cover loss of 0.8901, secret loss of 0.9562
# Training: Batch 383/1000. Loss of 1.1546, cover loss of 0.8921, secret loss of 0.9080
# Training: Batch 384/1000. Loss of 1.1210, cover loss of 0.9536, secret loss of 0.8178
# Training: Batch 385/1000. Loss of 1.1545, cover loss of 0.9785, secret loss of 0.8212
# Training: Batch 386/1000. Loss of 1.0997, cover loss of 0.8184, secret loss of 0.9640
# Training: Batch 387/1000. Loss of 1.0575, cover loss of 0.8538, secret loss of 0.8725
# Training: Batch 388/1000. Loss of 1.1165, cover loss of 0.8834, secret loss of 0.8976
# Training: Batch 389/1000. Loss of 1.0251, cover loss of 0.8524, secret loss of 0.8324
# Training: Batch 390/1000. Loss of 0.9960, cover loss of 0.8054, secret loss of 0.8419
# Training: Batch 391/1000. Loss of 1.1295, cover loss of 0.9304, secret loss of 0.8784
# Training: Batch 392/1000. Loss of 1.1853, cover loss of 0.9940, secret loss of 0.8573
# Training: Batch 393/1000. Loss of 1.0293, cover loss of 0.8140, secret loss of 0.8637
# Training: Batch 394/1000. Loss of 1.1638, cover loss of 0.8503, secret loss of 0.9872
# Training: Batch 395/1000. Loss of 1.0509, cover loss of 0.8371, secret loss of 0.8680
# Training: Batch 396/1000. Loss of 1.1014, cover loss of 0.8332, secret loss of 0.9399
# Training: Batch 397/1000. Loss of 0.9861, cover loss of 0.8827, secret loss of 0.7429
# Training: Batch 398/1000. Loss of 1.0755, cover loss of 0.8690, secret loss of 0.8767
# Training: Batch 399/1000. Loss of 1.0977, cover loss of 0.8501, secret loss of 0.9263
# Training: Batch 400/1000. Loss of 1.0703, cover loss of 0.8262, secret loss of 0.9304
# Training: Batch 401/1000. Loss of 1.1215, cover loss of 0.8570, secret loss of 0.9220
# Training: Batch 402/1000. Loss of 1.1443, cover loss of 0.8811, secret loss of 0.9421
# Training: Batch 403/1000. Loss of 1.0280, cover loss of 0.8089, secret loss of 0.8789
# Training: Batch 404/1000. Loss of 1.1192, cover loss of 0.8884, secret loss of 0.9315
# Training: Batch 405/1000. Loss of 1.2093, cover loss of 0.8782, secret loss of 0.9990
# Training: Batch 406/1000. Loss of 1.1329, cover loss of 0.8558, secret loss of 0.9416
# Training: Batch 407/1000. Loss of 1.1660, cover loss of 0.9326, secret loss of 0.8952
# Training: Batch 408/1000. Loss of 1.0961, cover loss of 0.9251, secret loss of 0.8525
# Training: Batch 409/1000. Loss of 1.0128, cover loss of 0.7910, secret loss of 0.8829
# Training: Batch 410/1000. Loss of 0.9745, cover loss of 0.7816, secret loss of 0.8548
# Training: Batch 411/1000. Loss of 1.0794, cover loss of 0.9283, secret loss of 0.8293
# Training: Batch 412/1000. Loss of 1.0368, cover loss of 0.8218, secret loss of 0.8911
# Training: Batch 413/1000. Loss of 1.0106, cover loss of 0.8614, secret loss of 0.7964
# Training: Batch 414/1000. Loss of 1.1871, cover loss of 0.9682, secret loss of 0.8819
# Training: Batch 415/1000. Loss of 1.0464, cover loss of 0.8199, secret loss of 0.8739
# Training: Batch 416/1000. Loss of 1.2713, cover loss of 1.0205, secret loss of 0.9274
# Training: Batch 417/1000. Loss of 1.1888, cover loss of 0.9021, secret loss of 1.0083
# Training: Batch 418/1000. Loss of 1.1763, cover loss of 0.9312, secret loss of 0.9126
# Training: Batch 419/1000. Loss of 1.0287, cover loss of 0.8302, secret loss of 0.8444
# Training: Batch 420/1000. Loss of 1.1692, cover loss of 0.8913, secret loss of 0.9500
# Training: Batch 421/1000. Loss of 1.0925, cover loss of 0.9231, secret loss of 0.8336
# Training: Batch 422/1000. Loss of 1.0515, cover loss of 0.8585, secret loss of 0.8814
# Training: Batch 423/1000. Loss of 1.2082, cover loss of 0.8909, secret loss of 0.9525
# Training: Batch 424/1000. Loss of 1.0631, cover loss of 0.8238, secret loss of 0.9074
# Training: Batch 425/1000. Loss of 1.0808, cover loss of 0.9039, secret loss of 0.8581
# Training: Batch 426/1000. Loss of 1.1472, cover loss of 0.9071, secret loss of 0.9120
# Training: Batch 427/1000. Loss of 1.1250, cover loss of 0.8152, secret loss of 0.9792
# Training: Batch 428/1000. Loss of 1.0402, cover loss of 0.8553, secret loss of 0.8586
# Training: Batch 429/1000. Loss of 1.1535, cover loss of 0.9732, secret loss of 0.8455
# Training: Batch 430/1000. Loss of 0.9420, cover loss of 0.7899, secret loss of 0.7988
# Training: Batch 431/1000. Loss of 1.2305, cover loss of 0.9124, secret loss of 1.0126
# Training: Batch 432/1000. Loss of 1.0753, cover loss of 0.8901, secret loss of 0.8477
# Training: Batch 433/1000. Loss of 1.1489, cover loss of 0.9405, secret loss of 0.9098
# Training: Batch 434/1000. Loss of 1.0891, cover loss of 0.8388, secret loss of 0.9001
# Training: Batch 435/1000. Loss of 1.0820, cover loss of 0.9159, secret loss of 0.8217
# Training: Batch 436/1000. Loss of 1.0446, cover loss of 0.8368, secret loss of 0.8486
# Training: Batch 437/1000. Loss of 1.0429, cover loss of 0.8942, secret loss of 0.8004
# Training: Batch 438/1000. Loss of 1.0881, cover loss of 0.8528, secret loss of 0.9149
# Training: Batch 439/1000. Loss of 1.1829, cover loss of 0.8944, secret loss of 0.9611
# Training: Batch 440/1000. Loss of 1.1480, cover loss of 0.9050, secret loss of 0.9158
# Training: Batch 441/1000. Loss of 1.2352, cover loss of 0.9365, secret loss of 0.9744
# Training: Batch 442/1000. Loss of 1.1104, cover loss of 0.8357, secret loss of 0.9631
# Training: Batch 443/1000. Loss of 1.0581, cover loss of 0.9371, secret loss of 0.8041
# Training: Batch 444/1000. Loss of 1.1197, cover loss of 0.9128, secret loss of 0.8476
# Training: Batch 445/1000. Loss of 1.1792, cover loss of 0.9244, secret loss of 0.9381
# Training: Batch 446/1000. Loss of 1.1671, cover loss of 1.0010, secret loss of 0.8722
# Training: Batch 447/1000. Loss of 1.1779, cover loss of 0.9602, secret loss of 0.8851
# Training: Batch 448/1000. Loss of 1.1923, cover loss of 0.8447, secret loss of 1.0379
# Training: Batch 449/1000. Loss of 1.0944, cover loss of 0.8927, secret loss of 0.8894
# Training: Batch 450/1000. Loss of 1.2234, cover loss of 1.0858, secret loss of 0.8248
# Training: Batch 451/1000. Loss of 1.0705, cover loss of 0.8890, secret loss of 0.8426
# Training: Batch 452/1000. Loss of 1.0649, cover loss of 0.8958, secret loss of 0.8690
# Training: Batch 453/1000. Loss of 1.1014, cover loss of 0.8423, secret loss of 0.8956
# Training: Batch 454/1000. Loss of 1.1385, cover loss of 0.9536, secret loss of 0.8706
# Training: Batch 455/1000. Loss of 1.1042, cover loss of 0.8678, secret loss of 0.8904
# Training: Batch 456/1000. Loss of 1.1307, cover loss of 0.8604, secret loss of 0.9396
# Training: Batch 457/1000. Loss of 1.0084, cover loss of 0.8354, secret loss of 0.8185
# Training: Batch 458/1000. Loss of 1.0541, cover loss of 0.8022, secret loss of 0.9125
# Training: Batch 459/1000. Loss of 1.0435, cover loss of 0.8366, secret loss of 0.8875
# Training: Batch 460/1000. Loss of 1.2219, cover loss of 0.8333, secret loss of 1.0020
# Training: Batch 461/1000. Loss of 1.1718, cover loss of 0.9031, secret loss of 0.9395
# Training: Batch 462/1000. Loss of 1.0355, cover loss of 0.8814, secret loss of 0.8253
# Training: Batch 463/1000. Loss of 1.1270, cover loss of 0.9772, secret loss of 0.7876
# Training: Batch 464/1000. Loss of 1.2263, cover loss of 0.9772, secret loss of 0.9403
# Training: Batch 465/1000. Loss of 0.9363, cover loss of 0.7134, secret loss of 0.8637
# Training: Batch 466/1000. Loss of 1.2465, cover loss of 0.8738, secret loss of 1.0340
# Training: Batch 467/1000. Loss of 1.2226, cover loss of 0.9877, secret loss of 0.8972
# Training: Batch 468/1000. Loss of 1.0533, cover loss of 0.8856, secret loss of 0.8161
# Training: Batch 469/1000. Loss of 1.1615, cover loss of 0.9181, secret loss of 0.9530
# Training: Batch 470/1000. Loss of 1.1200, cover loss of 0.9969, secret loss of 0.7908
# Training: Batch 471/1000. Loss of 1.1816, cover loss of 0.9153, secret loss of 0.9404
# Training: Batch 472/1000. Loss of 1.1110, cover loss of 0.9230, secret loss of 0.8748
# Training: Batch 473/1000. Loss of 1.1254, cover loss of 0.9622, secret loss of 0.8636
# Training: Batch 474/1000. Loss of 1.2434, cover loss of 0.9752, secret loss of 0.9494
# Training: Batch 475/1000. Loss of 1.0416, cover loss of 0.8398, secret loss of 0.8762
# Training: Batch 476/1000. Loss of 1.0793, cover loss of 0.8579, secret loss of 0.8979
# Training: Batch 477/1000. Loss of 1.2203, cover loss of 0.9038, secret loss of 0.9868
# Training: Batch 478/1000. Loss of 1.1151, cover loss of 0.8292, secret loss of 0.9492
# Training: Batch 479/1000. Loss of 1.0767, cover loss of 0.8692, secret loss of 0.8574
# Training: Batch 480/1000. Loss of 1.1856, cover loss of 0.9339, secret loss of 0.9473
# Training: Batch 481/1000. Loss of 1.1755, cover loss of 0.8575, secret loss of 0.9575
# Training: Batch 482/1000. Loss of 1.0795, cover loss of 0.8574, secret loss of 0.8830
# Training: Batch 483/1000. Loss of 1.0015, cover loss of 0.8080, secret loss of 0.8537
# Training: Batch 484/1000. Loss of 1.0055, cover loss of 0.8646, secret loss of 0.7921
# Training: Batch 485/1000. Loss of 1.0891, cover loss of 0.8865, secret loss of 0.8736
# Training: Batch 486/1000. Loss of 0.9759, cover loss of 0.7266, secret loss of 0.8989
# Training: Batch 487/1000. Loss of 1.0534, cover loss of 0.8685, secret loss of 0.8744
# Training: Batch 488/1000. Loss of 1.0888, cover loss of 0.8807, secret loss of 0.8805
# Training: Batch 489/1000. Loss of 1.1644, cover loss of 0.8993, secret loss of 0.9527
# Training: Batch 490/1000. Loss of 1.0787, cover loss of 0.9116, secret loss of 0.8476
# Training: Batch 491/1000. Loss of 1.1242, cover loss of 0.8767, secret loss of 0.9059
# Training: Batch 492/1000. Loss of 1.0097, cover loss of 0.8382, secret loss of 0.8277
# Training: Batch 493/1000. Loss of 1.1527, cover loss of 0.9339, secret loss of 0.9049
# Training: Batch 494/1000. Loss of 1.1917, cover loss of 0.8913, secret loss of 0.9350
# Training: Batch 495/1000. Loss of 1.1391, cover loss of 0.8737, secret loss of 0.9420
# Training: Batch 496/1000. Loss of 1.1712, cover loss of 0.9691, secret loss of 0.8809
# Training: Batch 497/1000. Loss of 1.0398, cover loss of 0.8213, secret loss of 0.9036
# Training: Batch 498/1000. Loss of 1.0306, cover loss of 0.8291, secret loss of 0.8747
# Training: Batch 499/1000. Loss of 0.9988, cover loss of 0.7826, secret loss of 0.8408
# Training: Batch 500/1000. Loss of 1.1037, cover loss of 0.9347, secret loss of 0.8073
# Training: Batch 501/1000. Loss of 1.1187, cover loss of 0.9692, secret loss of 0.7988
# Training: Batch 502/1000. Loss of 1.1941, cover loss of 0.8551, secret loss of 1.0146
# Training: Batch 503/1000. Loss of 1.0675, cover loss of 0.8166, secret loss of 0.9193
# Training: Batch 504/1000. Loss of 1.0889, cover loss of 0.8045, secret loss of 0.9615
# Training: Batch 505/1000. Loss of 1.0225, cover loss of 0.8828, secret loss of 0.8116
# Training: Batch 506/1000. Loss of 1.2190, cover loss of 0.9438, secret loss of 0.9181
# Training: Batch 507/1000. Loss of 1.0984, cover loss of 0.8910, secret loss of 0.8891
# Training: Batch 508/1000. Loss of 1.1378, cover loss of 0.8636, secret loss of 0.9010
# Training: Batch 509/1000. Loss of 1.1349, cover loss of 0.8332, secret loss of 0.9779
# Training: Batch 510/1000. Loss of 1.1002, cover loss of 0.8850, secret loss of 0.8863
# Training: Batch 511/1000. Loss of 0.9837, cover loss of 0.8558, secret loss of 0.7571
# Training: Batch 512/1000. Loss of 1.0707, cover loss of 0.8052, secret loss of 0.9328
# Training: Batch 513/1000. Loss of 1.2010, cover loss of 0.9741, secret loss of 0.9271
# Training: Batch 514/1000. Loss of 1.0716, cover loss of 0.8790, secret loss of 0.8680
# Training: Batch 515/1000. Loss of 0.9637, cover loss of 0.7595, secret loss of 0.8584
# Training: Batch 516/1000. Loss of 1.0604, cover loss of 0.8801, secret loss of 0.8865
# Training: Batch 517/1000. Loss of 1.3004, cover loss of 1.0111, secret loss of 0.9576
# Training: Batch 518/1000. Loss of 1.0614, cover loss of 0.8523, secret loss of 0.8806
# Training: Batch 519/1000. Loss of 1.0556, cover loss of 0.8129, secret loss of 0.8964
# Training: Batch 520/1000. Loss of 1.0494, cover loss of 0.9493, secret loss of 0.7571
# Training: Batch 521/1000. Loss of 1.0701, cover loss of 0.8354, secret loss of 0.8897
# Training: Batch 522/1000. Loss of 1.1769, cover loss of 1.0053, secret loss of 0.8877
# Training: Batch 523/1000. Loss of 1.0603, cover loss of 0.8793, secret loss of 0.8412
# Training: Batch 524/1000. Loss of 1.2121, cover loss of 0.9270, secret loss of 0.9664
# Training: Batch 525/1000. Loss of 1.1879, cover loss of 0.8960, secret loss of 0.9417
# Training: Batch 526/1000. Loss of 1.1075, cover loss of 0.9583, secret loss of 0.8039
# Training: Batch 527/1000. Loss of 1.0508, cover loss of 0.8438, secret loss of 0.8643
# Training: Batch 528/1000. Loss of 1.1614, cover loss of 0.9160, secret loss of 0.9157
# Training: Batch 529/1000. Loss of 1.2860, cover loss of 1.0148, secret loss of 0.9596
# Training: Batch 530/1000. Loss of 1.1579, cover loss of 0.9221, secret loss of 0.9382
# Training: Batch 531/1000. Loss of 0.9595, cover loss of 0.8070, secret loss of 0.8211
# Training: Batch 532/1000. Loss of 1.0917, cover loss of 0.9063, secret loss of 0.8585
# Training: Batch 533/1000. Loss of 0.9315, cover loss of 0.8663, secret loss of 0.7224
# Training: Batch 534/1000. Loss of 1.0335, cover loss of 0.8250, secret loss of 0.8650
# Training: Batch 535/1000. Loss of 1.1111, cover loss of 0.8936, secret loss of 0.9021
# Training: Batch 536/1000. Loss of 1.1755, cover loss of 0.9058, secret loss of 0.9481
# Training: Batch 537/1000. Loss of 1.1707, cover loss of 0.9944, secret loss of 0.8361
# Training: Batch 538/1000. Loss of 1.1756, cover loss of 0.8817, secret loss of 0.9671
# Training: Batch 539/1000. Loss of 1.0387, cover loss of 0.8536, secret loss of 0.8340
# Training: Batch 540/1000. Loss of 1.0187, cover loss of 0.8366, secret loss of 0.8646
# Training: Batch 541/1000. Loss of 1.0765, cover loss of 0.9168, secret loss of 0.8018
# Training: Batch 542/1000. Loss of 0.9975, cover loss of 0.8403, secret loss of 0.8155
# Training: Batch 543/1000. Loss of 1.1033, cover loss of 0.9061, secret loss of 0.8608
# Training: Batch 544/1000. Loss of 1.0860, cover loss of 0.8779, secret loss of 0.9031
# Training: Batch 545/1000. Loss of 1.0279, cover loss of 0.8386, secret loss of 0.8621
# Training: Batch 546/1000. Loss of 1.0905, cover loss of 0.8351, secret loss of 0.9274
# Training: Batch 547/1000. Loss of 1.3784, cover loss of 1.0032, secret loss of 1.0218
# Training: Batch 548/1000. Loss of 1.1419, cover loss of 0.8682, secret loss of 0.9645
# Training: Batch 549/1000. Loss of 1.2177, cover loss of 0.9813, secret loss of 0.9397
# Training: Batch 550/1000. Loss of 1.2382, cover loss of 0.8902, secret loss of 1.0142
# Training: Batch 551/1000. Loss of 1.0698, cover loss of 0.9258, secret loss of 0.8276
# Training: Batch 552/1000. Loss of 1.1871, cover loss of 0.8715, secret loss of 0.9812
# Training: Batch 553/1000. Loss of 1.1887, cover loss of 0.8761, secret loss of 0.9946
# Training: Batch 554/1000. Loss of 1.0126, cover loss of 0.9016, secret loss of 0.7934
# Training: Batch 555/1000. Loss of 1.0205, cover loss of 0.8836, secret loss of 0.8282
# Training: Batch 556/1000. Loss of 1.1327, cover loss of 0.8668, secret loss of 0.9265
# Training: Batch 557/1000. Loss of 1.0111, cover loss of 0.7845, secret loss of 0.8720
# Training: Batch 558/1000. Loss of 1.2318, cover loss of 0.8874, secret loss of 1.0222
# Training: Batch 559/1000. Loss of 1.2151, cover loss of 1.0259, secret loss of 0.8689
# Training: Batch 560/1000. Loss of 1.0950, cover loss of 0.9043, secret loss of 0.8601
# Training: Batch 561/1000. Loss of 1.0869, cover loss of 0.8483, secret loss of 0.8903
# Training: Batch 562/1000. Loss of 1.0982, cover loss of 0.9493, secret loss of 0.8270
# ...
# Training: Batch 816/1000. Loss of 1.2184, cover loss of 0.9300, secret loss of 0.9790
# Training: Batch 817/1000. Loss of 1.3040, cover loss of 0.9660, secret loss of 1.0243
# Training: Batch 818/1000. Loss of 1.0717, cover loss of 0.8484, secret loss of 0.8858
# Training: Batch 819/1000. Loss of 1.0514, cover loss of 0.8065, secret loss of 0.8773
# Training: Batch 820/1000. Loss of 1.0564, cover loss of 0.8204, secret loss of 0.8976
# Training: Batch 821/1000. Loss of 1.1699, cover loss of 0.9537, secret loss of 0.8909
# Training: Batch 822/1000. Loss of 1.2397, cover loss of 1.0003, secret loss of 0.9365
# Training: Batch 823/1000. Loss of 0.9187, cover loss of 0.7836, secret loss of 0.7901
# Training: Batch 824/1000. Loss of 1.0277, cover loss of 0.7813, secret loss of 0.8957
# Training: Batch 825/1000. Loss of 1.0721, cover loss of 0.8458, secret loss of 0.9057
# Training: Batch 826/1000. Loss of 1.0956, cover loss of 0.8705, secret loss of 0.8991
# Training: Batch 827/1000. Loss of 1.2013, cover loss of 0.9630, secret loss of 0.9261
# Training: Batch 828/1000. Loss of 1.1538, cover loss of 0.9441, secret loss of 0.8707
# Training: Batch 829/1000. Loss of 1.1291, cover loss of 0.7930, secret loss of 0.9873
# Training: Batch 830/1000. Loss of 1.0745, cover loss of 0.9118, secret loss of 0.8494
# Training: Batch 831/1000. Loss of 1.1284, cover loss of 0.9496, secret loss of 0.8491
# Training: Batch 832/1000. Loss of 1.0468, cover loss of 0.7538, secret loss of 0.9473
# Training: Batch 833/1000. Loss of 1.1820, cover loss of 0.9070, secret loss of 0.9855
# Training: Batch 834/1000. Loss of 1.1065, cover loss of 0.8865, secret loss of 0.9094
# Training: Batch 835/1000. Loss of 1.0875, cover loss of 0.8088, secret loss of 0.9360
# Training: Batch 836/1000. Loss of 1.1647, cover loss of 0.8590, secret loss of 0.9768
# Training: Batch 837/1000. Loss of 1.1099, cover loss of 0.8662, secret loss of 0.9018
# Training: Batch 838/1000. Loss of 1.1796, cover loss of 0.8882, secret loss of 0.9766
# Training: Batch 839/1000. Loss of 1.0562, cover loss of 0.8238, secret loss of 0.8676
# Training: Batch 840/1000. Loss of 1.1831, cover loss of 0.9580, secret loss of 0.9220
# Training: Batch 841/1000. Loss of 1.1050, cover loss of 0.8848, secret loss of 0.8644
# Training: Batch 842/1000. Loss of 1.2859, cover loss of 0.9359, secret loss of 1.0317
# Training: Batch 843/1000. Loss of 1.0041, cover loss of 0.8393, secret loss of 0.8275
# Training: Batch 844/1000. Loss of 1.0546, cover loss of 0.9245, secret loss of 0.7677
# Training: Batch 845/1000. Loss of 1.1169, cover loss of 0.7982, secret loss of 0.9735
# Training: Batch 846/1000. Loss of 1.1193, cover loss of 0.9114, secret loss of 0.8876
# Training: Batch 847/1000. Loss of 1.1032, cover loss of 0.7861, secret loss of 0.9690
# Training: Batch 848/1000. Loss of 1.1431, cover loss of 0.9479, secret loss of 0.8613
# Training: Batch 849/1000. Loss of 1.0841, cover loss of 0.8924, secret loss of 0.8665
# Training: Batch 850/1000. Loss of 1.0011, cover loss of 0.7776, secret loss of 0.9015
# Training: Batch 851/1000. Loss of 1.1435, cover loss of 0.8026, secret loss of 1.0271
# Training: Batch 852/1000. Loss of 1.1096, cover loss of 0.7798, secret loss of 0.9924
# Training: Batch 853/1000. Loss of 1.1995, cover loss of 0.8540, secret loss of 1.0081
# Training: Batch 854/1000. Loss of 1.2033, cover loss of 0.9745, secret loss of 0.9276
# Training: Batch 855/1000. Loss of 1.1049, cover loss of 0.8571, secret loss of 0.9079
# Training: Batch 856/1000. Loss of 0.9466, cover loss of 0.8342, secret loss of 0.7686
# Training: Batch 857/1000. Loss of 1.0372, cover loss of 0.8151, secret loss of 0.8942
# Training: Batch 858/1000. Loss of 0.9790, cover loss of 0.8185, secret loss of 0.7981
# Training: Batch 859/1000. Loss of 1.0972, cover loss of 0.8349, secret loss of 0.9087
# Training: Batch 860/1000. Loss of 1.0928, cover loss of 0.7732, secret loss of 0.9451
# Training: Batch 861/1000. Loss of 1.0558, cover loss of 0.8665, secret loss of 0.8495
# Training: Batch 862/1000. Loss of 1.0038, cover loss of 0.8393, secret loss of 0.8303
# Training: Batch 863/1000. Loss of 1.1437, cover loss of 0.9108, secret loss of 0.9238
# Training: Batch 864/1000. Loss of 1.0851, cover loss of 0.8449, secret loss of 0.9021
# Training: Batch 865/1000. Loss of 1.1260, cover loss of 0.8103, secret loss of 0.9633
# Training: Batch 866/1000. Loss of 1.1706, cover loss of 0.9425, secret loss of 0.9165
# Training: Batch 867/1000. Loss of 1.2771, cover loss of 1.0120, secret loss of 0.9454
# Training: Batch 868/1000. Loss of 1.2069, cover loss of 0.9127, secret loss of 0.9494
# Training: Batch 869/1000. Loss of 1.1237, cover loss of 0.9607, secret loss of 0.8395
# Training: Batch 870/1000. Loss of 1.0234, cover loss of 0.8204, secret loss of 0.8676
# Training: Batch 871/1000. Loss of 1.2132, cover loss of 0.9545, secret loss of 0.9859
# Training: Batch 872/1000. Loss of 0.9597, cover loss of 0.7854, secret loss of 0.8180
# Training: Batch 873/1000. Loss of 1.2521, cover loss of 0.8769, secret loss of 1.0533
# Training: Batch 874/1000. Loss of 1.1233, cover loss of 0.8759, secret loss of 0.9312
# Training: Batch 875/1000. Loss of 1.1976, cover loss of 0.9443, secret loss of 0.9244
# Training: Batch 876/1000. Loss of 0.9861, cover loss of 0.8114, secret loss of 0.8327
# Training: Batch 877/1000. Loss of 1.0875, cover loss of 0.8971, secret loss of 0.8662
# Training: Batch 878/1000. Loss of 1.2742, cover loss of 0.9241, secret loss of 1.0113
# Training: Batch 879/1000. Loss of 1.1110, cover loss of 0.8101, secret loss of 0.9331
# Training: Batch 880/1000. Loss of 1.2448, cover loss of 0.8995, secret loss of 1.0124
# Training: Batch 881/1000. Loss of 1.1075, cover loss of 0.9715, secret loss of 0.8192
# Training: Batch 882/1000. Loss of 1.3284, cover loss of 1.0110, secret loss of 1.0058
# Training: Batch 883/1000. Loss of 1.0203, cover loss of 0.7857, secret loss of 0.8989
# Training: Batch 884/1000. Loss of 1.0149, cover loss of 0.8443, secret loss of 0.8195
# Training: Batch 885/1000. Loss of 1.1657, cover loss of 0.8993, secret loss of 0.9302
# Training: Batch 886/1000. Loss of 1.0547, cover loss of 0.8700, secret loss of 0.8595
# Training: Batch 887/1000. Loss of 1.1944, cover loss of 0.9491, secret loss of 0.9249
# Training: Batch 888/1000. Loss of 1.1029, cover loss of 0.8612, secret loss of 0.9128
# Training: Batch 889/1000. Loss of 1.0125, cover loss of 0.9298, secret loss of 0.7491
# Training: Batch 890/1000. Loss of 1.1047, cover loss of 0.9167, secret loss of 0.8692
# Training: Batch 891/1000. Loss of 1.1367, cover loss of 0.9221, secret loss of 0.8936
# Training: Batch 892/1000. Loss of 0.9819, cover loss of 0.7480, secret loss of 0.8585
# Training: Batch 893/1000. Loss of 1.0351, cover loss of 0.8786, secret loss of 0.8112
# Training: Batch 894/1000. Loss of 1.1411, cover loss of 0.8938, secret loss of 0.9089
# Training: Batch 895/1000. Loss of 1.1433, cover loss of 0.9795, secret loss of 0.7984
# Training: Batch 896/1000. Loss of 1.1429, cover loss of 0.8725, secret loss of 0.9454
# Training: Batch 897/1000. Loss of 1.0933, cover loss of 0.9139, secret loss of 0.8284
# Training: Batch 898/1000. Loss of 1.0428, cover loss of 0.7781, secret loss of 0.9001
# Training: Batch 899/1000. Loss of 1.1286, cover loss of 0.8603, secret loss of 0.9402
# Training: Batch 900/1000. Loss of 1.0545, cover loss of 0.7381, secret loss of 0.9792
# Training: Batch 901/1000. Loss of 1.1780, cover loss of 0.9165, secret loss of 0.9508
# Training: Batch 902/1000. Loss of 1.1672, cover loss of 0.8642, secret loss of 0.9852
# Training: Batch 903/1000. Loss of 1.0839, cover loss of 0.8899, secret loss of 0.8729
# Training: Batch 904/1000. Loss of 0.9849, cover loss of 0.8480, secret loss of 0.7962
# Training: Batch 905/1000. Loss of 1.2265, cover loss of 0.9370, secret loss of 0.9457
# Training: Batch 906/1000. Loss of 1.2336, cover loss of 0.9679, secret loss of 0.9363
# Training: Batch 907/1000. Loss of 1.0735, cover loss of 0.8982, secret loss of 0.8445
# Training: Batch 908/1000. Loss of 1.0531, cover loss of 0.8559, secret loss of 0.8714
# Training: Batch 909/1000. Loss of 0.9723, cover loss of 0.8196, secret loss of 0.7791
# Training: Batch 910/1000. Loss of 1.1111, cover loss of 0.9444, secret loss of 0.8644
# Training: Batch 911/1000. Loss of 1.0604, cover loss of 0.8157, secret loss of 0.9309
# Training: Batch 912/1000. Loss of 1.1695, cover loss of 0.8239, secret loss of 0.9957
# Training: Batch 913/1000. Loss of 1.2210, cover loss of 0.9257, secret loss of 0.9668
# Training: Batch 914/1000. Loss of 1.0554, cover loss of 0.7914, secret loss of 0.9409
# Training: Batch 915/1000. Loss of 1.1269, cover loss of 0.8910, secret loss of 0.8901
# Training: Batch 916/1000. Loss of 1.2977, cover loss of 0.9969, secret loss of 1.0335
# Training: Batch 917/1000. Loss of 1.1634, cover loss of 0.8878, secret loss of 0.9512
# Training: Batch 918/1000. Loss of 1.1360, cover loss of 0.9079, secret loss of 0.9075
# Training: Batch 919/1000. Loss of 1.1728, cover loss of 0.8620, secret loss of 0.9951
# Training: Batch 920/1000. Loss of 1.0189, cover loss of 0.7664, secret loss of 0.8988
# Training: Batch 921/1000. Loss of 1.0883, cover loss of 0.8319, secret loss of 0.8816
# Training: Batch 922/1000. Loss of 1.0789, cover loss of 0.9135, secret loss of 0.8273
# Training: Batch 923/1000. Loss of 1.1107, cover loss of 0.8706, secret loss of 0.9071
# Training: Batch 924/1000. Loss of 1.1685, cover loss of 0.9149, secret loss of 0.8971
# Training: Batch 925/1000. Loss of 1.0966, cover loss of 0.8732, secret loss of 0.8787
# Training: Batch 926/1000. Loss of 1.0148, cover loss of 0.7709, secret loss of 0.9088
# Training: Batch 927/1000. Loss of 1.1939, cover loss of 0.9750, secret loss of 0.9420
# Training: Batch 928/1000. Loss of 1.1628, cover loss of 0.8881, secret loss of 0.9313
# Training: Batch 929/1000. Loss of 1.0307, cover loss of 0.7763, secret loss of 0.9207
# Training: Batch 930/1000. Loss of 1.1420, cover loss of 0.8410, secret loss of 0.9483
# Training: Batch 931/1000. Loss of 1.0198, cover loss of 0.8004, secret loss of 0.8819
# Training: Batch 932/1000. Loss of 1.3144, cover loss of 1.0207, secret loss of 0.9789
# Training: Batch 933/1000. Loss of 1.0532, cover loss of 0.8049, secret loss of 0.8966
# Training: Batch 934/1000. Loss of 1.2130, cover loss of 0.8703, secret loss of 1.0099
# Training: Batch 935/1000. Loss of 1.0386, cover loss of 0.8021, secret loss of 0.8823
# Training: Batch 936/1000. Loss of 1.0144, cover loss of 0.7898, secret loss of 0.8515
# Training: Batch 937/1000. Loss of 1.0039, cover loss of 0.7389, secret loss of 0.9102
# Training: Batch 938/1000. Loss of 1.1105, cover loss of 0.8740, secret loss of 0.8650
# Training: Batch 939/1000. Loss of 1.1820, cover loss of 0.9635, secret loss of 0.9184
# Training: Batch 940/1000. Loss of 0.9908, cover loss of 0.8624, secret loss of 0.7489
# Training: Batch 941/1000. Loss of 1.1519, cover loss of 0.8874, secret loss of 0.9274
# Training: Batch 942/1000. Loss of 1.1471, cover loss of 0.9308, secret loss of 0.9004
# Training: Batch 943/1000. Loss of 1.1342, cover loss of 0.9579, secret loss of 0.8667
# Training: Batch 944/1000. Loss of 1.0854, cover loss of 0.8986, secret loss of 0.8758
# Training: Batch 945/1000. Loss of 1.1571, cover loss of 0.8280, secret loss of 0.9972
# Training: Batch 946/1000. Loss of 0.9435, cover loss of 0.7720, secret loss of 0.8196
# Training: Batch 947/1000. Loss of 1.0460, cover loss of 0.8674, secret loss of 0.8332
# Training: Batch 948/1000. Loss of 1.2281, cover loss of 0.9344, secret loss of 0.9884
# Training: Batch 949/1000. Loss of 1.0016, cover loss of 0.8069, secret loss of 0.8349
# Training: Batch 950/1000. Loss of 1.0547, cover loss of 0.7980, secret loss of 0.8879
# Training: Batch 951/1000. Loss of 1.0355, cover loss of 0.8096, secret loss of 0.8755
# Training: Batch 952/1000. Loss of 1.1380, cover loss of 0.8681, secret loss of 0.9207
# Training: Batch 953/1000. Loss of 1.1657, cover loss of 0.9170, secret loss of 0.9183
# Training: Batch 954/1000. Loss of 1.0442, cover loss of 0.7845, secret loss of 0.8971
# Training: Batch 955/1000. Loss of 1.1296, cover loss of 0.8808, secret loss of 0.8904
# Training: Batch 956/1000. Loss of 1.2207, cover loss of 0.8710, secret loss of 1.0324
# Training: Batch 957/1000. Loss of 1.1123, cover loss of 0.9338, secret loss of 0.8518
# Training: Batch 958/1000. Loss of 1.0129, cover loss of 0.8112, secret loss of 0.8581
# Training: Batch 959/1000. Loss of 1.1330, cover loss of 0.8945, secret loss of 0.9297
# Training: Batch 960/1000. Loss of 1.0318, cover loss of 0.9024, secret loss of 0.7865
# Training: Batch 961/1000. Loss of 1.0777, cover loss of 1.0150, secret loss of 0.7940
# Training: Batch 962/1000. Loss of 1.1620, cover loss of 0.9338, secret loss of 0.9147
# Training: Batch 963/1000. Loss of 1.2149, cover loss of 1.0137, secret loss of 0.8542
# Training: Batch 964/1000. Loss of 1.0002, cover loss of 0.8468, secret loss of 0.8029
# Training: Batch 965/1000. Loss of 1.1336, cover loss of 0.8659, secret loss of 0.9382
# Training: Batch 966/1000. Loss of 0.9973, cover loss of 0.8119, secret loss of 0.8055
# Training: Batch 967/1000. Loss of 0.9624, cover loss of 0.8437, secret loss of 0.7767
# Training: Batch 968/1000. Loss of 1.1306, cover loss of 0.8610, secret loss of 0.9526
# Training: Batch 969/1000. Loss of 1.0371, cover loss of 0.8510, secret loss of 0.8431
# Training: Batch 970/1000. Loss of 1.0471, cover loss of 0.7666, secret loss of 0.9272
# Training: Batch 971/1000. Loss of 1.2225, cover loss of 1.0081, secret loss of 0.8825
# Training: Batch 972/1000. Loss of 1.3093, cover loss of 0.9676, secret loss of 1.0321
# Training: Batch 973/1000. Loss of 1.2400, cover loss of 0.8763, secret loss of 1.0149
# Training: Batch 974/1000. Loss of 1.0018, cover loss of 0.7307, secret loss of 0.9163
# Training: Batch 975/1000. Loss of 1.1026, cover loss of 0.9087, secret loss of 0.8519
# Training: Batch 976/1000. Loss of 1.0324, cover loss of 0.8191, secret loss of 0.8730
# Training: Batch 977/1000. Loss of 1.0548, cover loss of 0.8474, secret loss of 0.8584
# Training: Batch 978/1000. Loss of 1.0615, cover loss of 0.8479, secret loss of 0.8526
# Training: Batch 979/1000. Loss of 0.9505, cover loss of 0.7189, secret loss of 0.8738
# Training: Batch 980/1000. Loss of 1.1982, cover loss of 0.9481, secret loss of 0.9324
# Training: Batch 981/1000. Loss of 0.9836, cover loss of 0.8045, secret loss of 0.8344
# Training: Batch 982/1000. Loss of 1.1085, cover loss of 0.9151, secret loss of 0.8456
# Training: Batch 983/1000. Loss of 1.0765, cover loss of 0.8603, secret loss of 0.8669
# Training: Batch 984/1000. Loss of 1.1652, cover loss of 1.0028, secret loss of 0.8440
# Training: Batch 985/1000. Loss of 1.3146, cover loss of 1.0186, secret loss of 1.0008
# Training: Batch 986/1000. Loss of 1.1046, cover loss of 0.8885, secret loss of 0.8738
# Training: Batch 987/1000. Loss of 1.2252, cover loss of 0.9084, secret loss of 0.9614
# Training: Batch 988/1000. Loss of 1.2047, cover loss of 0.9665, secret loss of 0.9210
# Training: Batch 989/1000. Loss of 1.0497, cover loss of 0.8600, secret loss of 0.8339
# Training: Batch 990/1000. Loss of 1.1404, cover loss of 0.8008, secret loss of 1.0029
# Training: Batch 991/1000. Loss of 1.2193, cover loss of 0.9215, secret loss of 0.9724
# Training: Batch 992/1000. Loss of 1.2749, cover loss of 1.0079, secret loss of 0.9611
# Training: Batch 993/1000. Loss of 1.1537, cover loss of 0.9177, secret loss of 0.9116
# Training: Batch 994/1000. Loss of 0.9862, cover loss of 0.7992, secret loss of 0.8504
# Training: Batch 995/1000. Loss of 1.0941, cover loss of 0.8217, secret loss of 0.9158
# Training: Batch 996/1000. Loss of 1.0802, cover loss of 0.8915, secret loss of 0.8680
# Training: Batch 997/1000. Loss of 1.2078, cover loss of 0.9169, secret loss of 0.9501
# Training: Batch 998/1000. Loss of 1.2635, cover loss of 0.9861, secret loss of 0.9877
# Training: Batch 999/1000. Loss of 1.1050, cover loss of 0.8497, secret loss of 0.9288
# Training: Batch 1000/1000. Loss of 1.0947, cover loss of 0.8760, secret loss of 0.8459
# Epoch [50/50], Average_loss: 1.1100

# %%
 # Plot loss through epochs
plt.plot(loss_history)
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Batch')
plt.show()

# %%
def pixel_errors(input_S, input_C, decoded_S, decoded_C):
    """Calculates mean of Sum of Squared Errors per pixel for cover and secret images. """
    input_S = np.array(input_S.detach().cpu())
    input_C = np.array(input_C.detach().cpu())
    decoded_S = np.array(decoded_S.detach().cpu())
    decoded_C = np.array(decoded_C.detach().cpu())
    # print(input_S)
    see_Spixel = np.sqrt(np.mean(np.square(255*(input_S - decoded_S))))
    see_Cpixel = np.sqrt(np.mean(np.square(255*(input_C - decoded_C))))
    
    return see_Spixel, see_Cpixel

import math
def psnr(input_S, input_C, decoded_S, decoded_C):
    input_S = np.array(input_S.detach().cpu())
    input_C = np.array(input_C.detach().cpu())
    decoded_S = np.array(decoded_S.detach().cpu())
    decoded_C = np.array(decoded_C.detach().cpu())
    mse_s = np.mean(np.square(255*(input_S - decoded_S)))
    mse_c = np.mean(np.square(255*(input_C - decoded_C)))
    psnr_s = 10*math.log10(255**2/mse_s)
    psnr_c = 10*math.log10(255**2/mse_c)
    return psnr_s, psnr_c

def pixel_histogram(diff_S, diff_C):
    """Calculates histograms of errors for cover and secret image. """
    diff_Sflat = diff_S.flatten()
    diff_Cflat = diff_C.flatten()
    
    fig = plt.figure(figsize=(15, 5))
    a=fig.add_subplot(1,2,1)
        
    imgplot = plt.hist(255* diff_Cflat, 100, density=1, alpha=0.75, facecolor='red')
    a.set_title('Distribution of error in the Cover image.')
    plt.axis([0, 250, 0, 0.2])
    
    a=fig.add_subplot(1,2,2)
    imgplot = plt.hist(255* diff_Sflat, 100, density=1, alpha=0.75, facecolor='red')
    a.set_title('Distribution of errors in the Secret image.')
    plt.axis([0, 250, 0, 0.2])
    
    plt.show()

# %%
# net.load_state_dict(torch.load(MODELS_PATH+'Epoch N4.pkl'))

# Switch to evaluate mode
net.eval()
Path(PATH+"LOSS1_ds_img_30").mkdir(parents=True, exist_ok=True)
Path(PATH+"LOSS1_ds_img_30/cover_images/").mkdir(parents=True, exist_ok=True)
Path(PATH+"LOSS1_ds_img_30/container_images/").mkdir(parents=True, exist_ok=True)
save_path = PATH+"LOSS1_ds_img_30/"

test_losses = []

S_errors = []
C_errors = []

psnr_s,psnr_c = [], []
# Show images
for idx, test_batch in enumerate(test_loader):
     # Saves images
    data, _ = test_batch
    data = data.to(device)

    # Saves secret images and secret covers
    test_secret = data[:len(data)//2]
    test_cover = data[len(data)//2:]

    # Creates variable from secret and cover images
    test_secret = Variable(test_secret, volatile=True)
    test_cover = Variable(test_cover, volatile=True)

    # Compute output
    test_hidden, test_output = net(test_secret, test_cover)
    
    # Calculate loss
    test_loss, loss_cover, loss_secret = customized_loss(test_output, test_hidden, test_secret, test_cover, beta)
    
    diff_S, diff_C = np.abs(np.array(test_output.data.detach().cpu()) - np.array(test_secret.data.detach().cpu())), np.abs(np.array(test_hidden.data.detach().cpu()) - np.array(test_cover.data.detach().cpu()))
    
#     print (diff_S, diff_C)

    # Print pixel-wise average errors in a 256 scale.
    S_error, C_error = pixel_errors(test_secret, test_cover, test_output, test_hidden)
    S_errors.append(S_error)
    C_errors.append(C_error)

    S_psnr, C_psnr = psnr(test_secret, test_cover, test_output, test_hidden)
    psnr_s.append(S_psnr)
    psnr_c.append(C_psnr)
    
    if idx in [1,2,3,4]:
        print ('Total loss: {:.2f} \nLoss on secret: {:.2f} \nLoss on cover: {:.2f}'.format(test_loss.data.item(), loss_secret.data.item(), loss_cover.data.item()))

        # Creates img tensor
        imgs = [test_secret.data.detach().cpu(), test_output.data.detach().cpu(), test_cover.data.detach().cpu(), test_hidden.data.detach().cpu()]
        imgs_tsor = torch.cat(imgs, 0)

        # Prints Images
        imshow(utils.make_grid(imgs_tsor), idx+1, learning_rate=learning_rate, beta=beta)

    if idx < 500:
        container_img = tensor_to_image(test_hidden.data.detach().cpu())
        container_img = Image.fromarray(container_img)
        container_img.save(save_path+"container_images/"+str(idx)+".jpeg")
        cover_img = tensor_to_image(test_cover.data.detach().cpu())
        cover_img = Image.fromarray(cover_img)
        cover_img.save(save_path+"cover_images/"+str(idx)+".jpeg")
            
    test_losses.append(test_loss.data.item())
        
mean_test_loss = np.mean(test_losses)

print ('Average loss on test set: {:.2f}'.format(mean_test_loss))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:27: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:43: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
# Total loss: 1.69
# Loss on secret: 1.37
# Loss on cover: 1.40
# Total loss: 1.12
# Loss on secret: 0.84
# Loss on cover: 1.07
# Total loss: 1.34
# Loss on secret: 1.09
# Loss on cover: 0.96
# Total loss: 1.72
# Loss on secret: 1.06
# Loss on cover: 1.55
# Average loss on test set: 1.08

# %%
print ("Avg. S error per pixel [0, 255]:", sum(S_errors)/len(S_errors))
print ("Avg. C error per pixel [0, 255]:", sum(C_errors)/len(C_errors))
# Out:
# Avg. S error per pixel [0, 255]: 285.6967474975586
# Avg. C error per pixel [0, 255]: 281.28410668029784

# %%
print ("Avg. PSNR of secret and decoded secret:", sum(psnr_s)/len(psnr_s))
print ("Avg. PSNR of cover and container:", sum(psnr_c)/len(psnr_c))
# Out:
# Avg. PSNR of secret and decoded secret: -0.7722640282639328
# Avg. PSNR of cover and container: -0.6361328182676971

# %%
# Plot distribution of errors in cover and secret images.
pixel_histogram(diff_S, diff_C)
